# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
SMC Swing Backtester (Long-only) — Weekly Bias + Daily Execution
-----------------------------------------------------------------

Replaces prior EMA/RSI/ADX logic with Smart Money Concepts:

DETECTION (on each timeframe):
  • Swing highs/lows via left/right windows
  • Market Structure Events: BOS_up / BOS_down / CHoCH_up / CHoCH_down
  • Liquidity Sweeps: price takes prior swing low/high and closes back inside
  • Fair Value Gaps (FVG): simple 3-candle imbalance
  • Order Blocks (OB): last opposing candle body before BOS

STRATEGY (long-only):
  • Bias (Weekly): trend == 'up' (from structure) OR recent BOS_up/CHoCH_up on WEEKLY
  • Trigger (Daily): (recent sweep_low in last N bars) OR (recent CHoCH_up/BOS_up on DAILY)
  • Optional momentum confirm: Daily close > prior Daily high
  • Entry: at next day's open by default (configurable)
  • Stop: OB-low if present else ATR(14)*k below entry (intrabar checks)
  • Targets: TP1=1R (move SL→BE), TP2=2R; Structure flip (CHoCH_down) or Time stop exits

PORTFOLIO:
  • Your fee model preserved
  • Optional 52-week proximity filter before allocating
  • VOLAR ranking + long-only Markowitz sizing
  • Max concurrent positions + capped deployable cash per day

NOTES:
  • No EMA/RSI/ADX anywhere; ATR is used *only* for risk.
  • Uses yfinance EOD data for both Weekly (via resample) and Daily.

"""

import os, json, math, warnings, logging
from dataclasses import dataclass
from typing import Dict, List, Tuple, Optional

import numpy as np
import pandas as pd

try:
    import yfinance as yf
    import matplotlib.pyplot as plt
except Exception:
    pass

warnings.filterwarnings("ignore", category=FutureWarning)

# =========================
# LOGGING
# =========================
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)
log = logging.getLogger("smc_swing_long_only_WD")

# =========================
# CONFIG
# =========================
@dataclass
class Config:
    # Data
    start_date: str = "2015-01-01"
    end_date: str   = "2025-01-01"
    static_symbols: Optional[List[str]] = None       # e.g., ["RELIANCE.NS", ...]
    static_symbols_path: Optional[str] = None        # or path to file with one symbol per line
    cache_dir: str = "cache"
    out_dir: str   = "outputs"
    plot: bool     = True

    # --- SMC params (Daily) ---
    swing_left_D: int = 2
    swing_right_D: int = 2
    min_fvg_gap_pct_D: float = 0.02   # 0.02% gap
    lookback_D: int = 5000

    # --- SMC params (Weekly bias) ---
    swing_left_W: int = 2
    swing_right_W: int = 2
    min_fvg_gap_pct_W: float = 0.02
    lookback_W: int = 2000

    # Entry recipe (Daily execution)
    recent_sweep_lookback: int = 10
    require_fvg_or_ob: bool = False   # loosened: sweep OR structure is enough; FVG/OB optional
    momentum_confirm: bool = False    # loosened: allow entries without D close > prior high

    # Exits
    atr_len: int = 14
    atr_mult_sl: float = 1.5
    rr_tp1: float = 1.0
    rr_tp2: float = 2.0
    time_stop_bars: int = 15
    exit_on_next_open: bool = True
    entry_on_next_open: bool = True

    # Portfolio / universe
    apply_fees: bool    = True
    initial_capital: float = 200_000.0
    max_concurrent_positions: int = 6
    deploy_cash_frac: float = 0.35    # cap daily deployable cash

    # Ranking / filters
    benchmark_try: Tuple[str,...] = ("^CNX500","^CRSLDX","^NSE500","^NIFTY500","^BSE500","^NSEI")
    volar_lookback: int = 252
    filter_52w_window: int = 252
    within_pct_of_52w_high: float = 0.60
    enable_52w_filter: bool = True
    top_k_daily: int = 4

CFG = Config()

# =========================
# FEES (unchanged)
# =========================
APPLY_FEES = True
def calc_fees(turnover_buy: float, turnover_sell: float) -> float:
    if not APPLY_FEES:
        return 0.0
    BROKER_PCT = 0.001
    BROKER_MIN = 5.0
    BROKER_CAP = 20.0
    STT_PCT = 0.001
    STAMP_BUY_PCT = 0.00015
    EXCH_PCT = 0.0000297
    SEBI_PCT = 0.000001
    IPFT_PCT = 0.000001
    GST_PCT = 0.18
    DP_SELL = 20.0 if turnover_sell >= 100 else 0.0

    def _broker(turnover):
        if turnover <= 0:
            return 0.0
        fee = turnover * BROKER_PCT
        fee = max(BROKER_MIN, min(fee, BROKER_CAP))
        return fee

    br_buy  = _broker(turnover_buy)
    br_sell = _broker(turnover_sell)
    stt   = STT_PCT * (turnover_buy + turnover_sell)
    stamp = STAMP_BUY_PCT * turnover_buy
    exch  = EXCH_PCT * (turnover_buy + turnover_sell)
    sebi  = SEBI_PCT * (turnover_buy + turnover_sell)
    ipft  = IPFT_PCT * (turnover_buy + turnover_sell)
    dp    = DP_SELL
    gst_base = br_buy + br_sell + dp + exch + sebi + ipft
    gst   = GST_PCT * gst_base
    return float((br_buy + br_sell) + stt + stamp + exch + sebi + ipft + dp + gst)

# =========================
# Helpers
# =========================
def ensure_dirs(*paths):
    for p in paths:
        os.makedirs(p, exist_ok=True)

def today_str():
    return pd.Timestamp.today(tz="Asia/Kolkata").strftime("%Y-%m-%d")

def load_static_symbols(static_symbols: Optional[List[str]], static_symbols_path: Optional[str]) -> List[str]:
    syms: List[str] = []
    if static_symbols and len(static_symbols) > 0:
        syms = list(static_symbols)
    elif static_symbols_path and os.path.exists(static_symbols_path):
        with open(static_symbols_path, "r") as f:
            syms = [line.strip() for line in f if line.strip()]
    else:
        raise ValueError(
            "Provide CFG.static_symbols=[...] ('.NS' suffixes) or set CFG.static_symbols_path "
            "to a file containing one symbol per line."
        )
    out = []
    for s in syms:
        s = s.strip().upper()
        if not s.endswith(".NS"):
            s = f"{s}.NS"
        out.append(s)
    seen = set(); uniq = []
    for s in out:
        if s not in seen:
            uniq.append(s); seen.add(s)
    return uniq

def fetch_prices(tickers: List[str], start: str, end: Optional[str], cache_dir: str) -> Dict[str, pd.DataFrame]:
    ensure_dirs(cache_dir)
    data = {}
    end = end or today_str()
    for ticker in tickers:
        cache_path = os.path.join(cache_dir, f"{ticker.replace('^', '_')}.parquet")
        if os.path.exists(cache_path):
            try:
                df = pd.read_parquet(cache_path)
                if len(df) and pd.to_datetime(df.index[-1]).strftime("%Y-%m-%d") >= end:
                    data[ticker] = df
                    continue
            except Exception:
                pass
        try:
            df = yf.download(ticker, start=start, end=end, auto_adjust=True, progress=False, multi_level_index=False)
            if df is None or df.empty:
                continue
            df = df.rename(columns=str.title)  # Open, High, Low, Close, Volume
            df = df[['Open', 'High', 'Low', 'Close', 'Volume']].dropna()
            df.index.name = "date"
            data[ticker] = df
            df.to_parquet(cache_path)
        except Exception:
            continue
    return data

# =========================
# Risk (ATR)
# =========================
def ATR(df: pd.DataFrame, n=14) -> pd.Series:
    h, l, c = df['High'], df['Low'], df['Close']
    tr = pd.concat([
        (h - l),
        (h - c.shift()).abs(),
        (l - c.shift()).abs()
    ], axis=1).max(axis=1)
    return tr.rolling(n, min_periods=n).mean()

# =========================
# -------- SMC CORE -------
# =========================
@dataclass
class SMCParams:
    swing_left: int = 2
    swing_right: int = 2
    min_gap_pct: float = 0.02  # e.g., 0.02% -> 0.0002
    lookback: int = 5000

def _swing_points(df: pd.DataFrame, L: int, R: int) -> Tuple[pd.Series, pd.Series]:
    h, l = df['High'].values, df['Low'].values
    n = len(df)
    swing_high = np.zeros(n, dtype=bool)
    swing_low  = np.zeros(n, dtype=bool)
    for i in range(L, n - R):
        if h[i] == max(h[i-L:i+R+1]): swing_high[i] = True
        if l[i] == min(l[i-L:i+R+1]): swing_low[i]  = True
    return pd.Series(swing_high, index=df.index), pd.Series(swing_low, index=df.index)

def detect_market_structure(df: pd.DataFrame, prm: SMCParams) -> pd.DataFrame:
    out = df.copy()
    sh, sl = _swing_points(df, prm.swing_left, prm.swing_right)
    out['swing_high'] = sh
    out['swing_low']  = sl
    trend = []; event = []
    last_trend = None
    last_sh = np.nan; last_sl = np.nan
    for _, row in out.iterrows():
        if row['swing_high']: last_sh = row['High']
        if row['swing_low']:  last_sl = row['Low']
        e = None
        if np.isfinite(last_sh) and row['Close'] > last_sh:
            e = "BOS_up" if last_trend == 'up' else "CHoCH_up"; last_trend = 'up'
        elif np.isfinite(last_sl) and row['Close'] < last_sl:
            e = "BOS_down" if last_trend == 'down' else "CHoCH_down"; last_trend = 'down'
        trend.append(last_trend); event.append(e)
    out['trend'] = trend
    out['ms_event'] = event
    return out

def detect_fvg(df: pd.DataFrame, prm: SMCParams) -> pd.DataFrame:
    out = df.copy()
    up_fvg = np.zeros(len(df), dtype=bool)
    dn_fvg = np.zeros(len(df), dtype=bool)
    pct = prm.min_gap_pct / 100.0
    for i in range(2, len(df)):
        if df['Low'].iat[i] > df['High'].iat[i-2]:
            gap = (df['Low'].iat[i] - df['High'].iat[i-2]) / df['High'].iat[i-2]
            if gap >= pct: up_fvg[i] = True
        if df['High'].iat[i] < df['Low'].iat[i-2]:
            gap = (df['Low'].iat[i-2] - df['High'].iat[i]) / df['Low'].iat[i-2]
            if gap >= pct: dn_fvg[i] = True
    out['fvg_up'] = up_fvg; out['fvg_down'] = dn_fvg
    return out

def detect_liquidity_sweeps(df: pd.DataFrame, prm: SMCParams) -> pd.DataFrame:
    out = df.copy()
    sh, sl = _swing_points(df, prm.swing_left, prm.swing_right)
    sweep_hi = np.zeros(len(df), dtype=bool)
    sweep_lo = np.zeros(len(df), dtype=bool)
    swing_high_levels: List[float] = []; swing_low_levels: List[float] = []
    for i in range(len(df)):
        if sh.iat[i]: swing_high_levels.append(df['High'].iat[i])
        if sl.iat[i]: swing_low_levels.append(df['Low'].iat[i])
        if swing_high_levels:
            lvl = max(swing_high_levels)
            if df['High'].iat[i] > lvl and df['Close'].iat[i] < lvl: sweep_hi[i] = True
        if swing_low_levels:
            lvl = min(swing_low_levels)
            if df['Low'].iat[i] < lvl and df['Close'].iat[i] > lvl: sweep_lo[i] = True
    out['sweep_high'] = sweep_hi; out['sweep_low'] = sweep_lo
    return out

def detect_order_blocks(df: pd.DataFrame, ms: pd.DataFrame) -> pd.DataFrame:
    out = df.copy()
    out['bull_ob_low'] = np.nan; out['bull_ob_high'] = np.nan
    out['bear_ob_low'] = np.nan; out['bear_ob_high'] = np.nan
    last_down = None; last_up = None
    for i in range(len(df)):
        o, c = df['Open'].iat[i], df['Close'].iat[i]
        if c < o: last_down = (min(o,c), max(o,c))
        elif c > o: last_up = (min(o,c), max(o,c))
        ev = ms['ms_event'].iat[i] if 'ms_event' in ms.columns else None
        if ev == 'BOS_up' and last_down:
            lo, hi = last_down
            out.loc[df.index[i], ['bull_ob_low','bull_ob_high']] = (lo, hi)
        if ev == 'BOS_down' and last_up:
            lo, hi = last_up
            out.loc[df.index[i], ['bear_ob_low','bear_ob_high']] = (lo, hi)
    return out

def run_smc_pipeline(df: pd.DataFrame, prm: SMCParams) -> pd.DataFrame:
    d = df.copy().iloc[-prm.lookback:].dropna()
    ms  = detect_market_structure(d, prm)
    fvg = detect_fvg(d, prm)
    lq  = detect_liquidity_sweeps(d, prm)
    ob  = detect_order_blocks(d, ms)
    out = d.join(ms[['swing_high','swing_low','trend','ms_event']], how='left')
    out = out.join(fvg[['fvg_up','fvg_down']], how='left')
    out = out.join(lq[['sweep_high','sweep_low']], how='left')
    out = out.join(ob[['bull_ob_low','bull_ob_high','bear_ob_low','bear_ob_high']], how='left')
    return out

# =========================
# VOLAR + MVO (unchanged)
# =========================
def pick_benchmark(benchmarks: Tuple[str,...], start: str, end: Optional[str], cache_dir: str) -> Tuple[str, pd.DataFrame]:
    for t in benchmarks:
        data = fetch_prices([t], start, end, cache_dir)
        df = data.get(t)
        if df is not None and not df.empty:
            log.info("Using benchmark: %s", t)
            return t, df
    idx = pd.date_range(start=start, end=end or today_str(), freq="B")
    df = pd.DataFrame({"Close": np.ones(len(idx))}, index=idx)
    log.warning("No benchmark found; using synthetic flat series.")
    return "SYNTH_BENCH", df

def compute_volar_scores(end_dt: pd.Timestamp, tickers: List[str], data_map: Dict[str,pd.DataFrame], bench_df: pd.DataFrame, lookback: int) -> Dict[str, float]:
    scores = {}
    bser = bench_df["Close"].loc[:end_dt].pct_change().dropna().iloc[-lookback:]
    for t in tickers:
        df = data_map.get(t)
        if df is None or df.empty:
            scores[t] = 0.0; continue
        if end_dt not in df.index:
            df = df[df.index <= end_dt]
            if df.empty:
                scores[t] = 0.0; continue
        r = df["Close"].loc[:end_dt].pct_change().dropna().iloc[-lookback:]
        common = pd.concat([r, bser], axis=1, keys=["s","b"]).dropna()
        if common.shape[0] < max(20, int(0.4*lookback)):
            scores[t] = 0.0; continue
        excess = common["s"] - common["b"]
        vol = common["s"].std(ddof=0)
        scores[t] = 0.0 if vol <= 1e-8 else float((excess.mean() / vol) * math.sqrt(252.0))
    return scores

def markowitz_long_only(mu: np.ndarray, Sigma: np.ndarray) -> np.ndarray:
    n = len(mu); eps = 1e-6
    Sigma = Sigma + eps*np.eye(n)
    best_w = np.full(n, 1.0/n); best_sr = -1e9
    lambdas = np.logspace(-3, 3, 31)

    def solve_masked(lmbd, mask):
        idx = np.where(mask)[0]
        S = Sigma[np.ix_(idx, idx)]
        o = np.ones(len(idx))
        m = mu[idx]
        A = np.block([[2*lmbd*S, o[:,None]],[o[None,:], np.zeros((1,1))]])
        b = np.concatenate([m, np.array([1.0])])
        try:
            sol = np.linalg.solve(A, b)
            w_sub = sol[:len(idx)]
        except np.linalg.LinAlgError:
            w_sub = np.full(len(idx), 1.0/len(idx))
        w = np.zeros(n); w[idx] = w_sub
        return w

    for lmbd in lambdas:
        active = np.ones(n, dtype=bool)
        for _ in range(n):
            w = solve_masked(lmbd, active)
            if (w >= 0).all(): break
            active[np.argmin(w)] = False
        w = np.clip(w, 0, None)
        if w.sum() <= 0: continue
        w = w / w.sum()
        mu_p = float(mu @ w); vol_p = float(np.sqrt(w @ Sigma @ w))
        if vol_p <= 1e-8: continue
        sr = mu_p / vol_p
        if sr > best_sr:
            best_sr = sr; best_w = w.copy()
    return best_w

# =========================
# Utilities for signals
# =========================
def _recent_true(series_bool: pd.Series, window: int) -> pd.Series:
    return series_bool.astype(int).rolling(window, min_periods=1).max().gt(0)

def _weekly_from_daily(df: pd.DataFrame) -> pd.DataFrame:
    """OHLCV weekly (Fri close) using resample('W-FRI')."""
    W = pd.DataFrame(index=df.index)
    out = pd.DataFrame({
        "Open": df["Open"].resample("W-FRI").first(),
        "High": df["High"].resample("W-FRI").max(),
        "Low":  df["Low"].resample("W-FRI").min(),
        "Close":df["Close"].resample("W-FRI").last(),
        "Volume": df["Volume"].resample("W-FRI").sum()
    }).dropna()
    out.index.name = "date"
    return out

# =========================
# SMC LONG-ONLY (Weekly bias + Daily exec)
# =========================
def simulate_ticker_smc_long_WD(ticker: str, dfD: pd.DataFrame, cfg: Config):
    """
    Weekly SMC for bias; Daily SMC for entries/exits.
    """
    # --- WEEKLY (bias) ---
    dfW = _weekly_from_daily(dfD)
    smcW = run_smc_pipeline(
        dfW,
        SMCParams(
            swing_left=cfg.swing_left_W,
            swing_right=cfg.swing_right_W,
            min_gap_pct=cfg.min_fvg_gap_pct_W,
            lookback=cfg.lookback_W
        )
    )

    # Bias: weekly trend up OR recent BOS_up / CHoCH_up (weekly)
    biasW = (
        smcW['trend'].eq('up') |
        _recent_true(smcW['ms_event'].eq('BOS_up'), 5) |
        _recent_true(smcW['ms_event'].eq('CHoCH_up'), 5)
    ).astype(bool)

    # Forward-fill weekly bias onto daily dates
    biasW_D = biasW.reindex(dfD.index, method="ffill").fillna(False)

    # --- DAILY (entries/exits) ---
    smcD = run_smc_pipeline(
        dfD,
        SMCParams(
            swing_left=cfg.swing_left_D,
            swing_right=cfg.swing_right_D,
            min_gap_pct=cfg.min_fvg_gap_pct_D,
            lookback=cfg.lookback_D
        )
    )
    smcD = smcD.copy()
    smcD['atr'] = ATR(smcD, n=cfg.atr_len)

    # Triggers: (recent sweep_low) OR (recent CHoCH_up/BOS_up on Daily)
    trig_sweep = _recent_true(smcD['sweep_low'].fillna(False), cfg.recent_sweep_lookback)
    trig_struct = (
        _recent_true(smcD['ms_event'].eq('CHoCH_up'), 5) |
        _recent_true(smcD['ms_event'].eq('BOS_up'), 5)
    )
    triggerD = (trig_sweep | trig_struct)

    # Optional extra filter: FVG_up or bull_OB present (relaxed by default)
    if cfg.require_fvg_or_ob:
        triggerD = triggerD & (smcD['fvg_up'] | (~smcD['bull_ob_low'].isna()))

    # Momentum confirm (optional): close > prior high
    momentum = (smcD['Close'] > smcD['High'].shift(1)) if cfg.momentum_confirm else pd.Series(True, index=smcD.index)

    entry_bar = (biasW_D & triggerD & momentum).fillna(False)

    # Walk forward and create trades
    trades = []
    in_pos = False
    entry_px = sl = tp1 = tp2 = 0.0
    hit_tp1 = False
    bars_left = 0

    idx = list(smcD.index)
    for i in range(len(idx) - 1):
        dt, nxt = idx[i], idx[i+1]
        row, nxt_row = smcD.loc[dt], smcD.loc[nxt]

        if not in_pos:
            if entry_bar.loc[dt]:
                px = float(nxt_row["Open"] if cfg.entry_on_next_open else row["Close"])
                ob_low = row['bull_ob_low'] if pd.notna(row['bull_ob_low']) else np.nan
                atr_sl = px - cfg.atr_mult_sl * float(row['atr'])
                sl = float(min(ob_low, atr_sl)) if pd.notna(ob_low) else float(atr_sl)
                risk = max(1e-6, px - sl)
                tp1 = float(px + cfg.rr_tp1 * risk)
                tp2 = float(px + cfg.rr_tp2 * risk)
                in_pos = True
                hit_tp1 = False
                bars_left = cfg.time_stop_bars

                sig_reason = (
                    f"BiasW_up={bool(biasW_D.loc[dt])}; "
                    f"Trig=(sweep≤{cfg.recent_sweep_lookback} or recent BOS/CHoCH up D); "
                    f"{'FVG/OB req' if cfg.require_fvg_or_ob else 'No FVG/OB req'}; "
                    f"Momentum={'on' if cfg.momentum_confirm else 'off'}"
                )
                trades.append({
                    "ticker": ticker, "side": "BUY", "date": (nxt if cfg.entry_on_next_open else dt),
                    "price": px, "shares": 0, "reason": "candidate",
                    "signal_reason": sig_reason, "score": np.nan
                })
                continue

        else:
            bars_left -= 1
            high_i = float(nxt_row["High"])
            low_i  = float(nxt_row["Low"])
            exec_date = nxt if cfg.exit_on_next_open else dt

            # Intrabar SL/TP
            if low_i <= sl and high_i >= tp2:
                trades.append({"ticker": ticker, "side": "SELL", "date": exec_date, "price": tp2, "shares": 0, "reason": "TP2"})
                in_pos = False; continue
            if low_i <= sl:
                trades.append({"ticker": ticker, "side": "SELL", "date": exec_date, "price": sl, "shares": 0, "reason": "SL"})
                in_pos = False; continue
            if not hit_tp1 and high_i >= tp1:
                hit_tp1 = True
                sl = float(trades[-1]["price"]) if trades and trades[-1]["side"] == "BUY" else entry_px  # move to BE

            if high_i >= tp2:
                trades.append({"ticker": ticker, "side": "SELL", "date": exec_date, "price": tp2, "shares": 0, "reason": "TP2"})
                in_pos = False; continue

            # Structure invalidate on Daily: CHoCH_down
            if smcD['ms_event'].iat[i] == 'CHoCH_down':
                price_exit = float(nxt_row["Open"] if cfg.exit_on_next_open else row["Close"])
                trades.append({"ticker": ticker, "side": "SELL", "date": exec_date, "price": price_exit, "shares": 0, "reason": "StructureFlip"})
                in_pos = False; continue

            # Time stop
            if bars_left <= 0:
                price_exit = float(nxt_row["Open"] if cfg.exit_on_next_open else row["Close"])
                trades.append({"ticker": ticker, "side": "SELL", "date": exec_date, "price": price_exit, "shares": 0, "reason": "TimeStop"})
                in_pos = False; continue

    # Final close if still open
    if in_pos:
        last_dt = smcD.index[-1]
        trades.append({"ticker": ticker, "side": "SELL", "date": last_dt, "price": float(smcD.loc[last_dt, "Close"]), "shares": 0, "reason": "final_close"})

    cols = ["ticker","side","date","price","shares","reason","signal_reason","score"]
    return pd.DataFrame(trades, columns=cols), pd.Series(dtype=float)

# =========================
# Portfolio engine (same pattern as yours)
# =========================
def aggregate_and_apply(all_trades: pd.DataFrame, data_map: Dict[str, pd.DataFrame], bench_df: pd.DataFrame, cfg: Config):
    if all_trades.empty:
        return all_trades, pd.Series(dtype=float), {}

    side_order = {"BUY": 0, "SELL": 1}
    all_trades = (all_trades
        .assign(_sorder=all_trades["side"].map(side_order))
        .sort_values(by=["date", "_sorder"], kind="stable")
        .drop(columns=["_sorder"])
        .reset_index(drop=True)
    )
    all_trades["date"] = pd.to_datetime(all_trades["date"])

    equity_curve = []
    dates = sorted(all_trades["date"].unique().tolist())
    cash = cfg.initial_capital
    open_positions = {}
    completed_legs = []

    global APPLY_FEES
    APPLY_FEES = cfg.apply_fees

    def _get_close_on(tkr, dt):
        df = data_map.get(tkr)
        if df is None or df.empty:
            return np.nan
        if dt in df.index:
            return float(df.loc[dt, "Close"])
        prev = df[df.index <= dt]
        if prev.empty:
            return np.nan
        return float(prev["Close"].iloc[-1])

    if dates:
        seed_date = pd.to_datetime(dates[0]) - pd.Timedelta(days=1)
        equity_curve.append((seed_date, float(cash)))

    for dt in dates:
        day_trades = all_trades[all_trades["date"] == dt].copy()

        # ---- SELL first ----
        for _, tr in day_trades[day_trades["side"] == "SELL"].iterrows():
            tkr = tr["ticker"]; price = float(tr["price"])
            pos = open_positions.get(tkr)
            if pos is None: continue
            shares = int(pos["shares"])
            turnover_sell = shares * price
            fee = calc_fees(0.0, turnover_sell)
            pnl = (price - pos["entry_px"]) * shares
            cash += (turnover_sell - fee)
            realized = pnl - fee - pos.get("buy_fee", 0.0)
            completed_legs.append({
                "ticker": tkr, "side": "SELL", "date": dt, "price": price,
                "shares": shares, "reason": tr.get("reason",""),
                "turnover": turnover_sell, "fees_inr": fee, "pnl_inr": realized
            })
            log.info("Exit %-12s px=%8.2f shares=%6d reason=%s net=%.2f cash=%.2f",
                     tkr, price, shares, tr.get("reason",""), realized, cash)
            del open_positions[tkr]

        # ---- BUY candidates today ----
        buys_today = day_trades[day_trades["side"] == "BUY"].copy()

        # 52w filter
        if cfg.enable_52w_filter and not buys_today.empty:
            keep = []
            for _, rr in buys_today.iterrows():
                df = data_map.get(rr["ticker"])
                if df is None or df.empty or dt not in df.index:
                    continue
                close = float(df.loc[dt, "Close"])
                hist = df["Close"].loc[:dt]
                window = hist.iloc[-cfg.filter_52w_window:] if len(hist)>=cfg.filter_52w_window else hist
                high_52w = float(window.max())
                if high_52w > 0 and close >= cfg.within_pct_of_52w_high * high_52w:
                    keep.append(rr)
            buys_today = pd.DataFrame(keep) if keep else pd.DataFrame(columns=buys_today.columns)

        # Exclude already-held tickers
        if not buys_today.empty:
            buys_today = buys_today[~buys_today["ticker"].isin(open_positions.keys())]

        # VOLAR rank
        if not buys_today.empty:
            tickers = buys_today["ticker"].tolist()
            volar_scores = compute_volar_scores(dt, tickers, data_map, bench_df, cfg.volar_lookback)
            buys_today["volar"] = buys_today["ticker"].map(volar_scores)
            buys_today = buys_today.sort_values("volar", ascending=False).reset_index(drop=True)

        # Pick top-K respecting max concurrent
        slots = cfg.max_concurrent_positions - len(open_positions)
        selected = pd.DataFrame(columns=buys_today.columns)
        if slots > 0 and not buys_today.empty:
            selected = buys_today.head(min(cfg.top_k_daily, slots)).copy()

        # Allocate
        if not selected.empty:
            log.info("Selected %d BUY candidates on %s:", selected.shape[0], dt.date())
            for i, rr in selected.reset_index(drop=True).iterrows():
                log.info("  %-12s volar=%6.2f rank=%d px=%8.2f", rr["ticker"], rr.get("volar",0.0), i+1, rr["price"])

            names = selected["ticker"].tolist()
            rets = []
            for t in names:
                df = data_map.get(t)
                ser = df["Close"].loc[:dt].pct_change().dropna().iloc[-cfg.volar_lookback:]
                rets.append(ser)
            R = pd.concat(rets, axis=1)
            R.columns = names
            R = R.dropna()
            if R.empty or R.shape[0] < max(20, int(0.4*cfg.volar_lookback)) or R.shape[1] == 0:
                weights = np.full(len(names), 1.0/len(names))
            else:
                mu = R.mean().values
                Sigma = R.cov().values
                weights = markowitz_long_only(mu, Sigma)

            deploy_cash = max(0.0, float(cash)) * float(cfg.deploy_cash_frac)
            if deploy_cash <= 0:
                log.info("No deployable cash (cap=%.0f%%) on %s", 100*cfg.deploy_cash_frac, dt.date())
            else:
                alloc = (weights / weights.sum()) * deploy_cash if weights.sum()>0 else np.full(len(names), deploy_cash/len(names))
                rank_map = {row["ticker"]: (idx+1) for idx, (_, row) in enumerate(selected.iterrows())}
                for w_amt, t in zip(alloc, names):
                    df_t = data_map[t]
                    price = float(df_t.loc[dt, "Close"] if dt in df_t.index else df_t["Close"].loc[:dt].iloc[-1])
                    shares = int(math.floor(w_amt / price))
                    if shares <= 0:
                        log.info("Skip BUY %-12s (alloc %.2f too small)", t, w_amt); continue
                    turn = shares * price
                    fee = calc_fees(turn, 0.0)
                    total_cost = turn + fee
                    if total_cost > cash:
                        shares = int(math.floor((cash - fee) / price))
                        if shares <= 0:
                            log.info("Skip BUY %-12s due to cash/fees", t); continue
                        turn = shares * price; total_cost = turn + fee
                    cash -= total_cost
                    open_positions[t] = {"entry_date": dt, "entry_px": price, "shares": shares, "buy_fee": fee, "entry_reason": "entry"}

                    row_sel = selected[selected["ticker"]==t].iloc[0]
                    volar_val = float(row_sel.get("volar", np.nan))
                    rank_pos = rank_map.get(t, np.nan)
                    reason_text = (
                        f"SMC W→D long; VOLAR rank {int(rank_pos)}/{len(names)} (VOLAR={volar_val:.2f}); "
                        f"MVO weight={w_amt/deploy_cash:.1%} of capped cash ({100*cfg.deploy_cash_frac:.0f}% of available)"
                    )
                    completed_legs.append({
                        "ticker": t, "side": "BUY", "date": dt, "price": price,
                        "shares": shares, "reason": reason_text,
                        "turnover": turn, "fees_inr": fee, "pnl_inr": 0.0
                    })
                    log.info("BUY %-12s px=%8.2f sh=%6d fee=%.2f cash=%.2f :: %s",
                             t, price, shares, fee, cash, reason_text)

        # MTM valuation
        mtm = 0.0
        for _tkr, pos in open_positions.items():
            px = _get_close_on(_tkr, dt)
            if not np.isnan(px):
                mtm += pos["shares"] * px
        total_equity = cash + mtm
        equity_curve.append((dt, float(total_equity)))

    eq_ser = pd.Series([e for _, e in equity_curve], index=[d for d, _ in equity_curve])

    # Build roundtrips
    legs_df = pd.DataFrame(completed_legs).sort_values(["date","ticker","side"]).reset_index(drop=True)
    roundtrips = []
    by_tkr_open = {}
    for _, leg in legs_df.iterrows():
        tkr = leg["ticker"]
        if leg["side"] == "BUY":
            by_tkr_open[tkr] = leg
        else:
            buy = by_tkr_open.pop(tkr, None)
            if buy is None: continue
            fees_total = float(buy.get("fees_inr", 0.0) + leg.get("fees_inr", 0.0))
            gross_pnl = (leg["price"] - buy["price"]) * buy["shares"]
            net_pnl   = gross_pnl - fees_total
            ret_pct   = (leg["price"] / buy["price"] - 1.0) * 100.0
            days_held = (pd.to_datetime(leg["date"]) - pd.to_datetime(buy["date"])).days
            roundtrips.append({
                "ticker": tkr,
                "entry_date": pd.to_datetime(buy["date"]),
                "entry_price": float(buy["price"]),
                "exit_date": pd.to_datetime(leg["date"]),
                "exit_price": float(leg["price"]),
                "days_held": int(days_held),
                "shares": int(buy["shares"]),
                "entry_reason": buy.get("reason",""),
                "exit_reason": leg.get("reason",""),
                "gross_pnl_inr": float(gross_pnl),
                "fees_total_inr": float(fees_total),
                "net_pnl_inr": float(net_pnl),
                "return_pct": float(ret_pct),
            })
    trips_df = pd.DataFrame(roundtrips).sort_values(["entry_date","ticker"]).reset_index(drop=True)

    metrics = compute_metrics(eq_ser, legs_df)
    return legs_df, trips_df, eq_ser, metrics

def compute_metrics(equity: pd.Series, legs_df: pd.DataFrame):
    out = {}
    if equity is None or equity.empty:
        return out
    eq = equity.dropna()
    daily_ret = eq.pct_change().fillna(0.0)
    days = (eq.index[-1] - eq.index[0]).days or 1
    years = days / 365.25
    cagr = (eq.iloc[-1] / eq.iloc[0]) ** (1/years) - 1 if years > 0 else 0.0
    sharpe = (daily_ret.mean() / (daily_ret.std(ddof=0) or 1e-9)) * np.sqrt(252)
    cummax = eq.cummax()
    dd = (eq - cummax) / cummax
    max_dd = dd.min()
    n_sells = legs_df[legs_df["side"] == "SELL"].shape[0] if (legs_df is not None and not legs_df.empty) else 0
    wins = int((legs_df[legs_df["side"] == "SELL"]["pnl_inr"] > 0).sum()) if n_sells else 0
    win_rate = (wins / n_sells) * 100.0 if n_sells > 0 else 0.0
    out.update({
        "start_equity_inr": float(eq.iloc[0]),
        "final_equity_inr": float(eq.iloc[-1]),
        "cagr_pct": float(cagr * 100),
        "sharpe": float(sharpe),
        "max_drawdown_pct": float(max_dd * 100),
        "win_rate_pct": float(win_rate),
        "n_trades": int(n_sells),
    })
    return out

def plot_equity(equity: pd.Series, out_path: str):
    if equity is None or equity.empty:
        return
    try:
        import matplotlib.pyplot as plt
        plt.figure(figsize=(10,5))
        plt.plot(equity.index, equity.values)
        plt.title("Equity Curve")
        plt.xlabel("Date")
        plt.ylabel("Equity (INR)")
        plt.tight_layout()
        plt.savefig(out_path)
        plt.close()
    except Exception:
        pass

# =========================
# Backtest driver
# =========================
def backtest(cfg: Config):
    ensure_dirs(cfg.cache_dir, cfg.out_dir)
    log.info("Universe: loading static symbols...")
    symbols = load_static_symbols(cfg.static_symbols, cfg.static_symbols_path)
    log.info("Loaded %d symbols.", len(symbols))

    log.info("Data: fetching OHLCV from yfinance (adjusted)...")
    data_map = fetch_prices(symbols, cfg.start_date, cfg.end_date, cfg.cache_dir)
    log.info("Downloaded %d symbols with data.", len(data_map))

    bench_tkr, bench_df = pick_benchmark(cfg.benchmark_try, cfg.start_date, cfg.end_date, cfg.cache_dir)
    log.info("Benchmark selected: %s", bench_tkr)

    log.info("Signals: generating SMC W→D long-only entries...")
    all_trades = []
    for i, tkr in enumerate(symbols, 1):
        dfD = data_map.get(tkr)
        if dfD is None or dfD.empty:
            continue
        tr, _ = simulate_ticker_smc_long_WD(tkr, dfD, cfg)
        if not tr.empty:
            all_trades.append(tr)
        if i % 50 == 0:
            log.info("  processed %d/%d tickers...", i, len(symbols))

    if not all_trades:
        log.warning("No SMC signals generated; consider loosening triggers/lookbacks.")
        return None, None, None, {}
    all_trades = pd.concat(all_trades, ignore_index=True)

    log.info("Portfolio: cap daily deploy to %.0f%% of cash; 52w %s %.0f%% high; top-%d by VOLAR; MVO; max %d positions.",
             cfg.deploy_cash_frac*100, ">=" if cfg.enable_52w_filter else "(OFF)", cfg.within_pct_of_52w_high*100,
             cfg.top_k_daily, cfg.max_concurrent_positions)
    legs_df, trips_df, equity, metrics = aggregate_and_apply(all_trades, data_map, bench_df, cfg)

    stamp = pd.Timestamp.today(tz="Asia/Kolkata").strftime("%Y%m%d_%H%M%S")
    legs_path = os.path.join(cfg.out_dir, f"trades_legs_{stamp}.csv")
    trips_path = os.path.join(cfg.out_dir, f"trades_roundtrips_{stamp}.csv")
    equity_path = os.path.join(cfg.out_dir, f"equity_{stamp}.csv")
    metrics_path = os.path.join(cfg.out_dir, f"metrics_{stamp}.json")
    eq_plot_path = os.path.join(cfg.out_dir, f"equity_{stamp}.png")

    if legs_df is not None:
        legs_df.to_csv(legs_path, index=False)
    if trips_df is not None:
        trips_df.to_csv(trips_path, index=False)
    if equity is not None:
        pd.DataFrame({"date": equity.index, "equity": equity.values}).to_csv(equity_path, index=False)
    with open(metrics_path, "w") as f:
        json.dump(metrics, f, indent=2)

    if cfg.plot and equity is not None:
        plot_equity(equity, eq_plot_path)

    log.info("=== METRICS ===\n%s", json.dumps(metrics, indent=2))
    log.info("Files written:\n  %s\n  %s\n  %s\n  %s", legs_path, trips_path, equity_path, metrics_path)
    if cfg.plot:
        log.info("  %s", eq_plot_path)

def main():
    global APPLY_FEES
    APPLY_FEES = bool(CFG.apply_fees)

    # EITHER set symbols inline:
    # CFG.static_symbols = [
    #     'RELIANCE.NS','HDFCBANK.NS','ICICIBANK.NS','INFY.NS','TCS.NS','SBIN.NS',
    #     'ITC.NS','LT.NS','KOTAKBANK.NS','BHARTIARTL.NS','MARUTI.NS','AXISBANK.NS',
    #     'SUNPHARMA.NS','ONGC.NS','ASIANPAINT.NS','HCLTECH.NS','POWERGRID.NS','NTPC.NS',
    #     'ULTRACEMCO.NS','BAJFINANCE.NS','TATAMOTORS.NS','ADANIPORTS.NS','TATASTEEL.NS',
    #     'M&M.NS','HINDUNILVR.NS','WIPRO.NS','JSWSTEEL.NS','DIVISLAB.NS','NESTLEIND.NS',
    # ]
    # OR read from file (one per line):
    CFG.static_symbols_path = "nifty500.txt"

    backtest(CFG)

if __name__ == "__main__":
    main()
# Out:
# 2025-10-17 00:02:25 | INFO | Universe: loading static symbols...
# 2025-10-17 00:02:25 | INFO | Loaded 500 symbols.
# 2025-10-17 00:02:25 | INFO | Data: fetching OHLCV from yfinance (adjusted)...
# 2025-10-17 00:02:29 | ERROR |
# 1 Failed download:
# 2025-10-17 00:02:29 | ERROR | ['ABLBL.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 00:02:33 | ERROR |
# 1 Failed download:
# 2025-10-17 00:02:33 | ERROR | ['AEGISVOPAK.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 00:02:34 | ERROR |
# 1 Failed download:
# 2025-10-17 00:02:34 | ERROR | ['AGARWALEYE.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 00:02:43 | ERROR |
# 1 Failed download:
# 2025-10-17 00:02:43 | ERROR | ['ATHERENERG.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 00:03:06 | ERROR |
# 1 Failed download:
# 2025-10-17 00:03:06 | ERROR | ['COHANCE.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 00:03:18 | ERROR |
# 1 Failed download:
# 2025-10-17 00:03:18 | ERROR | ['ENRIN.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 00:03:33 | ERROR |
# 1 Failed download:
# 2025-10-17 00:03:33 | ERROR | ['HEXT.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 00:03:48 | ERROR |
# 1 Failed download:
# 2025-10-17 00:03:48 | ERROR | ['ITCHOTELS.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 00:04:22 | ERROR |
# 1 Failed download:
# 2025-10-17 00:04:22 | ERROR | ['ONESOURCE.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 00:04:57 | ERROR |
# 1 Failed download:
# 2025-10-17 00:04:57 | ERROR | ['THELEELA.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 00:05:11 | INFO | Downloaded 490 symbols with data.
# 2025-10-17 00:05:11 | ERROR |
# 1 Failed download:
# 2025-10-17 00:05:11 | ERROR | ['^CNX500']: YFTzMissingError('possibly delisted; no timezone found')
# 2025-10-17 00:05:12 | INFO | Using benchmark: ^CRSLDX
# 2025-10-17 00:05:12 | INFO | Benchmark selected: ^CRSLDX
# 2025-10-17 00:05:12 | INFO | Signals: generating SMC W→D long-only entries...
# 2025-10-17 00:05:24 | INFO |   processed 50/500 tickers...
# 2025-10-17 00:05:39 | INFO |   processed 100/500 tickers...
# 2025-10-17 00:05:53 | INFO |   processed 150/500 tickers...
# 2025-10-17 00:06:07 | INFO |   processed 200/500 tickers...
# 2025-10-17 00:06:20 | INFO |   processed 250/500 tickers...
# 2025-10-17 00:06:33 | INFO |   processed 300/500 tickers...
# 2025-10-17 00:06:47 | INFO |   processed 350/500 tickers...
# 2025-10-17 00:07:00 | INFO |   processed 400/500 tickers...
# 2025-10-17 00:07:14 | INFO |   processed 450/500 tickers...
# 2025-10-17 00:07:28 | INFO |   processed 500/500 tickers...
# 2025-10-17 00:07:28 | INFO | Portfolio: cap daily deploy to 35% of cash; 52w >= 60% high; top-4 by VOLAR; MVO; max 6 positions.
# 2025-10-17 00:07:28 | INFO | Selected 4 BUY candidates on 2015-02-16:
# 2025-10-17 00:07:28 | INFO |   BALKRISIND.NS volar=  0.00 rank=1 px=  317.27
# 2025-10-17 00:07:28 | INFO |   FORTIS.NS    volar=  0.00 rank=2 px=  138.97
# 2025-10-17 00:07:28 | INFO |   GILLETTE.NS  volar=  0.00 rank=3 px= 3638.63
# 2025-10-17 00:07:28 | INFO |   SUNTV.NS     volar=  0.00 rank=4 px=  330.33
# 2025-10-17 00:07:28 | INFO | BUY BALKRISIND.NS px=  301.25 sh=    58 fee=41.37 cash=182485.91 :: SMC W→D long; VOLAR rank 1/4 (VOLAR=0.00); MVO weight=25.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY FORTIS.NS    px=  137.19 sh=   127 fee=41.25 cash=165022.08 :: SMC W→D long; VOLAR rank 2/4 (VOLAR=0.00); MVO weight=25.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY GILLETTE.NS  px= 3504.69 sh=     4 fee=33.19 cash=150970.13 :: SMC W→D long; VOLAR rank 3/4 (VOLAR=0.00); MVO weight=25.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY SUNTV.NS     px=  325.01 sh=    53 fee=40.78 cash=133703.65 :: SMC W→D long; VOLAR rank 4/4 (VOLAR=0.00); MVO weight=25.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit FORTIS.NS    px=  138.97 shares=   127 reason=SL net=123.19 cash=151290.67
# 2025-10-17 00:07:28 | INFO | Exit GILLETTE.NS  px= 3426.76 shares=     4 reason=SL net=-398.88 cash=164943.73
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-02-20:
# 2025-10-17 00:07:28 | INFO |   GILLETTE.NS  volar=  0.00 rank=1 px= 3515.69
# 2025-10-17 00:07:28 | INFO | BUY GILLETTE.NS  px= 3481.77 sh=    16 fee=89.75 cash=109145.60 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit BALKRISIND.NS px=  288.63 shares=    58 reason=SL net=-834.27 cash=125825.42
# 2025-10-17 00:07:28 | INFO | Selected 4 BUY candidates on 2015-02-23:
# 2025-10-17 00:07:28 | INFO |   ADANIPOWER.NS volar=  0.00 rank=1 px=   11.02
# 2025-10-17 00:07:28 | INFO |   COFORGE.NS   volar=  0.00 rank=2 px=   66.75
# 2025-10-17 00:07:28 | INFO |   CONCOR.NS    volar=  0.00 rank=3 px=  450.75
# 2025-10-17 00:07:28 | INFO |   JINDALSTEL.NS volar=  0.00 rank=4 px=  187.35
# 2025-10-17 00:07:28 | INFO | BUY ADANIPOWER.NS px=   11.40 sh=   965 fee=26.04 cash=114798.37 :: SMC W→D long; VOLAR rank 1/4 (VOLAR=0.00); MVO weight=25.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY COFORGE.NS   px=   67.61 sh=   162 fee=25.93 cash=103819.73 :: SMC W→D long; VOLAR rank 2/4 (VOLAR=0.00); MVO weight=25.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY CONCOR.NS    px=  456.30 sh=    24 fee=25.93 cash=92842.55 :: SMC W→D long; VOLAR rank 3/4 (VOLAR=0.00); MVO weight=25.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY JINDALSTEL.NS px=  188.19 sh=    58 fee=25.84 cash=81901.66 :: SMC W→D long; VOLAR rank 4/4 (VOLAR=0.00); MVO weight=25.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit GILLETTE.NS  px= 3515.69 shares=    16 reason=SL net=347.37 cash=138047.18
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-02-26:
# 2025-10-17 00:07:28 | INFO |   MCX.NS       volar=  0.00 rank=1 px=  926.78
# 2025-10-17 00:07:28 | INFO | BUY MCX.NS       px=  904.19 sh=    53 fee=80.50 cash=90044.52 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit JINDALSTEL.NS px=  187.35 shares=    58 reason=SL net=-122.15 cash=100863.25
# 2025-10-17 00:07:28 | INFO | Exit MCX.NS       px= 1041.56 shares=    53 reason=TP2 net=7095.54 cash=155961.44
# 2025-10-17 00:07:28 | INFO | Selected 2 BUY candidates on 2015-03-02:
# 2025-10-17 00:07:28 | INFO |   LT.NS        volar=  0.00 rank=1 px= 1005.84
# 2025-10-17 00:07:28 | INFO |   NTPC.NS      volar=  0.00 rank=2 px=   89.08
# 2025-10-17 00:07:28 | INFO | BUY LT.NS        px= 1042.02 sh=    26 fee=55.77 cash=128813.08 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY NTPC.NS      px=   91.08 sh=   299 fee=55.93 cash=101525.56 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit CONCOR.NS    px=  426.44 shares=    24 reason=SL net=-788.85 cash=111713.88
# 2025-10-17 00:07:28 | INFO | Exit ADANIPOWER.NS px=   11.02 shares=   965 reason=SL net=-439.92 cash=122301.00
# 2025-10-17 00:07:28 | INFO | Exit LT.NS        px= 1005.84 shares=    26 reason=SL net=-1070.80 cash=148378.56
# 2025-10-17 00:07:28 | INFO | Selected 3 BUY candidates on 2015-03-10:
# 2025-10-17 00:07:28 | INFO |   AIAENG.NS    volar=  0.00 rank=1 px= 1107.62
# 2025-10-17 00:07:28 | INFO |   AJANTPHARM.NS volar=  0.00 rank=2 px=  726.30
# 2025-10-17 00:07:28 | INFO |   ASHOKLEY.NS  volar=  0.00 rank=3 px=   30.78
# 2025-10-17 00:07:28 | INFO | BUY AIAENG.NS    px= 1132.99 sh=    15 fee=40.23 cash=131343.53 :: SMC W→D long; VOLAR rank 1/3 (VOLAR=0.00); MVO weight=33.3% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY AJANTPHARM.NS px=  727.49 sh=    23 fee=39.61 cash=114571.75 :: SMC W→D long; VOLAR rank 2/3 (VOLAR=0.00); MVO weight=33.3% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY ASHOKLEY.NS  px=   31.08 sh=   557 fee=40.98 cash=97221.37 :: SMC W→D long; VOLAR rank 3/3 (VOLAR=0.00); MVO weight=33.3% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit COFORGE.NS   px=   74.19 shares=   162 reason=TP2 net=989.58 cash=109189.60
# 2025-10-17 00:07:28 | INFO | Exit SUNTV.NS     px=  306.73 shares=    53 reason=SL net=-1069.49 cash=125386.59
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-03-11:
# 2025-10-17 00:07:28 | INFO |   NATCOPHARM.NS volar=  0.00 rank=1 px=  306.97
# 2025-10-17 00:07:28 | INFO | BUY NATCOPHARM.NS px=  329.85 sh=   133 fee=75.69 cash=81441.15 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit AJANTPHARM.NS px=  811.82 shares=    23 reason=TP2 net=1835.14 cash=100048.07
# 2025-10-17 00:07:28 | INFO | Exit NATCOPHARM.NS px=  370.06 shares=   133 reason=TP2 net=5174.81 cash=149168.31
# 2025-10-17 00:07:28 | INFO | Selected 2 BUY candidates on 2015-03-12:
# 2025-10-17 00:07:28 | INFO |   GILLETTE.NS  volar=  0.00 rank=1 px= 3699.27
# 2025-10-17 00:07:28 | INFO |   THERMAX.NS   volar=  0.00 rank=2 px= 1205.06
# 2025-10-17 00:07:28 | INFO | BUY GILLETTE.NS  px= 3719.45 sh=     7 fee=54.52 cash=123077.61 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY THERMAX.NS   px= 1198.62 sh=    21 fee=53.49 cash=97853.04 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-03-13:
# 2025-10-17 00:07:28 | INFO |   NATCOPHARM.NS volar=  0.00 rank=1 px=  384.93
# 2025-10-17 00:07:28 | INFO | BUY NATCOPHARM.NS px=  408.70 sh=    83 fee=63.88 cash=63867.41 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit THERMAX.NS   px= 1132.86 shares=    21 reason=SL net=-1506.48 cash=87585.51
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-03-17:
# 2025-10-17 00:07:28 | INFO |   VTL.NS       volar=  0.00 rank=1 px=   92.29
# 2025-10-17 00:07:28 | INFO | BUY VTL.NS       px=   92.41 sh=   331 fee=59.92 cash=56938.41 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit AIAENG.NS    px= 1214.33 shares=    15 reason=TP2 net=1115.95 cash=75089.39
# 2025-10-17 00:07:28 | INFO | Exit GILLETTE.NS  px= 4117.76 shares=     7 reason=TP2 net=2656.50 cash=103836.58
# 2025-10-17 00:07:28 | INFO | Selected 2 BUY candidates on 2015-03-18:
# 2025-10-17 00:07:28 | INFO |   BHARTIARTL.NS volar=  0.00 rank=1 px=  327.60
# 2025-10-17 00:07:28 | INFO |   GRANULES.NS  volar=  0.00 rank=2 px=   90.07
# 2025-10-17 00:07:28 | INFO | BUY BHARTIARTL.NS px=  324.50 sh=    55 fee=42.25 cash=85946.82 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY GRANULES.NS  px=   90.46 sh=   200 fee=42.83 cash=67812.45 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit ASHOKLEY.NS  px=   29.06 shares=   557 reason=SL net=-1224.00 cash=83938.82
# 2025-10-17 00:07:28 | INFO | Exit GRANULES.NS  px=   84.67 shares=   200 reason=SL net=-1260.61 cash=100812.59
# 2025-10-17 00:07:28 | INFO | Exit NTPC.NS      px=   83.40 shares=   299 reason=SL net=-2425.33 cash=125674.78
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-03-20:
# 2025-10-17 00:07:28 | INFO |   SONATSOFTW.NS volar=  0.00 rank=1 px=   42.03
# 2025-10-17 00:07:28 | INFO | BUY SONATSOFTW.NS px=   40.33 sh=  1090 fee=75.80 cash=81637.82 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Selected 2 BUY candidates on 2015-03-23:
# 2025-10-17 00:07:28 | INFO |   AIAENG.NS    volar=  0.00 rank=1 px= 1154.58
# 2025-10-17 00:07:28 | INFO |   BIOCON.NS    volar=  0.00 rank=2 px=   69.56
# 2025-10-17 00:07:28 | INFO | BUY AIAENG.NS    px= 1140.72 sh=    12 fee=32.41 cash=67916.77 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY BIOCON.NS    px=   69.88 sh=   204 fee=33.75 cash=53626.87 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit AIAENG.NS    px= 1075.14 shares=    12 reason=SL net=-871.63 cash=66476.29
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-03-25:
# 2025-10-17 00:07:28 | INFO |   AIAENG.NS    volar=  0.00 rank=1 px= 1090.22
# 2025-10-17 00:07:28 | INFO | BUY AIAENG.NS    px= 1074.89 sh=    21 fee=50.40 cash=43853.21 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit BIOCON.NS    px=   76.69 shares=   204 reason=TP2 net=1296.69 cash=59439.81
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-04-01:
# 2025-10-17 00:07:28 | INFO |   BALKRISIND.NS volar=  0.00 rank=1 px=  294.94
# 2025-10-17 00:07:28 | INFO | BUY BALKRISIND.NS px=  297.67 sh=    69 fee=47.99 cash=38852.62 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit NATCOPHARM.NS px=  446.66 shares=    83 reason=TimeStop net=3001.83 cash=75840.08
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-04-07:
# 2025-10-17 00:07:28 | INFO |   APLAPOLLO.NS volar=  0.00 rank=1 px=   41.59
# 2025-10-17 00:07:28 | INFO | BUY APLAPOLLO.NS px=   41.97 sh=   632 fee=55.09 cash=49261.73 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit VTL.NS       px=  103.66 shares=   331 reason=TP2 net=3580.95 cash=83489.78
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-04-08:
# 2025-10-17 00:07:28 | INFO |   AARTIIND.NS  volar=  0.00 rank=1 px=   85.32
# 2025-10-17 00:07:28 | INFO | BUY AARTIIND.NS  px=   85.93 sh=   340 fee=58.29 cash=54215.53 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit BALKRISIND.NS px=  327.51 shares=    69 reason=TP2 net=1940.61 cash=76743.32
# 2025-10-17 00:07:28 | INFO | Exit BHARTIARTL.NS px=  345.51 shares=    55 reason=TimeStop net=1047.60 cash=95680.69
# 2025-10-17 00:07:28 | INFO | Selected 2 BUY candidates on 2015-04-10:
# 2025-10-17 00:07:28 | INFO |   ADANIPOWER.NS volar=  0.00 rank=1 px=    9.88
# 2025-10-17 00:07:28 | INFO |   CANFINHOME.NS volar=  0.00 rank=2 px=  141.14
# 2025-10-17 00:07:28 | INFO | BUY ADANIPOWER.NS px=    9.96 sh=  1681 fee=39.64 cash=78898.29 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY CANFINHOME.NS px=  135.57 sh=   123 fee=39.48 cash=62183.66 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit SONATSOFTW.NS px=   45.78 shares=  1090 reason=TimeStop net=5761.39 cash=111982.01
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-04-15:
# 2025-10-17 00:07:28 | INFO |   ASHOKLEY.NS  volar=  0.00 rank=1 px=   31.70
# 2025-10-17 00:07:28 | INFO | BUY ASHOKLEY.NS  px=   31.26 sh=  1253 fee=70.11 cash=72738.30 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit AARTIIND.NS  px=   78.94 shares=   340 reason=SL net=-2508.46 cash=99504.09
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-04-16:
# 2025-10-17 00:07:28 | INFO |   NAVINFLUOR.NS volar=  0.00 rank=1 px=  174.75
# 2025-10-17 00:07:28 | INFO | BUY NAVINFLUOR.NS px=  169.30 sh=   205 fee=64.81 cash=64732.81 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit ASHOKLEY.NS  px=   30.29 shares=  1253 reason=SL net=-1374.68 cash=102601.84
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-04-17:
# 2025-10-17 00:07:28 | INFO |   ASIANPAINT.NS volar=  0.00 rank=1 px=  752.94
# 2025-10-17 00:07:28 | INFO | BUY ASIANPAINT.NS px=  747.95 sh=    48 fee=66.23 cash=66634.10 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit ADANIPOWER.NS px=    9.37 shares=  1681 reason=SL net=-1088.16 cash=82328.34
# 2025-10-17 00:07:28 | INFO | Exit AIAENG.NS    px= 1090.22 shares=    21 reason=SL net=200.57 cash=105152.00
# 2025-10-17 00:07:28 | INFO | Exit NAVINFLUOR.NS px=  165.18 shares=   205 reason=SL net=-991.28 cash=138932.00
# 2025-10-17 00:07:28 | INFO | Selected 3 BUY candidates on 2015-04-20:
# 2025-10-17 00:07:28 | INFO |   ABREL.NS     volar=  0.00 rank=1 px=  671.14
# 2025-10-17 00:07:28 | INFO |   ASHOKLEY.NS  volar=  0.00 rank=2 px=   30.37
# 2025-10-17 00:07:28 | INFO |   CCL.NS       volar=  0.00 rank=3 px=  175.71
# 2025-10-17 00:07:28 | INFO | BUY ABREL.NS     px=  643.84 sh=    25 fee=38.11 cash=122797.88 :: SMC W→D long; VOLAR rank 1/3 (VOLAR=0.00); MVO weight=33.3% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY ASHOKLEY.NS  px=   29.47 sh=   550 fee=38.37 cash=106550.91 :: SMC W→D long; VOLAR rank 2/3 (VOLAR=0.00); MVO weight=33.3% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY CCL.NS       px=  166.34 sh=    97 fee=38.20 cash=90378.18 :: SMC W→D long; VOLAR rank 3/3 (VOLAR=0.00); MVO weight=33.3% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit ASHOKLEY.NS  px=   29.32 shares=   550 reason=StructureFlip net=-178.03 cash=106447.12
# 2025-10-17 00:07:28 | INFO | Exit CCL.NS       px=  162.42 shares=    97 reason=SL net=-476.94 cash=122142.92
# 2025-10-17 00:07:28 | INFO | Selected 2 BUY candidates on 2015-04-21:
# 2025-10-17 00:07:28 | INFO |   BRITANNIA.NS volar=  0.00 rank=1 px=  942.67
# 2025-10-17 00:07:28 | INFO |   COFORGE.NS   volar=  0.00 rank=2 px=   61.82
# 2025-10-17 00:07:28 | INFO | BUY BRITANNIA.NS px=  899.01 sh=    23 fee=48.15 cash=101417.48 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY COFORGE.NS   px=   63.17 sh=   338 fee=48.95 cash=80017.85 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit ASIANPAINT.NS px=  724.60 shares=    48 reason=SL net=-1270.02 cash=114715.56
# 2025-10-17 00:07:28 | INFO | Exit BRITANNIA.NS px=  894.17 shares=    23 reason=SL net=-227.97 cash=135213.04
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-04-23:
# 2025-10-17 00:07:28 | INFO |   IDEA.NS      volar=  0.00 rank=1 px=  112.06
# 2025-10-17 00:07:28 | INFO | BUY IDEA.NS      px=  110.03 sh=   430 fee=79.78 cash=87818.68 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit ABREL.NS     px=  611.51 shares=    25 reason=SL net=-903.89 cash=103048.90
# 2025-10-17 00:07:28 | INFO | Exit APLAPOLLO.NS px=   39.91 shares=   632 reason=StructureFlip net=-1430.94 cash=128196.31
# 2025-10-17 00:07:28 | INFO | Exit CANFINHOME.NS px=  117.20 shares=   123 reason=SL net=-2354.19 cash=142556.76
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-04-27:
# 2025-10-17 00:07:28 | INFO |   SRF.NS       volar=  0.00 rank=1 px=  191.52
# 2025-10-17 00:07:28 | INFO | BUY SRF.NS       px=  182.24 sh=   273 fee=82.68 cash=92722.12 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Selected 1 BUY candidates on 2015-04-28:
# 2025-10-17 00:07:28 | INFO |   INDUSTOWER.NS volar=  0.00 rank=1 px=  271.08
# 2025-10-17 00:07:28 | INFO | BUY INDUSTOWER.NS px=  278.73 sh=   116 fee=61.99 cash=60327.53 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Exit COFORGE.NS   px=   61.82 shares=   338 reason=SL net=-574.86 cash=81152.30
# 2025-10-17 00:07:28 | INFO | Exit IDEA.NS      px=  112.06 shares=   430 reason=SL net=694.72 cash=129241.36
# 2025-10-17 00:07:28 | INFO | Selected 4 BUY candidates on 2015-04-30:
# 2025-10-17 00:07:28 | INFO |   KPRMILL.NS   volar=  0.00 rank=1 px=   58.26
# 2025-10-17 00:07:28 | INFO |   PAGEIND.NS   volar=  0.00 rank=2 px=11981.34
# 2025-10-17 00:07:28 | INFO |   SUPREMEIND.NS volar=  0.00 rank=3 px=  610.82
# 2025-10-17 00:07:28 | INFO |   WELSPUNLIV.NS volar=  0.00 rank=4 px=   41.07
# 2025-10-17 00:07:28 | INFO | BUY KPRMILL.NS   px=   58.68 sh=   192 fee=26.67 cash=117948.54 :: SMC W→D long; VOLAR rank 1/4 (VOLAR=0.00); MVO weight=25.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | Skip BUY PAGEIND.NS   (alloc 11308.62 too small)
# 2025-10-17 00:07:28 | INFO | BUY SUPREMEIND.NS px=  608.85 sh=    18 fee=25.95 cash=106963.24 :: SMC W→D long; VOLAR rank 3/4 (VOLAR=0.00); MVO weight=25.0% of capped cash (35% of available)
# 2025-10-17 00:07:28 | INFO | BUY WELSPUNLIV.NS px=   42.81 sh=   264 fee=26.76 cash=95633.58 :: SMC W→D long; VOLAR rank 4/4 (VOLAR=0.00); MVO weight=25.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-05-04:
# 2025-10-17 00:07:29 | INFO |   BRITANNIA.NS volar=  0.00 rank=1 px=  959.18
# 2025-10-17 00:07:29 | INFO | BUY BRITANNIA.NS px=  976.73 sh=    34 fee=63.03 cash=62361.77 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit BRITANNIA.NS px=  959.18 shares=    34 reason=SL net=-740.77 cash=94892.81
# 2025-10-17 00:07:29 | INFO | Exit INDUSTOWER.NS px=  255.48 shares=   116 reason=SL net=-2836.68 cash=124450.72
# 2025-10-17 00:07:29 | INFO | Exit KPRMILL.NS   px=   53.31 shares=   192 reason=SL net=-1103.13 cash=134640.41
# 2025-10-17 00:07:29 | INFO | Exit SRF.NS       px=  176.56 shares=   273 reason=SL net=-1732.13 cash=182742.92
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-05-07:
# 2025-10-17 00:07:29 | INFO |   ICICIBANK.NS volar=  0.00 rank=1 px=  260.56
# 2025-10-17 00:07:29 | INFO | BUY ICICIBANK.NS px=  254.21 sh=   251 fee=99.37 cash=118835.79 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Selected 2 BUY candidates on 2015-05-08:
# 2025-10-17 00:07:29 | INFO |   BRITANNIA.NS volar=  0.00 rank=1 px=  976.12
# 2025-10-17 00:07:29 | INFO |   KPRMILL.NS   volar=  0.00 rank=2 px=   56.92
# 2025-10-17 00:07:29 | INFO | BUY BRITANNIA.NS px=  957.18 sh=    21 fee=47.47 cash=98687.54 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY KPRMILL.NS   px=   57.38 sh=   362 fee=48.27 cash=77866.71 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-05-11:
# 2025-10-17 00:07:29 | INFO |   ABFRL.NS     volar=  0.00 rank=1 px=  200.99
# 2025-10-17 00:07:29 | INFO | BUY ABFRL.NS     px=  176.59 sh=   154 fee=55.89 cash=50616.04 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit WELSPUNLIV.NS px=   50.01 shares=   264 reason=TP2 net=1820.54 cash=63766.24
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-05-14:
# 2025-10-17 00:07:29 | INFO |   ASHOKLEY.NS  volar=  0.00 rank=1 px=   28.91
# 2025-10-17 00:07:29 | INFO | BUY ASHOKLEY.NS  px=   29.76 sh=   749 fee=50.07 cash=41424.30 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit BRITANNIA.NS px= 1109.46 shares=    21 reason=TP2 net=3078.93 cash=64651.49
# 2025-10-17 00:07:29 | INFO | Exit SUPREMEIND.NS px=  619.69 shares=    18 reason=TimeStop net=120.72 cash=75757.52
# 2025-10-17 00:07:29 | INFO | Selected 2 BUY candidates on 2015-05-22:
# 2025-10-17 00:07:29 | INFO |   ADANIPORTS.NS volar=  0.00 rank=1 px=  329.25
# 2025-10-17 00:07:29 | INFO |   LT.NS        volar=  0.00 rank=2 px=  925.69
# 2025-10-17 00:07:29 | INFO | BUY ADANIPORTS.NS px=  330.58 sh=    40 fee=31.30 cash=62502.97 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY LT.NS        px=  933.28 sh=    14 fee=30.93 cash=49406.08 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit ADANIPORTS.NS px=  310.46 shares=    40 reason=SL net=-887.28 cash=61773.35
# 2025-10-17 00:07:29 | INFO | Exit ICICIBANK.NS px=  262.27 shares=   251 reason=TimeStop net=1806.62 cash=127487.10
# 2025-10-17 00:07:29 | INFO | Selected 2 BUY candidates on 2015-05-28:
# 2025-10-17 00:07:29 | INFO |   AJANTPHARM.NS volar=  0.00 rank=1 px=  889.60
# 2025-10-17 00:07:29 | INFO |   BHARTIARTL.NS volar=  0.00 rank=2 px=  349.76
# 2025-10-17 00:07:29 | INFO | BUY AJANTPHARM.NS px=  884.30 sh=    25 fee=49.85 cash=105329.77 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY BHARTIARTL.NS px=  342.12 sh=    65 fee=50.00 cash=83042.28 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=0.00); MVO weight=50.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit KPRMILL.NS   px=   55.92 shares=   362 reason=TimeStop net=-647.11 cash=103215.99
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-05-29:
# 2025-10-17 00:07:29 | INFO |   ADANIENT.NS  volar=  0.00 rank=1 px=  105.80
# 2025-10-17 00:07:29 | INFO | BUY ADANIENT.NS  px=  101.80 sh=   354 fee=66.39 cash=67110.73 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit ABFRL.NS     px=  182.31 shares=   154 reason=TimeStop net=748.22 cash=95109.62
# 2025-10-17 00:07:29 | INFO | Exit ADANIENT.NS  px=   99.50 shares=   354 reason=SL net=-964.25 cash=130250.62
# 2025-10-17 00:07:29 | INFO | Exit AJANTPHARM.NS px=  994.64 shares=    25 reason=TP2 net=2635.56 cash=155043.51
# 2025-10-17 00:07:29 | INFO | Exit BHARTIARTL.NS px=  349.76 shares=    65 reason=SL net=375.83 cash=177706.83
# 2025-10-17 00:07:29 | INFO | Selected 4 BUY candidates on 2015-06-01:
# 2025-10-17 00:07:29 | INFO |   KAJARIACER.NS volar=  2.49 rank=1 px=  394.76
# 2025-10-17 00:07:29 | INFO |   CONCOR.NS    volar=  1.85 rank=2 px=  508.70
# 2025-10-17 00:07:29 | INFO |   SRF.NS       volar=  1.66 rank=3 px=  211.86
# 2025-10-17 00:07:29 | INFO |   CERA.NS      volar=  1.38 rank=4 px= 2216.13
# 2025-10-17 00:07:29 | INFO | BUY KAJARIACER.NS px=  392.57 sh=    69 fee=55.76 cash=150563.89 :: SMC W→D long; VOLAR rank 1/4 (VOLAR=2.49); MVO weight=44.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY CONCOR.NS    px=  507.10 sh=    42 fee=48.89 cash=129216.76 :: SMC W→D long; VOLAR rank 2/4 (VOLAR=1.85); MVO weight=34.8% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY SRF.NS       px=  216.35 sh=    26 fee=13.32 cash=123578.22 :: SMC W→D long; VOLAR rank 3/4 (VOLAR=1.66); MVO weight=9.3% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY CERA.NS      px= 2206.80 sh=     3 fee=15.67 cash=116942.16 :: SMC W→D long; VOLAR rank 4/4 (VOLAR=1.38); MVO weight=11.8% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit CERA.NS      px= 2105.28 shares=     3 reason=SL net=-357.82 cash=123220.40
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-06-02:
# 2025-10-17 00:07:29 | INFO |   AJANTPHARM.NS volar=  2.66 rank=1 px=  984.04
# 2025-10-17 00:07:29 | INFO | BUY AJANTPHARM.NS px=  949.43 sh=    45 fee=74.33 cash=80421.49 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.66); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit AJANTPHARM.NS px=  929.48 shares=    45 reason=SL net=-1062.76 cash=122157.64
# 2025-10-17 00:07:29 | INFO | Exit KAJARIACER.NS px=  380.12 shares=    69 reason=SL net=-988.80 cash=148311.78
# 2025-10-17 00:07:29 | INFO | Exit SRF.NS       px=  201.02 shares=    26 reason=SL net=-447.22 cash=153503.11
# 2025-10-17 00:07:29 | INFO | Selected 3 BUY candidates on 2015-06-03:
# 2025-10-17 00:07:29 | INFO |   BAJAJFINSV.NS volar=  1.41 rank=1 px=  147.53
# 2025-10-17 00:07:29 | INFO |   KEI.NS       volar=  1.32 rank=2 px=   68.14
# 2025-10-17 00:07:29 | INFO |   CERA.NS      volar=  1.28 rank=3 px= 2131.26
# 2025-10-17 00:07:29 | INFO | BUY BAJAJFINSV.NS px=  150.77 sh=   157 fee=51.71 cash=129780.75 :: SMC W→D long; VOLAR rank 1/3 (VOLAR=1.41); MVO weight=44.2% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY KEI.NS       px=   62.13 sh=   200 fee=29.42 cash=117324.78 :: SMC W→D long; VOLAR rank 2/3 (VOLAR=1.32); MVO weight=23.2% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY CERA.NS      px= 2092.45 sh=     8 fee=39.63 cash=100545.52 :: SMC W→D long; VOLAR rank 3/3 (VOLAR=1.28); MVO weight=32.6% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit ASHOKLEY.NS  px=   28.20 shares=   749 reason=TimeStop net=-1290.79 cash=121596.67
# 2025-10-17 00:07:29 | INFO | Exit CERA.NS      px= 2026.13 shares=     8 reason=SL net=-629.78 cash=137746.15
# 2025-10-17 00:07:29 | INFO | Exit KEI.NS       px=   62.86 shares=   200 reason=SL net=64.85 cash=150266.97
# 2025-10-17 00:07:29 | INFO | Selected 3 BUY candidates on 2015-06-04:
# 2025-10-17 00:07:29 | INFO |   BRITANNIA.NS volar=  2.88 rank=1 px= 1099.93
# 2025-10-17 00:07:29 | INFO |   AJANTPHARM.NS volar=  2.70 rank=2 px=  947.42
# 2025-10-17 00:07:29 | INFO |   KAJARIACER.NS volar=  2.42 rank=3 px=  380.60
# 2025-10-17 00:07:29 | INFO | BUY BRITANNIA.NS px= 1120.95 sh=    20 fee=50.22 cash=127797.69 :: SMC W→D long; VOLAR rank 1/3 (VOLAR=2.88); MVO weight=43.5% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY AJANTPHARM.NS px=  949.37 sh=    15 fee=33.71 cash=113523.37 :: SMC W→D long; VOLAR rank 2/3 (VOLAR=2.70); MVO weight=27.5% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY KAJARIACER.NS px=  378.13 sh=    40 fee=35.81 cash=98362.29 :: SMC W→D long; VOLAR rank 3/3 (VOLAR=2.42); MVO weight=29.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit BAJAJFINSV.NS px=  147.53 shares=   157 reason=SL net=-631.75 cash=121452.90
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-06-08:
# 2025-10-17 00:07:29 | INFO |   PRAJIND.NS   volar=  1.71 rank=1 px=   71.78
# 2025-10-17 00:07:29 | INFO | BUY PRAJIND.NS   px=   69.90 sh=   608 fee=74.06 cash=78881.28 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=1.71); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit CONCOR.NS    px=  478.77 shares=    42 reason=SL net=-1307.02 cash=98921.39
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-06-10:
# 2025-10-17 00:07:29 | INFO |   KEC.NS       volar=  1.32 rank=1 px=  117.75
# 2025-10-17 00:07:29 | INFO | BUY KEC.NS       px=  112.50 sh=   307 fee=64.61 cash=64318.40 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=1.32); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit KAJARIACER.NS px=  365.50 shares=    40 reason=SL net=-597.00 cash=78882.47
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-06-11:
# 2025-10-17 00:07:29 | INFO |   MOTHERSON.NS volar=  0.65 rank=1 px=   34.76
# 2025-10-17 00:07:29 | INFO | BUY MOTHERSON.NS px=   33.70 sh=   819 fee=56.38 cash=51222.41 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.65); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit AJANTPHARM.NS px=  884.62 shares=    15 reason=SL net=-1058.08 cash=64438.66
# 2025-10-17 00:07:29 | INFO | Exit LT.NS        px=  945.22 shares=    14 reason=TimeStop net=83.25 cash=77618.80
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-06-12:
# 2025-10-17 00:07:29 | INFO |   IDEA.NS      volar=  0.75 rank=1 px=   98.97
# 2025-10-17 00:07:29 | INFO | BUY IDEA.NS      px=  101.63 sh=   267 fee=55.82 cash=50428.55 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.75); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-06-15:
# 2025-10-17 00:07:29 | INFO |   BEML.NS      volar=  2.47 rank=1 px=  966.92
# 2025-10-17 00:07:29 | INFO | BUY BEML.NS      px=  953.67 sh=    18 fee=40.64 cash=33221.90 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.47); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit BRITANNIA.NS px= 1165.09 shares=    20 reason=TimeStop net=761.13 cash=56452.30
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-06-25:
# 2025-10-17 00:07:29 | INFO |   NAVINFLUOR.NS volar=  2.30 rank=1 px=  179.19
# 2025-10-17 00:07:29 | INFO | BUY NAVINFLUOR.NS px=  180.47 sh=   109 fee=46.57 cash=36734.57 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.30); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit MOTHERSON.NS px=   34.76 shares=   819 reason=SL net=730.41 cash=65125.05
# 2025-10-17 00:07:29 | INFO | Exit PRAJIND.NS   px=   73.07 shares=   608 reason=TimeStop net=1762.05 cash=109458.72
# 2025-10-17 00:07:29 | INFO | Selected 2 BUY candidates on 2015-06-29:
# 2025-10-17 00:07:29 | INFO |   CANFINHOME.NS volar=  2.07 rank=1 px=  136.92
# 2025-10-17 00:07:29 | INFO |   BPCL.NS      volar=  1.94 rank=2 px=   77.26
# 2025-10-17 00:07:29 | INFO | BUY CANFINHOME.NS px=  138.12 sh=   113 fee=36.95 cash=93813.80 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=2.07); MVO weight=40.7% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY BPCL.NS      px=   78.88 sh=   287 fee=50.48 cash=71124.19 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=1.94); MVO weight=59.3% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit KEC.NS       px=  119.32 shares=   307 reason=TimeStop net=1943.42 cash=107670.60
# 2025-10-17 00:07:29 | INFO | Exit NAVINFLUOR.NS px=  199.48 shares=   109 reason=TP2 net=1956.24 cash=129344.57
# 2025-10-17 00:07:29 | INFO | Selected 2 BUY candidates on 2015-07-01:
# 2025-10-17 00:07:29 | INFO |   KEI.NS       volar=  1.50 rank=1 px=   75.61
# 2025-10-17 00:07:29 | INFO |   DABUR.NS     volar=  1.39 rank=2 px=  254.98
# 2025-10-17 00:07:29 | INFO | BUY KEI.NS       px=   70.81 sh=   177 fee=29.67 cash=116781.87 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=1.50); MVO weight=27.7% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY DABUR.NS     px=  255.70 sh=   128 fee=62.46 cash=83989.83 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=1.39); MVO weight=72.3% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit KEI.NS       px=   71.00 shares=   177 reason=SL net=-47.13 cash=96505.40
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-07-02:
# 2025-10-17 00:07:29 | INFO |   NAVINFLUOR.NS volar=  2.52 rank=1 px=  197.01
# 2025-10-17 00:07:29 | INFO | BUY NAVINFLUOR.NS px=  195.24 sh=   173 fee=63.71 cash=62665.05 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.52); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit IDEA.NS      px=  108.99 shares=   267 reason=TimeStop net=1832.82 cash=91688.13
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-07-03:
# 2025-10-17 00:07:29 | INFO |   SAMMAANCAP.NS volar=  2.32 rank=1 px=  440.88
# 2025-10-17 00:07:29 | INFO | BUY SAMMAANCAP.NS px=  430.77 sh=    74 fee=61.45 cash=59749.44 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.32); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit BEML.NS      px= 1014.69 shares=    18 reason=TimeStop net=993.58 cash=77949.67
# 2025-10-17 00:07:29 | INFO | Exit BPCL.NS      px=   82.91 shares=   287 reason=TP2 net=1034.92 cash=101674.20
# 2025-10-17 00:07:29 | INFO | Exit DABUR.NS     px=  245.47 shares=   128 reason=SL net=-1451.16 cash=133015.08
# 2025-10-17 00:07:29 | INFO | Selected 3 BUY candidates on 2015-07-06:
# 2025-10-17 00:07:29 | INFO |   SIEMENS.NS   volar=  2.61 rank=1 px=  738.32
# 2025-10-17 00:07:29 | INFO |   EMAMILTD.NS  volar=  2.17 rank=2 px=  523.33
# 2025-10-17 00:07:29 | INFO |   LUPIN.NS     volar=  1.90 rank=3 px= 1693.94
# 2025-10-17 00:07:29 | INFO | BUY SIEMENS.NS   px=  753.07 sh=    19 fee=33.87 cash=118672.87 :: SMC W→D long; VOLAR rank 1/3 (VOLAR=2.61); MVO weight=31.8% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY EMAMILTD.NS  px=  525.98 sh=    23 fee=28.64 cash=106546.74 :: SMC W→D long; VOLAR rank 2/3 (VOLAR=2.17); MVO weight=26.4% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY LUPIN.NS     px= 1805.46 sh=    10 fee=42.74 cash=88449.39 :: SMC W→D long; VOLAR rank 3/3 (VOLAR=1.90); MVO weight=41.8% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit SAMMAANCAP.NS px=  416.73 shares=    74 reason=SL net=-1179.79 cash=119208.28
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-07-08:
# 2025-10-17 00:07:29 | INFO |   WELCORP.NS   volar=  2.23 rank=1 px=  113.95
# 2025-10-17 00:07:29 | INFO | BUY WELCORP.NS   px=  111.82 sh=   373 fee=73.13 cash=77425.65 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.23); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit EMAMILTD.NS  px=  498.60 shares=    23 reason=SL net=-707.41 cash=88844.37
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-07-09:
# 2025-10-17 00:07:29 | INFO |   APLLTD.NS    volar=  2.81 rank=1 px=  665.40
# 2025-10-17 00:07:29 | INFO | BUY APLLTD.NS    px=  661.76 sh=    46 fee=59.75 cash=58343.85 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.81); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit LUPIN.NS     px= 1834.46 shares=    10 reason=TP2 net=182.97 cash=76624.17
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-07-15:
# 2025-10-17 00:07:29 | INFO |   FORTIS.NS    volar=  1.94 rank=1 px=  186.43
# 2025-10-17 00:07:29 | INFO | BUY FORTIS.NS    px=  185.53 sh=   144 fee=55.32 cash=49852.36 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=1.94); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit CANFINHOME.NS px=  150.94 shares=   113 reason=TP2 net=1349.72 cash=66847.00
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-07-16:
# 2025-10-17 00:07:29 | INFO |   LUPIN.NS     volar=  1.89 rank=1 px= 1843.36
# 2025-10-17 00:07:29 | INFO | BUY LUPIN.NS     px= 1846.95 sh=    12 fee=49.92 cash=44633.64 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=1.89); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit LUPIN.NS     px= 1776.94 shares=    12 reason=SL net=-959.43 cash=65887.57
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-07-21:
# 2025-10-17 00:07:29 | INFO |   CHENNPETRO.NS volar=  2.80 rank=1 px=  147.36
# 2025-10-17 00:07:29 | INFO | BUY CHENNPETRO.NS px=  142.70 sh=   161 fee=50.88 cash=42861.48 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.80); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit NAVINFLUOR.NS px=  207.39 shares=   173 reason=TimeStop net=1954.39 cash=78656.22
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-07-23:
# 2025-10-17 00:07:29 | INFO |   HINDPETRO.NS volar=  2.29 rank=1 px=   82.43
# 2025-10-17 00:07:29 | INFO | BUY HINDPETRO.NS px=   82.01 sh=   335 fee=56.22 cash=51126.44 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.29); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit CHENNPETRO.NS px=  136.12 shares=   161 reason=SL net=-1181.05 cash=72971.48
# 2025-10-17 00:07:29 | INFO | Exit SIEMENS.NS   px=  738.32 shares=    19 reason=SL net=-368.84 cash=86944.84
# 2025-10-17 00:07:29 | INFO | Selected 2 BUY candidates on 2015-07-27:
# 2025-10-17 00:07:29 | INFO |   TATAELXSI.NS volar=  3.11 rank=1 px=  708.95
# 2025-10-17 00:07:29 | INFO |   VTL.NS       volar=  2.31 rank=2 px=  132.04
# 2025-10-17 00:07:29 | INFO | BUY TATAELXSI.NS px=  752.62 sh=    20 fee=35.64 cash=71856.86 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=3.11); MVO weight=51.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY VTL.NS       px=  131.57 sh=   113 fee=35.20 cash=56954.49 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=2.31); MVO weight=49.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit WELCORP.NS   px=  112.25 shares=   373 reason=TimeStop net=-5.18 cash=98731.94
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-07-29:
# 2025-10-17 00:07:29 | INFO |   WELSPUNLIV.NS volar=  3.77 rank=1 px=   77.78
# 2025-10-17 00:07:29 | INFO | BUY WELSPUNLIV.NS px=   79.40 sh=   435 fee=64.61 cash=64129.23 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=3.77); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit APLLTD.NS    px=  675.67 shares=    46 reason=TimeStop net=500.67 cash=95130.41
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-07-30:
# 2025-10-17 00:07:29 | INFO |   NAVINFLUOR.NS volar=  2.83 rank=1 px=  224.50
# 2025-10-17 00:07:29 | INFO | BUY NAVINFLUOR.NS px=  233.94 sh=   142 fee=63.04 cash=61848.18 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.83); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit VTL.NS       px=  146.14 shares=   113 reason=TP2 net=1551.67 cash=78302.23
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-08-03:
# 2025-10-17 00:07:29 | INFO |   BRITANNIA.NS volar=  2.95 rank=1 px= 1387.36
# 2025-10-17 00:07:29 | INFO | BUY BRITANNIA.NS px= 1370.25 sh=    20 fee=56.14 cash=50841.02 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.95); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit WELSPUNLIV.NS px=   87.63 shares=   435 reason=TP2 net=3431.17 cash=88874.90
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-08-04:
# 2025-10-17 00:07:29 | INFO |   VTL.NS       volar=  2.52 rank=1 px=  146.22
# 2025-10-17 00:07:29 | INFO | BUY VTL.NS       px=  144.87 sh=   214 fee=60.41 cash=57812.48 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.52); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit FORTIS.NS    px=  197.01 shares=   144 reason=TimeStop net=1520.83 cash=86105.12
# 2025-10-17 00:07:29 | INFO | Exit TATAELXSI.NS px=  852.94 shares=    20 reason=TP2 net=1909.47 cash=103102.57
# 2025-10-17 00:07:29 | INFO | Selected 2 BUY candidates on 2015-08-05:
# 2025-10-17 00:07:29 | INFO |   WELSPUNLIV.NS volar=  3.82 rank=1 px=   84.89
# 2025-10-17 00:07:29 | INFO |   SAMMAANCAP.NS volar=  2.84 rank=2 px=  520.42
# 2025-10-17 00:07:29 | INFO | BUY WELSPUNLIV.NS px=   85.55 sh=   232 fee=46.99 cash=83207.03 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=3.82); MVO weight=55.1% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY SAMMAANCAP.NS px=  526.32 sh=    30 fee=37.38 cash=67380.16 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=2.84); MVO weight=44.9% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit VTL.NS       px=  160.39 shares=   214 reason=TP2 net=3177.89 cash=101620.47
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-08-06:
# 2025-10-17 00:07:29 | INFO |   TATAELXSI.NS volar=  3.13 rank=1 px=  828.04
# 2025-10-17 00:07:29 | INFO | BUY TATAELXSI.NS px=  824.03 sh=    43 fee=65.67 cash=66121.43 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=3.13); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit HINDPETRO.NS px=   89.33 shares=   335 reason=TP2 net=2317.47 cash=95968.68
# 2025-10-17 00:07:29 | INFO | Exit WELSPUNLIV.NS px=   78.82 shares=   232 reason=SL net=-1673.34 cash=114190.89
# 2025-10-17 00:07:29 | INFO | Selected 2 BUY candidates on 2015-08-10:
# 2025-10-17 00:07:29 | INFO |   3MINDIA.NS   volar=  2.12 rank=1 px= 9728.51
# 2025-10-17 00:07:29 | INFO |   AARTIIND.NS  volar=  2.05 rank=2 px=   99.32
# 2025-10-17 00:07:29 | INFO | BUY 3MINDIA.NS   px= 9764.37 sh=     2 fee=46.23 cash=94615.91 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=2.12); MVO weight=57.2% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY AARTIIND.NS  px=  103.46 sh=   165 fee=40.41 cash=77505.10 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=2.05); MVO weight=42.8% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit BRITANNIA.NS px= 1475.84 shares=    20 reason=TP2 net=1977.70 cash=106944.00
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-08-11:
# 2025-10-17 00:07:29 | INFO |   VTL.NS       volar=  2.86 rank=1 px=  165.04
# 2025-10-17 00:07:29 | INFO | BUY VTL.NS       px=  163.89 sh=   228 fee=67.97 cash=69508.92 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.86); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit 3MINDIA.NS   px= 9204.30 shares=     2 reason=SL net=-1230.80 cash=87853.10
# 2025-10-17 00:07:29 | INFO | Exit TATAELXSI.NS px=  763.63 shares=    43 reason=SL net=-2744.41 cash=120607.73
# 2025-10-17 00:07:29 | INFO | Exit VTL.NS       px=  153.82 shares=   228 reason=SL net=-2448.48 cash=155594.33
# 2025-10-17 00:07:29 | INFO | Selected 3 BUY candidates on 2015-08-12:
# 2025-10-17 00:07:29 | INFO |   BRITANNIA.NS volar=  3.35 rank=1 px= 1470.74
# 2025-10-17 00:07:29 | INFO |   CHENNPETRO.NS volar=  2.94 rank=2 px=  190.01
# 2025-10-17 00:07:29 | INFO |   COFORGE.NS   volar=  1.69 rank=3 px=   91.52
# 2025-10-17 00:07:29 | INFO | BUY BRITANNIA.NS px= 1470.74 sh=    21 fee=60.27 cash=124648.41 :: SMC W→D long; VOLAR rank 1/3 (VOLAR=3.35); MVO weight=59.3% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY CHENNPETRO.NS px=  180.94 sh=    57 fee=24.42 cash=114310.51 :: SMC W→D long; VOLAR rank 2/3 (VOLAR=2.94); MVO weight=19.1% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | BUY COFORGE.NS   px=   92.76 sh=   127 fee=27.89 cash=102502.69 :: SMC W→D long; VOLAR rank 3/3 (VOLAR=1.69); MVO weight=21.7% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit NAVINFLUOR.NS px=  265.85 shares=   142 reason=TP2 net=4381.85 cash=140166.77
# 2025-10-17 00:07:29 | INFO | Selected 1 BUY candidates on 2015-08-20:
# 2025-10-17 00:07:29 | INFO |   MARUTI.NS    volar=  2.33 rank=1 px= 4202.15
# 2025-10-17 00:07:29 | INFO | BUY MARUTI.NS    px= 4205.91 sh=    11 fee=78.54 cash=93823.20 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.33); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:07:29 | INFO | Exit BRITANNIA.NS px= 1371.52 shares=    21 reason=SL net=-2221.08 cash=122548.04
# 2025-10-17 00:07:29 | INFO | Exit MARUTI.NS    px= 4110.76 shares=    11 reason=SL net=-1219.29 cash=167672.33
# 2025-10-17 00:07:29 | INFO | Selected 2 BUY candidates on 2015-08-21:
# 2025-10-17 00:07:29 | INFO |   NAVINFLUOR.NS volar=  2.91 rank=1 px=  249.75
# ...
# 2025-10-17 00:08:13 | INFO | Exit MOTILALOFS.NS px=  900.03 shares=    58 reason=SL net=-3356.00 cash=170244.94
# 2025-10-17 00:08:13 | INFO | Selected 1 BUY candidates on 2024-10-23:
# 2025-10-17 00:08:13 | INFO |   CHOICEIN.NS  volar=  2.03 rank=1 px=  481.05
# 2025-10-17 00:08:13 | INFO | BUY CHOICEIN.NS  px=  481.90 sh=   123 fee=93.98 cash=110877.26 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.03); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:13 | INFO | Exit CHOICEIN.NS  px=  456.87 shares=   123 reason=SL net=-3277.77 cash=166967.17
# 2025-10-17 00:08:13 | INFO | Selected 1 BUY candidates on 2024-10-25:
# 2025-10-17 00:08:13 | INFO |   ASTERDM.NS   volar=  0.96 rank=1 px=  434.56
# 2025-10-17 00:08:13 | INFO | BUY ASTERDM.NS   px=  444.22 sh=   131 fee=92.70 cash=108682.13 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.96); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:13 | INFO | Exit ANANDRATHI.NS px= 1952.33 shares=    14 reason=SL net=-919.34 cash=135939.25
# 2025-10-17 00:08:13 | INFO | Exit GVT&D.NS     px= 1608.38 shares=    19 reason=SL net=-2712.99 cash=166419.60
# 2025-10-17 00:08:13 | INFO | Selected 2 BUY candidates on 2024-10-28:
# 2025-10-17 00:08:13 | INFO |   MCX.NS       volar=  2.13 rank=1 px= 6474.27
# 2025-10-17 00:08:13 | INFO |   RADICO.NS    volar=  1.16 rank=2 px= 2256.73
# 2025-10-17 00:08:13 | INFO | BUY MCX.NS       px= 6540.42 sh=     5 fee=62.43 cash=133655.07 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=2.13); MVO weight=64.5% of capped cash (35% of available)
# 2025-10-17 00:08:13 | INFO | BUY RADICO.NS    px= 2294.47 sh=     9 fee=48.12 cash=112956.69 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=1.16); MVO weight=35.5% of capped cash (35% of available)
# 2025-10-17 00:08:13 | INFO | Exit MCX.NS       px= 6474.27 shares=     5 reason=SL net=-473.95 cash=145247.28
# 2025-10-17 00:08:13 | INFO | Selected 1 BUY candidates on 2024-10-30:
# 2025-10-17 00:08:13 | INFO |   DEEPAKFERT.NS volar=  0.85 rank=1 px= 1315.58
# 2025-10-17 00:08:13 | INFO | BUY DEEPAKFERT.NS px= 1206.11 sh=    42 fee=83.75 cash=94506.80 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=0.85); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:13 | INFO | Exit WOCKPHARMA.NS px= 1232.57 shares=    20 reason=TP2 net=3196.65 cash=119085.38
# 2025-10-17 00:08:13 | INFO | Selected 1 BUY candidates on 2024-11-01:
# 2025-10-17 00:08:13 | INFO |   CHOICEIN.NS  volar=  2.27 rank=1 px=  524.90
# 2025-10-17 00:08:13 | INFO | BUY CHOICEIN.NS  px=  522.85 sh=    79 fee=72.65 cash=77707.59 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.27); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:13 | INFO | Exit NEULANDLAB.NS px=14073.00 shares=     1 reason=SL net=376.59 cash=91725.78
# 2025-10-17 00:08:13 | INFO | Selected 1 BUY candidates on 2024-11-06:
# 2025-10-17 00:08:13 | INFO |   TARIL.NS     volar=  2.75 rank=1 px=  482.30
# 2025-10-17 00:08:13 | INFO | BUY TARIL.NS     px=  486.45 sh=    65 fee=61.14 cash=60045.50 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.75); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit BSE.NS       px= 1629.53 shares=    26 reason=TimeStop net=5277.32 cash=102322.05
# 2025-10-17 00:08:14 | INFO | Selected 1 BUY candidates on 2024-11-08:
# 2025-10-17 00:08:14 | INFO |   VIJAYA.NS    volar=  1.08 rank=1 px= 1022.94
# 2025-10-17 00:08:14 | INFO | BUY VIJAYA.NS    px= 1117.20 sh=    32 fee=66.05 cash=66505.61 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=1.08); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit RADICO.NS    px= 2256.73 shares=     9 reason=SL net=-456.10 cash=86747.88
# 2025-10-17 00:08:14 | INFO | Selected 1 BUY candidates on 2024-11-11:
# 2025-10-17 00:08:14 | INFO |   GODFRYPHLP.NS volar=  1.47 rank=1 px= 2175.11
# 2025-10-17 00:08:14 | INFO | BUY GODFRYPHLP.NS px= 2187.03 sh=    13 fee=57.36 cash=58259.17 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=1.47); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit TARIL.NS     px=  482.30 shares=    65 reason=SL net=-410.50 cash=89528.94
# 2025-10-17 00:08:14 | INFO | Selected 1 BUY candidates on 2024-11-12:
# 2025-10-17 00:08:14 | INFO |   PGEL.NS      volar=  1.92 rank=1 px=  632.72
# 2025-10-17 00:08:14 | INFO | BUY PGEL.NS      px=  648.96 sh=    48 fee=60.59 cash=58318.09 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=1.92); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit VIJAYA.NS    px= 1022.94 shares=    32 reason=SL net=-3163.53 cash=90971.00
# 2025-10-17 00:08:14 | INFO | Selected 1 BUY candidates on 2024-11-13:
# 2025-10-17 00:08:14 | INFO |   TARIL.NS     volar=  2.55 rank=1 px=  444.84
# 2025-10-17 00:08:14 | INFO | BUY TARIL.NS     px=  444.84 sh=    71 fee=61.10 cash=59326.22 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.55); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit ASTERDM.NS   px=  430.61 shares=   131 reason=StructureFlip net=-1981.47 cash=115629.79
# 2025-10-17 00:08:14 | INFO | Selected 1 BUY candidates on 2024-11-14:
# 2025-10-17 00:08:14 | INFO |   SIEMENS.NS   volar=  1.51 rank=1 px= 3921.43
# 2025-10-17 00:08:14 | INFO | BUY SIEMENS.NS   px= 3940.65 sh=    10 fee=70.39 cash=76152.91 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=1.51); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit GODFRYPHLP.NS px= 1991.56 shares=    13 reason=SL net=-2672.54 cash=101969.09
# 2025-10-17 00:08:14 | INFO | Selected 1 BUY candidates on 2024-11-18:
# 2025-10-17 00:08:14 | INFO |   ETERNAL.NS   volar=  1.69 rank=1 px=  274.30
# 2025-10-17 00:08:14 | INFO | BUY ETERNAL.NS   px=  270.79 sh=   131 fee=65.72 cash=66429.88 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=1.69); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit DEEPAKFERT.NS px= 1270.90 shares=    42 reason=TimeStop net=2534.69 cash=119705.05
# 2025-10-17 00:08:14 | INFO | Selected 1 BUY candidates on 2024-11-22:
# 2025-10-17 00:08:14 | INFO |   JYOTICNC.NS  volar=  2.13 rank=1 px= 1232.30
# 2025-10-17 00:08:14 | INFO | BUY JYOTICNC.NS  px= 1231.15 sh=    34 fee=73.30 cash=77772.64 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.13); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit SIEMENS.NS   px= 4262.17 shares=    10 reason=TP2 net=3053.46 cash=120302.97
# 2025-10-17 00:08:14 | INFO | Selected 1 BUY candidates on 2024-11-25:
# 2025-10-17 00:08:14 | INFO |   UNITDSPR.NS  volar=  1.61 rank=1 px= 1505.62
# 2025-10-17 00:08:14 | INFO | BUY UNITDSPR.NS  px= 1473.11 sh=    28 fee=72.58 cash=78983.32 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=1.61); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit CHOICEIN.NS  px=  524.90 shares=    79 reason=SL net=-0.91 cash=120360.21
# 2025-10-17 00:08:14 | INFO | Exit UNITDSPR.NS  px= 1458.16 shares=    28 reason=SL net=-580.59 cash=161099.26
# 2025-10-17 00:08:14 | INFO | Selected 2 BUY candidates on 2024-11-26:
# 2025-10-17 00:08:14 | INFO |   TRENT.NS     volar=  2.10 rank=1 px= 6769.14
# 2025-10-17 00:08:14 | INFO |   NAVA.NS      volar=  1.65 rank=2 px=  519.32
# 2025-10-17 00:08:14 | INFO | BUY TRENT.NS     px= 6663.58 sh=     5 fee=63.16 cash=127718.22 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=2.10); MVO weight=63.2% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | BUY NAVA.NS      px=  508.68 sh=    40 fee=47.76 cash=107323.44 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=1.65); MVO weight=36.8% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit NAVA.NS      px=  519.32 shares=    40 reason=SL net=309.24 cash=128027.46
# 2025-10-17 00:08:14 | INFO | Exit PGEL.NS      px=  738.33 shares=    48 reason=TP2 net=4144.93 cash=163383.24
# 2025-10-17 00:08:14 | INFO | Selected 2 BUY candidates on 2024-12-02:
# 2025-10-17 00:08:14 | INFO |   HUDCO.NS     volar=  1.57 rank=1 px=  233.90
# 2025-10-17 00:08:14 | INFO |   PPLPHARMA.NS volar=  1.53 rank=2 px=  271.12
# 2025-10-17 00:08:14 | INFO | BUY HUDCO.NS     px=  231.94 sh=    88 fee=47.84 cash=142924.86 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=1.57); MVO weight=35.9% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | BUY PPLPHARMA.NS px=  273.27 sh=   134 fee=67.08 cash=106239.21 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=1.53); MVO weight=64.1% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit TARIL.NS     px=  522.28 shares=    71 reason=TimeStop net=5351.67 cash=143235.66
# 2025-10-17 00:08:14 | INFO | Selected 1 BUY candidates on 2024-12-06:
# 2025-10-17 00:08:14 | INFO |   AIIL.NS      volar=  1.59 rank=1 px= 1612.12
# 2025-10-17 00:08:14 | INFO | BUY AIIL.NS      px= 1653.49 sh=    30 fee=82.50 cash=93548.53 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=1.59); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit AIIL.NS      px= 1775.83 shares=    30 reason=TP2 net=3485.39 cash=146721.05
# 2025-10-17 00:08:14 | INFO | Exit ETERNAL.NS   px=  296.75 shares=   131 reason=TimeStop net=3247.51 cash=185507.77
# 2025-10-17 00:08:14 | INFO | Selected 2 BUY candidates on 2024-12-10:
# 2025-10-17 00:08:14 | INFO |   ZENTEC.NS    volar=  1.81 rank=1 px= 2012.11
# 2025-10-17 00:08:14 | INFO |   KALYANKJIL.NS volar=  1.72 rank=2 px=  775.73
# 2025-10-17 00:08:14 | INFO | BUY ZENTEC.NS    px= 2061.25 sh=    13 fee=55.42 cash=158656.16 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=1.81); MVO weight=44.4% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | BUY KALYANKJIL.NS px=  756.69 sh=    47 fee=65.83 cash=123026.10 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=1.72); MVO weight=55.6% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit JYOTICNC.NS  px= 1267.80 shares=    34 reason=TimeStop net=1080.88 cash=166039.38
# 2025-10-17 00:08:14 | INFO | Exit PPLPHARMA.NS px=  249.71 shares=   134 reason=SL net=-3306.48 cash=199418.56
# 2025-10-17 00:08:14 | INFO | Selected 2 BUY candidates on 2024-12-13:
# 2025-10-17 00:08:14 | INFO |   CHALET.NS    volar=  1.22 rank=1 px= 1009.65
# 2025-10-17 00:08:14 | INFO |   MAXHEALTH.NS volar=  1.06 rank=2 px= 1170.75
# 2025-10-17 00:08:14 | INFO | BUY CHALET.NS    px= 1007.55 sh=    39 fee=70.26 cash=160053.85 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=1.22); MVO weight=56.4% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | BUY MAXHEALTH.NS px= 1178.69 sh=    25 fee=58.59 cash=130528.01 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=1.06); MVO weight=43.6% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit ZENTEC.NS    px= 2261.62 shares=    13 reason=TP2 net=2471.75 cash=159851.38
# 2025-10-17 00:08:14 | INFO | Selected 1 BUY candidates on 2024-12-16:
# 2025-10-17 00:08:14 | INFO |   PGEL.NS      volar=  2.46 rank=1 px=  932.59
# 2025-10-17 00:08:14 | INFO | BUY PGEL.NS      px=  999.71 sh=    55 fee=88.89 cash=104778.48 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.46); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit TRENT.NS     px= 6993.94 shares=     5 reason=TimeStop net=1505.18 cash=139664.70
# 2025-10-17 00:08:14 | INFO | Selected 1 BUY candidates on 2024-12-17:
# 2025-10-17 00:08:14 | INFO |   ZENTEC.NS    volar=  2.32 rank=1 px= 2330.72
# 2025-10-17 00:08:14 | INFO | BUY ZENTEC.NS    px= 2397.27 sh=    20 fee=80.53 cash=91638.73 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.32); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit PGEL.NS      px=  932.59 shares=    55 reason=SL net=-3880.92 cash=142830.71
# 2025-10-17 00:08:14 | INFO | Selected 1 BUY candidates on 2024-12-18:
# 2025-10-17 00:08:14 | INFO |   GVT&D.NS     volar=  3.10 rank=1 px= 2074.20
# 2025-10-17 00:08:14 | INFO | BUY GVT&D.NS     px= 2049.15 sh=    24 fee=82.00 cash=93569.22 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=3.10); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit KALYANKJIL.NS px=  718.55 shares=    47 reason=SL net=-1940.57 cash=127258.71
# 2025-10-17 00:08:14 | INFO | Selected 1 BUY candidates on 2024-12-20:
# 2025-10-17 00:08:14 | INFO |   KFINTECH.NS  volar=  2.00 rank=1 px= 1395.66
# 2025-10-17 00:08:14 | INFO | BUY KFINTECH.NS  px= 1434.89 sh=    31 fee=76.42 cash=82700.61 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=2.00); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit CHALET.NS    px=  948.62 shares=    39 reason=SL net=-2454.26 cash=119611.06
# 2025-10-17 00:08:14 | INFO | Exit HUDCO.NS     px=  236.82 shares=    88 reason=TimeStop net=313.01 cash=140382.45
# 2025-10-17 00:08:14 | INFO | Selected 2 BUY candidates on 2024-12-23:
# 2025-10-17 00:08:14 | INFO |   TARIL.NS     volar=  2.94 rank=1 px=  541.53
# 2025-10-17 00:08:14 | INFO |   NEWGEN.NS    volar=  1.58 rank=2 px= 1581.25
# 2025-10-17 00:08:14 | INFO | BUY TARIL.NS     px=  539.85 sh=    61 fee=62.70 cash=107388.83 :: SMC W→D long; VOLAR rank 1/2 (VOLAR=2.94); MVO weight=67.5% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | BUY NEWGEN.NS    px= 1577.62 sh=    10 fee=37.35 cash=91575.27 :: SMC W→D long; VOLAR rank 2/2 (VOLAR=1.58); MVO weight=32.5% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit GVT&D.NS     px= 2074.20 shares=    24 reason=SL net=420.46 cash=141257.22
# 2025-10-17 00:08:14 | INFO | Selected 1 BUY candidates on 2024-12-24:
# 2025-10-17 00:08:14 | INFO |   TECHNOE.NS   volar=  1.48 rank=1 px= 1624.95
# 2025-10-17 00:08:14 | INFO | BUY TECHNOE.NS   px= 1590.21 sh=    31 fee=82.14 cash=91878.48 :: SMC W→D long; VOLAR rank 1/1 (VOLAR=1.48); MVO weight=100.0% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | Exit KFINTECH.NS  px= 1527.03 shares=    31 reason=final_close net=2683.40 cash=139119.99
# 2025-10-17 00:08:14 | INFO | Exit MAXHEALTH.NS px= 1126.85 shares=    25 reason=final_close net=-1431.02 cash=167214.81
# 2025-10-17 00:08:14 | INFO | Exit NEWGEN.NS    px= 1693.50 shares=    10 reason=final_close net=1060.32 cash=184088.69
# 2025-10-17 00:08:14 | INFO | Exit TARIL.NS     px=  569.66 shares=    61 reason=final_close net=1672.62 cash=218754.93
# 2025-10-17 00:08:14 | INFO | Exit TECHNOE.NS   px= 1561.04 shares=    31 reason=final_close net=-1083.80 cash=267049.87
# 2025-10-17 00:08:14 | INFO | Exit ZENTEC.NS    px= 2442.21 shares=    20 reason=final_close net=720.33 cash=315796.18
# 2025-10-17 00:08:14 | INFO | Selected 4 BUY candidates on 2024-12-31:
# 2025-10-17 00:08:14 | INFO |   FSL.NS       volar=  1.50 rank=1 px=  371.88
# 2025-10-17 00:08:14 | INFO |   DIVISLAB.NS  volar=  1.48 rank=2 px= 6002.07
# 2025-10-17 00:08:14 | INFO |   HSCL.NS      volar=  1.44 rank=3 px=  586.21
# 2025-10-17 00:08:14 | INFO |   PTCIL.NS     volar=  1.28 rank=4 px=13487.00
# 2025-10-17 00:08:14 | INFO | BUY FSL.NS       px=  371.88 sh=    59 fee=49.65 cash=293805.87 :: SMC W→D long; VOLAR rank 1/4 (VOLAR=1.50); MVO weight=19.9% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | BUY DIVISLAB.NS  px= 6071.16 sh=     8 fee=81.27 cash=245155.36 :: SMC W→D long; VOLAR rank 2/4 (VOLAR=1.48); MVO weight=48.3% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | BUY HSCL.NS      px=  583.96 sh=    34 fee=47.00 cash=225253.68 :: SMC W→D long; VOLAR rank 3/4 (VOLAR=1.44); MVO weight=18.2% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | BUY PTCIL.NS     px=13458.60 sh=     1 fee=31.86 cash=211763.22 :: SMC W→D long; VOLAR rank 4/4 (VOLAR=1.28); MVO weight=13.6% of capped cash (35% of available)
# 2025-10-17 00:08:14 | INFO | === METRICS ===
# {
#   "start_equity_inr": 200000.0,
#   "final_equity_inr": 315586.38900644984,
#   "cagr_pct": 4.727009546740457,
#   "sharpe": 0.36854714006387707,
#   "max_drawdown_pct": -55.428264313896825,
#   "win_rate_pct": 40.72727272727273,
#   "n_trades": 1925
# }
# 2025-10-17 00:08:14 | INFO | Files written:
#   outputs/trades_legs_20251017_000814.csv
#   outputs/trades_roundtrips_20251017_000814.csv
#   outputs/equity_20251017_000814.csv
#   outputs/metrics_20251017_000814.json
# 2025-10-17 00:08:14 | INFO |   outputs/equity_20251017_000814.png
