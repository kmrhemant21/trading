# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import os, json, math, warnings, logging
from dataclasses import dataclass
from typing import Dict, List, Tuple, Optional

import numpy as np
import pandas as pd

try:
    import yfinance as yf
    import matplotlib.pyplot as plt
except Exception:
    pass

warnings.filterwarnings("ignore", category=FutureWarning)

# =========================
# LOGGING
# =========================
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)
log = logging.getLogger("candle_confirm_mvo_v1")

# =========================
# CONFIG
# =========================
@dataclass
class Config:
    # Data
    start_date: str = "2015-01-01"
    end_date: str   = "2025-01-01"
    static_symbols: Optional[List[str]] = None
    static_symbols_path: Optional[str] = None
    cache_dir: str = "cache"
    out_dir: str   = "outputs"
    plot: bool     = True

    # Trend filters
    ema_fast: int = 10
    ema_slow: int = 20
    ema_htf:  int = 200  # long-term trend
    use_htf_trend: bool = True  # require Close > EMA200

    # Exits
    stop_loss_pct: float = 0.05
    target_pct: float    = 0.10

    # Portfolio
    apply_fees: bool    = True
    initial_capital: float = 500_000.0
    max_concurrent_positions: int = 5
    deploy_cash_frac: float = 0.25
    top_k_daily: int = 300

    # Ranking & filters
    benchmark_try: Tuple[str,...] = ("^CNX500","^CRSLDX","^NSE500","^NIFTY500","^BSE500","^NSEI")
    volar_lookback: int = 252
    filter_52w_window: int = 252
    within_pct_of_52w_high: float = 0.50

    # Liquidity guards (optional)
    enable_basic_liquidity: bool = False
    min_price_inr: float = 50.0
    min_avg_vol_20d: float = 50_000.0

CFG = Config()

# =========================
# FEES (Groww-like)
# =========================
APPLY_FEES = True

def calc_fees(turnover_buy: float, turnover_sell: float) -> float:
    if not APPLY_FEES:
        return 0.0
    BROKER_PCT = 0.001
    BROKER_MIN = 5.0
    BROKER_CAP = 20.0
    STT_PCT = 0.001
    STAMP_BUY_PCT = 0.00015
    EXCH_PCT = 0.0000297
    SEBI_PCT = 0.000001
    IPFT_PCT = 0.000001
    GST_PCT = 0.18
    DP_SELL = 20.0 if turnover_sell >= 100 else 0.0

    def _broker(turnover):
        if turnover <= 0: return 0.0
        fee = turnover * BROKER_PCT
        return max(BROKER_MIN, min(fee, BROKER_CAP))

    br_buy  = _broker(turnover_buy)
    br_sell = _broker(turnover_sell)
    stt   = STT_PCT * (turnover_buy + turnover_sell)
    stamp = STAMP_BUY_PCT * turnover_buy
    exch  = EXCH_PCT * (turnover_buy + turnover_sell)
    sebi  = SEBI_PCT * (turnover_buy + turnover_sell)
    ipft  = IPFT_PCT * (turnover_buy + turnover_sell)
    dp    = DP_SELL
    gst_base = br_buy + br_sell + dp + exch + sebi + ipft
    gst   = GST_PCT * gst_base
    return float((br_buy + br_sell) + stt + stamp + exch + sebi + ipft + dp + gst)

# =========================
# Helpers
# =========================
def ensure_dirs(*paths): [os.makedirs(p, exist_ok=True) for p in paths]

def today_str():
    return pd.Timestamp.today(tz="Asia/Kolkata").strftime("%Y-%m-%d")

def load_static_symbols(static_symbols: Optional[List[str]], static_symbols_path: Optional[str]) -> List[str]:
    syms: List[str] = []
    if static_symbols and len(static_symbols) > 0:
        syms = list(static_symbols)
    elif static_symbols_path and os.path.exists(static_symbols_path):
        with open(static_symbols_path, "r") as f:
            syms = [line.strip() for line in f if line.strip()]
    else:
        raise ValueError("Provide CFG.static_symbols=[...] or CFG.static_symbols_path file.")
    out = []
    for s in syms:
        s = s.strip().upper()
        if not s.endswith(".NS"): s = f"{s}.NS"
        out.append(s)
    uniq = []
    seen = set()
    for s in out:
        if s not in seen:
            uniq.append(s); seen.add(s)
    return uniq

def fetch_prices(tickers: List[str], start: str, end: Optional[str], cache_dir: str) -> Dict[str, pd.DataFrame]:
    ensure_dirs(cache_dir)
    data = {}
    end = end or today_str()
    for ticker in tickers:
        cache_path = os.path.join(cache_dir, f"{ticker.replace('^','_')}.parquet")
        if os.path.exists(cache_path):
            try:
                df = pd.read_parquet(cache_path)
                if len(df) and pd.to_datetime(df.index[-1]).strftime("%Y-%m-%d") >= end:
                    data[ticker] = df; continue
            except Exception:
                pass
        try:
            df = yf.download(ticker, start=start, end=end, auto_adjust=True, progress=False, multi_level_index=False)
            if df is None or df.empty: continue
            df = df.rename(columns=str.title)[['Open','High','Low','Close','Volume']].dropna()
            df.index.name = "date"
            df.to_parquet(cache_path)
            data[ticker] = df
        except Exception:
            continue
    return data

# =========================
# Indicators (pure Python)
# =========================
def sma(series: pd.Series, window: int) -> pd.Series:
    return series.rolling(window, min_periods=window).mean()

def ema(series: pd.Series, span: int) -> pd.Series:
    return series.ewm(span=span, adjust=False, min_periods=span).mean()

def rsi(series: pd.Series, length: int = 14) -> pd.Series:
    delta = series.diff()
    gain = (delta.where(delta > 0, 0.0)).rolling(length).mean()
    loss = (-delta.where(delta < 0, 0.0)).rolling(length).mean()
    rs = gain / loss.replace(0.0, np.nan)
    out = 100 - (100 / (1 + rs))
    return out.fillna(50.0)

def macd(series: pd.Series, fast=12, slow=26, signal=9):
    ema_fast = ema(series, fast)
    ema_slow = ema(series, slow)
    line = ema_fast - ema_slow
    sig = ema(line, signal)
    hist = line - sig
    return line, sig, hist

def _true_range(high: pd.Series, low: pd.Series, prev_close: pd.Series) -> pd.Series:
    return pd.concat([
        (high - low).abs(),
        (high - prev_close).abs(),
        (low - prev_close).abs()
    ], axis=1).max(axis=1)

def adx_plus_minus_di(high: pd.Series, low: pd.Series, close: pd.Series, length: int = 14):
    prev_high = high.shift(1)
    prev_low  = low.shift(1)
    prev_close = close.shift(1)

    up_move   = high - prev_high
    down_move = prev_low - low
    plus_dm  = up_move.where((up_move > down_move) & (up_move > 0), 0.0)
    minus_dm = down_move.where((down_move > up_move) & (down_move > 0), 0.0)

    tr = _true_range(high, low, prev_close)
    alpha = 1.0 / length
    atr = tr.ewm(alpha=alpha, adjust=False, min_periods=length).mean()

    plus_di  = 100 * (plus_dm.ewm(alpha=alpha, adjust=False, min_periods=length).mean() / atr)
    minus_di = 100 * (minus_dm.ewm(alpha=alpha, adjust=False, min_periods=length).mean() / atr)

    dx = 100 * (plus_di - minus_di).abs() / (plus_di + minus_di).replace(0, np.nan)
    adx_series = dx.ewm(alpha=alpha, adjust=False, min_periods=length).mean()
    return adx_series, plus_di, minus_di

# =========================
# Candlestick pattern detectors (bullish only)
# =========================
# All functions return a boolean pd.Series aligned to df.index
def _body(o, c): return (c - o).abs()
def _is_bull(o, c): return c > o
def _is_bear(o, c): return c < o

def patt_bull_engulfing(df: pd.DataFrame) -> pd.Series:
    o, h, l, c = df["Open"], df["High"], df["Low"], df["Close"]
    op, cp = o.shift(1), c.shift(1)
    cond = _is_bear(op, cp) & _is_bull(o, c) & (c >= op) & (o <= cp)
    return cond.fillna(False)

def patt_piercing(df: pd.DataFrame) -> pd.Series:
    o, h, l, c = df["Open"], df["High"], df["Low"], df["Close"]
    op, hp, lp, cp = o.shift(1), h.shift(1), l.shift(1), c.shift(1)
    mid_prev = (op + cp) / 2.0
    cond = _is_bear(op, cp) & _is_bull(o, c) \
           & (o < lp) \
           & (c > mid_prev) & (c < op)
    return cond.fillna(False)

def patt_morning_star(df: pd.DataFrame) -> pd.Series:
    # 3-candle: bear -> small -> strong bull closing into first candle body (>50%)
    o, c, h, l = df["Open"], df["Close"], df["High"], df["Low"]
    o1, c1 = o.shift(1), c.shift(1)
    o2, c2 = o.shift(2), c.shift(2)

    bear1 = _is_bear(o2, c2)
    small2 = (_body(o1, c1) <= (_body(o2, c2) * 0.6))  # small-ish
    bull3 = _is_bull(o, c)

    # Close of 3rd candle retraces >50% into candle 1 body
    mid1 = (o2 + c2) / 2.0
    retrace = c > mid1

    cond = bear1 & small2 & bull3 & retrace
    return cond.fillna(False)

def patt_harami_bull(df: pd.DataFrame) -> pd.Series:
    o, c, h, l = df["Open"], df["Close"], df["High"], df["Low"]
    o1, c1 = o.shift(1), c.shift(1)
    # Previous bearish, current small body entirely within previous body
    prev_bear = _is_bear(o1, c1)
    body_small = (_body(o, c) <= _body(o1, c1) * 0.75)
    inside = (h <= o1.clip(upper=h)) & (l >= c1.clip(lower=l))  # h<=prev open and l>=prev close for bearish prev
    # Allow bullish or doji small body
    cond = prev_bear & body_small & inside & (c >= o)  # bullish/neutral close
    return cond.fillna(False)

def patt_harami_cross_bull(df: pd.DataFrame, doji_pct=0.1) -> pd.Series:
    o, c, h, l = df["Open"], df["Close"], df["High"], df["Low"]
    o1, c1 = o.shift(1), c.shift(1)
    rng = (h - l).replace(0, np.nan)
    doji = (_body(o, c) <= (rng * doji_pct))
    prev_bear = _is_bear(o1, c1)
    inside = (h <= o1) & (l >= c1)
    cond = prev_bear & doji & inside
    return cond.fillna(False)

def patt_hammer(df: pd.DataFrame, shadow_mult=2.0) -> pd.Series:
    o, c, h, l = df["Open"], df["Close"], df["High"], df["Low"]
    body = _body(o, c)
    lower_shadow = (o.clip(lower=c) - l).abs() if (o>=c).all() else (np.minimum(o, c) - l).abs()
    upper_shadow = (h - np.maximum(o, c)).abs()
    cond = (lower_shadow >= shadow_mult * body) & (upper_shadow <= body) & (c >= o)  # bullish close
    return cond.fillna(False)

def patt_inverted_hammer(df: pd.DataFrame, shadow_mult=2.0) -> pd.Series:
    o, c, h, l = df["Open"], df["Close"], df["High"], df["Low"]
    body = _body(o, c)
    upper_shadow = (h - np.maximum(o, c)).abs()
    lower_shadow = (np.minimum(o, c) - l).abs()
    cond = (upper_shadow >= shadow_mult * body) & (lower_shadow <= body) & (c >= o)
    return cond.fillna(False)

# Unified bullish pattern set
BULLISH_PATTERNS = [
    "ENGULFING",
    "PIERCING",
    "MORNING_STAR",
    "HARAMI",
    "HARAMI_CROSS",
    "HAMMER",
    "INVERTED_HAMMER",
]

def compute_indicators(df: pd.DataFrame, cfg: Config) -> pd.DataFrame:
    out = df.copy()
    # Trend EMAs
    out["ema_fast"] = ema(out["Close"], cfg.ema_fast)
    out["ema_slow"] = ema(out["Close"], cfg.ema_slow)
    out["ema_htf"]  = ema(out["Close"], cfg.ema_htf)

    # Confirmations
    out["rsi"] = rsi(out["Close"], 14)
    macd_line, macd_sig, macd_hist = macd(out["Close"], 12, 26, 9)
    out["macd_line"] = macd_line
    out["macd_signal"] = macd_sig
    out["macd_hist"] = macd_hist

    out["sma50"] = sma(out["Close"], 50)
    out["bb_mid"] = sma(out["Close"], 20)
    adxv, pdi, ndi = adx_plus_minus_di(out["High"], out["Low"], out["Close"], 14)
    out["adx"] = adxv
    out["+di"] = pdi
    out["-di"] = ndi

    # Liquidity helpers
    out["avg_vol_20"] = out["Volume"].rolling(20).mean()

    # 52w high for ranking filter later
    out["high_52w"] = out["Close"].rolling(252).max()

    # ----- Candlestick pattern masks -----
    patt_map = {
        "ENGULFING":       patt_bull_engulfing(out),
        "PIERCING":        patt_piercing(out),
        "MORNING_STAR":    patt_morning_star(out),
        "HARAMI":          patt_harami_bull(out),
        "HARAMI_CROSS":    patt_harami_cross_bull(out),
        "HAMMER":          patt_hammer(out),
        "INVERTED_HAMMER": patt_inverted_hammer(out),
    }
    # Any bullish pattern today
    patt_any = None
    for name in BULLISH_PATTERNS:
        patt_any = patt_map[name] if patt_any is None else (patt_any | patt_map[name])
    out["bullish_pattern"] = patt_any.fillna(False)

    return out.dropna()

def basic_liquidity_ok(row: pd.Series, cfg: Config) -> bool:
    if not cfg.enable_basic_liquidity:
        return True
    if row["Close"] < cfg.min_price_inr: return False
    if row["avg_vol_20"] < cfg.min_avg_vol_20d: return False
    return True

def simulate_ticker(ticker: str, df: pd.DataFrame, cfg: Config):
    d = compute_indicators(df, cfg).copy()
    # NOTE: added "pattern" so we can carry the exact bullish pattern name to the portfolio stage
    cols = ["ticker","side","date","price","shares","reason","signal_reason","score",
            "pattern","rsi","adx","+di","-di","macd_line","macd_signal",
            "ema_fast","ema_slow","ema_htf","sma50","bb_mid","close","high_52w"]
    if d.empty:
        return pd.DataFrame(columns=cols), pd.Series(dtype=float)

    # --- Entry conditions ---
    trend_ok   = (d["ema_fast"] > d["ema_slow"])
    htf_ok     = (d["Close"] > d["ema_htf"]) if cfg.use_htf_trend else pd.Series(True, index=d.index)

    # Rebuild the same pattern map here to know exactly which pattern fired at dt
    patt_map = {
        "ENGULFING":       patt_bull_engulfing(d),
        "PIERCING":        patt_piercing(d),
        "MORNING_STAR":    patt_morning_star(d),
        "HARAMI":          patt_harami_bull(d),
        "HARAMI_CROSS":    patt_harami_cross_bull(d),
        "HAMMER":          patt_hammer(d),
        "INVERTED_HAMMER": patt_inverted_hammer(d),
    }
    pattern_ok = None
    for nm, ser in patt_map.items():
        pattern_ok = ser if pattern_ok is None else (pattern_ok | ser)
    pattern_ok = pattern_ok.fillna(False)

    # Confirmation: any ONE true
    conf_rsi    = d["rsi"] > 50.0
    conf_macd   = d["macd_line"] > d["macd_signal"]
    conf_adx    = (d["adx"] > 20.0) & (d["+di"] > d["-di"])
    conf_sma50  = d["Close"] > d["sma50"]
    conf_bbmid  = d["Close"] > d["bb_mid"]
    confirmation_any = conf_rsi | conf_macd | conf_adx | conf_sma50 | conf_bbmid

    entry_signal = pattern_ok & trend_ok & htf_ok & confirmation_any
    exit_ind = (d["ema_fast"] < d["ema_slow"])  # trend invalidation

    in_pos = False
    entry_px = stop_px = tgt_px = 0.0
    trades = []

    idx = list(d.index)
    for i in range(len(idx)-1):
        dt, nxt = idx[i], idx[i+1]
        row, nxt_row = d.loc[dt], d.loc[nxt]

        if not in_pos:
            if entry_signal.loc[dt]:
                # Which bullish pattern(s) fired exactly today?
                patterns_detected = [nm for nm, ser in patt_map.items() if bool(ser.loc[dt])]
                patt_str = " + ".join(patterns_detected) if patterns_detected else "BullishPattern"

                # Which confirmations passed?
                confs = []
                if conf_rsi.loc[dt]:    confs.append("RSI>50")
                if conf_macd.loc[dt]:   confs.append("MACD>Signal")
                if conf_adx.loc[dt]:    confs.append("ADX>20 & +DI>-DI")
                if conf_sma50.loc[dt]:  confs.append("Close>SMA50")
                if conf_bbmid.loc[dt]:  confs.append("Close>BBmid")
                sig_reason = ", ".join(confs) if confs else "none"

                px = float(nxt_row["Open"])  # enter next open
                trades.append({
                    "ticker": ticker, "side": "BUY", "date": nxt,
                    "price": px, "shares": 0,
                    # reason is a short tag here; portfolio stage will build a verbose "Entry: ..." string
                    "reason": "candidate",
                    "signal_reason": sig_reason,
                    "score": float(1000.0*((row["ema_fast"]-row["ema_slow"])/row["Close"])) + float(row["adx"]) - float(row["rsi"]),
                    "pattern": patt_str,
                    "rsi": float(row["rsi"]), "adx": float(row["adx"]), "+di": float(row["+di"]), "-di": float(row["-di"]),
                    "macd_line": float(row["macd_line"]), "macd_signal": float(row["macd_signal"]),
                    "ema_fast": float(row["ema_fast"]), "ema_slow": float(row["ema_slow"]), "ema_htf": float(row["ema_htf"]),
                    "sma50": float(row["sma50"]), "bb_mid": float(row["bb_mid"]),
                    "close": float(row["Close"]), "high_52w": float(row["high_52w"])
                })
                in_pos = True
                entry_px = px
                stop_px = entry_px * (1 - cfg.stop_loss_pct)
                tgt_px  = entry_px * (1 + cfg.target_pct)

        else:
            hit = None
            exec_date = nxt
            exit_detail = ""
            if nxt_row["Low"] <= stop_px and nxt_row["High"] >= tgt_px:
                hit = "target"
                exec_price = float(tgt_px)
                exit_detail = f"TakeProfit hit: High {float(nxt_row['High']):.2f} ≥ TP {tgt_px:.2f} (from entry {entry_px:.2f})"
            elif nxt_row["Low"] <= stop_px:
                hit = "stop"
                exec_price = float(stop_px)
                exit_detail = f"StopLoss hit: Low {float(nxt_row['Low']):.2f} ≤ SL {stop_px:.2f} (from entry {entry_px:.2f})"
            elif nxt_row["High"] >= tgt_px:
                hit = "target"
                exec_price = float(tgt_px)
                exit_detail = f"TakeProfit hit: High {float(nxt_row['High']):.2f} ≥ TP {tgt_px:.2f} (from entry {entry_px:.2f})"
            elif exit_ind.loc[dt]:
                hit = "indicator_exit"
                exec_price = float(nxt_row["Open"])
                exit_detail = f"Trend invalidation: EMA{cfg.ema_fast}<EMA{cfg.ema_slow} at close {float(row['Close']):.2f}"

            if hit is not None:
                trades.append({
                    "ticker": ticker, "side": "SELL", "date": exec_date,
                    "price": float(exec_price), "shares": 0,
                    "reason": hit,                  # 'stop' | 'target' | 'indicator_exit'
                    "signal_reason": exit_detail,   # human-readable explanation
                    "score": np.nan,
                    "pattern": "",                  # not applicable on exit
                    "rsi": float(row["rsi"]), "adx": float(row["adx"]), "+di": float(row["+di"]), "-di": float(row["-di"]),
                    "macd_line": float(row["macd_line"]), "macd_signal": float(row["macd_signal"]),
                    "ema_fast": float(row["ema_fast"]), "ema_slow": float(row["ema_slow"]), "ema_htf": float(row["ema_htf"]),
                    "sma50": float(row["sma50"]), "bb_mid": float(row["bb_mid"]),
                    "close": float(row["Close"]), "high_52w": float(row["high_52w"])
                })
                in_pos = False
                entry_px = stop_px = tgt_px = 0.0

    if in_pos:
        last_dt = d.index[-1]; row = d.loc[last_dt]
        trades.append({
            "ticker": ticker, "side": "SELL", "date": last_dt,
            "price": float(row["Close"]), "shares": 0,
            "reason": "final_close",
            "signal_reason": "Final close: end of data",
            "score": np.nan,
            "pattern": "",
            "rsi": float(row["rsi"]), "adx": float(row["adx"]), "+di": float(row["+di"]), "-di": float(row["-di"]),
            "macd_line": float(row["macd_line"]), "macd_signal": float(row["macd_signal"]),
            "ema_fast": float(row["ema_fast"]), "ema_slow": float(row["ema_slow"]), "ema_htf": float(row["ema_htf"]),
            "sma50": float(row["sma50"]), "bb_mid": float(row["bb_mid"]),
            "close": float(row["Close"]), "high_52w": float(row["high_52w"])
        })

    return pd.DataFrame(trades, columns=cols), pd.Series(dtype=float)


# =========================
# Ranking, portfolio, metrics (unchanged core)
# =========================
def pick_benchmark(benchmarks: Tuple[str,...], start: str, end: Optional[str], cache_dir: str) -> Tuple[str, pd.DataFrame]:
    for t in benchmarks:
        data = fetch_prices([t], start, end, cache_dir)
        df = data.get(t)
        if df is not None and not df.empty:
            log.info("Using benchmark: %s", t)
            return t, df
    idx = pd.date_range(start=start, end=end or today_str(), freq="B")
    df = pd.DataFrame({"Close": np.ones(len(idx))}, index=idx)
    log.warning("No benchmark found; using synthetic flat series.")
    return "SYNTH_BENCH", df

def compute_volar_scores(end_dt: pd.Timestamp, tickers: List[str], data_map: Dict[str,pd.DataFrame], bench_df: pd.DataFrame, lookback: int) -> Dict[str, float]:
    scores = {}
    bser = bench_df["Close"].loc[:end_dt].pct_change().dropna().iloc[-lookback:]
    for t in tickers:
        df = data_map.get(t)
        if df is None or df.empty:
            scores[t] = 0.0; continue
        if end_dt not in df.index:
            df = df[df.index <= end_dt]
            if df.empty:
                scores[t] = 0.0; continue
        r = df["Close"].loc[:end_dt].pct_change().dropna().iloc[-lookback:]
        common = pd.concat([r, bser], axis=1, keys=["s","b"]).dropna()
        if common.shape[0] < max(20, int(0.4*lookback)):
            scores[t] = 0.0; continue
        excess = common["s"] - common["b"]
        vol = common["s"].std(ddof=0)
        scores[t] = 0.0 if vol <= 1e-8 else float((excess.mean() / vol) * math.sqrt(252.0))
    return scores

def markowitz_long_only(mu: np.ndarray, Sigma: np.ndarray) -> np.ndarray:
    n = len(mu); eps = 1e-6
    Sigma = Sigma + eps*np.eye(n)

    def solve_lambda(lmbd: float, active_mask=None):
        if active_mask is None:
            A = np.block([[2*lmbd*Sigma, np.ones((n,1))],[np.ones((1,n)), np.zeros((1,1))]])
            b = np.concatenate([mu, np.array([1.0])])
            try: w = np.linalg.solve(A, b)[:n]
            except np.linalg.LinAlgError: w = np.full(n, 1.0/n)
            return w
        else:
            idx = np.where(active_mask)[0]
            if len(idx)==0: return np.full(n, 1.0/n)
            S = Sigma[np.ix_(idx, idx)]
            o = np.ones(len(idx)); m = mu[idx]
            A = np.block([[2*lmbd*S, o[:,None]],[o[None,:], np.zeros((1,1))]])
            b = np.concatenate([m, np.array([1.0])])
            try: w_sub = np.linalg.solve(A, b)[:len(idx)]
            except np.linalg.LinAlgError: w_sub = np.full(len(idx), 1.0/len(idx))
            w = np.zeros(n); w[idx] = w_sub; return w

    best_w = np.full(n, 1.0/n); best_sr = -1e9
    for lmbd in np.logspace(-3, 3, 31):
        active = np.ones(n, dtype=bool); w = None
        for _ in range(n):
            w = solve_lambda(lmbd, active_mask=active)
            if not (w < 0).any(): break
            active[np.argmin(w)] = False
        if w is None: continue
        w = np.clip(w, 0, None); 
        if w.sum() <= 0: continue
        w = w / w.sum()
        mu_p = float(mu @ w); vol_p = float(np.sqrt(w @ Sigma @ w))
        if vol_p <= 1e-8: continue
        sr = mu_p / vol_p
        if sr > best_sr: best_sr, best_w = sr, w.copy()
    return best_w

def aggregate_and_apply(all_trades: pd.DataFrame, data_map: Dict[str, pd.DataFrame], bench_df: pd.DataFrame, cfg: Config):
    if all_trades.empty:
        return all_trades, pd.Series(dtype=float), {}

    side_order = {"BUY": 0, "SELL": 1}
    all_trades = (all_trades
        .assign(_sorder=all_trades["side"].map(side_order))
        .sort_values(by=["date", "_sorder"], kind="stable")
        .drop(columns=["_sorder"])
        .reset_index(drop=True)
    )
    all_trades["date"] = pd.to_datetime(all_trades["date"])

    equity_curve = []
    dates = sorted(all_trades["date"].unique().tolist())
    cash = cfg.initial_capital
    open_positions = {}
    completed_legs = []

    global APPLY_FEES
    APPLY_FEES = cfg.apply_fees

    def _get_close_on(tkr, dt):
        df = data_map.get(tkr)
        if df is None or df.empty:
            return np.nan
        if dt in df.index:
            return float(df.loc[dt, "Close"])
        prev = df[df.index <= dt]
        if prev.empty:
            return np.nan
        return float(prev["Close"].iloc[-1])

    if dates:
        seed_date = pd.to_datetime(dates[0]) - pd.Timedelta(days=1)
        equity_curve.append((seed_date, float(cash)))

    for dt in dates:
        day_trades = all_trades[all_trades["date"] == dt].copy()

        # ---- SELL first (with readable exit reason) ----
        for _, tr in day_trades[day_trades["side"] == "SELL"].iterrows():
            tkr = tr["ticker"]
            price = float(tr["price"])
            pos = open_positions.get(tkr)
            if pos is None:
                continue
            shares = int(pos["shares"])
            turnover_sell = shares * price
            fee = calc_fees(0.0, turnover_sell)
            pnl = (price - pos["entry_px"]) * shares
            cash += (turnover_sell - fee)
            realized = pnl - fee - pos.get("buy_fee", 0.0)

            # Make the exit reason human-readable
            base = str(tr.get("reason", "")).lower()
            detail = str(tr.get("signal_reason", "")).strip()
            if base == "stop":
                exit_text = f"Exit: StopLoss hit — {detail}" if detail else "Exit: StopLoss hit"
            elif base == "target":
                exit_text = f"Exit: TakeProfit hit — {detail}" if detail else "Exit: TakeProfit hit"
            elif base == "indicator_exit":
                exit_text = f"Exit: Trend invalidation — {detail}" if detail else "Exit: Trend invalidation (EMA fast<slow)"
            elif base == "final_close":
                exit_text = "Exit: Final close — end of data"
            else:
                exit_text = f"Exit: {tr.get('reason','')}"

            completed_legs.append({
                "ticker": tkr, "side": "SELL", "date": dt, "price": price,
                "shares": shares, "reason": exit_text,
                "turnover": turnover_sell, "fees_inr": fee, "pnl_inr": realized,
                "rsi": tr.get("rsi", np.nan), "adx": tr.get("adx", np.nan),
                "+di": tr.get("+di", np.nan), "-di": tr.get("-di", np.nan),
                "macd_line": tr.get("macd_line", np.nan), "macd_signal": tr.get("macd_signal", np.nan),
                "ema_fast": tr.get("ema_fast", np.nan), "ema_slow": tr.get("ema_slow", np.nan), "ema_htf": tr.get("ema_htf", np.nan),
                "sma50": tr.get("sma50", np.nan), "bb_mid": tr.get("bb_mid", np.nan),
                "close": tr.get("close", np.nan), "high_52w": tr.get("high_52w", np.nan),
                "volar": tr.get("volar", np.nan), "mvo_weight": np.nan, "alloc_inr": np.nan
            })
            log.info("Exit %-12s px=%8.2f shares=%6d :: %s | net=%.2f cash=%.2f",
                     tkr, price, shares, exit_text, realized, cash)
            del open_positions[tkr]

        # ---- BUY candidates today ----
        buys_today = day_trades[day_trades["side"] == "BUY"].copy()
        # 52w filter
        if not buys_today.empty:
            keep = []
            for _, rr in buys_today.iterrows():
                df = data_map.get(rr["ticker"])
                if df is None or df.empty or dt not in df.index:
                    continue
                close = float(df.loc[dt, "Close"])
                hist = df["Close"].loc[:dt]
                window = hist.iloc[-cfg.filter_52w_window:] if len(hist)>=cfg.filter_52w_window else hist
                high_52w = float(window.max())
                if high_52w>0 and close >= cfg.within_pct_of_52w_high * high_52w:
                    keep.append(rr)
            buys_today = pd.DataFrame(keep) if keep else pd.DataFrame(columns=buys_today.columns)

        # Exclude already-held tickers
        if not buys_today.empty:
            buys_today = buys_today[~buys_today["ticker"].isin(open_positions.keys())]

        # VOLAR ranking
        if not buys_today.empty:
            tickers = buys_today["ticker"].tolist()
            volar_scores = compute_volar_scores(dt, tickers, data_map, bench_df, cfg.volar_lookback)
            buys_today["volar"] = buys_today["ticker"].map(volar_scores)
            buys_today = buys_today.sort_values("volar", ascending=False).reset_index(drop=True)

        slots = cfg.max_concurrent_positions - len(open_positions)
        selected = pd.DataFrame(columns=buys_today.columns)
        if slots > 0 and not buys_today.empty:
            selected = buys_today.head(min(cfg.top_k_daily, slots)).copy()

        if not selected.empty:
            log.info("Selected %d BUY candidates on %s:", selected.shape[0], dt.date())
            for i, rr in selected.reset_index(drop=True).iterrows():
                log.info("  %-12s volar=%6.2f rank=%d px=%8.2f", rr["ticker"], rr.get("volar",0.0), i+1, rr["price"])

            # MVO sizing
            names = selected["ticker"].tolist()
            rets = []
            for t in names:
                df = data_map.get(t)
                ser = df["Close"].loc[:dt].pct_change().dropna().iloc[-cfg.volar_lookback:]
                rets.append(ser)
            R = pd.concat(rets, axis=1); R.columns = names; R = R.dropna()
            if R.empty or R.shape[0] < max(20, int(0.4*cfg.volar_lookback)) or R.shape[1] == 0:
                weights = np.full(len(names), 1.0/len(names))
            else:
                mu = R.mean().values; Sigma = R.cov().values
                weights = markowitz_long_only(mu, Sigma)

            deploy_cash = max(0.0, float(cash)) * float(cfg.deploy_cash_frac)
            if deploy_cash <= 0:
                log.info("No deployable cash (cap=%.0f%%) on %s", 100*cfg.deploy_cash_frac, dt.date())
            else:
                alloc = (weights / weights.sum()) * deploy_cash if weights.sum()>0 else np.full(len(names), deploy_cash/len(names))
                rank_map = {row["ticker"]: (idx+1) for idx, (_, row) in enumerate(selected.iterrows())}
                for w_amt, t in zip(alloc, names):
                    df_t = data_map[t]
                    price = float(df_t.loc[dt, "Close"] if dt in df_t.index else df_t["Close"].loc[:dt].iloc[-1])
                    shares = int(math.floor(w_amt / price))
                    if shares <= 0:
                        log.info("Skip BUY %-12s (alloc %.2f too small)", t, w_amt); continue
                    turn = shares * price
                    fee = calc_fees(turn, 0.0)
                    total_cost = turn + fee
                    if total_cost > cash:
                        shares = int(math.floor((cash - fee) / price))
                        if shares <= 0:
                            log.info("Skip BUY %-12s due to cash/fees", t); continue
                        turn = shares * price; total_cost = turn + fee
                    cash -= total_cost
                    open_positions[t] = {"entry_date": dt, "entry_px": price, "shares": shares, "buy_fee": fee, "entry_reason": "entry"}

                    row_sel = selected[selected["ticker"]==t].iloc[0]
                    patt_str = str(row_sel.get("pattern","BullishPattern"))
                    sigs = str(row_sel.get("signal_reason","")).strip()
                    sigs_fmt = f"[{sigs}]" if sigs else "[none]"
                    volar_val = float(row_sel.get("volar", np.nan))
                    rank_pos = rank_map.get(t, np.nan)
                    high_52w = float(row_sel.get("high_52w", np.nan))
                    close_val = float(row_sel.get("close", np.nan))
                    pct_52w = (close_val / high_52w) if (high_52w and high_52w>0) else np.nan
                    mvo_weight_today = (w_amt / deploy_cash) if deploy_cash > 0 else 0.0

                    # *** READABLE ENTRY REASON ***
                    reason_text = (
                        f"Entry: {patt_str} + EMA{cfg.ema_fast}>EMA{cfg.ema_slow} + Close>EMA{cfg.ema_htf}; "
                        f"Conf={sigs_fmt}; 52w%={pct_52w:.1%} (≥ {cfg.within_pct_of_52w_high:.0%}); "
                        f"VOLAR rank {int(rank_pos)}/{len(names)} (VOLAR={volar_val:.2f}); "
                        f"MVO weight={mvo_weight_today:.1%} of capped cash"
                    )

                    completed_legs.append({
                        "ticker": t, "side": "BUY", "date": dt, "price": price,
                        "shares": shares, "reason": reason_text,
                        "turnover": turn, "fees_inr": fee, "pnl_inr": 0.0,
                        "rsi": float(row_sel.get("rsi", np.nan)), "adx": float(row_sel.get("adx", np.nan)),
                        "+di": float(row_sel.get("+di", np.nan)), "-di": float(row_sel.get("-di", np.nan)),
                        "macd_line": float(row_sel.get("macd_line", np.nan)), "macd_signal": float(row_sel.get("macd_signal", np.nan)),
                        "ema_fast": float(row_sel.get("ema_fast", np.nan)), "ema_slow": float(row_sel.get("ema_slow", np.nan)), "ema_htf": float(row_sel.get("ema_htf", np.nan)),
                        "sma50": float(row_sel.get("sma50", np.nan)), "bb_mid": float(row_sel.get("bb_mid", np.nan)),
                        "close": close_val, "high_52w": high_52w,
                        "volar": volar_val, "mvo_weight": float(mvo_weight_today), "alloc_inr": float(w_amt)
                    })
                    log.info("BUY %-12s px=%8.2f sh=%6d fee=%.2f cash=%.2f :: %s",
                             t, price, shares, fee, cash, reason_text)

        # MTM valuation
        mtm = 0.0
        for _tkr, pos in open_positions.items():
            px = _get_close_on(_tkr, dt)
            if not np.isnan(px):
                mtm += pos["shares"] * px
        total_equity = cash + mtm
        equity_curve.append((dt, float(total_equity)))

    eq_ser = pd.Series([e for _, e in equity_curve], index=[d for d, _ in equity_curve])
    legs_df = pd.DataFrame(completed_legs).sort_values(["date", "ticker", "side"]).reset_index(drop=True)

    # Roundtrips (these already carry the improved BUY/SELL "reason")
    roundtrips = []
    by_tkr_open = {}
    for _, leg in legs_df.iterrows():
        tkr = leg["ticker"]
        if leg["side"] == "BUY":
            by_tkr_open[tkr] = leg
        else:
            buy = by_tkr_open.pop(tkr, None)
            if buy is None:
                continue
            fees_total = float(buy.get("fees_inr", 0.0) + leg.get("fees_inr", 0.0))
            gross_pnl = (leg["price"] - buy["price"]) * buy["shares"]
            net_pnl   = gross_pnl - fees_total
            ret_pct   = (leg["price"] / buy["price"] - 1.0) * 100.0
            days_held = (pd.to_datetime(leg["date"]) - pd.to_datetime(buy["date"])).days
            roundtrips.append({
                "ticker": tkr,
                "entry_date": pd.to_datetime(buy["date"]),
                "entry_price": float(buy["price"]),
                "exit_date": pd.to_datetime(leg["date"]),
                "exit_price": float(leg["price"]),
                "days_held": int(days_held),
                "shares": int(buy["shares"]),
                "entry_reason": buy.get("reason",""),
                "exit_reason": leg.get("reason",""),
                "gross_pnl_inr": float(gross_pnl),
                "fees_total_inr": float(fees_total),
                "net_pnl_inr": float(net_pnl),
                "return_pct": float(ret_pct),
                # carry some entry context
                "rsi_entry": float(buy.get("rsi", np.nan)),
                "adx_entry": float(buy.get("adx", np.nan)),
                "ema_fast_entry": float(buy.get("ema_fast", np.nan)),
                "ema_slow_entry": float(buy.get("ema_slow", np.nan)),
                "ema_htf_entry": float(buy.get("ema_htf", np.nan)),
                "sma50_entry": float(buy.get("sma50", np.nan)),
                "bb_mid_entry": float(buy.get("bb_mid", np.nan)),
                "volar_entry": float(buy.get("volar", np.nan)),
                "mvo_weight_entry": float(buy.get("mvo_weight", np.nan)),
                "alloc_inr_entry": float(buy.get("alloc_inr", np.nan))
            })
    trips_df = pd.DataFrame(roundtrips).sort_values(["entry_date","ticker"]).reset_index(drop=True)

    metrics = compute_metrics(eq_ser, legs_df)
    return legs_df, trips_df, eq_ser, metrics


def compute_metrics(equity: pd.Series, legs_df: pd.DataFrame):
    out = {}
    if equity is None or equity.empty: return out
    eq = equity.dropna()
    daily_ret = eq.pct_change().fillna(0.0)

    days = (eq.index[-1] - eq.index[0]).days or 1
    years = days / 365.25
    cagr = (eq.iloc[-1] / eq.iloc[0]) ** (1/years) - 1 if years > 0 else 0.0

    sharpe = (daily_ret.mean() / daily_ret.std(ddof=0) * np.sqrt(252)) if daily_ret.std(ddof=0) > 0 else 0.0

    cummax = eq.cummax()
    dd = (eq - cummax) / cummax
    max_dd = dd.min()

    wins = 0
    n_sells = legs_df[legs_df["side"] == "SELL"].shape[0] if legs_df is not None and not legs_df.empty else 0
    for _, r in legs_df[legs_df["side"] == "SELL"].iterrows():
        if float(r.get("pnl_inr", 0.0)) > 0: wins += 1
    win_rate = (wins / n_sells) * 100.0 if n_sells > 0 else 0.0

    out.update({
        "start_equity_inr": float(eq.iloc[0]),
        "final_equity_inr": float(eq.iloc[-1]),
        "cagr_pct": float(cagr * 100),
        "sharpe": float(sharpe),
        "max_drawdown_pct": float(max_dd * 100),
        "win_rate_pct": float(win_rate),
        "n_trades": int(n_sells),
    })
    return out

def plot_equity(equity: pd.Series, out_path: str):
    if equity is None or equity.empty: return
    try:
        import matplotlib.pyplot as plt
        plt.figure(figsize=(10,5))
        plt.plot(equity.index, equity.values)
        plt.title("Equity Curve")
        plt.xlabel("Date"); plt.ylabel("Equity (INR)")
        plt.tight_layout(); plt.savefig(out_path); plt.close()
    except Exception:
        pass

def backtest(cfg: Config):
    ensure_dirs(cfg.cache_dir, cfg.out_dir)
    log.info("Universe: loading static symbols...")
    symbols = load_static_symbols(cfg.static_symbols, cfg.static_symbols_path)
    log.info("Loaded %d symbols.", len(symbols))

    log.info("Data: fetching OHLCV from yfinance (adjusted)...")
    data_map = fetch_prices(symbols, cfg.start_date, cfg.end_date, cfg.cache_dir)
    log.info("Downloaded %d symbols with data.", len(data_map))

    bench_tkr, bench_df = pick_benchmark(cfg.benchmark_try, cfg.start_date, cfg.end_date, cfg.cache_dir)
    log.info("Benchmark selected: %s", bench_tkr)

    log.info("Signals: scanning bullish candlesticks + confirmations + trend filters...")
    all_trades = []
    for i, tkr in enumerate(symbols, 1):
        df = data_map.get(tkr)
        if df is None or df.empty: continue
        tr, _ = simulate_ticker(tkr, df, cfg)
        if not tr.empty: all_trades.append(tr)
        if i % 50 == 0:
            log.info("  processed %d/%d tickers...", i, len(symbols))

    if not all_trades:
        log.warning("No signals generated; check your thresholds or timeframe.")
        return None, None, None, {}
    all_trades = pd.concat(all_trades, ignore_index=True)

    log.info("Portfolio: cap daily deploy to %.0f%% cash; 52w>=%.0f%% high; top-%d by VOLAᵣ; MVO; max %d positions.",
             cfg.deploy_cash_frac*100, cfg.within_pct_of_52w_high*100, cfg.top_k_daily, cfg.max_concurrent_positions)
    legs_df, trips_df, equity, metrics = aggregate_and_apply(all_trades, data_map, bench_df, cfg)

    stamp = pd.Timestamp.today(tz="Asia/Kolkata").strftime("%Y%m%d_%H%M%S")
    legs_path = os.path.join(cfg.out_dir, f"trades_legs_{stamp}.csv")
    trips_path = os.path.join(cfg.out_dir, f"trades_roundtrips_{stamp}.csv")
    equity_path = os.path.join(cfg.out_dir, f"equity_{stamp}.csv")
    metrics_path = os.path.join(cfg.out_dir, f"metrics_{stamp}.json")
    eq_plot_path = os.path.join(cfg.out_dir, f"equity_{stamp}.png")

    if legs_df is not None: legs_df.to_csv(legs_path, index=False)
    if trips_df is not None: trips_df.to_csv(trips_path, index=False)
    if equity is not None: pd.DataFrame({"date": equity.index, "equity": equity.values}).to_csv(equity_path, index=False)
    with open(metrics_path, "w") as f: json.dump(metrics, f, indent=2)
    if cfg.plot and equity is not None: plot_equity(equity, eq_plot_path)

    log.info("=== METRICS ===\n%s", json.dumps(metrics, indent=2))
    log.info("Files written:\n  %s\n  %s\n  %s\n  %s", legs_path, trips_path, equity_path, metrics_path)
    if cfg.plot: log.info("  %s", eq_plot_path)

def main():
    global APPLY_FEES
    APPLY_FEES = bool(CFG.apply_fees)

    # Example universe (yours). You can switch to a file via CFG.static_symbols_path.
    CFG.static_symbols = ['360ONE.NS','3MINDIA.NS','AARTIIND.NS','ABB.NS','ACC.NS','ADANIENT.NS','ADANIPORTS.NS','APOLLOHOSP.NS','ASIANPAINT.NS','AXISBANK.NS','BAJAJ-AUTO.NS','BAJFINANCE.NS','BHARTIARTL.NS','BPCL.NS','BRITANNIA.NS','CIPLA.NS','COALINDIA.NS','COFORGE.NS','DRREDDY.NS','EICHERMOT.NS','GRASIM.NS','HCLTECH.NS','HDFCBANK.NS','HINDALCO.NS','HINDUNILVR.NS','ICICIBANK.NS','INFY.NS','ITC.NS','JSWSTEEL.NS','KOTAKBANK.NS','LT.NS','MARUTI.NS','NESTLEIND.NS','NTPC.NS','ONGC.NS','POWERGRID.NS','RELIANCE.NS','SBIN.NS','SUNPHARMA.NS','TATAMOTORS.NS','TATASTEEL.NS','TCS.NS','TECHM.NS','TITAN.NS','ULTRACEMCO.NS','WIPRO.NS']
    # Or: CFG.static_symbols_path = "nifty500.txt"

    backtest(CFG)

if __name__ == "__main__":
    main()
# Out:
# 2025-10-08 20:25:20 | INFO | Universe: loading static symbols...
# 2025-10-08 20:25:20 | INFO | Loaded 46 symbols.
# 2025-10-08 20:25:20 | INFO | Data: fetching OHLCV from yfinance (adjusted)...
# 2025-10-08 20:25:21 | INFO | Downloaded 46 symbols with data.
# 2025-10-08 20:25:22 | ERROR | HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: ^CNX500"}}}
# 2025-10-08 20:25:22 | ERROR |
# 1 Failed download:
# 2025-10-08 20:25:22 | ERROR | ['^CNX500']: YFTzMissingError('possibly delisted; no timezone found')
# 2025-10-08 20:25:22 | INFO | Using benchmark: ^CRSLDX
# 2025-10-08 20:25:22 | INFO | Benchmark selected: ^CRSLDX
# 2025-10-08 20:25:22 | INFO | Signals: scanning bullish candlesticks + confirmations + trend filters...
# 2025-10-08 20:25:27 | INFO | Portfolio: cap daily deploy to 25% cash; 52w>=50% high; top-300 by VOLAᵣ; MVO; max 5 positions.
# 2025-10-08 20:25:27 | INFO | Selected 1 BUY candidates on 2016-01-11:
# 2025-10-08 20:25:27 | INFO |   KOTAKBANK.NS volar=  0.67 rank=1 px=  685.54
# 2025-10-08 20:25:27 | INFO | BUY KOTAKBANK.NS px=  696.32 sh=   179 fee=171.60 cash=375187.75 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[ADX>20 & +DI>-DI, Close>SMA50]; 52w%=93.8% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.67); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:27 | INFO | Selected 1 BUY candidates on 2016-01-12:
# 2025-10-08 20:25:27 | INFO |   AARTIIND.NS  volar=  2.07 rank=1 px=  119.93
# 2025-10-08 20:25:27 | INFO | BUY AARTIIND.NS  px=  120.16 sh=   780 fee=134.89 cash=281331.22 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, Close>SMA50]; 52w%=90.2% (≥ 50%); VOLAR rank 1/1 (VOLAR=2.07); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:27 | INFO | Exit AARTIIND.NS  px=  113.94 shares=   780 :: Exit: StopLoss hit — StopLoss hit: Low 113.87 ≤ SL 113.94 (from entry 119.93) | net=-5124.62 cash=370063.13
# 2025-10-08 20:25:27 | INFO | Exit KOTAKBANK.NS px=  675.01 shares=   179 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 679.67 | net=-4158.85 cash=490716.53
# 2025-10-08 20:25:27 | INFO | Selected 1 BUY candidates on 2016-01-15:
# 2025-10-08 20:25:27 | INFO |   ASIANPAINT.NS volar=  0.78 rank=1 px=  824.59
# 2025-10-08 20:25:27 | INFO | BUY ASIANPAINT.NS px=  811.90 sh=   151 fee=169.17 cash=367951.09 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, Close>SMA50, Close>BBmid]; 52w%=96.6% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.78); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:27 | INFO | Exit ASIANPAINT.NS px=  783.36 shares=   151 :: Exit: StopLoss hit — StopLoss hit: Low 777.18 ≤ SL 783.36 (from entry 824.59) | net=-4647.56 cash=486068.97
# 2025-10-08 20:25:27 | INFO | Selected 1 BUY candidates on 2016-01-25:
# 2025-10-08 20:25:27 | INFO |   RELIANCE.NS  volar=  1.04 rank=1 px=  218.85
# 2025-10-08 20:25:27 | INFO | BUY RELIANCE.NS  px=  217.54 sh=   558 fee=167.74 cash=364514.00 :: Entry: HARAMI + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, Close>SMA50]; 52w%=93.2% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.04); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:27 | INFO | Exit RELIANCE.NS  px=  216.90 shares=   558 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 216.54 | net=-697.18 cash=485371.79
# 2025-10-08 20:25:27 | INFO | Selected 1 BUY candidates on 2016-02-01:
# 2025-10-08 20:25:27 | INFO |   APOLLOHOSP.NS volar=  1.07 rank=1 px= 1433.31
# 2025-10-08 20:25:27 | INFO | BUY APOLLOHOSP.NS px= 1449.17 sh=    83 fee=166.42 cash=364924.48 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=98.3% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.07); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:27 | INFO | Selected 1 BUY candidates on 2016-02-02:
# 2025-10-08 20:25:27 | INFO |   JSWSTEEL.NS  volar=  0.57 rank=1 px=   94.47
# 2025-10-08 20:25:27 | INFO | BUY JSWSTEEL.NS  px=   90.10 sh=  1012 fee=131.87 cash=273614.85 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=93.7% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.57); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:27 | INFO | Exit JSWSTEEL.NS  px=   89.75 shares=  1012 :: Exit: StopLoss hit — StopLoss hit: Low 86.06 ≤ SL 89.75 (from entry 94.47) | net=-623.40 cash=364301.08
# 2025-10-08 20:25:27 | INFO | Selected 1 BUY candidates on 2016-02-04:
# 2025-10-08 20:25:27 | INFO |   BAJFINANCE.NS volar=  1.92 rank=1 px=   62.05
# 2025-10-08 20:25:27 | INFO | BUY BAJFINANCE.NS px=   61.40 sh=  1483 fee=131.73 cash=273106.04 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.92); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:27 | INFO | Selected 1 BUY candidates on 2016-02-08:
# 2025-10-08 20:25:27 | INFO |   EICHERMOT.NS volar=  0.88 rank=1 px= 1703.22
# 2025-10-08 20:25:27 | INFO | BUY EICHERMOT.NS px= 1704.22 sh=    40 fee=104.54 cash=204832.87 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=84.9% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.88); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:27 | INFO | Exit BAJFINANCE.NS px=   58.95 shares=  1483 :: Exit: StopLoss hit — StopLoss hit: Low 58.67 ≤ SL 58.95 (from entry 62.05) | net=-3907.76 cash=292120.15
# 2025-10-08 20:25:27 | INFO | Selected 1 BUY candidates on 2016-02-11:
# 2025-10-08 20:25:27 | INFO |   TITAN.NS     volar=  0.13 rank=1 px=  354.74
# 2025-10-08 20:25:27 | INFO | BUY TITAN.NS     px=  342.58 sh=   213 fee=110.24 cash=219041.39 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=85.6% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.13); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:27 | INFO | Exit APOLLOHOSP.NS px= 1361.64 shares=    83 :: Exit: StopLoss hit — StopLoss hit: Low 1295.97 ≤ SL 1361.64 (from entry 1433.31) | net=-7595.56 cash=331893.14
# 2025-10-08 20:25:27 | INFO | Exit EICHERMOT.NS px= 1618.06 shares=    40 :: Exit: StopLoss hit — StopLoss hit: Low 1612.73 ≤ SL 1618.06 (from entry 1703.22) | net=-3665.18 cash=396501.13
# 2025-10-08 20:25:27 | INFO | Exit TITAN.NS     px=  337.00 shares=   213 :: Exit: StopLoss hit — StopLoss hit: Low 327.91 ≤ SL 337.00 (from entry 354.74) | net=-1419.56 cash=468160.33
# 2025-10-08 20:25:27 | INFO | Selected 1 BUY candidates on 2016-02-18:
# 2025-10-08 20:25:27 | INFO |   BAJFINANCE.NS volar=  1.91 rank=1 px=   59.62
# 2025-10-08 20:25:27 | INFO | BUY BAJFINANCE.NS px=   59.66 sh=  1961 fee=162.53 cash=350998.66 :: Entry: HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, Close>SMA50, Close>BBmid]; 52w%=91.2% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.91); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:27 | INFO | Exit BAJFINANCE.NS px=   56.64 shares=  1961 :: Exit: StopLoss hit — StopLoss hit: Low 56.64 ≤ SL 56.64 (from entry 59.62) | net=-6246.14 cash=461914.19
# 2025-10-08 20:25:27 | INFO | Selected 2 BUY candidates on 2016-02-22:
# 2025-10-08 20:25:27 | INFO |   JSWSTEEL.NS  volar=  0.97 rank=1 px=   97.80
# 2025-10-08 20:25:27 | INFO |   ULTRACEMCO.NS volar=  0.55 rank=2 px= 2734.53
# 2025-10-08 20:25:27 | INFO | BUY JSWSTEEL.NS  px=   99.02 sh=  1166 fee=160.70 cash=346292.97 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=96.6% (≥ 50%); VOLAR rank 1/2 (VOLAR=0.97); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:27 | INFO | Skip BUY ULTRACEMCO.NS (alloc 0.00 too small)
# 2025-10-08 20:25:27 | INFO | Selected 3 BUY candidates on 2016-02-23:
# 2025-10-08 20:25:27 | INFO |   3MINDIA.NS   volar=  1.66 rank=1 px=10261.62
# 2025-10-08 20:25:27 | INFO |   EICHERMOT.NS volar=  1.11 rank=2 px= 1770.61
# 2025-10-08 20:25:27 | INFO |   HINDUNILVR.NS volar=  0.65 rank=3 px=  736.00
# 2025-10-08 20:25:27 | INFO | BUY 3MINDIA.NS   px= 9959.18 sh=     7 fee=106.38 cash=276472.30 :: Entry: ENGULFING + INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=88.2% (≥ 50%); VOLAR rank 1/3 (VOLAR=1.66); MVO weight=85.5% of capped cash
# 2025-10-08 20:25:27 | INFO | BUY EICHERMOT.NS px= 1761.60 sh=     7 fee=29.19 cash=264111.91 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=88.6% (≥ 50%); VOLAR rank 2/3 (VOLAR=1.11); MVO weight=14.5% of capped cash
# 2025-10-08 20:25:27 | INFO | Skip BUY HINDUNILVR.NS (alloc 0.00 too small)
# 2025-10-08 20:25:27 | INFO | Exit 3MINDIA.NS   px= 9748.54 shares=     7 :: Exit: StopLoss hit — StopLoss hit: Low 9485.21 ≤ SL 9748.54 (from entry 10261.62) | net=-1698.88 cash=332233.69
# 2025-10-08 20:25:27 | INFO | Selected 1 BUY candidates on 2016-03-02:
# 2025-10-08 20:25:27 | INFO |   3MINDIA.NS   volar=  1.32 rank=1 px=10103.83
# 2025-10-08 20:25:27 | INFO | BUY 3MINDIA.NS   px= 9992.26 sh=     8 fee=118.52 cash=252177.12 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=88.3% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.32); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:27 | INFO | Selected 1 BUY candidates on 2016-03-03:
# 2025-10-08 20:25:27 | INFO |   BRITANNIA.NS volar=  1.62 rank=1 px= 1257.18
# 2025-10-08 20:25:27 | INFO | BUY BRITANNIA.NS px= 1241.39 sh=    50 fee=97.30 cash=190010.30 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=84.2% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.62); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:27 | INFO | Selected 1 BUY candidates on 2016-03-04:
# 2025-10-08 20:25:27 | INFO |   ASIANPAINT.NS volar=  0.89 rank=1 px=  818.68
# 2025-10-08 20:25:27 | INFO | BUY ASIANPAINT.NS px=  799.48 sh=    59 fee=79.61 cash=142761.59 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=95.6% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.89); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:27 | INFO | Exit JSWSTEEL.NS  px=  107.58 shares=  1166 :: Exit: TakeProfit hit — TakeProfit hit: High 108.38 ≥ TP 107.58 (from entry 97.80) | net=9635.85 cash=268018.66
# 2025-10-08 20:25:27 | INFO | Selected 1 BUY candidates on 2016-03-09:
# 2025-10-08 20:25:27 | INFO |   TATASTEEL.NS volar=  0.19 rank=1 px=   20.85
# 2025-10-08 20:25:27 | INFO | BUY TATASTEEL.NS px=   21.73 sh=  3084 fee=103.16 cash=200911.74 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=79.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.19); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit BRITANNIA.NS px= 1194.32 shares=    50 :: Exit: StopLoss hit — StopLoss hit: Low 1168.13 ≤ SL 1194.32 (from entry 1257.18) | net=-2559.85 cash=260518.71
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-03-16:
# 2025-10-08 20:25:28 | INFO |   POWERGRID.NS volar=  0.42 rank=1 px=   50.96
# 2025-10-08 20:25:28 | INFO | BUY POWERGRID.NS px=   50.72 sh=  1284 fee=100.93 cash=195294.54 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>BBmid]; 52w%=91.5% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.42); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit EICHERMOT.NS px= 1682.08 shares=     7 :: Exit: StopLoss hit — StopLoss hit: Low 1668.09 ≤ SL 1682.08 (from entry 1770.61) | net=-635.54 cash=207019.39
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-03-17:
# 2025-10-08 20:25:28 | INFO |   BAJFINANCE.NS volar=  1.97 rank=1 px=   63.43
# 2025-10-08 20:25:28 | INFO | BUY BAJFINANCE.NS px=   63.88 sh=   810 fee=85.04 cash=155189.36 :: Entry: HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=97.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.97); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit POWERGRID.NS px=   49.91 shares=  1284 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 50.02 | net=-1247.20 cash=219166.32
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-03-21:
# 2025-10-08 20:25:28 | INFO |   GRASIM.NS    volar=  0.68 rank=1 px=  533.64
# 2025-10-08 20:25:28 | INFO | BUY GRASIM.NS    px=  544.17 sh=   100 fee=88.22 cash=164660.92 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=96.7% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.68); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit ASIANPAINT.NS px=  787.98 shares=    59 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 787.98 | net=-853.32 cash=211056.31
# 2025-10-08 20:25:28 | INFO | Exit TATASTEEL.NS px=   22.94 shares=  3084 :: Exit: TakeProfit hit — TakeProfit hit: High 23.38 ≥ TP 22.94 (from entry 20.85) | net=3507.51 cash=281670.73
# 2025-10-08 20:25:28 | INFO | Selected 2 BUY candidates on 2016-03-23:
# 2025-10-08 20:25:28 | INFO |   BPCL.NS      volar=  1.03 rank=1 px=   82.77
# 2025-10-08 20:25:28 | INFO |   TITAN.NS     volar=  0.04 rank=2 px=  346.97
# 2025-10-08 20:25:28 | INFO | BUY BPCL.NS      px=   82.17 sh=   857 fee=107.21 cash=211145.89 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=93.7% (≥ 50%); VOLAR rank 1/2 (VOLAR=1.03); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Skip BUY TITAN.NS     (alloc 0.00 too small)
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-03-28:
# 2025-10-08 20:25:28 | INFO |   WIPRO.NS     volar=  0.11 rank=1 px=   97.43
# 2025-10-08 20:25:28 | INFO | BUY WIPRO.NS     px=   97.02 sh=   544 fee=86.27 cash=158283.34 :: Entry: PIERCING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=85.9% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.11); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit 3MINDIA.NS   px= 9751.74 shares=     8 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 9751.88 | net=-2170.80 cash=236169.11
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-04-08:
# 2025-10-08 20:25:28 | INFO |   AARTIIND.NS  volar=  1.48 rank=1 px=  123.48
# 2025-10-08 20:25:28 | INFO | BUY AARTIIND.NS  px=  123.25 sh=   479 fee=93.70 cash=177040.55 :: Entry: HARAMI + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=93.8% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.48); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit BAJFINANCE.NS px=   69.78 shares=   810 :: Exit: TakeProfit hit — TakeProfit hit: High 70.18 ≥ TP 69.78 (from entry 63.43) | net=4583.64 cash=233454.22
# 2025-10-08 20:25:28 | INFO | Exit GRASIM.NS    px=  587.01 shares=   100 :: Exit: TakeProfit hit — TakeProfit hit: High 587.05 ≥ TP 587.01 (from entry 533.64) | net=4087.26 cash=292046.88
# 2025-10-08 20:25:28 | INFO | Selected 2 BUY candidates on 2016-04-11:
# 2025-10-08 20:25:28 | INFO |   3MINDIA.NS   volar=  1.32 rank=1 px=10224.14
# 2025-10-08 20:25:28 | INFO |   COFORGE.NS   volar=  1.08 rank=2 px=   87.54
# 2025-10-08 20:25:28 | INFO | BUY 3MINDIA.NS   px=10543.57 sh=     4 fee=73.68 cash=249798.92 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=89.6% (≥ 50%); VOLAR rank 1/2 (VOLAR=1.32); MVO weight=61.6% of capped cash
# 2025-10-08 20:25:28 | INFO | BUY COFORGE.NS   px=   86.84 sh=   322 fee=56.80 cash=221779.50 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=80.3% (≥ 50%); VOLAR rank 2/2 (VOLAR=1.08); MVO weight=38.4% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit 3MINDIA.NS   px=11246.55 shares=     4 :: Exit: TakeProfit hit — TakeProfit hit: High 12634.43 ≥ TP 11246.55 (from entry 10224.14) | net=2644.36 cash=266671.82
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-04-12:
# 2025-10-08 20:25:28 | INFO |   BHARTIARTL.NS volar= -0.03 rank=1 px=  297.25
# 2025-10-08 20:25:28 | INFO | BUY BHARTIARTL.NS px=  298.87 sh=   223 fee=102.74 cash=199920.73 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=78.7% (≥ 50%); VOLAR rank 1/1 (VOLAR=-0.03); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit BPCL.NS      px=   91.05 shares=   857 :: Exit: TakeProfit hit — TakeProfit hit: High 92.69 ≥ TP 91.05 (from entry 82.77) | net=7377.20 cash=277822.77
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-04-18:
# 2025-10-08 20:25:28 | INFO |   BAJFINANCE.NS volar=  1.88 rank=1 px=   72.15
# 2025-10-08 20:25:28 | INFO | BUY BAJFINANCE.NS px=   70.99 sh=   978 fee=106.04 cash=208287.39 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.88); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit BAJFINANCE.NS px=   68.54 shares=   978 :: Exit: StopLoss hit — StopLoss hit: Low 67.41 ≤ SL 68.54 (from entry 72.15) | net=-2620.18 cash=275202.58
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-04-22:
# 2025-10-08 20:25:28 | INFO |   TATAMOTORS.NS volar= -0.30 rank=1 px=  404.65
# 2025-10-08 20:25:28 | INFO | BUY TATAMOTORS.NS px=  409.46 sh=   168 fee=105.28 cash=206308.21 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=74.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=-0.30); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit BHARTIARTL.NS px=  326.97 shares=   223 :: Exit: TakeProfit hit — TakeProfit hit: High 328.66 ≥ TP 326.97 (from entry 297.25) | net=6041.38 cash=279100.69
# 2025-10-08 20:25:28 | INFO | Exit COFORGE.NS   px=   83.16 shares=   322 :: Exit: StopLoss hit — StopLoss hit: Low 81.66 ≤ SL 83.16 (from entry 87.54) | net=-1316.42 cash=305803.69
# 2025-10-08 20:25:28 | INFO | Exit WIPRO.NS     px=   96.12 shares=   544 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 96.70 | net=-676.43 cash=357989.82
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-05-02:
# 2025-10-08 20:25:28 | INFO |   ABB.NS       volar=  0.09 rank=1 px= 1131.50
# 2025-10-08 20:25:28 | INFO | BUY ABB.NS       px= 1109.20 sh=    80 fee=128.97 cash=269124.82 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[ADX>20 & +DI>-DI, Close>SMA50]; 52w%=91.1% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.09); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit ABB.NS       px= 1074.92 shares=    80 :: Exit: StopLoss hit — StopLoss hit: Low 1066.79 ≤ SL 1074.92 (from entry 1131.50) | net=-3007.55 cash=354982.26
# 2025-10-08 20:25:28 | INFO | Exit TATAMOTORS.NS px=  384.42 shares=   168 :: Exit: StopLoss hit — StopLoss hit: Low 373.23 ≤ SL 384.42 (from entry 404.65) | net=-4426.83 cash=419449.80
# 2025-10-08 20:25:28 | INFO | Selected 3 BUY candidates on 2016-05-04:
# 2025-10-08 20:25:28 | INFO |   GRASIM.NS    volar=  0.97 rank=1 px=  603.01
# 2025-10-08 20:25:28 | INFO |   ULTRACEMCO.NS volar=  0.88 rank=2 px= 3044.55
# 2025-10-08 20:25:28 | INFO |   ASIANPAINT.NS volar=  0.76 rank=3 px=  805.20
# 2025-10-08 20:25:28 | INFO | BUY GRASIM.NS    px=  603.91 sh=    88 fee=86.70 cash=366218.88 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/3 (VOLAR=0.97); MVO weight=50.8% of capped cash
# 2025-10-08 20:25:28 | INFO | BUY ULTRACEMCO.NS px= 3055.73 sh=     9 fee=56.26 cash=338661.05 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, ADX>20 & +DI>-DI, Close>SMA50]; 52w%=94.4% (≥ 50%); VOLAR rank 2/3 (VOLAR=0.88); MVO weight=27.7% of capped cash
# 2025-10-08 20:25:28 | INFO | BUY ASIANPAINT.NS px=  806.68 sh=    28 fee=50.42 cash=316023.62 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, Close>SMA50, Close>BBmid]; 52w%=94.7% (≥ 50%); VOLAR rank 3/3 (VOLAR=0.76); MVO weight=21.6% of capped cash
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-05-05:
# 2025-10-08 20:25:28 | INFO |   BAJAJ-AUTO.NS volar=  1.09 rank=1 px= 1932.69
# 2025-10-08 20:25:28 | INFO | BUY BAJAJ-AUTO.NS px= 1925.08 sh=    41 fee=117.32 cash=236978.00 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, ADX>20 & +DI>-DI, Close>SMA50]; 52w%=95.3% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.09); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit ASIANPAINT.NS px=  797.77 shares=    28 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 800.63 | net=-370.30 cash=259245.13
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-05-06:
# 2025-10-08 20:25:28 | INFO |   BAJFINANCE.NS volar=  2.11 rank=1 px=   70.11
# 2025-10-08 20:25:28 | INFO | BUY BAJFINANCE.NS px=   70.51 sh=   919 fee=100.54 cash=194344.83 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=96.3% (≥ 50%); VOLAR rank 1/1 (VOLAR=2.11); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit ULTRACEMCO.NS px= 2975.44 shares=     9 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 2975.35 | net=-853.84 cash=221048.82
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-05-09:
# 2025-10-08 20:25:28 | INFO |   ASIANPAINT.NS volar=  0.89 rank=1 px=  826.39
# 2025-10-08 20:25:28 | INFO | BUY ASIANPAINT.NS px=  837.15 sh=    66 fee=89.21 cash=165707.65 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=96.5% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.89); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit AARTIIND.NS  px=  120.55 shares=   479 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 118.89 | net=-1490.31 cash=223345.91
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-05-12:
# 2025-10-08 20:25:28 | INFO |   TATASTEEL.NS volar=  0.02 rank=1 px=   24.36
# 2025-10-08 20:25:28 | INFO | BUY TATASTEEL.NS px=   24.32 sh=  2296 fee=89.89 cash=167428.42 :: Entry: PIERCING + EMA10>EMA20 + Close>EMA200; Conf=[Close>SMA50]; 52w%=89.3% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.02); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit TATASTEEL.NS px=   23.76 shares=  2296 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 23.73 | net=-1468.64 cash=221877.26
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-05-18:
# 2025-10-08 20:25:28 | INFO |   ULTRACEMCO.NS volar=  0.71 rank=1 px= 3136.69
# 2025-10-08 20:25:28 | INFO | BUY ULTRACEMCO.NS px= 3094.08 sh=    17 fee=86.06 cash=169191.91 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, Close>SMA50, Close>BBmid]; 52w%=95.5% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.71); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit ULTRACEMCO.NS px= 3010.38 shares=    17 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 3008.08 | net=-1609.20 cash=220268.07
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-05-23:
# 2025-10-08 20:25:28 | INFO |   ITC.NS       volar=  0.57 rank=1 px=  168.09
# 2025-10-08 20:25:28 | INFO | BUY ITC.NS       px=  166.75 sh=   330 fee=88.94 cash=165153.26 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=92.2% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.57); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit BAJAJ-AUTO.NS px= 1899.73 shares=    41 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 1900.36 | net=-1284.50 cash=242914.39
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-05-24:
# 2025-10-08 20:25:28 | INFO |   3MINDIA.NS   volar=  1.44 rank=1 px=11984.13
# 2025-10-08 20:25:28 | INFO | BUY 3MINDIA.NS   px=12040.52 sh=     5 fee=95.08 cash=182616.70 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[Close>SMA50]; 52w%=92.2% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.44); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit ASIANPAINT.NS px=  909.03 shares=    66 :: Exit: TakeProfit hit — TakeProfit hit: High 909.55 ≥ TP 909.03 (from entry 826.39) | net=4545.55 cash=242503.42
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-05-25:
# 2025-10-08 20:25:28 | INFO |   JSWSTEEL.NS  volar=  1.34 rank=1 px=  118.90
# 2025-10-08 20:25:28 | INFO | BUY JSWSTEEL.NS  px=  116.77 sh=   519 fee=95.56 cash=181803.31 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[ADX>20 & +DI>-DI, Close>SMA50]; 52w%=96.1% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.34); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit JSWSTEEL.NS  px=  117.37 shares=   519 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 116.77 | net=103.98 cash=242607.40
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-05-26:
# 2025-10-08 20:25:28 | INFO |   ASIANPAINT.NS volar=  1.15 rank=1 px=  912.82
# 2025-10-08 20:25:28 | INFO | BUY ASIANPAINT.NS px=  915.87 sh=    66 fee=95.38 cash=182064.58 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.15); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit 3MINDIA.NS   px=11384.92 shares=     5 :: Exit: StopLoss hit — StopLoss hit: Low 11309.72 ≤ SL 11384.92 (from entry 11984.13) | net=-3479.32 cash=238882.94
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-05-31:
# 2025-10-08 20:25:28 | INFO |   TECHM.NS     volar= -0.42 rank=1 px=  396.80
# 2025-10-08 20:25:28 | INFO | BUY TECHM.NS     px=  394.06 sh=   151 fee=94.26 cash=179284.89 :: Entry: ENGULFING + INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=82.5% (≥ 50%); VOLAR rank 1/1 (VOLAR=-0.42); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit BAJFINANCE.NS px=   77.13 shares=   919 :: Exit: TakeProfit hit — TakeProfit hit: High 77.65 ≥ TP 77.13 (from entry 70.11) | net=5856.90 cash=250042.08
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-06-02:
# 2025-10-08 20:25:28 | INFO |   NTPC.NS      volar=  0.55 rank=1 px=   84.73
# 2025-10-08 20:25:28 | INFO | BUY NTPC.NS      px=   85.11 sh=   734 fee=97.78 cash=187472.62 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.55); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit TECHM.NS     px=  376.96 shares=   151 :: Exit: StopLoss hit — StopLoss hit: Low 359.93 ≤ SL 376.96 (from entry 396.80) | net=-2783.39 cash=244287.29
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-06-24:
# 2025-10-08 20:25:28 | INFO |   POWERGRID.NS volar=  0.48 rank=1 px=   56.09
# 2025-10-08 20:25:28 | INFO | BUY POWERGRID.NS px=   56.95 sh=  1072 fee=96.09 cash=183139.14 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=99.7% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.48); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit GRASIM.NS    px=  663.31 shares=    88 :: Exit: TakeProfit hit — TakeProfit hit: High 684.58 ≥ TP 663.31 (from entry 603.01) | net=5032.51 cash=241402.57
# 2025-10-08 20:25:28 | INFO | Exit ITC.NS       px=  184.90 shares=   330 :: Exit: TakeProfit hit — TakeProfit hit: High 191.85 ≥ TP 184.90 (from entry 168.09) | net=5791.78 cash=302309.15
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-07-01:
# 2025-10-08 20:25:28 | INFO |   TATAMOTORS.NS volar=  0.28 rank=1 px=  455.22
# 2025-10-08 20:25:28 | INFO | BUY TATAMOTORS.NS px=  449.62 sh=   168 fee=113.29 cash=226659.84 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, Close>SMA50]; 52w%=94.1% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.28); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-07-04:
# 2025-10-08 20:25:28 | INFO |   AARTIIND.NS  volar=  1.42 rank=1 px=  124.91
# 2025-10-08 20:25:28 | INFO | BUY AARTIIND.NS  px=  126.65 sh=   447 fee=90.82 cash=169957.97 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=94.4% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.42); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit POWERGRID.NS px=   61.70 shares=  1072 :: Exit: TakeProfit hit — TakeProfit hit: High 62.56 ≥ TP 61.70 (from entry 56.09) | net=4880.33 cash=235986.45
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-07-11:
# 2025-10-08 20:25:28 | INFO |   ABB.NS       volar= -0.05 rank=1 px= 1113.14
# 2025-10-08 20:25:28 | INFO | BUY ABB.NS       px= 1118.95 sh=    52 fee=92.69 cash=177708.35 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=88.2% (≥ 50%); VOLAR rank 1/1 (VOLAR=-0.05); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit NTPC.NS      px=   93.20 shares=   734 :: Exit: TakeProfit hit — TakeProfit hit: High 93.57 ≥ TP 93.20 (from entry 84.73) | net=5723.06 cash=246000.88
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-07-12:
# 2025-10-08 20:25:28 | INFO |   GRASIM.NS    volar=  1.51 rank=1 px=  665.98
# 2025-10-08 20:25:28 | INFO | BUY GRASIM.NS    px=  676.10 sh=    90 fee=95.85 cash=185056.36 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=97.8% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.51); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit TATAMOTORS.NS px=  500.74 shares=   168 :: Exit: TakeProfit hit — TakeProfit hit: High 501.91 ≥ TP 500.74 (from entry 455.22) | net=8340.15 cash=269045.83
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-07-25:
# 2025-10-08 20:25:28 | INFO |   BAJFINANCE.NS volar=  1.82 rank=1 px=   86.28
# 2025-10-08 20:25:28 | INFO | BUY BAJFINANCE.NS px=   87.27 sh=   770 fee=103.39 cash=201744.91 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.82); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit BAJFINANCE.NS px=   94.91 shares=   770 :: Exit: TakeProfit hit — TakeProfit hit: High 97.04 ≥ TP 94.91 (from entry 86.28) | net=5656.97 cash=274702.81
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-07-26:
# 2025-10-08 20:25:28 | INFO |   TITAN.NS     volar=  0.66 rank=1 px=  401.06
# 2025-10-08 20:25:28 | INFO | BUY TITAN.NS     px=  400.57 sh=   171 fee=104.93 cash=206099.95 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=98.8% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.66); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit ASIANPAINT.NS px= 1004.11 shares=    66 :: Exit: TakeProfit hit — TakeProfit hit: High 1071.10 ≥ TP 1004.11 (from entry 912.82) | net=5612.19 cash=272254.96
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-07-28:
# 2025-10-08 20:25:28 | INFO |   ULTRACEMCO.NS volar=  0.36 rank=1 px= 3516.46
# 2025-10-08 20:25:28 | INFO | BUY ULTRACEMCO.NS px= 3540.76 sh=    19 fee=103.48 cash=204877.01 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=99.5% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.36); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit GRASIM.NS    px=  732.57 shares=    90 :: Exit: TakeProfit hit — TakeProfit hit: High 735.33 ≥ TP 732.57 (from entry 665.98) | net=4871.48 cash=270693.01
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-08-02:
# 2025-10-08 20:25:28 | INFO |   TATAMOTORS.NS volar=  0.61 rank=1 px=  500.98
# 2025-10-08 20:25:28 | INFO | BUY TATAMOTORS.NS px=  484.58 sh=   139 fee=103.58 cash=203233.48 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=99.6% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.61); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit ABB.NS       px= 1057.48 shares=    52 :: Exit: StopLoss hit — StopLoss hit: Low 1044.06 ≤ SL 1057.48 (from entry 1113.14) | net=-3393.46 cash=258118.11
# 2025-10-08 20:25:28 | INFO | Exit TATAMOTORS.NS px=  475.93 shares=   139 :: Exit: StopLoss hit — StopLoss hit: Low 467.09 ≤ SL 475.93 (from entry 500.98) | net=-1420.97 cash=324156.67
# 2025-10-08 20:25:28 | INFO | Selected 2 BUY candidates on 2016-08-08:
# 2025-10-08 20:25:28 | INFO |   ASIANPAINT.NS volar=  1.09 rank=1 px= 1070.36
# 2025-10-08 20:25:28 | INFO |   BAJAJ-AUTO.NS volar=  0.48 rank=2 px= 2257.96
# 2025-10-08 20:25:28 | INFO | BUY ASIANPAINT.NS px= 1066.04 sh=    55 fee=93.22 cash=265431.19 :: Entry: HARAMI + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/2 (VOLAR=1.09); MVO weight=73.4% of capped cash
# 2025-10-08 20:25:28 | INFO | BUY BAJAJ-AUTO.NS px= 2257.45 sh=     9 fee=47.72 cash=245066.44 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 2/2 (VOLAR=0.48); MVO weight=26.6% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit AARTIIND.NS  px=  137.40 shares=   447 :: Exit: TakeProfit hit — TakeProfit hit: High 140.69 ≥ TP 137.40 (from entry 124.91) | net=4605.93 cash=306374.24
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-08-09:
# 2025-10-08 20:25:28 | INFO |   MARUTI.NS    volar=  0.45 rank=1 px= 4574.17
# 2025-10-08 20:25:28 | INFO | BUY MARUTI.NS    px= 4529.39 sh=    16 fee=109.65 cash=233794.35 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.45); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit TITAN.NS     px=  381.00 shares=   171 :: Exit: StopLoss hit — StopLoss hit: Low 379.77 ≤ SL 381.00 (from entry 401.06) | net=-3566.03 cash=298831.18
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-08-16:
# 2025-10-08 20:25:28 | INFO |   JSWSTEEL.NS  volar=  2.17 rank=1 px=  156.33
# 2025-10-08 20:25:28 | INFO | BUY JSWSTEEL.NS  px=  157.78 sh=   473 fee=112.22 cash=224089.25 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=99.4% (≥ 50%); VOLAR rank 1/1 (VOLAR=2.17); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit ASIANPAINT.NS px= 1016.84 shares=    55 :: Exit: StopLoss hit — StopLoss hit: Low 1012.85 ≤ SL 1016.84 (from entry 1070.36) | net=-2904.50 cash=279910.23
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-08-29:
# 2025-10-08 20:25:28 | INFO |   HINDALCO.NS  volar=  1.40 rank=1 px=  145.45
# 2025-10-08 20:25:28 | INFO | BUY HINDALCO.NS  px=  148.54 sh=   471 fee=106.68 cash=209839.93 :: Entry: HARAMI + HARAMI_CROSS + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=97.8% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.40); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit ULTRACEMCO.NS px= 3868.10 shares=    19 :: Exit: TakeProfit hit — TakeProfit hit: High 3911.46 ≥ TP 3868.10 (from entry 3516.46) | net=5992.59 cash=283210.47
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-08-31:
# 2025-10-08 20:25:28 | INFO |   POWERGRID.NS volar=  1.13 rank=1 px=   66.93
# 2025-10-08 20:25:28 | INFO | BUY POWERGRID.NS px=   67.15 sh=  1054 fee=107.64 cash=212326.53 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.13); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit MARUTI.NS    px= 5031.59 shares=    16 :: Exit: TakeProfit hit — TakeProfit hit: High 5055.65 ≥ TP 5031.59 (from entry 4574.17) | net=7794.85 cash=292701.27
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-09-09:
# 2025-10-08 20:25:28 | INFO |   ULTRACEMCO.NS volar=  0.77 rank=1 px= 3964.50
# 2025-10-08 20:25:28 | INFO | BUY ULTRACEMCO.NS px= 3805.40 sh=    19 fee=109.45 cash=220289.26 :: Entry: ENGULFING + MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.77); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit HINDALCO.NS  px=  138.17 shares=   471 :: Exit: StopLoss hit — StopLoss hit: Low 132.12 ≤ SL 138.17 (from entry 145.45) | net=-5105.14 cash=285254.41
# 2025-10-08 20:25:28 | INFO | Exit ULTRACEMCO.NS px= 3766.27 shares=    19 :: Exit: StopLoss hit — StopLoss hit: Low 3700.34 ≤ SL 3766.27 (from entry 3964.50) | net=-974.27 cash=356692.16
# 2025-10-08 20:25:28 | INFO | Selected 2 BUY candidates on 2016-09-14:
# 2025-10-08 20:25:28 | INFO |   TATAMOTORS.NS volar=  1.14 rank=1 px=  546.41
# 2025-10-08 20:25:28 | INFO |   AARTIIND.NS  volar=  0.91 rank=2 px=  142.32
# 2025-10-08 20:25:28 | INFO | BUY TATAMOTORS.NS px=  550.59 sh=    71 fee=70.02 cash=317530.49 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=94.0% (≥ 50%); VOLAR rank 1/2 (VOLAR=1.14); MVO weight=44.0% of capped cash
# 2025-10-08 20:25:28 | INFO | BUY AARTIIND.NS  px=  140.76 sh=   354 fee=82.77 cash=267619.91 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[ADX>20 & +DI>-DI, Close>SMA50]; 52w%=95.0% (≥ 50%); VOLAR rank 2/2 (VOLAR=0.91); MVO weight=56.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit POWERGRID.NS px=   65.64 shares=  1054 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 65.64 | net=-1818.74 cash=336685.10
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-09-26:
# 2025-10-08 20:25:28 | INFO |   ONGC.NS      volar=  0.07 rank=1 px=  108.06
# 2025-10-08 20:25:28 | INFO | BUY ONGC.NS      px=  103.92 sh=   809 fee=123.42 cash=252492.90 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.07); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit BAJAJ-AUTO.NS px= 2294.04 shares=     9 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 2273.29 | net=213.02 cash=273070.66
# 2025-10-08 20:25:28 | INFO | Exit ONGC.NS      px=  102.66 shares=   809 :: Exit: StopLoss hit — StopLoss hit: Low 102.58 ≤ SL 102.66 (from entry 108.06) | net=-1275.85 cash=355987.02
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-09-27:
# 2025-10-08 20:25:28 | INFO |   BAJFINANCE.NS volar=  2.03 rank=1 px=  109.77
# 2025-10-08 20:25:28 | INFO | BUY BAJFINANCE.NS px=  106.72 sh=   833 fee=129.16 cash=266959.38 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=96.6% (≥ 50%); VOLAR rank 1/1 (VOLAR=2.03); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit JSWSTEEL.NS  px=  158.25 shares=   473 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 158.89 | net=-15.05 cash=341686.26
# 2025-10-08 20:25:28 | INFO | Exit BAJFINANCE.NS px=  104.28 shares=   833 :: Exit: StopLoss hit — StopLoss hit: Low 98.23 ≤ SL 104.28 (from entry 109.77) | net=-2297.56 cash=428416.34
# 2025-10-08 20:25:28 | INFO | Exit TATAMOTORS.NS px=  519.09 shares=    71 :: Exit: StopLoss hit — StopLoss hit: Low 507.51 ≤ SL 519.09 (from entry 546.41) | net=-2391.63 cash=465186.39
# 2025-10-08 20:25:28 | INFO | Selected 3 BUY candidates on 2016-09-29:
# 2025-10-08 20:25:28 | INFO |   JSWSTEEL.NS  volar=  1.74 rank=1 px=  161.12
# 2025-10-08 20:25:28 | INFO |   EICHERMOT.NS volar=  0.89 rank=2 px= 2455.39
# 2025-10-08 20:25:28 | INFO |   ULTRACEMCO.NS volar=  0.77 rank=3 px= 3840.43
# 2025-10-08 20:25:28 | INFO | BUY JSWSTEEL.NS  px=  151.49 sh=   420 fee=99.15 cash=401460.29 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[Close>SMA50]; 52w%=95.3% (≥ 50%); VOLAR rank 1/3 (VOLAR=1.74); MVO weight=54.7% of capped cash
# 2025-10-08 20:25:28 | INFO | BUY EICHERMOT.NS px= 2322.51 sh=    12 fee=56.69 cash=373533.42 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 2/3 (VOLAR=0.89); MVO weight=25.7% of capped cash
# 2025-10-08 20:25:28 | INFO | BUY ULTRACEMCO.NS px= 3716.46 sh=     6 fee=50.08 cash=351184.56 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[Close>SMA50]; 52w%=96.5% (≥ 50%); VOLAR rank 3/3 (VOLAR=0.77); MVO weight=19.6% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit EICHERMOT.NS px= 2332.62 shares=    12 :: Exit: StopLoss hit — StopLoss hit: Low 2288.13 ≤ SL 2332.62 (from entry 2455.39) | net=-11.64 cash=379099.79
# 2025-10-08 20:25:28 | INFO | Exit JSWSTEEL.NS  px=  153.06 shares=   420 :: Exit: StopLoss hit — StopLoss hit: Low 150.67 ≤ SL 153.06 (from entry 161.12) | net=446.60 cash=443272.49
# 2025-10-08 20:25:28 | INFO | Exit ULTRACEMCO.NS px= 3729.55 shares=     6 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 3707.08 | net=-41.95 cash=465579.39
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-10-03:
# 2025-10-08 20:25:28 | INFO |   GRASIM.NS    volar=  1.15 rank=1 px=  713.36
# 2025-10-08 20:25:28 | INFO | BUY GRASIM.NS    px=  718.52 sh=   161 fee=160.96 cash=349737.00 :: Entry: HARAMI + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, Close>SMA50, Close>BBmid]; 52w%=92.1% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.15); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit AARTIIND.NS  px=  156.55 shares=   354 :: Exit: TakeProfit hit — TakeProfit hit: High 160.32 ≥ TP 156.55 (from entry 142.32) | net=5402.24 cash=405049.81
# 2025-10-08 20:25:28 | INFO | Selected 4 BUY candidates on 2016-10-04:
# 2025-10-08 20:25:28 | INFO |   BAJFINANCE.NS volar=  2.10 rank=1 px=  106.08
# 2025-10-08 20:25:28 | INFO |   TATASTEEL.NS volar=  1.29 rank=2 px=   29.03
# 2025-10-08 20:25:28 | INFO |   EICHERMOT.NS volar=  0.80 rank=3 px= 2422.37
# 2025-10-08 20:25:28 | INFO |   SBIN.NS      volar=  0.02 rank=4 px=  233.92
# 2025-10-08 20:25:28 | INFO | BUY BAJFINANCE.NS px=  105.28 sh=   543 fee=91.48 cash=347792.21 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[Close>SMA50]; 52w%=93.5% (≥ 50%); VOLAR rank 1/4 (VOLAR=2.10); MVO weight=56.5% of capped cash
# 2025-10-08 20:25:28 | INFO | BUY TATASTEEL.NS px=   29.42 sh=   877 fee=54.23 cash=321939.50 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=95.0% (≥ 50%); VOLAR rank 2/4 (VOLAR=1.29); MVO weight=25.5% of capped cash
# 2025-10-08 20:25:28 | INFO | BUY EICHERMOT.NS px= 2408.65 sh=     7 fee=39.92 cash=305039.06 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 3/4 (VOLAR=0.80); MVO weight=18.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Skip BUY SBIN.NS      (alloc 0.00 too small)
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-10-05:
# 2025-10-08 20:25:28 | INFO |   ADANIPORTS.NS volar= -0.58 rank=1 px=  256.90
# 2025-10-08 20:25:28 | INFO | BUY ADANIPORTS.NS px=  252.62 sh=   301 fee=113.89 cash=228887.73 :: Entry: HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, Close>SMA50, Close>BBmid]; 52w%=82.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=-0.58); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit ADANIPORTS.NS px=  254.09 shares=   301 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 252.62 | net=203.58 cash=305242.65
# 2025-10-08 20:25:28 | INFO | Exit BAJFINANCE.NS px=  104.53 shares=   543 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 104.36 | net=-603.73 cash=361896.53
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-10-06:
# 2025-10-08 20:25:28 | INFO |   HINDALCO.NS  volar=  1.68 rank=1 px=  149.21
# 2025-10-08 20:25:28 | INFO | BUY HINDALCO.NS  px=  149.54 sh=   605 fee=131.03 cash=271293.43 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=97.1% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.68); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-10-13:
# 2025-10-08 20:25:28 | INFO |   JSWSTEEL.NS  volar=  2.22 rank=1 px=  163.27
# 2025-10-08 20:25:28 | INFO | BUY JSWSTEEL.NS  px=  159.97 sh=   423 fee=103.95 cash=203520.94 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=97.4% (≥ 50%); VOLAR rank 1/1 (VOLAR=2.22); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit EICHERMOT.NS px= 2301.25 shares=     7 :: Exit: StopLoss hit — StopLoss hit: Low 2289.57 ≤ SL 2301.25 (from entry 2422.37) | net=-850.99 cash=219570.38
# 2025-10-08 20:25:28 | INFO | Exit HINDALCO.NS  px=  141.75 shares=   605 :: Exit: StopLoss hit — StopLoss hit: Low 141.66 ≤ SL 141.75 (from entry 149.21) | net=-4980.77 cash=305192.70
# 2025-10-08 20:25:28 | INFO | Exit JSWSTEEL.NS  px=  155.10 shares=   423 :: Exit: StopLoss hit — StopLoss hit: Low 154.85 ≤ SL 155.10 (from entry 163.27) | net=-2278.70 cash=370686.49
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-10-17:
# 2025-10-08 20:25:28 | INFO |   NESTLEIND.NS volar= -0.05 rank=1 px=  304.83
# 2025-10-08 20:25:28 | INFO | BUY NESTLEIND.NS px=  301.56 sh=   307 fee=133.53 cash=277974.33 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=95.2% (≥ 50%); VOLAR rank 1/1 (VOLAR=-0.05); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit TATASTEEL.NS px=   31.93 shares=   877 :: Exit: TakeProfit hit — TakeProfit hit: High 32.08 ≥ TP 31.93 (from entry 29.03) | net=2075.73 cash=305902.77
# 2025-10-08 20:25:28 | INFO | Selected 3 BUY candidates on 2016-10-19:
# 2025-10-08 20:25:28 | INFO |   TATASTEEL.NS volar=  1.48 rank=1 px=   32.04
# 2025-10-08 20:25:28 | INFO |   TATAMOTORS.NS volar=  1.15 rank=2 px=  542.29
# 2025-10-08 20:25:28 | INFO |   EICHERMOT.NS volar=  0.77 rank=3 px= 2340.38
# 2025-10-08 20:25:28 | INFO | BUY TATASTEEL.NS px=   32.04 sh=  1034 fee=62.94 cash=272712.90 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/3 (VOLAR=1.48); MVO weight=43.4% of capped cash
# 2025-10-08 20:25:28 | INFO | BUY TATAMOTORS.NS px=  540.76 sh=    29 fee=37.13 cash=256993.63 :: Entry: HARAMI + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, Close>SMA50, Close>BBmid]; 52w%=94.1% (≥ 50%); VOLAR rank 2/3 (VOLAR=1.15); MVO weight=21.2% of capped cash
# 2025-10-08 20:25:28 | INFO | BUY EICHERMOT.NS px= 2328.09 sh=    11 fee=54.01 cash=231330.60 :: Entry: HARAMI + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, ADX>20 & +DI>-DI, Close>SMA50]; 52w%=95.4% (≥ 50%); VOLAR rank 3/3 (VOLAR=0.77); MVO weight=35.5% of capped cash
# 2025-10-08 20:25:28 | INFO | Exit TATAMOTORS.NS px=  515.17 shares=    29 :: Exit: StopLoss hit — StopLoss hit: Low 513.90 ≤ SL 515.17 (from entry 542.29) | net=-836.01 cash=246213.85
# 2025-10-08 20:25:28 | INFO | Exit TATASTEEL.NS px=   30.44 shares=  1034 :: Exit: StopLoss hit — StopLoss hit: Low 29.40 ≤ SL 30.44 (from entry 32.04) | net=-1799.13 cash=277604.59
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-10-26:
# 2025-10-08 20:25:28 | INFO |   AARTIIND.NS  volar=  1.07 rank=1 px=  177.12
# 2025-10-08 20:25:28 | INFO | BUY AARTIIND.NS  px=  178.35 sh=   389 fee=105.98 cash=208119.90 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.07); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:28 | INFO | Selected 1 BUY candidates on 2016-10-27:
# ...
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-09-04:
# 2025-10-08 20:25:37 | INFO |   AXISBANK.NS  volar= -0.52 rank=1 px= 1181.69
# 2025-10-08 20:25:37 | INFO | BUY AXISBANK.NS  px= 1176.69 sh=   106 fee=171.70 cash=375757.95 :: Entry: HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>BBmid]; 52w%=90.5% (≥ 50%); VOLAR rank 1/1 (VOLAR=-0.52); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit AXISBANK.NS  px= 1157.01 shares=   106 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 1157.76 | net=-2432.55 cash=498226.71
# 2025-10-08 20:25:37 | INFO | Exit EICHERMOT.NS px= 4639.35 shares=    25 :: Exit: StopLoss hit — StopLoss hit: Low 4629.32 ≤ SL 4639.35 (from entry 4883.53) | net=-5675.74 cash=614042.97
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-09-11:
# 2025-10-08 20:25:37 | INFO |   HCLTECH.NS   volar=  0.57 rank=1 px= 1715.50
# 2025-10-08 20:25:37 | INFO | BUY HCLTECH.NS   px= 1716.03 sh=    89 fee=204.95 cash=461111.46 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=98.5% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.57); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-09-12:
# 2025-10-08 20:25:37 | INFO |   COFORGE.NS   volar= -0.21 rank=1 px= 1366.52
# 2025-10-08 20:25:37 | INFO | BUY COFORGE.NS   px= 1362.26 sh=    84 fee=159.47 cash=346522.47 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=-0.21); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit CIPLA.NS     px= 1664.12 shares=    67 :: Exit: TakeProfit hit — TakeProfit hit: High 1665.21 ≥ TP 1664.12 (from entry 1512.84) | net=9842.47 cash=457855.86
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-09-18:
# 2025-10-08 20:25:37 | INFO |   BHARTIARTL.NS volar=  1.51 rank=1 px= 1641.48
# 2025-10-08 20:25:37 | INFO | BUY BHARTIARTL.NS px= 1641.18 sh=    69 fee=158.06 cash=344456.38 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.51); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit TCS.NS       px= 4177.16 shares=    12 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 4157.08 | net=1227.25 cash=394483.04
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-09-20:
# 2025-10-08 20:25:37 | INFO |   BAJAJ-AUTO.NS volar=  2.54 rank=1 px=11630.24
# 2025-10-08 20:25:37 | INFO | BUY BAJAJ-AUTO.NS px=11646.53 sh=     8 fee=134.23 cash=301176.56 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=99.3% (≥ 50%); VOLAR rank 1/1 (VOLAR=2.54); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit ASIANPAINT.NS px= 3041.68 shares=    32 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 3039.20 | net=-1135.07 cash=398362.00
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-10-09:
# 2025-10-08 20:25:37 | INFO |   INFY.NS      volar=  0.09 rank=1 px= 1903.78
# 2025-10-08 20:25:37 | INFO | BUY INFY.NS      px= 1903.98 sh=    52 fee=141.16 cash=299214.04 :: Entry: HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=99.2% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.09); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit COFORGE.NS   px= 1503.17 shares=    84 :: Exit: TakeProfit hit — TakeProfit hit: High 1506.54 ≥ TP 1503.17 (from entry 1366.52) | net=11498.83 cash=425301.87
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-10-15:
# 2025-10-08 20:25:37 | INFO |   APOLLOHOSP.NS volar=  0.09 rank=1 px= 7095.87
# 2025-10-08 20:25:37 | INFO | BUY APOLLOHOSP.NS px= 7120.95 sh=    14 fee=141.98 cash=325466.59 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=98.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.09); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit BAJAJ-AUTO.NS px=11048.73 shares=     8 :: Exit: StopLoss hit — StopLoss hit: Low 9822.07 ≤ SL 11048.73 (from entry 11630.24) | net=-5055.53 cash=413717.54
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-10-18:
# 2025-10-08 20:25:37 | INFO |   COFORGE.NS   volar=  0.26 rank=1 px= 1432.27
# 2025-10-08 20:25:37 | INFO | BUY COFORGE.NS   px= 1432.14 sh=    72 fee=146.04 cash=310457.43 :: Entry: HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=97.2% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.26); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit COFORGE.NS   px= 1360.66 shares=    72 :: Exit: StopLoss hit — StopLoss hit: Low 1338.84 ≤ SL 1360.66 (from entry 1432.27) | net=-5441.74 cash=408275.80
# 2025-10-08 20:25:37 | INFO | Exit INFY.NS      px= 1808.59 shares=    52 :: Exit: StopLoss hit — StopLoss hit: Low 1792.09 ≤ SL 1808.59 (from entry 1903.78) | net=-5245.90 cash=502177.86
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-10-21:
# 2025-10-08 20:25:37 | INFO |   ABB.NS       volar=  1.23 rank=1 px= 8759.78
# 2025-10-08 20:25:37 | INFO | BUY ABB.NS       px= 8213.77 sh=    15 fee=169.90 cash=378801.46 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=97.5% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.23); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit ABB.NS       px= 8321.79 shares=    15 :: Exit: StopLoss hit — StopLoss hit: Low 8090.11 ≤ SL 8321.79 (from entry 8759.78) | net=1273.82 cash=503451.68
# 2025-10-08 20:25:37 | INFO | Exit APOLLOHOSP.NS px= 6866.49 shares=    14 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 6873.42 | net=-3851.40 cash=599435.56
# 2025-10-08 20:25:37 | INFO | Selected 2 BUY candidates on 2024-10-24:
# 2025-10-08 20:25:37 | INFO |   COFORGE.NS   volar=  0.66 rank=1 px= 1496.61
# 2025-10-08 20:25:37 | INFO |   HDFCBANK.NS  volar= -0.48 rank=2 px=  857.46
# 2025-10-08 20:25:37 | INFO | BUY COFORGE.NS   px= 1529.20 sh=    55 fee=123.47 cash=515206.31 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/2 (VOLAR=0.66); MVO weight=56.7% of capped cash
# 2025-10-08 20:25:37 | INFO | BUY HDFCBANK.NS  px=  863.16 sh=    75 fee=100.47 cash=450369.01 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=97.3% (≥ 50%); VOLAR rank 2/2 (VOLAR=-0.48); MVO weight=43.3% of capped cash
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-10-29:
# 2025-10-08 20:25:37 | INFO |   ICICIBANK.NS volar=  0.33 rank=1 px= 1291.39
# 2025-10-08 20:25:37 | INFO | BUY ICICIBANK.NS px= 1321.65 sh=    85 fee=156.99 cash=337871.60 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=96.6% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.33); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit BHARTIARTL.NS px= 1614.30 shares=    69 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 1623.53 | net=-2175.21 cash=449095.87
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-10-30:
# 2025-10-08 20:25:37 | INFO |   SBIN.NS      volar=  0.47 rank=1 px=  811.70
# 2025-10-08 20:25:37 | INFO | BUY SBIN.NS      px=  806.26 sh=   139 fee=156.67 cash=336868.97 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=91.9% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.47); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit HCLTECH.NS   px= 1717.80 shares=    89 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 1711.93 | net=-252.78 cash=489547.69
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-11-07:
# 2025-10-08 20:25:37 | INFO |   EICHERMOT.NS volar=  0.53 rank=1 px= 4854.21
# 2025-10-08 20:25:37 | INFO | BUY EICHERMOT.NS px= 4815.56 sh=    25 fee=166.55 cash=368992.18 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=97.1% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.53); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit EICHERMOT.NS px= 4611.50 shares=    25 :: Exit: StopLoss hit — StopLoss hit: Low 4477.99 ≤ SL 4611.50 (from entry 4854.21) | net=-5434.89 cash=484112.80
# 2025-10-08 20:25:37 | INFO | Exit ICICIBANK.NS px= 1244.15 shares=    85 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 1244.10 | net=-6901.57 cash=589708.64
# 2025-10-08 20:25:37 | INFO | Exit HDFCBANK.NS  px=  845.57 shares=    75 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 841.18 | net=-1532.50 cash=653013.44
# 2025-10-08 20:25:37 | INFO | Exit SBIN.NS      px=  771.12 shares=   139 :: Exit: StopLoss hit — StopLoss hit: Low 746.56 ≤ SL 771.12 (from entry 811.70) | net=-5200.13 cash=760040.21
# 2025-10-08 20:25:37 | INFO | Exit COFORGE.NS   px= 1646.27 shares=    55 :: Exit: TakeProfit hit — TakeProfit hit: High 1657.35 ≥ TP 1646.27 (from entry 1496.61) | net=6174.65 cash=850444.12
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-11-26:
# 2025-10-08 20:25:37 | INFO |   HDFCBANK.NS  volar= -0.21 rank=1 px=  892.93
# 2025-10-08 20:25:37 | INFO | BUY HDFCBANK.NS  px=  880.87 sh=   241 fee=275.67 cash=637879.17 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=-0.21); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-11-27:
# 2025-10-08 20:25:37 | INFO |   360ONE.NS    volar=  1.42 rank=1 px= 1094.98
# 2025-10-08 20:25:37 | INFO | BUY 360ONE.NS    px= 1125.10 sh=   141 fee=211.97 cash=479028.54 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=96.7% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.42); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-11-28:
# 2025-10-08 20:25:37 | INFO |   ICICIBANK.NS volar=  0.40 rank=1 px= 1291.09
# 2025-10-08 20:25:37 | INFO | BUY ICICIBANK.NS px= 1276.50 sh=    93 fee=164.56 cash=360149.44 :: Entry: INVERTED_HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=97.2% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.40); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-11-29:
# 2025-10-08 20:25:37 | INFO |   SBIN.NS      volar=  0.64 rank=1 px=  824.54
# 2025-10-08 20:25:37 | INFO | BUY SBIN.NS      px=  822.44 sh=   109 fee=130.05 cash=270373.89 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=92.6% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.64); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-12-02:
# 2025-10-08 20:25:37 | INFO |   COFORGE.NS   volar=  0.72 rank=1 px= 1725.24
# 2025-10-08 20:25:37 | INFO | BUY COFORGE.NS   px= 1730.13 sh=    39 fee=103.72 cash=202795.04 :: Entry: ENGULFING + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=100.0% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.72); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit 360ONE.NS    px= 1204.48 shares=   141 :: Exit: TakeProfit hit — TakeProfit hit: High 1218.47 ≥ TP 1204.48 (from entry 1094.98) | net=10757.63 cash=372403.31
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-12-12:
# 2025-10-08 20:25:37 | INFO |   GRASIM.NS    volar=  0.11 rank=1 px= 2673.28
# 2025-10-08 20:25:37 | INFO | BUY GRASIM.NS    px= 2650.41 sh=    35 fee=133.75 cash=279505.26 :: Entry: HARAMI + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=94.3% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.11); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit COFORGE.NS   px= 1897.76 shares=    39 :: Exit: TakeProfit hit — TakeProfit hit: High 1921.14 ≥ TP 1897.76 (from entry 1725.24) | net=6309.77 cash=353393.88
# 2025-10-08 20:25:37 | INFO | Exit GRASIM.NS    px= 2539.61 shares=    35 :: Exit: StopLoss hit — StopLoss hit: Low 2518.09 ≤ SL 2539.61 (from entry 2673.28) | net=-4151.05 cash=442140.87
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-12-20:
# 2025-10-08 20:25:37 | INFO |   APOLLOHOSP.NS volar=  0.50 rank=1 px= 7305.10
# 2025-10-08 20:25:37 | INFO | BUY APOLLOHOSP.NS px= 7232.20 sh=    15 fee=152.41 cash=333505.44 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, Close>SMA50, Close>BBmid]; 52w%=98.3% (≥ 50%); VOLAR rank 1/1 (VOLAR=0.50); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit SBIN.NS      px=  801.21 shares=   109 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 796.02 | net=-2581.24 cash=420699.75
# 2025-10-08 20:25:37 | INFO | Selected 1 BUY candidates on 2024-12-26:
# 2025-10-08 20:25:37 | INFO |   360ONE.NS    volar=  1.41 rank=1 px= 1228.86
# 2025-10-08 20:25:37 | INFO | BUY 360ONE.NS    px= 1248.59 sh=    84 fee=148.14 cash=315670.12 :: Entry: HAMMER + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=98.8% (≥ 50%); VOLAR rank 1/1 (VOLAR=1.41); MVO weight=100.0% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit HDFCBANK.NS  px=  885.43 shares=   241 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 883.43 | net=555.52 cash=528790.59
# 2025-10-08 20:25:37 | INFO | Exit ICICIBANK.NS px= 1288.61 shares=    93 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 1287.42 | net=789.84 cash=648459.52
# 2025-10-08 20:25:37 | INFO | Selected 2 BUY candidates on 2024-12-27:
# 2025-10-08 20:25:37 | INFO |   COFORGE.NS   volar=  0.87 rank=1 px= 1892.47
# 2025-10-08 20:25:37 | INFO |   DRREDDY.NS   volar=  0.27 rank=2 px= 1354.46
# 2025-10-08 20:25:37 | INFO | BUY COFORGE.NS   px= 1877.19 sh=    39 fee=110.53 cash=575138.55 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=98.3% (≥ 50%); VOLAR rank 1/2 (VOLAR=0.87); MVO weight=45.9% of capped cash
# 2025-10-08 20:25:37 | INFO | BUY DRREDDY.NS   px= 1380.69 sh=    63 fee=126.88 cash=488027.99 :: Entry: MORNING_STAR + EMA10>EMA20 + Close>EMA200; Conf=[RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid]; 52w%=95.9% (≥ 50%); VOLAR rank 2/2 (VOLAR=0.27); MVO weight=54.1% of capped cash
# 2025-10-08 20:25:37 | INFO | Exit 360ONE.NS    px= 1247.15 shares=    84 :: Exit: Final close — end of data | net=-425.07 cash=592632.55
# 2025-10-08 20:25:37 | INFO | Exit APOLLOHOSP.NS px= 7276.73 shares=    15 :: Exit: Final close — end of data | net=355.10 cash=701623.08
# 2025-10-08 20:25:37 | INFO | Exit COFORGE.NS   px= 1919.27 shares=    39 :: Exit: Final close — end of data | net=1405.66 cash=776349.71
# 2025-10-08 20:25:37 | INFO | Exit DRREDDY.NS   px= 1379.75 shares=    63 :: Exit: Final close — end of data | net=-323.73 cash=863136.54
# 2025-10-08 20:25:38 | INFO | === METRICS ===
# {
#   "start_equity_inr": 500000.0,
#   "final_equity_inr": 863136.5436165389,
#   "cagr_pct": 6.272241990247984,
#   "sharpe": 0.7703128368381472,
#   "max_drawdown_pct": -19.701643535119967,
#   "win_rate_pct": 38.174807197943444,
#   "n_trades": 778
# }
# 2025-10-08 20:25:38 | INFO | Files written:
#   outputs/trades_legs_20251008_202537.csv
#   outputs/trades_roundtrips_20251008_202537.csv
#   outputs/equity_20251008_202537.csv
#   outputs/metrics_20251008_202537.json
# 2025-10-08 20:25:38 | INFO |   outputs/equity_20251008_202537.png
