# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import os, json, math, warnings, logging
from dataclasses import dataclass
from typing import Dict, List, Tuple, Optional

import numpy as np
import pandas as pd

try:
    import yfinance as yf
    import matplotlib.pyplot as plt
except Exception:
    pass

warnings.filterwarnings("ignore", category=FutureWarning)

# =========================
# LOGGING
# =========================
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)
log = logging.getLogger("vwap_swing_v2_patched")

# =========================
# CONFIG
# =========================
@dataclass
class Config:
    # Data
    start_date: str = "2015-01-01"
    end_date: Optional[str] = None   # None -> uses today's date
    static_symbols: Optional[List[str]] = None
    static_symbols_path: Optional[str] = None
    cache_dir: str = "cache"
    out_dir: str   = "outputs"
    plot: bool     = True

    # Trend filters (kept)
    ema_fast: int   = 10
    ema_slow: int   = 50
    ema_htf:  int   = 200
    use_htf_trend: bool = False   # relaxed: don't require Close > EMA200

    # VWAP windows
    vwap_short: int = 5          # ~weekly
    vwap_long:  int = 10         # relaxed from 20 → easier trend pass

    # Risk (ATR + trailing)
    atr_stop_mult: float = 1.5   # stop = 1.5 * ATR(14)
    atr_rr:       float = 2.0    # initial target = stop * RR (2R)
    trail_vwap20: bool  = True   # trail under VWAP(long)
    trail_buffer: float = 0.005  # 0.5% below vwap_long

    # Portfolio / turnover control
    apply_fees: bool    = True
    initial_capital: float = 200_000.0
    max_concurrent_positions: int = 4
    deploy_cash_frac: float = 0.15   # cap daily deployment to 15% of available cash
    cooldown_days: int = 5           # relaxed from 10

    # Execution
    entry_on_next_open: bool = True
    exit_on_next_open: bool = True

    # Candidate ranking & filters
    benchmark_try: Tuple[str,...] = ("^CNX500","^CRSLDX","^NSE500","^NIFTY500","^BSE500","^NSEI")
    volar_lookback: int = 252
    filter_52w_window: int = 252
    within_pct_of_52w_high: float = 0.80  # relaxed from 0.90
    top_k_daily: int = 3                   # relaxed from 2

    # Optional guards (ON by default)
    enable_basic_liquidity: bool = True
    min_price_inr: float = 100.0
    min_avg_vol_20d: float = 150_000.0     # relaxed from 200k

    # Optional market regime via benchmark EMA200 (off by default)
    use_bench_regime: bool = False

CFG = Config()

# =========================
# FEES
# =========================
APPLY_FEES = True

def calc_fees(turnover_buy: float, turnover_sell: float) -> float:
    if not APPLY_FEES:
        return 0.0
    BROKER_PCT = 0.001
    BROKER_MIN = 5.0
    BROKER_CAP = 20.0
    STT_PCT = 0.001
    STAMP_BUY_PCT = 0.00015
    EXCH_PCT = 0.0000297
    SEBI_PCT = 0.000001
    IPFT_PCT = 0.000001
    GST_PCT = 0.18
    DP_SELL = 20.0 if turnover_sell >= 100 else 0.0

    def _broker(turnover):
        if turnover <= 0:
            return 0.0
        fee = turnover * BROKER_PCT
        fee = max(BROKER_MIN, min(fee, BROKER_CAP))
        return fee

    br_buy  = _broker(turnover_buy)
    br_sell = _broker(turnover_sell)
    stt   = STT_PCT * (turnover_buy + turnover_sell)
    stamp = STAMP_BUY_PCT * turnover_buy
    exch  = EXCH_PCT * (turnover_buy + turnover_sell)
    sebi  = SEBI_PCT * (turnover_buy + turnover_sell)
    ipft  = IPFT_PCT * (turnover_buy + turnover_sell)
    dp    = DP_SELL
    gst_base = br_buy + br_sell + dp + exch + sebi + ipft
    gst   = GST_PCT * gst_base
    return float((br_buy + br_sell) + stt + stamp + exch + sebi + ipft + dp + gst)

# =========================
# Helpers
# =========================
def ensure_dirs(*paths):
    for p in paths:
        os.makedirs(p, exist_ok=True)

def today_str():
    return pd.Timestamp.today(tz="Asia/Kolkata").strftime("%Y-%m-%d")

def load_static_symbols(static_symbols: Optional[List[str]], static_symbols_path: Optional[str]) -> List[str]:
    syms: List[str] = []
    if static_symbols and len(static_symbols) > 0:
        syms = list(static_symbols)
    elif static_symbols_path and os.path.exists(static_symbols_path):
        with open(static_symbols_path, "r") as f:
            syms = [line.strip() for line in f if line.strip()]
    else:
        raise ValueError(
            "Provide CFG.static_symbols=[...] ('.NS' suffixes) or set CFG.static_symbols_path "
            "to a file containing one symbol per line."
        )
    out = []
    for s in syms:
        s = s.strip().upper()
        if not s.endswith(".NS"):
            s = f"{s}.NS"
        out.append(s)
    seen = set()
    uniq = []
    for s in out:
        if s not in seen:
            uniq.append(s)
            seen.add(s)
    return uniq

def fetch_prices(tickers: List[str], start: str, end: Optional[str], cache_dir: str) -> Dict[str, pd.DataFrame]:
    ensure_dirs(cache_dir)
    data = {}
    end = end or today_str()
    for ticker in tickers:
        cache_path = os.path.join(cache_dir, f"{ticker.replace('^', '_')}.parquet")
        if os.path.exists(cache_path):
            try:
                df = pd.read_parquet(cache_path)
                if len(df) and pd.to_datetime(df.index[-1]).strftime("%Y-%m-%d") >= end:
                    data[ticker] = df
                    continue
            except Exception:
                pass
        try:
            df = yf.download(ticker, start=start, end=end, auto_adjust=True, progress=False, multi_level_index=False)
            if df is None or df.empty:
                continue
            df = df.rename(columns=str.title)  # Open, High, Low, Close, Volume
            df = df[['Open', 'High', 'Low', 'Close', 'Volume']].dropna()
            df.index.name = "date"
            df.to_parquet(cache_path)
            data[ticker] = df
        except Exception:
            continue
    return data

def ema(series: pd.Series, span: int) -> pd.Series:
    return series.ewm(span=span, adjust=False, min_periods=span).mean()

# -------- VWAP & ATR utilities --------
def rolling_vwap(df: pd.DataFrame, window: int) -> pd.Series:
    tp = (df["High"] + df["Low"] + df["Close"]) / 3.0
    pv = tp * df["Volume"]
    num = pv.rolling(window=window, min_periods=window).sum()
    den = df["Volume"].rolling(window=window, min_periods=window).sum()
    vwap = num / den.replace(0, np.nan)
    return vwap

def atr(high: pd.Series, low: pd.Series, close: pd.Series, length: int = 14) -> pd.Series:
    prev_close = close.shift(1)
    tr = pd.concat([(high-low).abs(), (high-prev_close).abs(), (low-prev_close).abs()], axis=1).max(axis=1)
    return tr.ewm(alpha=1/length, adjust=False, min_periods=length).mean()

def compute_indicators(df: pd.DataFrame, cfg: Config) -> pd.DataFrame:
    out = df.copy()
    # Trend context
    out["ema_fast"] = ema(out["Close"], cfg.ema_fast)
    out["ema_slow"] = ema(out["Close"], cfg.ema_slow)
    out["ema_htf"]  = ema(out["Close"], cfg.ema_htf)
    # Liquidity baseline
    out["avg_vol_20"] = out["Volume"].rolling(20).mean()

    # VWAPs (rolling proxies)
    out["vwap_5d"]  = rolling_vwap(out, cfg.vwap_short)
    out["vwap_20d"] = rolling_vwap(out, cfg.vwap_long)
    # VWAP slope proxy (short-term)
    out["vwap5_slope"] = out["vwap_5d"] - out["vwap_5d"].shift(3)

    # ATR for risk
    out["atr_14"] = atr(out["High"], out["Low"], out["Close"], 14)

    # 52w high for filter
    out["high_52w"] = out["Close"].rolling(cfg.filter_52w_window, min_periods=20).max()

    # Convenience
    out["prev_close"] = out["Close"].shift(1)
    out["prev_vwap5"] = out["vwap_5d"].shift(1)

    # Drop warmup
    return out.dropna()

def basic_liquidity_ok(row: pd.Series, cfg: Config) -> bool:
    if not cfg.enable_basic_liquidity:
        return True
    if row["Close"] < cfg.min_price_inr:
        return False
    if row["avg_vol_20"] < cfg.min_avg_vol_20d:
        return False
    return True

def simulate_ticker(ticker: str, df: pd.DataFrame, cfg: Config, bench_regime: Optional[pd.Series] = None):
    d = compute_indicators(df, cfg).copy()
    cols = [
        "ticker","side","date","price","shares","reason","signal_reason","score",
        "ema_fast","ema_slow","ema_htf","vwap_5d","vwap_20d",
        "close","high_52w"
    ]
    if d.empty:
        return pd.DataFrame(columns=cols), pd.Series(dtype=float)

    # --------- ENTRY LOGIC (VWAP 2-bar confirm) ---------
    trend_ok   = (d["ema_fast"] > d["ema_slow"])
    htf_ok     = (d["Close"] > d["ema_htf"]) if cfg.use_htf_trend else pd.Series(True, index=d.index)
    vwap_trend = (d["Close"] >= d["vwap_20d"])
    slope_ok   = (d["vwap5_slope"] > 0)
    vol_conf   = (d["Volume"] >= d["avg_vol_20"])  # defined, not gating initially

    # Two-bar confirmation above VWAP(5)
    two_above  = (d["prev_close"] >= d["prev_vwap5"]) & (d["Close"] >= d["vwap_5d"])

    # Optional market regime (benchmark Close>EMA200)
    if cfg.use_bench_regime and bench_regime is not None:
        regime = bench_regime.reindex(d.index).fillna(False)
    else:
        regime = pd.Series(True, index=d.index)

    # NOTE: omit vol_conf from the gate for now to ensure signals start flowing
    entry_signal = trend_ok & htf_ok & vwap_trend & slope_ok & two_above & regime

    # --------- EXIT INDICATORS ---------
    exit_ind = (d["Close"] < d["vwap_5d"]) | (d["ema_fast"] < d["ema_slow"])

    in_pos = False
    entry_px = stop_px = tgt_px = 0.0
    trades = []

    idx = list(d.index)
    for i in range(len(idx)-1):
        dt, nxt = idx[i], idx[i+1]
        row, nxt_row = d.loc[dt], d.loc[nxt]

        if not in_pos:
            if entry_signal.loc[dt] and basic_liquidity_ok(row, cfg):
                # Relaxed gap guard to 1%
                gap = (nxt_row["Open"] - row["Close"]) / row["Close"]
                if abs(gap) <= 0.01:
                    px = float(nxt_row["Open"] if cfg.entry_on_next_open else row["Close"])
                    sig_reason = "2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); " + \
                                 ("Close>EMA200; " if cfg.use_htf_trend else "") + "VWAP(5) slope>0"
                    score = float(1000.0*((row["ema_fast"]-row["ema_slow"])/row["Close"]))
                    trades.append({
                        "ticker": ticker, "side": "BUY", "date": nxt if cfg.entry_on_next_open else dt,
                        "price": px, "shares": 0,
                        "reason": "candidate",
                        "signal_reason": sig_reason,
                        "score": score,
                        "ema_fast": float(row["ema_fast"]), "ema_slow": float(row["ema_slow"]), "ema_htf": float(row["ema_htf"]),
                        "vwap_5d": float(row["vwap_5d"]), "vwap_20d": float(row["vwap_20d"]),
                        "close": float(row["Close"]), "high_52w": float(row["high_52w"])
                    })
                    in_pos = True
                    entry_px = px
                    # ATR-based initial stop/target (using Day 0 ATR)
                    entry_atr = float(row["atr_14"])
                    risk_pts  = cfg.atr_stop_mult * entry_atr
                    stop_px   = entry_px - risk_pts
                    tgt_px    = entry_px + (cfg.atr_rr * risk_pts)

        else:
            # --- raise trailing stop under VWAP(long) BEFORE checking next bar hits ---
            if cfg.trail_vwap20:
                trail_base = float(row["vwap_20d"])  # using current day's vwap_long
                trail_px = trail_base * (1.0 - cfg.trail_buffer)
                stop_px  = max(stop_px, trail_px)

            hit = None
            exec_date = nxt if cfg.exit_on_next_open else dt

            # Next-bar stop/target checks
            if nxt_row["Low"] <= stop_px and nxt_row["High"] >= tgt_px:
                hit, exec_price = "target", float(tgt_px)      # favorable tie-break
            elif nxt_row["Low"] <= stop_px:
                hit, exec_price = "stop", float(stop_px)
            elif nxt_row["High"] >= tgt_px:
                hit, exec_price = "target", float(tgt_px)
            elif exit_ind.loc[dt]:
                exec_price = float(nxt_row["Open"] if cfg.exit_on_next_open else row["Close"])
                hit = "vwap_or_trend_exit"

            if hit is not None:
                trades.append({
                    "ticker": ticker, "side": "SELL", "date": exec_date,
                    "price": float(exec_price), "shares": 0, "reason": hit,
                    "signal_reason": "",
                    "score": np.nan,
                    "ema_fast": float(row["ema_fast"]), "ema_slow": float(row["ema_slow"]), "ema_htf": float(row["ema_htf"]),
                    "vwap_5d": float(row["vwap_5d"]), "vwap_20d": float(row["vwap_20d"]),
                    "close": float(row["Close"]), "high_52w": float(row["high_52w"])
                })
                in_pos = False
                entry_px = stop_px = tgt_px = 0.0

    if in_pos:
        last_dt = d.index[-1]; row = d.loc[last_dt]
        trades.append({
            "ticker": ticker, "side": "SELL", "date": last_dt,
            "price": float(row["Close"]), "shares": 0, "reason": "final_close",
            "signal_reason": "",
            "score": np.nan,
            "ema_fast": float(row["ema_fast"]), "ema_slow": float(row["ema_slow"]), "ema_htf": float(row["ema_htf"]),
            "vwap_5d": float(row["vwap_5d"]), "vwap_20d": float(row["vwap_20d"]),
            "close": float(row["Close"]), "high_52w": float(row["high_52w"])
        })

    return pd.DataFrame(trades, columns=cols), pd.Series(dtype=float)

def pick_benchmark(benchmarks: Tuple[str,...], start: str, end: Optional[str], cache_dir: str) -> Tuple[str, pd.DataFrame]:
    for t in benchmarks:
        data = fetch_prices([t], start, end, cache_dir)
        df = data.get(t)
        if df is not None and not df.empty:
            log.info("Using benchmark: %s", t)
            return t, df
    idx = pd.date_range(start=start, end=end or today_str(), freq="B")
    df = pd.DataFrame({"Close": np.ones(len(idx))}, index=idx)
    log.warning("No benchmark found; using synthetic flat series.")
    return "SYNTH_BENCH", df

def compute_volar_scores(end_dt: pd.Timestamp, tickers: List[str], data_map: Dict[str,pd.DataFrame], bench_df: pd.DataFrame, lookback: int) -> Dict[str, float]:
    scores = {}
    bser = bench_df["Close"].loc[:end_dt].pct_change().dropna().iloc[-lookback:]
    for t in tickers:
        df = data_map.get(t)
        if df is None or df.empty:
            scores[t] = 0.0
            continue
        if end_dt not in df.index:
            df = df[df.index <= end_dt]
            if df.empty:
                scores[t] = 0.0
                continue
        r = df["Close"].loc[:end_dt].pct_change().dropna().iloc[-lookback:]
        common = pd.concat([r, bser], axis=1, keys=["s","b"]).dropna()
        if common.shape[0] < max(20, int(0.4*lookback)):
            scores[t] = 0.0
            continue
        excess = common["s"] - common["b"]
        vol = common["s"].std(ddof=0)
        scores[t] = 0.0 if vol <= 1e-8 else float((excess.mean() / vol) * math.sqrt(252.0))
    return scores

def markowitz_long_only(mu: np.ndarray, Sigma: np.ndarray) -> np.ndarray:
    n = len(mu)
    eps = 1e-6
    Sigma = Sigma + eps*np.eye(n)

    def solve_lambda(lmbd: float, active_mask=None):
        if active_mask is None:
            ones = np.ones(n)
            A = np.block([[2*lmbd*Sigma, ones[:,None]],[ones[None,:], np.zeros((1,1))]])
            b = np.concatenate([mu, np.array([1.0])])
            try:
                sol = np.linalg.solve(A, b)
                w = sol[:n]
            except np.linalg.LinAlgError:
                w = np.full(n, 1.0/n)
            return w
        else:
            idx = np.where(active_mask)[0]
            if len(idx)==0:
                return np.full(n, 1.0/n)
            S = Sigma[np.ix_(idx, idx)]
            o = np.ones(len(idx))
            m = mu[idx]
            A = np.block([[2*lmbd*S, o[:,None]],[o[None,:], np.zeros((1,1))]])
            b = np.concatenate([m, np.array([1.0])])
            try:
                sol = np.linalg.solve(A, b)
                w_sub = sol[:len(idx)]
            except np.linalg.LinAlgError:
                w_sub = np.full(len(idx), 1.0/len(idx))
            w = np.zeros(n)
            w[idx] = w_sub
            return w

    best_w = np.full(n, 1.0/n)
    best_sr = -1e9
    lambdas = np.logspace(-3, 3, 31)
    for lmbd in lambdas:
        active = np.ones(n, dtype=bool)
        w = None
        for _ in range(n):
            w = solve_lambda(lmbd, active_mask=active)
            neg = w < 0
            if not neg.any():
                break
            worst = np.argmin(w)
            active[worst] = False
        if w is None:
            continue
        w = np.clip(w, 0, None)
        if w.sum() <= 0:
            continue
        w = w / w.sum()
        mu_p = float(mu @ w)
        vol_p = float(np.sqrt(w @ Sigma @ w))
        if vol_p <= 1e-8:
            continue
        sr = mu_p / vol_p
        if sr > best_sr:
            best_sr = sr
            best_w = w.copy()
    return best_w

def aggregate_and_apply(all_trades: pd.DataFrame, data_map: Dict[str, pd.DataFrame], bench_df: pd.DataFrame, cfg: Config):
    if all_trades.empty:
        return all_trades, pd.Series(dtype=float), {}

    side_order = {"BUY": 0, "SELL": 1}
    all_trades = (all_trades
        .assign(_sorder=all_trades["side"].map(side_order))
        .sort_values(by=["date", "_sorder"], kind="stable")
        .drop(columns=["_sorder"])
        .reset_index(drop=True)
    )
    all_trades["date"] = pd.to_datetime(all_trades["date"])

    equity_curve = []
    dates = sorted(all_trades["date"].unique().tolist())
    cash = cfg.initial_capital
    open_positions = {}
    completed_legs = []
    last_exit: Dict[str, pd.Timestamp] = {}   # cooldown tracker

    global APPLY_FEES
    APPLY_FEES = cfg.apply_fees

    def _get_close_on(tkr, dt):
        df = data_map.get(tkr)
        if df is None or df.empty:
            return np.nan
        if dt in df.index:
            return float(df.loc[dt, "Close"])
        prev = df[df.index <= dt]
        if prev.empty:
            return np.nan
        return float(prev["Close"].iloc[-1])

    if dates:
        seed_date = pd.to_datetime(dates[0]) - pd.Timedelta(days=1)
        equity_curve.append((seed_date, float(cash)))

    for dt in dates:
        day_trades = all_trades[all_trades["date"] == dt].copy()

        # ---- SELL first ----
        for _, tr in day_trades[day_trades["side"] == "SELL"].iterrows():
            tkr = tr["ticker"]
            price = float(tr["price"])
            pos = open_positions.get(tkr)
            if pos is None:
                continue
            shares = int(pos["shares"])
            turnover_sell = shares * price
            fee = calc_fees(0.0, turnover_sell)
            pnl = (price - pos["entry_px"]) * shares
            cash += (turnover_sell - fee)
            realized = pnl - fee - pos.get("buy_fee", 0.0)
            completed_legs.append({
                "ticker": tkr, "side": "SELL", "date": dt, "price": price,
                "shares": shares, "reason": tr.get("reason",""),
                "turnover": turnover_sell, "fees_inr": fee, "pnl_inr": realized,
                "ema_fast": tr.get("ema_fast", np.nan), "ema_slow": tr.get("ema_slow", np.nan), "ema_htf": tr.get("ema_htf", np.nan),
                "vwap_5d": tr.get("vwap_5d", np.nan), "vwap_20d": tr.get("vwap_20d", np.nan),
                "close": tr.get("close", np.nan), "high_52w": tr.get("high_52w", np.nan),
                "volar": tr.get("volar", np.nan), "mvo_weight": np.nan, "alloc_inr": np.nan
            })
            last_exit[tkr] = dt  # mark cooldown
            log.info("Exit %-12s px=%8.2f shares=%6d reason=%s net=%.2f cash=%.2f",
                     tkr, price, shares, tr.get("reason",""), realized, cash)
            del open_positions[tkr]

        # ---- BUY candidates today ----
        buys_today = day_trades[day_trades["side"] == "BUY"].copy()
        # 52w filter
        if not buys_today.empty:
            keep = []
            for _, rr in buys_today.iterrows():
                df = data_map.get(rr["ticker"])
                if df is None or df.empty or dt not in df.index:
                    continue
                close = float(df.loc[dt, "Close"])
                hist = df["Close"].loc[:dt]
                window = hist.iloc[-cfg.filter_52w_window:] if len(hist)>=cfg.filter_52w_window else hist
                high_52w = float(window.max())
                if high_52w>0 and close >= cfg.within_pct_of_52w_high * high_52w:
                    keep.append(rr)
            buys_today = pd.DataFrame(keep) if keep else pd.DataFrame(columns=buys_today.columns)

        # Exclude already-held tickers
        if not buys_today.empty:
            buys_today = buys_today[~buys_today["ticker"].isin(open_positions.keys())]

        # Apply cooldown
        if not buys_today.empty and cfg.cooldown_days > 0:
            def _cool_ok(t):
                last = last_exit.get(t)
                if last is None: return True
                return (dt - last).days >= cfg.cooldown_days
            buys_today = buys_today[buys_today["ticker"].map(_cool_ok)]

        # VOLAR ranking
        if not buys_today.empty:
            tickers = buys_today["ticker"].tolist()
            volar_scores = compute_volar_scores(dt, tickers, data_map, bench_df, cfg.volar_lookback)
            buys_today["volar"] = buys_today["ticker"].map(volar_scores)
            buys_today = buys_today.sort_values("volar", ascending=False).reset_index(drop=True)

        slots = cfg.max_concurrent_positions - len(open_positions)
        selected = pd.DataFrame(columns=buys_today.columns)
        if slots > 0 and not buys_today.empty:
            selected = buys_today.head(min(cfg.top_k_daily, slots)).copy()

        if not selected.empty:
            log.info("Selected %d BUY candidates on %s:", selected.shape[0], dt.date())
            for i, rr in selected.reset_index(drop=True).iterrows():
                log.info("  %-12s volar=%6.2f rank=%d px=%8.2f", rr["ticker"], rr.get("volar",0.0), i+1, rr["price"])

            # MVO sizing
            names = selected["ticker"].tolist()
            rets = []
            for t in names:
                df_t = data_map.get(t)
                ser = df_t["Close"].loc[:dt].pct_change().dropna().iloc[-cfg.volar_lookback:]
                rets.append(ser)
            R = pd.concat(rets, axis=1)
            R.columns = names
            R = R.dropna()
            if R.empty or R.shape[0] < max(20, int(0.4*cfg.volar_lookback)) or R.shape[1] == 0:
                weights = np.full(len(names), 1.0/len(names))
            else:
                mu = R.mean().values
                Sigma = R.cov().values
                weights = markowitz_long_only(mu, Sigma)

            # Cap daily deployed cash
            deploy_cash = max(0.0, float(cash)) * float(cfg.deploy_cash_frac)

            if deploy_cash <= 0:
                log.info("No deployable cash (cap=%.0f%%) on %s", 100*cfg.deploy_cash_frac, dt.date())
            else:
                alloc = (weights / weights.sum()) * deploy_cash if weights.sum()>0 else np.full(len(names), deploy_cash/len(names))
                rank_map = {row["ticker"]: (idx+1) for idx, (_, row) in enumerate(selected.iterrows())}
                for w_amt, t in zip(alloc, names):
                    df_t = data_map[t]
                    price = float(df_t.loc[dt, "Close"] if dt in df_t.index else df_t["Close"].loc[:dt].iloc[-1])
                    shares = int(math.floor(w_amt / price))
                    if shares <= 0:
                        log.info("Skip BUY %-12s (alloc %.2f too small)", t, w_amt)
                        continue
                    turn = shares * price
                    fee = calc_fees(turn, 0.0)
                    total_cost = turn + fee
                    if total_cost > cash:
                        shares = int(math.floor((cash - fee) / price))
                        if shares <= 0:
                            log.info("Skip BUY %-12s due to cash/fees", t)
                            continue
                        turn = shares * price
                        total_cost = turn + fee
                    cash -= total_cost
                    open_positions[t] = {"entry_date": dt, "entry_px": price, "shares": shares, "buy_fee": fee, "entry_reason": "entry"}
                    row_sel = selected[selected["ticker"]==t].iloc[0]
                    volar_val = float(row_sel.get("volar", np.nan))
                    rank_pos = rank_map.get(t, np.nan)
                    high_52w = float(row_sel.get("high_52w", np.nan))
                    close_val = float(row_sel.get("close", np.nan))
                    pct_52w = (close_val / high_52w) if (high_52w and high_52w>0) else np.nan
                    mvo_weight_today = (w_amt / deploy_cash) if deploy_cash > 0 else 0.0
                    sig_reason = row_sel.get(
                        "signal_reason",
                        "2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0"
                        + ("; Close>EMA200" if CFG.use_htf_trend else "")
                    )
                    reason_text = (
                        f"{sig_reason}; 52w%={pct_52w:.1%} (>= {CFG.within_pct_of_52w_high:.0%}); "
                        f"VOLAR rank {int(rank_pos)}/{len(names)} (VOLAR={volar_val:.2f}); "
                        f"MVO weight={mvo_weight_today:.1%} of capped cash ({100*cfg.deploy_cash_frac:.0f}% of available)"
                    )
                    completed_legs.append({
                        "ticker": t, "side": "BUY", "date": dt, "price": price,
                        "shares": shares, "reason": reason_text,
                        "turnover": turn, "fees_inr": fee, "pnl_inr": 0.0,
                        "ema_fast": float(row_sel.get("ema_fast", np.nan)), "ema_slow": float(row_sel.get("ema_slow", np.nan)), "ema_htf": float(row_sel.get("ema_htf", np.nan)),
                        "vwap_5d": float(row_sel.get("vwap_5d", np.nan)), "vwap_20d": float(row_sel.get("vwap_20d", np.nan)),
                        "close": close_val, "high_52w": high_52w,
                        "volar": volar_val, "mvo_weight": float(mvo_weight_today), "alloc_inr": float(w_amt)
                    })
                    log.info("BUY %-12s px=%8.2f sh=%6d fee=%.2f cash=%.2f :: %s",
                             t, price, shares, fee, cash, reason_text)

        # MTM valuation
        mtm = 0.0
        for _tkr, pos in open_positions.items():
            px = _get_close_on(_tkr, dt)
            if not np.isnan(px):
                mtm += pos["shares"] * px
        total_equity = cash + mtm
        equity_curve.append((dt, float(total_equity)))

    eq_ser = pd.Series([e for _, e in equity_curve], index=[d for d, _ in equity_curve])
    legs_df = pd.DataFrame(completed_legs).sort_values(["date", "ticker", "side"]).reset_index(drop=True)

    # Build roundtrips
    roundtrips = []
    by_tkr_open = {}
    for _, leg in legs_df.iterrows():
        tkr = leg["ticker"]
        if leg["side"] == "BUY":
            by_tkr_open[tkr] = leg
        else:
            buy = by_tkr_open.pop(tkr, None)
            if buy is None:
                continue
            fees_total = float(buy.get("fees_inr", 0.0) + leg.get("fees_inr", 0.0))
            gross_pnl = (leg["price"] - buy["price"]) * buy["shares"]
            net_pnl   = gross_pnl - fees_total
            ret_pct   = (leg["price"] / buy["price"] - 1.0) * 100.0
            days_held = (pd.to_datetime(leg["date"]) - pd.to_datetime(buy["date"])).days
            roundtrips.append({
                "ticker": tkr,
                "entry_date": pd.to_datetime(buy["date"]),
                "entry_price": float(buy["price"]),
                "exit_date": pd.to_datetime(leg["date"]),
                "exit_price": float(leg["price"]),
                "days_held": int(days_held),
                "shares": int(buy["shares"]),
                "entry_reason": buy.get("reason",""),
                "exit_reason": leg.get("reason",""),
                "gross_pnl_inr": float(gross_pnl),
                "fees_total_inr": float(fees_total),
                "net_pnl_inr": float(net_pnl),
                "return_pct": float(ret_pct),
                "ema_fast_entry": float(buy.get("ema_fast", np.nan)),
                "ema_slow_entry": float(buy.get("ema_slow", np.nan)),
                "ema_htf_entry": float(buy.get("ema_htf", np.nan)),
                "vwap_5d_entry": float(buy.get("vwap_5d", np.nan)),
                "vwap_20d_entry": float(buy.get("vwap_20d", np.nan)),
                "close_entry": float(buy.get("close", np.nan)),
                "high_52w_entry": float(buy.get("high_52w", np.nan)),
                "volar_entry": float(buy.get("volar", np.nan)),
                "mvo_weight_entry": float(buy.get("mvo_weight", np.nan)),
                "alloc_inr_entry": float(buy.get("alloc_inr", np.nan))
            })
    trips_df = pd.DataFrame(roundtrips).sort_values(["entry_date","ticker"]).reset_index(drop=True)

    metrics = compute_metrics(eq_ser, legs_df)
    return legs_df, trips_df, eq_ser, metrics

def compute_metrics(equity: pd.Series, legs_df: pd.DataFrame):
    out = {}
    if equity is None or equity.empty:
        return out
    eq = equity.dropna()
    daily_ret = eq.pct_change().fillna(0.0)

    days = (eq.index[-1] - eq.index[0]).days or 1
    years = days / 365.25
    cagr = (eq.iloc[-1] / eq.iloc[0]) ** (1/years) - 1 if years > 0 else 0.0

    if daily_ret.std(ddof=0) > 0:
        sharpe = (daily_ret.mean() / daily_ret.std(ddof=0)) * np.sqrt(252)
    else:
        sharpe = 0.0

    cummax = eq.cummax()
    dd = (eq - cummax) / cummax
    max_dd = dd.min()

    wins = 0
    n_sells = legs_df[legs_df["side"] == "SELL"].shape[0] if legs_df is not None and not legs_df.empty else 0
    for _, r in legs_df[legs_df["side"] == "SELL"].iterrows():
        if float(r.get("pnl_inr", 0.0)) > 0:
            wins += 1
    win_rate = (wins / n_sells) * 100.0 if n_sells > 0 else 0.0

    out.update({
        "start_equity_inr": float(eq.iloc[0]),
        "final_equity_inr": float(eq.iloc[-1]),
        "cagr_pct": float(cagr * 100),
        "sharpe": float(sharpe),
        "max_drawdown_pct": float(max_dd * 100),
        "win_rate_pct": float(win_rate),
        "n_trades": int(n_sells),
    })
    return out

def plot_equity(equity: pd.Series, out_path: str):
    if equity is None or equity.empty:
        return
    try:
        import matplotlib.pyplot as plt
        plt.figure(figsize=(10,5))
        plt.plot(equity.index, equity.values)
        plt.title("Equity Curve")
        plt.xlabel("Date")
        plt.ylabel("Equity (INR)")
        plt.tight_layout()
        plt.savefig(out_path)
        plt.close()
    except Exception:
        pass

def backtest(cfg: Config):
    ensure_dirs(cfg.cache_dir, cfg.out_dir)
    log.info("Universe: loading static symbols...")
    symbols = load_static_symbols(cfg.static_symbols, cfg.static_symbols_path)
    log.info("Loaded %d symbols.", len(symbols))

    log.info("Data: fetching OHLCV from yfinance (adjusted)...")
    data_map = fetch_prices(symbols, cfg.start_date, cfg.end_date, cfg.cache_dir)
    log.info("Downloaded %d symbols with data.", len(data_map))

    bench_tkr, bench_df = pick_benchmark(cfg.benchmark_try, cfg.start_date, cfg.end_date, cfg.cache_dir)
    log.info("Benchmark selected: %s", bench_tkr)

    # Optional regime series: benchmark Close > EMA200
    bench_df = bench_df.copy()
    bench_df["ema200"] = bench_df["Close"].ewm(span=200, adjust=False, min_periods=200).mean()
    bench_regime_ser = (bench_df["Close"] > bench_df["ema200"]).astype(bool) if cfg.use_bench_regime else None

    log.info("Signals: generating VWAP/EMA logic and candidate entries...")
    all_trades = []
    for i, tkr in enumerate(symbols, 1):
        df = data_map.get(tkr)
        if df is None or df.empty:
            continue
        tr, _ = simulate_ticker(tkr, df, cfg, bench_regime=bench_regime_ser)
        if not tr.empty:
            all_trades.append(tr)
        if i % 50 == 0:
            log.info("  processed %d/%d tickers...", i, len(symbols))

    if not all_trades:
        log.warning("No signals generated; consider: set use_htf_trend=False, vwap_long=10, within_pct_of_52w_high<=0.80, cooldown_days<=5, or widen gap guard.")
        return None, None, None, {}
    all_trades = pd.concat(all_trades, ignore_index=True)

    log.info("Portfolio: cap daily deploy to %.0f%% of cash; 52w>=%.0f%% high; top-%d by VOLAᵣ; MVO; max %d positions; cooldown=%d days.",
             cfg.deploy_cash_frac*100, cfg.within_pct_of_52w_high*100, cfg.top_k_daily, cfg.max_concurrent_positions, cfg.cooldown_days)
    legs_df, trips_df, equity, metrics = aggregate_and_apply(all_trades, data_map, bench_df, cfg)

    stamp = pd.Timestamp.today(tz="Asia/Kolkata").strftime("%Y%m%d_%H%M%S")
    legs_path = os.path.join(cfg.out_dir, f"trades_legs_{stamp}.csv")
    trips_path = os.path.join(cfg.out_dir, f"trades_roundtrips_{stamp}.csv")
    equity_path = os.path.join(cfg.out_dir, f"equity_{stamp}.csv")
    metrics_path = os.path.join(cfg.out_dir, f"metrics_{stamp}.json")
    eq_plot_path = os.path.join(cfg.out_dir, f"equity_{stamp}.png")

    if legs_df is not None:
        legs_df.to_csv(legs_path, index=False)
    if trips_df is not None:
        trips_df.to_csv(trips_path, index=False)
    if equity is not None:
        pd.DataFrame({"date": equity.index, "equity": equity.values}).to_csv(equity_path, index=False)
    with open(metrics_path, "w") as f:
        json.dump(metrics, f, indent=2)

    if cfg.plot and equity is not None:
        plot_equity(equity, eq_plot_path)

    log.info("=== METRICS ===\n%s", json.dumps(metrics, indent=2))
    log.info("Files written:\n  %s\n  %s\n  %s\n  %s", legs_path, trips_path, equity_path, metrics_path)
    if cfg.plot:
        log.info("  %s", eq_plot_path)

def main():
    global APPLY_FEES
    APPLY_FEES = bool(CFG.apply_fees)
    # Example: set your universe here or via file path.
    CFG.static_symbols = ['360ONE.NS', '3MINDIA.NS', 'AADHARHFC.NS', 'AARTIIND.NS', 'AAVAS.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'ABLBL.NS', 'ABREL.NS', 'ABSLAMC.NS', 'ACC.NS', 'ACE.NS', 'ACMESOLAR.NS', 'ADANIENSOL.NS', 'ADANIENT.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'AEGISLOG.NS', 'AEGISVOPAK.NS', 'AFCONS.NS', 'AFFLE.NS', 'AGARWALEYE.NS', 'AIAENG.NS', 'AIIL.NS', 'AJANTPHARM.NS', 'AKUMS.NS', 'AKZOINDIA.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'ALOKINDS.NS', 'AMBER.NS', 'AMBUJACEM.NS', 'ANANDRATHI.NS', 'ANANTRAJ.NS', 'ANGELONE.NS', 'APARINDS.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'APOLLOHOSP.NS', 'APOLLOTYRE.NS', 'APTUS.NS', 'ARE&M.NS', 'ASAHIINDIA.NS', 'ASHOKLEY.NS', 'ASIANPAINT.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'ASTRAZEN.NS', 'ATGL.NS', 'ATHERENERG.NS', 'ATUL.NS', 'AUBANK.NS', 'AUROPHARMA.NS', 'AWL.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BAJAJHFL.NS', 'BAJAJHLDNG.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BALRAMCHIN.NS', 'BANDHANBNK.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BASF.NS', 'BATAINDIA.NS', 'BAYERCROP.NS', 'BBTC.NS', 'BDL.NS', 'BEL.NS', 'BEML.NS', 'BERGEPAINT.NS', 'BHARATFORG.NS', 'BHARTIARTL.NS', 'BHARTIHEXA.NS', 'BHEL.NS', 'BIKAJI.NS', 'BIOCON.NS', 'BLS.NS', 'BLUEDART.NS', 'BLUEJET.NS', 'BLUESTARCO.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'BSE.NS', 'BSOFT.NS', 'CAMPUS.NS', 'CAMS.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CAPLIPOINT.NS', 'CARBORUNIV.NS', 'CASTROLIND.NS', 'CCL.NS', 'CDSL.NS', 'CEATLTD.NS', 'CENTRALBK.NS', 'CENTURYPLY.NS', 'CERA.NS', 'CESC.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHALET.NS', 'CHAMBLFERT.NS', 'CHENNPETRO.NS', 'CHOICEIN.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'CIPLA.NS', 'CLEAN.NS', 'COALINDIA.NS', 'COCHINSHIP.NS', 'COFORGE.NS', 'COHANCE.NS', 'COLPAL.NS', 'CONCOR.NS', 'CONCORDBIO.NS', 'COROMANDEL.NS', 'CRAFTSMAN.NS', 'CREDITACC.NS', 'CRISIL.NS', 'CROMPTON.NS', 'CUB.NS', 'CUMMINSIND.NS', 'CYIENT.NS', 'DABUR.NS', 'DALBHARAT.NS', 'DATAPATTNS.NS', 'DBREALTY.NS', 'DCMSHRIRAM.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'DELHIVERY.NS', 'DEVYANI.NS', 'DIVISLAB.NS', 'DIXON.NS', 'DLF.NS', 'DMART.NS', 'DOMS.NS', 'DRREDDY.NS', 'ECLERX.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'EIHOTEL.NS', 'ELECON.NS', 'ELGIEQUIP.NS', 'EMAMILTD.NS', 'EMCURE.NS', 'ENDURANCE.NS', 'ENGINERSIN.NS', 'ENRIN.NS', 'ERIS.NS', 'ESCORTS.NS', 'ETERNAL.NS', 'EXIDEIND.NS', 'FACT.NS', 'FEDERALBNK.NS', 'FINCABLES.NS', 'FINPIPE.NS', 'FIRSTCRY.NS', 'FIVESTAR.NS', 'FLUOROCHEM.NS', 'FORCEMOT.NS', 'FORTIS.NS', 'FSL.NS', 'GAIL.NS', 'GESHIP.NS', 'GICRE.NS', 'GILLETTE.NS', 'GLAND.NS', 'GLAXO.NS', 'GLENMARK.NS', 'GMDCLTD.NS', 'GMRAIRPORT.NS', 'GODFRYPHLP.NS', 'GODIGIT.NS', 'GODREJAGRO.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GODREJPROP.NS', 'GPIL.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'GRAVITA.NS', 'GRSE.NS', 'GSPL.NS', 'GUJGASLTD.NS', 'GVT&D.NS', 'HAL.NS', 'HAPPSTMNDS.NS', 'HAVELLS.NS', 'HBLENGINE.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HEG.NS', 'HEROMOTOCO.NS', 'HEXT.NS', 'HFCL.NS', 'HINDALCO.NS', 'HINDCOPPER.NS', 'HINDPETRO.NS', 'HINDUNILVR.NS', 'HINDZINC.NS', 'HOMEFIRST.NS', 'HONASA.NS', 'HONAUT.NS', 'HSCL.NS', 'HUDCO.NS', 'HYUNDAI.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'IDBI.NS', 'IDEA.NS', 'IDFCFIRSTB.NS', 'IEX.NS', 'IFCI.NS', 'IGIL.NS', 'IGL.NS', 'IIFL.NS', 'IKS.NS', 'INDGN.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INDIAMART.NS', 'INDIANB.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'INFY.NS', 'INOXINDIA.NS', 'INOXWIND.NS', 'INTELLECT.NS', 'IOB.NS', 'IOC.NS', 'IPCALAB.NS', 'IRB.NS', 'IRCON.NS', 'IRCTC.NS', 'IREDA.NS', 'IRFC.NS', 'ITC.NS', 'ITCHOTELS.NS', 'ITI.NS', 'J&KBANK.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JIOFIN.NS', 'JKCEMENT.NS', 'JKTYRE.NS', 'JMFINANCIL.NS', 'JPPOWER.NS', 'JSL.NS', 'JSWENERGY.NS', 'JSWINFRA.NS', 'JSWSTEEL.NS', 'JUBLFOOD.NS', 'JUBLINGREA.NS', 'JUBLPHARMA.NS', 'JWL.NS', 'JYOTHYLAB.NS', 'JYOTICNC.NS', 'KAJARIACER.NS', 'KALYANKJIL.NS', 'KARURVYSYA.NS', 'KAYNES.NS', 'KEC.NS', 'KEI.NS', 'KFINTECH.NS', 'KIMS.NS', 'KIRLOSBROS.NS', 'KIRLOSENG.NS', 'KOTAKBANK.NS', 'KPIL.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'KSB.NS', 'LALPATHLAB.NS', 'LATENTVIEW.NS', 'LAURUSLABS.NS', 'LEMONTREE.NS', 'LICHSGFIN.NS', 'LICI.NS', 'LINDEINDIA.NS', 'LLOYDSME.NS', 'LODHA.NS', 'LT.NS', 'LTF.NS', 'LTFOODS.NS', 'LTIM.NS', 'LTTS.NS', 'LUPIN.NS', 'M&M.NS', 'M&MFIN.NS', 'MAHABANK.NS', 'MAHSCOOTER.NS', 'MAHSEAMLES.NS', 'MANAPPURAM.NS', 'MANKIND.NS', 'MANYAVAR.NS', 'MAPMYINDIA.NS', 'MARICO.NS', 'MARUTI.NS', 'MAXHEALTH.NS', 'MAZDOCK.NS', 'MCX.NS', 'MEDANTA.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MGL.NS', 'MINDACORP.NS', 'MMTC.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'MPHASIS.NS', 'MRF.NS', 'MRPL.NS', 'MSUMI.NS', 'MUTHOOTFIN.NS', 'NAM-INDIA.NS', 'NATCOPHARM.NS', 'NATIONALUM.NS', 'NAUKRI.NS', 'NAVA.NS', 'NAVINFLUOR.NS', 'NBCC.NS', 'NCC.NS', 'NESTLEIND.NS', 'NETWEB.NS', 'NEULANDLAB.NS', 'NEWGEN.NS', 'NH.NS', 'NHPC.NS', 'NIACL.NS', 'NIVABUPA.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NSLNISP.NS', 'NTPC.NS', 'NTPCGREEN.NS', 'NUVAMA.NS', 'NUVOCO.NS', 'NYKAA.NS', 'OBEROIRLTY.NS', 'OFSS.NS', 'OIL.NS', 'OLAELEC.NS', 'OLECTRA.NS', 'ONESOURCE.NS', 'ONGC.NS', 'PAGEIND.NS', 'PATANJALI.NS', 'PAYTM.NS', 'PCBL.NS', 'PERSISTENT.NS', 'PETRONET.NS', 'PFC.NS', 'PFIZER.NS', 'PGEL.NS', 'PGHH.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'PIIND.NS', 'PNB.NS', 'PNBHOUSING.NS', 'POLICYBZR.NS', 'POLYCAB.NS', 'POLYMED.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'POWERINDIA.NS', 'PPLPHARMA.NS', 'PRAJIND.NS', 'PREMIERENE.NS', 'PRESTIGE.NS', 'PTCIL.NS', 'PVRINOX.NS', 'RADICO.NS', 'RAILTEL.NS', 'RAINBOW.NS', 'RAMCOCEM.NS', 'RBLBANK.NS', 'RCF.NS', 'RECLTD.NS', 'REDINGTON.NS', 'RELIANCE.NS', 'RELINFRA.NS', 'RHIM.NS', 'RITES.NS', 'RKFORGE.NS', 'RPOWER.NS', 'RRKABEL.NS', 'RVNL.NS', 'SAGILITY.NS', 'SAIL.NS', 'SAILIFE.NS', 'SAMMAANCAP.NS', 'SAPPHIRE.NS', 'SARDAEN.NS', 'SAREGAMA.NS', 'SBFC.NS', 'SBICARD.NS', 'SBILIFE.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SCHNEIDER.NS', 'SCI.NS', 'SHREECEM.NS', 'SHRIRAMFIN.NS', 'SHYAMMETL.NS', 'SIEMENS.NS', 'SIGNATURE.NS', 'SJVN.NS', 'SKFINDIA.NS', 'SOBHA.NS', 'SOLARINDS.NS', 'SONACOMS.NS', 'SONATSOFTW.NS', 'SRF.NS', 'STARHEALTH.NS', 'SUMICHEM.NS', 'SUNDARMFIN.NS', 'SUNDRMFAST.NS', 'SUNPHARMA.NS', 'SUNTV.NS', 'SUPREMEIND.NS', 'SUZLON.NS', 'SWANCORP.NS', 'SWIGGY.NS', 'SYNGENE.NS', 'SYRMA.NS', 'TARIL.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TATAMOTORS.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TATATECH.NS', 'TBOTEK.NS', 'TCS.NS', 'TECHM.NS', 'TECHNOE.NS', 'TEJASNET.NS', 'THELEELA.NS', 'THERMAX.NS', 'TIINDIA.NS', 'TIMKEN.NS', 'TITAGARH.NS', 'TITAN.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TRENT.NS', 'TRIDENT.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TTML.NS', 'TVSMOTOR.NS', 'UBL.NS', 'UCOBANK.NS', 'ULTRACEMCO.NS', 'UNIONBANK.NS', 'UNITDSPR.NS', 'UNOMINDA.NS', 'UPL.NS', 'USHAMART.NS', 'UTIAMC.NS', 'VBL.NS', 'VEDL.NS', 'VENTIVE.NS', 'VGUARD.NS', 'VIJAYA.NS', 'VMM.NS', 'VOLTAS.NS', 'VTL.NS', 'WAAREEENER.NS', 'WELCORP.NS', 'WELSPUNLIV.NS', 'WHIRLPOOL.NS', 'WIPRO.NS', 'WOCKPHARMA.NS', 'YESBANK.NS', 'ZEEL.NS', 'ZENSARTECH.NS', 'ZENTEC.NS', 'ZFCVINDIA.NS', 'ZYDUSLIFE.NS']
    # CFG.static_symbols_path = "nifty500.txt"
    backtest(CFG)

if __name__ == "__main__":
    main()
# Out:
# 2025-10-08 10:19:08 | INFO | Universe: loading static symbols...
# 2025-10-08 10:19:08 | INFO | Loaded 500 symbols.
# 2025-10-08 10:19:08 | INFO | Data: fetching OHLCV from yfinance (adjusted)...
# 2025-10-08 10:22:15 | INFO | Downloaded 500 symbols with data.
# 2025-10-08 10:22:16 | ERROR | HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: ^CNX500"}}}
# 2025-10-08 10:22:17 | ERROR |
# 1 Failed download:
# 2025-10-08 10:22:17 | ERROR | ['^CNX500']: YFTzMissingError('possibly delisted; no timezone found')
# 2025-10-08 10:22:17 | INFO | Using benchmark: ^CRSLDX
# 2025-10-08 10:22:17 | INFO | Benchmark selected: ^CRSLDX
# 2025-10-08 10:22:17 | INFO | Signals: generating VWAP/EMA logic and candidate entries...
# 2025-10-08 10:22:21 | INFO |   processed 50/500 tickers...
# 2025-10-08 10:22:25 | INFO |   processed 100/500 tickers...
# 2025-10-08 10:22:30 | INFO |   processed 150/500 tickers...
# 2025-10-08 10:22:35 | INFO |   processed 200/500 tickers...
# 2025-10-08 10:22:39 | INFO |   processed 250/500 tickers...
# 2025-10-08 10:22:43 | INFO |   processed 300/500 tickers...
# 2025-10-08 10:22:47 | INFO |   processed 350/500 tickers...
# 2025-10-08 10:22:51 | INFO |   processed 400/500 tickers...
# 2025-10-08 10:22:55 | INFO |   processed 450/500 tickers...
# 2025-10-08 10:23:00 | INFO |   processed 500/500 tickers...
# 2025-10-08 10:23:00 | INFO | Portfolio: cap daily deploy to 15% of cash; 52w>=80% high; top-3 by VOLAᵣ; MVO; max 4 positions; cooldown=5 days.
# 2025-10-08 10:23:00 | INFO | Selected 3 BUY candidates on 2015-10-23:
# 2025-10-08 10:23:00 | INFO |   BRITANNIA.NS volar=  2.43 rank=1 px= 1441.52
# 2025-10-08 10:23:00 | INFO |   TATAELXSI.NS volar=  2.42 rank=2 px=  845.99
# 2025-10-08 10:23:00 | INFO |   CHENNPETRO.NS volar=  2.39 rank=3 px=  181.17
# 2025-10-08 10:23:00 | INFO | BUY BRITANNIA.NS px= 1418.13 sh=    11 fee=36.93 cash=184363.65 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=96.7% (>= 80%); VOLAR rank 1/3 (VOLAR=2.43); MVO weight=54.9% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY TATAELXSI.NS px=  832.18 sh=     7 fee=13.79 cash=178524.62 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=84.9% (>= 80%); VOLAR rank 2/3 (VOLAR=2.42); MVO weight=21.4% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY CHENNPETRO.NS px=  180.36 sh=    39 fee=16.65 cash=171474.06 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=91.2% (>= 80%); VOLAR rank 3/3 (VOLAR=2.39); MVO weight=23.7% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit BRITANNIA.NS px= 1405.90 shares=    11 reason=stop net=-229.34 cash=186881.07
# 2025-10-08 10:23:00 | INFO | Exit CHENNPETRO.NS px=  178.31 shares=    39 reason=stop net=-135.33 cash=193796.30
# 2025-10-08 10:23:00 | INFO | Exit TATAELXSI.NS px=  825.31 shares=     7 reason=stop net=-98.24 cash=199537.08
# 2025-10-08 10:23:00 | INFO | Selected 3 BUY candidates on 2015-10-26:
# 2025-10-08 10:23:00 | INFO |   JUBLPHARMA.NS volar=  2.55 rank=1 px=  285.31
# 2025-10-08 10:23:00 | INFO |   TORNTPHARM.NS volar=  1.26 rank=2 px=  694.65
# 2025-10-08 10:23:00 | INFO |   ZYDUSLIFE.NS volar=  1.16 rank=3 px=  406.83
# 2025-10-08 10:23:00 | INFO | BUY JUBLPHARMA.NS px=  283.18 sh=    52 fee=34.86 cash=184776.66 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/3 (VOLAR=2.55); MVO weight=50.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY TORNTPHARM.NS px=  684.74 sh=    13 fee=21.07 cash=175853.98 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=95.8% (>= 80%); VOLAR rank 2/3 (VOLAR=1.26); MVO weight=29.9% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY ZYDUSLIFE.NS px=  390.51 sh=    15 fee=13.87 cash=169982.46 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 3/3 (VOLAR=1.16); MVO weight=20.2% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit TORNTPHARM.NS px=  682.06 shares=    13 reason=vwap_or_trend_exit net=-99.15 cash=178805.99
# 2025-10-08 10:23:00 | INFO | Exit ZYDUSLIFE.NS px=  393.38 shares=    15 reason=stop net=-7.47 cash=184670.04
# 2025-10-08 10:23:00 | INFO | Selected 3 BUY candidates on 2015-10-27:
# 2025-10-08 10:23:00 | INFO |   SAMMAANCAP.NS volar=  1.99 rank=1 px=  496.17
# 2025-10-08 10:23:00 | INFO |   GODREJPROP.NS volar=  1.29 rank=2 px=  362.95
# 2025-10-08 10:23:00 | INFO |   GODREJCP.NS  volar=  1.06 rank=3 px=  396.14
# 2025-10-08 10:23:00 | INFO | BUY SAMMAANCAP.NS px=  498.00 sh=    31 fee=36.55 cash=169195.43 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=92.9% (>= 80%); VOLAR rank 1/3 (VOLAR=1.99); MVO weight=56.5% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY GODREJPROP.NS px=  360.10 sh=    17 fee=14.49 cash=163059.24 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=99.3% (>= 80%); VOLAR rank 2/3 (VOLAR=1.29); MVO weight=22.4% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY GODREJCP.NS  px=  399.39 sh=    14 fee=13.24 cash=157454.61 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=91.3% (>= 80%); VOLAR rank 3/3 (VOLAR=1.06); MVO weight=21.1% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit GODREJPROP.NS px=  353.41 shares=    17 reason=stop net=-165.12 cash=163425.69
# 2025-10-08 10:23:00 | INFO | Exit JUBLPHARMA.NS px=  274.94 shares=    52 reason=stop net=-518.88 cash=177667.23
# 2025-10-08 10:23:00 | INFO | Exit SAMMAANCAP.NS px=  490.58 shares=    31 reason=stop net=-323.98 cash=192817.86
# 2025-10-08 10:23:00 | INFO | Selected 3 BUY candidates on 2015-10-28:
# 2025-10-08 10:23:00 | INFO |   COFORGE.NS   volar=  1.44 rank=1 px=  101.07
# 2025-10-08 10:23:00 | INFO |   WOCKPHARMA.NS volar=  1.26 rank=2 px= 1457.76
# 2025-10-08 10:23:00 | INFO |   DIVISLAB.NS  volar=  1.17 rank=3 px= 1015.63
# 2025-10-08 10:23:00 | INFO | BUY COFORGE.NS   px=   99.30 sh=   136 fee=31.97 cash=179281.29 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/3 (VOLAR=1.44); MVO weight=46.8% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY WOCKPHARMA.NS px= 1470.26 sh=     5 fee=17.40 cash=171912.56 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=80.9% (>= 80%); VOLAR rank 2/3 (VOLAR=1.26); MVO weight=27.6% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY DIVISLAB.NS  px= 1026.50 sh=     7 fee=17.01 cash=164710.07 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=90.0% (>= 80%); VOLAR rank 3/3 (VOLAR=1.17); MVO weight=25.7% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit COFORGE.NS   px=   97.76 shares=   136 reason=vwap_or_trend_exit net=-293.87 cash=177952.77
# 2025-10-08 10:23:00 | INFO | Exit WOCKPHARMA.NS px= 1435.87 shares=     5 reason=stop net=-228.87 cash=185092.62
# 2025-10-08 10:23:00 | INFO | Selected 2 BUY candidates on 2015-10-30:
# 2025-10-08 10:23:00 | INFO |   INTELLECT.NS volar=  2.23 rank=1 px=  224.72
# 2025-10-08 10:23:00 | INFO |   TORNTPOWER.NS volar=  0.87 rank=2 px=  152.87
# 2025-10-08 10:23:00 | INFO | BUY INTELLECT.NS px=  229.55 sh=   116 fee=55.22 cash=158409.11 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=97.8% (>= 80%); VOLAR rank 1/2 (VOLAR=2.23); MVO weight=96.1% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY TORNTPOWER.NS px=  154.54 sh=     6 fee=7.00 cash=157474.88 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 2/2 (VOLAR=0.87); MVO weight=3.9% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit GODREJCP.NS  px=  388.03 shares=    14 reason=stop net=-207.85 cash=162871.66
# 2025-10-08 10:23:00 | INFO | Selected 1 BUY candidates on 2015-11-02:
# 2025-10-08 10:23:00 | INFO |   DRREDDY.NS   volar=  1.46 rank=1 px=  795.34
# 2025-10-08 10:23:00 | INFO | BUY DRREDDY.NS   px=  803.44 sh=    30 fee=52.22 cash=138716.17 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=98.4% (>= 80%); VOLAR rank 1/1 (VOLAR=1.46); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit DIVISLAB.NS  px= 1104.87 shares=     7 reason=target net=490.86 cash=146409.52
# 2025-10-08 10:23:00 | INFO | Exit TORNTPOWER.NS px=  151.64 shares=     6 reason=vwap_or_trend_exit net=-54.86 cash=147288.88
# 2025-10-08 10:23:00 | INFO | Selected 2 BUY candidates on 2015-11-03:
# 2025-10-08 10:23:00 | INFO |   NAVINFLUOR.NS volar=  2.72 rank=1 px=  327.82
# 2025-10-08 10:23:00 | INFO |   ZENSARTECH.NS volar=  1.52 rank=2 px=  171.18
# 2025-10-08 10:23:00 | INFO | BUY NAVINFLUOR.NS px=  330.65 sh=    47 fee=36.79 cash=131711.40 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/2 (VOLAR=2.72); MVO weight=70.9% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY ZENSARTECH.NS px=  171.89 sh=    37 fee=15.06 cash=125336.51 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=99.9% (>= 80%); VOLAR rank 2/2 (VOLAR=1.52); MVO weight=29.1% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit ZENSARTECH.NS px=  166.45 shares=    37 reason=stop net=-253.54 cash=131457.86
# 2025-10-08 10:23:00 | INFO | Selected 1 BUY candidates on 2015-11-04:
# 2025-10-08 10:23:00 | INFO |   JUBLPHARMA.NS volar=  2.59 rank=1 px=  294.97
# 2025-10-08 10:23:00 | INFO | BUY JUBLPHARMA.NS px=  290.24 sh=    67 fee=46.04 cash=111965.55 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=99.9% (>= 80%); VOLAR rank 1/1 (VOLAR=2.59); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit JUBLPHARMA.NS px=  282.79 shares=    67 reason=stop net=-610.96 cash=130846.90
# 2025-10-08 10:23:00 | INFO | Selected 1 BUY candidates on 2015-11-05:
# 2025-10-08 10:23:00 | INFO |   CHOLAFIN.NS  volar=  1.27 rank=1 px=  123.96
# 2025-10-08 10:23:00 | INFO | BUY CHOLAFIN.NS  px=  119.79 sh=   163 fee=46.22 cash=111275.52 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=89.2% (>= 80%); VOLAR rank 1/1 (VOLAR=1.27); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit CHOLAFIN.NS  px=  118.70 shares=   163 reason=stop net=-289.66 cash=130557.24
# 2025-10-08 10:23:00 | INFO | Exit DRREDDY.NS   px=  785.21 shares=    30 reason=stop net=-670.85 cash=154041.88
# 2025-10-08 10:23:00 | INFO | Exit INTELLECT.NS px=  229.28 shares=   116 reason=vwap_or_trend_exit net=-162.07 cash=180563.32
# 2025-10-08 10:23:00 | INFO | Exit NAVINFLUOR.NS px=  306.34 shares=    47 reason=stop net=-1234.82 cash=194905.99
# 2025-10-08 10:23:00 | INFO | Selected 1 BUY candidates on 2015-11-06:
# 2025-10-08 10:23:00 | INFO |   ZYDUSLIFE.NS volar=  1.11 rank=1 px=  394.94
# 2025-10-08 10:23:00 | INFO | BUY ZYDUSLIFE.NS px=  376.02 sh=    77 fee=57.98 cash=165894.47 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=96.9% (>= 80%); VOLAR rank 1/1 (VOLAR=1.11); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit ZYDUSLIFE.NS px=  384.05 shares=    77 reason=stop net=482.23 cash=195388.22
# 2025-10-08 10:23:00 | INFO | Selected 3 BUY candidates on 2015-11-10:
# 2025-10-08 10:23:00 | INFO |   MARUTI.NS    volar=  2.07 rank=1 px= 4245.12
# 2025-10-08 10:23:00 | INFO |   KEI.NS       volar=  1.83 rank=2 px=  101.23
# 2025-10-08 10:23:00 | INFO |   GODREJCP.NS  volar=  1.24 rank=3 px=  417.17
# 2025-10-08 10:23:00 | INFO | BUY MARUTI.NS    px= 4302.82 sh=     4 fee=40.75 cash=178136.18 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=98.8% (>= 80%); VOLAR rank 1/3 (VOLAR=2.07); MVO weight=64.6% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY KEI.NS       px=  101.71 sh=    48 fee=11.70 cash=173242.21 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=90.0% (>= 80%); VOLAR rank 2/3 (VOLAR=1.83); MVO weight=16.8% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY GODREJCP.NS  px=  408.37 sh=    13 fee=12.57 cash=167920.85 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=96.0% (>= 80%); VOLAR rank 3/3 (VOLAR=1.24); MVO weight=18.6% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit GODREJCP.NS  px=  396.74 shares=    13 reason=stop net=-198.75 cash=173043.46
# 2025-10-08 10:23:00 | INFO | Exit KEI.NS       px=  100.90 shares=    48 reason=stop net=-85.34 cash=177852.10
# 2025-10-08 10:23:00 | INFO | Selected 1 BUY candidates on 2015-11-16:
# 2025-10-08 10:23:00 | INFO |   M&M.NS       volar=  0.41 rank=1 px=  570.61
# 2025-10-08 10:23:00 | INFO | BUY M&M.NS       px=  583.34 sh=    45 fee=54.77 cash=151546.81 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=89.6% (>= 80%); VOLAR rank 1/1 (VOLAR=0.41); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Selected 2 BUY candidates on 2015-11-17:
# 2025-10-08 10:23:00 | INFO |   CANFINHOME.NS volar=  2.13 rank=1 px=  183.06
# 2025-10-08 10:23:00 | INFO |   GRANULES.NS  volar=  1.70 rank=2 px=  141.17
# 2025-10-08 10:23:00 | INFO | BUY CANFINHOME.NS px=  181.21 sh=    72 fee=30.89 cash=138468.98 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=97.7% (>= 80%); VOLAR rank 1/2 (VOLAR=2.13); MVO weight=57.4% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY GRANULES.NS  px=  138.24 sh=    70 fee=22.91 cash=128768.93 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=91.7% (>= 80%); VOLAR rank 2/2 (VOLAR=1.70); MVO weight=42.6% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit GRANULES.NS  px=  138.62 shares=    70 reason=stop net=-41.96 cash=138427.02
# 2025-10-08 10:23:00 | INFO | Exit MARUTI.NS    px= 4168.13 shares=     4 reason=stop net=-640.10 cash=155038.96
# 2025-10-08 10:23:00 | INFO | Selected 2 BUY candidates on 2015-11-18:
# 2025-10-08 10:23:00 | INFO |   NAVINFLUOR.NS volar=  2.89 rank=1 px=  369.49
# 2025-10-08 10:23:00 | INFO |   GODFRYPHLP.NS volar=  1.84 rank=2 px=  366.97
# 2025-10-08 10:23:00 | INFO | BUY NAVINFLUOR.NS px=  363.81 sh=    43 fee=37.04 cash=139358.18 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/2 (VOLAR=2.89); MVO weight=68.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY GODFRYPHLP.NS px=  343.09 sh=    21 fee=17.06 cash=132136.21 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 2/2 (VOLAR=1.84); MVO weight=32.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit CANFINHOME.NS px=  180.06 shares=    72 reason=vwap_or_trend_exit net=-165.61 cash=145048.42
# 2025-10-08 10:23:00 | INFO | Exit GODFRYPHLP.NS px=  335.06 shares=    21 reason=stop net=-224.93 cash=152045.46
# 2025-10-08 10:23:00 | INFO | Selected 1 BUY candidates on 2015-11-19:
# 2025-10-08 10:23:00 | INFO |   ITC.NS       volar=  0.12 rank=1 px=  168.26
# 2025-10-08 10:23:00 | INFO | BUY ITC.NS       px=  169.24 sh=   134 fee=50.53 cash=129316.11 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=88.8% (>= 80%); VOLAR rank 1/1 (VOLAR=0.12); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit NAVINFLUOR.NS px=  344.45 shares=    43 reason=stop net=-925.88 cash=144071.00
# 2025-10-08 10:23:00 | INFO | Selected 2 BUY candidates on 2015-11-20:
# 2025-10-08 10:23:00 | INFO |   NATCOPHARM.NS volar=  1.51 rank=1 px=  471.17
# 2025-10-08 10:23:00 | INFO |   DIVISLAB.NS  volar=  1.37 rank=2 px= 1067.89
# 2025-10-08 10:23:00 | INFO | BUY NATCOPHARM.NS px=  475.70 sh=    20 fee=22.52 cash=134534.57 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=97.6% (>= 80%); VOLAR rank 1/2 (VOLAR=1.51); MVO weight=44.8% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY DIVISLAB.NS  px= 1062.85 sh=    11 fee=27.68 cash=122815.56 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=94.5% (>= 80%); VOLAR rank 2/2 (VOLAR=1.37); MVO weight=55.2% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit ITC.NS       px=  163.25 shares=   134 reason=stop net=-923.20 cash=144621.71
# 2025-10-08 10:23:00 | INFO | Selected 1 BUY candidates on 2015-11-23:
# 2025-10-08 10:23:00 | INFO |   GRANULES.NS  volar=  1.84 rank=1 px=  141.55
# 2025-10-08 10:23:00 | INFO | BUY GRANULES.NS  px=  148.97 sh=   145 fee=49.25 cash=122972.37 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=92.2% (>= 80%); VOLAR rank 1/1 (VOLAR=1.84); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit DIVISLAB.NS  px= 1046.29 shares=    11 reason=stop net=-258.90 cash=134432.48
# 2025-10-08 10:23:00 | INFO | Exit M&M.NS       px=  617.05 shares=    45 reason=target net=1386.04 cash=162123.80
# 2025-10-08 10:23:00 | INFO | Exit NATCOPHARM.NS px=  523.04 shares=    20 reason=target net=877.48 cash=172537.71
# 2025-10-08 10:23:00 | INFO | Selected 3 BUY candidates on 2015-11-26:
# 2025-10-08 10:23:00 | INFO |   NAVINFLUOR.NS volar=  2.71 rank=1 px=  358.43
# 2025-10-08 10:23:00 | INFO |   JUBLPHARMA.NS volar=  2.47 rank=2 px=  288.53
# 2025-10-08 10:23:00 | INFO |   AUROPHARMA.NS volar=  1.35 rank=3 px=  791.86
# 2025-10-08 10:23:00 | INFO | BUY NAVINFLUOR.NS px=  352.19 sh=    41 fee=34.18 cash=158063.77 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=97.1% (>= 80%); VOLAR rank 1/3 (VOLAR=2.71); MVO weight=56.1% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY JUBLPHARMA.NS px=  283.63 sh=    40 fee=26.86 cash=146691.74 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=97.8% (>= 80%); VOLAR rank 2/3 (VOLAR=2.47); MVO weight=43.9% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Skip BUY AUROPHARMA.NS (alloc 0.00 too small)
# 2025-10-08 10:23:00 | INFO | Exit JUBLPHARMA.NS px=  278.80 shares=    40 reason=stop net=-268.19 cash=157795.58
# 2025-10-08 10:23:00 | INFO | Exit NAVINFLUOR.NS px=  354.46 shares=    41 reason=stop net=3.00 cash=172272.52
# 2025-10-08 10:23:00 | INFO | Selected 3 BUY candidates on 2015-11-27:
# 2025-10-08 10:23:00 | INFO |   TATAELXSI.NS volar=  2.44 rank=1 px=  848.69
# 2025-10-08 10:23:00 | INFO |   GODREJIND.NS volar=  1.10 rank=2 px=  390.79
# 2025-10-08 10:23:00 | INFO |   ASIANPAINT.NS volar=  0.71 rank=3 px=  796.52
# 2025-10-08 10:23:00 | INFO | BUY TATAELXSI.NS px=  882.46 sh=    21 fee=43.87 cash=153696.91 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=85.6% (>= 80%); VOLAR rank 1/3 (VOLAR=2.44); MVO weight=72.6% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY GODREJIND.NS px=  385.21 sh=    18 fee=16.42 cash=146746.71 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=98.6% (>= 80%); VOLAR rank 2/3 (VOLAR=1.10); MVO weight=27.4% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Skip BUY ASIANPAINT.NS (alloc 0.00 too small)
# 2025-10-08 10:23:00 | INFO | Exit GODREJIND.NS px=  381.84 shares=    18 reason=stop net=-115.85 cash=153581.06
# 2025-10-08 10:23:00 | INFO | Exit GRANULES.NS  px=  146.23 shares=   145 reason=vwap_or_trend_exit net=-515.65 cash=174714.75
# 2025-10-08 10:23:00 | INFO | Selected 3 BUY candidates on 2015-11-30:
# 2025-10-08 10:23:00 | INFO |   JBCHEPHARM.NS volar=  1.09 rank=1 px=  128.79
# 2025-10-08 10:23:00 | INFO |   GODREJCP.NS  volar=  0.93 rank=2 px=  399.40
# 2025-10-08 10:23:00 | INFO |   KOTAKBANK.NS volar=  0.54 rank=3 px=  693.19
# 2025-10-08 10:23:00 | INFO | BUY JBCHEPHARM.NS px=  124.99 sh=    83 fee=24.56 cash=164315.78 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=93.7% (>= 80%); VOLAR rank 1/3 (VOLAR=1.09); MVO weight=39.9% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY GODREJCP.NS  px=  381.91 sh=    27 fee=24.41 cash=153979.73 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=91.2% (>= 80%); VOLAR rank 2/3 (VOLAR=0.93); MVO weight=40.4% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY KOTAKBANK.NS px=  687.87 sh=     7 fee=11.62 cash=149153.01 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=94.3% (>= 80%); VOLAR rank 3/3 (VOLAR=0.54); MVO weight=19.8% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit GODREJCP.NS  px=  383.33 shares=    27 reason=stop net=-32.70 cash=159456.37
# 2025-10-08 10:23:00 | INFO | Exit JBCHEPHARM.NS px=  125.09 shares=    83 reason=stop net=-63.42 cash=169791.91
# 2025-10-08 10:23:00 | INFO | Selected 2 BUY candidates on 2015-12-01:
# 2025-10-08 10:23:00 | INFO |   GODREJPROP.NS volar=  1.03 rank=1 px=  336.50
# 2025-10-08 10:23:00 | INFO |   INDUSINDBK.NS volar=  0.76 rank=2 px=  888.90
# 2025-10-08 10:23:00 | INFO | BUY GODREJPROP.NS px=  333.95 sh=    40 fee=31.62 cash=156402.29 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=92.2% (>= 80%); VOLAR rank 1/2 (VOLAR=1.03); MVO weight=53.4% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY INDUSINDBK.NS px=  891.41 sh=    13 fee=27.43 cash=144786.57 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=96.1% (>= 80%); VOLAR rank 2/2 (VOLAR=0.76); MVO weight=46.6% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit KOTAKBANK.NS px=  677.35 shares=     7 reason=stop net=-119.72 cash=149493.57
# 2025-10-08 10:23:00 | INFO | Selected 1 BUY candidates on 2015-12-02:
# 2025-10-08 10:23:00 | INFO |   JUBLPHARMA.NS volar=  2.57 rank=1 px=  308.40
# 2025-10-08 10:23:00 | INFO | BUY JUBLPHARMA.NS px=  307.41 sh=    72 fee=49.88 cash=127310.11 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/1 (VOLAR=2.57); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit TATAELXSI.NS px=  885.59 shares=    21 reason=vwap_or_trend_exit net=-43.04 cash=145842.68
# 2025-10-08 10:23:00 | INFO | Selected 1 BUY candidates on 2015-12-03:
# 2025-10-08 10:23:00 | INFO |   INTELLECT.NS volar=  2.29 rank=1 px=  265.30
# 2025-10-08 10:23:00 | INFO | BUY INTELLECT.NS px=  261.84 sh=    83 fee=49.41 cash=124060.47 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/1 (VOLAR=2.29); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit INTELLECT.NS px=  254.82 shares=    83 reason=stop net=-701.50 cash=145141.18
# 2025-10-08 10:23:00 | INFO | Selected 1 BUY candidates on 2015-12-04:
# 2025-10-08 10:23:00 | INFO |   GODFRYPHLP.NS volar=  2.26 rank=1 px=  469.55
# 2025-10-08 10:23:00 | INFO | BUY GODFRYPHLP.NS px=  453.02 sh=    48 fee=49.42 cash=123346.60 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/1 (VOLAR=2.26); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit GODFRYPHLP.NS px=  428.38 shares=    48 reason=stop net=-1300.99 cash=143840.19
# 2025-10-08 10:23:00 | INFO | Exit GODREJPROP.NS px=  335.30 shares=    40 reason=vwap_or_trend_exit net=-30.96 cash=157198.85
# 2025-10-08 10:23:00 | INFO | Exit JUBLPHARMA.NS px=  298.81 shares=    72 reason=vwap_or_trend_exit net=-738.68 cash=178643.63
# 2025-10-08 10:23:00 | INFO | Selected 1 BUY candidates on 2015-12-07:
# 2025-10-08 10:23:00 | INFO |   HAVELLS.NS   volar=  0.50 rank=1 px=  279.34
# 2025-10-08 10:23:00 | INFO | BUY HAVELLS.NS   px=  273.46 sh=    97 fee=55.10 cash=152062.80 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=96.6% (>= 80%); VOLAR rank 1/1 (VOLAR=0.50); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit HAVELLS.NS   px=  271.92 shares=    97 reason=stop net=-279.38 cash=178364.25
# 2025-10-08 10:23:00 | INFO | Selected 1 BUY candidates on 2015-12-08:
# 2025-10-08 10:23:00 | INFO |   COFORGE.NS   volar=  1.52 rank=1 px=  103.78
# 2025-10-08 10:23:00 | INFO | BUY COFORGE.NS   px=  103.71 sh=   257 fee=55.25 cash=151654.77 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=95.9% (>= 80%); VOLAR rank 1/1 (VOLAR=1.52); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit INDUSINDBK.NS px=  879.40 shares=    13 reason=stop net=-232.42 cash=163038.07
# 2025-10-08 10:23:00 | INFO | Selected 3 BUY candidates on 2015-12-09:
# 2025-10-08 10:23:00 | INFO |   VOLTAS.NS    volar=  0.81 rank=1 px=  275.11
# 2025-10-08 10:23:00 | INFO |   INDUSTOWER.NS volar=  0.76 rank=2 px=  284.92
# 2025-10-08 10:23:00 | INFO |   ASIANPAINT.NS volar=  0.75 rank=3 px=  800.08
# 2025-10-08 10:23:00 | INFO | BUY VOLTAS.NS    px=  270.40 sh=    30 fee=19.20 cash=154906.92 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=82.0% (>= 80%); VOLAR rank 1/3 (VOLAR=0.81); MVO weight=33.9% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY INDUSTOWER.NS px=  280.09 sh=    29 fee=19.23 cash=146765.21 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=83.8% (>= 80%); VOLAR rank 2/3 (VOLAR=0.76); MVO weight=33.9% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY ASIANPAINT.NS px=  775.65 sh=    10 fee=18.36 cash=138990.32 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=93.5% (>= 80%); VOLAR rank 3/3 (VOLAR=0.75); MVO weight=32.1% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit ASIANPAINT.NS px=  782.56 shares=    10 reason=stop net=9.73 cash=146774.94
# 2025-10-08 10:23:00 | INFO | Exit INDUSTOWER.NS px=  282.66 shares=    29 reason=vwap_or_trend_exit net=13.65 cash=154930.30
# 2025-10-08 10:23:00 | INFO | Exit VOLTAS.NS    px=  269.25 shares=    30 reason=stop net=-95.17 cash=162966.28
# 2025-10-08 10:23:00 | INFO | Exit COFORGE.NS   px=  101.26 shares=   257 reason=stop net=-760.53 cash=188915.22
# 2025-10-08 10:23:00 | INFO | Selected 2 BUY candidates on 2015-12-14:
# 2025-10-08 10:23:00 | INFO |   APOLLOHOSP.NS volar=  0.99 rank=1 px= 1333.69
# 2025-10-08 10:23:00 | INFO |   HAVELLS.NS   volar=  0.64 rank=2 px=  276.93
# 2025-10-08 10:23:00 | INFO | BUY APOLLOHOSP.NS px= 1354.05 sh=    14 fee=44.88 cash=169913.66 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=92.1% (>= 80%); VOLAR rank 1/2 (VOLAR=0.99); MVO weight=70.4% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY HAVELLS.NS   px=  280.92 sh=    29 fee=19.29 cash=161747.78 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=96.8% (>= 80%); VOLAR rank 2/2 (VOLAR=0.64); MVO weight=29.6% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Selected 2 BUY candidates on 2015-12-15:
# 2025-10-08 10:23:00 | INFO |   TATAELXSI.NS volar=  2.58 rank=1 px=  958.94
# 2025-10-08 10:23:00 | INFO |   TITAGARH.NS  volar=  1.82 rank=2 px=  150.77
# 2025-10-08 10:23:00 | INFO | BUY TATAELXSI.NS px=  984.12 sh=    16 fee=37.28 cash=145964.62 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=96.9% (>= 80%); VOLAR rank 1/2 (VOLAR=2.58); MVO weight=67.1% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY TITAGARH.NS  px=  146.39 sh=    54 fee=18.71 cash=138040.65 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=94.9% (>= 80%); VOLAR rank 2/2 (VOLAR=1.82); MVO weight=32.9% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit APOLLOHOSP.NS px= 1344.33 shares=    14 reason=vwap_or_trend_exit net=-246.29 cash=156795.92
# 2025-10-08 10:23:00 | INFO | Exit TITAGARH.NS  px=  147.85 shares=    54 reason=vwap_or_trend_exit net=18.77 cash=164738.66
# 2025-10-08 10:23:00 | INFO | Selected 2 BUY candidates on 2015-12-17:
# 2025-10-08 10:23:00 | INFO |   MARUTI.NS    volar=  1.78 rank=1 px= 4245.58
# 2025-10-08 10:23:00 | INFO |   NATCOPHARM.NS volar=  1.60 rank=2 px=  502.13
# 2025-10-08 10:23:00 | INFO | BUY MARUTI.NS    px= 4260.87 sh=     4 fee=40.35 cash=147654.84 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=97.5% (>= 80%); VOLAR rank 1/2 (VOLAR=1.78); MVO weight=69.7% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY NATCOPHARM.NS px=  513.55 sh=    14 fee=17.02 cash=140448.08 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=98.9% (>= 80%); VOLAR rank 2/2 (VOLAR=1.60); MVO weight=30.3% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit NATCOPHARM.NS px=  508.02 shares=    14 reason=vwap_or_trend_exit net=-133.79 cash=147521.06
# 2025-10-08 10:23:00 | INFO | Selected 1 BUY candidates on 2015-12-21:
# 2025-10-08 10:23:00 | INFO |   VTL.NS       volar=  1.77 rank=1 px=  145.54
# 2025-10-08 10:23:00 | INFO | BUY VTL.NS       px=  145.32 sh=   152 fee=49.83 cash=125382.39 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=85.6% (>= 80%); VOLAR rank 1/1 (VOLAR=1.77); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit HAVELLS.NS   px=  281.84 shares=    29 reason=vwap_or_trend_exit net=-34.15 cash=133514.12
# 2025-10-08 10:23:00 | INFO | Exit MARUTI.NS    px= 4231.88 shares=     4 reason=vwap_or_trend_exit net=-217.44 cash=150380.51
# 2025-10-08 10:23:00 | INFO | Exit VTL.NS       px=  141.82 shares=   152 reason=vwap_or_trend_exit net=-651.57 cash=171867.60
# 2025-10-08 10:23:00 | INFO | Selected 1 BUY candidates on 2015-12-23:
# 2025-10-08 10:23:00 | INFO |   CHENNPETRO.NS volar=  1.97 rank=1 px=  162.17
# 2025-10-08 10:23:00 | INFO | BUY CHENNPETRO.NS px=  161.28 sh=   159 fee=54.05 cash=146170.38 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=82.1% (>= 80%); VOLAR rank 1/1 (VOLAR=1.97); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Selected 2 BUY candidates on 2015-12-24:
# 2025-10-08 10:23:00 | INFO |   CHOLAFIN.NS  volar=  1.33 rank=1 px=  125.86
# 2025-10-08 10:23:00 | INFO |   GODREJPROP.NS volar=  1.03 rank=2 px=  339.15
# 2025-10-08 10:23:00 | INFO | BUY CHOLAFIN.NS  px=  126.26 sh=   110 fee=32.88 cash=132248.74 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=90.9% (>= 80%); VOLAR rank 1/2 (VOLAR=1.33); MVO weight=63.5% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | BUY GODREJPROP.NS px=  336.55 sh=    23 fee=18.33 cash=124489.76 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=93.2% (>= 80%); VOLAR rank 2/2 (VOLAR=1.03); MVO weight=36.5% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit CHENNPETRO.NS px=  161.08 shares=   159 reason=vwap_or_trend_exit net=-158.65 cash=150028.34
# 2025-10-08 10:23:00 | INFO | Selected 1 BUY candidates on 2015-12-28:
# 2025-10-08 10:23:00 | INFO |   KAJARIACER.NS volar=  1.85 rank=1 px=  454.62
# 2025-10-08 10:23:00 | INFO | BUY KAJARIACER.NS px=  460.10 sh=    48 fee=49.82 cash=127893.67 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/1 (VOLAR=1.85); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:00 | INFO | Exit CHOLAFIN.NS  px=  123.59 shares=   110 reason=stop net=-380.46 cash=141434.85
# 2025-10-08 10:23:00 | INFO | Exit GODREJPROP.NS px=  332.34 shares=    23 reason=stop net=-155.67 cash=149038.16
# 2025-10-08 10:23:00 | INFO | Exit TATAELXSI.NS px= 1012.94 shares=    16 reason=vwap_or_trend_exit net=364.34 cash=165185.66
# 2025-10-08 10:23:00 | INFO | Selected 3 BUY candidates on 2015-12-29:
# 2025-10-08 10:23:01 | INFO |   AARTIIND.NS  volar=  2.01 rank=1 px=  121.32
# 2025-10-08 10:23:01 | INFO |   TITAGARH.NS  volar=  1.84 rank=2 px=  159.43
# 2025-10-08 10:23:01 | INFO |   SAMMAANCAP.NS volar=  1.72 rank=3 px=  480.08
# 2025-10-08 10:23:01 | INFO | BUY AARTIIND.NS  px=  120.94 sh=    84 fee=24.05 cash=155002.85 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=91.7% (>= 80%); VOLAR rank 1/3 (VOLAR=2.01); MVO weight=41.0% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | BUY TITAGARH.NS  px=  156.66 sh=    34 fee=12.61 cash=149663.94 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=99.8% (>= 80%); VOLAR rank 2/3 (VOLAR=1.84); MVO weight=21.9% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | BUY SAMMAANCAP.NS px=  494.05 sh=    18 fee=21.05 cash=140750.06 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=89.7% (>= 80%); VOLAR rank 3/3 (VOLAR=1.72); MVO weight=37.1% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Exit KAJARIACER.NS px=  448.68 shares=    48 reason=stop net=-667.56 cash=162217.16
# 2025-10-08 10:23:01 | INFO | Selected 1 BUY candidates on 2015-12-30:
# 2025-10-08 10:23:01 | INFO |   INTELLECT.NS volar=  2.15 rank=1 px=  259.03
# 2025-10-08 10:23:01 | INFO | BUY INTELLECT.NS px=  258.02 sh=    94 fee=52.40 cash=137911.05 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=97.0% (>= 80%); VOLAR rank 1/1 (VOLAR=2.15); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Exit INTELLECT.NS px=  258.66 shares=    94 reason=vwap_or_trend_exit net=-64.21 cash=162152.95
# 2025-10-08 10:23:01 | INFO | Selected 1 BUY candidates on 2015-12-31:
# 2025-10-08 10:23:01 | INFO |   JBCHEPHARM.NS volar=  1.02 rank=1 px=  125.28
# 2025-10-08 10:23:01 | INFO | BUY JBCHEPHARM.NS px=  125.13 sh=   194 fee=52.42 cash=137825.80 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=90.8% (>= 80%); VOLAR rank 1/1 (VOLAR=1.02); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Exit JBCHEPHARM.NS px=  125.64 shares=   194 reason=vwap_or_trend_exit net=-24.73 cash=162128.23
# 2025-10-08 10:23:01 | INFO | Selected 1 BUY candidates on 2016-01-01:
# 2025-10-08 10:23:01 | INFO |   GODFRYPHLP.NS volar=  1.85 rank=1 px=  397.28
# 2025-10-08 10:23:01 | INFO | BUY GODFRYPHLP.NS px=  408.51 sh=    59 fee=52.22 cash=137973.88 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=83.8% (>= 80%); VOLAR rank 1/1 (VOLAR=1.85); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Exit TITAGARH.NS  px=  154.95 shares=    34 reason=stop net=-106.02 cash=143206.77
# 2025-10-08 10:23:01 | INFO | Selected 1 BUY candidates on 2016-01-04:
# 2025-10-08 10:23:01 | INFO |   KAJARIACER.NS volar=  1.84 rank=1 px=  453.24
# 2025-10-08 10:23:01 | INFO | BUY KAJARIACER.NS px=  457.85 sh=    46 fee=48.61 cash=122097.22 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=99.2% (>= 80%); VOLAR rank 1/1 (VOLAR=1.84); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Exit AARTIIND.NS  px=  122.84 shares=    84 reason=vwap_or_trend_exit net=89.21 cash=132369.24
# 2025-10-08 10:23:01 | INFO | Exit KAJARIACER.NS px=  450.19 shares=    46 reason=stop net=-469.54 cash=153009.24
# 2025-10-08 10:23:01 | INFO | Exit SAMMAANCAP.NS px=  489.29 shares=    18 reason=vwap_or_trend_exit net=-149.79 cash=161773.33
# 2025-10-08 10:23:01 | INFO | Selected 3 BUY candidates on 2016-01-05:
# 2025-10-08 10:23:01 | INFO |   JUBLPHARMA.NS volar=  2.32 rank=1 px=  289.69
# 2025-10-08 10:23:01 | INFO |   GODREJCP.NS  volar=  1.06 rank=2 px=  411.20
# 2025-10-08 10:23:01 | INFO |   TORNTPOWER.NS volar=  0.89 rank=3 px=  159.19
# 2025-10-08 10:23:01 | INFO | BUY JUBLPHARMA.NS px=  288.19 sh=    62 fee=42.30 cash=143863.45 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=93.6% (>= 80%); VOLAR rank 1/3 (VOLAR=2.32); MVO weight=74.2% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | BUY GODREJCP.NS  px=  406.93 sh=    14 fee=13.49 cash=138152.94 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=94.5% (>= 80%); VOLAR rank 2/3 (VOLAR=1.06); MVO weight=24.2% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | BUY TORNTPOWER.NS px=  159.75 sh=     2 fee=6.28 cash=137827.16 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 3/3 (VOLAR=0.89); MVO weight=1.6% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Exit GODREJCP.NS  px=  403.98 shares=    14 reason=stop net=-90.98 cash=143446.69
# 2025-10-08 10:23:01 | INFO | Exit JUBLPHARMA.NS px=  283.66 shares=    62 reason=stop net=-385.64 cash=160970.94
# 2025-10-08 10:23:01 | INFO | Exit TORNTPOWER.NS px=  175.32 shares=     2 reason=target net=-4.99 cash=161291.72
# 2025-10-08 10:23:01 | INFO | Exit GODFRYPHLP.NS px=  386.41 shares=    59 reason=stop net=-1427.26 cash=184018.81
# 2025-10-08 10:23:01 | INFO | Selected 2 BUY candidates on 2016-01-07:
# 2025-10-08 10:23:01 | INFO |   SRF.NS       volar=  1.30 rank=1 px=  256.21
# 2025-10-08 10:23:01 | INFO |   TATACOMM.NS  volar=  0.24 rank=2 px=  238.63
# 2025-10-08 10:23:01 | INFO | BUY SRF.NS       px=  248.83 sh=   110 fee=56.10 cash=156591.26 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=92.3% (>= 80%); VOLAR rank 1/2 (VOLAR=1.30); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Skip BUY TATACOMM.NS  (alloc 0.00 too small)
# 2025-10-08 10:23:01 | INFO | Exit SRF.NS       px=  248.96 shares=   110 reason=vwap_or_trend_exit net=-117.03 cash=183901.78
# 2025-10-08 10:23:01 | INFO | Selected 1 BUY candidates on 2016-01-08:
# 2025-10-08 10:23:01 | INFO |   RELIANCE.NS  volar=  0.82 rank=1 px=  221.02
# 2025-10-08 10:23:01 | INFO | BUY RELIANCE.NS  px=  222.26 sh=   124 fee=56.33 cash=156284.77 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=96.5% (>= 80%); VOLAR rank 1/1 (VOLAR=0.82); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Selected 2 BUY candidates on 2016-01-11:
# 2025-10-08 10:23:01 | INFO |   GODREJIND.NS volar=  1.03 rank=1 px=  380.67
# 2025-10-08 10:23:01 | INFO |   MUTHOOTFIN.NS volar= -0.06 rank=2 px=  154.25
# 2025-10-08 10:23:01 | INFO | BUY GODREJIND.NS px=  373.96 sh=    62 fee=51.13 cash=133048.10 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=96.4% (>= 80%); VOLAR rank 1/2 (VOLAR=1.03); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Skip BUY MUTHOOTFIN.NS (alloc 0.00 too small)
# 2025-10-08 10:23:01 | INFO | Exit GODREJIND.NS px=  375.46 shares=    62 reason=stop net=-29.35 cash=156255.43
# 2025-10-08 10:23:01 | INFO | Selected 3 BUY candidates on 2016-01-12:
# 2025-10-08 10:23:01 | INFO |   KEI.NS       volar=  1.86 rank=1 px=  121.33
# 2025-10-08 10:23:01 | INFO |   CHOLAHLDNG.NS volar=  1.19 rank=2 px=  277.98
# 2025-10-08 10:23:01 | INFO |   TORNTPOWER.NS volar=  1.16 rank=3 px=  178.96
# 2025-10-08 10:23:01 | INFO | BUY KEI.NS       px=  119.23 sh=    99 fee=27.95 cash=144423.29 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/3 (VOLAR=1.86); MVO weight=50.5% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | BUY CHOLAHLDNG.NS px=  279.89 sh=    20 fee=13.25 cash=138812.33 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=98.1% (>= 80%); VOLAR rank 2/3 (VOLAR=1.19); MVO weight=24.2% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | BUY TORNTPOWER.NS px=  174.74 sh=    34 fee=14.07 cash=132857.10 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=99.9% (>= 80%); VOLAR rank 3/3 (VOLAR=1.16); MVO weight=25.4% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Exit CHOLAHLDNG.NS px=  273.41 shares=    20 reason=stop net=-178.47 cash=138289.59
# 2025-10-08 10:23:01 | INFO | Exit KEI.NS       px=  115.80 shares=    99 reason=stop net=-417.31 cash=149704.41
# 2025-10-08 10:23:01 | INFO | Exit RELIANCE.NS  px=  234.36 shares=   124 reason=target net=1365.86 cash=178687.28
# 2025-10-08 10:23:01 | INFO | Exit TORNTPOWER.NS px=  176.09 shares=    34 reason=vwap_or_trend_exit net=-4.97 cash=184637.54
# 2025-10-08 10:23:01 | INFO | Selected 2 BUY candidates on 2016-01-13:
# 2025-10-08 10:23:01 | INFO |   INDHOTEL.NS  volar=  0.30 rank=1 px=  106.55
# 2025-10-08 10:23:01 | INFO |   OBEROIRLTY.NS volar=  0.10 rank=2 px=  260.59
# 2025-10-08 10:23:01 | INFO | BUY INDHOTEL.NS  px=  105.14 sh=   263 fee=56.43 cash=156928.56 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=98.3% (>= 80%); VOLAR rank 1/2 (VOLAR=0.30); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Skip BUY OBEROIRLTY.NS (alloc 0.00 too small)
# 2025-10-08 10:23:01 | INFO | Exit INDHOTEL.NS  px=  103.83 shares=   263 reason=stop net=-477.95 cash=184159.59
# 2025-10-08 10:23:01 | INFO | Selected 2 BUY candidates on 2016-01-18:
# 2025-10-08 10:23:01 | INFO |   INFY.NS      volar=  1.02 rank=1 px=  441.72
# 2025-10-08 10:23:01 | INFO |   BERGEPAINT.NS volar=  0.51 rank=2 px=  144.59
# 2025-10-08 10:23:01 | INFO | BUY INFY.NS      px=  438.62 sh=    51 fee=50.16 cash=161739.74 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=97.3% (>= 80%); VOLAR rank 1/2 (VOLAR=1.02); MVO weight=81.7% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | BUY BERGEPAINT.NS px=  138.53 sh=    36 fee=11.82 cash=156740.70 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=95.4% (>= 80%); VOLAR rank 2/2 (VOLAR=0.51); MVO weight=18.3% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Exit BERGEPAINT.NS px=  142.13 shares=    36 reason=stop net=82.85 cash=161822.58
# 2025-10-08 10:23:01 | INFO | Exit INFY.NS      px=  439.82 shares=    51 reason=vwap_or_trend_exit net=-59.37 cash=184183.07
# 2025-10-08 10:23:01 | INFO | Selected 1 BUY candidates on 2016-01-21:
# 2025-10-08 10:23:01 | INFO |   MARICO.NS    volar=  1.38 rank=1 px=  195.35
# 2025-10-08 10:23:01 | INFO | BUY MARICO.NS    px=  188.78 sh=   146 fee=56.33 cash=156564.61 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=97.7% (>= 80%); VOLAR rank 1/1 (VOLAR=1.38); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Exit MARICO.NS    px=  190.92 shares=   146 reason=stop net=179.07 cash=184362.14
# 2025-10-08 10:23:01 | INFO | Selected 3 BUY candidates on 2016-01-27:
# 2025-10-08 10:23:01 | INFO |   BERGEPAINT.NS volar=  1.06 rank=1 px=  149.89
# 2025-10-08 10:23:01 | INFO |   RAMCOCEM.NS  volar=  0.86 rank=2 px=  374.35
# 2025-10-08 10:23:01 | INFO |   HAVELLS.NS   volar=  0.82 rank=3 px=  278.42
# 2025-10-08 10:23:01 | INFO | BUY BERGEPAINT.NS px=  153.07 sh=    92 fee=33.34 cash=170246.21 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=98.3% (>= 80%); VOLAR rank 1/3 (VOLAR=1.06); MVO weight=50.9% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | BUY RAMCOCEM.NS  px=  371.22 sh=    20 fee=17.58 cash=162804.22 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=96.9% (>= 80%); VOLAR rank 2/3 (VOLAR=0.86); MVO weight=27.4% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | BUY HAVELLS.NS   px=  278.09 sh=    21 fee=13.83 cash=156950.46 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=94.2% (>= 80%); VOLAR rank 3/3 (VOLAR=0.82); MVO weight=21.7% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Selected 1 BUY candidates on 2016-01-28:
# 2025-10-08 10:23:01 | INFO |   KAJARIACER.NS volar=  1.65 rank=1 px=  442.95
# 2025-10-08 10:23:01 | INFO | BUY KAJARIACER.NS px=  443.99 sh=    53 fee=51.54 cash=133367.18 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=96.5% (>= 80%); VOLAR rank 1/1 (VOLAR=1.65); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Exit HAVELLS.NS   px=  274.99 shares=    21 reason=vwap_or_trend_exit net=-115.39 cash=139105.55
# 2025-10-08 10:23:01 | INFO | Exit KAJARIACER.NS px=  444.79 shares=    53 reason=vwap_or_trend_exit net=-81.32 cash=162607.51
# 2025-10-08 10:23:01 | INFO | Selected 2 BUY candidates on 2016-01-29:
# 2025-10-08 10:23:01 | INFO |   CANFINHOME.NS volar=  1.68 rank=1 px=  197.88
# 2025-10-08 10:23:01 | INFO |   TORNTPOWER.NS volar=  1.20 rank=2 px=  175.38
# 2025-10-08 10:23:01 | INFO | BUY CANFINHOME.NS px=  198.78 sh=    78 fee=36.71 cash=147065.77 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=95.8% (>= 80%); VOLAR rank 1/2 (VOLAR=1.68); MVO weight=63.9% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | BUY TORNTPOWER.NS px=  186.11 sh=    47 fee=20.71 cash=138297.71 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=93.7% (>= 80%); VOLAR rank 2/2 (VOLAR=1.20); MVO weight=36.1% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Exit RAMCOCEM.NS  px=  368.86 shares=    20 reason=vwap_or_trend_exit net=-104.70 cash=145635.00
# 2025-10-08 10:23:01 | INFO | Selected 1 BUY candidates on 2016-02-02:
# 2025-10-08 10:23:01 | INFO |   INFY.NS      volar=  0.91 rank=1 px=  456.04
# 2025-10-08 10:23:01 | INFO | BUY INFY.NS      px=  455.54 sh=    47 fee=49.02 cash=124175.78 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/1 (VOLAR=0.91); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Exit BERGEPAINT.NS px=  147.31 shares=    92 reason=stop net=-616.61 cash=137675.10
# 2025-10-08 10:23:01 | INFO | Exit CANFINHOME.NS px=  186.69 shares=    78 reason=stop net=-1036.05 cash=152180.79
# 2025-10-08 10:23:01 | INFO | Selected 1 BUY candidates on 2016-02-03:
# 2025-10-08 10:23:01 | INFO |   MARICO.NS    volar=  1.31 rank=1 px=  189.68
# 2025-10-08 10:23:01 | INFO | BUY MARICO.NS    px=  189.90 sh=   120 fee=50.66 cash=129342.38 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=96.2% (>= 80%); VOLAR rank 1/1 (VOLAR=1.31); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Exit INFY.NS      px=  449.53 shares=    47 reason=vwap_or_trend_exit net=-400.43 cash=150401.17
# 2025-10-08 10:23:01 | INFO | Exit TORNTPOWER.NS px=  179.09 shares=    47 reason=stop net=-393.07 cash=158776.16
# 2025-10-08 10:23:01 | INFO | Selected 2 BUY candidates on 2016-02-04:
# 2025-10-08 10:23:01 | INFO |   CHOLAFIN.NS  volar=  1.52 rank=1 px=  125.85
# 2025-10-08 10:23:01 | INFO |   YESBANK.NS   volar=  0.19 rank=2 px=  150.88
# 2025-10-08 10:23:01 | INFO | BUY CHOLAFIN.NS  px=  129.40 sh=   184 fee=51.87 cash=134915.06 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=90.8% (>= 80%); VOLAR rank 1/2 (VOLAR=1.52); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Skip BUY YESBANK.NS   (alloc 0.00 too small)
# 2025-10-08 10:23:01 | INFO | Selected 1 BUY candidates on 2016-02-05:
# 2025-10-08 10:23:01 | INFO |   TITAN.NS     volar=  0.06 rank=1 px=  349.59
# 2025-10-08 10:23:01 | INFO | BUY TITAN.NS     px=  355.26 sh=    56 fee=47.10 cash=114973.13 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=82.5% (>= 80%); VOLAR rank 1/1 (VOLAR=0.06); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:23:01 | INFO | Selected 1 BUY candidates on 2016-02-08:
# 2025-10-08 10:23:01 | INFO |   BERGEPAINT.NS volar=  1.18 rank=1 px=  156.93
# ...
# 2025-10-08 10:24:01 | INFO | Selected 1 BUY candidates on 2025-09-05:
# 2025-10-08 10:24:01 | INFO |   LAURUSLABS.NS volar=  1.89 rank=1 px=  875.60
# 2025-10-08 10:24:01 | INFO | BUY LAURUSLABS.NS px=  880.65 sh=     7 fee=14.59 cash=37853.08 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=96.1% (>= 80%); VOLAR rank 1/1 (VOLAR=1.89); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit FORTIS.NS    px=  930.57 shares=     7 reason=stop net=-188.38 cash=44329.04
# 2025-10-08 10:24:01 | INFO | Selected 1 BUY candidates on 2025-09-08:
# 2025-10-08 10:24:01 | INFO |   KIMS.NS      volar=  1.29 rank=1 px=  744.75
# 2025-10-08 10:24:01 | INFO | BUY KIMS.NS      px=  736.00 sh=     9 fee=15.68 cash=37689.36 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=94.1% (>= 80%); VOLAR rank 1/1 (VOLAR=1.29); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit KIMS.NS      px=  741.80 shares=     9 reason=vwap_or_trend_exit net=-1.89 cash=44327.16
# 2025-10-08 10:24:01 | INFO | Selected 1 BUY candidates on 2025-09-09:
# 2025-10-08 10:24:01 | INFO |   MUTHOOTFIN.NS volar=  1.55 rank=1 px= 2918.00
# 2025-10-08 10:24:01 | INFO | BUY MUTHOOTFIN.NS px= 2942.40 sh=     2 fee=13.93 cash=38428.42 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/1 (VOLAR=1.55); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit DALBHARAT.NS px= 2387.28 shares=     1 reason=stop net=-11.60 cash=40783.72
# 2025-10-08 10:24:01 | INFO | Selected 1 BUY candidates on 2025-09-10:
# 2025-10-08 10:24:01 | INFO |   HDFCAMC.NS   volar=  1.15 rank=1 px= 5670.50
# 2025-10-08 10:24:01 | INFO | BUY HDFCAMC.NS   px= 5804.50 sh=     1 fee=13.74 cash=34965.48 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=95.9% (>= 80%); VOLAR rank 1/1 (VOLAR=1.15); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit ASTERDM.NS   px=  624.49 shares=    12 reason=stop net=-5.78 cash=42419.12
# 2025-10-08 10:24:01 | INFO | Exit MUTHOOTFIN.NS px= 2899.00 shares=     2 reason=vwap_or_trend_exit net=-137.19 cash=48180.67
# 2025-10-08 10:24:01 | INFO | Selected 2 BUY candidates on 2025-09-12:
# 2025-10-08 10:24:01 | INFO |   CHOICEIN.NS  volar=  2.13 rank=1 px=  819.70
# 2025-10-08 10:24:01 | INFO |   INDIANB.NS   volar=  1.41 rank=2 px=  695.85
# 2025-10-08 10:24:01 | INFO | BUY CHOICEIN.NS  px=  817.45 sh=     7 fee=13.55 cash=42444.97 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=99.6% (>= 80%); VOLAR rank 1/2 (VOLAR=2.13); MVO weight=82.4% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | BUY INDIANB.NS   px=  697.75 sh=     1 fee=6.73 cash=41740.49 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 2/2 (VOLAR=1.41); MVO weight=17.6% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit LAURUSLABS.NS px=  896.30 shares=     7 reason=vwap_or_trend_exit net=57.44 cash=47977.08
# 2025-10-08 10:24:01 | INFO | Selected 1 BUY candidates on 2025-09-15:
# 2025-10-08 10:24:01 | INFO |   BAJFINANCE.NS volar=  1.26 rank=1 px=  999.00
# 2025-10-08 10:24:01 | INFO | BUY BAJFINANCE.NS px= 1009.85 sh=     7 fee=16.74 cash=40891.39 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/1 (VOLAR=1.26); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit HDFCAMC.NS   px= 5767.50 shares=     1 reason=vwap_or_trend_exit net=-87.13 cash=46622.51
# 2025-10-08 10:24:01 | INFO | Selected 1 BUY candidates on 2025-09-16:
# 2025-10-08 10:24:01 | INFO |   GVT&D.NS     volar=  1.53 rank=1 px= 2853.00
# 2025-10-08 10:24:01 | INFO | BUY GVT&D.NS     px= 2924.60 sh=     2 fee=13.85 cash=40759.46 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=97.9% (>= 80%); VOLAR rank 1/1 (VOLAR=1.53); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit BAJFINANCE.NS px=  991.00 shares=     7 reason=vwap_or_trend_exit net=-187.67 cash=47657.48
# 2025-10-08 10:24:01 | INFO | Exit CHOICEIN.NS  px=  820.00 shares=     7 reason=vwap_or_trend_exit net=-32.02 cash=53361.15
# 2025-10-08 10:24:01 | INFO | Exit GVT&D.NS     px= 3111.92 shares=     2 reason=target net=323.39 cash=59547.58
# 2025-10-08 10:24:01 | INFO | Exit INDIANB.NS   px=  701.00 shares=     1 reason=vwap_or_trend_exit net=-33.71 cash=60218.35
# 2025-10-08 10:24:01 | INFO | Selected 3 BUY candidates on 2025-09-19:
# 2025-10-08 10:24:01 | INFO |   LTF.NS       volar=  1.26 rank=1 px=  247.04
# 2025-10-08 10:24:01 | INFO |   AFFLE.NS     volar=  1.09 rank=2 px= 2104.80
# 2025-10-08 10:24:01 | INFO |   KPRMILL.NS   volar=  0.94 rank=3 px= 1120.00
# 2025-10-08 10:24:01 | INFO | BUY LTF.NS       px=  246.70 sh=    16 fee=10.59 cash=56260.57 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/3 (VOLAR=1.26); MVO weight=46.4% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | BUY AFFLE.NS     px= 2145.20 sh=     1 fee=8.45 cash=54106.92 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=98.1% (>= 80%); VOLAR rank 2/3 (VOLAR=1.09); MVO weight=28.2% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | BUY KPRMILL.NS   px= 1133.45 sh=     2 fee=8.59 cash=51831.43 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=85.8% (>= 80%); VOLAR rank 3/3 (VOLAR=0.94); MVO weight=25.4% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Selected 1 BUY candidates on 2025-09-22:
# 2025-10-08 10:24:01 | INFO |   LAURUSLABS.NS volar=  1.83 rank=1 px=  937.30
# 2025-10-08 10:24:01 | INFO | BUY LAURUSLABS.NS px=  903.80 sh=     8 fee=17.12 cash=44583.91 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/1 (VOLAR=1.83); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit AFFLE.NS     px= 2070.65 shares=     1 reason=stop net=-114.65 cash=46622.91
# 2025-10-08 10:24:01 | INFO | Exit LAURUSLABS.NS px=  906.11 shares=     8 reason=stop net=-38.30 cash=53832.13
# 2025-10-08 10:24:01 | INFO | Selected 2 BUY candidates on 2025-09-23:
# 2025-10-08 10:24:01 | INFO |   ASTERDM.NS   volar=  1.62 rank=1 px=  644.00
# 2025-10-08 10:24:01 | INFO |   CANBK.NS     volar=  0.81 rank=2 px=  118.77
# 2025-10-08 10:24:01 | INFO | BUY ASTERDM.NS   px=  636.60 sh=     9 fee=13.56 cash=48089.17 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=99.7% (>= 80%); VOLAR rank 1/2 (VOLAR=1.62); MVO weight=78.7% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | BUY CANBK.NS     px=  121.90 sh=    14 fee=7.93 cash=46374.64 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 2/2 (VOLAR=0.81); MVO weight=21.3% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit LTF.NS       px=  246.00 shares=    16 reason=vwap_or_trend_exit net=-55.37 cash=50277.06
# 2025-10-08 10:24:01 | INFO | Selected 1 BUY candidates on 2025-09-24:
# 2025-10-08 10:24:01 | INFO |   MUTHOOTFIN.NS volar=  1.73 rank=1 px= 3049.90
# 2025-10-08 10:24:01 | INFO | BUY MUTHOOTFIN.NS px= 3088.30 sh=     2 fee=14.62 cash=44085.83 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/1 (VOLAR=1.73); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit ASTERDM.NS   px=  635.40 shares=     9 reason=vwap_or_trend_exit net=-60.64 cash=49768.15
# 2025-10-08 10:24:01 | INFO | Exit KPRMILL.NS   px= 1102.95 shares=     2 reason=vwap_or_trend_exit net=-101.38 cash=51942.26
# 2025-10-08 10:24:01 | INFO | Selected 2 BUY candidates on 2025-09-25:
# 2025-10-08 10:24:01 | INFO |   SYRMA.NS     volar=  1.42 rank=1 px=  860.00
# 2025-10-08 10:24:01 | INFO |   MFSL.NS      volar=  1.39 rank=2 px= 1586.00
# 2025-10-08 10:24:01 | INFO | BUY SYRMA.NS     px=  835.30 sh=     3 fee=8.88 cash=49427.49 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/2 (VOLAR=1.42); MVO weight=33.0% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | BUY MFSL.NS      px= 1565.60 sh=     3 fee=11.48 cash=44719.21 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=95.5% (>= 80%); VOLAR rank 2/2 (VOLAR=1.39); MVO weight=67.0% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit CANBK.NS     px=  117.90 shares=    14 reason=stop net=-95.10 cash=46338.64
# 2025-10-08 10:24:01 | INFO | Exit MFSL.NS      px= 1559.74 shares=     3 reason=stop net=-63.40 cash=50983.52
# 2025-10-08 10:24:01 | INFO | Exit SYRMA.NS     px=  824.03 shares=     3 reason=stop net=-74.75 cash=53423.54
# 2025-10-08 10:24:01 | INFO | Selected 3 BUY candidates on 2025-09-26:
# 2025-10-08 10:24:01 | INFO |   INDIANB.NS   volar=  1.58 rank=1 px=  711.05
# 2025-10-08 10:24:01 | INFO |   CUB.NS       volar=  1.11 rank=2 px=  212.80
# 2025-10-08 10:24:01 | INFO |   NAM-INDIA.NS volar=  0.89 rank=3 px=  859.00
# 2025-10-08 10:24:01 | INFO | BUY INDIANB.NS   px=  706.35 sh=     6 fee=10.93 cash=49174.51 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/3 (VOLAR=1.58); MVO weight=53.4% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | BUY CUB.NS       px=  207.65 sh=    11 fee=8.61 cash=46881.75 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=93.1% (>= 80%); VOLAR rank 2/3 (VOLAR=1.11); MVO weight=29.7% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | BUY NAM-INDIA.NS px=  855.90 sh=     1 fee=6.92 cash=46018.93 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=98.7% (>= 80%); VOLAR rank 3/3 (VOLAR=0.89); MVO weight=16.9% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit CUB.NS       px=  206.68 shares=    11 reason=stop net=-51.15 cash=48260.54
# 2025-10-08 10:24:01 | INFO | Exit INDIANB.NS   px=  709.55 shares=     6 reason=vwap_or_trend_exit net=-25.65 cash=52483.92
# 2025-10-08 10:24:01 | INFO | Exit MUTHOOTFIN.NS px= 3029.60 shares=     2 reason=vwap_or_trend_exit net=-169.06 cash=58506.09
# 2025-10-08 10:24:01 | INFO | Selected 2 BUY candidates on 2025-09-29:
# 2025-10-08 10:24:01 | INFO |   RBLBANK.NS   volar=  1.05 rank=1 px=  274.00
# 2025-10-08 10:24:01 | INFO |   NLCINDIA.NS  volar=  0.49 rank=2 px=  280.30
# 2025-10-08 10:24:01 | INFO | BUY RBLBANK.NS   px=  277.80 sh=    31 fee=20.39 cash=49873.90 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=98.9% (>= 80%); VOLAR rank 1/2 (VOLAR=1.05); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Skip BUY NLCINDIA.NS  (alloc 0.00 too small)
# 2025-10-08 10:24:01 | INFO | Selected 2 BUY candidates on 2025-09-30:
# 2025-10-08 10:24:01 | INFO |   TATAINVEST.NS volar=  1.42 rank=1 px= 8903.50
# 2025-10-08 10:24:01 | INFO |   ASHOKLEY.NS  volar=  1.16 rank=2 px=  143.13
# 2025-10-08 10:24:01 | INFO | Skip BUY TATAINVEST.NS (alloc 4474.18 too small)
# 2025-10-08 10:24:01 | INFO | BUY ASHOKLEY.NS  px=  142.67 sh=    21 fee=9.46 cash=46868.37 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=98.9% (>= 80%); VOLAR rank 2/2 (VOLAR=1.16); MVO weight=40.2% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit RBLBANK.NS   px=  270.75 shares=    31 reason=stop net=-281.08 cash=55219.48
# 2025-10-08 10:24:01 | INFO | Selected 2 BUY candidates on 2025-10-01:
# 2025-10-08 10:24:01 | INFO |   SBIN.NS      volar=  0.88 rank=1 px=  872.30
# 2025-10-08 10:24:01 | INFO |   BANKBARODA.NS volar=  0.63 rank=2 px=  259.80
# 2025-10-08 10:24:01 | INFO | BUY SBIN.NS      px=  864.10 sh=     9 fee=18.41 cash=47424.17 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/2 (VOLAR=0.88); MVO weight=95.3% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | BUY BANKBARODA.NS px=  259.60 sh=     1 fee=6.21 cash=47158.36 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 2/2 (VOLAR=0.63); MVO weight=4.7% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit ASHOKLEY.NS  px=  141.23 shares=    21 reason=vwap_or_trend_exit net=-72.27 cash=50091.61
# 2025-10-08 10:24:01 | INFO | Exit SBIN.NS      px=  864.10 shares=     9 reason=vwap_or_trend_exit net=-59.26 cash=57827.67
# 2025-10-08 10:24:01 | INFO | Selected 2 BUY candidates on 2025-10-02:
# 2025-10-08 10:24:01 | INFO |   FORTIS.NS    volar=  1.94 rank=1 px=  989.65
# 2025-10-08 10:24:01 | INFO |   BEL.NS       volar=  1.61 rank=2 px=  406.50
# 2025-10-08 10:24:01 | INFO | BUY FORTIS.NS    px=  989.65 sh=     5 fee=11.78 cash=52867.64 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/2 (VOLAR=1.94); MVO weight=58.4% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | BUY BEL.NS       px=  406.50 sh=     8 fee=9.76 cash=49605.88 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=94.3% (>= 80%); VOLAR rank 2/2 (VOLAR=1.61); MVO weight=41.6% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit FORTIS.NS    px= 1051.70 shares=     5 reason=target net=263.19 cash=54829.10
# 2025-10-08 10:24:01 | INFO | Selected 1 BUY candidates on 2025-10-06:
# 2025-10-08 10:24:01 | INFO |   GVT&D.NS     volar=  1.83 rank=1 px= 3193.00
# 2025-10-08 10:24:01 | INFO | BUY GVT&D.NS     px= 3145.90 sh=     2 fee=14.90 cash=48522.40 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 1/1 (VOLAR=1.83); MVO weight=100.0% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Exit BANKBARODA.NS px=  261.85 shares=     1 reason=final_close net=-33.73 cash=48754.48
# 2025-10-08 10:24:01 | INFO | Exit BEL.NS       px=  410.30 shares=     8 reason=final_close net=-12.27 cash=52003.98
# 2025-10-08 10:24:01 | INFO | Exit GVT&D.NS     px= 3097.90 shares=     2 reason=final_close net=-148.23 cash=58162.44
# 2025-10-08 10:24:01 | INFO | Exit NAM-INDIA.NS px=  876.00 shares=     1 reason=vwap_or_trend_exit net=-17.23 cash=59008.03
# 2025-10-08 10:24:01 | INFO | Selected 3 BUY candidates on 2025-10-07:
# 2025-10-08 10:24:01 | INFO |   PAYTM.NS     volar=  1.67 rank=1 px= 1230.30
# 2025-10-08 10:24:01 | INFO |   POONAWALLA.NS volar=  0.98 rank=2 px=  531.50
# 2025-10-08 10:24:01 | INFO |   TVSMOTOR.NS  volar=  0.96 rank=3 px= 3509.00
# 2025-10-08 10:24:01 | INFO | BUY PAYTM.NS     px= 1237.60 sh=     3 fee=10.31 cash=55284.92 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=95.0% (>= 80%); VOLAR rank 1/3 (VOLAR=1.67); MVO weight=47.6% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | BUY POONAWALLA.NS px=  537.00 sh=     2 fee=7.18 cash=54203.74 :: 2-bar confirm above VWAP(5); EMA10>EMA50; Close≥VWAP(10); VWAP(5) slope>0; 52w%=100.0% (>= 80%); VOLAR rank 2/3 (VOLAR=0.98); MVO weight=17.1% of capped cash (15% of available)
# 2025-10-08 10:24:01 | INFO | Skip BUY TVSMOTOR.NS  (alloc 3126.06 too small)
# 2025-10-08 10:24:02 | INFO | === METRICS ===
# {
#   "start_equity_inr": 200000.0,
#   "final_equity_inr": 58990.54466214839,
#   "cagr_pct": -11.53654441209696,
#   "sharpe": -1.969262501515206,
#   "max_drawdown_pct": -70.60805649427421,
#   "win_rate_pct": 26.701400195376102,
#   "n_trades": 3071
# }
# 2025-10-08 10:24:02 | INFO | Files written:
#   outputs/trades_legs_20251008_102402.csv
#   outputs/trades_roundtrips_20251008_102402.csv
#   outputs/equity_20251008_102402.csv
#   outputs/metrics_20251008_102402.json
# 2025-10-08 10:24:02 | INFO |   outputs/equity_20251008_102402.png
