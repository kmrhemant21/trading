# %%
import pandas as pd
import yfinance as yf
import talib
from datetime import datetime

# List of all TA-Lib candlestick pattern functions
PATTERNS = {
    'CDL2CROWS': talib.CDL2CROWS,
    'CDL3BLACKCROWS': talib.CDL3BLACKCROWS,
    'CDL3INSIDE': talib.CDL3INSIDE,
    'CDL3LINESTRIKE': talib.CDL3LINESTRIKE,
    'CDL3OUTSIDE': talib.CDL3OUTSIDE,
    'CDL3STARSINSOUTH': talib.CDL3STARSINSOUTH,
    'CDL3WHITESOLDIERS': talib.CDL3WHITESOLDIERS,
    'CDLABANDONEDBABY': talib.CDLABANDONEDBABY,
    'CDLADVANCEBLOCK': talib.CDLADVANCEBLOCK,
    'CDLBELTHOLD': talib.CDLBELTHOLD,
    'CDLBREAKAWAY': talib.CDLBREAKAWAY,
    'CDLCLOSINGMARUBOZU': talib.CDLCLOSINGMARUBOZU,
    'CDLCONCEALBABYSWALL': talib.CDLCONCEALBABYSWALL,
    'CDLCOUNTERATTACK': talib.CDLCOUNTERATTACK,
    'CDLDARKCLOUDCOVER': talib.CDLDARKCLOUDCOVER,
    'CDLDOJI': talib.CDLDOJI,
    'CDLDOJISTAR': talib.CDLDOJISTAR,
    'CDLDRAGONFLYDOJI': talib.CDLDRAGONFLYDOJI,
    'CDLENGULFING': talib.CDLENGULFING,
    'CDLEVENINGDOJISTAR': talib.CDLEVENINGDOJISTAR,
    'CDLEVENINGSTAR': talib.CDLEVENINGSTAR,
    'CDLGAPSIDESIDEWHITE': talib.CDLGAPSIDESIDEWHITE,
    'CDLGRAVESTONEDOJI': talib.CDLGRAVESTONEDOJI,
    'CDLHAMMER': talib.CDLHAMMER,
    'CDLHANGINGMAN': talib.CDLHANGINGMAN,
    'CDLHARAMI': talib.CDLHARAMI,
    'CDLHARAMICROSS': talib.CDLHARAMICROSS,
    'CDLHIGHWAVE': talib.CDLHIGHWAVE,
    'CDLHIKKAKE': talib.CDLHIKKAKE,
    'CDLHIKKAKEMOD': talib.CDLHIKKAKEMOD,
    'CDLHOMINGPIGEON': talib.CDLHOMINGPIGEON,
    'CDLIDENTICAL3CROWS': talib.CDLIDENTICAL3CROWS,
    'CDLINNECK': talib.CDLINNECK,
    'CDLINVERTEDHAMMER': talib.CDLINVERTEDHAMMER,
    'CDLKICKING': talib.CDLKICKING,
    'CDLKICKINGBYLENGTH': talib.CDLKICKINGBYLENGTH,
    'CDLLADDERBOTTOM': talib.CDLLADDERBOTTOM,
    'CDLLONGLEGGEDDOJI': talib.CDLLONGLEGGEDDOJI,
    'CDLLONGLINE': talib.CDLLONGLINE,
    'CDLMARUBOZU': talib.CDLMARUBOZU,
    'CDLMATCHINGLOW': talib.CDLMATCHINGLOW,
    'CDLMATHOLD': talib.CDLMATHOLD,
    'CDLMORNINGDOJISTAR': talib.CDLMORNINGDOJISTAR,
    'CDLMORNINGSTAR': talib.CDLMORNINGSTAR,
    'CDLONNECK': talib.CDLONNECK,
    'CDLPIERCING': talib.CDLPIERCING,
    'CDLRICKSHAWMAN': talib.CDLRICKSHAWMAN,
    'CDLRISEFALL3METHODS': talib.CDLRISEFALL3METHODS,
    'CDLSEPARATINGLINES': talib.CDLSEPARATINGLINES,
    'CDLSHOOTINGSTAR': talib.CDLSHOOTINGSTAR,
    'CDLSHORTLINE': talib.CDLSHORTLINE,
    'CDLSPINNINGTOP': talib.CDLSPINNINGTOP,
    'CDLSTALLEDPATTERN': talib.CDLSTALLEDPATTERN,
    'CDLSTICKSANDWICH': talib.CDLSTICKSANDWICH,
    'CDLTAKURI': talib.CDLTAKURI,
    'CDLTASUKIGAP': talib.CDLTASUKIGAP,
    'CDLTHRUSTING': talib.CDLTHRUSTING,
    'CDLTRISTAR': talib.CDLTRISTAR,
    'CDLUNIQUE3RIVER': talib.CDLUNIQUE3RIVER,
    'CDLUPSIDEGAP2CROWS': talib.CDLUPSIDEGAP2CROWS,
    'CDLXSIDEGAP3METHODS': talib.CDLXSIDEGAP3METHODS
}

# Priority hierarchy: higher absolute value means higher priority
# Negative for bearish, positive for bullish
PATTERN_PRIORITY = {
    # High priority bearish
    'CDLEVENINGSTAR': -10,
    'CDLEVENINGDOJISTAR': -10,
    'CDL3BLACKCROWS': -9,
    'CDLABANDONEDBABY': -9,
    'CDLDARKCLOUDCOVER': -8,
    'CDLENGULFING': -7,  # Bearish version
    # Medium priority bearish
    'CDLBELTHOLD': -6,
    'CDLSHOOTINGSTAR': -5,
    'CDLHANGINGMAN': -5,
    'CDLUPSIDEGAP2CROWS': -4,
    # Low priority bearish
    'CDLDOJI': -3,
    'CDLDOJISTAR': -3,
    'CDLGRAVESTONEDOJI': -2,
    'CDLHIKKAKE': -1,  # Bearish version

    # High priority bullish
    'CDLMORNINGSTAR': 10,
    'CDLMORNINGDOJISTAR': 10,
    'CDL3WHITESOLDIERS': 9,
    'CDLABANDONEDBABY': 9,  # Bullish version
    'CDLPIERCING': 8,
    'CDLENGULFING': 7,  # Bullish version
    # Medium priority bullish
    'CDLHAMMER': 6,
    'CDLINVERTEDHAMMER': 5,
    'CDLDRAGONFLYDOJI': 5,
    'CDLHOMINGPIGEON': 4,
    # Low priority bullish
    'CDLDOJI': 3,
    'CDLDOJISTAR': 3,
    'CDLTAKURI': 2,
    'CDLHIKKAKE': 1,  # Bullish version

    # Add other patterns with appropriate priorities (e.g., -5 to 5)
    'CDL2CROWS': -4,
    'CDL3INSIDE': -3,  # Adjust based on bearish/bullish
    'CDL3LINESTRIKE': -6,
    'CDL3OUTSIDE': -5,
    'CDL3STARSINSOUTH': 4,
    'CDLADVANCEBLOCK': 4,
    'CDLBREAKAWAY': -4,
    'CDLCLOSINGMARUBOZU': -3,
    'CDLCONCEALBABYSWALL': 5,
    'CDLCOUNTERATTACK': -3,
    'CDLGAPSIDESIDEWHITE': -2,
    'CDLHARAMI': 3,
    'CDLHARAMICROSS': 3,
    'CDLHIGHWAVE': -1,
    'CDLHIKKAKEMOD': 2,
    'CDLIDENTICAL3CROWS': -4,
    'CDLINNECK': -2,
    'CDLKICKING': -5,
    'CDLKICKINGBYLENGTH': -5,
    'CDLLADDERBOTTOM': 4,
    'CDLLONGLEGGEDDOJI': -1,
    'CDLLONGLINE': -2,
    'CDLMARUBOZU': -3,
    'CDLMATCHINGLOW': 3,
    'CDLMATHOLD': 4,
    'CDLONNECK': -2,
    'CDLRICKSHAWMAN': -1,
    'CDLRISEFALL3METHODS': 3,
    'CDLSEPARATINGLINES': -3,
    'CDLSHORTLINE': -1,
    'CDLSPINNINGTOP': -1,
    'CDLSTALLEDPATTERN': -3,
    'CDLSTICKSANDWICH': 3,
    'CDLTASUKIGAP': 2,
    'CDLTHRUSTING': -2,
    'CDLTRISTAR': -3,
    'CDLUNIQUE3RIVER': 3,
    'CDLXSIDEGAP3METHODS': -3
}

# Full list of base tickers from user query
BASE_TICKERS = ['BIOCON']

# Create full tickers list with .NS suffix
TICKERS = [ticker + ".NS" for ticker in BASE_TICKERS]

def download_data(ticker, start="2023-01-01", end=None):
    """Download OHLCV data using yfinance."""
    if end is None:
        end = datetime.today().strftime('%Y-%m-%d')
    df = yf.download(ticker, start=start, end=end, interval="5m", progress=False, multi_level_index=False, auto_adjust=True)
    df.dropna(inplace=True)
    return df

def detect_patterns(df):
    """Detect all patterns and return a DataFrame with pattern values."""
    pattern_df = pd.DataFrame(index=df.index)
    for name, func in PATTERNS.items():
        pattern_df[name] = func(df['Open'], df['High'], df['Low'], df['Close'])
    return pattern_df

def prioritize_signals(pattern_df, date=None):
    """Prioritize signals based on pattern strength."""
    if date is None:
        date = pattern_df.index[-1]  # Latest date
    row = pattern_df.loc[date]
    
    signals = []
    for pattern, value in row.items():
        if value != 0:
            priority = PATTERN_PRIORITY.get(pattern, 0)  # Default 0 if not in priority list
            direction = 1 if value > 0 else -1
            score = abs(priority) * direction
            signals.append((pattern, score))
    
    if signals:
        # Sort by absolute score descending (highest priority first)
        signals.sort(key=lambda x: abs(x[1]), reverse=True)
        top_pattern, top_score = signals[0]
        if top_score > 0:
            return f"Bullish {top_pattern} detected - Go Long (Priority Score: {top_score})"
        elif top_score < 0:
            return f"Bearish {top_pattern} detected - Go Short (Priority Score: {top_score})"
    return "No patterns detected or neutral signal"

if __name__ == "__main__":
    # User inputs (optional: adjust start date)
    start_date = "2025-08-20"  # Adjust as needed
    end_date = None  # Today

    # List to hold results
    results = []

    # Loop through all tickers
    for ticker in TICKERS:
        try:
            # Download data
            df = download_data(ticker, start=start_date, end=end_date)
            
            if df.empty:
                results.append({"Ticker": ticker, "Date": "N/A", "Signal": "No data available"})
                continue

            # Detect patterns
            patterns = detect_patterns(df)

            # Get prioritized signal
            priority_signal = prioritize_signals(patterns)

            # Append to results
            results.append({"Ticker": ticker, "Date": str(patterns.index[-1].date()), "Signal": priority_signal})
        except Exception as e:
            results.append({"Ticker": ticker, "Date": "N/A", "Signal": f"Error: {str(e)}"})

    # Create DataFrame and print
    results_df = pd.DataFrame(results)  # Convert results list to DataFrame
    print(results_df.to_string(index=False))
    results_df.to_csv("pattern_signals.csv", index=False)  # Save DataFrame to CSV
# Out:
#    Ticker       Date                                                       Signal
# BIOCON.NS 2025-09-05 Bearish CDLBELTHOLD detected - Go Short (Priority Score: -6)

# %%
import pandas as pd
import yfinance as yf
import talib
from datetime import datetime, timedelta

# List of all TA-Lib candlestick pattern functions (same as before)
PATTERNS = {
    'CDL2CROWS': talib.CDL2CROWS,
    'CDL3BLACKCROWS': talib.CDL3BLACKCROWS,
    'CDL3INSIDE': talib.CDL3INSIDE,
    'CDL3LINESTRIKE': talib.CDL3LINESTRIKE,
    'CDL3OUTSIDE': talib.CDL3OUTSIDE,
    'CDL3STARSINSOUTH': talib.CDL3STARSINSOUTH,
    'CDL3WHITESOLDIERS': talib.CDL3WHITESOLDIERS,
    'CDLABANDONEDBABY': talib.CDLABANDONEDBABY,
    'CDLADVANCEBLOCK': talib.CDLADVANCEBLOCK,
    'CDLBELTHOLD': talib.CDLBELTHOLD,
    'CDLBREAKAWAY': talib.CDLBREAKAWAY,
    'CDLCLOSINGMARUBOZU': talib.CDLCLOSINGMARUBOZU,
    'CDLCONCEALBABYSWALL': talib.CDLCONCEALBABYSWALL,
    'CDLCOUNTERATTACK': talib.CDLCOUNTERATTACK,
    'CDLDARKCLOUDCOVER': talib.CDLDARKCLOUDCOVER,
    'CDLDOJI': talib.CDLDOJI,
    'CDLDOJISTAR': talib.CDLDOJISTAR,
    'CDLDRAGONFLYDOJI': talib.CDLDRAGONFLYDOJI,
    'CDLENGULFING': talib.CDLENGULFING,
    'CDLEVENINGDOJISTAR': talib.CDLEVENINGDOJISTAR,
    'CDLEVENINGSTAR': talib.CDLEVENINGSTAR,
    'CDLGAPSIDESIDEWHITE': talib.CDLGAPSIDESIDEWHITE,
    'CDLGRAVESTONEDOJI': talib.CDLGRAVESTONEDOJI,
    'CDLHAMMER': talib.CDLHAMMER,
    'CDLHANGINGMAN': talib.CDLHANGINGMAN,
    'CDLHARAMI': talib.CDLHARAMI,
    'CDLHARAMICROSS': talib.CDLHARAMICROSS,
    'CDLHIGHWAVE': talib.CDLHIGHWAVE,
    'CDLHIKKAKE': talib.CDLHIKKAKE,
    'CDLHIKKAKEMOD': talib.CDLHIKKAKEMOD,
    'CDLHOMINGPIGEON': talib.CDLHOMINGPIGEON,
    'CDLIDENTICAL3CROWS': talib.CDLIDENTICAL3CROWS,
    'CDLINNECK': talib.CDLINNECK,
    'CDLINVERTEDHAMMER': talib.CDLINVERTEDHAMMER,
    'CDLKICKING': talib.CDLKICKING,
    'CDLKICKINGBYLENGTH': talib.CDLKICKINGBYLENGTH,
    'CDLLADDERBOTTOM': talib.CDLLADDERBOTTOM,
    'CDLLONGLEGGEDDOJI': talib.CDLLONGLEGGEDDOJI,
    'CDLLONGLINE': talib.CDLLONGLINE,
    'CDLMARUBOZU': talib.CDLMARUBOZU,
    'CDLMATCHINGLOW': talib.CDLMATCHINGLOW,
    'CDLMATHOLD': talib.CDLMATHOLD,
    'CDLMORNINGDOJISTAR': talib.CDLMORNINGDOJISTAR,
    'CDLMORNINGSTAR': talib.CDLMORNINGSTAR,
    'CDLONNECK': talib.CDLONNECK,
    'CDLPIERCING': talib.CDLPIERCING,
    'CDLRICKSHAWMAN': talib.CDLRICKSHAWMAN,
    'CDLRISEFALL3METHODS': talib.CDLRISEFALL3METHODS,
    'CDLSEPARATINGLINES': talib.CDLSEPARATINGLINES,
    'CDLSHOOTINGSTAR': talib.CDLSHOOTINGSTAR,
    'CDLSHORTLINE': talib.CDLSHORTLINE,
    'CDLSPINNINGTOP': talib.CDLSPINNINGTOP,
    'CDLSTALLEDPATTERN': talib.CDLSTALLEDPATTERN,
    'CDLSTICKSANDWICH': talib.CDLSTICKSANDWICH,
    'CDLTAKURI': talib.CDLTAKURI,
    'CDLTASUKIGAP': talib.CDLTASUKIGAP,
    'CDLTHRUSTING': talib.CDLTHRUSTING,
    'CDLTRISTAR': talib.CDLTRISTAR,
    'CDLUNIQUE3RIVER': talib.CDLUNIQUE3RIVER,
    'CDLUPSIDEGAP2CROWS': talib.CDLUPSIDEGAP2CROWS,
    'CDLXSIDEGAP3METHODS': talib.CDLXSIDEGAP3METHODS
}

# Priority hierarchy (same as before)
PATTERN_PRIORITY = {
    'CDLEVENINGSTAR': -10,
    'CDLEVENINGDOJISTAR': -10,
    'CDL3BLACKCROWS': -9,
    'CDLABANDONEDBABY': -9,
    'CDLDARKCLOUDCOVER': -8,
    'CDLENGULFING': -7,
    'CDLBELTHOLD': -6,
    'CDLSHOOTINGSTAR': -5,
    'CDLHANGINGMAN': -5,
    'CDLUPSIDEGAP2CROWS': -4,
    'CDLDOJI': -3,
    'CDLDOJISTAR': -3,
    'CDLGRAVESTONEDOJI': -2,
    'CDLHIKKAKE': -1,
    'CDLMORNINGSTAR': 10,
    'CDLMORNINGDOJISTAR': 10,
    'CDL3WHITESOLDIERS': 9,
    'CDLABANDONEDBABY': 9,
    'CDLPIERCING': 8,
    'CDLENGULFING': 7,
    'CDLHAMMER': 6,
    'CDLINVERTEDHAMMER': 5,
    'CDLDRAGONFLYDOJI': 5,
    'CDLHOMINGPIGEON': 4,
    'CDLDOJI': 3,
    'CDLDOJISTAR': 3,
    'CDLTAKURI': 2,
    'CDLHIKKAKE': 1,
    'CDL2CROWS': -4,
    'CDL3INSIDE': -3,
    'CDL3LINESTRIKE': -6,
    'CDL3OUTSIDE': -5,
    'CDL3STARSINSOUTH': 4,
    'CDLADVANCEBLOCK': 4,
    'CDLBREAKAWAY': -4,
    'CDLCLOSINGMARUBOZU': -3,
    'CDLCONCEALBABYSWALL': 5,
    'CDLCOUNTERATTACK': -3,
    'CDLGAPSIDESIDEWHITE': -2,
    'CDLHARAMI': 3,
    'CDLHARAMICROSS': 3,
    'CDLHIGHWAVE': -1,
    'CDLHIKKAKEMOD': 2,
    'CDLIDENTICAL3CROWS': -4,
    'CDLINNECK': -2,
    'CDLKICKING': -5,
    'CDLKICKINGBYLENGTH': -5,
    'CDLLADDERBOTTOM': 4,
    'CDLLONGLEGGEDDOJI': -1,
    'CDLLONGLINE': -2,
    'CDLMARUBOZU': -3,
    'CDLMATCHINGLOW': 3,
    'CDLMATHOLD': 4,
    'CDLONNECK': -2,
    'CDLRICKSHAWMAN': -1,
    'CDLRISEFALL3METHODS': 3,
    'CDLSEPARATINGLINES': -3,
    'CDLSHORTLINE': -1,
    'CDLSPINNINGTOP': -1,
    'CDLSTALLEDPATTERN': -3,
    'CDLSTICKSANDWICH': 3,
    'CDLTASUKIGAP': 2,
    'CDLTHRUSTING': -2,
    'CDLTRISTAR': -3,
    'CDLUNIQUE3RIVER': 3,
    'CDLXSIDEGAP3METHODS': -3
}

# Tickers (same as before)
BASE_TICKERS = ['ADANIENT', 'ADANIPORTS', 'APOLLOHOSP', 'ASIANPAINT', 'AXISBANK', 'BAJAJ-AUTO', 'BAJFINANCE', 'BAJAJFINSV', 'BEL', 'BHARTIARTL', 'CIPLA', 'COALINDIA', 'DRREDDY', 'EICHERMOT', 'ETERNAL', 'GRASIM', 'HCLTECH', 'HDFCBANK', 'HDFCLIFE', 'HEROMOTOCO', 'HINDALCO', 'HINDUNILVR', 'ICICIBANK', 'ITC', 'INDUSINDBK', 'INFY', 'JSWSTEEL', 'JIOFIN', 'KOTAKBANK', 'LT', 'M&M', 'MARUTI', 'NTPC', 'NESTLEIND', 'ONGC', 'POWERGRID', 'RELIANCE', 'SBILIFE', 'SHRIRAMFIN', 'SBIN', 'SUNPHARMA', 'TCS', 'TATACONSUM', 'TATAMOTORS', 'TATASTEEL', 'TECHM', 'TITAN', 'TRENT', 'ULTRACEMCO', 'WIPRO']
TICKERS = [ticker + ".NS" for ticker in BASE_TICKERS]

def download_data(ticker, start="2022-01-01", end=None):
    if end is None:
        end = datetime.today().strftime('%Y-%m-%d')
    df = yf.download(ticker, start=start, end=end, progress=False, auto_adjust=True, multi_level_index=False)
    df.dropna(inplace=True)
    return df

def detect_patterns(df):
    pattern_df = pd.DataFrame(index=df.index)
    for name, func in PATTERNS.items():
        pattern_df[name] = func(df['Open'], df['High'], df['Low'], df['Close'])
    return pattern_df

def get_signal(pattern_df, df, date, adx_threshold=25, adx_period=14):
    if date not in pattern_df.index or len(df.loc[:date]) < adx_period:
        return None, None
    
    row = pattern_df.loc[date]
    
    adx = talib.ADX(df['High'][:date], df['Low'][:date], df['Close'][:date], timeperiod=adx_period)[-1]
    
    if adx <= adx_threshold:
        return None, adx
    
    signals = []
    for pattern, value in row.items():
        if value != 0:
            priority = PATTERN_PRIORITY.get(pattern, 0)
            direction = 1 if value > 0 else -1
            score = abs(priority) * direction
            signals.append((pattern, score))
    
    if signals:
        signals.sort(key=lambda x: abs(x[1]), reverse=True)
        top_pattern, top_score = signals[0]
        if top_score > 0:
            return "long", adx
        elif top_score < 0:
            return "short", adx
    return None, adx

def backtest_strategy(df, max_hold_days=10, adx_threshold=25, adx_period=14):
    pattern_df = detect_patterns(df)
    trades = []
    position = None  # 'long' or 'short'
    entry_date = None
    entry_price = None
    
    dates = df.index[adx_period:]  # Start after enough data for ADX
    
    for i, date in enumerate(dates):
        signal, adx = get_signal(pattern_df, df, date, adx_threshold, adx_period)
        
        # Check for exit (opposite signal or max hold)
        if position:
            days_held = (date - entry_date).days
            opposite_signal = (position == 'long' and signal == 'short') or (position == 'short' and signal == 'long')
            if opposite_signal or days_held >= max_hold_days:
                # Exit on next day's open if available
                exit_idx = i + 1
                if exit_idx < len(dates):
                    exit_date = dates[exit_idx]
                    exit_price = df['Open'][exit_date]
                    if position == 'long':
                        pnl = exit_price - entry_price
                    else:  # short
                        pnl = entry_price - exit_price
                    trades.append({
                        'ticker': df.ticker if hasattr(df, 'ticker') else 'Unknown',
                        'entry_date': entry_date,
                        'action': position,
                        'entry_price': entry_price,
                        'exit_date': exit_date,
                        'exit_price': exit_price,
                        'pnl': pnl
                    })
                    position = None
        
        # Check for entry
        if not position and signal:
            # Enter on next day's open if available
            entry_idx = i + 1
            if entry_idx < len(dates):
                entry_date = dates[entry_idx]
                entry_price = df['Open'][entry_date]
                position = signal
    
    # Close any open position at the end
    if position:
        exit_date = df.index[-1]
        exit_price = df['Close'][-1]  # Use close if no next open
        if position == 'long':
            pnl = exit_price - entry_price
        else:
            pnl = entry_price - exit_price
        trades.append({
            'ticker': df.ticker if hasattr(df, 'ticker') else 'Unknown',
            'entry_date': entry_date,
            'action': position,
            'entry_price': entry_price,
            'exit_date': exit_date,
            'exit_price': exit_price,
            'pnl': pnl
        })
    
    return trades

if __name__ == "__main__":
    start_date = "2022-01-01"
    end_date = None  # Today
    max_hold_days = 10
    adx_threshold = 25
    adx_period = 14
    
    all_trades = []
    for ticker in TICKERS[:5]:  # Limit to first 5 tickers for speed; remove slice for all
        try:
            df = download_data(ticker, start=start_date, end=end_date)
            if df.empty:
                continue
            df.ticker = ticker  # Add ticker for reference
            trades = backtest_strategy(df, max_hold_days, adx_threshold, adx_period)
            all_trades.extend(trades)
        except Exception as e:
            print(f"Error for {ticker}: {e}")
    
    # Print trades
    print("Trades Taken:")
    for trade in all_trades:
        print(f"Ticker: {trade['ticker']}, Entry Date: {trade['entry_date'].date()}, Action: {trade['action'].upper()} (Buy for long, Sell for short), Entry Price: {trade['entry_price']:.2f}, Exit Date: {trade['exit_date'].date()}, Exit Price: {trade['exit_price']:.2f}, P&L: {trade['pnl']:.2f}")
    
    # Summary metrics
    if all_trades:
        total_trades = len(all_trades)
        wins = sum(1 for t in all_trades if t['pnl'] > 0)
        win_pct = (wins / total_trades) * 100 if total_trades > 0 else 0
        total_pnl = sum(t['pnl'] for t in all_trades)
        print(f"\nSummary: Total Trades: {total_trades}, Win Percentage: {win_pct:.2f}%, Total P&L: {total_pnl:.2f}")
    else:
        print("No trades generated.")
# Out:
# /var/folders/mn/tx231v5158797chnp22wm9000000gp/T/ipykernel_63255/2074742764.py:164: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   adx = talib.ADX(df['High'][:date], df['Low'][:date], df['Close'][:date], timeperiod=adx_period)[-1]
# /var/folders/mn/tx231v5158797chnp22wm9000000gp/T/ipykernel_63255/2074742764.py:235: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   exit_price = df['Close'][-1]  # Use close if no next open
# /var/folders/mn/tx231v5158797chnp22wm9000000gp/T/ipykernel_63255/2074742764.py:164: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   adx = talib.ADX(df['High'][:date], df['Low'][:date], df['Close'][:date], timeperiod=adx_period)[-1]
# /var/folders/mn/tx231v5158797chnp22wm9000000gp/T/ipykernel_63255/2074742764.py:164: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   adx = talib.ADX(df['High'][:date], df['Low'][:date], df['Close'][:date], timeperiod=adx_period)[-1]
# /var/folders/mn/tx231v5158797chnp22wm9000000gp/T/ipykernel_63255/2074742764.py:164: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   adx = talib.ADX(df['High'][:date], df['Low'][:date], df['Close'][:date], timeperiod=adx_period)[-1]
# Trades Taken:
# Ticker: ADANIENT.NS, Entry Date: 2022-01-25, Action: SHORT (Buy for long, Sell for short), Entry Price: 1664.94, Exit Date: 2022-01-27, Exit Price: 1714.84, P&L: -49.91
# Ticker: ADANIENT.NS, Entry Date: 2022-01-27, Action: LONG (Buy for long, Sell for short), Entry Price: 1714.84, Exit Date: 2022-01-28, Exit Price: 1699.37, P&L: -15.47
# Ticker: ADANIENT.NS, Entry Date: 2022-01-28, Action: SHORT (Buy for long, Sell for short), Entry Price: 1699.37, Exit Date: 2022-02-03, Exit Price: 1768.69, P&L: -69.32
# Ticker: ADANIENT.NS, Entry Date: 2022-02-03, Action: LONG (Buy for long, Sell for short), Entry Price: 1768.69, Exit Date: 2022-02-08, Exit Price: 1736.20, P&L: -32.49
# Ticker: ADANIENT.NS, Entry Date: 2022-02-08, Action: SHORT (Buy for long, Sell for short), Entry Price: 1736.20, Exit Date: 2022-02-10, Exit Price: 1795.69, P&L: -59.49
# Ticker: ADANIENT.NS, Entry Date: 2022-02-10, Action: LONG (Buy for long, Sell for short), Entry Price: 1795.69, Exit Date: 2022-02-22, Exit Price: 1633.09, P&L: -162.60
# Ticker: ADANIENT.NS, Entry Date: 2022-03-07, Action: SHORT (Buy for long, Sell for short), Entry Price: 1587.08, Exit Date: 2022-03-10, Exit Price: 1678.91, P&L: -91.83
# Ticker: ADANIENT.NS, Entry Date: 2022-03-10, Action: LONG (Buy for long, Sell for short), Entry Price: 1678.91, Exit Date: 2022-03-22, Exit Price: 1799.64, P&L: 120.73
# Ticker: ADANIENT.NS, Entry Date: 2022-04-07, Action: LONG (Buy for long, Sell for short), Entry Price: 2161.97, Exit Date: 2022-04-08, Exit Price: 2111.11, P&L: -50.86
# Ticker: ADANIENT.NS, Entry Date: 2022-04-08, Action: SHORT (Buy for long, Sell for short), Entry Price: 2111.11, Exit Date: 2022-04-11, Exit Price: 2177.84, P&L: -66.73
# Ticker: ADANIENT.NS, Entry Date: 2022-04-11, Action: LONG (Buy for long, Sell for short), Entry Price: 2177.84, Exit Date: 2022-04-20, Exit Price: 2174.00, P&L: -3.84
# Ticker: ADANIENT.NS, Entry Date: 2022-04-20, Action: SHORT (Buy for long, Sell for short), Entry Price: 2174.00, Exit Date: 2022-04-21, Exit Price: 2211.93, P&L: -37.93
# Ticker: ADANIENT.NS, Entry Date: 2022-04-21, Action: LONG (Buy for long, Sell for short), Entry Price: 2211.93, Exit Date: 2022-04-25, Exit Price: 2255.80, P&L: 43.87
# Ticker: ADANIENT.NS, Entry Date: 2022-04-25, Action: SHORT (Buy for long, Sell for short), Entry Price: 2255.80, Exit Date: 2022-04-26, Exit Price: 2292.78, P&L: -36.98
# Ticker: ADANIENT.NS, Entry Date: 2022-04-26, Action: LONG (Buy for long, Sell for short), Entry Price: 2292.78, Exit Date: 2022-04-28, Exit Price: 2355.51, P&L: 62.73
# Ticker: ADANIENT.NS, Entry Date: 2022-04-28, Action: SHORT (Buy for long, Sell for short), Entry Price: 2355.51, Exit Date: 2022-04-29, Exit Price: 2384.61, P&L: -29.10
# Ticker: ADANIENT.NS, Entry Date: 2022-04-29, Action: LONG (Buy for long, Sell for short), Entry Price: 2384.61, Exit Date: 2022-05-02, Exit Price: 2320.73, P&L: -63.88
# Ticker: ADANIENT.NS, Entry Date: 2022-05-02, Action: SHORT (Buy for long, Sell for short), Entry Price: 2320.73, Exit Date: 2022-05-06, Exit Price: 2205.94, P&L: 114.79
# Ticker: ADANIENT.NS, Entry Date: 2022-05-06, Action: LONG (Buy for long, Sell for short), Entry Price: 2205.94, Exit Date: 2022-05-17, Exit Price: 2129.13, P&L: -76.81
# Ticker: ADANIENT.NS, Entry Date: 2022-05-17, Action: LONG (Buy for long, Sell for short), Entry Price: 2129.13, Exit Date: 2022-05-19, Exit Price: 2141.06, P&L: 11.93
# Ticker: ADANIENT.NS, Entry Date: 2022-05-19, Action: SHORT (Buy for long, Sell for short), Entry Price: 2141.06, Exit Date: 2022-05-23, Exit Price: 2227.65, P&L: -86.59
# Ticker: ADANIENT.NS, Entry Date: 2022-05-23, Action: LONG (Buy for long, Sell for short), Entry Price: 2227.65, Exit Date: 2022-06-03, Exit Price: 2230.89, P&L: 3.24
# Ticker: ADANIENT.NS, Entry Date: 2022-07-26, Action: LONG (Buy for long, Sell for short), Entry Price: 2551.39, Exit Date: 2022-07-28, Exit Price: 2556.28, P&L: 4.89
# Ticker: ADANIENT.NS, Entry Date: 2022-07-28, Action: SHORT (Buy for long, Sell for short), Entry Price: 2556.28, Exit Date: 2022-07-29, Exit Price: 2561.38, P&L: -5.09
# Ticker: ADANIENT.NS, Entry Date: 2022-07-29, Action: LONG (Buy for long, Sell for short), Entry Price: 2561.38, Exit Date: 2022-08-01, Exit Price: 2572.21, P&L: 10.83
# Ticker: ADANIENT.NS, Entry Date: 2022-08-01, Action: SHORT (Buy for long, Sell for short), Entry Price: 2572.21, Exit Date: 2022-08-02, Exit Price: 2656.24, P&L: -84.03
# Ticker: ADANIENT.NS, Entry Date: 2022-08-02, Action: LONG (Buy for long, Sell for short), Entry Price: 2656.24, Exit Date: 2022-08-04, Exit Price: 2721.15, P&L: 64.91
# Ticker: ADANIENT.NS, Entry Date: 2022-08-04, Action: SHORT (Buy for long, Sell for short), Entry Price: 2721.15, Exit Date: 2022-08-05, Exit Price: 2756.10, P&L: -34.95
# Ticker: ADANIENT.NS, Entry Date: 2022-08-05, Action: LONG (Buy for long, Sell for short), Entry Price: 2756.10, Exit Date: 2022-08-08, Exit Price: 2696.19, P&L: -59.92
# Ticker: ADANIENT.NS, Entry Date: 2022-08-08, Action: SHORT (Buy for long, Sell for short), Entry Price: 2696.19, Exit Date: 2022-08-10, Exit Price: 2797.79, P&L: -101.61
# Ticker: ADANIENT.NS, Entry Date: 2022-08-10, Action: LONG (Buy for long, Sell for short), Entry Price: 2797.79, Exit Date: 2022-08-12, Exit Price: 2835.99, P&L: 38.20
# Ticker: ADANIENT.NS, Entry Date: 2022-08-12, Action: SHORT (Buy for long, Sell for short), Entry Price: 2835.99, Exit Date: 2022-08-16, Exit Price: 2874.93, P&L: -38.94
# Ticker: ADANIENT.NS, Entry Date: 2022-08-16, Action: LONG (Buy for long, Sell for short), Entry Price: 2874.93, Exit Date: 2022-08-22, Exit Price: 3129.57, P&L: 254.64
# Ticker: ADANIENT.NS, Entry Date: 2022-08-22, Action: SHORT (Buy for long, Sell for short), Entry Price: 3129.57, Exit Date: 2022-08-24, Exit Price: 3033.71, P&L: 95.86
# Ticker: ADANIENT.NS, Entry Date: 2022-08-24, Action: LONG (Buy for long, Sell for short), Entry Price: 3033.71, Exit Date: 2022-08-26, Exit Price: 3075.65, P&L: 41.94
# Ticker: ADANIENT.NS, Entry Date: 2022-08-26, Action: SHORT (Buy for long, Sell for short), Entry Price: 3075.65, Exit Date: 2022-08-29, Exit Price: 3050.68, P&L: 24.96
# Ticker: ADANIENT.NS, Entry Date: 2022-08-29, Action: LONG (Buy for long, Sell for short), Entry Price: 3050.68, Exit Date: 2022-09-01, Exit Price: 3195.48, P&L: 144.80
# Ticker: ADANIENT.NS, Entry Date: 2022-09-01, Action: SHORT (Buy for long, Sell for short), Entry Price: 3195.48, Exit Date: 2022-09-02, Exit Price: 3256.39, P&L: -60.91
# Ticker: ADANIENT.NS, Entry Date: 2022-09-02, Action: LONG (Buy for long, Sell for short), Entry Price: 3256.39, Exit Date: 2022-09-05, Exit Price: 3369.33, P&L: 112.94
# Ticker: ADANIENT.NS, Entry Date: 2022-09-05, Action: SHORT (Buy for long, Sell for short), Entry Price: 3369.33, Exit Date: 2022-09-07, Exit Price: 3430.95, P&L: -61.61
# Ticker: ADANIENT.NS, Entry Date: 2022-09-07, Action: LONG (Buy for long, Sell for short), Entry Price: 3430.95, Exit Date: 2022-09-09, Exit Price: 3474.08, P&L: 43.14
# Ticker: ADANIENT.NS, Entry Date: 2022-09-09, Action: SHORT (Buy for long, Sell for short), Entry Price: 3474.08, Exit Date: 2022-09-13, Exit Price: 3473.09, P&L: 1.00
# Ticker: ADANIENT.NS, Entry Date: 2022-09-13, Action: LONG (Buy for long, Sell for short), Entry Price: 3473.09, Exit Date: 2022-09-19, Exit Price: 3713.70, P&L: 240.61
# Ticker: ADANIENT.NS, Entry Date: 2022-09-19, Action: SHORT (Buy for long, Sell for short), Entry Price: 3713.70, Exit Date: 2022-09-23, Exit Price: 3726.73, P&L: -13.03
# Ticker: ADANIENT.NS, Entry Date: 2022-09-23, Action: LONG (Buy for long, Sell for short), Entry Price: 3726.73, Exit Date: 2022-09-26, Exit Price: 3641.15, P&L: -85.58
# Ticker: ADANIENT.NS, Entry Date: 2022-09-26, Action: SHORT (Buy for long, Sell for short), Entry Price: 3641.15, Exit Date: 2022-09-29, Exit Price: 3578.44, P&L: 62.71
# Ticker: ADANIENT.NS, Entry Date: 2022-09-29, Action: LONG (Buy for long, Sell for short), Entry Price: 3578.44, Exit Date: 2022-09-30, Exit Price: 3443.08, P&L: -135.36
# Ticker: ADANIENT.NS, Entry Date: 2022-09-30, Action: SHORT (Buy for long, Sell for short), Entry Price: 3443.08, Exit Date: 2022-10-06, Exit Price: 3265.38, P&L: 177.70
# Ticker: ADANIENT.NS, Entry Date: 2022-10-06, Action: LONG (Buy for long, Sell for short), Entry Price: 3265.38, Exit Date: 2022-10-12, Exit Price: 3292.34, P&L: 26.96
# Ticker: ADANIENT.NS, Entry Date: 2022-10-12, Action: SHORT (Buy for long, Sell for short), Entry Price: 3292.34, Exit Date: 2022-10-14, Exit Price: 3267.38, P&L: 24.96
# Ticker: ADANIENT.NS, Entry Date: 2022-10-14, Action: LONG (Buy for long, Sell for short), Entry Price: 3267.38, Exit Date: 2022-10-17, Exit Price: 3206.46, P&L: -60.91
# Ticker: ADANIENT.NS, Entry Date: 2022-10-17, Action: SHORT (Buy for long, Sell for short), Entry Price: 3206.46, Exit Date: 2022-10-18, Exit Price: 3244.41, P&L: -37.95
# Ticker: ADANIENT.NS, Entry Date: 2022-10-18, Action: LONG (Buy for long, Sell for short), Entry Price: 3244.41, Exit Date: 2022-10-20, Exit Price: 3255.39, P&L: 10.98
# Ticker: ADANIENT.NS, Entry Date: 2022-10-20, Action: SHORT (Buy for long, Sell for short), Entry Price: 3255.39, Exit Date: 2022-10-21, Exit Price: 3370.13, P&L: -114.74
# Ticker: ADANIENT.NS, Entry Date: 2022-10-21, Action: LONG (Buy for long, Sell for short), Entry Price: 3370.13, Exit Date: 2022-11-01, Exit Price: 3357.15, P&L: -12.98
# Ticker: ADANIENT.NS, Entry Date: 2022-11-07, Action: SHORT (Buy for long, Sell for short), Entry Price: 3847.01, Exit Date: 2022-11-11, Exit Price: 4034.29, P&L: -187.29
# Ticker: ADANIENT.NS, Entry Date: 2022-11-11, Action: LONG (Buy for long, Sell for short), Entry Price: 4034.29, Exit Date: 2022-11-14, Exit Price: 3993.35, P&L: -40.94
# Ticker: ADANIENT.NS, Entry Date: 2022-11-14, Action: SHORT (Buy for long, Sell for short), Entry Price: 3993.35, Exit Date: 2022-11-16, Exit Price: 4051.57, P&L: -58.22
# Ticker: ADANIENT.NS, Entry Date: 2022-11-16, Action: LONG (Buy for long, Sell for short), Entry Price: 4051.57, Exit Date: 2022-11-17, Exit Price: 3964.39, P&L: -87.18
# Ticker: ADANIENT.NS, Entry Date: 2022-11-17, Action: SHORT (Buy for long, Sell for short), Entry Price: 3964.39, Exit Date: 2022-11-18, Exit Price: 4022.66, P&L: -58.27
# Ticker: ADANIENT.NS, Entry Date: 2022-11-18, Action: LONG (Buy for long, Sell for short), Entry Price: 4022.66, Exit Date: 2022-11-24, Exit Price: 3904.48, P&L: -118.18
# Ticker: ADANIENT.NS, Entry Date: 2022-11-24, Action: SHORT (Buy for long, Sell for short), Entry Price: 3904.48, Exit Date: 2022-11-25, Exit Price: 3923.45, P&L: -18.97
# Ticker: ADANIENT.NS, Entry Date: 2022-11-25, Action: LONG (Buy for long, Sell for short), Entry Price: 3923.45, Exit Date: 2022-11-28, Exit Price: 3893.89, P&L: -29.56
# Ticker: ADANIENT.NS, Entry Date: 2022-11-28, Action: SHORT (Buy for long, Sell for short), Entry Price: 3893.89, Exit Date: 2022-11-30, Exit Price: 3892.29, P&L: 1.60
# Ticker: ADANIENT.NS, Entry Date: 2022-11-30, Action: LONG (Buy for long, Sell for short), Entry Price: 3892.29, Exit Date: 2022-12-13, Exit Price: 4022.11, P&L: 129.82
# Ticker: ADANIENT.NS, Entry Date: 2023-01-20, Action: SHORT (Buy for long, Sell for short), Entry Price: 3445.13, Exit Date: 2023-01-23, Exit Price: 3438.19, P&L: 6.94
# Ticker: ADANIENT.NS, Entry Date: 2023-01-23, Action: LONG (Buy for long, Sell for short), Entry Price: 3438.19, Exit Date: 2023-01-27, Exit Price: 3330.29, P&L: -107.90
# Ticker: ADANIENT.NS, Entry Date: 2023-01-27, Action: SHORT (Buy for long, Sell for short), Entry Price: 3330.29, Exit Date: 2023-01-31, Exit Price: 2975.79, P&L: 354.50
# Ticker: ADANIENT.NS, Entry Date: 2023-01-31, Action: LONG (Buy for long, Sell for short), Entry Price: 2975.79, Exit Date: 2023-02-02, Exit Price: 2345.53, P&L: -630.26
# Ticker: ADANIENT.NS, Entry Date: 2023-02-02, Action: SHORT (Buy for long, Sell for short), Entry Price: 2345.53, Exit Date: 2023-02-07, Exit Price: 1568.78, P&L: 776.75
# Ticker: ADANIENT.NS, Entry Date: 2023-02-07, Action: LONG (Buy for long, Sell for short), Entry Price: 1568.78, Exit Date: 2023-02-14, Exit Price: 1732.55, P&L: 163.77
# Ticker: ADANIENT.NS, Entry Date: 2023-02-14, Action: SHORT (Buy for long, Sell for short), Entry Price: 1732.55, Exit Date: 2023-02-15, Exit Price: 1777.49, P&L: -44.94
# Ticker: ADANIENT.NS, Entry Date: 2023-02-15, Action: LONG (Buy for long, Sell for short), Entry Price: 1777.49, Exit Date: 2023-02-16, Exit Price: 1817.43, P&L: 39.94
# Ticker: ADANIENT.NS, Entry Date: 2023-02-16, Action: SHORT (Buy for long, Sell for short), Entry Price: 1817.43, Exit Date: 2023-02-24, Exit Price: 1408.01, P&L: 409.42
# Ticker: ADANIENT.NS, Entry Date: 2023-02-24, Action: LONG (Buy for long, Sell for short), Entry Price: 1408.01, Exit Date: 2023-02-27, Exit Price: 1298.16, P&L: -109.84
# Ticker: ADANIENT.NS, Entry Date: 2023-02-27, Action: SHORT (Buy for long, Sell for short), Entry Price: 1298.16, Exit Date: 2023-03-01, Exit Price: 1421.99, P&L: -123.82
# Ticker: ADANIENT.NS, Entry Date: 2023-03-01, Action: LONG (Buy for long, Sell for short), Entry Price: 1421.99, Exit Date: 2023-03-14, Exit Price: 1871.35, P&L: 449.36
# Ticker: ADANIENT.NS, Entry Date: 2023-03-15, Action: SHORT (Buy for long, Sell for short), Entry Price: 1758.41, Exit Date: 2023-03-16, Exit Price: 1858.37, P&L: -99.96
# Ticker: ADANIENT.NS, Entry Date: 2023-03-16, Action: LONG (Buy for long, Sell for short), Entry Price: 1858.37, Exit Date: 2023-03-20, Exit Price: 1834.40, P&L: -23.97
# Ticker: ADANIENT.NS, Entry Date: 2023-03-20, Action: SHORT (Buy for long, Sell for short), Entry Price: 1834.40, Exit Date: 2023-03-22, Exit Price: 1831.41, P&L: 3.00
# Ticker: ADANIENT.NS, Entry Date: 2023-03-22, Action: LONG (Buy for long, Sell for short), Entry Price: 1831.41, Exit Date: 2023-03-23, Exit Price: 1791.47, P&L: -39.94
# Ticker: ADANIENT.NS, Entry Date: 2023-03-23, Action: SHORT (Buy for long, Sell for short), Entry Price: 1791.47, Exit Date: 2023-03-24, Exit Price: 1793.46, P&L: -2.00
# Ticker: ADANIENT.NS, Entry Date: 2023-03-24, Action: LONG (Buy for long, Sell for short), Entry Price: 1793.46, Exit Date: 2023-03-27, Exit Price: 1738.19, P&L: -55.27
# Ticker: ADANIENT.NS, Entry Date: 2023-03-27, Action: SHORT (Buy for long, Sell for short), Entry Price: 1738.19, Exit Date: 2023-03-31, Exit Price: 1785.47, P&L: -47.28
# Ticker: ADANIENT.NS, Entry Date: 2023-03-31, Action: LONG (Buy for long, Sell for short), Entry Price: 1785.47, Exit Date: 2023-04-05, Exit Price: 1715.02, P&L: -70.45
# Ticker: ADANIENT.NS, Entry Date: 2023-04-05, Action: SHORT (Buy for long, Sell for short), Entry Price: 1715.02, Exit Date: 2023-04-10, Exit Price: 1771.49, P&L: -56.47
# Ticker: ADANIENT.NS, Entry Date: 2023-04-10, Action: LONG (Buy for long, Sell for short), Entry Price: 1771.49, Exit Date: 2023-04-21, Exit Price: 1843.39, P&L: 71.90
# Ticker: ADANIENT.NS, Entry Date: 2023-05-29, Action: SHORT (Buy for long, Sell for short), Entry Price: 2566.37, Exit Date: 2023-05-30, Exit Price: 2525.73, P&L: 40.64
# Ticker: ADANIENT.NS, Entry Date: 2023-05-30, Action: LONG (Buy for long, Sell for short), Entry Price: 2525.73, Exit Date: 2023-05-31, Exit Price: 2478.49, P&L: -47.23
# Ticker: ADANIENT.NS, Entry Date: 2023-05-31, Action: SHORT (Buy for long, Sell for short), Entry Price: 2478.49, Exit Date: 2023-06-01, Exit Price: 2496.37, P&L: -17.87
# Ticker: ADANIENT.NS, Entry Date: 2023-06-01, Action: LONG (Buy for long, Sell for short), Entry Price: 2496.37, Exit Date: 2023-06-08, Exit Price: 2446.54, P&L: -49.83
# Ticker: ADANIENT.NS, Entry Date: 2023-06-08, Action: SHORT (Buy for long, Sell for short), Entry Price: 2446.54, Exit Date: 2023-06-12, Exit Price: 2456.52, P&L: -9.99
# Ticker: ADANIENT.NS, Entry Date: 2023-06-12, Action: LONG (Buy for long, Sell for short), Entry Price: 2456.52, Exit Date: 2023-06-13, Exit Price: 2495.47, P&L: 38.94
# Ticker: ADANIENT.NS, Entry Date: 2023-06-13, Action: SHORT (Buy for long, Sell for short), Entry Price: 2495.47, Exit Date: 2023-06-19, Exit Price: 2500.46, P&L: -4.99
# Ticker: ADANIENT.NS, Entry Date: 2023-06-19, Action: LONG (Buy for long, Sell for short), Entry Price: 2500.46, Exit Date: 2023-07-03, Exit Price: 2401.60, P&L: -98.86
# Ticker: ADANIENT.NS, Entry Date: 2023-11-17, Action: SHORT (Buy for long, Sell for short), Entry Price: 2203.88, Exit Date: 2023-11-20, Exit Price: 2208.98, P&L: -5.10
# Ticker: ADANIENT.NS, Entry Date: 2023-11-20, Action: LONG (Buy for long, Sell for short), Entry Price: 2208.98, Exit Date: 2023-11-21, Exit Price: 2158.03, P&L: -50.95
# Ticker: ADANIENT.NS, Entry Date: 2023-11-21, Action: SHORT (Buy for long, Sell for short), Entry Price: 2158.03, Exit Date: 2023-11-22, Exit Price: 2203.13, P&L: -45.11
# Ticker: ADANIENT.NS, Entry Date: 2023-11-22, Action: LONG (Buy for long, Sell for short), Entry Price: 2203.13, Exit Date: 2023-11-30, Exit Price: 2397.86, P&L: 194.72
# Ticker: ADANIENT.NS, Entry Date: 2023-11-30, Action: SHORT (Buy for long, Sell for short), Entry Price: 2397.86, Exit Date: 2023-12-01, Exit Price: 2367.83, P&L: 30.02
# Ticker: ADANIENT.NS, Entry Date: 2023-12-01, Action: LONG (Buy for long, Sell for short), Entry Price: 2367.83, Exit Date: 2023-12-05, Exit Price: 2528.89, P&L: 161.05
# Ticker: ADANIENT.NS, Entry Date: 2023-12-05, Action: SHORT (Buy for long, Sell for short), Entry Price: 2528.89, Exit Date: 2023-12-06, Exit Price: 3077.19, P&L: -548.30
# Ticker: ADANIENT.NS, Entry Date: 2023-12-06, Action: LONG (Buy for long, Sell for short), Entry Price: 3077.19, Exit Date: 2023-12-15, Exit Price: 2909.39, P&L: -167.80
# Ticker: ADANIENT.NS, Entry Date: 2023-12-15, Action: SHORT (Buy for long, Sell for short), Entry Price: 2909.39, Exit Date: 2023-12-18, Exit Price: 2991.21, P&L: -81.83
# Ticker: ADANIENT.NS, Entry Date: 2023-12-18, Action: LONG (Buy for long, Sell for short), Entry Price: 2991.21, Exit Date: 2023-12-20, Exit Price: 2943.31, P&L: -47.91
# Ticker: ADANIENT.NS, Entry Date: 2023-12-20, Action: SHORT (Buy for long, Sell for short), Entry Price: 2943.31, Exit Date: 2023-12-22, Exit Price: 2813.38, P&L: 129.93
# Ticker: ADANIENT.NS, Entry Date: 2023-12-22, Action: LONG (Buy for long, Sell for short), Entry Price: 2813.38, Exit Date: 2023-12-28, Exit Price: 2852.39, P&L: 39.01
# Ticker: ADANIENT.NS, Entry Date: 2023-12-28, Action: SHORT (Buy for long, Sell for short), Entry Price: 2852.39, Exit Date: 2024-01-03, Exit Price: 3044.22, P&L: -191.82
# Ticker: ADANIENT.NS, Entry Date: 2024-01-03, Action: LONG (Buy for long, Sell for short), Entry Price: 3044.22, Exit Date: 2024-01-04, Exit Price: 3036.62, P&L: -7.59
# Ticker: ADANIENT.NS, Entry Date: 2024-01-04, Action: SHORT (Buy for long, Sell for short), Entry Price: 3036.62, Exit Date: 2024-01-08, Exit Price: 3017.24, P&L: 19.38
# Ticker: ADANIENT.NS, Entry Date: 2024-01-08, Action: LONG (Buy for long, Sell for short), Entry Price: 3017.24, Exit Date: 2024-01-09, Exit Price: 2987.97, P&L: -29.27
# Ticker: ADANIENT.NS, Entry Date: 2024-01-09, Action: SHORT (Buy for long, Sell for short), Entry Price: 2987.97, Exit Date: 2024-01-10, Exit Price: 3021.24, P&L: -33.27
# Ticker: ADANIENT.NS, Entry Date: 2024-01-10, Action: LONG (Buy for long, Sell for short), Entry Price: 3021.24, Exit Date: 2024-01-12, Exit Price: 3093.52, P&L: 72.28
# Ticker: ADANIENT.NS, Entry Date: 2024-01-12, Action: SHORT (Buy for long, Sell for short), Entry Price: 3093.52, Exit Date: 2024-01-15, Exit Price: 3124.14, P&L: -30.62
# Ticker: ADANIENT.NS, Entry Date: 2024-01-15, Action: LONG (Buy for long, Sell for short), Entry Price: 3124.14, Exit Date: 2024-01-16, Exit Price: 3092.17, P&L: -31.97
# Ticker: ADANIENT.NS, Entry Date: 2024-01-16, Action: SHORT (Buy for long, Sell for short), Entry Price: 3092.17, Exit Date: 2024-01-23, Exit Price: 3012.19, P&L: 79.98
# Ticker: ADANIENT.NS, Entry Date: 2024-01-23, Action: LONG (Buy for long, Sell for short), Entry Price: 3012.19, Exit Date: 2024-01-24, Exit Price: 2898.35, P&L: -113.85
# Ticker: ADANIENT.NS, Entry Date: 2024-01-24, Action: SHORT (Buy for long, Sell for short), Entry Price: 2898.35, Exit Date: 2024-01-25, Exit Price: 2900.80, P&L: -2.45
# Ticker: ADANIENT.NS, Entry Date: 2024-01-25, Action: LONG (Buy for long, Sell for short), Entry Price: 2900.80, Exit Date: 2024-01-29, Exit Price: 2926.32, P&L: 25.53
# Ticker: ADANIENT.NS, Entry Date: 2024-01-29, Action: SHORT (Buy for long, Sell for short), Entry Price: 2926.32, Exit Date: 2024-01-30, Exit Price: 3078.18, P&L: -151.86
# Ticker: ADANIENT.NS, Entry Date: 2024-01-30, Action: LONG (Buy for long, Sell for short), Entry Price: 3078.18, Exit Date: 2024-02-08, Exit Price: 3242.63, P&L: 164.45
# Ticker: ADANIENT.NS, Entry Date: 2024-02-08, Action: SHORT (Buy for long, Sell for short), Entry Price: 3242.63, Exit Date: 2024-02-12, Exit Price: 3226.05, P&L: 16.58
# Ticker: ADANIENT.NS, Entry Date: 2024-02-12, Action: LONG (Buy for long, Sell for short), Entry Price: 3226.05, Exit Date: 2024-02-13, Exit Price: 3177.09, P&L: -48.96
# Ticker: ADANIENT.NS, Entry Date: 2024-02-13, Action: SHORT (Buy for long, Sell for short), Entry Price: 3177.09, Exit Date: 2024-02-14, Exit Price: 3181.09, P&L: -4.00
# Ticker: ADANIENT.NS, Entry Date: 2024-02-14, Action: LONG (Buy for long, Sell for short), Entry Price: 3181.09, Exit Date: 2024-02-20, Exit Price: 3264.01, P&L: 82.92
# Ticker: ADANIENT.NS, Entry Date: 2024-02-20, Action: SHORT (Buy for long, Sell for short), Entry Price: 3264.01, Exit Date: 2024-02-26, Exit Price: 3269.01, P&L: -5.00
# Ticker: ADANIENT.NS, Entry Date: 2024-02-26, Action: LONG (Buy for long, Sell for short), Entry Price: 3269.01, Exit Date: 2024-02-28, Exit Price: 3306.18, P&L: 37.17
# Ticker: ADANIENT.NS, Entry Date: 2024-02-28, Action: SHORT (Buy for long, Sell for short), Entry Price: 3306.18, Exit Date: 2024-03-01, Exit Price: 3306.83, P&L: -0.65
# Ticker: ADANIENT.NS, Entry Date: 2024-03-01, Action: LONG (Buy for long, Sell for short), Entry Price: 3306.83, Exit Date: 2024-03-05, Exit Price: 3322.26, P&L: 15.44
# Ticker: ADANIENT.NS, Entry Date: 2024-03-05, Action: SHORT (Buy for long, Sell for short), Entry Price: 3322.26, Exit Date: 2024-03-18, Exit Price: 3047.31, P&L: 274.95
# Ticker: ADANIENT.NS, Entry Date: 2024-03-18, Action: SHORT (Buy for long, Sell for short), Entry Price: 3047.31, Exit Date: 2024-03-21, Exit Price: 3086.73, P&L: -39.41
# Ticker: ADANIENT.NS, Entry Date: 2024-03-21, Action: LONG (Buy for long, Sell for short), Entry Price: 3086.73, Exit Date: 2024-03-22, Exit Price: 3063.75, P&L: -22.98
# Ticker: ADANIENT.NS, Entry Date: 2024-03-22, Action: SHORT (Buy for long, Sell for short), Entry Price: 3063.75, Exit Date: 2024-03-26, Exit Price: 3097.67, P&L: -33.92
# Ticker: ADANIENT.NS, Entry Date: 2024-03-26, Action: LONG (Buy for long, Sell for short), Entry Price: 3097.67, Exit Date: 2024-03-28, Exit Price: 3131.14, P&L: 33.47
# Ticker: ADANIENT.NS, Entry Date: 2024-03-28, Action: SHORT (Buy for long, Sell for short), Entry Price: 3131.14, Exit Date: 2024-04-02, Exit Price: 3255.97, P&L: -124.84
# Ticker: ADANIENT.NS, Entry Date: 2024-04-02, Action: LONG (Buy for long, Sell for short), Entry Price: 3255.97, Exit Date: 2024-04-15, Exit Price: 3147.12, P&L: -108.85
# Ticker: ADANIENT.NS, Entry Date: 2024-05-06, Action: SHORT (Buy for long, Sell for short), Entry Price: 2990.51, Exit Date: 2024-05-09, Exit Price: 2862.18, P&L: 128.33
# Ticker: ADANIENT.NS, Entry Date: 2024-05-09, Action: LONG (Buy for long, Sell for short), Entry Price: 2862.18, Exit Date: 2024-05-10, Exit Price: 2792.40, P&L: -69.79
# Ticker: ADANIENT.NS, Entry Date: 2024-05-10, Action: SHORT (Buy for long, Sell for short), Entry Price: 2792.40, Exit Date: 2024-05-13, Exit Price: 2800.44, P&L: -8.04
# Ticker: ADANIENT.NS, Entry Date: 2024-05-13, Action: LONG (Buy for long, Sell for short), Entry Price: 2800.44, Exit Date: 2024-05-16, Exit Price: 3062.20, P&L: 261.76
# Ticker: ADANIENT.NS, Entry Date: 2024-05-16, Action: SHORT (Buy for long, Sell for short), Entry Price: 3062.20, Exit Date: 2024-05-21, Exit Price: 3065.10, P&L: -2.90
# Ticker: ADANIENT.NS, Entry Date: 2024-05-21, Action: LONG (Buy for long, Sell for short), Entry Price: 3065.10, Exit Date: 2024-05-27, Exit Price: 3354.93, P&L: 289.84
# Ticker: ADANIENT.NS, Entry Date: 2024-05-27, Action: SHORT (Buy for long, Sell for short), Entry Price: 3354.93, Exit Date: 2024-05-30, Exit Price: 3251.03, P&L: 103.90
# Ticker: ADANIENT.NS, Entry Date: 2024-05-30, Action: LONG (Buy for long, Sell for short), Entry Price: 3251.03, Exit Date: 2024-05-31, Exit Price: 3222.30, P&L: -28.72
# Ticker: ADANIENT.NS, Entry Date: 2024-05-31, Action: SHORT (Buy for long, Sell for short), Entry Price: 3222.30, Exit Date: 2024-06-03, Exit Price: 3721.60, P&L: -499.29
# Ticker: ADANIENT.NS, Entry Date: 2024-06-03, Action: LONG (Buy for long, Sell for short), Entry Price: 3721.60, Exit Date: 2024-06-05, Exit Price: 3027.23, P&L: -694.36
# Ticker: ADANIENT.NS, Entry Date: 2024-06-05, Action: SHORT (Buy for long, Sell for short), Entry Price: 3027.23, Exit Date: 2024-06-06, Exit Price: 3181.09, P&L: -153.86
# Ticker: ADANIENT.NS, Entry Date: 2024-06-06, Action: LONG (Buy for long, Sell for short), Entry Price: 3181.09, Exit Date: 2024-06-19, Exit Price: 3312.31, P&L: 131.22
# Ticker: ADANIENT.NS, Entry Date: 2024-07-25, Action: SHORT (Buy for long, Sell for short), Entry Price: 2959.19, Exit Date: 2024-07-26, Exit Price: 2993.47, P&L: -34.28
# Ticker: ADANIENT.NS, Entry Date: 2024-07-26, Action: LONG (Buy for long, Sell for short), Entry Price: 2993.47, Exit Date: 2024-08-06, Exit Price: 3082.42, P&L: 88.95
# Ticker: ADANIENT.NS, Entry Date: 2024-09-09, Action: SHORT (Buy for long, Sell for short), Entry Price: 2970.58, Exit Date: 2024-09-10, Exit Price: 2970.08, P&L: 0.50
# Ticker: ADANIENT.NS, Entry Date: 2024-09-10, Action: LONG (Buy for long, Sell for short), Entry Price: 2970.08, Exit Date: 2024-09-11, Exit Price: 2983.47, P&L: 13.39
# Ticker: ADANIENT.NS, Entry Date: 2024-09-11, Action: SHORT (Buy for long, Sell for short), Entry Price: 2983.47, Exit Date: 2024-09-16, Exit Price: 2970.48, P&L: 12.99
# Ticker: ADANIENT.NS, Entry Date: 2024-09-16, Action: LONG (Buy for long, Sell for short), Entry Price: 2970.48, Exit Date: 2024-09-17, Exit Price: 2988.52, P&L: 18.04
# Ticker: ADANIENT.NS, Entry Date: 2024-09-17, Action: SHORT (Buy for long, Sell for short), Entry Price: 2988.52, Exit Date: 2024-09-23, Exit Price: 3018.46, P&L: -29.93
# Ticker: ADANIENT.NS, Entry Date: 2024-09-23, Action: LONG (Buy for long, Sell for short), Entry Price: 3018.46, Exit Date: 2024-09-24, Exit Price: 3053.44, P&L: 34.98
# Ticker: ADANIENT.NS, Entry Date: 2024-09-24, Action: SHORT (Buy for long, Sell for short), Entry Price: 3053.44, Exit Date: 2024-09-25, Exit Price: 3106.41, P&L: -52.97
# Ticker: ADANIENT.NS, Entry Date: 2024-09-25, Action: LONG (Buy for long, Sell for short), Entry Price: 3106.41, Exit Date: 2024-10-08, Exit Price: 3016.96, P&L: -89.45
# Ticker: ADANIENT.NS, Entry Date: 2024-10-23, Action: SHORT (Buy for long, Sell for short), Entry Price: 2839.40, Exit Date: 2024-10-24, Exit Price: 2839.60, P&L: -0.20
# Ticker: ADANIENT.NS, Entry Date: 2024-10-24, Action: LONG (Buy for long, Sell for short), Entry Price: 2839.60, Exit Date: 2024-10-25, Exit Price: 2843.55, P&L: 3.95
# Ticker: ADANIENT.NS, Entry Date: 2024-10-25, Action: SHORT (Buy for long, Sell for short), Entry Price: 2843.55, Exit Date: 2024-11-04, Exit Price: 2933.50, P&L: -89.95
# Ticker: ADANIENT.NS, Entry Date: 2024-11-04, Action: LONG (Buy for long, Sell for short), Entry Price: 2933.50, Exit Date: 2024-11-08, Exit Price: 2963.58, P&L: 30.08
# Ticker: ADANIENT.NS, Entry Date: 2024-11-08, Action: SHORT (Buy for long, Sell for short), Entry Price: 2963.58, Exit Date: 2024-11-11, Exit Price: 2926.50, P&L: 37.08
# Ticker: ADANIENT.NS, Entry Date: 2024-11-11, Action: LONG (Buy for long, Sell for short), Entry Price: 2926.50, Exit Date: 2024-11-12, Exit Price: 2908.51, P&L: -17.99
# Ticker: ADANIENT.NS, Entry Date: 2024-11-12, Action: SHORT (Buy for long, Sell for short), Entry Price: 2908.51, Exit Date: 2024-11-18, Exit Price: 2825.36, P&L: 83.16
# Ticker: ADANIENT.NS, Entry Date: 2024-11-18, Action: LONG (Buy for long, Sell for short), Entry Price: 2825.36, Exit Date: 2024-11-19, Exit Price: 2829.55, P&L: 4.20
# Ticker: ADANIENT.NS, Entry Date: 2024-11-19, Action: SHORT (Buy for long, Sell for short), Entry Price: 2829.55, Exit Date: 2024-11-21, Exit Price: 2538.05, P&L: 291.50
# Ticker: ADANIENT.NS, Entry Date: 2024-11-21, Action: LONG (Buy for long, Sell for short), Entry Price: 2538.05, Exit Date: 2024-11-22, Exit Price: 2099.93, P&L: -438.13
# Ticker: ADANIENT.NS, Entry Date: 2024-11-22, Action: SHORT (Buy for long, Sell for short), Entry Price: 2099.93, Exit Date: 2024-11-29, Exit Price: 2462.79, P&L: -362.86
# Ticker: ADANIENT.NS, Entry Date: 2024-11-29, Action: LONG (Buy for long, Sell for short), Entry Price: 2462.79, Exit Date: 2024-12-04, Exit Price: 2526.71, P&L: 63.92
# Ticker: ADANIENT.NS, Entry Date: 2024-12-04, Action: SHORT (Buy for long, Sell for short), Entry Price: 2526.71, Exit Date: 2024-12-10, Exit Price: 2499.72, P&L: 26.99
# Ticker: ADANIENT.NS, Entry Date: 2024-12-10, Action: LONG (Buy for long, Sell for short), Entry Price: 2499.72, Exit Date: 2024-12-11, Exit Price: 2467.74, P&L: -31.98
# Ticker: ADANIENT.NS, Entry Date: 2024-12-11, Action: SHORT (Buy for long, Sell for short), Entry Price: 2467.74, Exit Date: 2024-12-13, Exit Price: 2502.72, P&L: -34.98
# Ticker: ADANIENT.NS, Entry Date: 2024-12-13, Action: LONG (Buy for long, Sell for short), Entry Price: 2502.72, Exit Date: 2024-12-17, Exit Price: 2510.72, P&L: 8.00
# Ticker: ADANIENT.NS, Entry Date: 2024-12-17, Action: SHORT (Buy for long, Sell for short), Entry Price: 2510.72, Exit Date: 2024-12-18, Exit Price: 2487.73, P&L: 22.99
# Ticker: ADANIENT.NS, Entry Date: 2024-12-18, Action: LONG (Buy for long, Sell for short), Entry Price: 2487.73, Exit Date: 2024-12-19, Exit Price: 2427.76, P&L: -59.97
# Ticker: ADANIENT.NS, Entry Date: 2024-12-19, Action: SHORT (Buy for long, Sell for short), Entry Price: 2427.76, Exit Date: 2024-12-26, Exit Price: 2376.83, P&L: 50.92
# Ticker: ADANIENT.NS, Entry Date: 2024-12-26, Action: LONG (Buy for long, Sell for short), Entry Price: 2376.83, Exit Date: 2025-01-01, Exit Price: 2534.70, P&L: 157.87
# Ticker: ADANIENT.NS, Entry Date: 2025-01-01, Action: SHORT (Buy for long, Sell for short), Entry Price: 2534.70, Exit Date: 2025-01-02, Exit Price: 2564.39, P&L: -29.68
# Ticker: ADANIENT.NS, Entry Date: 2025-01-02, Action: LONG (Buy for long, Sell for short), Entry Price: 2564.39, Exit Date: 2025-01-14, Exit Price: 2240.35, P&L: -324.03
# Ticker: ADANIENT.NS, Entry Date: 2025-02-25, Action: LONG (Buy for long, Sell for short), Entry Price: 2114.07, Exit Date: 2025-02-27, Exit Price: 2142.65, P&L: 28.59
# Ticker: ADANIENT.NS, Entry Date: 2025-02-27, Action: SHORT (Buy for long, Sell for short), Entry Price: 2142.65, Exit Date: 2025-03-03, Exit Price: 2107.92, P&L: 34.73
# Ticker: ADANIENT.NS, Entry Date: 2025-03-03, Action: LONG (Buy for long, Sell for short), Entry Price: 2107.92, Exit Date: 2025-03-07, Exit Price: 2248.80, P&L: 140.88
# Ticker: ADANIENT.NS, Entry Date: 2025-03-07, Action: SHORT (Buy for long, Sell for short), Entry Price: 2248.80, Exit Date: 2025-03-10, Exit Price: 2243.85, P&L: 4.95
# Ticker: ADANIENT.NS, Entry Date: 2025-03-10, Action: LONG (Buy for long, Sell for short), Entry Price: 2243.85, Exit Date: 2025-03-21, Exit Price: 2342.60, P&L: 98.75
# Ticker: ADANIENT.NS, Entry Date: 2025-08-05, Action: LONG (Buy for long, Sell for short), Entry Price: 2370.00, Exit Date: 2025-08-05, Exit Price: 2328.20, P&L: -41.80
# Ticker: ADANIPORTS.NS, Entry Date: 2022-01-24, Action: LONG (Buy for long, Sell for short), Entry Price: 707.63, Exit Date: 2022-01-25, Exit Price: 680.35, P&L: -27.27
# Ticker: ADANIPORTS.NS, Entry Date: 2022-01-25, Action: SHORT (Buy for long, Sell for short), Entry Price: 680.35, Exit Date: 2022-01-27, Exit Price: 684.07, P&L: -3.71
# Ticker: ADANIPORTS.NS, Entry Date: 2022-01-27, Action: LONG (Buy for long, Sell for short), Entry Price: 684.07, Exit Date: 2022-01-28, Exit Price: 696.97, P&L: 12.90
# Ticker: ADANIPORTS.NS, Entry Date: 2022-01-28, Action: SHORT (Buy for long, Sell for short), Entry Price: 696.97, Exit Date: 2022-02-02, Exit Price: 707.63, P&L: -10.66
# Ticker: ADANIPORTS.NS, Entry Date: 2022-02-02, Action: LONG (Buy for long, Sell for short), Entry Price: 707.63, Exit Date: 2022-02-04, Exit Price: 718.48, P&L: 10.85
# Ticker: ADANIPORTS.NS, Entry Date: 2022-02-04, Action: SHORT (Buy for long, Sell for short), Entry Price: 718.48, Exit Date: 2022-02-07, Exit Price: 712.42, P&L: 6.06
# Ticker: ADANIPORTS.NS, Entry Date: 2022-02-07, Action: LONG (Buy for long, Sell for short), Entry Price: 712.42, Exit Date: 2022-02-08, Exit Price: 702.84, P&L: -9.58
# Ticker: ADANIPORTS.NS, Entry Date: 2022-02-08, Action: SHORT (Buy for long, Sell for short), Entry Price: 702.84, Exit Date: 2022-02-09, Exit Price: 705.77, P&L: -2.93
# Ticker: ADANIPORTS.NS, Entry Date: 2022-02-09, Action: LONG (Buy for long, Sell for short), Entry Price: 705.77, Exit Date: 2022-02-22, Exit Price: 682.31, P&L: -23.46
# Ticker: ADANIPORTS.NS, Entry Date: 2022-04-11, Action: LONG (Buy for long, Sell for short), Entry Price: 821.12, Exit Date: 2022-04-13, Exit Price: 830.79, P&L: 9.68
# Ticker: ADANIPORTS.NS, Entry Date: 2022-04-13, Action: SHORT (Buy for long, Sell for short), Entry Price: 830.79, Exit Date: 2022-04-19, Exit Price: 829.91, P&L: 0.88
# Ticker: ADANIPORTS.NS, Entry Date: 2022-04-19, Action: LONG (Buy for long, Sell for short), Entry Price: 829.91, Exit Date: 2022-04-20, Exit Price: 807.04, P&L: -22.87
# Ticker: ADANIPORTS.NS, Entry Date: 2022-04-20, Action: SHORT (Buy for long, Sell for short), Entry Price: 807.04, Exit Date: 2022-04-21, Exit Price: 814.27, P&L: -7.23
# Ticker: ADANIPORTS.NS, Entry Date: 2022-04-21, Action: LONG (Buy for long, Sell for short), Entry Price: 814.27, Exit Date: 2022-04-26, Exit Price: 848.49, P&L: 34.21
# Ticker: ADANIPORTS.NS, Entry Date: 2022-04-26, Action: SHORT (Buy for long, Sell for short), Entry Price: 848.49, Exit Date: 2022-04-27, Exit Price: 893.50, P&L: -45.01
# Ticker: ADANIPORTS.NS, Entry Date: 2022-04-27, Action: LONG (Buy for long, Sell for short), Entry Price: 893.50, Exit Date: 2022-04-28, Exit Price: 878.79, P&L: -14.71
# Ticker: ADANIPORTS.NS, Entry Date: 2022-04-28, Action: SHORT (Buy for long, Sell for short), Entry Price: 878.79, Exit Date: 2022-04-29, Exit Price: 872.63, P&L: 6.16
# Ticker: ADANIPORTS.NS, Entry Date: 2022-04-29, Action: LONG (Buy for long, Sell for short), Entry Price: 872.63, Exit Date: 2022-05-02, Exit Price: 830.89, P&L: -41.74
# Ticker: ADANIPORTS.NS, Entry Date: 2022-05-02, Action: SHORT (Buy for long, Sell for short), Entry Price: 830.89, Exit Date: 2022-05-09, Exit Price: 789.30, P&L: 41.59
# Ticker: ADANIPORTS.NS, Entry Date: 2022-05-09, Action: LONG (Buy for long, Sell for short), Entry Price: 789.30, Exit Date: 2022-05-13, Exit Price: 710.66, P&L: -78.64
# Ticker: ADANIPORTS.NS, Entry Date: 2022-05-13, Action: SHORT (Buy for long, Sell for short), Entry Price: 710.66, Exit Date: 2022-05-17, Exit Price: 703.81, P&L: 6.84
# Ticker: ADANIPORTS.NS, Entry Date: 2022-05-17, Action: LONG (Buy for long, Sell for short), Entry Price: 703.81, Exit Date: 2022-05-20, Exit Price: 733.09, P&L: 29.28
# Ticker: ADANIPORTS.NS, Entry Date: 2022-05-20, Action: SHORT (Buy for long, Sell for short), Entry Price: 733.09, Exit Date: 2022-05-23, Exit Price: 757.43, P&L: -24.34
# Ticker: ADANIPORTS.NS, Entry Date: 2022-05-23, Action: LONG (Buy for long, Sell for short), Entry Price: 757.43, Exit Date: 2022-06-03, Exit Price: 740.96, P&L: -16.47
# Ticker: ADANIPORTS.NS, Entry Date: 2022-06-22, Action: LONG (Buy for long, Sell for short), Entry Price: 669.50, Exit Date: 2022-06-23, Exit Price: 657.58, P&L: -11.93
# Ticker: ADANIPORTS.NS, Entry Date: 2022-06-23, Action: SHORT (Buy for long, Sell for short), Entry Price: 657.58, Exit Date: 2022-06-24, Exit Price: 667.64, P&L: -10.07
# Ticker: ADANIPORTS.NS, Entry Date: 2022-06-24, Action: LONG (Buy for long, Sell for short), Entry Price: 667.64, Exit Date: 2022-06-27, Exit Price: 682.31, P&L: 14.66
# Ticker: ADANIPORTS.NS, Entry Date: 2022-06-27, Action: SHORT (Buy for long, Sell for short), Entry Price: 682.31, Exit Date: 2022-06-30, Exit Price: 665.25, P&L: 17.06
# Ticker: ADANIPORTS.NS, Entry Date: 2022-06-30, Action: LONG (Buy for long, Sell for short), Entry Price: 665.25, Exit Date: 2022-07-01, Exit Price: 654.94, P&L: -10.31
# Ticker: ADANIPORTS.NS, Entry Date: 2022-07-01, Action: SHORT (Buy for long, Sell for short), Entry Price: 654.94, Exit Date: 2022-07-05, Exit Price: 671.02, P&L: -16.08
# Ticker: ADANIPORTS.NS, Entry Date: 2022-07-05, Action: LONG (Buy for long, Sell for short), Entry Price: 671.02, Exit Date: 2022-07-06, Exit Price: 662.76, P&L: -8.26
# Ticker: ADANIPORTS.NS, Entry Date: 2022-07-06, Action: SHORT (Buy for long, Sell for short), Entry Price: 662.76, Exit Date: 2022-07-07, Exit Price: 685.24, P&L: -22.48
# Ticker: ADANIPORTS.NS, Entry Date: 2022-07-07, Action: LONG (Buy for long, Sell for short), Entry Price: 685.24, Exit Date: 2022-07-19, Exit Price: 725.37, P&L: 40.13
# Ticker: ADANIPORTS.NS, Entry Date: 2022-07-28, Action: LONG (Buy for long, Sell for short), Entry Price: 751.65, Exit Date: 2022-08-04, Exit Price: 798.31, P&L: 46.66
# Ticker: ADANIPORTS.NS, Entry Date: 2022-08-04, Action: SHORT (Buy for long, Sell for short), Entry Price: 798.31, Exit Date: 2022-08-08, Exit Price: 800.13, P&L: -1.82
# Ticker: ADANIPORTS.NS, Entry Date: 2022-08-08, Action: LONG (Buy for long, Sell for short), Entry Price: 800.13, Exit Date: 2022-08-11, Exit Price: 782.22, P&L: -17.91
# Ticker: ADANIPORTS.NS, Entry Date: 2022-08-11, Action: SHORT (Buy for long, Sell for short), Entry Price: 782.22, Exit Date: 2022-08-12, Exit Price: 781.03, P&L: 1.18
# Ticker: ADANIPORTS.NS, Entry Date: 2022-08-12, Action: LONG (Buy for long, Sell for short), Entry Price: 781.03, Exit Date: 2022-08-18, Exit Price: 811.79, P&L: 30.76
# Ticker: ADANIPORTS.NS, Entry Date: 2022-08-18, Action: SHORT (Buy for long, Sell for short), Entry Price: 811.79, Exit Date: 2022-08-19, Exit Price: 824.10, P&L: -12.30
# Ticker: ADANIPORTS.NS, Entry Date: 2022-08-19, Action: LONG (Buy for long, Sell for short), Entry Price: 824.10, Exit Date: 2022-08-24, Exit Price: 817.21, P&L: -6.89
# Ticker: ADANIPORTS.NS, Entry Date: 2022-08-24, Action: SHORT (Buy for long, Sell for short), Entry Price: 817.21, Exit Date: 2022-08-25, Exit Price: 827.30, P&L: -10.09
# Ticker: ADANIPORTS.NS, Entry Date: 2022-08-25, Action: LONG (Buy for long, Sell for short), Entry Price: 827.30, Exit Date: 2022-08-26, Exit Price: 808.10, P&L: -19.19
# Ticker: ADANIPORTS.NS, Entry Date: 2022-08-26, Action: SHORT (Buy for long, Sell for short), Entry Price: 808.10, Exit Date: 2022-08-30, Exit Price: 830.74, P&L: -22.64
# Ticker: ADANIPORTS.NS, Entry Date: 2022-08-30, Action: LONG (Buy for long, Sell for short), Entry Price: 830.74, Exit Date: 2022-09-02, Exit Price: 828.77, P&L: -1.97
# Ticker: ADANIPORTS.NS, Entry Date: 2022-09-02, Action: SHORT (Buy for long, Sell for short), Entry Price: 828.77, Exit Date: 2022-09-07, Exit Price: 833.69, P&L: -4.92
# Ticker: ADANIPORTS.NS, Entry Date: 2022-09-07, Action: LONG (Buy for long, Sell for short), Entry Price: 833.69, Exit Date: 2022-09-19, Exit Price: 928.09, P&L: 94.39
# Ticker: ADANIPORTS.NS, Entry Date: 2022-09-19, Action: SHORT (Buy for long, Sell for short), Entry Price: 928.09, Exit Date: 2022-09-23, Exit Price: 935.08, P&L: -6.99
# Ticker: ADANIPORTS.NS, Entry Date: 2022-09-23, Action: LONG (Buy for long, Sell for short), Entry Price: 935.08, Exit Date: 2022-09-26, Exit Price: 894.72, P&L: -40.36
# Ticker: ADANIPORTS.NS, Entry Date: 2022-09-26, Action: SHORT (Buy for long, Sell for short), Entry Price: 894.72, Exit Date: 2022-10-03, Exit Price: 808.10, P&L: 86.62
# Ticker: ADANIPORTS.NS, Entry Date: 2022-10-03, Action: LONG (Buy for long, Sell for short), Entry Price: 808.10, Exit Date: 2022-10-07, Exit Price: 808.10, P&L: -0.00
# Ticker: ADANIPORTS.NS, Entry Date: 2022-10-07, Action: SHORT (Buy for long, Sell for short), Entry Price: 808.10, Exit Date: 2022-10-11, Exit Price: 801.21, P&L: 6.89
# Ticker: ADANIPORTS.NS, Entry Date: 2022-10-11, Action: LONG (Buy for long, Sell for short), Entry Price: 801.21, Exit Date: 2022-10-12, Exit Price: 788.42, P&L: -12.80
# Ticker: ADANIPORTS.NS, Entry Date: 2022-10-12, Action: SHORT (Buy for long, Sell for short), Entry Price: 788.42, Exit Date: 2022-10-13, Exit Price: 794.32, P&L: -5.91
# Ticker: ADANIPORTS.NS, Entry Date: 2022-10-13, Action: LONG (Buy for long, Sell for short), Entry Price: 794.32, Exit Date: 2022-10-14, Exit Price: 791.37, P&L: -2.95
# Ticker: ADANIPORTS.NS, Entry Date: 2022-10-14, Action: SHORT (Buy for long, Sell for short), Entry Price: 791.37, Exit Date: 2022-10-18, Exit Price: 779.02, P&L: 12.35
# Ticker: ADANIPORTS.NS, Entry Date: 2022-10-18, Action: LONG (Buy for long, Sell for short), Entry Price: 779.02, Exit Date: 2022-10-24, Exit Price: 795.31, P&L: 16.29
# Ticker: ADANIPORTS.NS, Entry Date: 2022-10-24, Action: SHORT (Buy for long, Sell for short), Entry Price: 795.31, Exit Date: 2022-10-25, Exit Price: 794.03, P&L: 1.28
# Ticker: ADANIPORTS.NS, Entry Date: 2022-10-25, Action: LONG (Buy for long, Sell for short), Entry Price: 794.03, Exit Date: 2022-11-03, Exit Price: 812.04, P&L: 18.01
# Ticker: ADANIPORTS.NS, Entry Date: 2022-11-03, Action: SHORT (Buy for long, Sell for short), Entry Price: 812.04, Exit Date: 2022-11-10, Exit Price: 879.96, P&L: -67.92
# Ticker: ADANIPORTS.NS, Entry Date: 2022-11-10, Action: LONG (Buy for long, Sell for short), Entry Price: 879.96, Exit Date: 2022-11-17, Exit Price: 872.08, P&L: -7.87
# Ticker: ADANIPORTS.NS, Entry Date: 2022-11-17, Action: SHORT (Buy for long, Sell for short), Entry Price: 872.08, Exit Date: 2022-11-18, Exit Price: 878.04, P&L: -5.95
# Ticker: ADANIPORTS.NS, Entry Date: 2022-11-18, Action: LONG (Buy for long, Sell for short), Entry Price: 878.04, Exit Date: 2022-11-22, Exit Price: 857.91, P&L: -20.13
# Ticker: ADANIPORTS.NS, Entry Date: 2022-11-22, Action: SHORT (Buy for long, Sell for short), Entry Price: 857.91, Exit Date: 2022-12-05, Exit Price: 877.59, P&L: -19.69
# Ticker: ADANIPORTS.NS, Entry Date: 2022-12-15, Action: LONG (Buy for long, Sell for short), Entry Price: 886.11, Exit Date: 2022-12-16, Exit Price: 869.08, P&L: -17.03
# Ticker: ADANIPORTS.NS, Entry Date: 2022-12-16, Action: SHORT (Buy for long, Sell for short), Entry Price: 869.08, Exit Date: 2022-12-27, Exit Price: 797.37, P&L: 71.71
# Ticker: ADANIPORTS.NS, Entry Date: 2022-12-29, Action: SHORT (Buy for long, Sell for short), Entry Price: 794.32, Exit Date: 2022-12-30, Exit Price: 809.53, P&L: -15.21
# Ticker: ADANIPORTS.NS, Entry Date: 2022-12-30, Action: LONG (Buy for long, Sell for short), Entry Price: 809.53, Exit Date: 2023-01-02, Exit Price: 810.07, P&L: 0.54
# Ticker: ADANIPORTS.NS, Entry Date: 2023-01-02, Action: SHORT (Buy for long, Sell for short), Entry Price: 810.07, Exit Date: 2023-01-03, Exit Price: 809.33, P&L: 0.74
# Ticker: ADANIPORTS.NS, Entry Date: 2023-01-03, Action: LONG (Buy for long, Sell for short), Entry Price: 809.33, Exit Date: 2023-01-09, Exit Price: 797.72, P&L: -11.61
# Ticker: ADANIPORTS.NS, Entry Date: 2023-01-09, Action: SHORT (Buy for long, Sell for short), Entry Price: 797.72, Exit Date: 2023-01-10, Exit Price: 804.16, P&L: -6.45
# Ticker: ADANIPORTS.NS, Entry Date: 2023-01-10, Action: LONG (Buy for long, Sell for short), Entry Price: 804.16, Exit Date: 2023-01-11, Exit Price: 787.43, P&L: -16.73
# Ticker: ADANIPORTS.NS, Entry Date: 2023-01-11, Action: SHORT (Buy for long, Sell for short), Entry Price: 787.43, Exit Date: 2023-01-12, Exit Price: 784.18, P&L: 3.25
# Ticker: ADANIPORTS.NS, Entry Date: 2023-01-12, Action: LONG (Buy for long, Sell for short), Entry Price: 784.18, Exit Date: 2023-01-17, Exit Price: 775.96, P&L: -8.22
# Ticker: ADANIPORTS.NS, Entry Date: 2023-01-17, Action: SHORT (Buy for long, Sell for short), Entry Price: 775.96, Exit Date: 2023-01-19, Exit Price: 771.63, P&L: 4.33
# Ticker: ADANIPORTS.NS, Entry Date: 2023-01-19, Action: LONG (Buy for long, Sell for short), Entry Price: 771.63, Exit Date: 2023-01-20, Exit Price: 763.81, P&L: -7.83
# Ticker: ADANIPORTS.NS, Entry Date: 2023-01-20, Action: SHORT (Buy for long, Sell for short), Entry Price: 763.81, Exit Date: 2023-01-23, Exit Price: 766.12, P&L: -2.31
# Ticker: ADANIPORTS.NS, Entry Date: 2023-01-23, Action: LONG (Buy for long, Sell for short), Entry Price: 766.12, Exit Date: 2023-01-24, Exit Price: 757.07, P&L: -9.06
# Ticker: ADANIPORTS.NS, Entry Date: 2023-01-24, Action: SHORT (Buy for long, Sell for short), Entry Price: 757.07, Exit Date: 2023-01-31, Exit Price: 590.57, P&L: 166.49
# Ticker: ADANIPORTS.NS, Entry Date: 2023-01-31, Action: LONG (Buy for long, Sell for short), Entry Price: 590.57, Exit Date: 2023-02-02, Exit Price: 501.99, P&L: -88.59
# Ticker: ADANIPORTS.NS, Entry Date: 2023-02-02, Action: SHORT (Buy for long, Sell for short), Entry Price: 501.99, Exit Date: 2023-02-07, Exit Price: 541.36, P&L: -39.37
# Ticker: ADANIPORTS.NS, Entry Date: 2023-02-07, Action: LONG (Buy for long, Sell for short), Entry Price: 541.36, Exit Date: 2023-02-08, Exit Price: 555.14, P&L: 13.78
# Ticker: ADANIPORTS.NS, Entry Date: 2023-02-08, Action: SHORT (Buy for long, Sell for short), Entry Price: 555.14, Exit Date: 2023-02-09, Exit Price: 578.02, P&L: -22.88
# Ticker: ADANIPORTS.NS, Entry Date: 2023-02-09, Action: LONG (Buy for long, Sell for short), Entry Price: 578.02, Exit Date: 2023-02-14, Exit Price: 542.34, P&L: -35.68
# Ticker: ADANIPORTS.NS, Entry Date: 2023-02-14, Action: SHORT (Buy for long, Sell for short), Entry Price: 542.34, Exit Date: 2023-02-15, Exit Price: 558.88, P&L: -16.54
# Ticker: ADANIPORTS.NS, Entry Date: 2023-02-15, Action: LONG (Buy for long, Sell for short), Entry Price: 558.88, Exit Date: 2023-02-16, Exit Price: 570.89, P&L: 12.01
# Ticker: ADANIPORTS.NS, Entry Date: 2023-02-16, Action: SHORT (Buy for long, Sell for short), Entry Price: 570.89, Exit Date: 2023-02-20, Exit Price: 558.39, P&L: 12.50
# Ticker: ADANIPORTS.NS, Entry Date: 2023-02-20, Action: LONG (Buy for long, Sell for short), Entry Price: 558.39, Exit Date: 2023-02-23, Exit Price: 531.02, P&L: -27.36
# ...
# Ticker: AXISBANK.NS, Entry Date: 2023-06-09, Action: SHORT (Buy for long, Sell for short), Entry Price: 964.44, Exit Date: 2023-06-13, Exit Price: 971.73, P&L: -7.28
# Ticker: AXISBANK.NS, Entry Date: 2023-06-13, Action: LONG (Buy for long, Sell for short), Entry Price: 971.73, Exit Date: 2023-06-15, Exit Price: 985.74, P&L: 14.01
# Ticker: AXISBANK.NS, Entry Date: 2023-06-15, Action: SHORT (Buy for long, Sell for short), Entry Price: 985.74, Exit Date: 2023-06-19, Exit Price: 981.25, P&L: 4.49
# Ticker: AXISBANK.NS, Entry Date: 2023-06-19, Action: LONG (Buy for long, Sell for short), Entry Price: 981.25, Exit Date: 2023-06-22, Exit Price: 959.66, P&L: -21.59
# Ticker: AXISBANK.NS, Entry Date: 2023-06-22, Action: SHORT (Buy for long, Sell for short), Entry Price: 959.66, Exit Date: 2023-06-27, Exit Price: 964.45, P&L: -4.79
# Ticker: AXISBANK.NS, Entry Date: 2023-06-27, Action: LONG (Buy for long, Sell for short), Entry Price: 964.45, Exit Date: 2023-07-04, Exit Price: 979.51, P&L: 15.06
# Ticker: AXISBANK.NS, Entry Date: 2023-07-04, Action: SHORT (Buy for long, Sell for short), Entry Price: 979.51, Exit Date: 2023-07-07, Exit Price: 974.66, P&L: 4.84
# Ticker: AXISBANK.NS, Entry Date: 2023-07-07, Action: LONG (Buy for long, Sell for short), Entry Price: 974.66, Exit Date: 2023-07-18, Exit Price: 962.43, P&L: -12.23
# Ticker: AXISBANK.NS, Entry Date: 2023-09-25, Action: SHORT (Buy for long, Sell for short), Entry Price: 1013.55, Exit Date: 2023-09-26, Exit Price: 1017.34, P&L: -3.79
# Ticker: AXISBANK.NS, Entry Date: 2023-09-26, Action: LONG (Buy for long, Sell for short), Entry Price: 1017.34, Exit Date: 2023-09-27, Exit Price: 1008.31, P&L: -9.04
# Ticker: AXISBANK.NS, Entry Date: 2023-09-27, Action: SHORT (Buy for long, Sell for short), Entry Price: 1008.31, Exit Date: 2023-09-28, Exit Price: 1025.33, P&L: -17.02
# Ticker: AXISBANK.NS, Entry Date: 2023-09-28, Action: LONG (Buy for long, Sell for short), Entry Price: 1025.33, Exit Date: 2023-10-05, Exit Price: 998.38, P&L: -26.96
# Ticker: AXISBANK.NS, Entry Date: 2023-10-05, Action: SHORT (Buy for long, Sell for short), Entry Price: 998.38, Exit Date: 2023-10-06, Exit Price: 1003.37, P&L: -4.99
# Ticker: AXISBANK.NS, Entry Date: 2023-10-06, Action: LONG (Buy for long, Sell for short), Entry Price: 1003.37, Exit Date: 2023-10-09, Exit Price: 993.18, P&L: -10.18
# Ticker: AXISBANK.NS, Entry Date: 2023-10-09, Action: SHORT (Buy for long, Sell for short), Entry Price: 993.18, Exit Date: 2023-10-10, Exit Price: 998.28, P&L: -5.09
# Ticker: AXISBANK.NS, Entry Date: 2023-10-10, Action: LONG (Buy for long, Sell for short), Entry Price: 998.28, Exit Date: 2023-10-23, Exit Price: 978.41, P&L: -19.87
# Ticker: AXISBANK.NS, Entry Date: 2023-12-06, Action: SHORT (Buy for long, Sell for short), Entry Price: 1133.26, Exit Date: 2023-12-08, Exit Price: 1114.04, P&L: 19.22
# Ticker: AXISBANK.NS, Entry Date: 2023-12-08, Action: LONG (Buy for long, Sell for short), Entry Price: 1114.04, Exit Date: 2023-12-12, Exit Price: 1118.18, P&L: 4.14
# Ticker: AXISBANK.NS, Entry Date: 2023-12-12, Action: SHORT (Buy for long, Sell for short), Entry Price: 1118.18, Exit Date: 2023-12-15, Exit Price: 1117.38, P&L: 0.80
# Ticker: AXISBANK.NS, Entry Date: 2023-12-15, Action: LONG (Buy for long, Sell for short), Entry Price: 1117.38, Exit Date: 2023-12-19, Exit Price: 1121.97, P&L: 4.59
# Ticker: AXISBANK.NS, Entry Date: 2023-12-19, Action: SHORT (Buy for long, Sell for short), Entry Price: 1121.97, Exit Date: 2023-12-22, Exit Price: 1093.62, P&L: 28.35
# Ticker: AXISBANK.NS, Entry Date: 2023-12-22, Action: LONG (Buy for long, Sell for short), Entry Price: 1093.62, Exit Date: 2023-12-28, Exit Price: 1105.45, P&L: 11.83
# Ticker: AXISBANK.NS, Entry Date: 2023-12-28, Action: SHORT (Buy for long, Sell for short), Entry Price: 1105.45, Exit Date: 2023-12-29, Exit Price: 1099.66, P&L: 5.79
# Ticker: AXISBANK.NS, Entry Date: 2023-12-29, Action: LONG (Buy for long, Sell for short), Entry Price: 1099.66, Exit Date: 2024-01-03, Exit Price: 1089.23, P&L: -10.43
# Ticker: AXISBANK.NS, Entry Date: 2024-01-03, Action: SHORT (Buy for long, Sell for short), Entry Price: 1089.23, Exit Date: 2024-01-08, Exit Price: 1143.14, P&L: -53.91
# Ticker: AXISBANK.NS, Entry Date: 2024-01-08, Action: LONG (Buy for long, Sell for short), Entry Price: 1143.14, Exit Date: 2024-01-09, Exit Price: 1126.72, P&L: -16.42
# Ticker: AXISBANK.NS, Entry Date: 2024-01-09, Action: SHORT (Buy for long, Sell for short), Entry Price: 1126.72, Exit Date: 2024-01-23, Exit Price: 1124.07, P&L: 2.65
# Ticker: AXISBANK.NS, Entry Date: 2024-01-30, Action: LONG (Buy for long, Sell for short), Entry Price: 1058.33, Exit Date: 2024-01-31, Exit Price: 1046.50, P&L: -11.83
# Ticker: AXISBANK.NS, Entry Date: 2024-01-31, Action: SHORT (Buy for long, Sell for short), Entry Price: 1046.50, Exit Date: 2024-02-01, Exit Price: 1070.91, P&L: -24.41
# Ticker: AXISBANK.NS, Entry Date: 2024-02-01, Action: LONG (Buy for long, Sell for short), Entry Price: 1070.91, Exit Date: 2024-02-05, Exit Price: 1065.32, P&L: -5.59
# Ticker: AXISBANK.NS, Entry Date: 2024-02-05, Action: SHORT (Buy for long, Sell for short), Entry Price: 1065.32, Exit Date: 2024-02-12, Exit Price: 1049.69, P&L: 15.62
# Ticker: AXISBANK.NS, Entry Date: 2024-02-12, Action: LONG (Buy for long, Sell for short), Entry Price: 1049.69, Exit Date: 2024-02-13, Exit Price: 1049.29, P&L: -0.40
# Ticker: AXISBANK.NS, Entry Date: 2024-02-13, Action: SHORT (Buy for long, Sell for short), Entry Price: 1049.29, Exit Date: 2024-02-26, Exit Price: 1091.67, P&L: -42.38
# Ticker: AXISBANK.NS, Entry Date: 2024-07-11, Action: LONG (Buy for long, Sell for short), Entry Price: 1298.94, Exit Date: 2024-07-12, Exit Price: 1292.80, P&L: -6.14
# Ticker: AXISBANK.NS, Entry Date: 2024-07-12, Action: SHORT (Buy for long, Sell for short), Entry Price: 1292.80, Exit Date: 2024-07-15, Exit Price: 1315.58, P&L: -22.78
# Ticker: AXISBANK.NS, Entry Date: 2024-07-15, Action: LONG (Buy for long, Sell for short), Entry Price: 1315.58, Exit Date: 2024-07-16, Exit Price: 1306.33, P&L: -9.24
# Ticker: AXISBANK.NS, Entry Date: 2024-07-16, Action: SHORT (Buy for long, Sell for short), Entry Price: 1306.33, Exit Date: 2024-07-18, Exit Price: 1298.89, P&L: 7.44
# Ticker: AXISBANK.NS, Entry Date: 2024-07-18, Action: LONG (Buy for long, Sell for short), Entry Price: 1298.89, Exit Date: 2024-07-22, Exit Price: 1282.25, P&L: -16.64
# Ticker: AXISBANK.NS, Entry Date: 2024-07-22, Action: SHORT (Buy for long, Sell for short), Entry Price: 1282.25, Exit Date: 2024-07-23, Exit Price: 1287.40, P&L: -5.15
# Ticker: AXISBANK.NS, Entry Date: 2024-07-23, Action: LONG (Buy for long, Sell for short), Entry Price: 1287.40, Exit Date: 2024-07-26, Exit Price: 1164.01, P&L: -123.39
# Ticker: AXISBANK.NS, Entry Date: 2024-07-26, Action: SHORT (Buy for long, Sell for short), Entry Price: 1164.01, Exit Date: 2024-08-01, Exit Price: 1167.00, P&L: -3.00
# Ticker: AXISBANK.NS, Entry Date: 2024-08-01, Action: LONG (Buy for long, Sell for short), Entry Price: 1167.00, Exit Date: 2024-08-05, Exit Price: 1141.02, P&L: -25.98
# Ticker: AXISBANK.NS, Entry Date: 2024-08-05, Action: SHORT (Buy for long, Sell for short), Entry Price: 1141.02, Exit Date: 2024-08-08, Exit Price: 1132.13, P&L: 8.89
# Ticker: AXISBANK.NS, Entry Date: 2024-08-08, Action: LONG (Buy for long, Sell for short), Entry Price: 1132.13, Exit Date: 2024-08-12, Exit Price: 1145.02, P&L: 12.89
# Ticker: AXISBANK.NS, Entry Date: 2024-08-12, Action: SHORT (Buy for long, Sell for short), Entry Price: 1145.02, Exit Date: 2024-08-13, Exit Price: 1160.36, P&L: -15.34
# Ticker: AXISBANK.NS, Entry Date: 2024-08-13, Action: LONG (Buy for long, Sell for short), Entry Price: 1160.36, Exit Date: 2024-08-16, Exit Price: 1165.40, P&L: 5.05
# Ticker: AXISBANK.NS, Entry Date: 2024-08-16, Action: SHORT (Buy for long, Sell for short), Entry Price: 1165.40, Exit Date: 2024-08-19, Exit Price: 1168.00, P&L: -2.60
# Ticker: AXISBANK.NS, Entry Date: 2024-08-19, Action: LONG (Buy for long, Sell for short), Entry Price: 1168.00, Exit Date: 2024-08-20, Exit Price: 1157.01, P&L: -10.99
# Ticker: AXISBANK.NS, Entry Date: 2024-08-20, Action: SHORT (Buy for long, Sell for short), Entry Price: 1157.01, Exit Date: 2024-09-02, Exit Price: 1175.00, P&L: -17.98
# Ticker: AXISBANK.NS, Entry Date: 2024-09-27, Action: LONG (Buy for long, Sell for short), Entry Price: 1271.91, Exit Date: 2024-10-01, Exit Price: 1227.05, P&L: -44.86
# Ticker: AXISBANK.NS, Entry Date: 2024-10-01, Action: SHORT (Buy for long, Sell for short), Entry Price: 1227.05, Exit Date: 2024-10-09, Exit Price: 1153.01, P&L: 74.04
# Ticker: AXISBANK.NS, Entry Date: 2024-10-09, Action: LONG (Buy for long, Sell for short), Entry Price: 1153.01, Exit Date: 2024-10-15, Exit Price: 1165.10, P&L: 12.09
# Ticker: AXISBANK.NS, Entry Date: 2024-10-15, Action: SHORT (Buy for long, Sell for short), Entry Price: 1165.10, Exit Date: 2024-10-17, Exit Price: 1150.02, P&L: 15.09
# Ticker: AXISBANK.NS, Entry Date: 2024-10-17, Action: LONG (Buy for long, Sell for short), Entry Price: 1150.02, Exit Date: 2024-10-18, Exit Price: 1157.01, P&L: 6.99
# Ticker: AXISBANK.NS, Entry Date: 2024-10-18, Action: SHORT (Buy for long, Sell for short), Entry Price: 1157.01, Exit Date: 2024-10-21, Exit Price: 1195.83, P&L: -38.82
# Ticker: AXISBANK.NS, Entry Date: 2024-10-21, Action: LONG (Buy for long, Sell for short), Entry Price: 1195.83, Exit Date: 2024-11-01, Exit Price: 1163.06, P&L: -32.77
# Ticker: AXISBANK.NS, Entry Date: 2024-12-27, Action: SHORT (Buy for long, Sell for short), Entry Price: 1077.18, Exit Date: 2024-12-30, Exit Price: 1073.18, P&L: 4.00
# Ticker: AXISBANK.NS, Entry Date: 2024-12-30, Action: LONG (Buy for long, Sell for short), Entry Price: 1073.18, Exit Date: 2024-12-31, Exit Price: 1061.09, P&L: -12.09
# Ticker: AXISBANK.NS, Entry Date: 2024-12-31, Action: SHORT (Buy for long, Sell for short), Entry Price: 1061.09, Exit Date: 2025-01-01, Exit Price: 1063.24, P&L: -2.15
# Ticker: AXISBANK.NS, Entry Date: 2025-01-01, Action: LONG (Buy for long, Sell for short), Entry Price: 1063.24, Exit Date: 2025-01-07, Exit Price: 1063.64, P&L: 0.40
# Ticker: AXISBANK.NS, Entry Date: 2025-01-07, Action: SHORT (Buy for long, Sell for short), Entry Price: 1063.64, Exit Date: 2025-01-08, Exit Price: 1062.84, P&L: 0.80
# Ticker: AXISBANK.NS, Entry Date: 2025-01-08, Action: LONG (Buy for long, Sell for short), Entry Price: 1062.84, Exit Date: 2025-01-10, Exit Price: 1055.35, P&L: -7.49
# Ticker: AXISBANK.NS, Entry Date: 2025-01-10, Action: SHORT (Buy for long, Sell for short), Entry Price: 1055.35, Exit Date: 2025-01-14, Exit Price: 1052.05, P&L: 3.30
# Ticker: AXISBANK.NS, Entry Date: 2025-01-14, Action: LONG (Buy for long, Sell for short), Entry Price: 1052.05, Exit Date: 2025-01-16, Exit Price: 1033.02, P&L: -19.03
# Ticker: AXISBANK.NS, Entry Date: 2025-01-16, Action: SHORT (Buy for long, Sell for short), Entry Price: 1033.02, Exit Date: 2025-01-17, Exit Price: 999.15, P&L: 33.87
# Ticker: AXISBANK.NS, Entry Date: 2025-01-17, Action: LONG (Buy for long, Sell for short), Entry Price: 999.15, Exit Date: 2025-01-22, Exit Price: 974.92, P&L: -24.23
# Ticker: AXISBANK.NS, Entry Date: 2025-01-22, Action: SHORT (Buy for long, Sell for short), Entry Price: 974.92, Exit Date: 2025-01-27, Exit Price: 942.29, P&L: 32.62
# Ticker: AXISBANK.NS, Entry Date: 2025-01-27, Action: LONG (Buy for long, Sell for short), Entry Price: 942.29, Exit Date: 2025-01-30, Exit Price: 983.81, P&L: 41.51
# Ticker: AXISBANK.NS, Entry Date: 2025-01-30, Action: SHORT (Buy for long, Sell for short), Entry Price: 983.81, Exit Date: 2025-01-31, Exit Price: 981.16, P&L: 2.65
# Ticker: AXISBANK.NS, Entry Date: 2025-01-31, Action: LONG (Buy for long, Sell for short), Entry Price: 981.16, Exit Date: 2025-02-03, Exit Price: 986.26, P&L: 5.10
# Ticker: AXISBANK.NS, Entry Date: 2025-02-03, Action: SHORT (Buy for long, Sell for short), Entry Price: 986.26, Exit Date: 2025-02-04, Exit Price: 993.15, P&L: -6.89
# Ticker: AXISBANK.NS, Entry Date: 2025-02-04, Action: LONG (Buy for long, Sell for short), Entry Price: 993.15, Exit Date: 2025-02-06, Exit Price: 1011.14, P&L: 17.98
# Ticker: AXISBANK.NS, Entry Date: 2025-02-06, Action: SHORT (Buy for long, Sell for short), Entry Price: 1011.14, Exit Date: 2025-02-07, Exit Price: 1018.63, P&L: -7.49
# Ticker: AXISBANK.NS, Entry Date: 2025-02-07, Action: LONG (Buy for long, Sell for short), Entry Price: 1018.63, Exit Date: 2025-02-17, Exit Price: 991.60, P&L: -27.03
# Ticker: AXISBANK.NS, Entry Date: 2025-02-17, Action: SHORT (Buy for long, Sell for short), Entry Price: 991.60, Exit Date: 2025-02-19, Exit Price: 990.80, P&L: 0.80
# Ticker: AXISBANK.NS, Entry Date: 2025-02-19, Action: LONG (Buy for long, Sell for short), Entry Price: 990.80, Exit Date: 2025-03-04, Exit Price: 1000.25, P&L: 9.44
# Ticker: AXISBANK.NS, Entry Date: 2025-04-01, Action: LONG (Buy for long, Sell for short), Entry Price: 1092.27, Exit Date: 2025-04-02, Exit Price: 1090.77, P&L: -1.50
# Ticker: AXISBANK.NS, Entry Date: 2025-04-02, Action: SHORT (Buy for long, Sell for short), Entry Price: 1090.77, Exit Date: 2025-04-03, Exit Price: 1077.98, P&L: 12.79
# Ticker: AXISBANK.NS, Entry Date: 2025-04-03, Action: LONG (Buy for long, Sell for short), Entry Price: 1077.98, Exit Date: 2025-04-16, Exit Price: 1121.74, P&L: 43.76
# Ticker: AXISBANK.NS, Entry Date: 2025-04-23, Action: SHORT (Buy for long, Sell for short), Entry Price: 1224.25, Exit Date: 2025-04-24, Exit Price: 1198.08, P&L: 26.18
# Ticker: AXISBANK.NS, Entry Date: 2025-04-24, Action: LONG (Buy for long, Sell for short), Entry Price: 1198.08, Exit Date: 2025-05-06, Exit Price: 1176.99, P&L: -21.08
# Ticker: AXISBANK.NS, Entry Date: 2025-05-06, Action: SHORT (Buy for long, Sell for short), Entry Price: 1176.99, Exit Date: 2025-05-08, Exit Price: 1169.00, P&L: 7.99
# Ticker: AXISBANK.NS, Entry Date: 2025-05-08, Action: LONG (Buy for long, Sell for short), Entry Price: 1169.00, Exit Date: 2025-05-20, Exit Price: 1206.97, P&L: 37.97
# Ticker: AXISBANK.NS, Entry Date: 2025-05-21, Action: SHORT (Buy for long, Sell for short), Entry Price: 1196.08, Exit Date: 2025-06-03, Exit Price: 1193.98, P&L: 2.10
# Ticker: AXISBANK.NS, Entry Date: 2025-07-25, Action: SHORT (Buy for long, Sell for short), Entry Price: 1086.10, Exit Date: 2025-07-28, Exit Price: 1080.90, P&L: 5.20
# Ticker: AXISBANK.NS, Entry Date: 2025-07-28, Action: LONG (Buy for long, Sell for short), Entry Price: 1080.90, Exit Date: 2025-07-30, Exit Price: 1070.50, P&L: -10.40
# Ticker: AXISBANK.NS, Entry Date: 2025-07-30, Action: SHORT (Buy for long, Sell for short), Entry Price: 1070.50, Exit Date: 2025-07-31, Exit Price: 1066.00, P&L: 4.50
# Ticker: AXISBANK.NS, Entry Date: 2025-07-31, Action: LONG (Buy for long, Sell for short), Entry Price: 1066.00, Exit Date: 2025-08-04, Exit Price: 1064.40, P&L: -1.60
# Ticker: AXISBANK.NS, Entry Date: 2025-08-04, Action: SHORT (Buy for long, Sell for short), Entry Price: 1064.40, Exit Date: 2025-08-05, Exit Price: 1068.00, P&L: -3.60
# Ticker: AXISBANK.NS, Entry Date: 2025-08-05, Action: LONG (Buy for long, Sell for short), Entry Price: 1068.00, Exit Date: 2025-08-05, Exit Price: 1070.80, P&L: 2.80
#
# Summary: Total Trades: 892, Win Percentage: 41.26%, Total P&L: -2542.12
# /var/folders/mn/tx231v5158797chnp22wm9000000gp/T/ipykernel_63255/2074742764.py:164: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   adx = talib.ADX(df['High'][:date], df['Low'][:date], df['Close'][:date], timeperiod=adx_period)[-1]
# /var/folders/mn/tx231v5158797chnp22wm9000000gp/T/ipykernel_63255/2074742764.py:235: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   exit_price = df['Close'][-1]  # Use close if no next open
