# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
===============================================================
Strategy & Pipeline — Quick Reference
===============================================================

ENTRY (long-only)
-----------------
Signal day (D0):
  • Trend: EMA10 > EMA20.
  • Pattern: Two consecutive green candles (D-1 and D0) AND the D0 candle's
    O, H, L, C are each strictly > the D-1 candle's respective O, H, L, C.
  • Confirmation: At least ONE of the following is true on D0:
      - RSI > 50
      - MACD line > signal (hist > 0)
      - ADX > 20 AND +DI > -DI
      - Close > SMA50
      - Close > Bollinger middle band

Execution day (D1):
  • If configured (entry_on_next_open=True), the buy is placed at D1's Open.
  • Stop & Target are set off the executed entry price:
      SL = entry_price * (1 - stop_loss_pct)
      TP = entry_price * (1 + target_pct)

EXIT
----
Checked every bar after entry:
  1) Hard StopLoss (HSL): If next bar’s Low ≤ SL → exit (filled=SL).
  2) TakeProfit (TP):     If next bar’s High ≥ TP → exit (filled=TP).
     (If both SL and TP touch on the same bar, we assume TP priority and
      mark filled=TP — optimistic fill.)
  3) Trend reverse: If EMA10 < EMA20 on the signal bar, exit next open.

Exit reasons are verbose in CSV:
  • "StopLoss hit (5.0%). filled=..., SL=..., ret=...%, held=...d"
  • "TakeProfit hit (10.0%). filled=..., TP=..., ret=...%, held=...d"
  • "Trend reverse: EMA10 cross↓ below EMA20 (10=..., 20=...);
     bearish=RSI<50, MACD≤Signal, ...; filled=..., ret=...%, held=...d"

PORTFOLIO PIPELINE (daily loop)
-------------------------------
1) Aggregate all per-ticker BUY 'candidate' legs dated for D1 from signals on D0.
2) Optional filter: price within >= {within_pct_of_52w_high:.0%} of 52-week high.
3) Exclude tickers we already hold.
4) Rank survivors by VOLAᵣ (excess return vs benchmark / own volatility; 252d lookback).
5) Capacity gate:
   • slots = max_concurrent_positions - current_open_positions
   • pick = min(top_k_daily, slots)
6) Sizing via Markowitz (MVO), long-only:
   • Compute mu (means) and Sigma (cov) on 252d daily returns on D0.
   • Solve for weights that maximize mean/vol (with long-only projection).
   • Cap *deployable cash* to deploy_cash_frac × current cash (e.g., 25%).
   • Allocate that capped bucket by MVO weights across today's picks.
7) Execute BUYs at D1 (close or open per config), deduct fees, open positions.
8) Process SELLs before BUYs each day; update equity curve after all legs.

top_k_daily vs max_concurrent_positions
---------------------------------------
• If you have 1 open position and max_concurrent_positions=4, you have 3 slots.
• Even if top_k_daily=2, you'll only fill up to min(2, 3)=2 new entries on that day.
• No position becomes "unavailable"; we just respect the smaller of the two limits.

MINI TIMELINE EXAMPLE
---------------------
Assume: entry_on_next_open=True, stop=5%, target=10%, deploy_cash_frac=25%,
        top_k_daily=3, max_concurrent_positions=4, initial cash=₹200,000.

D0 (signal day):
  Ticker A meets: EMA10>EMA20, two strict green candles, confirmations: RSI>50, Close>SMA50.
  Ticker B meets: EMA10>EMA20, two strict greens, confirmations: MACD>Signal.
  Ticker C meets: EMA10>EMA20, two strict greens, confirmations: Close>BBmid.
  → All three create BUY 'candidate' legs for D1.

  Portfolio selection on D0 for D1 execution:
    • 52w filter removes none.
    • Already-held: none.
    • Rank by VOLAᵣ (252d): A=1.2, B=0.9, C=0.6 → order: A, B, C.
    • slots = 4 - 0 = 4; pick = min(top_k_daily=3, slots=4) = 3 → keep A,B,C.
    • deployable_cash = 25% * 200k = ₹50,000
    • MVO over (A,B,C) returns  weights e.g. [0.50, 0.30, 0.20]
      → Allocations: A=₹25,000; B=₹15,000; C=₹10,000

D1 (execution/open):
  • BUY A, B, C at D1 Open; compute shares=alloc / price, pay fees.
  • For each position, set SL and TP from the executed entry price.

D3:
  • A hits TP intraday → SELL recorded with reason:
    "TakeProfit hit (10.0%). filled=..., TP=..., ret=..., held=2d"
  • B shows EMA10<EMA20 on D3 bar → exit at D4 Open with reason:
    "Trend reverse: EMA10 cross↓ below EMA20 (10=..., 20=...); bearish=...; filled=..."
  • C continues to run.

FILES
-----
outputs/trades_legs_*.csv         : All executed legs (BUY and SELL) with rich reasons
outputs/trades_roundtrips_*.csv    : Pair-matched entries/exits with final P&L stats
outputs/equity_*.csv / equity_*.png: Daily equity series and plot
outputs/metrics_*.json             : Key summary stats (CAGR, Sharpe, MDD, Win rate, trades)
"""

import os, json, math, warnings, logging
from dataclasses import dataclass
from typing import Dict, List, Tuple, Optional

import numpy as np
import pandas as pd

try:
    import yfinance as yf
    import matplotlib.pyplot as plt
except Exception:
    pass

warnings.filterwarnings("ignore", category=FutureWarning)

# =========================
# LOGGING
# =========================
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)
log = logging.getLogger("ema10_ema20_2green_confirm_v1")

# =========================
# CONFIG
# =========================
@dataclass
class Config:
    # Data
    start_date: str = "2015-01-01"
    end_date: str   = "2025-01-01"
    static_symbols: Optional[List[str]] = None
    static_symbols_path: Optional[str] = None
    cache_dir: str = "cache"
    out_dir: str   = "outputs"
    plot: bool     = True

    # --- Strategy params ---
    ema_fast: int = 10            # EMA10
    ema_slow: int = 20            # EMA20
    sma_confirm_len: int = 50     # SMA50 for confirm
    sma_trend_len: int = 200      # SMA200 (kept for breadth/context if needed)
    rsi_len: int = 14
    macd_fast: int = 12
    macd_slow: int = 26
    macd_signal: int = 9
    bb_len: int = 20
    bb_std: float = 2.0
    adx_len: int = 14
    adx_min: float = 20.0

    # Exits
    stop_loss_pct: float = 0.10
    target_pct: float    = 0.10

    # Portfolio
    apply_fees: bool    = True
    initial_capital: float = 500_000.0
    max_concurrent_positions: int = 5
    deploy_cash_frac: float = 0.30
    entry_on_next_open: bool = True
    exit_on_next_open: bool  = True

    # Candidate ranking & filters
    benchmark_try: Tuple[str,...] = ("^CNX500","^CRSLDX","^NSE500","^NIFTY500","^BSE500","^NSEI")
    volar_lookback: int = 252
    filter_52w_window: int = 252
    within_pct_of_52w_high: float = 0.50
    top_k_daily: int = 300

    # Liquidity guards (OFF by default)
    enable_basic_liquidity: bool = False
    min_price_inr: float = 50.0
    min_avg_vol_20d: float = 50_000.0

CFG = Config()

# =========================
# FEES (per user spec)
# =========================
APPLY_FEES = True

def calc_fees(turnover_buy: float, turnover_sell: float) -> float:
    if not APPLY_FEES:
        return 0.0
    BROKER_PCT = 0.001
    BROKER_MIN = 5.0
    BROKER_CAP = 20.0
    STT_PCT = 0.001
    STAMP_BUY_PCT = 0.00015
    EXCH_PCT = 0.0000297
    SEBI_PCT = 0.000001
    IPFT_PCT = 0.000001
    GST_PCT = 0.18
    DP_SELL = 20.0 if turnover_sell >= 100 else 0.0

    def _broker(turnover):
        if turnover <= 0:
            return 0.0
        fee = turnover * BROKER_PCT
        fee = max(BROKER_MIN, min(fee, BROKER_CAP))
        return fee

    br_buy  = _broker(turnover_buy)
    br_sell = _broker(turnover_sell)
    stt   = STT_PCT * (turnover_buy + turnover_sell)
    stamp = STAMP_BUY_PCT * turnover_buy
    exch  = EXCH_PCT * (turnover_buy + turnover_sell)
    sebi  = SEBI_PCT * (turnover_buy + turnover_sell)
    ipft  = IPFT_PCT * (turnover_buy + turnover_sell)
    dp    = DP_SELL
    gst_base = br_buy + br_sell + dp + exch + sebi + ipft
    gst   = GST_PCT * gst_base
    return float((br_buy + br_sell) + stt + stamp + exch + sebi + ipft + dp + gst)

# =========================
# Helpers
# =========================
def ensure_dirs(*paths):
    for p in paths:
        os.makedirs(p, exist_ok=True)

def today_str():
    return pd.Timestamp.today(tz="Asia/Kolkata").strftime("%Y-%m-%d")

def load_static_symbols(static_symbols: Optional[List[str]], static_symbols_path: Optional[str]) -> List[str]:
    syms: List[str] = []
    if static_symbols and len(static_symbols) > 0:
        syms = list(static_symbols)
    elif static_symbols_path and os.path.exists(static_symbols_path):
        with open(static_symbols_path, "r") as f:
            syms = [line.strip() for line in f if line.strip()]
    else:
        raise ValueError(
            "Provide CFG.static_symbols=[...] ('.NS' suffixes) or set CFG.static_symbols_path "
            "to a file containing one symbol per line."
        )
    out = []
    for s in syms:
        s = s.strip().upper()
        if not s.endswith(".NS"):
            s = f"{s}.NS"
        out.append(s)
    seen = set()
    uniq = []
    for s in out:
        if s not in seen:
            uniq.append(s)
            seen.add(s)
    return uniq

def fetch_prices(tickers: List[str], start: str, end: Optional[str], cache_dir: str) -> Dict[str, pd.DataFrame]:
    ensure_dirs(cache_dir)
    data = {}
    end = end or today_str()
    for ticker in tickers:
        cache_path = os.path.join(cache_dir, f"{ticker.replace('^', '_')}.parquet")
        if os.path.exists(cache_path):
            try:
                df = pd.read_parquet(cache_path)
                if len(df) and pd.to_datetime(df.index[-1]).strftime("%Y-%m-%d") >= end:
                    data[ticker] = df
                    continue
            except Exception:
                pass
        try:
            df = yf.download(ticker, start=start, end=end, auto_adjust=True, progress=False, multi_level_index=False)
            if df is None or df.empty:
                continue
            df = df.rename(columns=str.title)  # Open, High, Low, Close, Volume
            df = df[['Open', 'High', 'Low', 'Close', 'Volume']].dropna()
            df.index.name = "date"
            df.to_parquet(cache_path)
            data[ticker] = df
        except Exception:
            continue
    return data

def ema(series: pd.Series, span: int) -> pd.Series:
    return series.ewm(span=span, adjust=False, min_periods=span).mean()

def sma(series: pd.Series, window: int) -> pd.Series:
    return series.rolling(window).mean()

def rsi(series: pd.Series, length: int = 14) -> pd.Series:
    delta = series.diff()
    gain = (delta.where(delta > 0, 0.0)).rolling(length).mean()
    loss = (-delta.where(delta < 0, 0.0)).rolling(length).mean()
    rs = gain / loss.replace(0.0, np.nan)
    out = 100 - (100 / (1 + rs))
    return out.fillna(50.0)

def macd(series: pd.Series, fast=12, slow=26, signal=9):
    ema_fast = series.ewm(span=fast, adjust=False, min_periods=slow).mean()
    ema_slow = series.ewm(span=slow, adjust=False, min_periods=slow).mean()
    macd_line = ema_fast - ema_slow
    macd_signal = macd_line.ewm(span=signal, adjust=False, min_periods=signal).mean()
    hist = macd_line - macd_signal
    return macd_line, macd_signal, hist

def _true_range(high: pd.Series, low: pd.Series, prev_close: pd.Series) -> pd.Series:
    return pd.concat([
        (high - low).abs(),
        (high - prev_close).abs(),
        (low - prev_close).abs()
    ], axis=1).max(axis=1)

def dmi_adx(high: pd.Series, low: pd.Series, close: pd.Series, length: int = 14):
    prev_high = high.shift(1)
    prev_low  = low.shift(1)
    prev_close = close.shift(1)

    up_move   = high - prev_high
    down_move = prev_low - low
    plus_dm  = up_move.where((up_move > down_move) & (up_move > 0), 0.0)
    minus_dm = down_move.where((down_move > up_move) & (down_move > 0), 0.0)

    tr = _true_range(high, low, prev_close)
    alpha = 1.0 / length
    atr = tr.ewm(alpha=alpha, adjust=False, min_periods=length).mean()
    plus_di  = 100 * (plus_dm.ewm(alpha=alpha, adjust=False, min_periods=length).mean() / atr)
    minus_di = 100 * (minus_dm.ewm(alpha=alpha, adjust=False, min_periods=length).mean() / atr)

    dx = 100 * (plus_di - minus_di).abs() / (plus_di + minus_di).replace(0, np.nan)
    adx_series = dx.ewm(alpha=alpha, adjust=False, min_periods=length).mean()
    return plus_di, minus_di, adx_series

def bollinger(series: pd.Series, length=20, nstd=2.0):
    mid = series.rolling(length).mean()
    sd  = series.rolling(length).std(ddof=0)
    upper = mid + nstd * sd
    lower = mid - nstd * sd
    return mid, upper, lower

def compute_indicators(df: pd.DataFrame, cfg: Config) -> pd.DataFrame:
    out = df.copy()
    out["ema_fast"] = ema(out["Close"], cfg.ema_fast)   # 10
    out["ema_slow"] = ema(out["Close"], cfg.ema_slow)   # 20
    out["sma50"]    = sma(out["Close"], cfg.sma_confirm_len)
    out["sma200"]   = sma(out["Close"], cfg.sma_trend_len)
    out["rsi"]      = rsi(out["Close"], cfg.rsi_len)
    macd_line, macd_signal, macd_hist = macd(out["Close"], cfg.macd_fast, cfg.macd_slow, cfg.macd_signal)
    out["macd_line"] = macd_line
    out["macd_signal"] = macd_signal
    out["macd_hist"] = macd_hist
    out["bb_mid"], out["bb_up"], out["bb_low"] = bollinger(out["Close"], cfg.bb_len, cfg.bb_std)
    out["+DI"], out["-DI"], out["ADX"] = dmi_adx(out["High"], out["Low"], out["Close"], cfg.adx_len)
    out["avg_vol_20"] = out["Volume"].rolling(20).mean()
    out["high_52w"] = out["Close"].rolling(cfg.filter_52w_window).max()
    return out.dropna()

def basic_liquidity_ok(row: pd.Series, cfg: Config) -> bool:
    if not cfg.enable_basic_liquidity:
        return True
    if row["Close"] < cfg.min_price_inr:
        return False
    if row["avg_vol_20"] < cfg.min_avg_vol_20d:
        return False
    return True

# ---------- NEW ENTRY/EXIT LOGIC ----------
def two_green_strict(prev_row: pd.Series, row: pd.Series) -> bool:
    g1 = prev_row["Close"] > prev_row["Open"]
    g2 = row["Close"] > row["Open"]
    # second candle's O/H/L/C > first candle's O/H/L/C
    strictly_above = (row["Open"]  > prev_row["Open"]) and \
                     (row["High"]  > prev_row["High"]) and \
                     (row["Low"]   > prev_row["Low"])  and \
                     (row["Close"] > prev_row["Close"])
    return bool(g1 and g2 and strictly_above)

def confirmation_any(row: pd.Series, cfg: Config) -> Tuple[bool, str]:
    checks = []
    # RSI > 50
    checks.append(("RSI>50", row["rsi"] > 50.0))
    # MACD line > signal (hist>0)
    checks.append(("MACD>Signal", row["macd_hist"] > 0.0))
    # ADX>20 and +DI > -DI
    checks.append(("ADX>20 & +DI>-DI", (row["ADX"] > cfg.adx_min) and (row["+DI"] > row["-DI"])))
    # Close > SMA50
    checks.append(("Close>SMA50", row["Close"] > row["sma50"]))
    # Close > Bollinger Mid
    checks.append(("Close>BBmid", row["Close"] > row["bb_mid"]))

    passed = [name for name, ok in checks if ok]
    return (len(passed) >= 1, ", ".join(passed) if passed else "none")

def simulate_ticker(ticker: str, df: pd.DataFrame, cfg: Config):
    d = compute_indicators(df, cfg).copy()
    cols = ["ticker","side","date","price","shares","reason","signal_reason","score",
            "rsi","ADX","+DI","-DI","ema_fast","ema_slow","sma50","sma200",
            "macd_line","macd_signal","macd_hist","bb_mid","bb_up","bb_low",
            "close","high_52w"]
    if d.empty or len(d) < 60:
        return pd.DataFrame(columns=cols), pd.Series(dtype=float)

    in_pos = False
    entry_px = stop_px = tgt_px = 0.0
    entry_dt = None  # <-- added: to report held days only
    trades = []

    idx = list(d.index)

    for i in range(1, len(idx)-1):
        dt = idx[i]           # signal candle (second green)
        nxt = idx[i+1]        # execution / evaluation next bar
        prev_dt = idx[i-1]

        row = d.loc[dt]
        prev_row = d.loc[prev_dt]
        nxt_row = d.loc[nxt]

        # Trend reverse condition for exit
        trend_reverse_now = row["ema_fast"] < row["ema_slow"]

        if not in_pos:
            # ENTRY: EMA10 > EMA20 AND two strict green candles AND ≥1 confirmation
            ema_ok = row["ema_fast"] > row["ema_slow"]
            two_green_ok = two_green_strict(prev_row, row)
            confirm_ok, confirm_str = confirmation_any(row, cfg)

            if ema_ok and two_green_ok and confirm_ok and basic_liquidity_ok(row, cfg):
                # Execute at next open (or current close if configured)
                px = float(nxt_row["Open"] if cfg.entry_on_next_open else row["Close"])
                sig_reason = f"EMA10>EMA20 & 2xGreenStrict; confirms: {confirm_str}"
                score = 1.0  # placeholder; downstream selection uses VOLAᵣ
                trades.append({
                    "ticker": ticker, "side": "BUY", "date": nxt if cfg.entry_on_next_open else dt,
                    "price": px, "shares": 0, "reason": "candidate",
                    "signal_reason": sig_reason, "score": float(score),
                    "rsi": float(row["rsi"]), "ADX": float(row["ADX"]),
                    "+DI": float(row["+DI"]), "-DI": float(row["-DI"]),
                    "ema_fast": float(row["ema_fast"]), "ema_slow": float(row["ema_slow"]),
                    "sma50": float(row["sma50"]), "sma200": float(row["sma200"]),
                    "macd_line": float(row["macd_line"]), "macd_signal": float(row["macd_signal"]), "macd_hist": float(row["macd_hist"]),
                    "bb_mid": float(row["bb_mid"]), "bb_up": float(row["bb_up"]), "bb_low": float(row["bb_low"]),
                    "close": float(row["Close"]), "high_52w": float(row["high_52w"])
                })
                in_pos = True
                entry_px = px
                entry_dt = nxt if cfg.entry_on_next_open else dt  # <-- added: remember entry date for held days
                stop_px = entry_px * (1 - cfg.stop_loss_pct)
                tgt_px  = entry_px * (1 + cfg.target_pct)

        else:
            # EXIT rules: HSL / TP / Trend reverse
            hit = None
            exec_date = nxt if cfg.exit_on_next_open else dt

            # Check next bar extremes for HSL/TP
            if nxt_row["Low"] <= stop_px and nxt_row["High"] >= tgt_px:
                hit, exec_price = "target", float(tgt_px)  # optimistic fill (unchanged)
            elif nxt_row["Low"] <= stop_px:
                hit, exec_price = "stop", float(stop_px)
            elif nxt_row["High"] >= tgt_px:
                hit, exec_price = "target", float(tgt_px)
            elif trend_reverse_now:
                exec_price = float(nxt_row["Open"] if cfg.exit_on_next_open else row["Close"])
                hit = "trend_reverse"

            if hit is not None:
                # ----- Only the text below is new; exits/prices are unchanged -----
                pnl_pct = float((exec_price / entry_px - 1.0) * 100.0) if entry_px else float("nan")
                held_days = int((pd.to_datetime(exec_date) - pd.to_datetime(entry_dt)).days) if entry_dt else 0

                if hit == "stop":
                    exit_reason = (
                        f"StopLoss hit ({cfg.stop_loss_pct*100:.1f}%). "
                        f"filled={exec_price:.2f}, SL={stop_px:.2f}, ret={pnl_pct:.2f}%, held={held_days}d"
                    )
                elif hit == "target":
                    exit_reason = (
                        f"TakeProfit hit ({cfg.target_pct*100:.1f}%). "
                        f"filled={exec_price:.2f}, TP={tgt_px:.2f}, ret={pnl_pct:.2f}%, held={held_days}d"
                    )
                else:  # trend_reverse
                    crossdown = (prev_row["ema_fast"] >= prev_row["ema_slow"]) and (row["ema_fast"] < row["ema_slow"])
                    cross_txt = " cross↓" if crossdown else ""
                    exit_reason = (
                        f"Trend reverse: EMA10{cross_txt} below EMA20 "
                        f"(10={row['ema_fast']:.2f}, 20={row['ema_slow']:.2f}); "
                        f"filled={exec_price:.2f}, ret={pnl_pct:.2f}%, held={held_days}d"
                    )
                # -------------------------------------------------------------------

                trades.append({
                    "ticker": ticker, "side": "SELL", "date": exec_date,
                    "price": float(exec_price), "shares": 0, "reason": exit_reason,  # <-- reason now verbose
                    "signal_reason": "", "score": np.nan,
                    "rsi": float(row["rsi"]), "ADX": float(row["ADX"]),
                    "+DI": float(row["+DI"]), "-DI": float(row["-DI"]),
                    "ema_fast": float(row["ema_fast"]), "ema_slow": float(row["ema_slow"]),
                    "sma50": float(row["sma50"]), "sma200": float(row["sma200"]),
                    "macd_line": float(row["macd_line"]), "macd_signal": float(row["macd_signal"]), "macd_hist": float(row["macd_hist"]),
                    "bb_mid": float(row["bb_mid"]), "bb_up": float(row["bb_up"]), "bb_low": float(row["bb_low"]),
                    "close": float(row["Close"]), "high_52w": float(row["high_52w"])
                })
                in_pos = False
                entry_px = stop_px = tgt_px = 0.0
                entry_dt = None  # <-- reset

    # Force close open pos at last bar
    if in_pos:
        last_dt = d.index[-1]; row = d.loc[last_dt]
        exec_price = float(row["Close"])
        pnl_pct = float((exec_price / entry_px - 1.0) * 100.0) if entry_px else float("nan")
        held_days = int((pd.to_datetime(last_dt) - pd.to_datetime(entry_dt)).days) if entry_dt else 0
        exit_reason = (
            f"Final close (backtest end). filled={exec_price:.2f}, ret={pnl_pct:.2f}%, held={held_days}d"
        )
        trades.append({
            "ticker": ticker, "side": "SELL", "date": last_dt,
            "price": exec_price, "shares": 0, "reason": exit_reason,  # <-- verbose
            "signal_reason": "", "score": np.nan,
            "rsi": float(row["rsi"]), "ADX": float(row["ADX"]),
            "+DI": float(row["+DI"]), "-DI": float(row["-DI"]),
            "ema_fast": float(row["ema_fast"]), "ema_slow": float(row["ema_slow"]),
            "sma50": float(row["sma50"]), "sma200": float(row["sma200"]),
            "macd_line": float(row["macd_line"]), "macd_signal": float(row["macd_signal"]), "macd_hist": float(row["macd_hist"]),
            "bb_mid": float(row["bb_mid"]), "bb_up": float(row["bb_up"]), "bb_low": float(row["bb_low"]),
            "close": float(row["Close"]), "high_52w": float(row["high_52w"])
        })

    return pd.DataFrame(trades, columns=cols), pd.Series(dtype=float)


# ---------- Portfolio: unchanged engine ----------
def pick_benchmark(benchmarks: Tuple[str,...], start: str, end: Optional[str], cache_dir: str) -> Tuple[str, pd.DataFrame]:
    for t in benchmarks:
        data = fetch_prices([t], start, end, cache_dir)
        df = data.get(t)
        if df is not None and not df.empty:
            log.info("Using benchmark: %s", t)
            return t, df
    idx = pd.date_range(start=start, end=end or today_str(), freq="B")
    df = pd.DataFrame({"Close": np.ones(len(idx))}, index=idx)
    log.warning("No benchmark found; using synthetic flat series.")
    return "SYNTH_BENCH", df

def compute_volar_scores(end_dt: pd.Timestamp, tickers: List[str], data_map: Dict[str,pd.DataFrame], bench_df: pd.DataFrame, lookback: int) -> Dict[str, float]:
    scores = {}
    bser = bench_df["Close"].loc[:end_dt].pct_change().dropna().iloc[-lookback:]
    for t in tickers:
        df = data_map.get(t)
        if df is None or df.empty:
            scores[t] = 0.0
            continue
        if end_dt not in df.index:
            df = df[df.index <= end_dt]
            if df.empty:
                scores[t] = 0.0
                continue
        r = df["Close"].loc[:end_dt].pct_change().dropna().iloc[-lookback:]
        common = pd.concat([r, bser], axis=1, keys=["s","b"]).dropna()
        if common.shape[0] < max(20, int(0.4*lookback)):
            scores[t] = 0.0
            continue
        excess = common["s"] - common["b"]
        vol = common["s"].std(ddof=0)
        scores[t] = 0.0 if vol <= 1e-8 else float((excess.mean() / vol) * math.sqrt(252.0))
    return scores

def markowitz_long_only(mu: np.ndarray, Sigma: np.ndarray) -> np.ndarray:
    n = len(mu)
    eps = 1e-6
    Sigma = Sigma + eps*np.eye(n)

    def solve_lambda(lmbd: float, active_mask=None):
        if active_mask is None:
            A = np.block([[2*lmbd*Sigma, np.ones((n,1))],[np.ones((1,n)), np.zeros((1,1))]])
            b = np.concatenate([mu, np.array([1.0])])
            try:
                sol = np.linalg.solve(A, b)
                w = sol[:n]
            except np.linalg.LinAlgError:
                w = np.full(n, 1.0/n)
            return w
        else:
            idx = np.where(active_mask)[0]
            if len(idx)==0:
                return np.full(n, 1.0/n)
            S = Sigma[np.ix_(idx, idx)]
            o = np.ones(len(idx))
            m = mu[idx]
            A = np.block([[2*lmbd*S, o[:,None]],[o[None,:], np.zeros((1,1))]])
            b = np.concatenate([m, np.array([1.0])])
            try:
                sol = np.linalg.solve(A, b)
                w_sub = sol[:len(idx)]
            except np.linalg.LinAlgError:
                w_sub = np.full(len(idx), 1.0/len(idx))
            w = np.zeros(n)
            w[idx] = w_sub
            return w

    best_w = np.full(n, 1.0/n)
    best_sr = -1e9
    lambdas = np.logspace(-3, 3, 31)
    for lmbd in lambdas:
        active = np.ones(n, dtype=bool)
        w = None
        for _ in range(n):
            w = solve_lambda(lmbd, active_mask=active)
            neg = w < 0
            if not neg.any():
                break
            worst = np.argmin(w)
            active[worst] = False
        if w is None:
            continue
        w = np.clip(w, 0, None)
        if w.sum() <= 0:
            continue
        w = w / w.sum()
        mu_p = float(mu @ w)
        vol_p = float(np.sqrt(w @ Sigma @ w))
        if vol_p <= 1e-8:
            continue
        sr = mu_p / vol_p
        if sr > best_sr:
            best_sr = sr
            best_w = w.copy()
    return best_w

def aggregate_and_apply(all_trades: pd.DataFrame, data_map: Dict[str, pd.DataFrame], bench_df: pd.DataFrame, cfg: Config):
    if all_trades.empty:
        return all_trades, pd.Series(dtype=float), {}

    side_order = {"BUY": 0, "SELL": 1}
    all_trades = (all_trades
        .assign(_sorder=all_trades["side"].map(side_order))
        .sort_values(by=["date", "_sorder"], kind="stable")
        .drop(columns=["_sorder"])
        .reset_index(drop=True)
    )
    all_trades["date"] = pd.to_datetime(all_trades["date"])

    equity_curve = []
    dates = sorted(all_trades["date"].unique().tolist())
    cash = cfg.initial_capital
    open_positions = {}
    completed_legs = []

    global APPLY_FEES
    APPLY_FEES = cfg.apply_fees

    def _get_close_on(tkr, dt):
        df = data_map.get(tkr)
        if df is None or df.empty:
            return np.nan
        if dt in df.index:
            return float(df.loc[dt, "Close"])
        prev = df[df.index <= dt]
        if prev.empty:
            return np.nan
        return float(prev["Close"].iloc[-1])

    if dates:
        seed_date = pd.to_datetime(dates[0]) - pd.Timedelta(days=1)
        equity_curve.append((seed_date, float(cash)))

    # Walk dates
    for dt in dates:
        day_trades = all_trades[all_trades["date"] == dt].copy()

        # SELLs first
        for _, tr in day_trades[day_trades["side"] == "SELL"].iterrows():
            tkr = tr["ticker"]
            price = float(tr["price"])
            pos = open_positions.get(tkr)
            if pos is None:
                continue
            shares = int(pos["shares"])
            turnover_sell = shares * price
            fee = calc_fees(0.0, turnover_sell)
            pnl = (price - pos["entry_px"]) * shares
            cash += (turnover_sell - fee)
            realized = pnl - fee - pos.get("buy_fee", 0.0)
            completed_legs.append({
                "ticker": tkr, "side": "SELL", "date": dt, "price": price,
                "shares": shares, "reason": tr.get("reason",""),
                "turnover": turnover_sell, "fees_inr": fee, "pnl_inr": realized,
                "rsi": tr.get("rsi", np.nan), "ADX": tr.get("ADX", np.nan),
                "+DI": tr.get("+DI", np.nan), "-DI": tr.get("-DI", np.nan),
                "ema_fast": tr.get("ema_fast", np.nan), "ema_slow": tr.get("ema_slow", np.nan),
                "sma50": tr.get("sma50", np.nan), "sma200": tr.get("sma200", np.nan),
                "macd_line": tr.get("macd_line", np.nan), "macd_signal": tr.get("macd_signal", np.nan), "macd_hist": tr.get("macd_hist", np.nan),
                "bb_mid": tr.get("bb_mid", np.nan), "bb_up": tr.get("bb_up", np.nan), "bb_low": tr.get("bb_low", np.nan),
                "close": tr.get("close", np.nan), "high_52w": tr.get("high_52w", np.nan),
                "volar": tr.get("volar", np.nan), "mvo_weight": np.nan, "alloc_inr": np.nan
            })
            log.info("Exit %-12s px=%8.2f sh=%6d reason=%s net=%.2f cash=%.2f",
                     tkr, price, shares, tr.get("reason",""), realized, cash)
            del open_positions[tkr]

        # BUY candidates
        buys_today = day_trades[day_trades["side"] == "BUY"].copy()

        # 52w proximity filter
        if not buys_today.empty:
            keep = []
            for _, rr in buys_today.iterrows():
                df = data_map.get(rr["ticker"])
                if df is None or df.empty or dt not in df.index:
                    continue
                close = float(df.loc[dt, "Close"])
                hist = df["Close"].loc[:dt]
                window = hist.iloc[-cfg.filter_52w_window:] if len(hist)>=cfg.filter_52w_window else hist
                high_52w = float(window.max())
                if high_52w>0 and close >= cfg.within_pct_of_52w_high * high_52w:
                    keep.append(rr)
            buys_today = pd.DataFrame(keep) if keep else pd.DataFrame(columns=buys_today.columns)

        # Exclude already-held tickers
        if not buys_today.empty:
            buys_today = buys_today[~buys_today["ticker"].isin(open_positions.keys())]

        # Rank by VOLAᵣ
        if not buys_today.empty:
            tickers = buys_today["ticker"].tolist()
            volar_scores = compute_volar_scores(dt, tickers, data_map, bench_df, cfg.volar_lookback)
            buys_today["volar"] = buys_today["ticker"].map(volar_scores)
            buys_today = buys_today.sort_values("volar", ascending=False).reset_index(drop=True)

        slots = cfg.max_concurrent_positions - len(open_positions)
        selected = pd.DataFrame(columns=buys_today.columns)
        if slots > 0 and not buys_today.empty:
            selected = buys_today.head(min(cfg.top_k_daily, slots)).copy()

        if not selected.empty:
            log.info("Selected %d BUY candidates on %s:", selected.shape[0], dt.date())
            for i, rr in selected.reset_index(drop=True).iterrows():
                log.info("  %-12s volar=%6.2f rank=%d px=%8.2f", rr["ticker"], rr.get("volar",0.0), i+1, rr["price"])

            names = selected["ticker"].tolist()
            rets = []
            for t in names:
                df = data_map.get(t)
                ser = df["Close"].loc[:dt].pct_change().dropna().iloc[-cfg.volar_lookback:]
                rets.append(ser)
            R = pd.concat(rets, axis=1)
            R.columns = names
            R = R.dropna()
            if R.empty or R.shape[0] < max(20, int(0.4*cfg.volar_lookback)) or R.shape[1] == 0:
                weights = np.full(len(names), 1.0/len(names))
            else:
                mu = R.mean().values
                Sigma = R.cov().values
                weights = markowitz_long_only(mu, Sigma)

            deploy_cash = max(0.0, float(cash)) * float(cfg.deploy_cash_frac)

            if deploy_cash <= 0:
                log.info("No deployable cash (cap=%.0f%%) on %s", 100*cfg.deploy_cash_frac, dt.date())
            else:
                alloc = (weights / weights.sum()) * deploy_cash if weights.sum()>0 else np.full(len(names), deploy_cash/len(names))
                rank_map = {row["ticker"]: (idx+1) for idx, (_, row) in enumerate(selected.iterrows())}
                for w_amt, t in zip(alloc, names):
                    df_t = data_map[t]
                    price = float(df_t.loc[dt, "Close"] if dt in df_t.index else df_t["Close"].loc[:dt].iloc[-1])
                    shares = int(math.floor(w_amt / price))
                    if shares <= 0:
                        log.info("Skip BUY %-12s (alloc %.2f too small)", t, w_amt)
                        continue
                    turn = shares * price
                    fee = calc_fees(turn, 0.0)
                    total_cost = turn + fee
                    if total_cost > cash:
                        shares = int(math.floor((cash - fee) / price))
                        if shares <= 0:
                            log.info("Skip BUY %-12s due to cash/fees", t)
                            continue
                        turn = shares * price
                        total_cost = turn + fee
                    cash -= total_cost
                    open_positions[t] = {"entry_date": dt, "entry_px": price, "shares": shares, "buy_fee": fee, "entry_reason": "entry"}

                    row_sel = selected[selected["ticker"]==t].iloc[0]
                    volar_val = float(row_sel.get("volar", np.nan))
                    rank_pos = rank_map.get(t, np.nan)
                    high_52w = float(row_sel.get("high_52w", np.nan))
                    close_val = float(row_sel.get("close", np.nan))
                    pct_52w = (close_val / high_52w) if (high_52w and high_52w>0) else np.nan
                    mvo_weight_today = (w_amt / deploy_cash) if deploy_cash > 0 else 0.0
                    sig_reason = row_sel.get("signal_reason", "EMA10>EMA20 & 2xGreenStrict (≥1 confirm)")
                    reason_text = (
                        f"{sig_reason}; 52w%={pct_52w:.1%} (>= {CFG.within_pct_of_52w_high:.0%}); "
                        f"VOLAR rank {int(rank_pos)}/{len(names)} (VOLAR={volar_val:.2f}); "
                        f"MVO weight={mvo_weight_today:.1%} of capped cash ({100*cfg.deploy_cash_frac:.0f}% of available)"
                    )
                    completed_legs.append({
                        "ticker": t, "side": "BUY", "date": dt, "price": price,
                        "shares": shares, "reason": reason_text,
                        "turnover": turn, "fees_inr": fee, "pnl_inr": 0.0,
                        "rsi": float(row_sel.get("rsi", np.nan)), "ADX": float(row_sel.get("ADX", np.nan)),
                        "+DI": float(row_sel.get("+DI", np.nan)), "-DI": float(row_sel.get("-DI", np.nan)),
                        "ema_fast": float(row_sel.get("ema_fast", np.nan)), "ema_slow": float(row_sel.get("ema_slow", np.nan)),
                        "sma50": float(row_sel.get("sma50", np.nan)), "sma200": float(row_sel.get("sma200", np.nan)),
                        "macd_line": float(row_sel.get("macd_line", np.nan)), "macd_signal": float(row_sel.get("macd_signal", np.nan)), "macd_hist": float(row_sel.get("macd_hist", np.nan)),
                        "bb_mid": float(row_sel.get("bb_mid", np.nan)), "bb_up": float(row_sel.get("bb_up", np.nan)), "bb_low": float(row_sel.get("bb_low", np.nan)),
                        "close": close_val, "high_52w": high_52w,
                        "volar": volar_val, "mvo_weight": float(mvo_weight_today), "alloc_inr": float(w_amt)
                    })
                    log.info("BUY %-12s px=%8.2f sh=%6d fee=%.2f cash=%.2f :: %s",
                             t, price, shares, fee, cash, reason_text)

        # MTM valuation
        mtm = 0.0
        for _tkr, pos in open_positions.items():
            px = _get_close_on(_tkr, dt)
            if not np.isnan(px):
                mtm += pos["shares"] * px
        total_equity = cash + mtm
        equity_curve.append((dt, float(total_equity)))

    eq_ser = pd.Series([e for _, e in equity_curve], index=[d for d, _ in equity_curve])
    legs_df = pd.DataFrame(completed_legs).sort_values(["date", "ticker", "side"]).reset_index(drop=True)

    # Roundtrips
    roundtrips = []
    by_tkr_open = {}
    for _, leg in legs_df.iterrows():
        tkr = leg["ticker"]
        if leg["side"] == "BUY":
            by_tkr_open[tkr] = leg
        else:
            buy = by_tkr_open.pop(tkr, None)
            if buy is None:
                continue
            fees_total = float(buy.get("fees_inr", 0.0) + leg.get("fees_inr", 0.0))
            gross_pnl = (leg["price"] - buy["price"]) * buy["shares"]
            net_pnl   = gross_pnl - fees_total
            ret_pct   = (leg["price"] / buy["price"] - 1.0) * 100.0
            days_held = (pd.to_datetime(leg["date"]) - pd.to_datetime(buy["date"])).days
            roundtrips.append({
                "ticker": tkr,
                "entry_date": pd.to_datetime(buy["date"]),
                "entry_price": float(buy["price"]),
                "exit_date": pd.to_datetime(leg["date"]),
                "exit_price": float(leg["price"]),
                "days_held": int(days_held),
                "shares": int(buy["shares"]),
                "entry_reason": buy.get("reason",""),
                "exit_reason": leg.get("reason",""),
                "gross_pnl_inr": float(gross_pnl),
                "fees_total_inr": float(fees_total),
                "net_pnl_inr": float(net_pnl),
                "return_pct": float(ret_pct),
                "rsi_entry": float(buy.get("rsi", np.nan)),
                "adx_entry": float(buy.get("ADX", np.nan)),
                "pdi_entry": float(buy.get("+DI", np.nan)),
                "mdi_entry": float(buy.get("-DI", np.nan)),
                "ema_fast_entry": float(buy.get("ema_fast", np.nan)),
                "ema_slow_entry": float(buy.get("ema_slow", np.nan)),
                "sma50_entry": float(buy.get("sma50", np.nan)),
                "sma200_entry": float(buy.get("sma200", np.nan)),
                "macd_line_entry": float(buy.get("macd_line", np.nan)),
                "macd_signal_entry": float(buy.get("macd_signal", np.nan)),
                "macd_hist_entry": float(buy.get("macd_hist", np.nan)),
                "bb_mid_entry": float(buy.get("bb_mid", np.nan)),
                "bb_up_entry": float(buy.get("bb_up", np.nan)),
                "bb_low_entry": float(buy.get("bb_low", np.nan)),
                "close_entry": float(buy.get("close", np.nan)),
                "high_52w_entry": float(buy.get("high_52w", np.nan)),
                "volar_entry": float(buy.get("volar", np.nan)),
                "mvo_weight_entry": float(buy.get("mvo_weight", np.nan)),
                "alloc_inr_entry": float(buy.get("alloc_inr", np.nan))
            })
    trips_df = pd.DataFrame(roundtrips).sort_values(["entry_date","ticker"]).reset_index(drop=True)

    metrics = compute_metrics(eq_ser, legs_df)
    return legs_df, trips_df, eq_ser, metrics

def compute_metrics(equity: pd.Series, legs_df: pd.DataFrame):
    out = {}
    if equity is None or equity.empty:
        return out
    eq = equity.dropna()
    daily_ret = eq.pct_change().fillna(0.0)

    days = (eq.index[-1] - eq.index[0]).days or 1
    years = days / 365.25
    cagr = (eq.iloc[-1] / eq.iloc[0]) ** (1/years) - 1 if years > 0 else 0.0

    if daily_ret.std(ddof=0) > 0:
        sharpe = (daily_ret.mean() / daily_ret.std(ddof=0)) * np.sqrt(252)
    else:
        sharpe = 0.0

    cummax = eq.cummax()
    dd = (eq - cummax) / cummax
    max_dd = dd.min()

    wins = 0
    n_sells = legs_df[legs_df["side"] == "SELL"].shape[0] if legs_df is not None and not legs_df.empty else 0
    for _, r in legs_df[legs_df["side"] == "SELL"].iterrows():
        if float(r.get("pnl_inr", 0.0)) > 0:
            wins += 1
    win_rate = (wins / n_sells) * 100.0 if n_sells > 0 else 0.0

    out.update({
        "start_equity_inr": float(eq.iloc[0]),
        "final_equity_inr": float(eq.iloc[-1]),
        "cagr_pct": float(cagr * 100),
        "sharpe": float(sharpe),
        "max_drawdown_pct": float(max_dd * 100),
        "win_rate_pct": float(win_rate),
        "n_trades": int(n_sells),
    })
    return out

def plot_equity(equity: pd.Series, out_path: str):
    if equity is None or equity.empty:
        return
    try:
        import matplotlib.pyplot as plt
        plt.figure(figsize=(10,5))
        plt.plot(equity.index, equity.values)
        plt.title("Equity Curve")
        plt.xlabel("Date")
        plt.ylabel("Equity (INR)")
        plt.tight_layout()
        plt.savefig(out_path)
        plt.close()
    except Exception:
        pass

def backtest(cfg: Config):
    ensure_dirs(cfg.cache_dir, cfg.out_dir)
    log.info("Universe: loading static symbols...")
    symbols = load_static_symbols(cfg.static_symbols, cfg.static_symbols_path)
    log.info("Loaded %d symbols.", len(symbols))

    log.info("Data: fetching OHLCV from yfinance (adjusted)...")
    data_map = fetch_prices(symbols, cfg.start_date, cfg.end_date, cfg.cache_dir)
    log.info("Downloaded %d symbols with data.", len(data_map))

    bench_tkr, bench_df = pick_benchmark(cfg.benchmark_try, cfg.start_date, cfg.end_date, cfg.cache_dir)
    log.info("Benchmark selected: %s", bench_tkr)

    log.info("Signals: generating new EMA10/EMA20 + 2xGreen + ≥1 confirm entries...")
    all_trades = []
    for i, tkr in enumerate(symbols, 1):
        df = data_map.get(tkr)
        if df is None or df.empty:
            continue
        tr, _ = simulate_ticker(tkr, df, cfg)
        if not tr.empty:
            all_trades.append(tr)
        if i % 50 == 0:
            log.info("  processed %d/%d tickers...", i, len(symbols))

    if not all_trades:
        log.warning("No signals generated; check thresholds or universe.")
        return None, None, None, {}
    all_trades = pd.concat(all_trades, ignore_index=True)

    log.info("Portfolio: cap daily deploy to %.0f%% of cash; 52w>=%.0f%% high; top-%d by VOLAᵣ; MVO; max %d positions.",
             cfg.deploy_cash_frac*100, cfg.within_pct_of_52w_high*100, cfg.top_k_daily, cfg.max_concurrent_positions)
    legs_df, trips_df, equity, metrics = aggregate_and_apply(all_trades, data_map, bench_df, cfg)

    stamp = pd.Timestamp.today(tz="Asia/Kolkata").strftime("%Y%m%d_%H%M%S")
    legs_path = os.path.join(cfg.out_dir, f"trades_legs_{stamp}.csv")
    trips_path = os.path.join(cfg.out_dir, f"trades_roundtrips_{stamp}.csv")
    equity_path = os.path.join(cfg.out_dir, f"equity_{stamp}.csv")
    metrics_path = os.path.join(cfg.out_dir, f"metrics_{stamp}.json")
    eq_plot_path = os.path.join(cfg.out_dir, f"equity_{stamp}.png")

    if legs_df is not None:
        legs_df.to_csv(legs_path, index=False)
    if trips_df is not None:
        trips_df.to_csv(trips_path, index=False)
    if equity is not None:
        pd.DataFrame({"date": equity.index, "equity": equity.values}).to_csv(equity_path, index=False)
    with open(metrics_path, "w") as f:
        json.dump(metrics, f, indent=2)

    if cfg.plot and equity is not None:
        plot_equity(equity, eq_plot_path)

    log.info("=== METRICS ===\n%s", json.dumps(metrics, indent=2))
    log.info("Files written:\n  %s\n  %s\n  %s\n  %s", legs_path, trips_path, equity_path, metrics_path)
    if cfg.plot:
        log.info("  %s", eq_plot_path)

def main():
    global APPLY_FEES
    APPLY_FEES = bool(CFG.apply_fees)
    # Example: set your universe here or via file path.
    # CFG.static_symbols = ['TCS.NS','HDFCBANK.NS','RELIANCE.NS','INFY.NS','ICICIBANK.NS']  # put your long list back here
    CFG.static_symbols_path = "nifty500.txt"
    backtest(CFG)

if __name__ == "__main__":
    main()
# Out:
# 2025-10-08 17:13:36 | INFO | Universe: loading static symbols...
# 2025-10-08 17:13:36 | INFO | Loaded 500 symbols.
# 2025-10-08 17:13:36 | INFO | Data: fetching OHLCV from yfinance (adjusted)...
# 2025-10-08 17:13:40 | ERROR |
# 1 Failed download:
# 2025-10-08 17:13:40 | ERROR | ['ABLBL.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-08 17:13:52 | ERROR |
# 1 Failed download:
# 2025-10-08 17:13:52 | ERROR | ['AEGISVOPAK.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-08 17:13:53 | ERROR |
# 1 Failed download:
# 2025-10-08 17:13:53 | ERROR | ['AGARWALEYE.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-08 17:14:03 | ERROR |
# 1 Failed download:
# 2025-10-08 17:14:03 | ERROR | ['ATHERENERG.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-08 17:14:29 | ERROR |
# 1 Failed download:
# 2025-10-08 17:14:29 | ERROR | ['COHANCE.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-08 17:14:42 | ERROR |
# 1 Failed download:
# 2025-10-08 17:14:42 | ERROR | ['ENRIN.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-08 17:15:00 | ERROR |
# 1 Failed download:
# 2025-10-08 17:15:00 | ERROR | ['HEXT.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-08 17:15:16 | ERROR |
# 1 Failed download:
# 2025-10-08 17:15:16 | ERROR | ['ITCHOTELS.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-08 17:15:56 | ERROR |
# 1 Failed download:
# 2025-10-08 17:15:56 | ERROR | ['ONESOURCE.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-08 17:16:33 | ERROR |
# 1 Failed download:
# 2025-10-08 17:16:33 | ERROR | ['THELEELA.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-08 17:16:49 | INFO | Downloaded 490 symbols with data.
# 2025-10-08 17:16:49 | ERROR |
# 1 Failed download:
# 2025-10-08 17:16:49 | ERROR | ['^CNX500']: YFTzMissingError('possibly delisted; no timezone found')
# 2025-10-08 17:16:50 | INFO | Using benchmark: ^CRSLDX
# 2025-10-08 17:16:50 | INFO | Benchmark selected: ^CRSLDX
# 2025-10-08 17:16:50 | INFO | Signals: generating new EMA10/EMA20 + 2xGreen + ≥1 confirm entries...
# 2025-10-08 17:16:55 | INFO |   processed 50/500 tickers...
# 2025-10-08 17:17:02 | INFO |   processed 100/500 tickers...
# 2025-10-08 17:17:09 | INFO |   processed 150/500 tickers...
# 2025-10-08 17:17:15 | INFO |   processed 200/500 tickers...
# 2025-10-08 17:17:21 | INFO |   processed 250/500 tickers...
# 2025-10-08 17:17:27 | INFO |   processed 300/500 tickers...
# 2025-10-08 17:17:33 | INFO |   processed 350/500 tickers...
# 2025-10-08 17:17:39 | INFO |   processed 400/500 tickers...
# 2025-10-08 17:17:45 | INFO |   processed 450/500 tickers...
# 2025-10-08 17:17:52 | INFO |   processed 500/500 tickers...
# 2025-10-08 17:17:52 | INFO | Portfolio: cap daily deploy to 30% of cash; 52w>=50% high; top-300 by VOLAᵣ; MVO; max 5 positions.
# 2025-10-08 17:17:52 | INFO | Selected 5 BUY candidates on 2016-01-12:
# 2025-10-08 17:17:52 | INFO |   KEI.NS       volar=  1.86 rank=1 px=  121.33
# 2025-10-08 17:17:52 | INFO |   TRIVENI.NS   volar=  1.70 rank=2 px=   50.34
# 2025-10-08 17:17:52 | INFO |   SAMMAANCAP.NS volar=  1.62 rank=3 px=  491.62
# 2025-10-08 17:17:52 | INFO |   FORTIS.NS    volar=  1.38 rank=4 px=  177.48
# 2025-10-08 17:17:52 | INFO |   SUPREMEIND.NS volar=  1.03 rank=5 px=  637.01
# 2025-10-08 17:17:52 | INFO | BUY KEI.NS       px=  119.23 sh=   308 fee=67.21 cash=463208.65 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/5 (VOLAR=1.86); MVO weight=24.5% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | BUY TRIVENI.NS   px=   47.41 sh=   761 fee=66.44 cash=427063.23 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 2/5 (VOLAR=1.70); MVO weight=24.1% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | BUY SAMMAANCAP.NS px=  481.63 sh=    83 fee=71.07 cash=387016.66 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=92.9% (>= 50%); VOLAR rank 3/5 (VOLAR=1.62); MVO weight=26.8% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | BUY FORTIS.NS    px=  182.20 sh=   107 fee=46.15 cash=367474.88 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, ADX>20 & +DI>-DI, Close>SMA50; 52w%=91.1% (>= 50%); VOLAR rank 4/5 (VOLAR=1.38); MVO weight=13.1% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | BUY SUPREMEIND.NS px=  641.20 sh=    27 fee=40.99 cash=350121.38 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=96.9% (>= 50%); VOLAR rank 5/5 (VOLAR=1.03); MVO weight=11.6% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit KEI.NS       px=  109.19 sh=   308 reason=StopLoss hit (10.0%). filled=109.19, SL=109.19, ret=-10.00%, held=1d net=-3241.62 cash=383671.11
# 2025-10-08 17:17:52 | INFO | Exit TRIVENI.NS   px=   45.30 sh=   761 reason=StopLoss hit (10.0%). filled=45.30, SL=45.30, ret=-10.00%, held=1d net=-1751.37 cash=418065.16
# 2025-10-08 17:17:52 | INFO | Selected 2 BUY candidates on 2016-01-13:
# 2025-10-08 17:17:52 | INFO |   APLAPOLLO.NS volar=  2.23 rank=1 px=   76.12
# 2025-10-08 17:17:52 | INFO |   AARTIIND.NS  volar=  2.05 rank=2 px=  122.48
# 2025-10-08 17:17:52 | INFO | BUY APLAPOLLO.NS px=   73.28 sh=   859 fee=98.34 cash=355023.28 :: EMA10>EMA20 & 2xGreenStrict; confirms: ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=99.7% (>= 50%); VOLAR rank 1/2 (VOLAR=2.23); MVO weight=50.2% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | BUY AARTIIND.NS  px=  117.86 sh=   529 fee=97.63 cash=292578.97 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, Close>SMA50, Close>BBmid; 52w%=91.3% (>= 50%); VOLAR rank 2/2 (VOLAR=2.05); MVO weight=49.8% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit AARTIIND.NS  px=  110.23 sh=   529 reason=StopLoss hit (10.0%). filled=110.23, SL=110.23, ret=-10.00%, held=5d net=-4240.39 cash=350782.89
# 2025-10-08 17:17:52 | INFO | Exit APLAPOLLO.NS px=   68.51 sh=   859 reason=StopLoss hit (10.0%). filled=68.51, SL=68.51, ret=-10.00%, held=5d net=-4304.18 cash=409520.58
# 2025-10-08 17:17:52 | INFO | Exit SAMMAANCAP.NS px=  442.46 sh=    83 reason=StopLoss hit (10.0%). filled=442.46, SL=442.46, ret=-10.00%, held=6d net=-3408.05 cash=446159.11
# 2025-10-08 17:17:52 | INFO | Selected 1 BUY candidates on 2016-01-18:
# 2025-10-08 17:17:52 | INFO |   BPCL.NS      volar=  1.38 rank=1 px=   86.40
# 2025-10-08 17:17:52 | INFO | BUY BPCL.NS      px=   83.25 sh=  1607 fee=182.45 cash=312194.99 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=98.5% (>= 50%); VOLAR rank 1/1 (VOLAR=1.38); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit FORTIS.NS    px=  167.49 sh=   107 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=174.61, 20=175.01); filled=167.49, ret=-5.63%, held=7d net=-1683.18 cash=330053.60
# 2025-10-08 17:17:52 | INFO | Selected 2 BUY candidates on 2016-01-20:
# 2025-10-08 17:17:52 | INFO |   EMAMILTD.NS  volar=  1.04 rank=1 px=  433.12
# 2025-10-08 17:17:52 | INFO |   BIOCON.NS    volar=  0.98 rank=2 px=   79.51
# 2025-10-08 17:17:52 | INFO | BUY EMAMILTD.NS  px=  434.22 sh=   122 fee=86.50 cash=276992.04 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=76.2% (>= 50%); VOLAR rank 1/2 (VOLAR=1.04); MVO weight=53.5% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | BUY BIOCON.NS    px=   78.16 sh=   588 fee=78.17 cash=230953.51 :: EMA10>EMA20 & 2xGreenStrict; confirms: Close>SMA50; 52w%=92.5% (>= 50%); VOLAR rank 2/2 (VOLAR=0.98); MVO weight=46.5% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit BIOCON.NS    px=   78.86 sh=   588 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=81.28, 20=81.41); filled=78.86, ret=-0.82%, held=1d net=236.79 cash=277228.84
# 2025-10-08 17:17:52 | INFO | Exit BPCL.NS      px=   82.82 sh=  1607 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=83.45, 20=83.49); filled=82.82, ret=-4.14%, held=3d net=-1054.14 cash=410138.81
# 2025-10-08 17:17:52 | INFO | Exit SUPREMEIND.NS px=  590.63 sh=    27 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=608.24, 20=609.66); filled=590.63, ret=-7.28%, held=9d net=-1465.50 cash=426026.81
# 2025-10-08 17:17:52 | INFO | Selected 1 BUY candidates on 2016-01-21:
# 2025-10-08 17:17:52 | INFO |   MARICO.NS    volar=  1.38 rank=1 px=  195.35
# 2025-10-08 17:17:52 | INFO | BUY MARICO.NS    px=  188.78 sh=   677 fee=175.36 cash=298046.28 :: EMA10>EMA20 & 2xGreenStrict; confirms: ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=97.7% (>= 50%); VOLAR rank 1/1 (VOLAR=1.38); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Selected 1 BUY candidates on 2016-01-22:
# 2025-10-08 17:17:52 | INFO |   TORNTPOWER.NS volar=  1.01 rank=1 px=  175.77
# 2025-10-08 17:17:52 | INFO | BUY TORNTPOWER.NS px=  171.56 sh=   521 fee=129.73 cash=208534.43 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=91.5% (>= 50%); VOLAR rank 1/1 (VOLAR=1.01); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit MARICO.NS    px=  191.44 sh=   677 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=191.22, 20=191.28); filled=191.44, ret=-2.00%, held=4d net=1445.09 cash=337960.04
# 2025-10-08 17:17:52 | INFO | Selected 1 BUY candidates on 2016-01-25:
# 2025-10-08 17:17:52 | INFO |   ASTRAZEN.NS  volar=  1.22 rank=1 px= 1204.10
# 2025-10-08 17:17:52 | INFO | BUY ASTRAZEN.NS  px= 1187.90 sh=    85 fee=143.49 cash=236844.92 :: EMA10>EMA20 & 2xGreenStrict; confirms: ADX>20 & +DI>-DI, Close>SMA50; 52w%=94.2% (>= 50%); VOLAR rank 1/1 (VOLAR=1.22); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Selected 2 BUY candidates on 2016-01-27:
# 2025-10-08 17:17:52 | INFO |   IGL.NS       volar=  1.24 rank=1 px=   51.86
# 2025-10-08 17:17:52 | INFO |   BERGEPAINT.NS volar=  1.06 rank=2 px=  149.89
# 2025-10-08 17:17:52 | INFO | BUY IGL.NS       px=   50.64 sh=   815 fee=72.61 cash=195500.47 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=98.5% (>= 50%); VOLAR rank 1/2 (VOLAR=1.24); MVO weight=58.1% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | BUY BERGEPAINT.NS px=  153.07 sh=   194 fee=58.86 cash=165745.72 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, Close>SMA50, Close>BBmid; 52w%=98.3% (>= 50%); VOLAR rank 2/2 (VOLAR=1.06); MVO weight=41.9% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit IGL.NS       px=   46.67 sh=   815 reason=StopLoss hit (10.0%). filled=46.67, SL=46.67, ret=-10.00%, held=2d net=-3393.74 cash=203696.43
# 2025-10-08 17:17:52 | INFO | Selected 1 BUY candidates on 2016-01-29:
# 2025-10-08 17:17:52 | INFO |   ECLERX.NS    volar=  1.47 rank=1 px=  941.93
# 2025-10-08 17:17:52 | INFO | BUY ECLERX.NS    px=  932.61 sh=    65 fee=95.58 cash=142981.48 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=95.8% (>= 50%); VOLAR rank 1/1 (VOLAR=1.47); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit TORNTPOWER.NS px=  193.35 sh=   521 reason=TakeProfit hit (10.0%). filled=193.35, TP=193.35, ret=10.00%, held=10d net=11072.62 cash=243565.96
# 2025-10-08 17:17:52 | INFO | Selected 1 BUY candidates on 2016-02-01:
# 2025-10-08 17:17:52 | INFO |   KAJARIACER.NS volar=  1.42 rank=1 px=  457.38
# 2025-10-08 17:17:52 | INFO | BUY KAJARIACER.NS px=  450.99 sh=   162 fee=110.35 cash=170395.16 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=98.4% (>= 50%); VOLAR rank 1/1 (VOLAR=1.42); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit ECLERX.NS    px=  893.11 sh=    65 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=904.55, 20=905.72); filled=893.11, ret=-5.18%, held=5d net=-2769.93 cash=228340.17
# 2025-10-08 17:17:52 | INFO | Selected 1 BUY candidates on 2016-02-03:
# 2025-10-08 17:17:52 | INFO |   IGL.NS       volar=  1.26 rank=1 px=   49.89
# 2025-10-08 17:17:52 | INFO | BUY IGL.NS       px=   49.18 sh=  1392 fee=104.89 cash=159775.74 :: EMA10>EMA20 & 2xGreenStrict; confirms: Close>SMA50, Close>BBmid; 52w%=95.9% (>= 50%); VOLAR rank 1/1 (VOLAR=1.26); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit ASTRAZEN.NS  px= 1123.36 sh=    85 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=1180.02, 20=1180.14); filled=1123.36, ret=-6.70%, held=11d net=-5775.39 cash=255115.47
# 2025-10-08 17:17:52 | INFO | Exit KAJARIACER.NS px=  434.61 sh=   162 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=441.12, 20=441.88); filled=434.61, ret=-4.98%, held=4d net=-2884.96 cash=325401.31
# 2025-10-08 17:17:52 | INFO | Selected 2 BUY candidates on 2016-02-05:
# 2025-10-08 17:17:52 | INFO |   MARICO.NS    volar=  1.46 rank=1 px=  194.33
# 2025-10-08 17:17:52 | INFO |   CHOLAFIN.NS  volar=  1.45 rank=2 px=  129.31
# 2025-10-08 17:17:52 | INFO | BUY MARICO.NS    px=  197.05 sh=   243 fee=80.46 cash=277437.69 :: EMA10>EMA20 & 2xGreenStrict; confirms: MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=97.2% (>= 50%); VOLAR rank 1/2 (VOLAR=1.46); MVO weight=49.2% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | BUY CHOLAFIN.NS  px=  132.62 sh=   373 fee=82.34 cash=227887.67 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=93.3% (>= 50%); VOLAR rank 2/2 (VOLAR=1.45); MVO weight=50.8% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit IGL.NS       px=   48.05 sh=  1392 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=48.63, 20=48.70); filled=48.05, ret=-3.69%, held=8d net=-1798.99 cash=294653.11
# 2025-10-08 17:17:52 | INFO | Selected 1 BUY candidates on 2016-02-11:
# 2025-10-08 17:17:52 | INFO |   AJANTPHARM.NS volar=  1.36 rank=1 px=  796.28
# 2025-10-08 17:17:52 | INFO | BUY AJANTPHARM.NS px=  796.83 sh=   110 fee=127.68 cash=206874.43 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=76.2% (>= 50%); VOLAR rank 1/1 (VOLAR=1.36); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit BERGEPAINT.NS px=  134.90 sh=   194 reason=StopLoss hit (10.0%). filled=134.90, SL=134.90, ret=-10.00%, held=16d net=-3658.68 cash=232970.51
# 2025-10-08 17:17:52 | INFO | Exit CHOLAFIN.NS  px=  142.24 sh=   373 reason=TakeProfit hit (10.0%). filled=142.24, TP=142.24, ret=10.00%, held=7d net=3404.20 cash=285924.73
# 2025-10-08 17:17:52 | INFO | Selected 1 BUY candidates on 2016-02-15:
# 2025-10-08 17:17:52 | INFO |   BHARTIARTL.NS volar=  0.22 rank=1 px=  280.47
# 2025-10-08 17:17:52 | INFO | BUY BHARTIARTL.NS px=  272.24 sh=   315 fee=125.43 cash=200044.69 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=73.3% (>= 50%); VOLAR rank 1/1 (VOLAR=0.22); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Selected 1 BUY candidates on 2016-02-16:
# 2025-10-08 17:17:52 | INFO |   3MINDIA.NS   volar=  1.81 rank=1 px=10274.77
# 2025-10-08 17:17:52 | INFO | BUY 3MINDIA.NS   px=10257.21 sh=     5 fee=84.50 cash=148674.15 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=89.5% (>= 50%); VOLAR rank 1/1 (VOLAR=1.81); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit EMAMILTD.NS  px=  428.63 sh=   122 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=439.26, 20=439.83); filled=428.63, ret=-1.04%, held=34d net=-870.18 cash=200865.52
# 2025-10-08 17:17:52 | INFO | Selected 1 BUY candidates on 2016-02-23:
# 2025-10-08 17:17:52 | INFO |   ASHOKLEY.NS  volar=  1.43 rank=1 px=   38.79
# 2025-10-08 17:17:52 | INFO | BUY ASHOKLEY.NS  px=   37.47 sh=  1608 fee=95.14 cash=140522.62 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=94.5% (>= 50%); VOLAR rank 1/1 (VOLAR=1.43); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit 3MINDIA.NS   px= 9708.08 sh=     5 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=9837.73, 20=9838.86); filled=9708.08, ret=-5.52%, held=13d net=-2927.72 cash=188965.44
# 2025-10-08 17:17:52 | INFO | Exit ASHOKLEY.NS  px=   36.06 sh=  1608 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=36.90, 20=36.98); filled=36.06, ret=-7.04%, held=6d net=-2465.15 cash=246843.19
# 2025-10-08 17:17:52 | INFO | Selected 1 BUY candidates on 2016-02-29:
# 2025-10-08 17:17:52 | INFO |   FINCABLES.NS volar=  0.36 rank=1 px=  221.89
# 2025-10-08 17:17:52 | INFO | BUY FINCABLES.NS px=  216.44 sh=   342 fee=111.49 cash=172710.74 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=82.0% (>= 50%); VOLAR rank 1/1 (VOLAR=0.36); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Selected 1 BUY candidates on 2016-03-01:
# 2025-10-08 17:17:52 | INFO |   CUB.NS       volar=  0.31 rank=1 px=   66.13
# 2025-10-08 17:17:52 | INFO | BUY CUB.NS       px=   67.88 sh=   763 fee=85.10 cash=120832.73 :: EMA10>EMA20 & 2xGreenStrict; confirms: MACD>Signal, ADX>20 & +DI>-DI, Close>BBmid; 52w%=82.5% (>= 50%); VOLAR rank 1/1 (VOLAR=0.31); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit AJANTPHARM.NS px=  875.90 sh=   110 reason=TakeProfit hit (10.0%). filled=875.90, TP=875.90, ret=10.00%, held=26d net=8423.65 cash=217035.07
# 2025-10-08 17:17:52 | INFO | Selected 1 BUY candidates on 2016-03-08:
# 2025-10-08 17:17:52 | INFO |   CHENNPETRO.NS volar=  1.90 rank=1 px=  157.36
# 2025-10-08 17:17:52 | INFO | BUY CHENNPETRO.NS px=  154.96 sh=   420 fee=100.88 cash=151852.25 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=79.5% (>= 50%); VOLAR rank 1/1 (VOLAR=1.90); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit MARICO.NS    px=  213.76 sh=   243 reason=TakeProfit hit (10.0%). filled=213.76, TP=213.76, ret=10.00%, held=35d net=3878.92 cash=203694.79
# 2025-10-08 17:17:52 | INFO | Selected 1 BUY candidates on 2016-03-11:
# 2025-10-08 17:17:52 | INFO |   WELSPUNLIV.NS volar=  2.62 rank=1 px=   83.89
# 2025-10-08 17:17:52 | INFO | BUY WELSPUNLIV.NS px=   89.93 sh=   679 fee=96.11 cash=142536.21 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=96.1% (>= 50%); VOLAR rank 1/1 (VOLAR=2.62); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | Exit FINCABLES.NS px=  209.07 sh=   342 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=212.10, 20=212.23); filled=209.07, ret=-5.78%, held=14d net=-2752.07 cash=213916.60
# 2025-10-08 17:17:52 | INFO | Exit WELSPUNLIV.NS px=   92.28 sh=   679 reason=TakeProfit hit (10.0%). filled=92.28, TP=92.28, ret=10.00%, held=3d net=1385.07 cash=276460.24
# 2025-10-08 17:17:52 | INFO | Selected 2 BUY candidates on 2016-03-14:
# 2025-10-08 17:17:52 | INFO |   PETRONET.NS  volar=  1.76 rank=1 px=   88.77
# 2025-10-08 17:17:52 | INFO |   FINPIPE.NS   volar=  1.38 rank=2 px=   63.25
# 2025-10-08 17:17:52 | INFO | BUY PETRONET.NS  px=   87.99 sh=   621 fee=88.48 cash=221729.62 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=93.5% (>= 50%); VOLAR rank 1/2 (VOLAR=1.76); MVO weight=65.9% of capped cash (30% of available)
# 2025-10-08 17:17:52 | INFO | BUY FINPIPE.NS   px=   62.00 sh=   455 fee=57.09 cash=193464.35 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 2/2 (VOLAR=1.38); MVO weight=34.1% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit CUB.NS       px=   72.74 sh=   763 reason=TakeProfit hit (10.0%). filled=72.74, TP=72.74, ret=10.00%, held=27d net=3516.84 cash=248859.20
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-03-28:
# 2025-10-08 17:17:53 | INFO |   WELSPUNLIV.NS volar=  2.58 rank=1 px=   99.66
# 2025-10-08 17:17:53 | INFO | BUY WELSPUNLIV.NS px=   92.72 sh=   805 fee=112.23 cash=174104.24 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=2.58); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit WELSPUNLIV.NS px=   89.69 sh=   805 reason=StopLoss hit (10.0%). filled=89.69, SL=89.69, ret=-10.00%, held=1d net=-2675.29 cash=246183.90
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-03-29:
# 2025-10-08 17:17:53 | INFO |   MINDACORP.NS volar=  0.77 rank=1 px=   98.43
# 2025-10-08 17:17:53 | INFO | BUY MINDACORP.NS px=  100.97 sh=   731 fee=111.24 cash=172264.25 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=0.77); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit MINDACORP.NS px=  108.27 sh=   731 reason=TakeProfit hit (10.0%). filled=108.27, TP=108.27, ret=10.00%, held=6d net=5097.07 cash=251280.97
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-04-04:
# 2025-10-08 17:17:53 | INFO |   BALRAMCHIN.NS volar=  1.86 rank=1 px=   96.62
# 2025-10-08 17:17:53 | INFO | BUY BALRAMCHIN.NS px=   94.99 sh=   793 fee=113.04 cash=175842.31 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=1.86); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit PETRONET.NS  px=   86.54 sh=   621 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=87.52, 20=87.57); filled=86.54, ret=-2.51%, held=23d net=-1091.53 cash=229481.40
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-04-06:
# 2025-10-08 17:17:53 | INFO |   RKFORGE.NS   volar=  0.36 rank=1 px=   74.28
# 2025-10-08 17:17:53 | INFO | BUY RKFORGE.NS   px=   77.37 sh=   889 fee=105.27 cash=160595.85 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=50.0% (>= 50%); VOLAR rank 1/1 (VOLAR=0.36); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit BHARTIARTL.NS px=  291.49 sh=   315 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=289.59, 20=289.61); filled=291.49, ret=3.93%, held=56d net=5795.97 cash=252271.86
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-04-11:
# 2025-10-08 17:17:53 | INFO |   APLAPOLLO.NS volar=  1.68 rank=1 px=   69.37
# 2025-10-08 17:17:53 | INFO | BUY APLAPOLLO.NS px=   70.25 sh=  1077 fee=113.44 cash=176500.73 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=92.6% (>= 50%); VOLAR rank 1/1 (VOLAR=1.68); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit APLAPOLLO.NS px=   76.31 sh=  1077 reason=TakeProfit hit (10.0%). filled=76.31, TP=76.31, ret=10.00%, held=2d net=6284.08 cash=258555.95
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-04-13:
# 2025-10-08 17:17:53 | INFO |   GODFRYPHLP.NS volar=  2.01 rank=1 px=  351.95
# 2025-10-08 17:17:53 | INFO | BUY GODFRYPHLP.NS px=  353.35 sh=   219 fee=115.49 cash=181057.04 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=74.0% (>= 50%); VOLAR rank 1/1 (VOLAR=2.01); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit CHENNPETRO.NS px=  173.10 sh=   420 reason=TakeProfit hit (10.0%). filled=173.10, TP=173.10, ret=10.00%, held=44d net=7395.45 cash=253635.31
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-04-21:
# 2025-10-08 17:17:53 | INFO |   WELSPUNLIV.NS volar=  2.19 rank=1 px=   92.17
# 2025-10-08 17:17:53 | INFO | BUY WELSPUNLIV.NS px=   92.08 sh=   826 fee=113.91 cash=177466.01 :: EMA10>EMA20 & 2xGreenStrict; confirms: Close>SMA50, Close>BBmid; 52w%=91.4% (>= 50%); VOLAR rank 1/1 (VOLAR=2.19); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit GODFRYPHLP.NS px=  316.75 sh=   219 reason=StopLoss hit (10.0%). filled=316.75, SL=316.75, ret=-10.00%, held=13d net=-8249.21 cash=246715.70
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-04-26:
# 2025-10-08 17:17:53 | INFO |   APLAPOLLO.NS volar=  1.72 rank=1 px=   74.60
# 2025-10-08 17:17:53 | INFO | BUY APLAPOLLO.NS px=   77.40 sh=   956 fee=111.46 cash=172614.57 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=1.72); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit RKFORGE.NS   px=   81.71 sh=   889 reason=TakeProfit hit (10.0%). filled=81.71, TP=81.71, ret=10.00%, held=27d net=3632.98 cash=245133.10
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-05-03:
# 2025-10-08 17:17:53 | INFO |   BIOCON.NS    volar=  1.44 rank=1 px=  100.54
# 2025-10-08 17:17:53 | INFO | BUY BIOCON.NS    px=  100.43 sh=   732 fee=110.89 cash=171506.16 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=1.44); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit WELSPUNLIV.NS px=   85.98 sh=   826 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=88.82, 20=88.86); filled=85.98, ret=-6.72%, held=18d net=-5274.59 cash=242400.87
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-05-09:
# 2025-10-08 17:17:53 | INFO |   CHOLAFIN.NS  volar=  1.64 rank=1 px=  173.42
# 2025-10-08 17:17:53 | INFO | BUY CHOLAFIN.NS  px=  174.71 sh=   416 fee=109.90 cash=169610.84 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=1.64); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit APLAPOLLO.NS px=   82.06 sh=   956 reason=TakeProfit hit (10.0%). filled=82.06, TP=82.06, ret=10.00%, held=17d net=4220.78 cash=247932.75
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-05-13:
# 2025-10-08 17:17:53 | INFO |   TRIDENT.NS   volar=  1.56 rank=1 px=    4.27
# 2025-10-08 17:17:53 | INFO | BUY TRIDENT.NS   px=    4.07 sh= 18277 fee=111.92 cash=173442.42 :: EMA10>EMA20 & 2xGreenStrict; confirms: Close>SMA50, Close>BBmid; 52w%=89.3% (>= 50%); VOLAR rank 1/1 (VOLAR=1.56); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit TRIDENT.NS   px=    4.00 sh= 18277 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=4.07, 20=4.07); filled=4.00, ret=-6.30%, held=5d net=-1534.73 cash=246398.02
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-05-18:
# 2025-10-08 17:17:53 | INFO |   UNOMINDA.NS  volar=  1.74 rank=1 px=   35.40
# 2025-10-08 17:17:53 | INFO | BUY UNOMINDA.NS  px=   35.42 sh=  2086 fee=111.33 cash=172400.76 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=1.74); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit FINPIPE.NS   px=   69.58 sh=   455 reason=TakeProfit hit (10.0%). filled=69.58, TP=69.58, ret=10.00%, held=70d net=3312.31 cash=203978.34
# 2025-10-08 17:17:53 | INFO | Exit UNOMINDA.NS  px=   38.94 sh=  2086 reason=TakeProfit hit (10.0%). filled=38.94, TP=38.94, ret=10.00%, held=5d net=7101.43 cash=285077.04
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-05-24:
# 2025-10-08 17:17:53 | INFO |   APOLLOHOSP.NS volar=  0.60 rank=1 px= 1330.64
# 2025-10-08 17:17:53 | INFO | BUY APOLLOHOSP.NS px= 1321.55 sh=    64 fee=124.03 cash=200373.58 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=91.0% (>= 50%); VOLAR rank 1/1 (VOLAR=0.60); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-05-25:
# 2025-10-08 17:17:53 | INFO |   CUB.NS       volar=  0.52 rank=1 px=   82.81
# 2025-10-08 17:17:53 | INFO | BUY CUB.NS       px=   81.90 sh=   733 fee=94.89 cash=140243.12 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=0.52); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit BIOCON.NS    px=  110.59 sh=   732 reason=TakeProfit hit (10.0%). filled=110.59, TP=110.59, ret=10.00%, held=24d net=7195.37 cash=221065.42
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-05-27:
# 2025-10-08 17:17:53 | INFO |   HINDPETRO.NS volar=  1.42 rank=1 px=   82.97
# 2025-10-08 17:17:53 | INFO | BUY HINDPETRO.NS px=   89.37 sh=   742 fee=102.34 cash=154653.82 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, Close>SMA50, Close>BBmid; 52w%=92.6% (>= 50%); VOLAR rank 1/1 (VOLAR=1.42); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit BALRAMCHIN.NS px=   94.02 sh=   793 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=96.67, 20=96.72); filled=94.02, ret=-2.69%, held=56d net=-1005.86 cash=229086.62
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-05-30:
# 2025-10-08 17:17:53 | INFO |   BIOCON.NS    volar=  1.83 rank=1 px=  115.44
# 2025-10-08 17:17:53 | INFO | BUY BIOCON.NS    px=  115.04 sh=   597 fee=105.15 cash=160300.26 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=1.83); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit CHOLAFIN.NS  px=  190.76 sh=   416 reason=TakeProfit hit (10.0%). filled=190.76, TP=190.76, ret=10.00%, held=22d net=6436.51 cash=239526.80
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-05-31:
# 2025-10-08 17:17:53 | INFO |   PETRONET.NS  volar=  1.50 rank=1 px=   98.58
# 2025-10-08 17:17:53 | INFO | BUY PETRONET.NS  px=   96.70 sh=   743 fee=108.92 cash=167566.24 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=98.2% (>= 50%); VOLAR rank 1/1 (VOLAR=1.50); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit APOLLOHOSP.NS px= 1293.77 sh=    64 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=1312.96, 20=1314.42); filled=1293.77, ret=-2.77%, held=22d net=-2035.02 cash=250234.69
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-06-15:
# 2025-10-08 17:17:53 | INFO |   RAMCOCEM.NS  volar=  1.80 rank=1 px=  518.62
# 2025-10-08 17:17:53 | INFO | BUY RAMCOCEM.NS  px=  525.94 sh=   142 fee=112.28 cash=175439.26 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=99.3% (>= 50%); VOLAR rank 1/1 (VOLAR=1.80); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit HINDPETRO.NS px=   91.27 sh=   742 reason=TakeProfit hit (10.0%). filled=91.27, TP=91.27, ret=10.00%, held=27d net=1193.02 cash=243043.89
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-06-23:
# 2025-10-08 17:17:53 | INFO |   IOC.NS       volar=  0.65 rank=1 px=   38.01
# 2025-10-08 17:17:53 | INFO | BUY IOC.NS       px=   38.45 sh=  1896 fee=110.16 cash=170031.47 :: EMA10>EMA20 & 2xGreenStrict; confirms: Close>BBmid; 52w%=93.5% (>= 50%); VOLAR rank 1/1 (VOLAR=0.65); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit CUB.NS       px=   91.09 sh=   733 reason=TakeProfit hit (10.0%). filled=91.09, TP=91.09, ret=10.00%, held=36d net=6523.49 cash=236685.42
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-06-30:
# 2025-10-08 17:17:53 | INFO |   MANAPPURAM.NS volar=  2.14 rank=1 px=   56.52
# 2025-10-08 17:17:53 | INFO | BUY MANAPPURAM.NS px=   57.35 sh=  1238 fee=107.90 cash=165580.85 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=2.14); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit IOC.NS       px=   41.81 sh=  1896 reason=TakeProfit hit (10.0%). filled=41.81, TP=41.81, ret=10.00%, held=8d net=6138.04 cash=244731.30
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-07-01:
# 2025-10-08 17:17:53 | INFO |   FINPIPE.NS   volar=  1.55 rank=1 px=   71.58
# 2025-10-08 17:17:53 | INFO | BUY FINPIPE.NS   px=   72.49 sh=  1012 fee=110.71 cash=171262.98 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=1.55); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit MANAPPURAM.NS px=   62.17 sh=  1238 reason=TakeProfit hit (10.0%). filled=62.17, TP=62.17, ret=10.00%, held=4d net=5732.07 cash=248099.62
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-07-04:
# 2025-10-08 17:17:53 | INFO |   KPRMILL.NS   volar=  1.60 rank=1 px=  104.89
# 2025-10-08 17:17:53 | INFO | BUY KPRMILL.NS   px=  105.54 sh=   705 fee=111.95 cash=173582.08 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=1.60); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:53 | INFO | Exit RAMCOCEM.NS  px=  570.48 sh=   142 reason=TakeProfit hit (10.0%). filled=570.48, TP=570.48, ret=10.00%, held=23d net=6081.07 cash=254458.57
# 2025-10-08 17:17:53 | INFO | Selected 1 BUY candidates on 2016-07-08:
# 2025-10-08 17:17:53 | INFO |   INTELLECT.NS volar=  1.47 rank=1 px=  199.89
# 2025-10-08 17:17:53 | INFO | BUY INTELLECT.NS px=  196.99 sh=   387 fee=114.12 cash=178108.90 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=74.9% (>= 50%); VOLAR rank 1/1 (VOLAR=1.47); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit BIOCON.NS    px=  113.84 sh=   597 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=117.94, 20=118.23); filled=113.84, ret=-1.39%, held=50d net=-942.47 cash=245952.79
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-07-19:
# 2025-10-08 17:17:54 | INFO |   SARDAEN.NS   volar=  0.81 rank=1 px=   13.18
# 2025-10-08 17:17:54 | INFO | BUY SARDAEN.NS   px=   13.05 sh=  5652 fee=111.20 cash=172064.86 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=0.81); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit INTELLECT.NS px=  181.98 sh=   387 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=190.52, 20=191.44); filled=181.98, ret=-8.96%, held=12d net=-6045.18 cash=242369.34
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-07-20:
# 2025-10-08 17:17:54 | INFO |   AIAENG.NS    volar=  0.11 rank=1 px=  972.40
# 2025-10-08 17:17:54 | INFO | BUY AIAENG.NS    px=  970.60 sh=    74 fee=108.88 cash=170436.19 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=96.7% (>= 50%); VOLAR rank 1/1 (VOLAR=0.11); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit FINPIPE.NS   px=   78.73 sh=  1012 reason=TakeProfit hit (10.0%). filled=78.73, TP=78.73, ret=10.00%, held=26d net=6079.19 cash=249983.70
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-07-27:
# 2025-10-08 17:17:54 | INFO |   JSWSTEEL.NS  volar=  2.20 rank=1 px=  150.92
# 2025-10-08 17:17:54 | INFO | BUY JSWSTEEL.NS  px=  156.99 sh=   477 fee=112.52 cash=174984.93 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=2.20); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit PETRONET.NS  px=  108.44 sh=   743 reason=TakeProfit hit (10.0%). filled=108.44, TP=108.44, ret=10.00%, held=62d net=8476.80 cash=255422.28
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-08-01:
# 2025-10-08 17:17:54 | INFO |   MUTHOOTFIN.NS volar=  1.72 rank=1 px=  281.56
# 2025-10-08 17:17:54 | INFO | BUY MUTHOOTFIN.NS px=  301.36 sh=   254 fee=114.49 cash=178762.95 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=1.72); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit MUTHOOTFIN.NS px=  309.72 sh=   254 reason=TakeProfit hit (10.0%). filled=309.72, TP=309.72, ret=10.00%, held=1d net=1880.01 cash=257302.30
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-08-02:
# 2025-10-08 17:17:54 | INFO |   MANAPPURAM.NS volar=  2.71 rank=1 px=   72.57
# 2025-10-08 17:17:54 | INFO | BUY MANAPPURAM.NS px=   73.07 sh=  1056 fee=115.22 cash=180027.71 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=2.71); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit SARDAEN.NS   px=   11.87 sh=  5652 reason=StopLoss hit (10.0%). filled=11.87, SL=11.87, ret=-10.00%, held=15d net=-6939.59 cash=246976.05
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-08-03:
# 2025-10-08 17:17:54 | INFO |   VGUARD.NS    volar=  1.93 rank=1 px=  119.52
# 2025-10-08 17:17:54 | INFO | BUY VGUARD.NS    px=  117.75 sh=   629 fee=111.55 cash=172799.69 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=1.93); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit AIAENG.NS    px= 1069.64 sh=    74 reason=TakeProfit hit (10.0%). filled=1069.64, TP=1069.64, ret=10.00%, held=22d net=7090.81 cash=251823.65
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-08-11:
# 2025-10-08 17:17:54 | INFO |   NHPC.NS      volar=  1.39 rank=1 px=   16.36
# 2025-10-08 17:17:54 | INFO | BUY NHPC.NS      px=   16.43 sh=  4599 fee=113.30 cash=176171.56 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=1.39); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit VGUARD.NS    px=  131.47 sh=   629 reason=TakeProfit hit (10.0%). filled=131.47, TP=131.47, ret=10.00%, held=27d net=8386.12 cash=258734.04
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-08-30:
# 2025-10-08 17:17:54 | INFO |   RAMCOCEM.NS  volar=  1.70 rank=1 px=  543.64
# 2025-10-08 17:17:54 | INFO | BUY RAMCOCEM.NS  px=  557.55 sh=   139 fee=115.62 cash=181118.41 :: EMA10>EMA20 & 2xGreenStrict; confirms: MACD>Signal, Close>SMA50, Close>BBmid; 52w%=94.9% (>= 50%); VOLAR rank 1/1 (VOLAR=1.70); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit JSWSTEEL.NS  px=  166.01 sh=   477 reason=TakeProfit hit (10.0%). filled=166.01, TP=166.01, ret=10.00%, held=41d net=4057.01 cash=260174.19
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-09-06:
# 2025-10-08 17:17:54 | INFO |   TRENT.NS     volar=  1.97 rank=1 px=  223.51
# 2025-10-08 17:17:54 | INFO | BUY TRENT.NS     px=  235.73 sh=   331 fee=116.25 cash=182032.29 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=1.97); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit KPRMILL.NS   px=  108.31 sh=   705 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=108.99, 20=109.04); filled=108.31, ret=3.26%, held=66d net=1717.57 cash=258267.40
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-09-08:
# 2025-10-08 17:17:54 | INFO |   KAJARIACER.NS volar=  2.35 rank=1 px=  630.49
# 2025-10-08 17:17:54 | INFO | BUY KAJARIACER.NS px=  630.53 sh=   122 fee=114.94 cash=181227.40 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=2.35); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit MANAPPURAM.NS px=   79.83 sh=  1056 reason=TakeProfit hit (10.0%). filled=79.83, TP=79.83, ret=10.00%, held=43d net=6886.39 cash=265388.37
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-09-15:
# 2025-10-08 17:17:54 | INFO |   MANAPPURAM.NS volar=  3.09 rank=1 px=   80.31
# 2025-10-08 17:17:54 | INFO | BUY MANAPPURAM.NS px=   80.56 sh=   988 fee=118.10 cash=185680.91 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=3.09); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit RAMCOCEM.NS  px=  598.00 sh=   139 reason=TakeProfit hit (10.0%). filled=598.00, TP=598.00, ret=10.00%, held=23d net=5373.03 cash=268669.57
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-09-22:
# 2025-10-08 17:17:54 | INFO |   EICHERMOT.NS volar=  0.73 rank=1 px= 2275.60
# 2025-10-08 17:17:54 | INFO | BUY EICHERMOT.NS px= 2312.32 sh=    34 fee=116.95 cash=189933.81 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=0.73); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit NHPC.NS      px=   16.18 sh=  4599 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=16.73, 20=16.78); filled=16.18, ret=-1.12%, held=47d net=-1363.35 cash=264222.56
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-09-27:
# 2025-10-08 17:17:54 | INFO |   HINDZINC.NS  volar=  1.87 rank=1 px=  104.75
# 2025-10-08 17:17:54 | INFO | BUY HINDZINC.NS  px=  104.25 sh=   760 fee=117.68 cash=184877.02 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=99.8% (>= 50%); VOLAR rank 1/1 (VOLAR=1.87); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit MANAPPURAM.NS px=   72.27 sh=   988 reason=StopLoss hit (10.0%). filled=72.27, SL=72.27, ret=-10.00%, held=14d net=-8421.47 cash=256163.01
# 2025-10-08 17:17:54 | INFO | Exit TRENT.NS     px=  206.42 sh=   331 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=212.25, 20=212.58); filled=206.42, ret=-7.65%, held=23d net=-9934.87 cash=324370.04
# 2025-10-08 17:17:54 | INFO | Selected 2 BUY candidates on 2016-09-29:
# 2025-10-08 17:17:54 | INFO |   NAVA.NS      volar=  0.95 rank=1 px=   55.13
# 2025-10-08 17:17:54 | INFO |   AIAENG.NS    volar=  0.76 rank=2 px= 1204.60
# 2025-10-08 17:17:54 | INFO | BUY NAVA.NS      px=   51.90 sh=   810 fee=73.52 cash=282258.72 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=98.0% (>= 50%); VOLAR rank 1/2 (VOLAR=0.95); MVO weight=43.2% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | BUY AIAENG.NS    px= 1217.63 sh=    45 fee=88.66 cash=227376.66 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=98.4% (>= 50%); VOLAR rank 2/2 (VOLAR=0.76); MVO weight=56.8% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit HINDZINC.NS  px=  115.22 sh=   760 reason=TakeProfit hit (10.0%). filled=115.22, TP=115.22, ret=10.00%, held=6d net=8085.79 cash=314807.98
# 2025-10-08 17:17:54 | INFO | Exit NAVA.NS      px=   60.64 sh=   810 reason=TakeProfit hit (10.0%). filled=60.64, TP=60.64, ret=10.00%, held=4d net=6910.21 cash=363829.52
# 2025-10-08 17:17:54 | INFO | Selected 2 BUY candidates on 2016-10-04:
# 2025-10-08 17:17:54 | INFO |   MANAPPURAM.NS volar=  2.96 rank=1 px=   79.55
# 2025-10-08 17:17:54 | INFO |   UNOMINDA.NS  volar=  2.17 rank=2 px=   50.60
# 2025-10-08 17:17:54 | INFO | BUY MANAPPURAM.NS px=   78.42 sh=   836 fee=101.45 cash=298166.54 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, Close>SMA50, Close>BBmid; 52w%=95.4% (>= 50%); VOLAR rank 1/2 (VOLAR=2.96); MVO weight=60.1% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | BUY UNOMINDA.NS  px=   51.60 sh=   843 fee=75.25 cash=254589.97 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=98.7% (>= 50%); VOLAR rank 2/2 (VOLAR=2.17); MVO weight=39.9% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit UNOMINDA.NS  px=   55.66 sh=   843 reason=TakeProfit hit (10.0%). filled=55.66, TP=55.66, ret=10.00%, held=9d net=3249.56 cash=301416.09
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-10-13:
# 2025-10-08 17:17:54 | INFO |   JSWSTEEL.NS  volar=  2.22 rank=1 px=  163.27
# 2025-10-08 17:17:54 | INFO | BUY JSWSTEEL.NS  px=  159.97 sh=   565 fee=130.92 cash=210900.46 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=97.4% (>= 50%); VOLAR rank 1/1 (VOLAR=2.22); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit JSWSTEEL.NS  px=  155.70 sh=   565 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=158.74, 20=158.91); filled=155.70, ret=-4.63%, held=5d net=-2681.62 cash=298734.47
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-10-18:
# 2025-10-08 17:17:54 | INFO |   BAYERCROP.NS volar=  0.54 rank=1 px= 3885.59
# 2025-10-08 17:17:54 | INFO | BUY BAYERCROP.NS px= 3868.15 sh=    23 fee=129.24 cash=209637.69 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=99.3% (>= 50%); VOLAR rank 1/1 (VOLAR=0.54); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit MANAPPURAM.NS px=   87.51 sh=   836 reason=TakeProfit hit (10.0%). filled=87.51, TP=87.51, ret=10.00%, held=15d net=7370.11 cash=282670.78
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-10-19:
# 2025-10-08 17:17:54 | INFO |   BAJFINANCE.NS volar=  2.19 rank=1 px=  109.12
# 2025-10-08 17:17:54 | INFO | BUY BAJFINANCE.NS px=  108.69 sh=   780 fee=124.26 cash=197769.86 :: EMA10>EMA20 & 2xGreenStrict; confirms: Close>SMA50, Close>BBmid; 52w%=96.1% (>= 50%); VOLAR rank 1/1 (VOLAR=2.19); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:17:54 | INFO | Exit KAJARIACER.NS px=  577.75 sh=   122 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=643.83, 20=644.14); filled=577.75, ret=-8.36%, held=46d net=-6674.60 cash=268135.26
# 2025-10-08 17:17:54 | INFO | Selected 1 BUY candidates on 2016-10-24:
# ...
# 2025-10-08 17:18:28 | INFO | BUY PPLPHARMA.NS px=  214.97 sh=   892 fee=251.29 cash=950909.49 :: EMA10>EMA20 & 2xGreenStrict; confirms: ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=96.9% (>= 50%); VOLAR rank 2/3 (VOLAR=1.55); MVO weight=51.2% of capped cash (30% of available)
# 2025-10-08 17:18:28 | INFO | BUY BBTC.NS      px= 2611.74 sh=    28 fee=110.43 cash=877670.22 :: EMA10>EMA20 & 2xGreenStrict; confirms: Close>SMA50, Close>BBmid; 52w%=97.1% (>= 50%); VOLAR rank 3/3 (VOLAR=1.18); MVO weight=20.0% of capped cash (30% of available)
# 2025-10-08 17:18:28 | INFO | Exit RRKABEL.NS   px= 1606.72 sh=   183 reason=StopLoss hit (10.0%). filled=1606.72, SL=1606.72, ret=-10.00%, held=15d net=-26407.59 cash=1171348.17
# 2025-10-08 17:18:28 | INFO | Exit PPLPHARMA.NS px=  249.99 sh=   892 reason=TakeProfit hit (10.0%). filled=249.99, TP=249.99, ret=10.00%, held=2d net=30706.52 cash=1394059.86
# 2025-10-08 17:18:28 | INFO | Selected 2 BUY candidates on 2024-10-24:
# 2025-10-08 17:18:28 | INFO |   POLYMED.NS   volar=  1.24 rank=1 px= 2580.47
# 2025-10-08 17:18:28 | INFO |   HINDZINC.NS  volar=  0.90 rank=2 px=  516.19
# 2025-10-08 17:18:28 | INFO | BUY POLYMED.NS   px= 2566.94 sh=   114 fee=371.07 cash=1101057.35 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/2 (VOLAR=1.24); MVO weight=70.0% of capped cash (30% of available)
# 2025-10-08 17:18:28 | INFO | BUY HINDZINC.NS  px=  528.98 sh=   236 fee=171.84 cash=976045.66 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=70.3% (>= 50%); VOLAR rank 2/2 (VOLAR=0.90); MVO weight=30.0% of capped cash (30% of available)
# 2025-10-08 17:18:28 | INFO | Exit GLENMARK.NS  px= 1675.39 sh=   126 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=1712.04, 20=1713.07); filled=1675.39, ret=-3.53%, held=16d net=-13961.40 cash=1186878.68
# 2025-10-08 17:18:28 | INFO | Selected 1 BUY candidates on 2024-10-25:
# 2025-10-08 17:18:28 | INFO |   PPLPHARMA.NS volar=  1.82 rank=1 px=  250.34
# 2025-10-08 17:18:28 | INFO | BUY PPLPHARMA.NS px=  244.27 sh=  1457 fee=446.20 cash=830528.57 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=1.82); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | Exit POLYMED.NS   px= 2838.52 sh=   114 reason=TakeProfit hit (10.0%). filled=2838.52, TP=2838.52, ret=10.00%, held=7d net=30205.37 cash=1153736.44
# 2025-10-08 17:18:29 | INFO | Selected 1 BUY candidates on 2024-10-31:
# 2025-10-08 17:18:29 | INFO |   ZENTEC.NS    volar=  1.75 rank=1 px= 1804.41
# 2025-10-08 17:18:29 | INFO | BUY ZENTEC.NS    px= 1881.70 sh=   183 fee=432.48 cash=808953.09 :: EMA10>EMA20 & 2xGreenStrict; confirms: Close>SMA50, Close>BBmid; 52w%=91.3% (>= 50%); VOLAR rank 1/1 (VOLAR=1.75); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | Exit PPLPHARMA.NS px=  275.37 sh=  1457 reason=TakeProfit hit (10.0%). filled=275.37, TP=275.37, ret=10.00%, held=7d net=44402.87 cash=1209706.07
# 2025-10-08 17:18:29 | INFO | Selected 1 BUY candidates on 2024-11-01:
# 2025-10-08 17:18:29 | INFO |   GVT&D.NS     volar=  2.97 rank=1 px= 1816.67
# 2025-10-08 17:18:29 | INFO | BUY GVT&D.NS     px= 1800.00 sh=   201 fee=453.20 cash=847452.45 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, Close>SMA50, Close>BBmid; 52w%=92.0% (>= 50%); VOLAR rank 1/1 (VOLAR=2.97); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | Exit BSE.NS       px= 1593.64 sh=    79 reason=TakeProfit hit (10.0%). filled=1593.64, TP=1593.64, ret=10.00%, held=15d net=18197.43 cash=973172.24
# 2025-10-08 17:18:29 | INFO | Selected 1 BUY candidates on 2024-11-06:
# 2025-10-08 17:18:29 | INFO |   NEULANDLAB.NS volar=  2.07 rank=1 px=15986.76
# 2025-10-08 17:18:29 | INFO | BUY NEULANDLAB.NS px=14153.53 sh=    20 fee=359.72 cash=689741.93 :: EMA10>EMA20 & 2xGreenStrict; confirms: MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=97.6% (>= 50%); VOLAR rank 1/1 (VOLAR=2.07); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | Exit NEULANDLAB.NS px=14388.09 sh=    20 reason=StopLoss hit (10.0%). filled=14388.09, SL=14388.09, ret=-10.00%, held=1d net=3985.67 cash=977157.91
# 2025-10-08 17:18:29 | INFO | Selected 1 BUY candidates on 2024-11-07:
# 2025-10-08 17:18:29 | INFO |   CHOICEIN.NS  volar=  2.35 rank=1 px=  537.00
# 2025-10-08 17:18:29 | INFO | BUY CHOICEIN.NS  px=  531.90 sh=   551 fee=371.60 cash=683709.39 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=2.35); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | Exit HINDZINC.NS  px=  499.08 sh=   236 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=513.47, 20=514.09); filled=499.08, ret=-3.31%, held=19d net=-7398.90 cash=801322.18
# 2025-10-08 17:18:29 | INFO | Selected 1 BUY candidates on 2024-11-12:
# 2025-10-08 17:18:29 | INFO |   THERMAX.NS   volar=  0.89 rank=1 px= 5258.78
# 2025-10-08 17:18:29 | INFO | BUY THERMAX.NS   px= 5091.16 sh=    47 fee=307.73 cash=561729.99 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=92.0% (>= 50%); VOLAR rank 1/1 (VOLAR=0.89); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | Exit BBTC.NS      px= 2514.74 sh=    28 reason=StopLoss hit (10.0%). filled=2514.74, SL=2514.74, ret=-10.00%, held=22d net=-2946.76 cash=632022.51
# 2025-10-08 17:18:29 | INFO | Selected 1 BUY candidates on 2024-11-13:
# 2025-10-08 17:18:29 | INFO |   NEULANDLAB.NS volar=  2.18 rank=1 px=15584.09
# 2025-10-08 17:18:29 | INFO | BUY NEULANDLAB.NS px=14654.21 sh=    12 fee=232.41 cash=455939.54 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=94.3% (>= 50%); VOLAR rank 1/1 (VOLAR=2.18); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | Exit THERMAX.NS   px= 4978.81 sh=    47 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=5049.74, 20=5061.09); filled=4978.81, ret=-5.32%, held=2d net=-5877.99 cash=689653.74
# 2025-10-08 17:18:29 | INFO | Exit ZENTEC.NS    px= 1687.62 sh=   183 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=1799.17, 20=1803.90); filled=1687.62, ret=-6.47%, held=14d net=-36316.08 cash=998121.02
# 2025-10-08 17:18:29 | INFO | Selected 2 BUY candidates on 2024-11-19:
# 2025-10-08 17:18:29 | INFO |   TARIL.NS     volar=  2.65 rank=1 px=  461.81
# 2025-10-08 17:18:29 | INFO |   MEDANTA.NS   volar=  0.33 rank=2 px= 1080.56
# 2025-10-08 17:18:29 | INFO | BUY TARIL.NS     px=  466.16 sh=   460 fee=278.22 cash=783410.74 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, Close>SMA50; 52w%=88.5% (>= 50%); VOLAR rank 1/2 (VOLAR=2.65); MVO weight=71.7% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | BUY MEDANTA.NS   px= 1091.51 sh=    77 fee=123.40 cash=699241.30 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, Close>SMA50, Close>BBmid; 52w%=72.7% (>= 50%); VOLAR rank 2/2 (VOLAR=0.33); MVO weight=28.3% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | Exit TARIL.NS     px=  507.99 sh=   460 reason=TakeProfit hit (10.0%). filled=507.99, TP=507.99, ret=10.00%, held=7d net=18675.18 cash=932626.75
# 2025-10-08 17:18:29 | INFO | Selected 1 BUY candidates on 2024-11-26:
# 2025-10-08 17:18:29 | INFO |   POLICYBZR.NS volar=  1.49 rank=1 px= 1811.00
# 2025-10-08 17:18:29 | INFO | BUY POLICYBZR.NS px= 1850.80 sh=   151 fee=355.45 cash=652800.50 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=93.5% (>= 50%); VOLAR rank 1/1 (VOLAR=1.49); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | Exit NEULANDLAB.NS px=17142.50 sh=    12 reason=TakeProfit hit (10.0%). filled=17142.50, TP=17142.50, ret=10.00%, held=19d net=29366.47 cash=858249.94
# 2025-10-08 17:18:29 | INFO | Exit POLICYBZR.NS px= 1992.10 sh=   151 reason=TakeProfit hit (10.0%). filled=1992.10, TP=1992.10, ret=10.00%, held=6d net=20621.59 cash=1158697.78
# 2025-10-08 17:18:29 | INFO | Selected 2 BUY candidates on 2024-12-02:
# 2025-10-08 17:18:29 | INFO |   JUBLPHARMA.NS volar=  1.87 rank=1 px= 1219.79
# 2025-10-08 17:18:29 | INFO |   ANANDRATHI.NS volar=  1.19 rank=2 px= 2069.33
# 2025-10-08 17:18:29 | INFO | BUY JUBLPHARMA.NS px= 1197.13 sh=   136 fee=216.92 cash=995670.63 :: EMA10>EMA20 & 2xGreenStrict; confirms: MACD>Signal, Close>SMA50, Close>BBmid; 52w%=97.8% (>= 50%); VOLAR rank 1/2 (VOLAR=1.87); MVO weight=47.0% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | BUY ANANDRATHI.NS px= 2075.90 sh=    88 fee=240.51 cash=812750.73 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=97.0% (>= 50%); VOLAR rank 2/2 (VOLAR=1.19); MVO weight=53.0% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | Exit ANANDRATHI.NS px= 2276.26 sh=    88 reason=TakeProfit hit (10.0%). filled=2276.26, TP=2276.26, ret=10.00%, held=7d net=17136.21 cash=1012806.84
# 2025-10-08 17:18:29 | INFO | Exit MEDANTA.NS   px= 1188.62 sh=    77 reason=TakeProfit hit (10.0%). filled=1188.62, TP=1188.62, ret=10.00%, held=20d net=7211.92 cash=1104188.21
# 2025-10-08 17:18:29 | INFO | Selected 2 BUY candidates on 2024-12-09:
# 2025-10-08 17:18:29 | INFO |   VEDL.NS      volar=  1.84 rank=1 px=  466.16
# 2025-10-08 17:18:29 | INFO |   RVNL.NS      volar=  1.46 rank=2 px=  463.28
# 2025-10-08 17:18:29 | INFO | BUY VEDL.NS      px=  463.45 sh=   526 fee=313.06 cash=860099.38 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=97.1% (>= 50%); VOLAR rank 1/2 (VOLAR=1.84); MVO weight=73.7% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | BUY RVNL.NS      px=  468.10 sh=   186 fee=126.98 cash=772905.17 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>SMA50, Close>BBmid; 52w%=74.0% (>= 50%); VOLAR rank 2/2 (VOLAR=1.46); MVO weight=26.3% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | Exit JUBLPHARMA.NS px= 1144.51 sh=   136 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=1172.03, 20=1173.09); filled=1144.51, ret=-6.17%, held=10d net=-7582.61 cash=928349.72
# 2025-10-08 17:18:29 | INFO | Selected 1 BUY candidates on 2024-12-12:
# 2025-10-08 17:18:29 | INFO |   TARIL.NS     volar=  2.91 rank=1 px=  569.74
# 2025-10-08 17:18:29 | INFO | BUY TARIL.NS     px=  561.69 sh=   495 fee=353.74 cash=649958.42 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=2.91); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | Exit GVT&D.NS     px= 1998.34 sh=   201 reason=TakeProfit hit (10.0%). filled=1998.34, TP=1998.34, ret=10.00%, held=45d net=38948.55 cash=1051160.60
# 2025-10-08 17:18:29 | INFO | Selected 1 BUY candidates on 2024-12-16:
# 2025-10-08 17:18:29 | INFO |   PGEL.NS      volar=  2.46 rank=1 px=  932.59
# 2025-10-08 17:18:29 | INFO | BUY PGEL.NS      px=  999.71 sh=   315 fee=397.52 cash=735854.63 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=2.46); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | Exit RVNL.NS      px=  427.76 sh=   186 reason=Trend reverse: EMA10 cross↓ below EMA20 (10=447.54, 20=448.58); filled=427.76, ret=-7.67%, held=15d net=-7759.81 cash=815289.03
# 2025-10-08 17:18:29 | INFO | Selected 1 BUY candidates on 2024-12-26:
# 2025-10-08 17:18:29 | INFO |   TRENT.NS     volar=  2.08 rank=1 px= 7041.85
# 2025-10-08 17:18:29 | INFO | BUY TRENT.NS     px= 7057.59 sh=    34 fee=308.53 cash=575022.58 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>BBmid; 52w%=85.1% (>= 50%); VOLAR rank 1/1 (VOLAR=2.08); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | Exit VEDL.NS      px=  419.54 sh=   526 reason=StopLoss hit (10.0%). filled=419.54, SL=419.54, ret=-10.00%, held=21d net=-23686.70 cash=795424.71
# 2025-10-08 17:18:29 | INFO | Selected 1 BUY candidates on 2024-12-30:
# 2025-10-08 17:18:29 | INFO |   GLENMARK.NS  volar=  1.83 rank=1 px= 1585.46
# 2025-10-08 17:18:29 | INFO | BUY GLENMARK.NS  px= 1585.91 sh=   150 fee=306.07 cash=557232.12 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, Close>BBmid; 52w%=87.2% (>= 50%); VOLAR rank 1/1 (VOLAR=1.83); MVO weight=100.0% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | Exit CHOICEIN.NS  px=  555.65 sh=   551 reason=Final close (backtest end). filled=555.65, ret=3.47%, held=54d net=12349.83 cash=863030.47
# 2025-10-08 17:18:29 | INFO | Exit GLENMARK.NS  px= 1605.16 sh=   150 reason=Final close (backtest end). filled=1605.16, ret=1.24%, held=1d net=2284.85 cash=1103507.92
# 2025-10-08 17:18:29 | INFO | Exit PGEL.NS      px= 1025.85 sh=   315 reason=TakeProfit hit (10.0%). filled=1025.85, TP=1025.85, ret=10.00%, held=15d net=7453.66 cash=1426267.54
# 2025-10-08 17:18:29 | INFO | Exit TARIL.NS     px=  569.66 sh=   495 reason=Final close (backtest end). filled=569.66, ret=-0.01%, held=19d net=3252.54 cash=1707911.37
# 2025-10-08 17:18:29 | INFO | Exit TRENT.NS     px= 7117.18 sh=    34 reason=Final close (backtest end). filled=7117.18, ret=1.07%, held=5d net=1419.57 cash=1949597.40
# 2025-10-08 17:18:29 | INFO | Selected 5 BUY candidates on 2024-12-31:
# 2025-10-08 17:18:29 | INFO |   OFSS.NS      volar=  2.20 rank=1 px=12461.57
# 2025-10-08 17:18:29 | INFO |   FSL.NS       volar=  1.50 rank=2 px=  371.88
# 2025-10-08 17:18:29 | INFO |   GODREJIND.NS volar=  1.03 rank=3 px= 1175.00
# 2025-10-08 17:18:29 | INFO |   BAJAJHLDNG.NS volar=  0.86 rank=4 px=12401.45
# 2025-10-08 17:18:29 | INFO |   AUROPHARMA.NS volar=  0.38 rank=5 px= 1297.13
# 2025-10-08 17:18:29 | INFO | BUY OFSS.NS      px=12392.19 sh=    16 fee=259.03 cash=1751063.28 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 1/5 (VOLAR=2.20); MVO weight=34.1% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | BUY FSL.NS       px=  371.88 sh=   300 fee=156.07 cash=1639344.56 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=98.4% (>= 50%); VOLAR rank 2/5 (VOLAR=1.50); MVO weight=19.1% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | BUY GODREJIND.NS px= 1166.20 sh=   114 fee=181.46 cash=1506216.30 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=97.3% (>= 50%); VOLAR rank 3/5 (VOLAR=1.03); MVO weight=22.9% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | BUY BAJAJHLDNG.NS px=11804.37 sh=    10 fee=163.77 cash=1388008.88 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>SMA50, Close>BBmid; 52w%=100.0% (>= 50%); VOLAR rank 4/5 (VOLAR=0.86); MVO weight=22.1% of capped cash (30% of available)
# 2025-10-08 17:18:29 | INFO | BUY AUROPHARMA.NS px= 1329.51 sh=     8 fee=25.18 cash=1377347.63 :: EMA10>EMA20 & 2xGreenStrict; confirms: RSI>50, MACD>Signal, ADX>20 & +DI>-DI, Close>BBmid; 52w%=82.7% (>= 50%); VOLAR rank 5/5 (VOLAR=0.38); MVO weight=1.8% of capped cash (30% of available)
# 2025-10-08 17:18:30 | INFO | === METRICS ===
# {
#   "start_equity_inr": 500000.0,
#   "final_equity_inr": 1948811.8847253968,
#   "cagr_pct": 16.372338534153986,
#   "sharpe": 1.1648240902010183,
#   "max_drawdown_pct": -22.354462093924415,
#   "win_rate_pct": 51.67322834645669,
#   "n_trades": 1016
# }
# 2025-10-08 17:18:30 | INFO | Files written:
#   outputs/trades_legs_20251008_171829.csv
#   outputs/trades_roundtrips_20251008_171829.csv
#   outputs/equity_20251008_171829.csv
#   outputs/metrics_20251008_171829.json
# 2025-10-08 17:18:30 | INFO |   outputs/equity_20251008_171829.png

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
===============================================================
Strategy & Pipeline — Quick Reference
===============================================================

ENTRY (long-only)
-----------------
Signal day (D0):
  • Trend: Close > EMA50.
  • Pattern: "Pivot Reclaim". The D-1 candle's Close was BELOW a pivot
    (PP, S1, or S2) AND the D0 candle's Close is ABOVE that same pivot.
  • Confirmation: At least ONE of the following is true on D0:
      - RSI > 50
      - MACD line > signal (hist > 0)
      - ADX > 20 AND +DI > -DI
      - Close > SMA50
      - Close > Bollinger middle band

Execution day (D1):
  • If configured (entry_on_next_open=True), the buy is placed at D1's Open.
  • Stop & Target are set off the executed entry price:
      SL = entry_price * (1 - stop_loss_pct)
      TP = entry_price * (1 + target_pct)

EXIT
----
Checked every bar after entry:
  1) Hard StopLoss (HSL): If next bar’s Low ≤ SL → exit (filled=SL).
  2) TakeProfit (TP):     If next bar’s High ≥ TP → exit (filled=TP).
     (If both SL and TP touch on the same bar, we assume TP priority.)
  3) Trend reverse: If Close < EMA50 on the signal bar, exit next open.

Exit reasons are verbose in CSV:
  • "StopLoss hit (5.0%). filled=..., SL=..., ret=...%, held=...d"
  • "TakeProfit hit (10.0%). filled=..., TP=..., ret=...%, held=...d"
  • "Trend reverse: Close below EMA50 (Close=..., EMA50=...);
     filled=..., ret=...%, held=...d"

PORTFOLIO PIPELINE (daily loop)
-------------------------------
1) Aggregate all per-ticker BUY 'candidate' legs dated for D1 from signals on D0.
2) Optional filter: price within >= {within_pct_of_52w_high:.0%} of 52-week high.
3) Exclude tickers we already hold.
4) Rank survivors by VOLAᵣ (excess return vs benchmark / own volatility; 252d lookback).
5) Capacity gate:
   • slots = max_concurrent_positions - current_open_positions
   • pick = min(top_k_daily, slots)
6) Sizing via Markowitz (MVO), long-only:
   • Compute mu (means) and Sigma (cov) on 252d daily returns on D0.
   • Solve for weights that maximize mean/vol (with long-only projection).
   • Cap *deployable cash* to deploy_cash_frac × current cash (e.g., 25%).
   • Allocate that capped bucket by MVO weights across today's picks.
7) Execute BUYs at D1 (close or open per config), deduct fees, open positions.
8) Process SELLs before BUYs each day; update equity curve after all legs.
"""

import os, json, math, warnings, logging
from dataclasses import dataclass
from typing import Dict, List, Tuple, Optional

import numpy as np
import pandas as pd

try:
    import yfinance as yf
    import matplotlib.pyplot as plt
except Exception:
    pass

warnings.filterwarnings("ignore", category=FutureWarning)

# =========================
# LOGGING
# =========================
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)
log = logging.getLogger("pivot_reclaim_ema50_confirm_v1")

# =========================
# CONFIG
# =========================
@dataclass
class Config:
    # Data
    start_date: str = "2015-01-01"
    end_date: str   = "2025-01-01"
    static_symbols: Optional[List[str]] = None
    static_symbols_path: Optional[str] = None
    cache_dir: str = "cache"
    out_dir: str   = "outputs"
    plot: bool     = True

    # --- Strategy params ---
    ema_trend_len: int = 50       # EMA50 for main trend
    sma_confirm_len: int = 50     # SMA50 for confirm
    sma_trend_len: int = 200      # SMA200 (kept for breadth/context if needed)
    rsi_len: int = 14
    macd_fast: int = 12
    macd_slow: int = 26
    macd_signal: int = 9
    bb_len: int = 20
    bb_std: float = 2.0
    adx_len: int = 14
    adx_min: float = 20.0

    # Exits
    stop_loss_pct: float = 0.10
    target_pct: float    = 0.10

    # Portfolio
    apply_fees: bool    = True
    initial_capital: float = 500_000.0
    max_concurrent_positions: int = 5
    deploy_cash_frac: float = 0.30
    entry_on_next_open: bool = True
    exit_on_next_open: bool  = True

    # Candidate ranking & filters
    benchmark_try: Tuple[str,...] = ("^CNX500","^CRSLDX","^NSE500","^NIFTY500","^BSE500","^NSEI")
    volar_lookback: int = 252
    filter_52w_window: int = 252
    within_pct_of_52w_high: float = 0.50
    top_k_daily: int = 300

    # Liquidity guards (OFF by default)
    enable_basic_liquidity: bool = False
    min_price_inr: float = 50.0
    min_avg_vol_20d: float = 50_000.0

CFG = Config()

# =========================
# FEES (per user spec)
# =========================
APPLY_FEES = True

def calc_fees(turnover_buy: float, turnover_sell: float) -> float:
    if not APPLY_FEES:
        return 0.0
    BROKER_PCT = 0.001
    BROKER_MIN = 5.0
    BROKER_CAP = 20.0
    STT_PCT = 0.001
    STAMP_BUY_PCT = 0.00015
    EXCH_PCT = 0.0000297
    SEBI_PCT = 0.000001
    IPFT_PCT = 0.000001
    GST_PCT = 0.18
    DP_SELL = 20.0 if turnover_sell >= 100 else 0.0

    def _broker(turnover):
        if turnover <= 0:
            return 0.0
        fee = turnover * BROKER_PCT
        fee = max(BROKER_MIN, min(fee, BROKER_CAP))
        return fee

    br_buy  = _broker(turnover_buy)
    br_sell = _broker(turnover_sell)
    stt   = STT_PCT * (turnover_buy + turnover_sell)
    stamp = STAMP_BUY_PCT * turnover_buy
    exch  = EXCH_PCT * (turnover_buy + turnover_sell)
    sebi  = SEBI_PCT * (turnover_buy + turnover_sell)
    ipft  = IPFT_PCT * (turnover_buy + turnover_sell)
    dp    = DP_SELL
    gst_base = br_buy + br_sell + dp + exch + sebi + ipft
    gst   = GST_PCT * gst_base
    return float((br_buy + br_sell) + stt + stamp + exch + sebi + ipft + dp + gst)

# =========================
# Helpers
# =========================
def ensure_dirs(*paths):
    for p in paths:
        os.makedirs(p, exist_ok=True)

def today_str():
    return pd.Timestamp.today(tz="Asia/Kolkata").strftime("%Y-%m-%d")

def load_static_symbols(static_symbols: Optional[List[str]], static_symbols_path: Optional[str]) -> List[str]:
    syms: List[str] = []
    if static_symbols and len(static_symbols) > 0:
        syms = list(static_symbols)
    elif static_symbols_path and os.path.exists(static_symbols_path):
        with open(static_symbols_path, "r") as f:
            syms = [line.strip() for line in f if line.strip()]
    else:
        raise ValueError(
            "Provide CFG.static_symbols=[...] ('.NS' suffixes) or set CFG.static_symbols_path "
            "to a file containing one symbol per line."
        )
    out = []
    for s in syms:
        s = s.strip().upper()
        if not s.endswith(".NS"):
            s = f"{s}.NS"
        out.append(s)
    seen = set()
    uniq = []
    for s in out:
        if s not in seen:
            uniq.append(s)
            seen.add(s)
    return uniq

def fetch_prices(tickers: List[str], start: str, end: Optional[str], cache_dir: str) -> Dict[str, pd.DataFrame]:
    ensure_dirs(cache_dir)
    data = {}
    end = end or today_str()
    for ticker in tickers:
        cache_path = os.path.join(cache_dir, f"{ticker.replace('^', '_')}.parquet")
        if os.path.exists(cache_path):
            try:
                df = pd.read_parquet(cache_path)
                if len(df) and pd.to_datetime(df.index[-1]).strftime("%Y-%m-%d") >= end:
                    data[ticker] = df
                    continue
            except Exception:
                pass
        try:
            df = yf.download(ticker, start=start, end=end, auto_adjust=True, progress=False, multi_level_index=False)
            if df is None or df.empty:
                continue
            df = df.rename(columns=str.title)  # Open, High, Low, Close, Volume
            df = df[['Open', 'High', 'Low', 'Close', 'Volume']].dropna()
            df.index.name = "date"
            df.to_parquet(cache_path)
            data[ticker] = df
        except Exception:
            continue
    return data

def ema(series: pd.Series, span: int) -> pd.Series:
    return series.ewm(span=span, adjust=False, min_periods=span).mean()

def sma(series: pd.Series, window: int) -> pd.Series:
    return series.rolling(window).mean()

def rsi(series: pd.Series, length: int = 14) -> pd.Series:
    delta = series.diff()
    gain = (delta.where(delta > 0, 0.0)).rolling(length).mean()
    loss = (-delta.where(delta < 0, 0.0)).rolling(length).mean()
    rs = gain / loss.replace(0.0, np.nan)
    out = 100 - (100 / (1 + rs))
    return out.fillna(50.0)

def macd(series: pd.Series, fast=12, slow=26, signal=9):
    ema_fast = series.ewm(span=fast, adjust=False, min_periods=slow).mean()
    ema_slow = series.ewm(span=slow, adjust=False, min_periods=slow).mean()
    macd_line = ema_fast - ema_slow
    macd_signal = macd_line.ewm(span=signal, adjust=False, min_periods=signal).mean()
    hist = macd_line - macd_signal
    return macd_line, macd_signal, hist

def _true_range(high: pd.Series, low: pd.Series, prev_close: pd.Series) -> pd.Series:
    return pd.concat([
        (high - low).abs(),
        (high - prev_close).abs(),
        (low - prev_close).abs()
    ], axis=1).max(axis=1)

def dmi_adx(high: pd.Series, low: pd.Series, close: pd.Series, length: int = 14):
    prev_high = high.shift(1)
    prev_low  = low.shift(1)
    prev_close = close.shift(1)

    up_move   = high - prev_high
    down_move = prev_low - low
    plus_dm  = up_move.where((up_move > down_move) & (up_move > 0), 0.0)
    minus_dm = down_move.where((down_move > up_move) & (down_move > 0), 0.0)

    tr = _true_range(high, low, prev_close)
    alpha = 1.0 / length
    atr = tr.ewm(alpha=alpha, adjust=False, min_periods=length).mean()
    plus_di  = 100 * (plus_dm.ewm(alpha=alpha, adjust=False, min_periods=length).mean() / atr)
    minus_di = 100 * (minus_dm.ewm(alpha=alpha, adjust=False, min_periods=length).mean() / atr)

    dx = 100 * (plus_di - minus_di).abs() / (plus_di + minus_di).replace(0, np.nan)
    adx_series = dx.ewm(alpha=alpha, adjust=False, min_periods=length).mean()
    return plus_di, minus_di, adx_series

def bollinger(series: pd.Series, length=20, nstd=2.0):
    mid = series.rolling(length).mean()
    sd  = series.rolling(length).std(ddof=0)
    upper = mid + nstd * sd
    lower = mid - nstd * sd
    return mid, upper, lower

def compute_indicators(df: pd.DataFrame, cfg: Config) -> pd.DataFrame:
    out = df.copy()
    
    # --- NEW: Add EMA50 for trend
    out["ema50"] = ema(out["Close"], cfg.ema_trend_len)
    
    # --- NEW: Add Standard Pivot Points ---
    prev_high = out['High'].shift(1)
    prev_low = out['Low'].shift(1)
    prev_close = out['Close'].shift(1)
    out['PP'] = (prev_high + prev_low + prev_close) / 3
    out['R1'] = (2 * out['PP']) - prev_low
    out['S1'] = (2 * out['PP']) - prev_high
    out['R2'] = out['PP'] + (prev_high - prev_low)
    out['S2'] = out['PP'] - (prev_high - prev_low)
    # --- End NEW ---

    # Keep all other indicators for the 'confirmation_any' function
    out["sma50"]    = sma(out["Close"], cfg.sma_confirm_len)
    out["sma200"]   = sma(out["Close"], cfg.sma_trend_len)
    out["rsi"]      = rsi(out["Close"], cfg.rsi_len)
    macd_line, macd_signal, macd_hist = macd(out["Close"], cfg.macd_fast, cfg.macd_slow, cfg.macd_signal)
    out["macd_line"] = macd_line
    out["macd_signal"] = macd_signal
    out["macd_hist"] = macd_hist
    out["bb_mid"], out["bb_up"], out["bb_low"] = bollinger(out["Close"], cfg.bb_len, cfg.bb_std)
    out["+DI"], out["-DI"], out["ADX"] = dmi_adx(out["High"], out["Low"], out["Close"], cfg.adx_len)
    
    out["avg_vol_20"] = out["Volume"].rolling(20).mean()
    out["high_52w"] = out["Close"].rolling(cfg.filter_52w_window).max()
    return out.dropna()

def basic_liquidity_ok(row: pd.Series, cfg: Config) -> bool:
    if not cfg.enable_basic_liquidity:
        return True
    if row["Close"] < cfg.min_price_inr:
        return False
    if row["avg_vol_20"] < cfg.min_avg_vol_20d:
        return False
    return True

# ---------- NEW ENTRY/EXIT LOGIC ----------
# (two_green_strict function removed as it's no longer used)

def confirmation_any(row: pd.Series, cfg: Config) -> Tuple[bool, str]:
    # This function is UNCHANGED. It serves as our confirmation.
    checks = []
    # RSI > 50
    checks.append(("RSI>50", row["rsi"] > 50.0))
    # MACD line > signal (hist>0)
    checks.append(("MACD>Signal", row["macd_hist"] > 0.0))
    # ADX>20 and +DI > -DI
    checks.append(("ADX>20 & +DI>-DI", (row["ADX"] > cfg.adx_min) and (row["+DI"] > row["-DI"])))
    # Close > SMA50
    checks.append(("Close>SMA50", row["Close"] > row["sma50"]))
    # Close > Bollinger Mid
    checks.append(("Close>BBmid", row["Close"] > row["bb_mid"]))

    passed = [name for name, ok in checks if ok]
    return (len(passed) >= 1, ", ".join(passed) if passed else "none")

def simulate_ticker(ticker: str, df: pd.DataFrame, cfg: Config):
    d = compute_indicators(df, cfg).copy()
    
    # --- NEW: Updated columns
    cols = ["ticker","side","date","price","shares","reason","signal_reason","score",
            "rsi","ADX","+DI","-DI",
            "ema50", "PP", "S1", "S2", # <-- NEW
            "sma50","sma200",
            "macd_line","macd_signal","macd_hist","bb_mid","bb_up","bb_low",
            "close","high_52w"]
            
    if d.empty or len(d) < 60:
        return pd.DataFrame(columns=cols), pd.Series(dtype=float)

    in_pos = False
    entry_px = stop_px = tgt_px = 0.0
    entry_dt = None
    trades = []

    idx = list(d.index)

    for i in range(1, len(idx)-1):
        dt = idx[i]
        nxt = idx[i+1]
        prev_dt = idx[i-1]

        row = d.loc[dt]
        prev_row = d.loc[prev_dt]
        nxt_row = d.loc[nxt]

        # --- NEW: Trend reverse condition for exit
        trend_reverse_now = row["Close"] < row["ema50"]

        if not in_pos:
            # --- NEW: Replaced entry logic ---
            # 1. Trend: Close > EMA50
            trend_ok = row["Close"] > row["ema50"]
            
            # 2. Pattern: "Pivot Reclaim" (was below, now above)
            reclaim_s1 = (prev_row["Close"] < row["S1"]) and (row["Close"] >= row["S1"])
            reclaim_s2 = (prev_row["Close"] < row["S2"]) and (row["Close"] >= row["S2"])
            reclaim_pp = (prev_row["Close"] < row["PP"]) and (row["Close"] >= row["PP"])
            pivot_ok = reclaim_s1 or reclaim_s2 or reclaim_pp
            
            # 3. Confirmation: Use existing function
            confirm_ok, confirm_str = confirmation_any(row, cfg)

            if trend_ok and pivot_ok and confirm_ok and basic_liquidity_ok(row, cfg):
                # --- End NEW logic ---
                
                # Execute at next open (or current close if configured)
                px = float(nxt_row["Open"] if cfg.entry_on_next_open else row["Close"])
                
                # --- NEW: Updated signal reason
                reclaimed_level = "S1" if reclaim_s1 else ("S2" if reclaim_s2 else "PP")
                sig_reason = f"Close>EMA50 & PivotReclaim ({reclaimed_level}); confirms: {confirm_str}"
                
                score = 1.0  # placeholder; downstream selection uses VOLAᵣ
                
                # --- NEW: Updated trade dict
                trades.append({
                    "ticker": ticker, "side": "BUY", "date": nxt if cfg.entry_on_next_open else dt,
                    "price": px, "shares": 0, "reason": "candidate",
                    "signal_reason": sig_reason, "score": float(score),
                    "rsi": float(row["rsi"]), "ADX": float(row["ADX"]),
                    "+DI": float(row["+DI"]), "-DI": float(row["-DI"]),
                    "ema50": float(row["ema50"]), # <-- NEW
                    "PP": float(row["PP"]), "S1": float(row["S1"]), "S2": float(row["S2"]), # <-- NEW
                    "sma50": float(row["sma50"]), "sma200": float(row["sma200"]),
                    "macd_line": float(row["macd_line"]), "macd_signal": float(row["macd_signal"]), "macd_hist": float(row["macd_hist"]),
                    "bb_mid": float(row["bb_mid"]), "bb_up": float(row["bb_up"]), "bb_low": float(row["bb_low"]),
                    "close": float(row["Close"]), "high_52w": float(row["high_52w"])
                })
                in_pos = True
                entry_px = px
                entry_dt = nxt if cfg.entry_on_next_open else dt
                stop_px = entry_px * (1 - cfg.stop_loss_pct)
                tgt_px  = entry_px * (1 + cfg.target_pct)

        else:
            # EXIT rules: HSL / TP / Trend reverse
            hit = None
            exec_date = nxt if cfg.exit_on_next_open else dt

            if nxt_row["Low"] <= stop_px and nxt_row["High"] >= tgt_px:
                hit, exec_price = "target", float(tgt_px)
            elif nxt_row["Low"] <= stop_px:
                hit, exec_price = "stop", float(stop_px)
            elif nxt_row["High"] >= tgt_px:
                hit, exec_price = "target", float(tgt_px)
            elif trend_reverse_now: # <-- This variable was updated
                exec_price = float(nxt_row["Open"] if cfg.exit_on_next_open else row["Close"])
                hit = "trend_reverse"

            if hit is not None:
                pnl_pct = float((exec_price / entry_px - 1.0) * 100.0) if entry_px else float("nan")
                held_days = int((pd.to_datetime(exec_date) - pd.to_datetime(entry_dt)).days) if entry_dt else 0

                if hit == "stop":
                    exit_reason = (
                        f"StopLoss hit ({cfg.stop_loss_pct*100:.1f}%). "
                        f"filled={exec_price:.2f}, SL={stop_px:.2f}, ret={pnl_pct:.2f}%, held={held_days}d"
                    )
                elif hit == "target":
                    exit_reason = (
                        f"TakeProfit hit ({cfg.target_pct*100:.1f}%). "
                        f"filled={exec_price:.2f}, TP={tgt_px:.2f}, ret={pnl_pct:.2f}%, held={held_days}d"
                    )
                else:  # trend_reverse
                    # --- NEW: Updated trend reverse exit reason
                    exit_reason = (
                        f"Trend reverse: Close below EMA50 "
                        f"(Close={row['Close']:.2f}, EMA50={row['ema50']:.2f}); "
                        f"filled={exec_price:.2f}, ret={pnl_pct:.2f}%, held={held_days}d"
                    )
                
                # --- NEW: Updated trade dict
                trades.append({
                    "ticker": ticker, "side": "SELL", "date": exec_date,
                    "price": float(exec_price), "shares": 0, "reason": exit_reason,
                    "signal_reason": "", "score": np.nan,
                    "rsi": float(row["rsi"]), "ADX": float(row["ADX"]),
                    "+DI": float(row["+DI"]), "-DI": float(row["-DI"]),
                    "ema50": float(row["ema50"]), # <-- NEW
                    "PP": np.nan, "S1": np.nan, "S2": np.nan, # <-- NEW (nan for exits)
                    "sma50": float(row["sma50"]), "sma200": float(row["sma200"]),
                    "macd_line": float(row["macd_line"]), "macd_signal": float(row["macd_signal"]), "macd_hist": float(row["macd_hist"]),
                    "bb_mid": float(row["bb_mid"]), "bb_up": float(row["bb_up"]), "bb_low": float(row["bb_low"]),
                    "close": float(row["Close"]), "high_52w": float(row["high_52w"])
                })
                in_pos = False
                entry_px = stop_px = tgt_px = 0.0
                entry_dt = None

    # Force close open pos at last bar
    if in_pos:
        last_dt = d.index[-1]; row = d.loc[last_dt]
        exec_price = float(row["Close"])
        pnl_pct = float((exec_price / entry_px - 1.0) * 100.0) if entry_px else float("nan")
        held_days = int((pd.to_datetime(last_dt) - pd.to_datetime(entry_dt)).days) if entry_dt else 0
        exit_reason = (
            f"Final close (backtest end). filled={exec_price:.2f}, ret={pnl_pct:.2f}%, held={held_days}d"
        )
        # --- NEW: Updated trade dict
        trades.append({
            "ticker": ticker, "side": "SELL", "date": last_dt,
            "price": exec_price, "shares": 0, "reason": exit_reason,
            "signal_reason": "", "score": np.nan,
            "rsi": float(row["rsi"]), "ADX": float(row["ADX"]),
            "+DI": float(row["+DI"]), "-DI": float(row["-DI"]),
            "ema50": float(row["ema50"]), # <-- NEW
            "PP": np.nan, "S1": np.nan, "S2": np.nan, # <-- NEW (nan for exits)
            "sma50": float(row["sma50"]), "sma200": float(row["sma200"]),
            "macd_line": float(row["macd_line"]), "macd_signal": float(row["macd_signal"]), "macd_hist": float(row["macd_hist"]),
            "bb_mid": float(row["bb_mid"]), "bb_up": float(row["bb_up"]), "bb_low": float(row["bb_low"]),
            "close": float(row["Close"]), "high_52w": float(row["high_52w"])
        })

    return pd.DataFrame(trades, columns=cols), pd.Series(dtype=float)


# ---------- Portfolio: unchanged engine ----------
def pick_benchmark(benchmarks: Tuple[str,...], start: str, end: Optional[str], cache_dir: str) -> Tuple[str, pd.DataFrame]:
    for t in benchmarks:
        data = fetch_prices([t], start, end, cache_dir)
        df = data.get(t)
        if df is not None and not df.empty:
            log.info("Using benchmark: %s", t)
            return t, df
    idx = pd.date_range(start=start, end=end or today_str(), freq="B")
    df = pd.DataFrame({"Close": np.ones(len(idx))}, index=idx)
    log.warning("No benchmark found; using synthetic flat series.")
    return "SYNTH_BENCH", df

def compute_volar_scores(end_dt: pd.Timestamp, tickers: List[str], data_map: Dict[str,pd.DataFrame], bench_df: pd.DataFrame, lookback: int) -> Dict[str, float]:
    scores = {}
    bser = bench_df["Close"].loc[:end_dt].pct_change().dropna().iloc[-lookback:]
    for t in tickers:
        df = data_map.get(t)
        if df is None or df.empty:
            scores[t] = 0.0
            continue
        if end_dt not in df.index:
            df = df[df.index <= end_dt]
            if df.empty:
                scores[t] = 0.0
                continue
        r = df["Close"].loc[:end_dt].pct_change().dropna().iloc[-lookback:]
        common = pd.concat([r, bser], axis=1, keys=["s","b"]).dropna()
        if common.shape[0] < max(20, int(0.4*lookback)):
            scores[t] = 0.0
            continue
        excess = common["s"] - common["b"]
        vol = common["s"].std(ddof=0)
        scores[t] = 0.0 if vol <= 1e-8 else float((excess.mean() / vol) * math.sqrt(252.0))
    return scores

def markowitz_long_only(mu: np.ndarray, Sigma: np.ndarray) -> np.ndarray:
    n = len(mu)
    eps = 1e-6
    Sigma = Sigma + eps*np.eye(n)

    def solve_lambda(lmbd: float, active_mask=None):
        if active_mask is None:
            A = np.block([[2*lmbd*Sigma, np.ones((n,1))],[np.ones((1,n)), np.zeros((1,1))]])
            b = np.concatenate([mu, np.array([1.0])])
            try:
                sol = np.linalg.solve(A, b)
                w = sol[:n]
            except np.linalg.LinAlgError:
                w = np.full(n, 1.0/n)
            return w
        else:
            idx = np.where(active_mask)[0]
            if len(idx)==0:
                return np.full(n, 1.0/n)
            S = Sigma[np.ix_(idx, idx)]
            o = np.ones(len(idx))
            m = mu[idx]
            A = np.block([[2*lmbd*S, o[:,None]],[o[None,:], np.zeros((1,1))]])
            b = np.concatenate([m, np.array([1.0])])
            try:
                sol = np.linalg.solve(A, b)
                w_sub = sol[:len(idx)]
            except np.linalg.LinAlgError:
                w_sub = np.full(len(idx), 1.0/len(idx))
            w = np.zeros(n)
            w[idx] = w_sub
            return w

    best_w = np.full(n, 1.0/n)
    best_sr = -1e9
    lambdas = np.logspace(-3, 3, 31)
    for lmbd in lambdas:
        active = np.ones(n, dtype=bool)
        w = None
        for _ in range(n):
            w = solve_lambda(lmbd, active_mask=active)
            neg = w < 0
            if not neg.any():
                break
            worst = np.argmin(w)
            active[worst] = False
        if w is None:
            continue
        w = np.clip(w, 0, None)
        if w.sum() <= 0:
            continue
        w = w / w.sum()
        mu_p = float(mu @ w)
        vol_p = float(np.sqrt(w @ Sigma @ w))
        if vol_p <= 1e-8:
            continue
        sr = mu_p / vol_p
        if sr > best_sr:
            best_sr = sr
            best_w = w.copy()
    return best_w

def aggregate_and_apply(all_trades: pd.DataFrame, data_map: Dict[str, pd.DataFrame], bench_df: pd.DataFrame, cfg: Config):
    if all_trades.empty:
        return all_trades, pd.Series(dtype=float), {}

    side_order = {"BUY": 0, "SELL": 1}
    all_trades = (all_trades
        .assign(_sorder=all_trades["side"].map(side_order))
        .sort_values(by=["date", "_sorder"], kind="stable")
        .drop(columns=["_sorder"])
        .reset_index(drop=True)
    )
    all_trades["date"] = pd.to_datetime(all_trades["date"])

    equity_curve = []
    dates = sorted(all_trades["date"].unique().tolist())
    cash = cfg.initial_capital
    open_positions = {}
    completed_legs = []

    global APPLY_FEES
    APPLY_FEES = cfg.apply_fees

    def _get_close_on(tkr, dt):
        df = data_map.get(tkr)
        if df is None or df.empty:
            return np.nan
        if dt in df.index:
            return float(df.loc[dt, "Close"])
        prev = df[df.index <= dt]
        if prev.empty:
            return np.nan
        return float(prev["Close"].iloc[-1])

    if dates:
        seed_date = pd.to_datetime(dates[0]) - pd.Timedelta(days=1)
        equity_curve.append((seed_date, float(cash)))

    # Walk dates
    for dt in dates:
        day_trades = all_trades[all_trades["date"] == dt].copy()

        # SELLs first
        for _, tr in day_trades[day_trades["side"] == "SELL"].iterrows():
            tkr = tr["ticker"]
            price = float(tr["price"])
            pos = open_positions.get(tkr)
            if pos is None:
                continue
            shares = int(pos["shares"])
            turnover_sell = shares * price
            fee = calc_fees(0.0, turnover_sell)
            pnl = (price - pos["entry_px"]) * shares
            cash += (turnover_sell - fee)
            realized = pnl - fee - pos.get("buy_fee", 0.0)
            
            # --- NEW: Updated completed_legs dict
            completed_legs.append({
                "ticker": tkr, "side": "SELL", "date": dt, "price": price,
                "shares": shares, "reason": tr.get("reason",""),
                "turnover": turnover_sell, "fees_inr": fee, "pnl_inr": realized,
                "rsi": tr.get("rsi", np.nan), "ADX": tr.get("ADX", np.nan),
                "+DI": tr.get("+DI", np.nan), "-DI": tr.get("-DI", np.nan),
                "ema50": tr.get("ema50", np.nan), # <-- NEW
                "sma50": tr.get("sma50", np.nan), "sma200": tr.get("sma200", np.nan),
                "macd_line": tr.get("macd_line", np.nan), "macd_signal": tr.get("macd_signal", np.nan), "macd_hist": tr.get("macd_hist", np.nan),
                "bb_mid": tr.get("bb_mid", np.nan), "bb_up": tr.get("bb_up", np.nan), "bb_low": tr.get("bb_low", np.nan),
                "close": tr.get("close", np.nan), "high_52w": tr.get("high_52w", np.nan),
                "volar": tr.get("volar", np.nan), "mvo_weight": np.nan, "alloc_inr": np.nan
            })
            log.info("Exit %-12s px=%8.2f sh=%6d reason=%s net=%.2f cash=%.2f",
                     tkr, price, shares, tr.get("reason",""), realized, cash)
            del open_positions[tkr]

        # BUY candidates
        buys_today = day_trades[day_trades["side"] == "BUY"].copy()

        # 52w proximity filter
        if not buys_today.empty:
            keep = []
            for _, rr in buys_today.iterrows():
                df = data_map.get(rr["ticker"])
                if df is None or df.empty or dt not in df.index:
                    continue
                # Use signal candle close (from trade row) for 52w check
                close = float(rr.get("close", df.loc[dt, "Close"])) 
                high_52w = float(rr.get("high_52w", 0.0))
                if high_52w > 0 and close >= cfg.within_pct_of_52w_high * high_52w:
                    keep.append(rr)
            buys_today = pd.DataFrame(keep) if keep else pd.DataFrame(columns=buys_today.columns)

        # Exclude already-held tickers
        if not buys_today.empty:
            buys_today = buys_today[~buys_today["ticker"].isin(open_positions.keys())]

        # Rank by VOLAᵣ
        if not buys_today.empty:
            tickers = buys_today["ticker"].tolist()
            volar_scores = compute_volar_scores(dt, tickers, data_map, bench_df, cfg.volar_lookback)
            buys_today["volar"] = buys_today["ticker"].map(volar_scores)
            buys_today = buys_today.sort_values("volar", ascending=False).reset_index(drop=True)

        slots = cfg.max_concurrent_positions - len(open_positions)
        selected = pd.DataFrame(columns=buys_today.columns)
        if slots > 0 and not buys_today.empty:
            selected = buys_today.head(min(cfg.top_k_daily, slots)).copy()

        if not selected.empty:
            log.info("Selected %d BUY candidates on %s:", selected.shape[0], dt.date())
            for i, rr in selected.reset_index(drop=True).iterrows():
                log.info("  %-12s volar=%6.2f rank=%d px=%8.2f", rr["ticker"], rr.get("volar",0.0), i+1, rr["price"])

            names = selected["ticker"].tolist()
            rets = []
            for t in names:
                df = data_map.get(t)
                ser = df["Close"].loc[:dt].pct_change().dropna().iloc[-cfg.volar_lookback:]
                rets.append(ser)
            R = pd.concat(rets, axis=1)
            R.columns = names
            R = R.dropna()
            if R.empty or R.shape[0] < max(20, int(0.4*cfg.volar_lookback)) or R.shape[1] == 0:
                weights = np.full(len(names), 1.0/len(names))
            else:
                mu = R.mean().values
                Sigma = R.cov().values
                weights = markowitz_long_only(mu, Sigma)

            deploy_cash = max(0.0, float(cash)) * float(cfg.deploy_cash_frac)

            if deploy_cash <= 0:
                log.info("No deployable cash (cap=%.0f%%) on %s", 100*cfg.deploy_cash_frac, dt.date())
            else:
                alloc = (weights / weights.sum()) * deploy_cash if weights.sum()>0 else np.full(len(names), deploy_cash/len(names))
                rank_map = {row["ticker"]: (idx+1) for idx, (_, row) in enumerate(selected.iterrows())}
                for w_amt, t in zip(alloc, names):
                    row_sel = selected[selected["ticker"]==t].iloc[0]
                    # Use the actual execution price from the 'BUY' candidate row
                    price = float(row_sel["price"])
                    shares = int(math.floor(w_amt / price))
                    if shares <= 0:
                        log.info("Skip BUY %-12s (alloc %.2f too small)", t, w_amt)
                        continue
                    turn = shares * price
                    fee = calc_fees(turn, 0.0)
                    total_cost = turn + fee
                    if total_cost > cash:
                        shares = int(math.floor((cash - fee) / price))
                        if shares <= 0:
                            log.info("Skip BUY %-12s due to cash/fees", t)
                            continue
                        turn = shares * price
                        total_cost = turn + fee
                    cash -= total_cost
                    # Use actual execution price for position tracking
                    open_positions[t] = {"entry_date": dt, "entry_px": price, "shares": shares, "buy_fee": fee, "entry_reason": "entry"} 

                    volar_val = float(row_sel.get("volar", np.nan))
                    rank_pos = rank_map.get(t, np.nan)
                    high_52w = float(row_sel.get("high_52w", np.nan))
                    close_val = float(row_sel.get("close", np.nan))
                    pct_52w = (close_val / high_52w) if (high_52w and high_52w>0) else np.nan
                    mvo_weight_today = (w_amt / deploy_cash) if deploy_cash > 0 else 0.0
                    sig_reason = row_sel.get("signal_reason", "Close>EMA50 & PivotReclaim (≥1 confirm)")
                    reason_text = (
                        f"{sig_reason}; 52w%={pct_52w:.1%} (>= {CFG.within_pct_of_52w_high:.0%}); "
                        f"VOLAR rank {int(rank_pos)}/{len(names)} (VOLAR={volar_val:.2f}); "
                        f"MVO weight={mvo_weight_today:.1%} of capped cash ({100*cfg.deploy_cash_frac:.0f}% of available)"
                    )
                    
                    # --- NEW: Updated completed_legs dict
                    completed_legs.append({
                        "ticker": t, "side": "BUY", "date": dt, "price": price,
                        "shares": shares, "reason": reason_text,
                        "turnover": turn, "fees_inr": fee, "pnl_inr": 0.0,
                        "rsi": float(row_sel.get("rsi", np.nan)), "ADX": float(row_sel.get("ADX", np.nan)),
                        "+DI": float(row_sel.get("+DI", np.nan)), "-DI": float(row_sel.get("-DI", np.nan)),
                        "ema50": float(row_sel.get("ema50", np.nan)), # <-- NEW
                        "PP": float(row_sel.get("PP", np.nan)), "S1": float(row_sel.get("S1", np.nan)), "S2": float(row_sel.get("S2", np.nan)), # <-- NEW
                        "sma50": float(row_sel.get("sma50", np.nan)), "sma200": float(row_sel.get("sma200", np.nan)),
                        "macd_line": float(row_sel.get("macd_line", np.nan)), "macd_signal": float(row_sel.get("macd_signal", np.nan)), "macd_hist": float(row_sel.get("macd_hist", np.nan)),
                        "bb_mid": float(row_sel.get("bb_mid", np.nan)), "bb_up": float(row_sel.get("bb_up", np.nan)), "bb_low": float(row_sel.get("bb_low", np.nan)),
                        "close": close_val, "high_52w": high_52w,
                        "volar": volar_val, "mvo_weight": float(mvo_weight_today), "alloc_inr": float(w_amt)
                    })
                    log.info("BUY %-12s px=%8.2f sh=%6d fee=%.2f cash=%.2f :: %s",
                             t, price, shares, fee, cash, reason_text)

        # MTM valuation
        mtm = 0.0
        for _tkr, pos in open_positions.items():
            px = _get_close_on(_tkr, dt)
            if not np.isnan(px):
                mtm += pos["shares"] * px
        total_equity = cash + mtm
        equity_curve.append((dt, float(total_equity)))

    eq_ser = pd.Series([e for _, e in equity_curve], index=[d for d, _ in equity_curve])
    legs_df = pd.DataFrame(completed_legs).sort_values(["date", "ticker", "side"]).reset_index(drop=True)

    # Roundtrips
    roundtrips = []
    by_tkr_open = {}
    for _, leg in legs_df.iterrows():
        tkr = leg["ticker"]
        if leg["side"] == "BUY":
            by_tkr_open[tkr] = leg
        else:
            buy = by_tkr_open.pop(tkr, None)
            if buy is None:
                continue
            fees_total = float(buy.get("fees_inr", 0.0) + leg.get("fees_inr", 0.0))
            gross_pnl = (leg["price"] - buy["price"]) * buy["shares"]
            net_pnl   = gross_pnl - fees_total
            ret_pct   = (leg["price"] / buy["price"] - 1.0) * 100.0
            days_held = (pd.to_datetime(leg["date"]) - pd.to_datetime(buy["date"])).days
            
            # --- NEW: Updated roundtrips dict
            roundtrips.append({
                "ticker": tkr,
                "entry_date": pd.to_datetime(buy["date"]),
                "entry_price": float(buy["price"]),
                "exit_date": pd.to_datetime(leg["date"]),
                "exit_price": float(leg["price"]),
                "days_held": int(days_held),
                "shares": int(buy["shares"]),
                "entry_reason": buy.get("reason",""),
                "exit_reason": leg.get("reason",""),
                "gross_pnl_inr": float(gross_pnl),
                "fees_total_inr": float(fees_total),
                "net_pnl_inr": float(net_pnl),
                "return_pct": float(ret_pct),
                "rsi_entry": float(buy.get("rsi", np.nan)),
                "adx_entry": float(buy.get("ADX", np.nan)),
                "pdi_entry": float(buy.get("+DI", np.nan)),
                "mdi_entry": float(buy.get("-DI", np.nan)),
                "ema50_entry": float(buy.get("ema50", np.nan)), # <-- NEW
                "pp_entry": float(buy.get("PP", np.nan)), # <-- NEW
                "s1_entry": float(buy.get("S1", np.nan)), # <-- NEW
                "s2_entry": float(buy.get("S2", np.nan)), # <-- NEW
                "sma50_entry": float(buy.get("sma50", np.nan)),
                "sma200_entry": float(buy.get("sma200", np.nan)),
                "macd_line_entry": float(buy.get("macd_line", np.nan)),
                "macd_signal_entry": float(buy.get("macd_signal", np.nan)),
                "macd_hist_entry": float(buy.get("macd_hist", np.nan)),
                "bb_mid_entry": float(buy.get("bb_mid", np.nan)),
                "bb_up_entry": float(buy.get("bb_up", np.nan)),
                "bb_low_entry": float(buy.get("bb_low", np.nan)),
                "close_entry": float(buy.get("close", np.nan)),
                "high_52w_entry": float(buy.get("high_52w", np.nan)),
                "volar_entry": float(buy.get("volar", np.nan)),
                "mvo_weight_entry": float(buy.get("mvo_weight", np.nan)),
                "alloc_inr_entry": float(buy.get("alloc_inr", np.nan))
            })
    trips_df = pd.DataFrame(roundtrips).sort_values(["entry_date","ticker"]).reset_index(drop=True)

    metrics = compute_metrics(eq_ser, legs_df)
    return legs_df, trips_df, eq_ser, metrics

def compute_metrics(equity: pd.Series, legs_df: pd.DataFrame):
    out = {}
    if equity is None or equity.empty:
        return out
    eq = equity.dropna()
    daily_ret = eq.pct_change().fillna(0.0)

    days = (eq.index[-1] - eq.index[0]).days or 1
    years = days / 365.25
    cagr = (eq.iloc[-1] / eq.iloc[0]) ** (1/years) - 1 if years > 0 else 0.0

    if daily_ret.std(ddof=0) > 0:
        sharpe = (daily_ret.mean() / daily_ret.std(ddof=0)) * np.sqrt(252)
    else:
        sharpe = 0.0

    cummax = eq.cummax()
    dd = (eq - cummax) / cummax
    max_dd = dd.min()

    wins = 0
    n_sells = legs_df[legs_df["side"] == "SELL"].shape[0] if legs_df is not None and not legs_df.empty else 0
    for _, r in legs_df[legs_df["side"] == "SELL"].iterrows():
        if float(r.get("pnl_inr", 0.0)) > 0:
            wins += 1
    win_rate = (wins / n_sells) * 100.0 if n_sells > 0 else 0.0

    out.update({
        "start_equity_inr": float(eq.iloc[0]),
        "final_equity_inr": float(eq.iloc[-1]),
        "cagr_pct": float(cagr * 100),
        "sharpe": float(sharpe),
        "max_drawdown_pct": float(max_dd * 100),
        "win_rate_pct": float(win_rate),
        "n_trades": int(n_sells),
    })
    return out

def plot_equity(equity: pd.Series, out_path: str):
    if equity is None or equity.empty:
        return
    try:
        import matplotlib.pyplot as plt
        plt.figure(figsize=(10,5))
        plt.plot(equity.index, equity.values)
        plt.title("Equity Curve")
        plt.xlabel("Date")
        plt.ylabel("Equity (INR)")
        plt.tight_layout()
        plt.savefig(out_path)
        plt.close()
    except Exception:
        pass

def backtest(cfg: Config):
    ensure_dirs(cfg.cache_dir, cfg.out_dir)
    log.info("Universe: loading static symbols...")
    symbols = load_static_symbols(cfg.static_symbols, cfg.static_symbols_path)
    log.info("Loaded %d symbols.", len(symbols))

    log.info("Data: fetching OHLCV from yfinance (adjusted)...")
    data_map = fetch_prices(symbols, cfg.start_date, cfg.end_date, cfg.cache_dir)
    log.info("Downloaded %d symbols with data.", len(data_map))

    bench_tkr, bench_df = pick_benchmark(cfg.benchmark_try, cfg.start_date, cfg.end_date, cfg.cache_dir)
    log.info("Benchmark selected: %s", bench_tkr)

    # --- NEW: Updated log message
    log.info("Signals: generating new EMA50-Trend + PivotReclaim + ≥1 confirm entries...")
    all_trades = []
    for i, tkr in enumerate(symbols, 1):
        df = data_map.get(tkr)
        if df is None or df.empty:
            continue
        tr, _ = simulate_ticker(tkr, df, cfg)
        if not tr.empty:
            all_trades.append(tr)
        if i % 50 == 0:
            log.info("  processed %d/%d tickers...", i, len(symbols))

    if not all_trades:
        log.warning("No signals generated; check thresholds or universe.")
        return None, None, None, {}
    all_trades = pd.concat(all_trades, ignore_index=True)

    log.info("Portfolio: cap daily deploy to %.0f%% of cash; 52w>=%.0f%% high; top-%d by VOLAᵣ; MVO; max %d positions.",
             cfg.deploy_cash_frac*100, cfg.within_pct_of_52w_high*100, cfg.top_k_daily, cfg.max_concurrent_positions)
    legs_df, trips_df, equity, metrics = aggregate_and_apply(all_trades, data_map, bench_df, cfg)

    stamp = pd.Timestamp.today(tz="Asia/Kolkata").strftime("%Y%m%d_%H%M%S")
    legs_path = os.path.join(cfg.out_dir, f"trades_legs_{stamp}.csv")
    trips_path = os.path.join(cfg.out_dir, f"trades_roundtrips_{stamp}.csv")
    equity_path = os.path.join(cfg.out_dir, f"equity_{stamp}.csv")
    metrics_path = os.path.join(cfg.out_dir, f"metrics_{stamp}.json")
    eq_plot_path = os.path.join(cfg.out_dir, f"equity_{stamp}.png")

    if legs_df is not None:
        legs_df.to_csv(legs_path, index=False)
    if trips_df is not None:
        trips_df.to_csv(trips_path, index=False)
    if equity is not None:
        pd.DataFrame({"date": equity.index, "equity": equity.values}).to_csv(equity_path, index=False)
    with open(metrics_path, "w") as f:
        json.dump(metrics, f, indent=2)

    if cfg.plot and equity is not None:
        plot_equity(equity, eq_plot_path)

    log.info("=== METRICS ===\n%s", json.dumps(metrics, indent=2))
    log.info("Files written:\n  %s\n  %s\n  %s\n  %s", legs_path, trips_path, equity_path, metrics_path)
    if cfg.plot:
        log.info("  %s", eq_plot_path)

def main():
    global APPLY_FEES
    APPLY_FEES = bool(CFG.apply_fees)
    # Example: set your universe here or via file path.
    # CFG.static_symbols = ['TCS.NS','HDFCBANK.NS','RELIANCE.NS','INFY.NS','ICICIBANK.NS']
    CFG.static_symbols_path = "nifty500.txt" # Make sure you have this file
    backtest(CFG)

if __name__ == "__main__":
    main()
# Out:
# 2025-10-24 20:53:51 | INFO | Universe: loading static symbols...
# 2025-10-24 20:53:51 | INFO | Loaded 500 symbols.
# 2025-10-24 20:53:51 | INFO | Data: fetching OHLCV from yfinance (adjusted)...
# 2025-10-24 20:53:55 | ERROR |
# 1 Failed download:
# 2025-10-24 20:53:55 | ERROR | ['ABLBL.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-24 20:54:01 | ERROR |
# 1 Failed download:
# 2025-10-24 20:54:01 | ERROR | ['AEGISVOPAK.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-24 20:54:02 | ERROR |
# 1 Failed download:
# 2025-10-24 20:54:02 | ERROR | ['AGARWALEYE.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 994
#     991     backtest(CFG)
#     993 if __name__ == "__main__":
# --> 994     main()
#
# Cell In[4], line 991, in main()
#     988 # Example: set your universe here or via file path.
#     989 # CFG.static_symbols = ['TCS.NS','HDFCBANK.NS','RELIANCE.NS','INFY.NS','ICICIBANK.NS']
#     990 CFG.static_symbols_path = "nifty500.txt" # Make sure you have this file
# --> 991 backtest(CFG)
#
# Cell In[4], line 933, in backtest(cfg)
#     930 log.info("Loaded %d symbols.", len(symbols))
#     932 log.info("Data: fetching OHLCV from yfinance (adjusted)...")
# --> 933 data_map = fetch_prices(symbols, cfg.start_date, cfg.end_date, cfg.cache_dir)
#     934 log.info("Downloaded %d symbols with data.", len(data_map))
#     936 bench_tkr, bench_df = pick_benchmark(cfg.benchmark_try, cfg.start_date, cfg.end_date, cfg.cache_dir)
#
# Cell In[4], line 226, in fetch_prices(tickers, start, end, cache_dir)
#     224         pass
#     225 try:
# --> 226     df = yf.download(ticker, start=start, end=end, auto_adjust=True, progress=False, multi_level_index=False)
#     227     if df is None or df.empty:
#     228         continue
#
# File ~/Documents/github/.talib/lib/python3.12/site-packages/yfinance/utils.py:92, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      89 logger.debug(f'Entering {func.__name__}()')
#      91 with IndentationContext():
# ---> 92     result = func(*args, **kwargs)
#      94 logger.debug(f'Exiting {func.__name__}()')
#      95 return result
#
# File ~/Documents/github/.talib/lib/python3.12/site-packages/yfinance/multi.py:167, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, interval, prepost, proxy, rounding, timeout, session, multi_level_index)
#     160         _download_one_threaded(ticker, period=period, interval=interval,
#     161                                start=start, end=end, prepost=prepost,
#     162                                actions=actions, auto_adjust=auto_adjust,
#     163                                back_adjust=back_adjust, repair=repair, keepna=keepna,
#     164                                progress=(progress and i > 0),
#     165                                rounding=rounding, timeout=timeout)
#     166     while len(shared._DFS) < len(tickers):
# --> 167         _time.sleep(0.01)
#     168 # download synchronously
#     169 else:
#     170     for i, ticker in enumerate(tickers):
#
# KeyboardInterrupt:
