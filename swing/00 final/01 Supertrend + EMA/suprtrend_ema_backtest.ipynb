# %%
# backtest_multi_stock.py (extended with toggleable indicators)
import pandas as pd
import numpy as np
import yfinance as yf
from custom_indicators import calculate_ema, calculate_supertrend

# -------------------- CONFIG --------------------
TICKER_LIST = [
    'ADANIENT.NS','ADANIPORTS.NS','APOLLOHOSP.NS','ASIANPAINT.NS','AXISBANK.NS',
    'BAJAJ-AUTO.NS','BAJFINANCE.NS','BAJAJFINSV.NS','BEL.NS','BHARTIARTL.NS',
    'CIPLA.NS','COALINDIA.NS','DRREDDY.NS','EICHERMOT.NS','ETERNAL.NS',
    'GRASIM.NS','HCLTECH.NS','HDFCBANK.NS','HDFCLIFE.NS','HEROMOTOCO.NS',
    'HINDALCO.NS','HINDUNILVR.NS','ICICIBANK.NS','ITC.NS','INDUSINDBK.NS',
    'INFY.NS','JSWSTEEL.NS','JIOFIN.NS','KOTAKBANK.NS','LT.NS','M&M.NS',
    'MARUTI.NS','NTPC.NS','NESTLEIND.NS','ONGC.NS','POWERGRID.NS','RELIANCE.NS',
    'SBILIFE.NS','SHRIRAMFIN.NS','SBIN.NS','SUNPHARMA.NS','TCS.NS','TATACONSUM.NS',
    'TATAMOTORS.NS','TATASTEEL.NS','TECHM.NS','TITAN.NS','TRENT.NS','ULTRACEMCO.NS','WIPRO.NS'
]

START_DATE = "2025-01-01"
END_DATE = "2025-08-31"
# Supertrend & EMA (existing)
ST_LENGTH = 10
ST_MULTIPLIER = 3.0
EMA_FAST_LENGTH = 9
EMA_SLOW_LENGTH = 15

# Backtest exit params
DEFAULT_TRAILING_STOP_PCT = 10.0
DEFAULT_HARD_STOP_PCT = 5.0
DEFAULT_MAX_HOLD_DAYS = 10

# Indicator toggles & params (change these to test combos)
INDICATORS = {
    "rsi": {
        "enabled": False,
        "length": 14,
        "buy_below": 40,    # require RSI below this for a buy confirmation (oversold)
        "sell_above": 70    # optional exit if RSI > this (overbought)
    },
    "macd": {
        "enabled": False,
        "fast": 12,
        "slow": 26,
        "signal": 9,
        # buy when macd > signal (bullish cross). 'momentum' param requires MACD - signal > threshold
        "momentum_threshold": 0.0
    },
    "adx": {
        "enabled": False,
        "length": 14,
        "min_adx": 20.0,   # require ADX above this to confirm trend strength
    },
    "sma": {
        "enabled": True,
        "length": 30,      # simple moving average - require price above SMA for buys
    },
    "bb": {
        "enabled": False,
        "length": 20,
        "stddev": 2.0,
        # buy when close crosses above lower band (optional)
    }
}

# How to combine indicator confirmations:
# 'all' => require all enabled indicators to confirm buy
# 'any' => require any one of the enabled indicators to confirm buy (in addition to supertrend+ema)
COMBINATION_MODE = 'any'  # 'all' or 'any'

# -------------------------------------------------


# -------------------- INDICATOR HELPERS --------------------
def calculate_rsi(df, length=14, column='Close'):
    """Compute RSI and place in df['RSI']"""
    delta = df[column].diff()
    gain = delta.clip(lower=0)
    loss = -1 * delta.clip(upper=0)
    avg_gain = gain.ewm(alpha=1/length, adjust=False).mean()
    avg_loss = loss.ewm(alpha=1/length, adjust=False).mean()
    rs = avg_gain / (avg_loss.replace(0, np.nan))
    rsi = 100 - (100 / (1 + rs))
    df['RSI'] = rsi.fillna(50)  # neutral default
    return df

def calculate_macd(df, fast=12, slow=26, signal=9, column='Close'):
    """Compute MACD line and signal line"""
    ema_fast = df[column].ewm(span=fast, adjust=False).mean()
    ema_slow = df[column].ewm(span=slow, adjust=False).mean()
    macd_line = ema_fast - ema_slow
    signal_line = macd_line.ewm(span=signal, adjust=False).mean()
    df['MACD'] = macd_line
    df['MACD_signal'] = signal_line
    df['MACD_hist'] = df['MACD'] - df['MACD_signal']
    return df

def calculate_sma(df, length=50, column='Close'):
    df[f'SMA_{length}'] = df[column].rolling(length).mean()
    return df

def calculate_bbands(df, length=20, stddev=2, column='Close'):
    sma = df[column].rolling(length).mean()
    std = df[column].rolling(length).std()
    df['BB_middle'] = sma
    df['BB_upper'] = sma + (stddev * std)
    df['BB_lower'] = sma - (stddev * std)
    return df

def calculate_adx(df, n=14):
    """
    Calculate +DI, -DI and ADX (classic Wilder's method).
    Places in df['ADX'], df['+DI'], df['-DI'].
    """
    high = df['High']
    low = df['Low']
    close = df['Close']

    # True Range
    tr1 = high - low
    tr2 = (high - close.shift(1)).abs()
    tr3 = (low - close.shift(1)).abs()
    tr = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)

    # Directional Movement
    up_move = high.diff()
    down_move = -low.diff()
    plus_dm = np.where((up_move > down_move) & (up_move > 0), up_move, 0.0)
    minus_dm = np.where((down_move > up_move) & (down_move > 0), down_move, 0.0)

    # Smooth TR, +DM, -DM (Wilder's smoothing)
    tr_smooth = pd.Series(tr).rolling(window=n).sum()
    plus_dm_smooth = pd.Series(plus_dm).rolling(window=n).sum()
    minus_dm_smooth = pd.Series(minus_dm).rolling(window=n).sum()

    # Avoid divide by zero
    plus_di = 100 * (plus_dm_smooth / tr_smooth).replace([np.inf, -np.inf], 0).fillna(0)
    minus_di = 100 * (minus_dm_smooth / tr_smooth).replace([np.inf, -np.inf], 0).fillna(0)

    dx = (abs(plus_di - minus_di) / (plus_di + minus_di)).replace([np.inf, -np.inf], 0) * 100
    adx = dx.rolling(window=n).mean()

    df['+DI'] = plus_di
    df['-DI'] = minus_di
    df['ADX'] = adx
    return df
# ------------------------------------------------------------


# -------------------- DATA & PREP --------------------
def get_stock_data(ticker, start, end, indicators=INDICATORS):
    df = yf.download(ticker, start=start, interval="1d", end=end, auto_adjust=True, progress=False, threads=True, multi_level_index=False)
    if df.empty:
        print(f"No data found for {ticker}. Skipping.")
        return None

    # Existing EMAs & Supertrend (using your custom functions)
    df['EMA_fast'] = calculate_ema(df, EMA_FAST_LENGTH)
    df['EMA_slow'] = calculate_ema(df, EMA_SLOW_LENGTH)
    df = calculate_supertrend(df, ST_LENGTH, ST_MULTIPLIER)

    # Additional indicators based on toggles
    if indicators.get('rsi', {}).get('enabled', False):
        df = calculate_rsi(df, length=indicators['rsi'].get('length', 14))

    if indicators.get('macd', {}).get('enabled', False):
        df = calculate_macd(df,
                            fast=indicators['macd'].get('fast', 12),
                            slow=indicators['macd'].get('slow', 26),
                            signal=indicators['macd'].get('signal', 9))

    if indicators.get('adx', {}).get('enabled', False):
        df = calculate_adx(df, n=indicators['adx'].get('length', 14))

    if indicators.get('sma', {}).get('enabled', False):
        df = calculate_sma(df, length=indicators['sma'].get('length', 50))

    if indicators.get('bb', {}).get('enabled', False):
        df = calculate_bbands(df, length=indicators['bb'].get('length', 20), stddev=indicators['bb'].get('stddev', 2.0))

    df.dropna(inplace=True)
    return df
# --------------------------------------------------


# -------------------- SIGNAL COMBINATION --------------------
def indicator_buy_checks(row, prev_row, indicators=INDICATORS):
    """
    Evaluate each enabled indicator's buy confirmation.
    Returns dict {indicator_name: True/False} (True means indicator confirms buy).
    """
    results = {}

    # RSI: buy if RSI <= buy_below (oversold)
    if indicators.get('rsi', {}).get('enabled', False):
        r = row.get('RSI', np.nan)
        results['rsi'] = (r <= indicators['rsi'].get('buy_below', 40))

    # MACD: buy when MACD > signal and optionally histogram > threshold
    if indicators.get('macd', {}).get('enabled', False):
        macd = row.get('MACD', 0)
        sig = row.get('MACD_signal', 0)
        hist = row.get('MACD_hist', 0)
        thr = indicators['macd'].get('momentum_threshold', 0.0)
        results['macd'] = (macd > sig) and (hist > thr)

    # ADX: buy if ADX >= min_adx AND +DI > -DI (trend strength + direction)
    if indicators.get('adx', {}).get('enabled', False):
        adx = row.get('ADX', 0)
        plus = row.get('+DI', 0)
        minus = row.get('-DI', 0)
        min_adx = indicators['adx'].get('min_adx', 20.0)
        results['adx'] = (adx >= min_adx) and (plus > minus)

    # SMA: buy if price above SMA
    if indicators.get('sma', {}).get('enabled', False):
        sma_col = f"SMA_{indicators['sma'].get('length', 50)}"
        results['sma'] = (row['Close'] > row.get(sma_col, np.nan))

    # BB: buy if close crosses above lower band (simple)
    if indicators.get('bb', {}).get('enabled', False):
        results['bb'] = (prev_row is not None) and (prev_row['Close'] < prev_row.get('BB_lower', np.nan)) and (row['Close'] > row.get('BB_lower', np.nan))

    return results

def combine_indicator_signals(ind_results, mode='all'):
    enabled = [k for k in ind_results.keys()]
    if not enabled:
        return True  # nothing to check
    truths = [v for v in ind_results.values()]
    if mode == 'all':
        return all(truths)
    else:
        return any(truths)
# --------------------------------------------------


# -------------------- BACKTEST --------------------
def run_backtest(df, ticker,
                 trailing_stop_loss_pct=DEFAULT_TRAILING_STOP_PCT,
                 hard_stop_loss_pct=DEFAULT_HARD_STOP_PCT,
                 max_holding_days=DEFAULT_MAX_HOLD_DAYS,
                 indicators=INDICATORS,
                 combination_mode=COMBINATION_MODE):
    in_position = False
    trades = []
    entry_price = 0
    entry_date = None

    peak_price = 0
    trailing_stop_price = 0
    hard_stop_price = 0
    days_in_trade = 0

    tsl_multiplier = 1 - (trailing_stop_loss_pct / 100)
    hsl_multiplier = 1 - (hard_stop_loss_pct / 100)

    print(f"--- Running backtest for {ticker} (TSL: {trailing_stop_loss_pct}%, HSL: {hard_stop_loss_pct}%, Max Days: {max_holding_days}) ---")

    # iterate rows by index, keep prev row for cross checks (BB / previous values)
    for i in range(1, len(df)):
        prev_row = df.iloc[i-1]
        current_row = df.iloc[i]

        # base supertrend + ema condition (your existing)
        is_bullish_state = current_row['supertrend_direction'] == 1 and current_row['EMA_fast'] > current_row['EMA_slow']
        was_bullish_state = prev_row['supertrend_direction'] == 1 and prev_row['EMA_fast'] > prev_row['EMA_slow']
        buy_signal_base = is_bullish_state and not was_bullish_state
        stop_loss_signal = prev_row['supertrend_direction'] == 1 and current_row['supertrend_direction'] == -1

        # Evaluate indicator confirmations
        ind_results = indicator_buy_checks(current_row, prev_row, indicators=indicators)
        ind_combined = combine_indicator_signals(ind_results, mode=combination_mode)

        # Final buy signal: base signal AND indicator combination (if any indicator enabled)
        enabled_any = any(v.get('enabled', False) for v in indicators.values())
        buy_signal = buy_signal_base and (ind_combined if enabled_any else True)

        if not in_position and buy_signal:
            entry_price = current_row['Close']
            in_position = True
            entry_date = current_row.name

            peak_price = entry_price
            trailing_stop_price = peak_price * tsl_multiplier
            hard_stop_price = entry_price * hsl_multiplier
            days_in_trade = 0
            # log
            print(f"  Enter: {entry_date.strftime('%Y-%m-%d %H:%M')} @ {entry_price:.2f} | indicators: {ind_results}")

        elif in_position:
            days_in_trade += 1

            # Update peak price and trailing stop (on intrabar high)
            if current_row['High'] > peak_price:
                peak_price = current_row['High']
                trailing_stop_price = peak_price * tsl_multiplier

            exit_price = 0
            exit_reason = None

            # 1. Hard stop
            if current_row['Low'] <= hard_stop_price:
                exit_price = hard_stop_price
                exit_reason = "HSL"
            # 2. Trailing stop
            elif current_row['Low'] <= trailing_stop_price:
                exit_price = trailing_stop_price
                exit_reason = "TSL"
            # 3. Time-based stop
            elif days_in_trade >= max_holding_days:
                exit_price = current_row['Close']
                exit_reason = "Time"
            # 4. Supertrend cross (your existing)
            elif stop_loss_signal:
                exit_price = current_row['Close']
                exit_reason = "SL"
            # 5. Indicator-based exit examples:
            else:
                # RSI overbought exit
                if indicators.get('rsi', {}).get('enabled', False):
                    r = current_row.get('RSI', np.nan)
                    if r >= indicators['rsi'].get('sell_above', 70):
                        exit_price = current_row['Close']
                        exit_reason = "RSI_exit"

                # ADX weakening (optional): ADX falls below threshold -> exit
                if exit_price == 0 and indicators.get('adx', {}).get('enabled', False):
                    adx = current_row.get('ADX', np.nan)
                    min_adx = indicators['adx'].get('min_adx', 20.0)
                    if adx < min_adx:
                        exit_price = current_row['Close']
                        exit_reason = "ADX_weak"

                # MACD bearish cross
                if exit_price == 0 and indicators.get('macd', {}).get('enabled', False):
                    # if MACD crosses below signal on this bar (prev macd > prev signal and now macd < signal)
                    prev_macd = prev_row.get('MACD', 0)
                    prev_sig = prev_row.get('MACD_signal', 0)
                    cur_macd = current_row.get('MACD', 0)
                    cur_sig = current_row.get('MACD_signal', 0)
                    if (prev_macd > prev_sig) and (cur_macd < cur_sig):
                        exit_price = current_row['Close']
                        exit_reason = "MACD_cross_down"

            if exit_price > 0:
                in_position = False
                exit_date = current_row.name
                percent_return = ((exit_price - entry_price) / entry_price) * 100

                trades.append({
                    "ticker": ticker,
                    "entry_date": entry_date, "exit_date": exit_date,
                    "entry_price": entry_price, "exit_price": exit_price,
                    "return_%": percent_return, "exit_reason": exit_reason,
                    "days_held": days_in_trade
                })
                print(f"  Trade Closed ({exit_reason}): {exit_date.strftime('%Y-%m-%d %H:%M')} | Return: {percent_return:.2f}% | Days: {days_in_trade}")

    return trades
# --------------------------------------------------


# -------------------- SUMMARY --------------------
def print_summary(all_trades):
    if not all_trades:
        print("\nNo trades were executed during the backtest period.")
        return

    trades_df = pd.DataFrame(all_trades)
    wins = trades_df[trades_df['return_%'] > 0]
    total_trades = len(trades_df)
    win_rate = (len(wins) / total_trades) * 100 if total_trades > 0 else 0

    hsl_exits = len(trades_df[trades_df['exit_reason'] == 'HSL'])
    tsl_exits = len(trades_df[trades_df['exit_reason'] == 'TSL'])
    time_exits = len(trades_df[trades_df['exit_reason'] == 'Time'])
    sl_exits = len(trades_df[trades_df['exit_reason'] == 'SL'])
    other_exits = total_trades - (hsl_exits + tsl_exits + time_exits + sl_exits)

    print(f"\nSummary:")
    print(f"  Total Trades: {total_trades}")
    print(f"  Win Rate: {win_rate:.2f}%")
    print(f"  Avg. Holding Period: {trades_df['days_held'].mean():.1f} bars")
    print("\n  Exit Reasons:")
    print(f"    Hard Stop-Loss (HSL): {hsl_exits}")
    print(f"    Trailing Stop-Loss (TSL): {tsl_exits}")
    print(f"    Time-Based Stop (Time): {time_exits}")
    print(f"    Supertrend Stop (SL): {sl_exits}")
    print(f"    Other Exits (RSI/MACD/ADX...): {other_exits}")
    print("-" * 30)
# --------------------------------------------------


# -------------------- MAIN --------------------
if __name__ == "__main__":
    overall_trades = []
    for stock_ticker in TICKER_LIST:
        stock_df = get_stock_data(stock_ticker, START_DATE, END_DATE, indicators=INDICATORS)
        if stock_df is not None:
            executed_trades = run_backtest(
                stock_df,
                stock_ticker,
                trailing_stop_loss_pct=DEFAULT_TRAILING_STOP_PCT,
                hard_stop_loss_pct=DEFAULT_HARD_STOP_PCT,
                max_holding_days=DEFAULT_MAX_HOLD_DAYS,
                indicators=INDICATORS,
                combination_mode=COMBINATION_MODE
            )
            overall_trades.extend(executed_trades)

    print("\n\n" + "="*50)
    print("Overall Portfolio Backtest Summary")
    print("="*50)
    print_summary(overall_trades)

    if overall_trades:
        results_df = pd.DataFrame(overall_trades)
        results_df.to_csv('backtest_results_advanced.csv', index=False)
        print("\n✅ Backtest results saved to backtest_results_advanced.csv")
    else:
        print("\nNo trades to save to CSV.")
# Out:
# --- Running backtest for ADANIENT.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-19 00:00 @ 2317.46 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-03 00:00 | Return: 3.97% | Days: 10
#   Enter: 2025-04-11 00:00 @ 2320.21 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-29 00:00 | Return: 0.40% | Days: 10
#   Enter: 2025-05-05 00:00 @ 2454.25 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-05-07 00:00 | Return: -5.00% | Days: 2
#   Enter: 2025-05-13 00:00 @ 2439.95 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-27 00:00 | Return: 4.06% | Days: 10
#   Enter: 2025-06-27 00:00 @ 2646.30 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-11 00:00 | Return: -3.31% | Days: 10
# --- Running backtest for ADANIPORTS.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-19 00:00 @ 1167.82 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-03 00:00 | Return: 2.25% | Days: 10
#   Enter: 2025-04-15 00:00 @ 1204.94 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-30 00:00 | Return: 0.47% | Days: 10
#   Enter: 2025-06-30 00:00 @ 1450.20 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-14 00:00 | Return: -1.19% | Days: 10
# --- Running backtest for APOLLOHOSP.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-21 00:00 @ 6603.10 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-07 00:00 | Return: 1.09% | Days: 10
#   Enter: 2025-06-27 00:00 @ 7299.16 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-11 00:00 | Return: -1.63% | Days: 10
#   Enter: 2025-08-13 00:00 @ 7798.52 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-28 00:00 | Return: -0.90% | Days: 10
# --- Running backtest for ASIANPAINT.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-10 00:00 @ 2257.77 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-03-25 00:00 | Return: 2.29% | Days: 10
#   Enter: 2025-06-27 00:00 @ 2358.70 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-11 00:00 | Return: 3.41% | Days: 10
#   Enter: 2025-08-06 00:00 @ 2491.20 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-21 00:00 | Return: 3.03% | Days: 10
# --- Running backtest for AXISBANK.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-02-20 00:00 @ 1016.33 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-03-07 00:00 | Return: 2.01% | Days: 10
#   Enter: 2025-06-09 00:00 @ 1218.86 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-06-23 00:00 | Return: -0.48% | Days: 10
# --- Running backtest for BAJAJ-AUTO.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-04-17 00:00 @ 7819.81 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-05 00:00 | Return: -1.22% | Days: 10
#   Enter: 2025-05-14 00:00 @ 7902.23 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-28 00:00 | Return: 9.21% | Days: 10
#   Enter: 2025-06-26 00:00 @ 8433.00 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-10 00:00 | Return: -1.76% | Days: 10
#   Enter: 2025-08-18 00:00 @ 8588.50 | indicators: {'sma': np.True_}
# --- Running backtest for BAJFINANCE.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-06-09 00:00 @ 960.75 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-06-19 00:00 | Return: -5.00% | Days: 8
#   Enter: 2025-06-26 00:00 @ 951.50 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-10 00:00 | Return: -0.40% | Days: 10
#   Enter: 2025-07-18 00:00 @ 942.00 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-07-28 00:00 | Return: -5.00% | Days: 6
# --- Running backtest for BAJAJFINSV.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-18 00:00 @ 1870.69 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-02 00:00 | Return: 3.17% | Days: 10
#   Enter: 2025-04-17 00:00 @ 2034.31 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-04-30 00:00 | Return: -5.00% | Days: 8
# --- Running backtest for BEL.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-07 00:00 @ 274.83 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-03-24 00:00 | Return: 9.67% | Days: 10
#   Enter: 2025-04-21 00:00 @ 299.26 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-06 00:00 | Return: 3.52% | Days: 10
# --- Running backtest for BHARTIARTL.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-20 00:00 @ 1691.11 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-04 00:00 | Return: 2.24% | Days: 10
#   Enter: 2025-05-27 00:00 @ 1828.51 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-06-10 00:00 | Return: 0.72% | Days: 10
# --- Running backtest for CIPLA.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-17 00:00 @ 1479.78 | indicators: {'sma': np.True_}
#   Trade Closed (SL): 2025-03-28 00:00 | Return: -3.38% | Days: 9
#   Enter: 2025-04-17 00:00 @ 1502.19 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-05 00:00 | Return: 1.83% | Days: 10
#   Enter: 2025-05-12 00:00 @ 1498.62 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-26 00:00 | Return: -1.81% | Days: 10
#   Enter: 2025-06-09 00:00 @ 1493.66 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-06-23 00:00 | Return: -0.50% | Days: 10
#   Enter: 2025-07-25 00:00 @ 1532.50 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-08 00:00 | Return: -3.05% | Days: 10
#   Enter: 2025-08-13 00:00 @ 1561.00 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-28 00:00 | Return: 1.24% | Days: 10
# --- Running backtest for COALINDIA.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-06 00:00 @ 372.01 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-03-21 00:00 | Return: 5.96% | Days: 10
#   Enter: 2025-05-14 00:00 @ 391.94 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-28 00:00 | Return: -1.22% | Days: 10
#   Enter: 2025-06-09 00:00 @ 389.90 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-06-23 00:00 | Return: -2.12% | Days: 10
#   Enter: 2025-08-18 00:00 @ 382.61 | indicators: {'sma': np.True_}
# --- Running backtest for DRREDDY.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-20 00:00 @ 1179.72 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-04-04 00:00 | Return: -5.00% | Days: 10
#   Enter: 2025-04-23 00:00 @ 1178.53 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-08 00:00 | Return: -3.20% | Days: 10
#   Enter: 2025-05-12 00:00 @ 1188.07 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-26 00:00 | Return: 3.79% | Days: 10
#   Enter: 2025-08-21 00:00 @ 1276.60 | indicators: {'sma': np.True_}
# --- Running backtest for EICHERMOT.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-20 00:00 @ 5162.41 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-04 00:00 | Return: 0.35% | Days: 10
#   Enter: 2025-04-15 00:00 @ 5458.23 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-30 00:00 | Return: 0.69% | Days: 10
#   Enter: 2025-06-24 00:00 @ 5556.95 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-08 00:00 | Return: 0.90% | Days: 10
#   Enter: 2025-08-04 00:00 @ 5621.00 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-19 00:00 | Return: 5.65% | Days: 10
# --- Running backtest for ETERNAL.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-04-17 00:00 @ 231.60 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-05 00:00 | Return: 3.58% | Days: 10
#   Enter: 2025-06-02 00:00 @ 241.20 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-06-16 00:00 | Return: 4.54% | Days: 10
# --- Running backtest for GRASIM.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-24 00:00 @ 2504.09 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-08 00:00 | Return: 3.06% | Days: 10
#   Enter: 2025-06-11 00:00 @ 2712.33 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-06-25 00:00 | Return: 4.03% | Days: 10
#   Enter: 2025-08-05 00:00 @ 2787.06 | indicators: {'sma': np.True_}
#   Trade Closed (SL): 2025-08-08 00:00 | Return: -3.78% | Days: 3
#   Enter: 2025-08-20 00:00 @ 2864.90 | indicators: {'sma': np.True_}
# --- Running backtest for HCLTECH.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-04-24 00:00 @ 1556.41 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-09 00:00 | Return: 0.05% | Days: 10
# --- Running backtest for HDFCBANK.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-02-28 00:00 @ 847.35 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-03-17 00:00 | Return: -1.27% | Days: 10
#   Enter: 2025-06-20 00:00 @ 960.97 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-04 00:00 | Return: 3.50% | Days: 10
# --- Running backtest for HDFCLIFE.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-11 00:00 @ 635.19 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-03-26 00:00 | Return: 4.94% | Days: 10
#   Enter: 2025-06-16 00:00 @ 768.43 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-06-30 00:00 | Return: 5.97% | Days: 10
#   Enter: 2025-08-14 00:00 @ 788.75 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-29 00:00 | Return: -2.12% | Days: 10
# --- Running backtest for HEROMOTOCO.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-28 00:00 @ 3667.49 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-04-07 00:00 | Return: -5.00% | Days: 5
#   Enter: 2025-04-15 00:00 @ 3747.24 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-30 00:00 | Return: 0.62% | Days: 10
#   Enter: 2025-07-15 00:00 @ 4387.65 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-29 00:00 | Return: -1.42% | Days: 10
# --- Running backtest for HINDALCO.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-02-19 00:00 @ 621.74 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-03-06 00:00 | Return: 8.89% | Days: 10
#   Enter: 2025-06-10 00:00 @ 653.56 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-06-24 00:00 | Return: 1.68% | Days: 10
#   Enter: 2025-07-21 00:00 @ 677.73 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-04 00:00 | Return: 0.73% | Days: 10
#   Enter: 2025-08-13 00:00 @ 700.50 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-28 00:00 | Return: 0.13% | Days: 10
# --- Running backtest for HINDUNILVR.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-04-09 00:00 @ 2325.54 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-28 00:00 | Return: -1.34% | Days: 10
#   Enter: 2025-07-07 00:00 @ 2410.40 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-21 00:00 | Return: 2.26% | Days: 10
# --- Running backtest for ICICIBANK.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-13 00:00 @ 1240.48 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-03-28 00:00 | Return: 7.86% | Days: 10
#   Enter: 2025-04-17 00:00 @ 1395.93 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-05 00:00 | Return: 1.61% | Days: 10
#   Enter: 2025-06-27 00:00 @ 1451.00 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-11 00:00 | Return: -2.76% | Days: 10
#   Enter: 2025-07-21 00:00 @ 1454.58 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-04 00:00 | Return: -0.18% | Days: 10
# --- Running backtest for ITC.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-04-11 00:00 @ 413.92 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-29 00:00 | Return: 1.06% | Days: 10
#   Enter: 2025-06-10 00:00 @ 427.00 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-06-24 00:00 | Return: -2.96% | Days: 10
#   Enter: 2025-07-14 00:00 @ 419.40 | indicators: {'sma': np.True_}
#   Trade Closed (SL): 2025-07-24 00:00 | Return: -2.25% | Days: 8
# --- Running backtest for INDUSINDBK.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-04-17 00:00 @ 794.70 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-05 00:00 | Return: 6.55% | Days: 10
#   Enter: 2025-05-27 00:00 @ 820.70 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-06-10 00:00 | Return: 2.97% | Days: 10
# --- Running backtest for INFY.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-05-12 00:00 @ 1604.33 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-05-22 00:00 | Return: -5.00% | Days: 8
#   Enter: 2025-08-25 00:00 @ 1532.10 | indicators: {'sma': np.True_}
# --- Running backtest for JSWSTEEL.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-04-22 00:00 @ 1041.40 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-05-02 00:00 | Return: -5.00% | Days: 7
#   Enter: 2025-05-16 00:00 @ 1019.06 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-30 00:00 | Return: -2.77% | Days: 10
#   Enter: 2025-06-17 00:00 @ 996.97 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-01 00:00 | Return: 3.00% | Days: 10
# --- Running backtest for JIOFIN.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-20 00:00 @ 231.33 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-04 00:00 | Return: -4.04% | Days: 10
#   Enter: 2025-04-15 00:00 @ 238.20 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-30 00:00 | Return: 9.16% | Days: 10
#   Enter: 2025-08-04 00:00 @ 333.38 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-08-07 00:00 | Return: -5.00% | Days: 3
# --- Running backtest for KOTAKBANK.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-12 00:00 @ 1980.27 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-03-27 00:00 | Return: 7.37% | Days: 10
#   Enter: 2025-04-17 00:00 @ 2185.58 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-05-05 00:00 | Return: -5.00% | Days: 10
#   Enter: 2025-06-10 00:00 @ 2148.62 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-06-24 00:00 | Return: 3.37% | Days: 10
# --- Running backtest for LT.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-21 00:00 @ 3384.39 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-04-04 00:00 | Return: -5.00% | Days: 9
#   Enter: 2025-05-09 00:00 @ 3412.08 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-23 00:00 | Return: 4.53% | Days: 10
#   Enter: 2025-07-31 00:00 @ 3636.50 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-14 00:00 | Return: 1.11% | Days: 10
# --- Running backtest for M&M.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-04-22 00:00 @ 2794.65 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-07 00:00 | Return: 10.75% | Days: 10
#   Enter: 2025-06-19 00:00 @ 3070.13 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-03 00:00 | Return: 2.57% | Days: 10
#   Enter: 2025-08-12 00:00 @ 3236.50 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-27 00:00 | Return: 2.91% | Days: 10
# --- Running backtest for MARUTI.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-04-30 00:00 @ 12125.76 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-15 00:00 | Return: 5.67% | Days: 10
#   Enter: 2025-06-19 00:00 @ 12668.88 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-03 00:00 | Return: -0.42% | Days: 10
#   Enter: 2025-07-31 00:00 @ 12473.00 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-14 00:00 | Return: 3.71% | Days: 10
# --- Running backtest for NTPC.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-02-21 00:00 @ 322.98 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-02-28 00:00 | Return: -5.00% | Days: 4
# --- Running backtest for NESTLEIND.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-02-18 00:00 @ 1101.90 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-03-05 00:00 | Return: -5.00% | Days: 10
#   Enter: 2025-03-10 00:00 @ 1114.79 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-03-25 00:00 | Return: 0.29% | Days: 10
#   Enter: 2025-05-12 00:00 @ 1181.92 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-26 00:00 | Return: 2.94% | Days: 10
#   Enter: 2025-06-26 00:00 @ 1205.52 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-10 00:00 | Return: -0.40% | Days: 10
#   Enter: 2025-08-20 00:00 @ 1190.30 | indicators: {'sma': np.True_}
# --- Running backtest for ONGC.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-21 00:00 @ 241.15 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-04-04 00:00 | Return: -5.00% | Days: 9
#   Enter: 2025-04-17 00:00 @ 242.22 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-05 00:00 | Return: -1.76% | Days: 10
#   Enter: 2025-05-14 00:00 @ 244.72 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-28 00:00 | Return: -1.36% | Days: 10
#   Enter: 2025-06-11 00:00 @ 246.03 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-06-25 00:00 | Return: -2.19% | Days: 10
# --- Running backtest for POWERGRID.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-19 00:00 @ 276.01 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-03 00:00 | Return: 7.90% | Days: 10
# --- Running backtest for RELIANCE.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-11 00:00 @ 1242.34 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-03-26 00:00 | Return: 2.06% | Days: 10
#   Enter: 2025-04-21 00:00 @ 1290.35 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-06 00:00 | Return: 9.68% | Days: 10
# --- Running backtest for SBILIFE.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-20 00:00 @ 1498.35 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-04 00:00 | Return: 0.95% | Days: 10
#   Enter: 2025-04-17 00:00 @ 1608.20 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-05 00:00 | Return: 10.05% | Days: 10
#   Enter: 2025-07-28 00:00 @ 1850.50 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-11 00:00 | Return: 0.03% | Days: 10
# --- Running backtest for SHRIRAMFIN.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-04-17 00:00 @ 688.66 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-04-25 00:00 | Return: -5.00% | Days: 5
#   Enter: 2025-06-06 00:00 @ 685.18 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-06-13 00:00 | Return: -5.00% | Days: 5
#   Enter: 2025-07-15 00:00 @ 684.45 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-07-18 00:00 | Return: -5.00% | Days: 3
# --- Running backtest for SBIN.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-19 00:00 @ 730.43 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-03 00:00 | Return: 4.58% | Days: 10
#   Enter: 2025-05-12 00:00 @ 785.87 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-26 00:00 | Return: 1.09% | Days: 10
#   Enter: 2025-06-30 00:00 @ 820.35 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-14 00:00 | Return: -1.40% | Days: 10
#   Enter: 2025-08-14 00:00 @ 826.55 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-29 00:00 | Return: -2.91% | Days: 10
# --- Running backtest for SUNPHARMA.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-17 00:00 @ 1698.71 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-01 00:00 | Return: -0.35% | Days: 10
#   Enter: 2025-04-28 00:00 @ 1835.56 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-05-09 00:00 | Return: -5.00% | Days: 8
# --- Running backtest for TCS.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-04-29 00:00 @ 3430.27 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-14 00:00 | Return: 2.19% | Days: 10
#   Enter: 2025-06-16 00:00 @ 3484.47 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-06-30 00:00 | Return: -0.98% | Days: 10
#   Enter: 2025-08-26 00:00 @ 3157.20 | indicators: {'sma': np.True_}
# --- Running backtest for TATACONSUM.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-28 00:00 @ 994.53 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-16 00:00 | Return: 10.38% | Days: 10
#   Enter: 2025-06-26 00:00 @ 1145.40 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-07-01 00:00 | Return: -5.00% | Days: 3
# --- Running backtest for TATAMOTORS.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-19 00:00 @ 676.43 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-03 00:00 | Return: -4.15% | Days: 10
#   Enter: 2025-04-24 00:00 @ 662.65 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-09 00:00 | Return: 6.01% | Days: 10
#   Enter: 2025-08-19 00:00 @ 700.25 | indicators: {'sma': np.True_}
# --- Running backtest for TATASTEEL.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-06-25 00:00 @ 156.39 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-09 00:00 | Return: 1.67% | Days: 10
# --- Running backtest for TECHM.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-02-18 00:00 @ 1674.41 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-02-24 00:00 | Return: -5.00% | Days: 4
#   Enter: 2025-04-24 00:00 @ 1419.27 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-05-09 00:00 | Return: 3.36% | Days: 10
# --- Running backtest for TITAN.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-04-09 00:00 @ 3164.63 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-28 00:00 | Return: 6.14% | Days: 10
#   Enter: 2025-06-25 00:00 @ 3641.24 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-07-08 00:00 | Return: -5.00% | Days: 9
#   Enter: 2025-08-12 00:00 @ 3486.80 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-27 00:00 | Return: 3.07% | Days: 10
# --- Running backtest for TRENT.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-04-01 00:00 @ 5571.92 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-04-07 00:00 | Return: -5.00% | Days: 4
#   Enter: 2025-05-15 00:00 @ 5572.67 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-05-22 00:00 | Return: -5.00% | Days: 5
#   Enter: 2025-08-11 00:00 @ 5443.50 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-26 00:00 | Return: -2.73% | Days: 10
# --- Running backtest for ULTRACEMCO.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-03-25 00:00 @ 11349.26 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-04-09 00:00 | Return: -0.21% | Days: 10
#   Enter: 2025-05-15 00:00 @ 11819.08 | indicators: {'sma': np.True_}
#   Trade Closed (HSL): 2025-05-28 00:00 | Return: -5.00% | Days: 9
#   Enter: 2025-06-25 00:00 @ 11659.10 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-07-09 00:00 | Return: 7.07% | Days: 10
#   Enter: 2025-08-11 00:00 @ 12405.00 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-08-26 00:00 | Return: 1.65% | Days: 10
# --- Running backtest for WIPRO.NS (TSL: 10.0%, HSL: 5.0%, Max Days: 10) ---
#   Enter: 2025-06-12 00:00 @ 254.60 | indicators: {'sma': np.True_}
#   Trade Closed (Time): 2025-06-26 00:00 | Return: 3.43% | Days: 10
#
#
# ==================================================
# Overall Portfolio Backtest Summary
# ==================================================
#
# Summary:
#   Total Trades: 136
#   Win Rate: 54.41%
#   Avg. Holding Period: 9.3 bars
#
#   Exit Reasons:
#     Hard Stop-Loss (HSL): 24
#     Trailing Stop-Loss (TSL): 0
#     Time-Based Stop (Time): 109
#     Supertrend Stop (SL): 3
#     Other Exits (RSI/MACD/ADX...): 0
# ------------------------------
#
# ✅ Backtest results saved to backtest_results_advanced.csv
