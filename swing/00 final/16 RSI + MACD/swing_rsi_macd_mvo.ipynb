# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import os, json, math, warnings, logging
from dataclasses import dataclass
from typing import Dict, List, Tuple, Optional

import numpy as np
import pandas as pd

try:
    import yfinance as yf
    import matplotlib.pyplot as plt
except Exception:
    pass

warnings.filterwarnings("ignore", category=FutureWarning)

# =========================
# LOGGING
# =========================
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)
log = logging.getLogger("macd_rsi_mr_v1")

# =========================
# CONFIG
# =========================
@dataclass
class Config:
    # Data
    start_date: str = "2015-01-01"
    end_date: str   = "2025-10-01"
    static_symbols: Optional[List[str]] = None
    static_symbols_path: Optional[str] = None
    cache_dir: str = "cache"
    out_dir: str   = "outputs"
    plot: bool     = True

    # ---- Indicators (your spec) ----
    # MACD
    macd_fast: int   = 12
    macd_slow: int   = 26
    macd_signal: int = 9

    # RSI
    rsi_len: int = 14

    # Mean reversion filter: z-score of Close vs SMA(z_len)
    z_len: int = 20
    z_entry: float = 1.0       # require prev z <= -1.0
    z_confirm: float = 0.2     # and now z >= -0.2
    z_exit_trigger: float = 0.5
    z_exit_reversal: float = 0.0

    # Volume expansion
    vol_ma_len: int = 20
    vol_expansion_mult: float = 1.5

    # Exits
    atr_len: int = 14
    trail_atr_mult: float = 2.5
    resistance_lookback: int = 50   # TP at prior N-day highest high

    # Portfolio
    apply_fees: bool    = True
    initial_capital: float = 500_000.0
    max_concurrent_positions: int = 5
    deploy_cash_frac: float = 0.25   # cap daily deployment to 25% of available cash
    top_k_daily: int = 300

    # Optional universe filters
    enable_basic_liquidity: bool = False
    min_price_inr: float = 50.0
    min_avg_vol_20d: float = 50_000.0

    # Execution
    entry_on_next_open: bool = True
    exit_on_next_open: bool = True

    # Candidate ranking & filters
    benchmark_try: Tuple[str,...] = ("^CNX500","^CRSLDX","^NSE500","^NIFTY500","^BSE500","^NSEI")
    volar_lookback: int = 252
    filter_52w_window: int = 252
    within_pct_of_52w_high: float = 0.50

CFG = Config()

# =========================
# FEES (per user spec)
# =========================
APPLY_FEES = True

def calc_fees(turnover_buy: float, turnover_sell: float) -> float:
    if not APPLY_FEES:
        return 0.0
    BROKER_PCT = 0.001
    BROKER_MIN = 5.0
    BROKER_CAP = 20.0
    STT_PCT = 0.001
    STAMP_BUY_PCT = 0.00015
    EXCH_PCT = 0.0000297
    SEBI_PCT = 0.000001
    IPFT_PCT = 0.000001
    GST_PCT = 0.18
    DP_SELL = 20.0 if turnover_sell >= 100 else 0.0

    def _broker(turnover):
        if turnover <= 0:
            return 0.0
        fee = turnover * BROKER_PCT
        fee = max(BROKER_MIN, min(fee, BROKER_CAP))
        return fee

    br_buy  = _broker(turnover_buy)
    br_sell = _broker(turnover_sell)
    stt   = STT_PCT * (turnover_buy + turnover_sell)
    stamp = STAMP_BUY_PCT * turnover_buy
    exch  = EXCH_PCT * (turnover_buy + turnover_sell)
    sebi  = SEBI_PCT * (turnover_buy + turnover_sell)
    ipft  = IPFT_PCT * (turnover_buy + turnover_sell)
    dp    = DP_SELL
    gst_base = br_buy + br_sell + dp + exch + sebi + ipft
    gst   = GST_PCT * gst_base
    return float((br_buy + br_sell) + stt + stamp + exch + sebi + ipft + dp + gst)

# =========================
# Helpers
# =========================
def ensure_dirs(*paths):
    for p in paths:
        os.makedirs(p, exist_ok=True)

def today_str():
    return pd.Timestamp.today(tz="Asia/Kolkata").strftime("%Y-%m-%d")

def load_static_symbols(static_symbols: Optional[List[str]], static_symbols_path: Optional[str]) -> List[str]:
    syms: List[str] = []
    if static_symbols and len(static_symbols) > 0:
        syms = list(static_symbols)
    elif static_symbols_path and os.path.exists(static_symbols_path):
        with open(static_symbols_path, "r") as f:
            syms = [line.strip() for line in f if line.strip()]
    else:
        raise ValueError(
            "Provide CFG.static_symbols=[...] ('.NS' suffixes) or set CFG.static_symbols_path "
            "to a file containing one symbol per line."
        )
    out = []
    for s in syms:
        s = s.strip().upper()
        if not s.endswith(".NS"):
            s = f"{s}.NS"
        out.append(s)
    seen = set()
    uniq = []
    for s in out:
        if s not in seen:
            uniq.append(s)
            seen.add(s)
    return uniq

def fetch_prices(tickers: List[str], start: str, end: Optional[str], cache_dir: str) -> Dict[str, pd.DataFrame]:
    ensure_dirs(cache_dir)
    data = {}
    end = end or today_str()
    for ticker in tickers:
        cache_path = os.path.join(cache_dir, f"{ticker.replace('^', '_')}.parquet")
        if os.path.exists(cache_path):
            try:
                df = pd.read_parquet(cache_path)
                if len(df) and pd.to_datetime(df.index[-1]).strftime("%Y-%m-%d") >= end:
                    data[ticker] = df
                    continue
            except Exception:
                pass
        try:
            df = yf.download(ticker, start=start, end=end, auto_adjust=True, progress=False, multi_level_index=False)
            if df is None or df.empty:
                continue
            df = df.rename(columns=str.title)  # Open, High, Low, Close, Volume
            df = df[['Open', 'High', 'Low', 'Close', 'Volume']].dropna()
            df.index.name = "date"
            df.to_parquet(cache_path)
            data[ticker] = df
        except Exception:
            continue
    return data

# ---- Indicators ----
def rsi(series: pd.Series, length: int = 14) -> pd.Series:
    delta = series.diff()
    gain = (delta.where(delta > 0, 0.0)).rolling(length).mean()
    loss = (-delta.where(delta < 0, 0.0)).rolling(length).mean()
    rs = gain / loss.replace(0.0, np.nan)
    out = 100 - (100 / (1 + rs))
    return out.fillna(50.0)

def ema(series: pd.Series, span: int) -> pd.Series:
    return series.ewm(span=span, adjust=False, min_periods=span).mean()

def macd_line(close: pd.Series, fast: int, slow: int) -> pd.Series:
    return ema(close, fast) - ema(close, slow)

def atr(high: pd.Series, low: pd.Series, close: pd.Series, length: int = 14) -> pd.Series:
    prev_close = close.shift(1)
    tr = pd.concat([
        (high - low).abs(),
        (high - prev_close).abs(),
        (low - prev_close).abs()
    ], axis=1).max(axis=1)
    return tr.ewm(alpha=1/length, adjust=False, min_periods=length).mean()

def compute_indicators(df: pd.DataFrame, cfg: Config) -> pd.DataFrame:
    out = df.copy()
    # MACD
    out["macd"]   = macd_line(out["Close"], cfg.macd_fast, cfg.macd_slow)
    out["macd_sig"] = out["macd"].ewm(span=cfg.macd_signal, adjust=False, min_periods=cfg.macd_signal).mean()
    out["macd_hist"] = out["macd"] - out["macd_sig"]
    out["macd_hist_prev"] = out["macd_hist"].shift(1)

    # RSI
    out["rsi"] = rsi(out["Close"], cfg.rsi_len)
    out["rsi_prev"] = out["rsi"].shift(1)

    # Mean reversion: z-score vs SMA(z_len)
    ma = out["Close"].rolling(cfg.z_len).mean()
    sd = out["Close"].rolling(cfg.z_len).std(ddof=0)
    out["zscore"] = (out["Close"] - ma) / sd.replace(0.0, np.nan)
    out["zscore_prev"] = out["zscore"].shift(1)

    # Volume expansion
    out["vol_ma"] = out["Volume"].rolling(cfg.vol_ma_len).mean()

    # ATR for trailing stop
    out["atr"] = atr(out["High"], out["Low"], out["Close"], cfg.atr_len)

    # Resistance (prior N-day highest high)
    out["resistance_pre"] = out["High"].rolling(cfg.resistance_lookback).max().shift(1)

    # 52w high for optional filter/ranking context
    out["high_52w"] = out["Close"].rolling(cfg.filter_52w_window).max()
    return out.dropna()

def basic_liquidity_ok(row: pd.Series, cfg: Config) -> bool:
    if not cfg.enable_basic_liquidity:
        return True
    if row["Close"] < cfg.min_price_inr:
        return False
    if row["vol_ma"] < cfg.min_avg_vol_20d:
        return False
    return True

# =========================
# SIGNAL SIMULATION (NEW LOGIC)
# =========================
def simulate_ticker(ticker: str, df: pd.DataFrame, cfg: Config):
    d = compute_indicators(df, cfg).copy()
    cols = ["ticker","side","date","price","shares","reason","signal_reason","score",
            "rsi","zscore","macd","macd_sig","macd_hist","atr","close","resistance_pre","high_52w","volume","vol_ma"]
    if d.empty:
        return pd.DataFrame(columns=cols), pd.Series(dtype=float)

    # ENTRY RULES
    macd_cross_up = (d["macd_hist_prev"] <= 0) & (d["macd_hist"] > 0)
    rsi_rises_from_oversold = (d["rsi_prev"] < 30) & (d["rsi"] > d["rsi_prev"]) & (d["rsi"] < 70)
    mr_confirm = (d["zscore_prev"] <= -cfg.z_entry) & (d["zscore"] >= -cfg.z_confirm)
    vol_expansion = (d["Volume"] >= cfg.vol_expansion_mult * d["vol_ma"])

    entry_signal = macd_cross_up & rsi_rises_from_oversold & mr_confirm & vol_expansion

    # EXIT RULES (checked while in position)
    # - Mean reversion reversal: zscore falls back below z_exit_reversal after being ≥ z_exit_trigger
    # We’ll track a flag "mr_extended" once zscore >= trigger; exit when it drops <= reversal.
    exit_indicator_key = "mr_reversal"

    in_pos = False
    entry_px = 0.0
    trail_stop = np.nan
    mr_extended = False
    tgt_px = np.nan
    atr_mult = cfg.trail_atr_mult

    trades = []
    idx = list(d.index)

    for i in range(len(idx)-1):
        dt, nxt = idx[i], idx[i+1]
        row, nxt_row = d.loc[dt], d.loc[nxt]

        if not in_pos:
            if entry_signal.loc[dt] and basic_liquidity_ok(row, cfg):
                # price used for execution
                exec_price = float(nxt_row["Open"] if cfg.entry_on_next_open else row["Close"])
                # initialize trailing stop and target
                entry_px = exec_price
                atr_now = float(row["atr"])
                trail_stop = entry_px - atr_mult * atr_now
                mr_extended = bool(row["zscore"] >= cfg.z_exit_trigger)
                # target at prior resistance
                tgt_pre = float(row["resistance_pre"]) if not np.isnan(row["resistance_pre"]) else np.nan
                tgt_px = tgt_pre if (tgt_pre > entry_px) else np.nan

                sig_reason = (
                    f"MACD cross ↑ (hist {row['macd_hist_prev']:.3f}→{row['macd_hist']:.3f}); "
                    f"RSI {row['rsi_prev']:.1f}→{row['rsi']:.1f} (<70); "
                    f"MR z {row['zscore_prev']:.2f}→{row['zscore']:.2f}; "
                    f"Vol {int(row['Volume'])} ≥ {cfg.vol_expansion_mult:.1f}×{int(row['vol_ma'])}"
                )
                trades.append({
                    "ticker": ticker, "side": "BUY", "date": nxt if cfg.entry_on_next_open else dt,
                    "price": exec_price, "shares": 0, "reason": "candidate",
                    "signal_reason": sig_reason,
                    "score": float( 3*row["macd_hist"] + 1.5*(row["zscore"]+cfg.z_entry) + np.log1p(row["Volume"]/max(row["vol_ma"],1.0)) ),
                    "rsi": float(row["rsi"]), "zscore": float(row["zscore"]),
                    "macd": float(row["macd"]), "macd_sig": float(row["macd_sig"]), "macd_hist": float(row["macd_hist"]),
                    "atr": atr_now, "close": float(row["Close"]), "resistance_pre": tgt_pre,
                    "high_52w": float(row["high_52w"]), "volume": float(row["Volume"]), "vol_ma": float(row["vol_ma"])
                })
                in_pos = True
                continue
        else:
            # Update trailing stop if price advances
            atr_now = float(row["atr"])
            new_trail = float(max(trail_stop, row["Close"] - atr_mult * atr_now))
            trail_stop = new_trail

            # Track MR extension state
            if not mr_extended and row["zscore"] >= cfg.z_exit_trigger:
                mr_extended = True

            # Check exits for next bar execution
            hit = None
            exec_date = nxt if cfg.exit_on_next_open else dt

            # 1) Hard target at prior resistance if available
            if not np.isnan(tgt_px) and nxt_row["High"] >= tgt_px:
                hit, exec_price = "target_resistance", float(tgt_px)

            # 2) Trailing ATR stop
            if hit is None and nxt_row["Low"] <= trail_stop:
                hit, exec_price = "trail_atr_stop", float(trail_stop)

            # 3) Mean reversion reversal
            if hit is None and mr_extended and (row["zscore"] <= cfg.z_exit_reversal):
                exec_price = float(nxt_row["Open"] if cfg.exit_on_next_open else row["Close"])
                hit = exit_indicator_key

            if hit is not None:
                trades.append({
                    "ticker": ticker, "side": "SELL", "date": exec_date,
                    "price": float(exec_price), "shares": 0, "reason": hit,
                    "signal_reason": "",
                    "score": np.nan,
                    "rsi": float(row["rsi"]), "zscore": float(row["zscore"]),
                    "macd": float(row["macd"]), "macd_sig": float(row["macd_sig"]), "macd_hist": float(row["macd_hist"]),
                    "atr": atr_now, "close": float(row["Close"]), "resistance_pre": float(row["resistance_pre"]),
                    "high_52w": float(row["high_52w"]), "volume": float(row["Volume"]), "vol_ma": float(row["vol_ma"])
                })
                in_pos = False
                entry_px = 0.0
                trail_stop = np.nan
                mr_extended = False
                tgt_px = np.nan

    # If still in position at the end, close at last close
    if in_pos:
        last_dt = d.index[-1]; row = d.loc[last_dt]
        trades.append({
            "ticker": ticker, "side": "SELL", "date": last_dt,
            "price": float(row["Close"]), "shares": 0, "reason": "final_close",
            "signal_reason": "",
            "score": np.nan,
            "rsi": float(row["rsi"]), "zscore": float(row["zscore"]),
            "macd": float(row["macd"]), "macd_sig": float(row["macd_sig"]), "macd_hist": float(row["macd_hist"]),
            "atr": float(row["atr"]), "close": float(row["Close"]), "resistance_pre": float(row["resistance_pre"]),
            "high_52w": float(row["high_52w"]), "volume": float(row["Volume"]), "vol_ma": float(row["vol_ma"])
        })

    return pd.DataFrame(trades, columns=cols), pd.Series(dtype=float)

# =========================
# Portfolio plumbing (unchanged except columns referenced)
# =========================
def pick_benchmark(benchmarks: Tuple[str,...], start: str, end: Optional[str], cache_dir: str) -> Tuple[str, pd.DataFrame]:
    for t in benchmarks:
        data = fetch_prices([t], start, end, cache_dir)
        df = data.get(t)
        if df is not None and not df.empty:
            log.info("Using benchmark: %s", t)
            return t, df
    idx = pd.date_range(start=start, end=end or today_str(), freq="B")
    df = pd.DataFrame({"Close": np.ones(len(idx))}, index=idx)
    log.warning("No benchmark found; using synthetic flat series.")
    return "SYNTH_BENCH", df

def compute_volar_scores(end_dt: pd.Timestamp, tickers: List[str], data_map: Dict[str,pd.DataFrame], bench_df: pd.DataFrame, lookback: int) -> Dict[str, float]:
    scores = {}
    bser = bench_df["Close"].loc[:end_dt].pct_change().dropna().iloc[-lookback:]
    for t in tickers:
        df = data_map.get(t)
        if df is None or df.empty:
            scores[t] = 0.0
            continue
        if end_dt not in df.index:
            df = df[df.index <= end_dt]
            if df.empty:
                scores[t] = 0.0
                continue
        r = df["Close"].loc[:end_dt].pct_change().dropna().iloc[-lookback:]
        common = pd.concat([r, bser], axis=1, keys=["s","b"]).dropna()
        if common.shape[0] < max(20, int(0.4*lookback)):
            scores[t] = 0.0
            continue
        excess = common["s"] - common["b"]
        vol = common["s"].std(ddof=0)
        scores[t] = 0.0 if vol <= 1e-8 else float((excess.mean() / vol) * math.sqrt(252.0))
    return scores

def markowitz_long_only(mu: np.ndarray, Sigma: np.ndarray) -> np.ndarray:
    n = len(mu)
    eps = 1e-6
    Sigma = Sigma + eps*np.eye(n)

    def solve_lambda(lmbd: float, active_mask=None):
        ones = np.ones(n if active_mask is None else np.count_nonzero(active_mask))
        if active_mask is None:
            A = np.block([[2*lmbd*Sigma, np.ones((n,1))],[np.ones((1,n)), np.zeros((1,1))]])
            b = np.concatenate([mu, np.array([1.0])])
            try:
                sol = np.linalg.solve(A, b)
                w = sol[:n]
            except np.linalg.LinAlgError:
                w = np.full(n, 1.0/n)
            return w
        else:
            idx = np.where(active_mask)[0]
            if len(idx)==0:
                return np.full(n, 1.0/n)
            S = Sigma[np.ix_(idx, idx)]
            o = np.ones(len(idx))
            m = mu[idx]
            A = np.block([[2*lmbd*S, o[:,None]],[o[None,:], np.zeros((1,1))]])
            b = np.concatenate([m, np.array([1.0])])
            try:
                sol = np.linalg.solve(A, b)
                w_sub = sol[:len(idx)]
            except np.linalg.LinAlgError:
                w_sub = np.full(len(idx), 1.0/len(idx))
            w = np.zeros(n)
            w[idx] = w_sub
            return w

    best_w = np.full(n, 1.0/n)
    best_sr = -1e9
    lambdas = np.logspace(-3, 3, 31)
    for lmbd in lambdas:
        active = np.ones(n, dtype=bool)
        w = None
        for _ in range(n):
            w = solve_lambda(lmbd, active_mask=active)
            neg = w < 0
            if not neg.any():
                break
            worst = np.argmin(w)
            active[worst] = False
        if w is None:
            continue
        w = np.clip(w, 0, None)
        if w.sum() <= 0:
            continue
        w = w / w.sum()
        mu_p = float(mu @ w)
        vol_p = float(np.sqrt(w @ Sigma @ w))
        if vol_p <= 1e-8:
            continue
        sr = mu_p / vol_p
        if sr > best_sr:
            best_w = w.copy(); best_sr = sr
    return best_w

def aggregate_and_apply(all_trades: pd.DataFrame, data_map: Dict[str, pd.DataFrame], bench_df: pd.DataFrame, cfg: Config):
    if all_trades.empty:
        return all_trades, pd.Series(dtype=float), {}

    side_order = {"BUY": 0, "SELL": 1}
    all_trades = (all_trades
        .assign(_sorder=all_trades["side"].map(side_order))
        .sort_values(by=["date", "_sorder"], kind="stable")
        .drop(columns=["_sorder"])
        .reset_index(drop=True)
    )
    all_trades["date"] = pd.to_datetime(all_trades["date"])

    equity_curve = []
    dates = sorted(all_trades["date"].unique().tolist())
    cash = cfg.initial_capital
    open_positions = {}
    completed_legs = []

    global APPLY_FEES
    APPLY_FEES = cfg.apply_fees

    def _get_close_on(tkr, dt):
        df = data_map.get(tkr)
        if df is None or df.empty:
            return np.nan
        if dt in df.index:
            return float(df.loc[dt, "Close"])
        prev = df[df.index <= dt]
        if prev.empty:
            return np.nan
        return float(prev["Close"].iloc[-1])

    if dates:
        seed_date = pd.to_datetime(dates[0]) - pd.Timedelta(days=1)
        equity_curve.append((seed_date, float(cash)))

    for dt in dates:
        day_trades = all_trades[all_trades["date"] == dt].copy()

        # SELL first
        for _, tr in day_trades[day_trades["side"] == "SELL"].iterrows():
            tkr = tr["ticker"]
            price = float(tr["price"])
            pos = open_positions.get(tkr)
            if pos is None:
                continue
            shares = int(pos["shares"])
            turnover_sell = shares * price
            fee = calc_fees(0.0, turnover_sell)
            pnl = (price - pos["entry_px"]) * shares
            cash += (turnover_sell - fee)
            realized = pnl - fee - pos.get("buy_fee", 0.0)
            completed_legs.append({
                "ticker": tkr, "side": "SELL", "date": dt, "price": price,
                "shares": shares, "reason": tr.get("reason",""),
                "turnover": turnover_sell, "fees_inr": fee, "pnl_inr": realized,
                "rsi": tr.get("rsi", np.nan), "zscore": tr.get("zscore", np.nan),
                "macd": tr.get("macd", np.nan), "macd_sig": tr.get("macd_sig", np.nan), "macd_hist": tr.get("macd_hist", np.nan),
                "atr": tr.get("atr", np.nan), "close": tr.get("close", np.nan),
                "resistance_pre": tr.get("resistance_pre", np.nan),
                "high_52w": tr.get("high_52w", np.nan),
                "volar": tr.get("volar", np.nan), "mvo_weight": np.nan, "alloc_inr": np.nan
            })
            log.info("Exit %-12s px=%8.2f sh=%6d reason=%s net=%.2f cash=%.2f",
                     tkr, price, shares, tr.get("reason",""), realized, cash)
            del open_positions[tkr]

        # BUY candidates selection (52w filter, dedupe, rank by VOLAR)
        buys_today = day_trades[day_trades["side"] == "BUY"].copy()
        if not buys_today.empty:
            keep = []
            for _, rr in buys_today.iterrows():
                df = data_map.get(rr["ticker"])
                if df is None or df.empty or dt not in df.index:
                    continue
                close = float(df.loc[dt, "Close"])
                hist = df["Close"].loc[:dt]
                window = hist.iloc[-cfg.filter_52w_window:] if len(hist)>=cfg.filter_52w_window else hist
                high_52w = float(window.max())
                if high_52w>0 and close >= cfg.within_pct_of_52w_high * high_52w:
                    keep.append(rr)
            buys_today = pd.DataFrame(keep) if keep else pd.DataFrame(columns=buys_today.columns)

        if not buys_today.empty:
            buys_today = buys_today[~buys_today["ticker"].isin(open_positions.keys())]

        if not buys_today.empty:
            tickers = buys_today["ticker"].tolist()
            volar_scores = compute_volar_scores(dt, tickers, data_map, bench_df, cfg.volar_lookback)
            buys_today["volar"] = buys_today["ticker"].map(volar_scores)
            # Slight preference also for stronger MACD hist & bigger volume surge
            buys_today["rank_score"] = buys_today["score"].fillna(0.0) + buys_today["volar"].fillna(0.0)
            buys_today = buys_today.sort_values("rank_score", ascending=False).reset_index(drop=True)

        slots = cfg.max_concurrent_positions - len(open_positions)
        selected = pd.DataFrame(columns=buys_today.columns)
        if slots > 0 and not buys_today.empty:
            selected = buys_today.head(min(cfg.top_k_daily, slots)).copy()

        if not selected.empty:
            log.info("Selected %d BUY candidates on %s:", selected.shape[0], dt.date())
            for i, rr in selected.reset_index(drop=True).iterrows():
                log.info("  %-12s rank=%.2f volar=%.2f px=%8.2f",
                         rr["ticker"], rr.get("rank_score",0.0), rr.get("volar",0.0), rr["price"])

            # MVO sizing
            names = selected["ticker"].tolist()
            rets = []
            for t in names:
                df = data_map.get(t)
                ser = df["Close"].loc[:dt].pct_change().dropna().iloc[-cfg.volar_lookback:]
                rets.append(ser)
            R = pd.concat(rets, axis=1)
            R.columns = names
            R = R.dropna()
            if R.empty or R.shape[0] < max(20, int(0.4*cfg.volar_lookback)) or R.shape[1] == 0:
                weights = np.full(len(names), 1.0/len(names))
            else:
                mu = R.mean().values
                Sigma = R.cov().values
                weights = markowitz_long_only(mu, Sigma)

            deploy_cash = max(0.0, float(cash)) * float(cfg.deploy_cash_frac)
            if deploy_cash <= 0:
                log.info("No deployable cash (cap=%.0f%%) on %s", 100*cfg.deploy_cash_frac, dt.date())
            else:
                alloc = (weights / weights.sum()) * deploy_cash if weights.sum()>0 else np.full(len(names), deploy_cash/len(names))
                rank_map = {row["ticker"]: (idx+1) for idx, (_, row) in enumerate(selected.iterrows())}
                for w_amt, t in zip(alloc, names):
                    df_t = data_map[t]
                    price = float(df_t.loc[dt, "Close"] if dt in df_t.index else df_t["Close"].loc[:dt].iloc[-1])
                    shares = int(math.floor(w_amt / price))
                    if shares <= 0:
                        log.info("Skip BUY %-12s (alloc %.2f too small)", t, w_amt); continue
                    turn = shares * price
                    fee = calc_fees(turn, 0.0)
                    total_cost = turn + fee
                    if total_cost > cash:
                        shares = int(math.floor((cash - fee) / price))
                        if shares <= 0:
                            log.info("Skip BUY %-12s due to cash/fees", t); continue
                        turn = shares * price
                        total_cost = turn + fee
                    cash -= total_cost
                    open_positions[t] = {"entry_date": dt, "entry_px": price, "shares": shares, "buy_fee": fee, "entry_reason": "entry"}
                    row_sel = selected[selected["ticker"]==t].iloc[0]
                    volar_val = float(row_sel.get("volar", np.nan))
                    rank_pos = rank_map.get(t, np.nan)
                    high_52w = float(row_sel.get("high_52w", np.nan))
                    close_val = float(row_sel.get("close", np.nan))
                    pct_52w = (close_val / high_52w) if (high_52w and high_52w>0) else np.nan
                    mvo_weight_today = (w_amt / deploy_cash) if deploy_cash > 0 else 0.0
                    sig_reason = row_sel.get("signal_reason", "MACD↑, RSI↑ from <30, MR confirm, Vol expand")
                    reason_text = (
                        f"{sig_reason}; 52w%={pct_52w:.1%} (>= {CFG.within_pct_of_52w_high:.0%}); "
                        f"VOLAR rank {int(rank_pos)}/{len(names)} (VOLAR={volar_val:.2f}); "
                        f"MVO weight={mvo_weight_today:.1%} of capped cash ({100*cfg.deploy_cash_frac:.0f}% of available)"
                    )
                    completed_legs.append({
                        "ticker": t, "side": "BUY", "date": dt, "price": price,
                        "shares": shares, "reason": reason_text,
                        "turnover": turn, "fees_inr": fee, "pnl_inr": 0.0,
                        "rsi": float(row_sel.get("rsi", np.nan)), "zscore": float(row_sel.get("zscore", np.nan)),
                        "macd": float(row_sel.get("macd", np.nan)), "macd_sig": float(row_sel.get("macd_sig", np.nan)), "macd_hist": float(row_sel.get("macd_hist", np.nan)),
                        "atr": float(row_sel.get("atr", np.nan)), "close": close_val, "resistance_pre": float(row_sel.get("resistance_pre", np.nan)),
                        "high_52w": high_52w, "volar": volar_val, "mvo_weight": float(mvo_weight_today), "alloc_inr": float(w_amt)
                    })
                    log.info("BUY %-12s px=%8.2f sh=%6d fee=%.2f cash=%.2f :: %s",
                             t, price, shares, fee, cash, reason_text)

        # MTM
        mtm = 0.0
        for _tkr, pos in open_positions.items():
            px = _get_close_on(_tkr, dt)
            if not np.isnan(px):
                mtm += pos["shares"] * px
        equity_curve.append((dt, float(cash + mtm)))

    eq_ser = pd.Series([e for _, e in equity_curve], index=[d for d, _ in equity_curve])
    legs_df = pd.DataFrame(completed_legs).sort_values(["date", "ticker", "side"]).reset_index(drop=True)

    # Roundtrips
    roundtrips = []
    by_tkr_open = {}
    for _, leg in legs_df.iterrows():
        tkr = leg["ticker"]
        if leg["side"] == "BUY":
            by_tkr_open[tkr] = leg
        else:
            buy = by_tkr_open.pop(tkr, None)
            if buy is None: continue
            fees_total = float(buy.get("fees_inr", 0.0) + leg.get("fees_inr", 0.0))
            gross_pnl = (leg["price"] - buy["price"]) * buy["shares"]
            net_pnl   = gross_pnl - fees_total
            ret_pct   = (leg["price"] / buy["price"] - 1.0) * 100.0
            days_held = (pd.to_datetime(leg["date"]) - pd.to_datetime(buy["date"])).days
            roundtrips.append({
                "ticker": tkr,
                "entry_date": pd.to_datetime(buy["date"]),
                "entry_price": float(buy["price"]),
                "exit_date": pd.to_datetime(leg["date"]),
                "exit_price": float(leg["price"]),
                "days_held": int(days_held),
                "shares": int(buy["shares"]),
                "entry_reason": buy.get("reason",""),
                "exit_reason": leg.get("reason",""),
                "gross_pnl_inr": float(gross_pnl),
                "fees_total_inr": float(fees_total),
                "net_pnl_inr": float(net_pnl),
                "return_pct": float(ret_pct),
                "rsi_entry": float(buy.get("rsi", np.nan)),
                "zscore_entry": float(buy.get("zscore", np.nan)),
                "macd_hist_entry": float(buy.get("macd_hist", np.nan)),
                "atr_entry": float(buy.get("atr", np.nan)),
                "close_entry": float(buy.get("close", np.nan)),
                "resistance_entry": float(buy.get("resistance_pre", np.nan)),
                "volar_entry": float(buy.get("volar", np.nan)),
                "mvo_weight_entry": float(buy.get("mvo_weight", np.nan)),
                "alloc_inr_entry": float(buy.get("alloc_inr", np.nan))
            })
    trips_df = pd.DataFrame(roundtrips).sort_values(["entry_date","ticker"]).reset_index(drop=True)

    metrics = compute_metrics(eq_ser, legs_df)
    return legs_df, trips_df, eq_ser, metrics

def compute_metrics(equity: pd.Series, legs_df: pd.DataFrame):
    out = {}
    if equity is None or equity.empty:
        return out
    eq = equity.dropna()
    daily_ret = eq.pct_change().fillna(0.0)

    days = (eq.index[-1] - eq.index[0]).days or 1
    years = days / 365.25
    cagr = (eq.iloc[-1] / eq.iloc[0]) ** (1/years) - 1 if years > 0 else 0.0

    if daily_ret.std(ddof=0) > 0:
        sharpe = (daily_ret.mean() / daily_ret.std(ddof=0)) * np.sqrt(252)
    else:
        sharpe = 0.0

    cummax = eq.cummax()
    dd = (eq - cummax) / cummax
    max_dd = dd.min()

    wins = 0
    n_sells = legs_df[legs_df["side"] == "SELL"].shape[0] if legs_df is not None and not legs_df.empty else 0
    for _, r in legs_df[legs_df["side"] == "SELL"].iterrows():
        if float(r.get("pnl_inr", 0.0)) > 0:
            wins += 1
    win_rate = (wins / n_sells) * 100.0 if n_sells > 0 else 0.0

    out.update({
        "start_equity_inr": float(eq.iloc[0]),
        "final_equity_inr": float(eq.iloc[-1]),
        "cagr_pct": float(cagr * 100),
        "sharpe": float(sharpe),
        "max_drawdown_pct": float(max_dd * 100),
        "win_rate_pct": float(win_rate),
        "n_trades": int(n_sells),
    })
    return out

def plot_equity(equity: pd.Series, out_path: str):
    if equity is None or equity.empty:
        return
    try:
        import matplotlib.pyplot as plt
        plt.figure(figsize=(10,5))
        plt.plot(equity.index, equity.values)
        plt.title("Equity Curve")
        plt.xlabel("Date")
        plt.ylabel("Equity (INR)")
        plt.tight_layout()
        plt.savefig(out_path)
        plt.close()
    except Exception:
        pass

def backtest(cfg: Config):
    ensure_dirs(cfg.cache_dir, cfg.out_dir)
    log.info("Universe: loading static symbols...")
    symbols = load_static_symbols(cfg.static_symbols, cfg.static_symbols_path)
    log.info("Loaded %d symbols.", len(symbols))

    log.info("Data: fetching OHLCV from yfinance (adjusted)...")
    data_map = fetch_prices(symbols, cfg.start_date, cfg.end_date, cfg.cache_dir)
    log.info("Downloaded %d symbols with data.", len(data_map))

    bench_tkr, bench_df = pick_benchmark(cfg.benchmark_try, cfg.start_date, cfg.end_date, cfg.cache_dir)
    log.info("Benchmark selected: %s", bench_tkr)

    log.info("Signals: generating MACD/RSI/MeanReversion + Volume expansion entries...")
    all_trades = []
    for i, tkr in enumerate(symbols, 1):
        df = data_map.get(tkr)
        if df is None or df.empty:
            continue
        tr, _ = simulate_ticker(tkr, df, cfg)
        if not tr.empty:
            all_trades.append(tr)
        if i % 50 == 0:
            log.info("  processed %d/%d tickers...", i, len(symbols))

    if not all_trades:
        log.warning("No signals generated; check thresholds.")
        return None, None, None, {}
    all_trades = pd.concat(all_trades, ignore_index=True)

    log.info("Portfolio: cap daily deploy to %.0f%% of cash; 52w>=%.0f%% high; top-%d by rank; MVO; max %d positions.",
             cfg.deploy_cash_frac*100, cfg.within_pct_of_52w_high*100, cfg.top_k_daily, cfg.max_concurrent_positions)
    legs_df, trips_df, equity, metrics = aggregate_and_apply(all_trades, data_map, bench_df, cfg)

    stamp = pd.Timestamp.today(tz="Asia/Kolkata").strftime("%Y%m%d_%H%M%S")
    legs_path = os.path.join(cfg.out_dir, f"trades_legs_{stamp}.csv")
    trips_path = os.path.join(cfg.out_dir, f"trades_roundtrips_{stamp}.csv")
    equity_path = os.path.join(cfg.out_dir, f"equity_{stamp}.csv")
    metrics_path = os.path.join(cfg.out_dir, f"metrics_{stamp}.json")
    eq_plot_path = os.path.join(cfg.out_dir, f"equity_{stamp}.png")

    if legs_df is not None:
        legs_df.to_csv(legs_path, index=False)
    if trips_df is not None:
        trips_df.to_csv(trips_path, index=False)
    if equity is not None:
        pd.DataFrame({"date": equity.index, "equity": equity.values}).to_csv(equity_path, index=False)
    with open(metrics_path, "w") as f:
        json.dump(metrics, f, indent=2)

    if cfg.plot and equity is not None:
        plot_equity(equity, eq_plot_path)

    log.info("=== METRICS ===\n%s", json.dumps(metrics, indent=2))
    log.info("Files written:\n  %s\n  %s\n  %s\n  %s", legs_path, trips_path, equity_path, metrics_path)
    if cfg.plot:
        log.info("  %s", eq_plot_path)

def main():
    global APPLY_FEES
    APPLY_FEES = bool(CFG.apply_fees)
    # === Set your universe here or via file path ===
    # CFG.static_symbols = ['RELIANCE.NS','TCS.NS','INFY.NS','HDFCBANK.NS','ICICIBANK.NS']  # replace with your big list or use .static_symbols_path
    CFG.static_symbols_path = "nifty500.txt"
    backtest(CFG)

if __name__ == "__main__":
    main()
# Out:
# 2025-10-15 17:21:16 | INFO | Universe: loading static symbols...
# 2025-10-15 17:21:16 | INFO | Loaded 500 symbols.
# 2025-10-15 17:21:16 | INFO | Data: fetching OHLCV from yfinance (adjusted)...
# 2025-10-15 17:24:11 | INFO | Downloaded 500 symbols with data.
# 2025-10-15 17:24:13 | ERROR | HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: ^CNX500"}}}
# 2025-10-15 17:24:13 | ERROR |
# 1 Failed download:
# 2025-10-15 17:24:13 | ERROR | ['^CNX500']: YFTzMissingError('possibly delisted; no timezone found')
# 2025-10-15 17:24:13 | INFO | Using benchmark: ^CRSLDX
# 2025-10-15 17:24:13 | INFO | Benchmark selected: ^CRSLDX
# 2025-10-15 17:24:13 | INFO | Signals: generating MACD/RSI/MeanReversion + Volume expansion entries...
# 2025-10-15 17:24:17 | INFO |   processed 50/500 tickers...
# 2025-10-15 17:24:21 | INFO |   processed 100/500 tickers...
# 2025-10-15 17:24:25 | INFO |   processed 150/500 tickers...
# 2025-10-15 17:24:29 | INFO |   processed 200/500 tickers...
# 2025-10-15 17:24:32 | INFO |   processed 250/500 tickers...
# 2025-10-15 17:24:36 | INFO |   processed 300/500 tickers...
# 2025-10-15 17:24:40 | INFO |   processed 350/500 tickers...
# 2025-10-15 17:24:43 | INFO |   processed 400/500 tickers...
# 2025-10-15 17:24:47 | INFO |   processed 450/500 tickers...
# 2025-10-15 17:24:51 | INFO |   processed 500/500 tickers...
# 2025-10-15 17:24:51 | INFO | Portfolio: cap daily deploy to 25% of cash; 52w>=50% high; top-300 by rank; MVO; max 5 positions.
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-01-28:
# 2025-10-15 17:24:51 | INFO |   KIRLOSENG.NS rank=6.88 volar=0.18 px=  203.20
# 2025-10-15 17:24:51 | INFO | BUY KIRLOSENG.NS px=  197.24 sh=   633 fee=171.85 cash=374976.89 :: MACD cross ↑ (hist -0.456→0.452); RSI 29.4→51.2 (<70); MR z -1.67→1.09; Vol 184491 ≥ 1.5×22647; 52w%=72.8% (>= 50%); VOLAR rank 1/1 (VOLAR=0.18); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Exit KIRLOSENG.NS px=  200.81 sh=   633 reason=mr_reversal net=1912.92 cash=501912.92
# 2025-10-15 17:24:51 | INFO | Selected 2 BUY candidates on 2016-02-01:
# 2025-10-15 17:24:51 | INFO |   ZFCVINDIA.NS rank=35.47 volar=0.88 px= 5625.80
# 2025-10-15 17:24:51 | INFO |   SHRIRAMFIN.NS rank=5.51 volar=-0.31 px=  145.03
# 2025-10-15 17:24:51 | INFO | BUY ZFCVINDIA.NS px= 5672.33 sh=    22 fee=171.78 cash=376949.85 :: MACD cross ↑ (hist -12.532→10.349); RSI 25.9→42.6 (<70); MR z -1.19→-0.07; Vol 56301 ≥ 1.5×7422; 52w%=77.0% (>= 50%); VOLAR rank 1/2 (VOLAR=0.88); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Skip BUY SHRIRAMFIN.NS (alloc 0.00 too small)
# 2025-10-15 17:24:51 | INFO | Exit ZFCVINDIA.NS px= 5115.59 sh=    22 reason=trail_atr_stop net=-12584.08 cash=489328.84
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-02-18:
# 2025-10-15 17:24:51 | INFO |   CHENNPETRO.NS rank=5.25 volar=1.79 px=  140.49
# 2025-10-15 17:24:51 | INFO | BUY CHENNPETRO.NS px=  137.24 sh=   891 fee=168.79 cash=366883.26 :: MACD cross ↑ (hist -1.276→0.018); RSI 29.4→47.1 (<70); MR z -1.44→0.33; Vol 1205452 ≥ 1.5×387774; 52w%=70.5% (>= 50%); VOLAR rank 1/1 (VOLAR=1.79); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Exit CHENNPETRO.NS px=  133.71 sh=   891 reason=mr_reversal net=-3483.76 cash=485845.08
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-05-16:
# 2025-10-15 17:24:51 | INFO |   CAPLIPOINT.NS rank=6.74 volar=0.42 px=  200.00
# 2025-10-15 17:24:51 | INFO | BUY CAPLIPOINT.NS px=  199.77 sh=   608 fee=167.82 cash=364220.08 :: MACD cross ↑ (hist -1.115→0.390); RSI 16.3→60.5 (<70); MR z -1.34→1.41; Vol 334250 ≥ 1.5×92869; 52w%=65.3% (>= 50%); VOLAR rank 1/1 (VOLAR=0.42); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-05-17:
# 2025-10-15 17:24:51 | INFO |   GRAVITA.NS   rank=6.22 volar=-0.31 px=   24.78
# 2025-10-15 17:24:51 | INFO | BUY GRAVITA.NS   px=   22.80 sh=  3993 fee=131.70 cash=273049.52 :: MACD cross ↑ (hist -0.119→0.003); RSI 29.3→60.3 (<70); MR z -1.12→2.23; Vol 296903 ≥ 1.5×69139; 52w%=72.6% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.31); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Exit GRAVITA.NS   px=   22.80 sh=  3993 reason=mr_reversal net=-273.33 cash=363946.75
# 2025-10-15 17:24:51 | INFO | Exit CAPLIPOINT.NS px=  187.22 sh=   608 reason=mr_reversal net=-7958.08 cash=477613.68
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-06-08:
# 2025-10-15 17:24:51 | INFO |   INOXWIND.NS  rank=1.41 volar=-1.12 px=   57.71
# 2025-10-15 17:24:51 | INFO | BUY INOXWIND.NS  px=   58.21 sh=  2051 fee=165.37 cash=358054.47 :: MACD cross ↑ (hist -0.274→0.005); RSI 13.8→39.6 (<70); MR z -1.74→-0.13; Vol 3211140 ≥ 1.5×1372336; 52w%=49.3% (>= 50%); VOLAR rank 1/1 (VOLAR=-1.12); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-06-09:
# 2025-10-15 17:24:51 | INFO |   JPPOWER.NS   rank=2.02 volar=-0.81 px=    4.05
# 2025-10-15 17:24:51 | INFO | BUY JPPOWER.NS   px=    4.05 sh= 22102 fee=129.89 cash=268411.48 :: MACD cross ↑ (hist -0.017→0.007); RSI 25.0→42.3 (<70); MR z -1.48→0.07; Vol 3181929 ≥ 1.5×1353652; 52w%=50.3% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.81); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Exit JPPOWER.NS   px=    5.25 sh= 22102 reason=target_resistance net=26224.93 cash=384279.40
# 2025-10-15 17:24:51 | INFO | Exit INOXWIND.NS  px=   55.59 sh=  2051 reason=trail_atr_stop net=-5709.22 cash=498129.39
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-06-29:
# 2025-10-15 17:24:51 | INFO |   GODFRYPHLP.NS rank=9.87 volar=1.21 px=  261.78
# 2025-10-15 17:24:51 | INFO | BUY GODFRYPHLP.NS px=  251.61 sh=   494 fee=171.19 cash=373663.93 :: MACD cross ↑ (hist -0.383→0.885); RSI 27.5→56.4 (<70); MR z -1.92→1.67; Vol 1043832 ≥ 1.5×163321; 52w%=55.1% (>= 50%); VOLAR rank 1/1 (VOLAR=1.21); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-06-30:
# 2025-10-15 17:24:51 | INFO |   CEATLTD.NS   rank=10.04 volar=0.73 px=  782.80
# 2025-10-15 17:24:51 | INFO | BUY CEATLTD.NS   px=  768.02 sh=   121 fee=133.95 cash=280599.87 :: MACD cross ↑ (hist -1.592→2.254); RSI 25.8→37.9 (<70); MR z -1.09→-0.18; Vol 1396797 ≥ 1.5×518939; 52w%=66.1% (>= 50%); VOLAR rank 1/1 (VOLAR=0.73); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Exit GODFRYPHLP.NS px=  249.67 sh=   494 reason=mr_reversal net=-1302.72 cash=403762.61
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-07-21:
# 2025-10-15 17:24:51 | INFO |   JUBLPHARMA.NS rank=5.77 volar=1.03 px=  217.19
# 2025-10-15 17:24:51 | INFO | BUY JUBLPHARMA.NS px=  220.89 sh=   456 fee=143.20 cash=302895.32 :: MACD cross ↑ (hist -0.047→0.607); RSI 27.4→44.5 (<70); MR z -1.47→-0.01; Vol 2120249 ≥ 1.5×676188; 52w%=69.6% (>= 50%); VOLAR rank 1/1 (VOLAR=1.03); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Exit CEATLTD.NS   px=  799.10 sh=   121 reason=mr_reversal net=3479.63 cash=399439.01
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-08-11:
# 2025-10-15 17:24:51 | INFO |   ASTRAZEN.NS  rank=7.70 volar=-0.57 px= 1039.68
# 2025-10-15 17:24:51 | INFO | BUY ASTRAZEN.NS  px= 1017.87 sh=    98 fee=142.05 cash=299545.63 :: MACD cross ↑ (hist -1.563→0.812); RSI 21.8→55.6 (<70); MR z -1.76→1.06; Vol 298771 ≥ 1.5×20532; 52w%=82.0% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.57); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Exit ASTRAZEN.NS  px= 1017.03 sh=    98 reason=mr_reversal net=-374.66 cash=399064.35
# 2025-10-15 17:24:51 | INFO | Exit JUBLPHARMA.NS px=  275.41 sh=   456 reason=target_resistance net=24539.99 cash=524471.62
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-08-19:
# 2025-10-15 17:24:51 | INFO |   TARIL.NS     rank=4.34 volar=0.70 px=   16.43
# 2025-10-15 17:24:51 | INFO | BUY TARIL.NS     px=   16.30 sh=  8044 fee=179.27 cash=393189.30 :: MACD cross ↑ (hist -0.134→0.011); RSI 18.1→44.7 (<70); MR z -1.14→0.53; Vol 1916180 ≥ 1.5×704859; 52w%=85.4% (>= 50%); VOLAR rank 1/1 (VOLAR=0.70); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Exit TARIL.NS     px=   15.84 sh=  8044 reason=mr_reversal net=-4077.44 cash=520394.19
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-09-29:
# 2025-10-15 17:24:51 | INFO |   PGEL.NS      rank=6.48 volar=0.22 px=   16.50
# 2025-10-15 17:24:51 | INFO | BUY PGEL.NS      px=   15.14 sh=  8593 fee=178.06 cash=390131.95 :: MACD cross ↑ (hist -0.083→0.021); RSI 13.2→53.1 (<70); MR z -1.38→1.63; Vol 3795580 ≥ 1.5×444430; 52w%=84.9% (>= 50%); VOLAR rank 1/1 (VOLAR=0.22); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Exit PGEL.NS      px=   14.74 sh=  8593 reason=trail_atr_stop net=-3784.70 cash=516609.49
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-10-04:
# 2025-10-15 17:24:51 | INFO |   USHAMART.NS  rank=3.07 volar=-0.16 px=   12.50
# 2025-10-15 17:24:51 | INFO | BUY USHAMART.NS  px=   12.50 sh= 10334 fee=176.95 cash=387285.90 :: MACD cross ↑ (hist -0.031→0.031); RSI 27.9→52.3 (<70); MR z -2.48→0.41; Vol 809441 ≥ 1.5×460777; 52w%=74.4% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.16); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-10-07:
# 2025-10-15 17:24:51 | INFO |   JPPOWER.NS   rank=2.51 volar=-0.90 px=    4.85
# 2025-10-15 17:24:51 | INFO | BUY JPPOWER.NS   px=    4.65 sh= 20821 fee=138.56 cash=290329.68 :: MACD cross ↑ (hist -0.013→0.019); RSI 18.2→56.5 (<70); MR z -1.39→0.26; Vol 9447175 ≥ 1.5×2831920; 52w%=60.7% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.90); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Exit JPPOWER.NS   px=    4.45 sh= 20821 reason=mr_reversal net=-4446.09 cash=382839.81
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-10-18:
# 2025-10-15 17:24:51 | INFO |   ZENSARTECH.NS rank=3.63 volar=0.48 px=  173.39
# 2025-10-15 17:24:51 | INFO | BUY ZENSARTECH.NS px=  175.18 sh=   546 fee=137.17 cash=287053.14 :: MACD cross ↑ (hist -0.006→0.151); RSI 30.0→43.9 (<70); MR z -1.63→-0.05; Vol 233985 ≥ 1.5×91971; 52w%=91.3% (>= 50%); VOLAR rank 1/1 (VOLAR=0.48); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Exit ZENSARTECH.NS px=  161.47 sh=   546 reason=trail_atr_stop net=-7762.39 cash=375077.42
# 2025-10-15 17:24:51 | INFO | Exit USHAMART.NS  px=   16.82 sh= 10334 reason=target_resistance net=44300.11 cash=548701.13
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-11-01:
# 2025-10-15 17:24:51 | INFO |   ABBOTINDIA.NS rank=30.91 volar=-0.78 px= 4513.26
# 2025-10-15 17:24:51 | INFO | BUY ABBOTINDIA.NS px= 4413.01 sh=    31 fee=186.04 cash=411711.74 :: MACD cross ↑ (hist -9.584→7.826); RSI 29.2→64.6 (<70); MR z -1.32→3.39; Vol 12265 ≥ 1.5×2985; 52w%=83.8% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.78); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Exit ABBOTINDIA.NS px= 4280.60 sh=    31 reason=trail_atr_stop net=-4475.74 cash=544225.38
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-11-03:
# 2025-10-15 17:24:51 | INFO |   ZENSARTECH.NS rank=7.89 volar=0.13 px=  179.36
# 2025-10-15 17:24:51 | INFO | BUY ZENSARTECH.NS px=  176.37 sh=   771 fee=185.07 cash=408055.62 :: MACD cross ↑ (hist -1.081→0.258); RSI 24.4→58.8 (<70); MR z -2.23→2.07; Vol 2145030 ≥ 1.5×219011; 52w%=94.8% (>= 50%); VOLAR rank 1/1 (VOLAR=0.13); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Exit ZENSARTECH.NS px=  168.31 sh=   771 reason=mr_reversal net=-6584.86 cash=537640.52
# 2025-10-15 17:24:51 | INFO | Selected 2 BUY candidates on 2016-12-06:
# 2025-10-15 17:24:51 | INFO |   TRENT.NS     rank=10.47 volar=0.80 px=  198.56
# 2025-10-15 17:24:51 | INFO |   SUNTV.NS     rank=8.74 volar=0.58 px=  396.77
# 2025-10-15 17:24:51 | INFO | BUY TRENT.NS     px=  194.97 sh=   497 fee=138.66 cash=440602.32 :: MACD cross ↑ (hist -0.279→1.183); RSI 18.5→59.1 (<70); MR z -1.36→1.51; Vol 1804413 ≥ 1.5×187828; 52w%=82.6% (>= 50%); VOLAR rank 1/2 (VOLAR=0.80); MVO weight=72.1% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | BUY SUNTV.NS     px=  373.24 sh=   100 fee=67.92 cash=403210.89 :: MACD cross ↑ (hist -1.228→1.283); RSI 28.2→51.0 (<70); MR z -1.37→0.54; Vol 11644194 ≥ 1.5×1824661; 52w%=87.5% (>= 50%); VOLAR rank 2/2 (VOLAR=0.58); MVO weight=27.9% of capped cash (25% of available)
# 2025-10-15 17:24:51 | INFO | Exit SUNTV.NS     px=  377.56 sh=   100 reason=mr_reversal net=278.70 cash=440881.01
# 2025-10-15 17:24:51 | INFO | Exit TRENT.NS     px=  189.22 sh=   497 reason=mr_reversal net=-3141.32 cash=534777.89
# 2025-10-15 17:24:51 | INFO | Selected 1 BUY candidates on 2016-12-30:
# 2025-10-15 17:24:52 | INFO |   GRASIM.NS    rank=4.84 volar=0.46 px=  615.85
# 2025-10-15 17:24:52 | INFO | BUY GRASIM.NS    px=  632.53 sh=   211 fee=182.07 cash=401132.64 :: MACD cross ↑ (hist -1.113→0.591); RSI 17.1→37.8 (<70); MR z -1.32→-0.04; Vol 1755798 ≥ 1.5×801125; 52w%=80.3% (>= 50%); VOLAR rank 1/1 (VOLAR=0.46); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit GRASIM.NS    px=  622.45 sh=   211 reason=mr_reversal net=-2492.57 cash=532285.33
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-03-06:
# 2025-10-15 17:24:52 | INFO |   INDUSTOWER.NS rank=2.70 volar=-1.07 px=  219.54
# 2025-10-15 17:24:52 | INFO | BUY INDUSTOWER.NS px=  220.43 sh=   603 fee=181.43 cash=399185.81 :: MACD cross ↑ (hist -0.849→0.226); RSI 29.0→44.7 (<70); MR z -1.21→0.23; Vol 12442632 ≥ 1.5×4974456; 52w%=77.6% (>= 50%); VOLAR rank 1/1 (VOLAR=-1.07); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-03-17:
# 2025-10-15 17:24:52 | INFO |   SWANCORP.NS  rank=6.05 volar=1.39 px=  159.29
# 2025-10-15 17:24:52 | INFO | BUY SWANCORP.NS  px=  159.44 sh=   625 fee=141.92 cash=299395.94 :: MACD cross ↑ (hist -0.682→0.145); RSI 29.2→48.0 (<70); MR z -1.82→0.99; Vol 1353760 ≥ 1.5×551270; 52w%=78.7% (>= 50%); VOLAR rank 1/1 (VOLAR=1.39); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-03-20:
# 2025-10-15 17:24:52 | INFO |   PFIZER.NS    rank=15.50 volar=-1.57 px= 1536.65
# 2025-10-15 17:24:52 | INFO | BUY PFIZER.NS    px= 1514.08 sh=    49 fee=111.69 cash=225094.33 :: MACD cross ↑ (hist -0.867→3.255); RSI 16.9→58.3 (<70); MR z -1.26→2.74; Vol 53943 ≥ 1.5×12067; 52w%=88.3% (>= 50%); VOLAR rank 1/1 (VOLAR=-1.57); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit PFIZER.NS    px= 1469.66 sh=    49 reason=trail_atr_stop net=-2410.23 cash=296985.72
# 2025-10-15 17:24:52 | INFO | Exit SWANCORP.NS  px=  153.47 sh=   625 reason=mr_reversal net=-4020.74 cash=392754.84
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-03-29:
# 2025-10-15 17:24:52 | INFO |   ACE.NS       rank=10.19 volar=0.80 px=   57.02
# 2025-10-15 17:24:52 | INFO | BUY ACE.NS       px=   58.18 sh=  1687 fee=140.14 cash=294467.33 :: MACD cross ↑ (hist -0.317→0.091); RSI 29.7→62.6 (<70); MR z -2.06→3.43; Vol 4620213 ≥ 1.5×429602; 52w%=100.0% (>= 50%); VOLAR rank 1/1 (VOLAR=0.80); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit INDUSTOWER.NS px=  256.64 sh=   603 reason=target_resistance net=21449.47 cash=449016.32
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-04-19:
# 2025-10-15 17:24:52 | INFO |   SWANCORP.NS  rank=5.08 volar=1.31 px=  145.35
# 2025-10-15 17:24:52 | INFO | BUY SWANCORP.NS  px=  144.21 sh=   778 fee=156.82 cash=336664.42 :: MACD cross ↑ (hist -0.273→0.274); RSI 6.6→45.0 (<70); MR z -1.37→-0.03; Vol 1439538 ≥ 1.5×415185; 52w%=72.2% (>= 50%); VOLAR rank 1/1 (VOLAR=1.31); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit ACE.NS       px=   60.68 sh=  1687 reason=mr_reversal net=3931.34 cash=438883.27
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-05-02:
# 2025-10-15 17:24:52 | INFO |   ONGC.NS      rank=5.19 volar=0.63 px=  120.73
# 2025-10-15 17:24:52 | INFO | BUY ONGC.NS      px=  123.56 sh=   888 fee=153.88 cash=329010.10 :: MACD cross ↑ (hist -0.127→0.198); RSI 23.8→50.3 (<70); MR z -1.52→0.98; Vol 10789077 ≥ 1.5×6316000; 52w%=90.7% (>= 50%); VOLAR rank 1/1 (VOLAR=0.63); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit ONGC.NS      px=  117.97 sh=   888 reason=trail_atr_stop net=-5274.79 cash=433608.47
# 2025-10-15 17:24:52 | INFO | Exit SWANCORP.NS  px=  147.79 sh=   778 reason=mr_reversal net=2464.14 cash=548424.52
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-05-11:
# 2025-10-15 17:24:52 | INFO |   AUROPHARMA.NS rank=1.24 volar=-1.56 px=  588.99
# 2025-10-15 17:24:52 | INFO | BUY AUROPHARMA.NS px=  593.37 sh=   231 fee=186.36 cash=411169.32 :: MACD cross ↑ (hist -2.021→0.166); RSI 20.6→41.2 (<70); MR z -1.18→-0.17; Vol 4083441 ≥ 1.5×2201498; 52w%=71.3% (>= 50%); VOLAR rank 1/1 (VOLAR=-1.56); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-05-16:
# 2025-10-15 17:24:52 | INFO |   HINDCOPPER.NS rank=5.44 volar=0.20 px=   64.25
# 2025-10-15 17:24:52 | INFO | BUY HINDCOPPER.NS px=   63.16 sh=  1627 fee=145.62 cash=308262.06 :: MACD cross ↑ (hist -0.171→0.048); RSI 21.3→51.4 (<70); MR z -1.77→1.54; Vol 1332279 ≥ 1.5×512840; 52w%=94.0% (>= 50%); VOLAR rank 1/1 (VOLAR=0.20); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit AUROPHARMA.NS px=  552.07 sh=   231 reason=trail_atr_stop net=-9905.96 cash=435611.29
# 2025-10-15 17:24:52 | INFO | Exit HINDCOPPER.NS px=   60.71 sh=  1627 reason=trail_atr_stop net=-4274.82 cash=534243.73
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-06-09:
# 2025-10-15 17:24:52 | INFO |   MMTC.NS      rank=6.30 volar=0.88 px=   40.75
# 2025-10-15 17:24:52 | INFO | BUY MMTC.NS      px=   40.07 sh=  3333 fee=182.17 cash=400520.89 :: MACD cross ↑ (hist -0.233→0.126); RSI 24.7→49.6 (<70); MR z -1.06→0.82; Vol 15260725 ≥ 1.5×1704279; 52w%=88.0% (>= 50%); VOLAR rank 1/1 (VOLAR=0.88); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-06-20:
# 2025-10-15 17:24:52 | INFO |   CCL.NS       rank=6.50 volar=-0.16 px=  266.36
# 2025-10-15 17:24:52 | INFO | BUY CCL.NS       px=  261.88 sh=   382 fee=142.38 cash=300341.37 :: MACD cross ↑ (hist -0.304→1.046); RSI 24.6→49.2 (<70); MR z -1.18→0.72; Vol 158731 ≥ 1.5×102523; 52w%=80.9% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.16); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-06-21:
# 2025-10-15 17:24:52 | INFO |   TATAPOWER.NS rank=5.21 volar=-0.45 px=   72.73
# 2025-10-15 17:24:52 | INFO | BUY TATAPOWER.NS px=   72.07 sh=  1041 fee=112.68 cash=225205.69 :: MACD cross ↑ (hist -0.105→0.178); RSI 28.1→54.4 (<70); MR z -1.10→1.50; Vol 10963089 ≥ 1.5×3723747; 52w%=90.9% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.45); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit CCL.NS       px=  258.21 sh=   382 reason=mr_reversal net=-1693.57 cash=323691.64
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-06-22:
# 2025-10-15 17:24:52 | INFO |   JWL.NS       rank=3.22 volar=-0.64 px=   11.91
# 2025-10-15 17:24:52 | INFO | BUY JWL.NS       px=   11.42 sh=  7087 fee=119.68 cash=242658.42 :: MACD cross ↑ (hist -0.038→0.029); RSI 19.4→52.9 (<70); MR z -2.05→0.49; Vol 160094 ≥ 1.5×43657; 52w%=71.1% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.64); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit MMTC.NS      px=   36.41 sh=  3333 reason=trail_atr_stop net=-12531.61 cash=363849.65
# 2025-10-15 17:24:52 | INFO | Selected 3 BUY candidates on 2017-07-07:
# 2025-10-15 17:24:52 | INFO |   INDIANB.NS   rank=6.68 volar=1.34 px=  258.14
# 2025-10-15 17:24:52 | INFO |   PNB.NS       rank=3.18 volar=0.48 px=  133.24
# 2025-10-15 17:24:52 | INFO |   IOB.NS       rank=1.87 volar=-0.84 px=   26.00
# 2025-10-15 17:24:52 | INFO | BUY INDIANB.NS   px=  257.11 sh=   353 fee=131.37 cash=272957.71 :: MACD cross ↑ (hist -1.177→0.356); RSI 27.3→46.6 (<70); MR z -1.32→0.76; Vol 4679332 ≥ 1.5×1143421; 52w%=85.6% (>= 50%); VOLAR rank 1/3 (VOLAR=1.34); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Skip BUY PNB.NS       (alloc 0.00 too small)
# 2025-10-15 17:24:52 | INFO | Skip BUY IOB.NS       (alloc 0.00 too small)
# 2025-10-15 17:24:52 | INFO | Exit JWL.NS       px=   11.66 sh=  7087 reason=trail_atr_stop net=1456.16 cash=355447.09
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-07-27:
# 2025-10-15 17:24:52 | INFO |   SCHNEIDER.NS rank=5.86 volar=-0.74 px=  133.90
# 2025-10-15 17:24:52 | INFO | BUY SCHNEIDER.NS px=  129.80 sh=   684 fee=129.02 cash=266534.86 :: MACD cross ↑ (hist -0.191→0.205); RSI 27.6→51.4 (<70); MR z -1.74→1.60; Vol 1317824 ≥ 1.5×186360; 52w%=79.0% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.74); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit TATAPOWER.NS px=   72.38 sh=  1041 reason=mr_reversal net=83.16 cash=341753.71
# 2025-10-15 17:24:52 | INFO | Exit INDIANB.NS   px=  265.62 sh=   353 reason=mr_reversal net=2728.26 cash=435373.91
# 2025-10-15 17:24:52 | INFO | Exit SCHNEIDER.NS px=  130.50 sh=   684 reason=mr_reversal net=209.98 cash=524496.10
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-08-02:
# 2025-10-15 17:24:52 | INFO |   PETRONET.NS  rank=3.81 volar=0.72 px=  149.72
# 2025-10-15 17:24:52 | INFO | BUY PETRONET.NS  px=  151.65 sh=   864 fee=179.18 cash=393293.51 :: MACD cross ↑ (hist -0.371→0.065); RSI 24.5→42.4 (<70); MR z -1.14→0.28; Vol 7353278 ≥ 1.5×4461773; 52w%=93.9% (>= 50%); VOLAR rank 1/1 (VOLAR=0.72); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit PETRONET.NS  px=  148.55 sh=   864 reason=mr_reversal net=-3035.97 cash=521460.13
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-08-24:
# 2025-10-15 17:24:52 | INFO |   BLS.NS       rank=9.53 volar=1.63 px=   51.24
# 2025-10-15 17:24:52 | INFO | BUY BLS.NS       px=   51.82 sh=  2515 fee=178.34 cash=390965.91 :: MACD cross ↑ (hist -0.210→0.310); RSI 24.9→60.1 (<70); MR z -1.19→2.45; Vol 15978448 ≥ 1.5×3188477; 52w%=98.1% (>= 50%); VOLAR rank 1/1 (VOLAR=1.63); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit BLS.NS       px=   52.90 sh=  2515 reason=target_resistance net=2370.15 cash=523830.28
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-08-29:
# 2025-10-15 17:24:52 | INFO |   CENTRALBK.NS rank=2.31 volar=-1.02 px=   78.31
# 2025-10-15 17:24:52 | INFO | BUY CENTRALBK.NS px=   77.17 sh=  1697 fee=179.10 cash=392695.94 :: MACD cross ↑ (hist -0.561→0.066); RSI 26.9→39.4 (<70); MR z -1.11→-0.11; Vol 5472238 ≥ 1.5×1096765; 52w%=66.4% (>= 50%); VOLAR rank 1/1 (VOLAR=-1.02); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit CENTRALBK.NS px=  101.52 sh=  1697 reason=target_resistance net=40922.73 cash=564753.01
# 2025-10-15 17:24:52 | INFO | Selected 2 BUY candidates on 2017-10-04:
# 2025-10-15 17:24:52 | INFO |   APOLLOHOSP.NS rank=4.38 volar=-1.55 px= 1033.28
# 2025-10-15 17:24:52 | INFO |   NHPC.NS      rank=2.57 volar=0.09 px=   19.28
# 2025-10-15 17:24:52 | INFO | Skip BUY APOLLOHOSP.NS (alloc 0.00 too small)
# 2025-10-15 17:24:52 | INFO | BUY NHPC.NS      px=   18.84 sh=  7493 fee=191.25 cash=423374.77 :: MACD cross ↑ (hist -0.051→0.002); RSI 27.1→37.7 (<70); MR z -1.53→-0.03; Vol 8253911 ≥ 1.5×4699769; 52w%=82.4% (>= 50%); VOLAR rank 2/2 (VOLAR=0.09); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-10-06:
# 2025-10-15 17:24:52 | INFO |   ZENTEC.NS    rank=5.66 volar=-0.68 px=   58.47
# 2025-10-15 17:24:52 | INFO | BUY ZENTEC.NS    px=   57.29 sh=  1847 fee=149.24 cash=317417.13 :: MACD cross ↑ (hist -0.494→0.083); RSI 27.6→56.8 (<70); MR z -1.94→1.84; Vol 870224 ≥ 1.5×165273; 52w%=69.8% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.68); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit ZENTEC.NS    px=   59.92 sh=  1847 reason=target_resistance net=4549.31 cash=427924.08
# 2025-10-15 17:24:52 | INFO | Exit NHPC.NS      px=   18.64 sh=  7493 reason=mr_reversal net=-1904.20 cash=567398.12
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-11-10:
# 2025-10-15 17:24:52 | INFO |   PIDILITIND.NS rank=6.51 volar=-0.14 px=  391.11
# 2025-10-15 17:24:52 | INFO | BUY PIDILITIND.NS px=  394.86 sh=   359 fee=191.92 cash=425451.08 :: MACD cross ↑ (hist -1.152→0.540); RSI 24.7→55.3 (<70); MR z -1.21→1.33; Vol 3690618 ≥ 1.5×1010640; 52w%=94.9% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.14); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-11-30:
# 2025-10-15 17:24:52 | INFO |   BOSCHLTD.NS  rank=110.56 volar=-0.84 px=18405.43
# 2025-10-15 17:24:52 | INFO | BUY BOSCHLTD.NS  px=18531.89 sh=     5 fee=133.62 cash=332658.02 :: MACD cross ↑ (hist -48.521→35.960); RSI 24.8→37.6 (<70); MR z -1.04→0.29; Vol 77162 ≥ 1.5×19583; 52w%=80.1% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.84); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit BOSCHLTD.NS  px=17451.99 sh=     5 reason=trail_atr_stop net=-5670.85 cash=419780.23
# 2025-10-15 17:24:52 | INFO | Exit PIDILITIND.NS px=  399.26 sh=   359 reason=mr_reversal net=1191.85 cash=562919.12
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-12-18:
# 2025-10-15 17:24:52 | INFO |   VEDL.NS      rank=4.37 volar=0.32 px=  107.76
# 2025-10-15 17:24:52 | INFO | BUY VEDL.NS      px=  112.27 sh=  1253 fee=190.64 cash=422051.04 :: MACD cross ↑ (hist -0.036→0.315); RSI 29.8→44.5 (<70); MR z -1.19→0.16; Vol 25896065 ≥ 1.5×8886564; 52w%=86.8% (>= 50%); VOLAR rank 1/1 (VOLAR=0.32); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2017-12-20:
# 2025-10-15 17:24:52 | INFO |   RBLBANK.NS   rank=5.18 volar=0.45 px=  502.75
# 2025-10-15 17:24:52 | INFO | BUY RBLBANK.NS   px=  499.17 sh=   211 fee=148.66 cash=316576.67 :: MACD cross ↑ (hist -0.430→0.179); RSI 28.8→45.9 (<70); MR z -1.22→1.04; Vol 2306811 ≥ 1.5×1098312; 52w%=88.1% (>= 50%); VOLAR rank 1/1 (VOLAR=0.45); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit RBLBANK.NS   px=  491.97 sh=   211 reason=mr_reversal net=-1823.35 cash=420227.69
# 2025-10-15 17:24:52 | INFO | Exit VEDL.NS      px=  118.86 sh=  1253 reason=mr_reversal net=7864.01 cash=568959.78
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-01-31:
# 2025-10-15 17:24:52 | INFO |   BPCL.NS      rank=2.27 volar=-0.59 px=  146.87
# 2025-10-15 17:24:52 | INFO | BUY BPCL.NS      px=  148.78 sh=   956 fee=192.49 cash=426537.05 :: MACD cross ↑ (hist -0.217→0.084); RSI 29.4→43.5 (<70); MR z -1.58→0.04; Vol 13185108 ≥ 1.5×7106209; 52w%=89.5% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.59); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit BPCL.NS      px=  142.04 sh=   956 reason=mr_reversal net=-6823.25 cash=562136.54
# 2025-10-15 17:24:52 | INFO | Selected 2 BUY candidates on 2018-02-26:
# 2025-10-15 17:24:52 | INFO |   CENTRALBK.NS rank=2.93 volar=-0.80 px=   68.51
# 2025-10-15 17:24:52 | INFO |   FEDERALBNK.NS rank=2.72 volar=-0.09 px=   89.25
# 2025-10-15 17:24:52 | INFO | Skip BUY CENTRALBK.NS (alloc 0.00 too small)
# 2025-10-15 17:24:52 | INFO | BUY FEDERALBNK.NS px=   89.86 sh=  1563 fee=190.37 cash=421498.66 :: MACD cross ↑ (hist -0.071→0.183); RSI 27.1→54.1 (<70); MR z -1.70→-0.20; Vol 18729626 ≥ 1.5×9856788; 52w%=74.9% (>= 50%); VOLAR rank 2/2 (VOLAR=-0.09); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-03-13:
# 2025-10-15 17:24:52 | INFO |   JPPOWER.NS   rank=4.27 volar=0.32 px=    6.20
# 2025-10-15 17:24:52 | INFO | BUY JPPOWER.NS   px=    6.80 sh= 15496 fee=148.72 cash=315977.14 :: MACD cross ↑ (hist -0.061→0.006); RSI 27.3→53.3 (<70); MR z -1.97→0.46; Vol 13445481 ≥ 1.5×2846221; 52w%=65.1% (>= 50%); VOLAR rank 1/1 (VOLAR=0.32); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-03-14:
# 2025-10-15 17:24:52 | INFO |   MMTC.NS      rank=2.68 volar=-0.48 px=   33.65
# 2025-10-15 17:24:52 | INFO | BUY MMTC.NS      px=   33.75 sh=  2340 fee=117.37 cash=236886.94 :: MACD cross ↑ (hist -0.075→0.158); RSI 27.1→45.0 (<70); MR z -1.11→-0.05; Vol 3692380 ≥ 1.5×1442696; 52w%=53.6% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.48); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit FEDERALBNK.NS px=   87.39 sh=  1563 reason=mr_reversal net=-4242.12 cash=373282.69
# 2025-10-15 17:24:52 | INFO | Selected 2 BUY candidates on 2018-03-16:
# 2025-10-15 17:24:52 | INFO |   ITI.NS       rank=6.28 volar=1.35 px=  120.50
# 2025-10-15 17:24:52 | INFO |   HINDCOPPER.NS rank=6.14 volar=0.07 px=   70.68
# 2025-10-15 17:24:52 | INFO | BUY ITI.NS       px=  116.70 sh=   799 fee=134.32 cash=279905.07 :: MACD cross ↑ (hist -0.485→0.282); RSI 28.3→44.1 (<70); MR z -1.24→0.80; Vol 3461324 ≥ 1.5×1169190; 52w%=76.6% (>= 50%); VOLAR rank 1/2 (VOLAR=1.35); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Skip BUY HINDCOPPER.NS (alloc 0.00 too small)
# 2025-10-15 17:24:52 | INFO | Exit ITI.NS       px=  117.00 sh=   799 reason=mr_reversal net=-38.80 cash=373243.89
# 2025-10-15 17:24:52 | INFO | Exit JPPOWER.NS   px=    5.64 sh= 15496 reason=trail_atr_stop net=-18264.56 cash=460500.86
# 2025-10-15 17:24:52 | INFO | Exit MMTC.NS      px=   38.48 sh=  2340 reason=trail_atr_stop net=10804.16 cash=550395.22
# 2025-10-15 17:24:52 | INFO | Selected 3 BUY candidates on 2018-03-28:
# 2025-10-15 17:24:52 | INFO |   CGCL.NS      rank=5.88 volar=1.13 px=   84.78
# 2025-10-15 17:24:52 | INFO |   PGEL.NS      rank=4.98 volar=0.88 px=   26.48
# 2025-10-15 17:24:52 | INFO |   JBCHEPHARM.NS rank=2.43 volar=-0.69 px=  138.80
# 2025-10-15 17:24:52 | INFO | BUY CGCL.NS      px=   83.08 sh=   995 fee=121.76 cash=467604.10 :: MACD cross ↑ (hist -0.248→0.436); RSI 16.6→54.4 (<70); MR z -1.73→0.38; Vol 125804 ≥ 1.5×42803; 52w%=66.8% (>= 50%); VOLAR rank 1/3 (VOLAR=1.13); MVO weight=60.1% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | BUY PGEL.NS      px=   31.59 sh=  1736 fee=88.72 cash=412673.81 :: MACD cross ↑ (hist -0.009→0.282); RSI 10.3→48.6 (<70); MR z -1.46→0.19; Vol 6840710 ≥ 1.5×2059416; 52w%=60.4% (>= 50%); VOLAR rank 2/3 (VOLAR=0.88); MVO weight=39.9% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Skip BUY JBCHEPHARM.NS (alloc 0.00 too small)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-04-03:
# 2025-10-15 17:24:52 | INFO |   NAVA.NS      rank=2.65 volar=0.25 px=   60.68
# 2025-10-15 17:24:52 | INFO | BUY NAVA.NS      px=   60.83 sh=  1695 fee=146.04 cash=309414.49 :: MACD cross ↑ (hist -0.156→0.054); RSI 28.2→39.9 (<70); MR z -1.08→-0.17; Vol 716928 ≥ 1.5×426213; 52w%=77.1% (>= 50%); VOLAR rank 1/1 (VOLAR=0.25); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit NAVA.NS      px=   59.23 sh=  1695 reason=mr_reversal net=-3018.62 cash=409655.19
# 2025-10-15 17:24:52 | INFO | Exit PGEL.NS      px=   29.52 sh=  1736 reason=mr_reversal net=-3788.52 cash=460796.97
# 2025-10-15 17:24:52 | INFO | Exit CGCL.NS      px=   89.40 sh=   995 reason=mr_reversal net=6018.62 cash=549606.71
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-05-16:
# 2025-10-15 17:24:52 | INFO |   LALPATHLAB.NS rank=15.05 volar=-0.69 px=  838.91
# 2025-10-15 17:24:52 | INFO | BUY LALPATHLAB.NS px=  843.46 sh=   162 fee=185.85 cash=412780.18 :: MACD cross ↑ (hist -2.119→2.463); RSI 14.4→66.9 (<70); MR z -2.41→2.85; Vol 1136557 ≥ 1.5×92831; 52w%=92.4% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.69); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-05-28:
# 2025-10-15 17:24:52 | INFO |   IFCI.NS      rank=3.12 volar=-0.94 px=   19.05
# 2025-10-15 17:24:52 | INFO | BUY IFCI.NS      px=   18.55 sh=  5563 fee=146.13 cash=309440.40 :: MACD cross ↑ (hist -0.145→0.004); RSI 15.8→42.3 (<70); MR z -1.70→0.27; Vol 54931088 ≥ 1.5×7290980; 52w%=57.9% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.94); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 2 BUY candidates on 2018-05-29:
# 2025-10-15 17:24:52 | INFO |   CANFINHOME.NS rank=10.24 volar=-0.91 px=  382.72
# 2025-10-15 17:24:52 | INFO |   PGEL.NS      rank=5.50 volar=0.75 px=   27.49
# 2025-10-15 17:24:52 | INFO | Skip BUY CANFINHOME.NS (alloc 0.00 too small)
# 2025-10-15 17:24:52 | INFO | BUY PGEL.NS      px=   26.63 sh=  2904 fee=115.44 cash=231978.16 :: MACD cross ↑ (hist -0.211→0.132); RSI 25.2→53.4 (<70); MR z -1.38→1.02; Vol 1021740 ≥ 1.5×367011; 52w%=59.5% (>= 50%); VOLAR rank 2/2 (VOLAR=0.75); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit LALPATHLAB.NS px=  820.04 sh=   162 reason=mr_reversal net=-4164.30 cash=364640.38
# 2025-10-15 17:24:52 | INFO | Exit IFCI.NS      px=   17.01 sh=  5563 reason=trail_atr_stop net=-8876.88 cash=459103.28
# 2025-10-15 17:24:52 | INFO | Exit PGEL.NS      px=   23.07 sh=  2904 reason=trail_atr_stop net=-10597.47 cash=525968.06
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-06-21:
# 2025-10-15 17:24:52 | INFO |   ZENTEC.NS    rank=9.59 volar=1.32 px=  102.37
# 2025-10-15 17:24:52 | INFO | BUY ZENTEC.NS    px=  107.58 sh=  1222 fee=179.71 cash=394319.87 :: MACD cross ↑ (hist -0.252→1.057); RSI 24.8→50.1 (<70); MR z -1.00→0.87; Vol 1973611 ≥ 1.5×222925; 52w%=66.4% (>= 50%); VOLAR rank 1/1 (VOLAR=1.32); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-06-26:
# 2025-10-15 17:24:52 | INFO |   PNBHOUSING.NS rank=27.30 volar=-1.03 px=  966.92
# 2025-10-15 17:24:52 | INFO | BUY PNBHOUSING.NS px=  979.09 sh=   100 fee=139.86 cash=296271.24 :: MACD cross ↑ (hist -0.346→7.353); RSI 29.6→64.2 (<70); MR z -1.41→1.69; Vol 4462811 ≥ 1.5×539255; 52w%=72.4% (>= 50%); VOLAR rank 1/1 (VOLAR=-1.03); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit ZENTEC.NS    px=   90.64 sh=  1222 reason=trail_atr_stop net=-21049.58 cash=406869.84
# 2025-10-15 17:24:52 | INFO | Exit PNBHOUSING.NS px=  890.78 sh=   100 reason=trail_atr_stop net=-9109.91 cash=495808.57
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-07-02:
# 2025-10-15 17:24:52 | INFO |   PETRONET.NS  rank=3.72 volar=-0.16 px=  157.86
# 2025-10-15 17:24:52 | INFO | BUY PETRONET.NS  px=  155.88 sh=   795 fee=170.74 cash=371716.93 :: MACD cross ↑ (hist -0.560→0.046); RSI 26.2→48.9 (<70); MR z -1.62→0.84; Vol 4979351 ≥ 1.5×2980978; 52w%=80.2% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.16); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-07-06:
# 2025-10-15 17:24:52 | INFO |   SAREGAMA.NS  rank=6.62 volar=1.73 px=   65.43
# 2025-10-15 17:24:52 | INFO | BUY SAREGAMA.NS  px=   64.57 sh=  1439 fee=133.92 cash=278673.56 :: MACD cross ↑ (hist -0.439→0.016); RSI 15.6→49.2 (<70); MR z -1.70→0.56; Vol 7773381 ≥ 1.5×694459; 52w%=78.9% (>= 50%); VOLAR rank 1/1 (VOLAR=1.73); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-07-09:
# 2025-10-15 17:24:52 | INFO |   BEL.NS       rank=1.90 volar=-1.28 px=   32.23
# 2025-10-15 17:24:52 | INFO | BUY BEL.NS       px=   31.09 sh=  2241 fee=106.32 cash=208901.85 :: MACD cross ↑ (hist -0.072→0.082); RSI 24.7→45.0 (<70); MR z -1.52→0.02; Vol 53028897 ≥ 1.5×17228878; 52w%=59.2% (>= 50%); VOLAR rank 1/1 (VOLAR=-1.28); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 2 BUY candidates on 2018-07-11:
# 2025-10-15 17:24:52 | INFO |   TRIDENT.NS   rank=5.34 volar=-0.71 px=    5.00
# 2025-10-15 17:24:52 | INFO |   PRAJIND.NS   rank=3.36 volar=0.14 px=   70.33
# 2025-10-15 17:24:52 | INFO | Skip BUY TRIDENT.NS   (alloc 0.00 too small)
# 2025-10-15 17:24:52 | INFO | BUY PRAJIND.NS   px=   71.79 sh=   727 fee=85.57 cash=156626.42 :: MACD cross ↑ (hist -0.336→0.097); RSI 26.1→44.3 (<70); MR z -1.20→-0.00; Vol 1835708 ≥ 1.5×572662; 52w%=62.6% (>= 50%); VOLAR rank 2/2 (VOLAR=0.14); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit BEL.NS       px=   31.45 sh=  2241 reason=mr_reversal net=581.54 cash=226979.68
# 2025-10-15 17:24:52 | INFO | Exit SAREGAMA.NS  px=   64.34 sh=  1439 reason=mr_reversal net=-606.40 cash=319416.64
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-07-13:
# 2025-10-15 17:24:52 | INFO |   SONATSOFTW.NS rank=6.74 volar=1.78 px=   95.14
# 2025-10-15 17:24:52 | INFO | BUY SONATSOFTW.NS px=  102.15 sh=   781 fee=118.33 cash=239518.84 :: MACD cross ↑ (hist -0.810→0.046); RSI 22.6→49.8 (<70); MR z -1.79→0.73; Vol 5816159 ≥ 1.5×706421; 52w%=84.5% (>= 50%); VOLAR rank 1/1 (VOLAR=1.78); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit PETRONET.NS  px=  148.95 sh=   795 reason=trail_atr_stop net=-5849.77 cash=357760.70
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-07-24:
# 2025-10-15 17:24:52 | INFO |   UPL.NS       rank=7.27 volar=-1.11 px=  389.87
# 2025-10-15 17:24:52 | INFO | BUY UPL.NS       px=  386.92 sh=   231 fee=129.73 cash=268252.58 :: MACD cross ↑ (hist -2.515→1.123); RSI 23.2→50.4 (<70); MR z -1.68→0.97; Vol 35708673 ≥ 1.5×5283421; 52w%=70.7% (>= 50%); VOLAR rank 1/1 (VOLAR=-1.11); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-07-25:
# 2025-10-15 17:24:52 | INFO |   GRASIM.NS    rank=11.07 volar=-0.49 px=  943.69
# 2025-10-15 17:24:52 | INFO | BUY GRASIM.NS    px=  937.32 sh=    71 fee=102.62 cash=201599.94 :: MACD cross ↑ (hist -2.543→2.344); RSI 29.9→57.8 (<70); MR z -1.55→1.03; Vol 3291693 ≥ 1.5×963995; 52w%=77.3% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.49); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-07-26:
# 2025-10-15 17:24:52 | INFO |   NAVINFLUOR.NS rank=15.88 volar=-0.08 px=  648.68
# 2025-10-15 17:24:52 | INFO | BUY NAVINFLUOR.NS px=  625.94 sh=    80 fee=83.06 cash=151441.91 :: MACD cross ↑ (hist -1.742→2.677); RSI 26.4→65.9 (<70); MR z -2.21→2.60; Vol 1263423 ≥ 1.5×109955; 52w%=78.5% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.08); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit SONATSOFTW.NS px=   98.90 sh=   781 reason=mr_reversal net=-2781.92 cash=228557.79
# 2025-10-15 17:24:52 | INFO | Exit GRASIM.NS    px=  921.16 sh=    71 reason=mr_reversal net=-1365.31 cash=293845.12
# 2025-10-15 17:24:52 | INFO | Exit UPL.NS       px=  380.25 sh=   231 reason=mr_reversal net=-1808.81 cash=381544.44
# 2025-10-15 17:24:52 | INFO | Exit PRAJIND.NS   px=   71.70 sh=   727 reason=mr_reversal net=-252.04 cash=433567.83
# 2025-10-15 17:24:52 | INFO | Exit NAVINFLUOR.NS px=  644.35 sh=    80 reason=mr_reversal net=1289.07 cash=485014.93
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-08-21:
# 2025-10-15 17:24:52 | INFO |   LT.NS        rank=10.12 volar=0.24 px= 1199.49
# 2025-10-15 17:24:52 | INFO | BUY LT.NS        px= 1188.30 sh=   102 fee=167.52 cash=363640.52 :: MACD cross ↑ (hist -3.827→1.154); RSI 28.2→61.5 (<70); MR z -1.58→2.17; Vol 11227838 ≥ 1.5×2615921; 52w%=92.1% (>= 50%); VOLAR rank 1/1 (VOLAR=0.24); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit LT.NS        px= 1214.04 sh=   102 reason=target_resistance net=2282.17 cash=487297.10
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-09-11:
# 2025-10-15 17:24:52 | INFO |   ECLERX.NS    rank=9.91 volar=-0.75 px=  723.65
# 2025-10-15 17:24:52 | INFO | BUY ECLERX.NS    px=  727.50 sh=   167 fee=167.86 cash=365636.81 :: MACD cross ↑ (hist -0.280→2.394); RSI 23.4→40.7 (<70); MR z -1.00→-0.10; Vol 643930 ≥ 1.5×86888; 52w%=68.7% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.75); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit ECLERX.NS    px=  721.46 sh=   167 reason=trail_atr_stop net=-1348.18 cash=485948.92
# 2025-10-15 17:24:52 | INFO | Selected 2 BUY candidates on 2018-10-11:
# 2025-10-15 17:24:52 | INFO |   ZEEL.NS      rank=8.08 volar=-0.32 px=  419.59
# 2025-10-15 17:24:52 | INFO |   ADANIPOWER.NS rank=4.49 volar=0.29 px=    5.60
# 2025-10-15 17:24:52 | INFO | Skip BUY ZEEL.NS      (alloc 0.00 too small)
# 2025-10-15 17:24:52 | INFO | BUY ADANIPOWER.NS px=    6.00 sh= 20247 fee=167.85 cash=364299.07 :: MACD cross ↑ (hist -0.075→0.020); RSI 27.4→51.1 (<70); MR z -1.08→1.07; Vol 209658645 ≥ 1.5×116340514; 52w%=63.9% (>= 50%); VOLAR rank 2/2 (VOLAR=0.29); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-10-15:
# 2025-10-15 17:24:52 | INFO |   DMART.NS     rank=11.72 volar=0.68 px= 1334.80
# 2025-10-15 17:24:52 | INFO | BUY DMART.NS     px= 1329.75 sh=    68 fee=130.97 cash=273745.10 :: MACD cross ↑ (hist -3.669→2.888); RSI 27.4→40.8 (<70); MR z -1.19→-0.07; Vol 899147 ≥ 1.5×534450; 52w%=84.5% (>= 50%); VOLAR rank 1/1 (VOLAR=0.68); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit ADANIPOWER.NS px=    7.22 sh= 20247 reason=target_resistance net=24334.64 cash=419729.59
# 2025-10-15 17:24:52 | INFO | Exit DMART.NS     px= 1175.81 sh=    68 reason=trail_atr_stop net=-10729.36 cash=499554.20
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-10-25:
# 2025-10-15 17:24:52 | INFO |   FINPIPE.NS   rank=2.68 volar=-0.87 px=   87.84
# 2025-10-15 17:24:52 | INFO | BUY FINPIPE.NS   px=   93.63 sh=  1333 fee=171.80 cash=374575.66 :: MACD cross ↑ (hist -0.229→0.220); RSI 27.2→43.3 (<70); MR z -1.23→0.17; Vol 1082490 ≥ 1.5×511176; 52w%=70.2% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.87); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-10-31:
# 2025-10-15 17:24:52 | INFO |   RAMCOCEM.NS  rank=9.22 volar=-0.39 px=  587.05
# 2025-10-15 17:24:52 | INFO | BUY RAMCOCEM.NS  px=  586.71 sh=   159 fee=134.37 cash=281154.46 :: MACD cross ↑ (hist -0.995→1.956); RSI 23.1→49.8 (<70); MR z -1.06→0.31; Vol 1522098 ≥ 1.5×309411; 52w%=70.2% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.39); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit FINPIPE.NS   px=   91.90 sh=  1333 reason=mr_reversal net=-2651.83 cash=403481.17
# 2025-10-15 17:24:52 | INFO | Exit RAMCOCEM.NS  px=  581.67 sh=   159 reason=mr_reversal net=-1078.71 cash=495823.65
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-11-27:
# 2025-10-15 17:24:52 | INFO |   COCHINSHIP.NS rank=2.92 volar=-1.50 px=  156.01
# 2025-10-15 17:24:52 | INFO | BUY COCHINSHIP.NS px=  154.03 sh=   804 fee=170.65 cash=371814.51 :: MACD cross ↑ (hist -0.023→0.191); RSI 22.1→46.5 (<70); MR z -1.71→0.86; Vol 513148 ≥ 1.5×273278; 52w%=69.0% (>= 50%); VOLAR rank 1/1 (VOLAR=-1.50); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit COCHINSHIP.NS px=  152.77 sh=   804 reason=mr_reversal net=-1358.36 cash=494465.30
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-11-29:
# 2025-10-15 17:24:52 | INFO |   PRESTIGE.NS  rank=3.28 volar=-0.79 px=  178.44
# 2025-10-15 17:24:52 | INFO | BUY PRESTIGE.NS  px=  193.41 sh=   639 fee=170.35 cash=370704.38 :: MACD cross ↑ (hist -0.227→0.496); RSI 24.2→43.0 (<70); MR z -1.11→0.02; Vol 391020 ≥ 1.5×209471; 52w%=53.4% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.79); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit PRESTIGE.NS  px=  187.47 sh=   639 reason=trail_atr_stop net=-4138.98 cash=490326.31
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2018-12-20:
# 2025-10-15 17:24:52 | INFO |   TTML.NS      rank=4.82 volar=-0.97 px=    4.02
# 2025-10-15 17:24:52 | INFO | BUY TTML.NS      px=    4.16 sh= 29450 fee=169.15 cash=367577.15 :: MACD cross ↑ (hist -0.010→0.010); RSI 28.6→55.6 (<70); MR z -1.14→1.39; Vol 8721486 ≥ 1.5×1116437; 52w%=52.9% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.97); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit TTML.NS      px=    3.83 sh= 29450 reason=mr_reversal net=-10196.07 cash=480130.24
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2019-01-09:
# 2025-10-15 17:24:52 | INFO |   SONATSOFTW.NS rank=4.03 volar=0.55 px=   96.42
# 2025-10-15 17:24:52 | INFO | BUY SONATSOFTW.NS px=   94.90 sh=  1264 fee=166.03 cash=360010.53 :: MACD cross ↑ (hist -0.231→0.048); RSI 19.3→46.1 (<70); MR z -1.28→0.34; Vol 699109 ≥ 1.5×252977; 52w%=75.7% (>= 50%); VOLAR rank 1/1 (VOLAR=0.55); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit SONATSOFTW.NS px=  107.00 sh=  1264 reason=target_resistance net=14940.46 cash=495070.71
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2019-02-01:
# 2025-10-15 17:24:52 | INFO |   INDHOTEL.NS  rank=4.70 volar=0.25 px=  134.79
# 2025-10-15 17:24:52 | INFO | BUY INDHOTEL.NS  px=  136.21 sh=   908 fee=170.46 cash=371218.20 :: MACD cross ↑ (hist -0.538→0.030); RSI 28.7→52.8 (<70); MR z -1.61→1.06; Vol 2610989 ≥ 1.5×1024903; 52w%=93.4% (>= 50%); VOLAR rank 1/1 (VOLAR=0.25); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2019-02-07:
# 2025-10-15 17:24:52 | INFO |   NAM-INDIA.NS rank=8.04 volar=-1.19 px=  133.00
# 2025-10-15 17:24:52 | INFO | BUY NAM-INDIA.NS px=  128.60 sh=   721 fee=133.70 cash=278363.27 :: MACD cross ↑ (hist -0.625→0.896); RSI 29.3→58.9 (<70); MR z -1.09→1.98; Vol 2018296 ≥ 1.5×291579; 52w%=57.9% (>= 50%); VOLAR rank 1/1 (VOLAR=-1.19); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit INDHOTEL.NS  px=  129.86 sh=   908 reason=mr_reversal net=-6104.64 cash=396111.14
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2019-02-14:
# 2025-10-15 17:24:52 | INFO |   NCC.NS       rank=3.40 volar=-0.18 px=   74.92
# 2025-10-15 17:24:52 | INFO | BUY NCC.NS       px=   78.59 sh=  1260 fee=141.18 cash=296947.62 :: MACD cross ↑ (hist -0.308→0.046); RSI 27.0→45.5 (<70); MR z -1.01→0.33; Vol 24202434 ≥ 1.5×7406258; 52w%=62.7% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.18); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2019-02-15:
# 2025-10-15 17:24:52 | INFO |   MMTC.NS      rank=4.11 volar=-0.25 px=   27.27
# 2025-10-15 17:24:52 | INFO | BUY MMTC.NS      px=   25.94 sh=  2861 fee=111.72 cash=222623.41 :: MACD cross ↑ (hist -0.211→0.037); RSI 15.5→48.8 (<70); MR z -1.35→0.79; Vol 2251239 ≥ 1.5×599506; 52w%=60.9% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.25); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Exit MMTC.NS      px=   25.99 sh=  2861 reason=mr_reversal net=-95.24 cash=296852.38
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2019-02-19:
# 2025-10-15 17:24:52 | INFO |   PRESTIGE.NS  rank=2.95 volar=-0.47 px=  202.53
# 2025-10-15 17:24:52 | INFO | BUY PRESTIGE.NS  px=  206.53 sh=   359 fee=111.64 cash=222597.32 :: MACD cross ↑ (hist -0.569→0.092); RSI 20.8→52.3 (<70); MR z -1.55→0.44; Vol 474891 ≥ 1.5×283814; 52w%=61.5% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.47); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:52 | INFO | Selected 1 BUY candidates on 2019-02-21:
# 2025-10-15 17:24:52 | INFO |   USHAMART.NS  rank=6.24 volar=0.95 px=   31.24
# ...
# 2025-10-15 17:24:53 | INFO | Selected 2 BUY candidates on 2025-01-03:
# 2025-10-15 17:24:53 | INFO |   CHOLAHLDNG.NS rank=23.85 volar=0.91 px= 1498.97
# 2025-10-15 17:24:53 | INFO |   CHOLAFIN.NS  rank=9.16 volar=-0.09 px= 1277.22
# 2025-10-15 17:24:53 | INFO | BUY CHOLAHLDNG.NS px= 1551.68 sh=    34 fee=86.24 cash=163024.79 :: MACD cross ↑ (hist -1.184→6.566); RSI 29.6→46.0 (<70); MR z -1.32→0.52; Vol 396478 ≥ 1.5×248732; 52w%=71.7% (>= 50%); VOLAR rank 1/2 (VOLAR=0.91); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Skip BUY CHOLAFIN.NS  (alloc 0.00 too small)
# 2025-10-15 17:24:53 | INFO | Exit ITC.NS       px=  452.29 sh=   194 reason=trail_atr_stop net=-679.26 cash=250631.73
# 2025-10-15 17:24:53 | INFO | Exit ATGL.NS      px=  707.59 sh=   125 reason=mr_reversal net=-6923.00 cash=338941.14
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-01-08:
# 2025-10-15 17:24:53 | INFO |   INDIAMART.NS rank=8.74 volar=-0.76 px= 2253.81
# 2025-10-15 17:24:53 | INFO | BUY INDIAMART.NS px= 2252.48 sh=    37 fee=122.56 cash=255476.69 :: MACD cross ↑ (hist -2.336→2.280); RSI 25.2→42.8 (<70); MR z -2.00→-0.13; Vol 671612 ≥ 1.5×234239; 52w%=72.8% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.76); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-01-09:
# 2025-10-15 17:24:53 | INFO |   MMTC.NS      rank=5.20 volar=0.28 px=   76.22
# 2025-10-15 17:24:53 | INFO | BUY MMTC.NS      px=   74.46 sh=   857 fee=99.37 cash=191565.10 :: MACD cross ↑ (hist -0.296→0.065); RSI 28.6→48.7 (<70); MR z -1.23→0.40; Vol 50812526 ≥ 1.5×3969570; 52w%=63.0% (>= 50%); VOLAR rank 1/1 (VOLAR=0.28); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-01-10:
# 2025-10-15 17:24:53 | INFO |   ALKYLAMINE.NS rank=10.77 volar=-1.65 px= 1795.65
# 2025-10-15 17:24:53 | INFO | BUY ALKYLAMINE.NS px= 1760.26 sh=    27 fee=80.03 cash=143958.02 :: MACD cross ↑ (hist -7.697→2.592); RSI 26.9→44.5 (<70); MR z -1.28→0.25; Vol 2355843 ≥ 1.5×157060; 52w%=69.8% (>= 50%); VOLAR rank 1/1 (VOLAR=-1.65); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Exit MMTC.NS      px=   68.21 sh=   857 reason=trail_atr_stop net=-5561.22 cash=202308.39
# 2025-10-15 17:24:53 | INFO | Exit MRPL.NS      px=  136.56 sh=   482 reason=trail_atr_stop net=-6350.22 cash=268015.34
# 2025-10-15 17:24:53 | INFO | Exit CHOLAHLDNG.NS px= 1483.53 sh=    34 reason=mr_reversal net=-2502.97 cash=318355.75
# 2025-10-15 17:24:53 | INFO | Exit INDIAMART.NS px= 2199.30 sh=    37 reason=mr_reversal net=-2222.07 cash=399598.13
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-01-17:
# 2025-10-15 17:24:53 | INFO |   HDFCLIFE.NS  rank=14.58 volar=-0.29 px=  638.24
# 2025-10-15 17:24:53 | INFO | BUY HDFCLIFE.NS  px=  640.43 sh=   155 fee=141.47 cash=300190.04 :: MACD cross ↑ (hist -0.173→2.628); RSI 28.0→58.4 (<70); MR z -2.39→2.34; Vol 24198675 ≥ 1.5×3849340; 52w%=84.5% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.29); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-01-23:
# 2025-10-15 17:24:53 | INFO |   ELGIEQUIP.NS rank=5.70 volar=0.10 px=  539.25
# 2025-10-15 17:24:53 | INFO | BUY ELGIEQUIP.NS px=  546.12 sh=   137 fee=112.44 cash=225259.01 :: MACD cross ↑ (hist -1.575→0.624); RSI 28.9→43.8 (<70); MR z -1.46→-0.01; Vol 1672223 ≥ 1.5×198888; 52w%=72.9% (>= 50%); VOLAR rank 1/1 (VOLAR=0.10); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Exit ALKYLAMINE.NS px= 1638.06 sh=    27 reason=trail_atr_stop net=-3472.65 cash=269393.45
# 2025-10-15 17:24:53 | INFO | Exit HDFCLIFE.NS  px=  609.27 sh=   155 reason=mr_reversal net=-5117.04 cash=363684.50
# 2025-10-15 17:24:53 | INFO | Selected 2 BUY candidates on 2025-01-30:
# 2025-10-15 17:24:53 | INFO |   LINDEINDIA.NS rank=74.37 volar=0.14 px= 6278.32
# 2025-10-15 17:24:53 | INFO |   KPITTECH.NS  rank=5.23 volar=-0.19 px= 1410.56
# 2025-10-15 17:24:53 | INFO | BUY LINDEINDIA.NS px= 6186.69 sh=    14 fee=126.45 cash=276944.35 :: MACD cross ↑ (hist -18.922→23.374); RSI 21.5→45.9 (<70); MR z -1.44→0.66; Vol 393613 ≥ 1.5×97473; 52w%=65.0% (>= 50%); VOLAR rank 1/2 (VOLAR=0.14); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Skip BUY KPITTECH.NS  (alloc 0.00 too small)
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-02-06:
# 2025-10-15 17:24:53 | INFO |   NAM-INDIA.NS rank=6.30 volar=0.30 px=  622.16
# 2025-10-15 17:24:53 | INFO | BUY NAM-INDIA.NS px=  597.67 sh=   115 fee=105.21 cash=208107.38 :: MACD cross ↑ (hist -3.747→1.037); RSI 21.6→37.7 (<70); MR z -1.04→0.15; Vol 2756675 ≥ 1.5×1235882; 52w%=78.2% (>= 50%); VOLAR rank 1/1 (VOLAR=0.30); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Exit LINDEINDIA.NS px= 6004.73 sh=    14 reason=mr_reversal net=-2808.32 cash=292039.21
# 2025-10-15 17:24:53 | INFO | Exit NAM-INDIA.NS px=  547.54 sh=   115 reason=trail_atr_stop net=-5982.90 cash=354893.28
# 2025-10-15 17:24:53 | INFO | Exit ELGIEQUIP.NS px=  527.89 sh=   137 reason=mr_reversal net=-2731.80 cash=427092.51
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-02-14:
# 2025-10-15 17:24:53 | INFO |   FINCABLES.NS rank=9.32 volar=-0.10 px=  980.81
# 2025-10-15 17:24:53 | INFO | BUY FINCABLES.NS px=  925.73 sh=   115 fee=150.01 cash=320484.07 :: MACD cross ↑ (hist -3.683→1.561); RSI 23.4→47.6 (<70); MR z -3.08→0.32; Vol 7843749 ≥ 1.5×529112; 52w%=60.3% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.10); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Exit FINCABLES.NS px=  861.09 sh=   115 reason=trail_atr_stop net=-7733.05 cash=419359.46
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-02-27:
# 2025-10-15 17:24:53 | INFO |   SUNTV.NS     rank=5.88 volar=-0.06 px=  592.21
# 2025-10-15 17:24:53 | INFO | BUY SUNTV.NS     px=  573.56 sh=   182 fee=147.55 cash=314824.45 :: MACD cross ↑ (hist -0.986→1.117); RSI 23.2→35.8 (<70); MR z -1.21→-0.08; Vol 1245059 ≥ 1.5×530609; 52w%=66.9% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.06); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Exit SUNTV.NS     px=  547.85 sh=   182 reason=trail_atr_stop net=-4977.13 cash=414382.33
# 2025-10-15 17:24:53 | INFO | Selected 4 BUY candidates on 2025-03-06:
# 2025-10-15 17:24:53 | INFO |   COFORGE.NS   rank=8.97 volar=0.65 px= 1563.22
# 2025-10-15 17:24:53 | INFO |   ATGL.NS      rank=6.29 volar=-0.85 px=  589.03
# 2025-10-15 17:24:53 | INFO |   ADANIENSOL.NS rank=5.25 volar=-0.54 px=  719.00
# 2025-10-15 17:24:53 | INFO |   GSPL.NS      rank=5.21 volar=-0.37 px=  283.94
# 2025-10-15 17:24:53 | INFO | BUY COFORGE.NS   px= 1517.82 sh=    68 fee=146.15 cash=311024.74 :: MACD cross ↑ (hist -6.320→1.682); RSI 17.9→45.0 (<70); MR z -1.58→-0.05; Vol 16970990 ≥ 1.5×3184945; 52w%=79.8% (>= 50%); VOLAR rank 1/4 (VOLAR=0.65); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Skip BUY ATGL.NS      (alloc 0.00 too small)
# 2025-10-15 17:24:53 | INFO | Skip BUY ADANIENSOL.NS (alloc 0.00 too small)
# 2025-10-15 17:24:53 | INFO | Skip BUY GSPL.NS      (alloc 0.00 too small)
# 2025-10-15 17:24:53 | INFO | Selected 2 BUY candidates on 2025-03-20:
# 2025-10-15 17:24:53 | INFO |   OLECTRA.NS   rank=22.71 volar=-0.76 px= 1139.73
# 2025-10-15 17:24:53 | INFO |   TRIDENT.NS   rank=2.02 volar=-1.08 px=   26.15
# 2025-10-15 17:24:53 | INFO | BUY OLECTRA.NS   px= 1125.28 sh=    69 fee=115.80 cash=233264.66 :: MACD cross ↑ (hist -0.835→6.657); RSI 27.4→46.4 (<70); MR z -1.56→0.40; Vol 1648978 ≥ 1.5×534398; 52w%=58.6% (>= 50%); VOLAR rank 1/2 (VOLAR=-0.76); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Skip BUY TRIDENT.NS   (alloc 0.00 too small)
# 2025-10-15 17:24:53 | INFO | Exit COFORGE.NS   px= 1475.35 sh=    68 reason=trail_atr_stop net=-3185.35 cash=333436.89
# 2025-10-15 17:24:53 | INFO | Exit OLECTRA.NS   px= 1101.73 sh=    69 reason=trail_atr_stop net=-1867.04 cash=409329.94
# 2025-10-15 17:24:53 | INFO | Selected 2 BUY candidates on 2025-06-10:
# 2025-10-15 17:24:53 | INFO |   CGCL.NS      rank=11.89 volar=-0.39 px=  176.81
# 2025-10-15 17:24:53 | INFO |   HAPPSTMNDS.NS rank=6.75 volar=-1.04 px=  615.49
# 2025-10-15 17:24:53 | INFO | BUY CGCL.NS      px=  178.79 sh=   572 fee=145.03 cash=306917.26 :: MACD cross ↑ (hist -0.722→1.290); RSI 19.2→69.8 (<70); MR z -1.21→2.80; Vol 94314540 ≥ 1.5×6710986; 52w%=80.1% (>= 50%); VOLAR rank 1/2 (VOLAR=-0.39); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Skip BUY HAPPSTMNDS.NS (alloc 0.00 too small)
# 2025-10-15 17:24:53 | INFO | Exit CGCL.NS      px=  168.52 sh=   572 reason=mr_reversal net=-6166.13 cash=403163.80
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-07-03:
# 2025-10-15 17:24:53 | INFO |   MANKIND.NS   rank=21.91 volar=0.26 px= 2383.86
# 2025-10-15 17:24:53 | INFO | BUY MANKIND.NS   px= 2360.77 sh=    42 fee=141.33 cash=303870.16 :: MACD cross ↑ (hist -0.383→5.582); RSI 29.5→49.1 (<70); MR z -1.66→1.29; Vol 1642680 ≥ 1.5×489684; 52w%=79.5% (>= 50%); VOLAR rank 1/1 (VOLAR=0.26); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Exit MANKIND.NS   px= 2641.16 sh=    42 reason=target_resistance net=11472.75 cash=414636.55
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-07-18:
# 2025-10-15 17:24:53 | INFO |   SONACOMS.NS  rank=9.73 volar=-0.97 px=  486.00
# 2025-10-15 17:24:53 | INFO | BUY SONACOMS.NS  px=  479.75 sh=   216 fee=146.65 cash=310863.90 :: MACD cross ↑ (hist -0.785→1.662); RSI 27.7→55.0 (<70); MR z -1.23→1.34; Vol 34339361 ≥ 1.5×4265418; 52w%=65.2% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.97); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-07-25:
# 2025-10-15 17:24:53 | INFO |   GRAVITA.NS   rank=11.25 volar=0.43 px= 1821.00
# 2025-10-15 17:24:53 | INFO | BUY GRAVITA.NS   px= 1886.60 sh=    41 fee=115.45 cash=233397.86 :: MACD cross ↑ (hist -4.674→2.271); RSI 15.4→41.6 (<70); MR z -1.01→0.45; Vol 1332132 ≥ 1.5×252470; 52w%=68.3% (>= 50%); VOLAR rank 1/1 (VOLAR=0.43); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Exit SONACOMS.NS  px=  469.05 sh=   216 reason=mr_reversal net=-2610.15 cash=334560.35
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-07-31:
# 2025-10-15 17:24:53 | INFO |   NIACL.NS     rank=10.16 volar=-0.51 px=  198.19
# 2025-10-15 17:24:53 | INFO | BUY NIACL.NS     px=  197.98 sh=   422 fee=122.81 cash=250889.11 :: MACD cross ↑ (hist -1.415→0.443); RSI 17.1→66.9 (<70); MR z -2.64→3.24; Vol 82688432 ≥ 1.5×4461457; 52w%=70.3% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.51); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Exit GRAVITA.NS   px= 1784.40 sh=    41 reason=mr_reversal net=-4428.74 cash=323926.42
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-08-06:
# 2025-10-15 17:24:53 | INFO |   NEWGEN.NS    rank=10.24 volar=0.11 px=  942.05
# 2025-10-15 17:24:53 | INFO | BUY NEWGEN.NS    px=  932.15 sh=    86 fee=118.79 cash=243642.73 :: MACD cross ↑ (hist -7.759→2.033); RSI 11.2→32.2 (<70); MR z -1.11→-0.06; Vol 19081968 ≥ 1.5×1480625; 52w%=53.9% (>= 50%); VOLAR rank 1/1 (VOLAR=0.11); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Exit NIACL.NS     px=  184.28 sh=   422 reason=mr_reversal net=-6034.42 cash=321279.55
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-08-14:
# 2025-10-15 17:24:53 | INFO |   NSLNISP.NS   rank=8.95 volar=-0.50 px=   44.25
# 2025-10-15 17:24:53 | INFO | BUY NSLNISP.NS   px=   40.08 sh=  2003 fee=118.93 cash=240880.38 :: MACD cross ↑ (hist -0.181→0.316); RSI 20.0→64.7 (<70); MR z -1.22→2.81; Vol 96740093 ≥ 1.5×6309824; 52w%=77.4% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.50); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Exit NSLNISP.NS   px=   40.81 sh=  2003 reason=trail_atr_stop net=1209.13 cash=322488.68
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-08-19:
# 2025-10-15 17:24:53 | INFO |   BAJFINANCE.NS rank=4.30 volar=1.21 px=  905.95
# 2025-10-15 17:24:53 | INFO | BUY BAJFINANCE.NS px=  902.30 sh=    89 fee=118.95 cash=242065.02 :: MACD cross ↑ (hist -3.423→0.024); RSI 28.2→59.5 (<70); MR z -1.04→0.28; Vol 16277779 ≥ 1.5×8032507; 52w%=93.5% (>= 50%); VOLAR rank 1/1 (VOLAR=1.21); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-08-20:
# 2025-10-15 17:24:53 | INFO |   DEVYANI.NS   rank=4.78 volar=-0.08 px=  166.26
# 2025-10-15 17:24:53 | INFO | BUY DEVYANI.NS   px=  169.65 sh=   356 fee=95.31 cash=181574.31 :: MACD cross ↑ (hist -0.819→0.117); RSI 26.4→50.2 (<70); MR z -1.11→0.51; Vol 25600957 ≥ 1.5×3015995; 52w%=75.4% (>= 50%); VOLAR rank 1/1 (VOLAR=-0.08); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-08-21:
# 2025-10-15 17:24:53 | INFO |   INTELLECT.NS rank=4.46 volar=0.12 px=  988.40
# 2025-10-15 17:24:53 | INFO | BUY INTELLECT.NS px=  960.70 sh=    47 fee=77.21 cash=136344.20 :: MACD cross ↑ (hist -5.919→0.429); RSI 25.1→39.2 (<70); MR z -1.16→-0.09; Vol 2334053 ≥ 1.5×528025; 52w%=80.9% (>= 50%); VOLAR rank 1/1 (VOLAR=0.12); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Exit BAJFINANCE.NS px=  870.20 sh=    89 reason=mr_reversal net=-3103.40 cash=213664.45
# 2025-10-15 17:24:53 | INFO | Selected 1 BUY candidates on 2025-09-03:
# 2025-10-15 17:24:53 | INFO |   ITI.NS       rank=5.47 volar=0.45 px=  303.40
# 2025-10-15 17:24:53 | INFO | BUY ITI.NS       px=  315.25 sh=   169 fee=86.86 cash=160300.34 :: MACD cross ↑ (hist -0.928→0.274); RSI 24.8→51.0 (<70); MR z -1.25→0.73; Vol 5079876 ≥ 1.5×1278681; 52w%=55.5% (>= 50%); VOLAR rank 1/1 (VOLAR=0.45); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Exit DEVYANI.NS   px=  181.00 sh=   356 reason=target_resistance net=3831.24 cash=224622.29
# 2025-10-15 17:24:53 | INFO | Exit INTELLECT.NS px=  957.80 sh=    47 reason=mr_reversal net=-307.42 cash=269544.99
# 2025-10-15 17:24:53 | INFO | Exit NEWGEN.NS    px=  880.00 sh=    86 reason=mr_reversal net=-4729.40 cash=345099.28
# 2025-10-15 17:24:53 | INFO | Selected 3 BUY candidates on 2025-09-11:
# 2025-10-15 17:24:53 | INFO |   HSCL.NS      rank=6.76 volar=-0.03 px=  474.90
# 2025-10-15 17:24:53 | INFO |   UNIONBANK.NS rank=4.29 volar=0.59 px=  132.95
# 2025-10-15 17:24:53 | INFO |   MAHABANK.NS  rank=3.31 volar=0.03 px=   54.20
# 2025-10-15 17:24:53 | INFO | Skip BUY HSCL.NS      (alloc 0.00 too small)
# 2025-10-15 17:24:53 | INFO | BUY UNIONBANK.NS px=  133.72 sh=   645 fee=126.01 cash=258723.87 :: MACD cross ↑ (hist -0.197→0.211); RSI 25.5→41.4 (<70); MR z -1.03→0.26; Vol 17944307 ≥ 1.5×8029592; 52w%=88.2% (>= 50%); VOLAR rank 2/3 (VOLAR=0.59); MVO weight=100.0% of capped cash (25% of available)
# 2025-10-15 17:24:53 | INFO | Skip BUY MAHABANK.NS  (alloc 0.00 too small)
# 2025-10-15 17:24:53 | INFO | Exit ITI.NS       px=  309.90 sh=   169 reason=mr_reversal net=-1092.54 cash=310995.44
# 2025-10-15 17:24:53 | INFO | Exit UNIONBANK.NS px=  138.51 sh=   645 reason=final_close net=2823.65 cash=400194.50
# 2025-10-15 17:24:54 | INFO | === METRICS ===
# {
#   "start_equity_inr": 500000.0,
#   "final_equity_inr": 400194.5014028625,
#   "cagr_pct": -2.274957878748274,
#   "sharpe": -0.48161983202786923,
#   "max_drawdown_pct": -35.562110263445035,
#   "win_rate_pct": 31.330472103004293,
#   "n_trades": 233
# }
# 2025-10-15 17:24:54 | INFO | Files written:
#   outputs/trades_legs_20251015_172453.csv
#   outputs/trades_roundtrips_20251015_172453.csv
#   outputs/equity_20251015_172453.csv
#   outputs/metrics_20251015_172453.json
# 2025-10-15 17:24:54 | INFO |   outputs/equity_20251015_172453.png
