# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import os, json, math, warnings, logging
from dataclasses import dataclass
from typing import Dict, List, Tuple, Optional

import numpy as np
import pandas as pd

try:
    import yfinance as yf
    import matplotlib.pyplot as plt
except Exception:
    pass

warnings.filterwarnings("ignore", category=FutureWarning)

# =========================
# LOGGING
# =========================
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)
log = logging.getLogger("candle_confirm_mvo_v2_toggles")

# =========================
# CONFIG
# =========================
@dataclass
class Config:
    # Data
    start_date: str = "2015-01-01"
    end_date: str   = "2025-01-01"
    static_symbols: Optional[List[str]] = None
    static_symbols_path: Optional[str] = None
    cache_dir: str = "cache"
    out_dir: str   = "outputs"
    plot: bool     = True

    # ===== Toggles (everything except candlestick pattern) =====
    # Trend filters
    use_trend_fast_slow: bool = False     # require EMA(fast) > EMA(slow)
    use_htf_trend: bool       = False     # require Close > EMA200

    # Confirmations
    use_rsi_confirm: bool   = True       # RSI > 50
    use_macd_confirm: bool  = False       # MACD line > signal
    use_adx_confirm: bool   = False       # ADX>20 and +DI > -DI
    use_sma50_confirm: bool = False      # Close > SMA50
    use_bbmid_confirm: bool = False      # Close > BB mid (SMA20)

    # Liquidity
    use_basic_liquidity: bool = False
    min_price_inr: float = 50.0
    min_avg_vol_20d: float = 50_000.0

    # Portfolio construction toggles
    use_52w_filter: bool     = True      # keep only those within % of 52w high
    use_volar_ranking: bool  = True      # rank by VOLAᵣ
    use_mvo_sizing: bool     = True      # Markowitz sizing (else equal-weight)

    # Trend params
    ema_fast: int = 10
    ema_slow: int = 20
    ema_htf:  int = 200  # long-term trend

    # Exits
    stop_loss_pct: float = 0.05
    target_pct: float    = 0.10

    # Portfolio caps
    apply_fees: bool    = True
    initial_capital: float = 500_000.0
    max_concurrent_positions: int = 5
    deploy_cash_frac: float = 0.25
    top_k_daily: int = 300

    # Ranking & filters
    benchmark_try: Tuple[str,...] = ("^CNX500","^CRSLDX","^NSE500","^NIFTY500","^BSE500","^NSEI")
    volar_lookback: int = 252
    filter_52w_window: int = 252
    within_pct_of_52w_high: float = 0.50  # 50%

CFG = Config()

# =========================
# FEES (Groww-like)
# =========================
APPLY_FEES = True

def calc_fees(turnover_buy: float, turnover_sell: float) -> float:
    if not APPLY_FEES:
        return 0.0
    BROKER_PCT = 0.001
    BROKER_MIN = 5.0
    BROKER_CAP = 20.0
    STT_PCT = 0.001
    STAMP_BUY_PCT = 0.00015
    EXCH_PCT = 0.0000297
    SEBI_PCT = 0.000001
    IPFT_PCT = 0.000001
    GST_PCT = 0.18
    DP_SELL = 20.0 if turnover_sell >= 100 else 0.0

    def _broker(turnover):
        if turnover <= 0: return 0.0
        fee = turnover * BROKER_PCT
        return max(BROKER_MIN, min(fee, BROKER_CAP))

    br_buy  = _broker(turnover_buy)
    br_sell = _broker(turnover_sell)
    stt   = STT_PCT * (turnover_buy + turnover_sell)
    stamp = STAMP_BUY_PCT * turnover_buy
    exch  = EXCH_PCT * (turnover_buy + turnover_sell)
    sebi  = SEBI_PCT * (turnover_buy + turnover_sell)
    ipft  = IPFT_PCT * (turnover_buy + turnover_sell)
    dp    = DP_SELL
    gst_base = br_buy + br_sell + dp + exch + sebi + ipft
    gst   = GST_PCT * gst_base
    return float((br_buy + br_sell) + stt + stamp + exch + sebi + ipft + dp + gst)

# =========================
# Helpers
# =========================
def ensure_dirs(*paths): [os.makedirs(p, exist_ok=True) for p in paths]

def today_str():
    return pd.Timestamp.today(tz="Asia/Kolkata").strftime("%Y-%m-%d")

def load_static_symbols(static_symbols: Optional[List[str]], static_symbols_path: Optional[str]) -> List[str]:
    syms: List[str] = []
    if static_symbols and len(static_symbols) > 0:
        syms = list(static_symbols)
    elif static_symbols_path and os.path.exists(static_symbols_path):
        with open(static_symbols_path, "r") as f:
            syms = [line.strip() for line in f if line.strip()]
    else:
        raise ValueError("Provide CFG.static_symbols=[...] or CFG.static_symbols_path file.")
    out = []
    for s in syms:
        s = s.strip().upper()
        if not s.endswith(".NS"): s = f"{s}.NS"
        out.append(s)
    uniq = []
    seen = set()
    for s in out:
        if s not in seen:
            uniq.append(s); seen.add(s)
    return uniq

def fetch_prices(tickers: List[str], start: str, end: Optional[str], cache_dir: str) -> Dict[str, pd.DataFrame]:
    ensure_dirs(cache_dir)
    data = {}
    end = end or today_str()
    for ticker in tickers:
        cache_path = os.path.join(cache_dir, f"{ticker.replace('^','_')}.parquet")
        if os.path.exists(cache_path):
            try:
                df = pd.read_parquet(cache_path)
                if len(df) and pd.to_datetime(df.index[-1]).strftime("%Y-%m-%d") >= end:
                    data[ticker] = df; continue
            except Exception:
                pass
        try:
            df = yf.download(ticker, start=start, end=end, auto_adjust=True, progress=False, multi_level_index=False)
            if df is None or df.empty: continue
            df = df.rename(columns=str.title)[['Open','High','Low','Close','Volume']].dropna()
            df.index.name = "date"
            df.to_parquet(cache_path)
            data[ticker] = df
        except Exception:
            continue
    return data

# =========================
# Indicators
# =========================
def sma(series: pd.Series, window: int) -> pd.Series:
    return series.rolling(window, min_periods=window).mean()

def ema(series: pd.Series, span: int) -> pd.Series:
    return series.ewm(span=span, adjust=False, min_periods=span).mean()

def rsi(series: pd.Series, length: int = 14) -> pd.Series:
    delta = series.diff()
    gain = (delta.where(delta > 0, 0.0)).rolling(length).mean()
    loss = (-delta.where(delta < 0, 0.0)).rolling(length).mean()
    rs = gain / loss.replace(0.0, np.nan)
    out = 100 - (100 / (1 + rs))
    return out.fillna(50.0)

def macd(series: pd.Series, fast=12, slow=26, signal=9):
    ema_fast = ema(series, fast)
    ema_slow = ema(series, slow)
    line = ema_fast - ema_slow
    sig = ema(line, signal)
    hist = line - sig
    return line, sig, hist

def _true_range(high: pd.Series, low: pd.Series, prev_close: pd.Series) -> pd.Series:
    return pd.concat([
        (high - low).abs(),
        (high - prev_close).abs(),
        (low - prev_close).abs()
    ], axis=1).max(axis=1)

def adx_plus_minus_di(high: pd.Series, low: pd.Series, close: pd.Series, length: int = 14):
    prev_high = high.shift(1)
    prev_low  = low.shift(1)
    prev_close = close.shift(1)

    up_move   = high - prev_high
    down_move = prev_low - low
    plus_dm  = up_move.where((up_move > down_move) & (up_move > 0), 0.0)
    minus_dm = down_move.where((down_move > up_move) & (down_move > 0), 0.0)

    tr = _true_range(high, low, prev_close)
    alpha = 1.0 / length
    atr = tr.ewm(alpha=alpha, adjust=False, min_periods=length).mean()

    plus_di  = 100 * (plus_dm.ewm(alpha=alpha, adjust=False, min_periods=length).mean() / atr)
    minus_di = 100 * (minus_dm.ewm(alpha=alpha, adjust=False, min_periods=length).mean() / atr)

    dx = 100 * (plus_di - minus_di).abs() / (plus_di + minus_di).replace(0, np.nan)
    adx_series = dx.ewm(alpha=alpha, adjust=False, min_periods=length).mean()
    return adx_series, plus_di, minus_di

# =========================
# Candlestick pattern detectors (bullish only)
# =========================
def _body(o, c): return (c - o).abs()
def _is_bull(o, c): return c > o
def _is_bear(o, c): return c < o

def patt_bull_engulfing(df: pd.DataFrame) -> pd.Series:
    o, h, l, c = df["Open"], df["High"], df["Low"], df["Close"]
    op, cp = o.shift(1), c.shift(1)
    cond = _is_bear(op, cp) & _is_bull(o, c) & (c >= op) & (o <= cp)
    return cond.fillna(False)

def patt_piercing(df: pd.DataFrame) -> pd.Series:
    o, h, l, c = df["Open"], df["High"], df["Low"], df["Close"]
    op, hp, lp, cp = o.shift(1), h.shift(1), l.shift(1), c.shift(1)
    mid_prev = (op + cp) / 2.0
    cond = _is_bear(op, cp) & _is_bull(o, c) \
           & (o < lp) \
           & (c > mid_prev) & (c < op)
    return cond.fillna(False)

def patt_morning_star(df: pd.DataFrame) -> pd.Series:
    o, c, h, l = df["Open"], df["Close"], df["High"], df["Low"]
    o1, c1 = o.shift(1), c.shift(1)
    o2, c2 = o.shift(2), c.shift(2)
    bear1 = _is_bear(o2, c2)
    small2 = (_body(o1, c1) <= (_body(o2, c2) * 0.6))
    bull3 = _is_bull(o, c)
    mid1 = (o2 + c2) / 2.0
    retrace = c > mid1
    cond = bear1 & small2 & bull3 & retrace
    return cond.fillna(False)

def patt_harami_bull(df: pd.DataFrame) -> pd.Series:
    o, c, h, l = df["Open"], df["Close"], df["High"], df["Low"]
    o1, c1 = o.shift(1), c.shift(1)
    prev_bear = _is_bear(o1, c1)
    body_small = (_body(o, c) <= _body(o1, c1) * 0.75)
    # inside previous bearish body
    inside = (np.maximum(o, c) <= o1) & (np.minimum(o, c) >= c1)
    cond = prev_bear & body_small & inside & (c >= o)
    return cond.fillna(False)

def patt_harami_cross_bull(df: pd.DataFrame, doji_pct=0.1) -> pd.Series:
    o, c, h, l = df["Open"], df["Close"], df["High"], df["Low"]
    o1, c1 = o.shift(1), c.shift(1)
    rng = (h - l).replace(0, np.nan)
    doji = (_body(o, c) <= (rng * doji_pct))
    prev_bear = _is_bear(o1, c1)
    inside = (np.maximum(o, c) <= o1) & (np.minimum(o, c) >= c1)
    cond = prev_bear & doji & inside
    return cond.fillna(False)

def patt_hammer(df: pd.DataFrame, shadow_mult=2.0) -> pd.Series:
    o, c, h, l = df["Open"], df["Close"], df["High"], df["Low"]
    body = _body(o, c)
    lower_shadow = (np.minimum(o, c) - l).abs()
    upper_shadow = (h - np.maximum(o, c)).abs()
    cond = (lower_shadow >= shadow_mult * body) & (upper_shadow <= body) & (c >= o)
    return cond.fillna(False)

def patt_inverted_hammer(df: pd.DataFrame, shadow_mult=2.0) -> pd.Series:
    o, c, h, l = df["Open"], df["Close"], df["High"], df["Low"]
    body = _body(o, c)
    upper_shadow = (h - np.maximum(o, c)).abs()
    lower_shadow = (np.minimum(o, c) - l).abs()
    cond = (upper_shadow >= shadow_mult * body) & (lower_shadow <= body) & (c >= o)
    return cond.fillna(False)

BULLISH_PATTERNS = [
    "ENGULFING",
    "PIERCING",
    "MORNING_STAR",
    "HARAMI",
    "HARAMI_CROSS",
    "HAMMER",
    "INVERTED_HAMMER",
]

# =========================
# Indicator computation
# =========================
def compute_indicators(df: pd.DataFrame, cfg: Config) -> pd.DataFrame:
    out = df.copy()

    # Trend EMAs
    out["ema_fast"] = ema(out["Close"], cfg.ema_fast)
    out["ema_slow"] = ema(out["Close"], cfg.ema_slow)
    out["ema_htf"]  = ema(out["Close"], cfg.ema_htf)

    # Confirmations
    out["rsi"] = rsi(out["Close"], 14)
    macd_line, macd_sig, macd_hist = macd(out["Close"], 12, 26, 9)
    out["macd_line"] = macd_line
    out["macd_signal"] = macd_sig
    out["macd_hist"] = macd_hist
    out["sma50"] = sma(out["Close"], 50)
    out["bb_mid"] = sma(out["Close"], 20)
    adxv, pdi, ndi = adx_plus_minus_di(out["High"], out["Low"], out["Close"], 14)
    out["adx"] = adxv
    out["+di"] = pdi
    out["-di"] = ndi

    # Liquidity helpers
    out["avg_vol_20"] = out["Volume"].rolling(20).mean()

    # 52w high for ranking/filtering
    out["high_52w"] = out["Close"].rolling(cfg.filter_52w_window).max()

    # ----- Candlestick masks -----
    patt_map = {
        "ENGULFING":       patt_bull_engulfing(out),
        "PIERCING":        patt_piercing(out),
        "MORNING_STAR":    patt_morning_star(out),
        "HARAMI":          patt_harami_bull(out),
        "HARAMI_CROSS":    patt_harami_cross_bull(out),
        "HAMMER":          patt_hammer(out),
        "INVERTED_HAMMER": patt_inverted_hammer(out),
    }
    patt_any = None
    for name in BULLISH_PATTERNS:
        patt_any = patt_map[name] if patt_any is None else (patt_any | patt_map[name])
    out["bullish_pattern"] = patt_any.fillna(False)

    return out.dropna()

def basic_liquidity_ok(row: pd.Series, cfg: Config) -> bool:
    if not cfg.use_basic_liquidity:
        return True
    if row["Close"] < cfg.min_price_inr: return False
    if row["avg_vol_20"] < cfg.min_avg_vol_20d: return False
    return True

def _and_if_enabled(enabled: bool, cond: pd.Series) -> pd.Series:
    """If toggle enabled -> use cond; else -> True."""
    if enabled:
        return cond.astype(bool).fillna(False)
    else:
        # return vector of True aligned to cond.index
        return pd.Series(True, index=cond.index)

def simulate_ticker(ticker: str, df: pd.DataFrame, cfg: Config):
    d = compute_indicators(df, cfg).copy()
    cols = ["ticker","side","date","price","shares","reason","signal_reason","score",
            "pattern","rsi","adx","+di","-di","macd_line","macd_signal",
            "ema_fast","ema_slow","ema_htf","sma50","bb_mid","close","high_52w","avg_vol_20"]
    if d.empty:
        return pd.DataFrame(columns=cols), pd.Series(dtype=float)

    # --- Build AND-of-enabled masks ---
    patt_ok = d["bullish_pattern"]  # always required

    conds = []

    # Trend filters (toggles)
    conds.append(_and_if_enabled(cfg.use_trend_fast_slow, (d["ema_fast"] > d["ema_slow"])))
    conds.append(_and_if_enabled(cfg.use_htf_trend, (d["Close"] > d["ema_htf"])))

    # Confirmations (toggles)
    conds.append(_and_if_enabled(cfg.use_rsi_confirm,  (d["rsi"] > 50.0)))
    conds.append(_and_if_enabled(cfg.use_macd_confirm, (d["macd_line"] > d["macd_signal"])))
    conds.append(_and_if_enabled(cfg.use_adx_confirm,  ((d["adx"] > 20.0) & (d["+di"] > d["-di"]))))
    conds.append(_and_if_enabled(cfg.use_sma50_confirm,(d["Close"] > d["sma50"])))
    conds.append(_and_if_enabled(cfg.use_bbmid_confirm,(d["Close"] > d["bb_mid"])))

    # Liquidity (toggle) — evaluated at bar of entry signal
    liq_series = d.apply(lambda r: basic_liquidity_ok(r, cfg), axis=1)
    conds.append(_and_if_enabled(cfg.use_basic_liquidity, liq_series.astype(bool)))

    # Final entry mask = bullish pattern AND (all enabled conditions)
    all_enabled_ok = conds[0]
    for c in conds[1:]:
        all_enabled_ok = all_enabled_ok & c

    entry_signal = patt_ok & all_enabled_ok
    exit_ind = (d["ema_fast"] < d["ema_slow"])  # indicator exit (unchanged)

    in_pos = False
    entry_px = stop_px = tgt_px = 0.0
    trades = []

    idx = list(d.index)
    # Rebuild pattern map to name the exact pattern(s)
    patt_map = {
        "ENGULFING":       patt_bull_engulfing(d),
        "PIERCING":        patt_piercing(d),
        "MORNING_STAR":    patt_morning_star(d),
        "HARAMI":          patt_harami_bull(d),
        "HARAMI_CROSS":    patt_harami_cross_bull(d),
        "HAMMER":          patt_hammer(d),
        "INVERTED_HAMMER": patt_inverted_hammer(d),
    }

    # Keep string list of which enabled confirms passed for log
    def confirm_tags_at(ti):
        tags = []
        if cfg.use_trend_fast_slow and bool((d["ema_fast"] > d["ema_slow"]).loc[ti]): tags.append("EMAfast>EMAslow")
        if cfg.use_htf_trend and bool((d["Close"] > d["ema_htf"]).loc[ti]):           tags.append("Close>EMA200")
        if cfg.use_rsi_confirm and bool((d["rsi"] > 50).loc[ti]):                     tags.append("RSI>50")
        if cfg.use_macd_confirm and bool((d["macd_line"] > d["macd_signal"]).loc[ti]):tags.append("MACD>Signal")
        if cfg.use_adx_confirm and bool(((d["adx"] > 20) & (d["+di"] > d["-di"])).loc[ti]): tags.append("ADX>20 & +DI>-DI")
        if cfg.use_sma50_confirm and bool((d["Close"] > d["sma50"]).loc[ti]):         tags.append("Close>SMA50")
        if cfg.use_bbmid_confirm and bool((d["Close"] > d["bb_mid"]).loc[ti]):         tags.append("Close>BBmid")
        if cfg.use_basic_liquidity and bool(liq_series.loc[ti]):                       tags.append("LiquidityOK")
        return tags

    for i in range(len(idx)-1):
        dt, nxt = idx[i], idx[i+1]
        row, nxt_row = d.loc[dt], d.loc[nxt]

        if not in_pos:
            if entry_signal.loc[dt]:
                patterns_detected = [nm for nm, ser in patt_map.items() if bool(ser.loc[dt])]
                patt_str = " + ".join(patterns_detected) if patterns_detected else "BullishPattern"

                sigs = confirm_tags_at(dt)
                sig_reason = ", ".join(sigs) if sigs else "pattern_only"

                px = float(nxt_row["Open"])  # enter next open
                trades.append({
                    "ticker": ticker, "side": "BUY", "date": nxt,
                    "price": px, "shares": 0,
                    "reason": "candidate",
                    "signal_reason": sig_reason,
                    "score": float(1000.0*((row["ema_fast"]-row["ema_slow"])/max(row["Close"],1e-9))) + float(row["adx"]) - float(row["rsi"]),
                    "pattern": patt_str,
                    "rsi": float(row["rsi"]), "adx": float(row["adx"]), "+di": float(row["+di"]), "-di": float(row["-di"]),
                    "macd_line": float(row["macd_line"]), "macd_signal": float(row["macd_signal"]),
                    "ema_fast": float(row["ema_fast"]), "ema_slow": float(row["ema_slow"]), "ema_htf": float(row["ema_htf"]),
                    "sma50": float(row["sma50"]), "bb_mid": float(row["bb_mid"]),
                    "close": float(row["Close"]), "high_52w": float(row["high_52w"]), "avg_vol_20": float(row["avg_vol_20"])
                })
                in_pos = True
                entry_px = px
                stop_px = entry_px * (1 - cfg.stop_loss_pct)
                tgt_px  = entry_px * (1 + cfg.target_pct)

        else:
            hit = None
            exec_date = nxt
            exit_detail = ""
            if nxt_row["Low"] <= stop_px and nxt_row["High"] >= tgt_px:
                hit = "target"
                exec_price = float(tgt_px)
                exit_detail = f"TakeProfit hit: High {float(nxt_row['High']):.2f} ≥ TP {tgt_px:.2f} (from entry {entry_px:.2f})"
            elif nxt_row["Low"] <= stop_px:
                hit = "stop"
                exec_price = float(stop_px)
                exit_detail = f"StopLoss hit: Low {float(nxt_row['Low']):.2f} ≤ SL {stop_px:.2f} (from entry {entry_px:.2f})"
            elif nxt_row["High"] >= tgt_px:
                hit = "target"
                exec_price = float(tgt_px)
                exit_detail = f"TakeProfit hit: High {float(nxt_row['High']):.2f} ≥ TP {tgt_px:.2f} (from entry {entry_px:.2f})"
            elif exit_ind.loc[dt]:
                hit = "indicator_exit"
                exec_price = float(nxt_row["Open"])
                exit_detail = f"Trend invalidation: EMA{cfg.ema_fast}<EMA{cfg.ema_slow} at close {float(row['Close']):.2f}"

            if hit is not None:
                trades.append({
                    "ticker": ticker, "side": "SELL", "date": exec_date,
                    "price": float(exec_price), "shares": 0,
                    "reason": hit,
                    "signal_reason": exit_detail,
                    "score": np.nan,
                    "pattern": "",
                    "rsi": float(row["rsi"]), "adx": float(row["adx"]), "+di": float(row["+di"]), "-di": float(row["-di"]),
                    "macd_line": float(row["macd_line"]), "macd_signal": float(row["macd_signal"]),
                    "ema_fast": float(row["ema_fast"]), "ema_slow": float(row["ema_slow"]), "ema_htf": float(row["ema_htf"]),
                    "sma50": float(row["sma50"]), "bb_mid": float(row["bb_mid"]),
                    "close": float(row["Close"]), "high_52w": float(row["high_52w"]), "avg_vol_20": float(row["avg_vol_20"])
                })
                in_pos = False
                entry_px = stop_px = tgt_px = 0.0

    if in_pos:
        last_dt = d.index[-1]; row = d.loc[last_dt]
        trades.append({
            "ticker": ticker, "side": "SELL", "date": last_dt,
            "price": float(row["Close"]), "shares": 0,
            "reason": "final_close",
            "signal_reason": "Final close: end of data",
            "score": np.nan,
            "pattern": "",
            "rsi": float(row["rsi"]), "adx": float(row["adx"]), "+di": float(row["+di"]), "-di": float(row["-di"]),
            "macd_line": float(row["macd_line"]), "macd_signal": float(row["macd_signal"]),
            "ema_fast": float(row["ema_fast"]), "ema_slow": float(row["ema_slow"]), "ema_htf": float(row["ema_htf"]),
            "sma50": float(row["sma50"]), "bb_mid": float(row["bb_mid"]),
            "close": float(row["Close"]), "high_52w": float(row["high_52w"]), "avg_vol_20": float(row["avg_vol_20"])
        })

    return pd.DataFrame(trades, columns=cols), pd.Series(dtype=float)

# =========================
# Ranking, portfolio, metrics
# =========================
def pick_benchmark(benchmarks: Tuple[str,...], start: str, end: Optional[str], cache_dir: str) -> Tuple[str, pd.DataFrame]:
    for t in benchmarks:
        data = fetch_prices([t], start, end, cache_dir)
        df = data.get(t)
        if df is not None and not df.empty:
            log.info("Using benchmark: %s", t)
            return t, df
    idx = pd.date_range(start=start, end=end or today_str(), freq="B")
    df = pd.DataFrame({"Close": np.ones(len(idx))}, index=idx)
    log.warning("No benchmark found; using synthetic flat series.")
    return "SYNTH_BENCH", df

def compute_volar_scores(end_dt: pd.Timestamp, tickers: List[str], data_map: Dict[str,pd.DataFrame], bench_df: pd.DataFrame, lookback: int) -> Dict[str, float]:
    scores = {}
    bser = bench_df["Close"].loc[:end_dt].pct_change().dropna().iloc[-lookback:]
    for t in tickers:
        df = data_map.get(t)
        if df is None or df.empty:
            scores[t] = 0.0; continue
        if end_dt not in df.index:
            df = df[df.index <= end_dt]
            if df.empty:
                scores[t] = 0.0; continue
        r = df["Close"].loc[:end_dt].pct_change().dropna().iloc[-lookback:]
        common = pd.concat([r, bser], axis=1, keys=["s","b"]).dropna()
        if common.shape[0] < max(20, int(0.4*lookback)):
            scores[t] = 0.0; continue
        excess = common["s"] - common["b"]
        vol = common["s"].std(ddof=0)
        scores[t] = 0.0 if vol <= 1e-8 else float((excess.mean() / vol) * math.sqrt(252.0))
    return scores

def markowitz_long_only(mu: np.ndarray, Sigma: np.ndarray) -> np.ndarray:
    n = len(mu); eps = 1e-6
    Sigma = Sigma + eps*np.eye(n)

    def solve_lambda(lmbd: float, active_mask=None):
        if active_mask is None:
            A = np.block([[2*lmbd*Sigma, np.ones((n,1))],[np.ones((1,n)), np.zeros((1,1))]])
            b = np.concatenate([mu, np.array([1.0])])
            try: w = np.linalg.solve(A, b)[:n]
            except np.linalg.LinAlgError: w = np.full(n, 1.0/n)
            return w
        else:
            idx = np.where(active_mask)[0]
            if len(idx)==0: return np.full(n, 1.0/n)
            S = Sigma[np.ix_(idx, idx)]
            o = np.ones(len(idx)); m = mu[idx]
            A = np.block([[2*lmbd*S, o[:,None]],[o[None,:], np.zeros((1,1))]])
            b = np.concatenate([m, np.array([1.0])])
            try: w_sub = np.linalg.solve(A, b)[:len(idx)]
            except np.linalg.LinAlgError: w_sub = np.full(len(idx), 1.0/len(idx))
            w = np.zeros(n); w[idx] = w_sub; return w

    best_w = np.full(n, 1.0/n); best_sr = -1e9
    for lmbd in np.logspace(-3, 3, 31):
        active = np.ones(n, dtype=bool); w = None
        for _ in range(n):
            w = solve_lambda(lmbd, active_mask=active)
            if not (w < 0).any(): break
            active[np.argmin(w)] = False
        if w is None: continue
        w = np.clip(w, 0, None); 
        if w.sum() <= 0: continue
        w = w / w.sum()
        mu_p = float(mu @ w); vol_p = float(np.sqrt(w @ Sigma @ w))
        if vol_p <= 1e-8: continue
        sr = mu_p / vol_p
        if sr > best_sr: best_sr, best_w = sr, w.copy()
    return best_w

def aggregate_and_apply(all_trades: pd.DataFrame, data_map: Dict[str, pd.DataFrame], bench_df: pd.DataFrame, cfg: Config):
    if all_trades.empty:
        return all_trades, pd.Series(dtype=float), {}

    side_order = {"BUY": 0, "SELL": 1}
    all_trades = (all_trades
        .assign(_sorder=all_trades["side"].map(side_order))
        .sort_values(by=["date", "_sorder"], kind="stable")
        .drop(columns=["_sorder"])
        .reset_index(drop=True)
    )
    all_trades["date"] = pd.to_datetime(all_trades["date"])

    equity_curve = []
    dates = sorted(all_trades["date"].unique().tolist())
    cash = cfg.initial_capital
    open_positions = {}
    completed_legs = []

    global APPLY_FEES
    APPLY_FEES = cfg.apply_fees

    def _get_close_on(tkr, dt):
        df = data_map.get(tkr)
        if df is None or df.empty:
            return np.nan
        if dt in df.index:
            return float(df.loc[dt, "Close"])
        prev = df[df.index <= dt]
        if prev.empty:
            return np.nan
        return float(prev["Close"].iloc[-1])

    if dates:
        seed_date = pd.to_datetime(dates[0]) - pd.Timedelta(days=1)
        equity_curve.append((seed_date, float(cash)))

    for dt in dates:
        day_trades = all_trades[all_trades["date"] == dt].copy()

        # ---- SELL first ----
        for _, tr in day_trades[day_trades["side"] == "SELL"].iterrows():
            tkr = tr["ticker"]
            price = float(tr["price"])
            pos = open_positions.get(tkr)
            if pos is None:
                continue
            shares = int(pos["shares"])
            turnover_sell = shares * price
            fee = calc_fees(0.0, turnover_sell)
            pnl = (price - pos["entry_px"]) * shares
            cash += (turnover_sell - fee)
            realized = pnl - fee - pos.get("buy_fee", 0.0)

            base = str(tr.get("reason", "")).lower()
            detail = str(tr.get("signal_reason", "")).strip()
            if base == "stop":
                exit_text = f"Exit: StopLoss hit — {detail}" if detail else "Exit: StopLoss hit"
            elif base == "target":
                exit_text = f"Exit: TakeProfit hit — {detail}" if detail else "Exit: TakeProfit hit"
            elif base == "indicator_exit":
                exit_text = f"Exit: Trend invalidation — {detail}" if detail else "Exit: Trend invalidation (EMA fast<slow)"
            elif base == "final_close":
                exit_text = "Exit: Final close — end of data"
            else:
                exit_text = f"Exit: {tr.get('reason','')}"

            completed_legs.append({
                "ticker": tkr, "side": "SELL", "date": dt, "price": price,
                "shares": shares, "reason": exit_text,
                "turnover": turnover_sell, "fees_inr": fee, "pnl_inr": realized,
                "rsi": tr.get("rsi", np.nan), "adx": tr.get("adx", np.nan),
                "+di": tr.get("+di", np.nan), "-di": tr.get("-di", np.nan),
                "macd_line": tr.get("macd_line", np.nan), "macd_signal": tr.get("macd_signal", np.nan),
                "ema_fast": tr.get("ema_fast", np.nan), "ema_slow": tr.get("ema_slow", np.nan), "ema_htf": tr.get("ema_htf", np.nan),
                "sma50": tr.get("sma50", np.nan), "bb_mid": tr.get("bb_mid", np.nan),
                "close": tr.get("close", np.nan), "high_52w": tr.get("high_52w", np.nan),
                "volar": tr.get("volar", np.nan), "mvo_weight": np.nan, "alloc_inr": np.nan
            })
            log.info("Exit %-12s px=%8.2f shares=%6d :: %s | net=%.2f cash=%.2f",
                     tkr, price, shares, exit_text, realized, cash)
            del open_positions[tkr]

        # ---- BUY candidates today ----
        buys_today = day_trades[day_trades["side"] == "BUY"].copy()

        # 52w filter (toggle)
        if cfg.use_52w_filter and not buys_today.empty:
            keep = []
            for _, rr in buys_today.iterrows():
                df = data_map.get(rr["ticker"])
                if df is None or df.empty or dt not in df.index:
                    continue
                close = float(df.loc[dt, "Close"])
                hist = df["Close"].loc[:dt]
                window = hist.iloc[-cfg.filter_52w_window:] if len(hist)>=cfg.filter_52w_window else hist
                high_52w = float(window.max())
                if high_52w>0 and close >= cfg.within_pct_of_52w_high * high_52w:
                    keep.append(rr)
            buys_today = pd.DataFrame(keep) if keep else pd.DataFrame(columns=buys_today.columns)

        # Exclude already-held tickers
        if not buys_today.empty:
            buys_today = buys_today[~buys_today["ticker"].isin(open_positions.keys())]

        # VOLAR ranking (toggle)
        if cfg.use_volar_ranking and not buys_today.empty:
            tickers = buys_today["ticker"].tolist()
            volar_scores = compute_volar_scores(dt, tickers, data_map, bench_df, cfg.volar_lookback)
            buys_today["volar"] = buys_today["ticker"].map(volar_scores)
            buys_today = buys_today.sort_values("volar", ascending=False).reset_index(drop=True)
        else:
            if not buys_today.empty:
                buys_today["volar"] = np.nan  # keep column for uniformity

        # Select up to available slots (and top_k_daily cap)
        slots = cfg.max_concurrent_positions - len(open_positions)
        selected = pd.DataFrame(columns=buys_today.columns)
        if slots > 0 and not buys_today.empty:
            # If volar ranking off, keep original order but still cap to top_k_daily
            selected = buys_today.head(min(cfg.top_k_daily, slots)).copy()

        if not selected.empty:
            log.info("Selected %d BUY candidates on %s:", selected.shape[0], dt.date())
            for i, rr in selected.reset_index(drop=True).iterrows():
                log.info("  %-12s volar=%6s rank=%d px=%8.2f",
                         rr["ticker"],
                         f"{rr.get('volar',np.nan):.2f}" if not pd.isna(rr.get('volar',np.nan)) else "NA",
                         i+1, rr["price"])

            # Sizing: MVO (toggle) or equal-weight
            names = selected["ticker"].tolist()
            if cfg.use_mvo_sizing and selected.shape[0] >= 2:
                rets = []
                for t in names:
                    df = data_map.get(t)
                    ser = df["Close"].loc[:dt].pct_change().dropna().iloc[-cfg.volar_lookback:]
                    rets.append(ser)
                R = pd.concat(rets, axis=1); R.columns = names; R = R.dropna()
                if R.empty or R.shape[0] < max(20, int(0.4*cfg.volar_lookback)) or R.shape[1] == 0:
                    weights = np.full(len(names), 1.0/len(names))
                else:
                    mu = R.mean().values; Sigma = R.cov().values
                    weights = markowitz_long_only(mu, Sigma)
            else:
                weights = np.full(len(names), 1.0/len(names))

            deploy_cash = max(0.0, float(cash)) * float(cfg.deploy_cash_frac)
            if deploy_cash <= 0:
                log.info("No deployable cash (cap=%.0f%%) on %s", 100*cfg.deploy_cash_frac, dt.date())
            else:
                alloc = (weights / weights.sum()) * deploy_cash if weights.sum()>0 else np.full(len(names), deploy_cash/len(names))
                rank_map = {row["ticker"]: (idx+1) for idx, (_, row) in enumerate(selected.iterrows())}
                for w_amt, t in zip(alloc, names):
                    df_t = data_map[t]
                    price = float(df_t.loc[dt, "Close"] if dt in df_t.index else df_t["Close"].loc[:dt].iloc[-1])
                    shares = int(math.floor(w_amt / price))
                    if shares <= 0:
                        log.info("Skip BUY %-12s (alloc %.2f too small)", t, w_amt); continue
                    turn = shares * price
                    fee = calc_fees(turn, 0.0)
                    total_cost = turn + fee
                    if total_cost > cash:
                        shares = int(math.floor((cash - fee) / price))
                        if shares <= 0:
                            log.info("Skip BUY %-12s due to cash/fees", t); continue
                        turn = shares * price; total_cost = turn + fee
                    cash -= total_cost
                    open_positions[t] = {"entry_date": dt, "entry_px": price, "shares": shares, "buy_fee": fee, "entry_reason": "entry"}

                    row_sel = selected[selected["ticker"]==t].iloc[0]
                    patt_str = str(row_sel.get("pattern","BullishPattern"))
                    sigs = str(row_sel.get("signal_reason","")).strip()
                    sigs_fmt = f"[{sigs}]" if sigs else "[none]"
                    volar_val = row_sel.get("volar", np.nan)
                    rank_pos = rank_map.get(t, np.nan)
                    high_52w = float(row_sel.get("high_52w", np.nan))
                    close_val = float(row_sel.get("close", np.nan))
                    pct_52w = (close_val / high_52w) if (high_52w and high_52w>0) else np.nan
                    mvo_weight_today = (w_amt / deploy_cash) if deploy_cash > 0 else 0.0

                    # Build readable entry reason safely (no broken f-strings)
                    parts = [f"Entry: {patt_str} + TogglesOK", f"Conf=[{sigs}]"]

                    # 52w piece
                    if cfg.use_52w_filter:
                        parts.append(f"52w%={(pct_52w*100):.1f}%" if not np.isnan(pct_52w) else "52w%=NA")
                    else:
                        parts.append("52w OFF")

                    # VOLAR piece
                    if cfg.use_volar_ranking and not pd.isna(volar_val):
                        try:
                            rank_pos_int = int(rank_pos) if not pd.isna(rank_pos) else None
                        except Exception:
                            rank_pos_int = None
                        if rank_pos_int is not None:
                            parts.append(f"VOLAR rank {rank_pos_int}/{len(names)} (VOLAR={float(volar_val):.2f})")
                        else:
                            parts.append(f"VOLAR (V={float(volar_val):.2f})")
                    else:
                        parts.append("VOLAR OFF")

                    # Sizing piece
                    sizing_label = "MVO" if cfg.use_mvo_sizing else "Equal"
                    parts.append(f"Sizing={sizing_label} (weight={mvo_weight_today:.1%})")

                    reason_text = "; ".join(parts)


                    completed_legs.append({
                        "ticker": t, "side": "BUY", "date": dt, "price": price,
                        "shares": shares, "reason": reason_text,
                        "turnover": turn, "fees_inr": fee, "pnl_inr": 0.0,
                        "rsi": float(row_sel.get("rsi", np.nan)), "adx": float(row_sel.get("adx", np.nan)),
                        "+di": float(row_sel.get("+di", np.nan)), "-di": float(row_sel.get("-di", np.nan)),
                        "macd_line": float(row_sel.get("macd_line", np.nan)), "macd_signal": float(row_sel.get("macd_signal", np.nan)),
                        "ema_fast": float(row_sel.get("ema_fast", np.nan)), "ema_slow": float(row_sel.get("ema_slow", np.nan)), "ema_htf": float(row_sel.get("ema_htf", np.nan)),
                        "sma50": float(row_sel.get("sma50", np.nan)), "bb_mid": float(row_sel.get("bb_mid", np.nan)),
                        "close": close_val, "high_52w": high_52w,
                        "volar": float(volar_val) if not pd.isna(volar_val) else np.nan,
                        "mvo_weight": float(mvo_weight_today), "alloc_inr": float(w_amt)
                    })
                    log.info("BUY %-12s px=%8.2f sh=%6d fee=%.2f cash=%.2f :: %s",
                             t, price, shares, fee, cash, reason_text)

        # MTM valuation
        mtm = 0.0
        for _tkr, pos in open_positions.items():
            px = _get_close_on(_tkr, dt)
            if not np.isnan(px):
                mtm += pos["shares"] * px
        total_equity = cash + mtm
        equity_curve.append((dt, float(total_equity)))

    eq_ser = pd.Series([e for _, e in equity_curve], index=[d for d, _ in equity_curve])
    legs_df = pd.DataFrame(completed_legs).sort_values(["date", "ticker", "side"]).reset_index(drop=True)

    # Roundtrips
    roundtrips = []
    by_tkr_open = {}
    for _, leg in legs_df.iterrows():
        tkr = leg["ticker"]
        if leg["side"] == "BUY":
            by_tkr_open[tkr] = leg
        else:
            buy = by_tkr_open.pop(tkr, None)
            if buy is None:
                continue
            fees_total = float(buy.get("fees_inr", 0.0) + leg.get("fees_inr", 0.0))
            gross_pnl = (leg["price"] - buy["price"]) * buy["shares"]
            net_pnl   = gross_pnl - fees_total
            ret_pct   = (leg["price"] / buy["price"] - 1.0) * 100.0
            days_held = (pd.to_datetime(leg["date"]) - pd.to_datetime(buy["date"])).days
            roundtrips.append({
                "ticker": tkr,
                "entry_date": pd.to_datetime(buy["date"]),
                "entry_price": float(buy["price"]),
                "exit_date": pd.to_datetime(leg["date"]),
                "exit_price": float(leg["price"]),
                "days_held": int(days_held),
                "shares": int(buy["shares"]),
                "entry_reason": buy.get("reason",""),
                "exit_reason": leg.get("reason",""),
                "gross_pnl_inr": float(gross_pnl),
                "fees_total_inr": float(fees_total),
                "net_pnl_inr": float(net_pnl),
                "return_pct": float(ret_pct),
                "rsi_entry": float(buy.get("rsi", np.nan)),
                "adx_entry": float(buy.get("adx", np.nan)),
                "ema_fast_entry": float(buy.get("ema_fast", np.nan)),
                "ema_slow_entry": float(buy.get("ema_slow", np.nan)),
                "ema_htf_entry": float(buy.get("ema_htf", np.nan)),
                "sma50_entry": float(buy.get("sma50", np.nan)),
                "bb_mid_entry": float(buy.get("bb_mid", np.nan)),
                "volar_entry": float(buy.get("volar", np.nan)),
                "mvo_weight_entry": float(buy.get("mvo_weight", np.nan)),
                "alloc_inr_entry": float(buy.get("alloc_inr", np.nan))
            })
    trips_df = pd.DataFrame(roundtrips).sort_values(["entry_date","ticker"]).reset_index(drop=True)

    metrics = compute_metrics(eq_ser, legs_df)
    return legs_df, trips_df, eq_ser, metrics

def compute_metrics(equity: pd.Series, legs_df: pd.DataFrame):
    out = {}
    if equity is None or equity.empty: return out
    eq = equity.dropna()
    daily_ret = eq.pct_change().fillna(0.0)

    days = (eq.index[-1] - eq.index[0]).days or 1
    years = days / 365.25
    cagr = (eq.iloc[-1] / eq.iloc[0]) ** (1/years) - 1 if years > 0 else 0.0

    sharpe = (daily_ret.mean() / daily_ret.std(ddof=0) * np.sqrt(252)) if daily_ret.std(ddof=0) > 0 else 0.0

    cummax = eq.cummax()
    dd = (eq - cummax) / cummax
    max_dd = dd.min()

    wins = 0
    n_sells = legs_df[legs_df["side"] == "SELL"].shape[0] if legs_df is not None and not legs_df.empty else 0
    for _, r in legs_df[legs_df["side"] == "SELL"].iterrows():
        if float(r.get("pnl_inr", 0.0)) > 0: wins += 1
    win_rate = (wins / n_sells) * 100.0 if n_sells > 0 else 0.0

    out.update({
        "start_equity_inr": float(eq.iloc[0]),
        "final_equity_inr": float(eq.iloc[-1]),
        "cagr_pct": float(cagr * 100),
        "sharpe": float(sharpe),
        "max_drawdown_pct": float(max_dd * 100),
        "win_rate_pct": float(win_rate),
        "n_trades": int(n_sells),
    })
    return out

def plot_equity(equity: pd.Series, out_path: str):
    if equity is None or equity.empty: return
    try:
        import matplotlib.pyplot as plt
        plt.figure(figsize=(10,5))
        plt.plot(equity.index, equity.values)
        plt.title("Equity Curve")
        plt.xlabel("Date"); plt.ylabel("Equity (INR)")
        plt.tight_layout(); plt.savefig(out_path); plt.close()
    except Exception:
        pass

def backtest(cfg: Config):
    ensure_dirs(cfg.cache_dir, cfg.out_dir)
    log.info("Universe: loading static symbols...")
    symbols = load_static_symbols(cfg.static_symbols, cfg.static_symbols_path)
    log.info("Loaded %d symbols.", len(symbols))

    log.info("Data: fetching OHLCV from yfinance (adjusted)...")
    data_map = fetch_prices(symbols, cfg.start_date, cfg.end_date, cfg.cache_dir)
    log.info("Downloaded %d symbols with data.", len(data_map))

    bench_tkr, bench_df = pick_benchmark(cfg.benchmark_try, cfg.start_date, cfg.end_date, cfg.cache_dir)
    log.info("Benchmark selected: %s", bench_tkr)

    log.info("Signals: bullish candles AND all enabled toggles...")
    all_trades = []
    for i, tkr in enumerate(symbols, 1):
        df = data_map.get(tkr)
        if df is None or df.empty: continue
        tr, _ = simulate_ticker(tkr, df, cfg)
        if not tr.empty: all_trades.append(tr)
        if i % 50 == 0:
            log.info("  processed %d/%d tickers...", i, len(symbols))

    if not all_trades:
        log.warning("No signals generated; check your toggles/thresholds or timeframe.")
        return None, None, None, {}
    all_trades = pd.concat(all_trades, ignore_index=True)

    log.info(
        "Portfolio: deploy %.0f%% cash; 52w filter=%s; VOLAR ranking=%s; sizing=%s; max %d positions.",
        cfg.deploy_cash_frac*100,
        cfg.use_52w_filter, cfg.use_volar_ranking, ("MVO" if cfg.use_mvo_sizing else "Equal"),
        cfg.max_concurrent_positions
    )
    legs_df, trips_df, equity, metrics = aggregate_and_apply(all_trades, data_map, bench_df, cfg)

    stamp = pd.Timestamp.today(tz="Asia/Kolkata").strftime("%Y%m%d_%H%M%S")
    legs_path = os.path.join(cfg.out_dir, f"trades_legs_{stamp}.csv")
    trips_path = os.path.join(cfg.out_dir, f"trades_roundtrips_{stamp}.csv")
    equity_path = os.path.join(cfg.out_dir, f"equity_{stamp}.csv")
    metrics_path = os.path.join(cfg.out_dir, f"metrics_{stamp}.json")
    eq_plot_path = os.path.join(cfg.out_dir, f"equity_{stamp}.png")

    if legs_df is not None: legs_df.to_csv(legs_path, index=False)
    if trips_df is not None: trips_df.to_csv(trips_path, index=False)
    if equity is not None: pd.DataFrame({"date": equity.index, "equity": equity.values}).to_csv(equity_path, index=False)
    with open(metrics_path, "w") as f: json.dump(metrics, f, indent=2)
    if cfg.plot and equity is not None: plot_equity(equity, eq_plot_path)

    log.info("=== METRICS ===\n%s", json.dumps(metrics, indent=2))
    log.info("Files written:\n  %s\n  %s\n  %s\n  %s", legs_path, trips_path, equity_path, metrics_path)
    if cfg.plot: log.info("  %s", eq_plot_path)

def main():
    global APPLY_FEES
    APPLY_FEES = bool(CFG.apply_fees)

    # Example universe (yours). You can switch to a file via CFG.static_symbols_path.
    # CFG.static_symbols = ['360ONE.NS','3MINDIA.NS','AARTIIND.NS','ABB.NS','ACC.NS','ADANIENT.NS','ADANIPORTS.NS','APOLLOHOSP.NS','ASIANPAINT.NS','AXISBANK.NS','BAJAJ-AUTO.NS','BAJFINANCE.NS','BHARTIARTL.NS','BPCL.NS','BRITANNIA.NS','CIPLA.NS','COALINDIA.NS','COFORGE.NS','DRREDDY.NS','EICHERMOT.NS','GRASIM.NS','HCLTECH.NS','HDFCBANK.NS','HINDALCO.NS','HINDUNILVR.NS','ICICIBANK.NS','INFY.NS','ITC.NS','JSWSTEEL.NS','KOTAKBANK.NS','LT.NS','MARUTI.NS','NESTLEIND.NS','NTPC.NS','ONGC.NS','POWERGRID.NS','RELIANCE.NS','SBIN.NS','SUNPHARMA.NS','TATAMOTORS.NS','TATASTEEL.NS','TCS.NS','TECHM.NS','TITAN.NS','ULTRACEMCO.NS','WIPRO.NS']
    CFG.static_symbols_path = "nifty500.txt"

    backtest(CFG)

if __name__ == "__main__":
    main()
# Out:
# 2025-10-17 15:48:44 | INFO | Universe: loading static symbols...
# 2025-10-17 15:48:44 | INFO | Loaded 500 symbols.
# 2025-10-17 15:48:44 | INFO | Data: fetching OHLCV from yfinance (adjusted)...
# 2025-10-17 15:48:48 | ERROR |
# 1 Failed download:
# 2025-10-17 15:48:48 | ERROR | ['ABLBL.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 15:48:54 | ERROR |
# 1 Failed download:
# 2025-10-17 15:48:54 | ERROR | ['AEGISVOPAK.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 15:48:55 | ERROR |
# 1 Failed download:
# 2025-10-17 15:48:55 | ERROR | ['AGARWALEYE.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 15:49:13 | ERROR |
# 1 Failed download:
# 2025-10-17 15:49:13 | ERROR | ['ATHERENERG.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 15:49:44 | ERROR |
# 1 Failed download:
# 2025-10-17 15:49:44 | ERROR | ['COHANCE.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 15:50:00 | ERROR |
# 1 Failed download:
# 2025-10-17 15:50:00 | ERROR | ['ENRIN.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 15:50:23 | ERROR |
# 1 Failed download:
# 2025-10-17 15:50:23 | ERROR | ['HEXT.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 15:50:42 | ERROR |
# 1 Failed download:
# 2025-10-17 15:50:42 | ERROR | ['ITCHOTELS.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 15:51:24 | ERROR |
# 1 Failed download:
# 2025-10-17 15:51:24 | ERROR | ['ONESOURCE.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 15:52:04 | ERROR |
# 1 Failed download:
# 2025-10-17 15:52:04 | ERROR | ['THELEELA.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420050600, endDate = 1735669800")')
# 2025-10-17 15:52:20 | INFO | Downloaded 490 symbols with data.
# 2025-10-17 15:52:22 | ERROR | HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: ^CNX500"}}}
# 2025-10-17 15:52:22 | ERROR |
# 1 Failed download:
# 2025-10-17 15:52:22 | ERROR | ['^CNX500']: YFTzMissingError('possibly delisted; no timezone found')
# 2025-10-17 15:52:22 | INFO | Using benchmark: ^CRSLDX
# 2025-10-17 15:52:22 | INFO | Benchmark selected: ^CRSLDX
# 2025-10-17 15:52:22 | INFO | Signals: bullish candles AND all enabled toggles...
# 2025-10-17 15:52:26 | INFO |   processed 50/500 tickers...
# 2025-10-17 15:52:31 | INFO |   processed 100/500 tickers...
# 2025-10-17 15:52:36 | INFO |   processed 150/500 tickers...
# 2025-10-17 15:52:40 | INFO |   processed 200/500 tickers...
# 2025-10-17 15:52:45 | INFO |   processed 250/500 tickers...
# 2025-10-17 15:52:49 | INFO |   processed 300/500 tickers...
# 2025-10-17 15:52:53 | INFO |   processed 350/500 tickers...
# 2025-10-17 15:52:58 | INFO |   processed 400/500 tickers...
# 2025-10-17 15:53:02 | INFO |   processed 450/500 tickers...
# 2025-10-17 15:53:07 | INFO |   processed 500/500 tickers...
# 2025-10-17 15:53:07 | INFO | Portfolio: deploy 25% cash; 52w filter=True; VOLAR ranking=True; sizing=MVO; max 5 positions.
# 2025-10-17 15:53:07 | INFO | Selected 5 BUY candidates on 2016-01-11:
# 2025-10-17 15:53:07 | INFO |   WELSPUNLIV.NS volar=  2.33 rank=1 px=   80.01
# 2025-10-17 15:53:07 | INFO |   CANFINHOME.NS volar=  2.14 rank=2 px=  193.29
# 2025-10-17 15:53:07 | INFO |   KEI.NS       volar=  1.94 rank=3 px=  116.41
# 2025-10-17 15:53:07 | INFO |   NATCOPHARM.NS volar=  1.69 rank=4 px=  548.10
# 2025-10-17 15:53:07 | INFO |   ABFRL.NS     volar=  1.51 rank=5 px=  226.66
# 2025-10-17 15:53:07 | INFO | BUY WELSPUNLIV.NS px=   80.73 sh=   464 fee=68.08 cash=462471.89 :: Entry: BullishPattern + TogglesOK; Conf=[RSI>50]; 52w%=93.2%; VOLAR rank 1/5 (VOLAR=2.33); Sizing=MVO (weight=30.0%)
# 2025-10-17 15:53:07 | INFO | BUY CANFINHOME.NS px=  194.91 sh=   197 fee=69.19 cash=424005.58 :: Entry: BullishPattern + TogglesOK; Conf=[RSI>50]; 52w%=95.2%; VOLAR rank 2/5 (VOLAR=2.14); Sizing=MVO (weight=30.8%)
# 2025-10-17 15:53:07 | INFO | BUY KEI.NS       px=  120.69 sh=   144 fee=41.15 cash=406584.47 :: Entry: BullishPattern + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 3/5 (VOLAR=1.94); Sizing=MVO (weight=14.0%)
# 2025-10-17 15:53:07 | INFO | BUY NATCOPHARM.NS px=  541.19 sh=    27 fee=34.59 cash=391937.66 :: Entry: BullishPattern + TogglesOK; Conf=[RSI>50]; 52w%=97.9%; VOLAR rank 4/5 (VOLAR=1.69); Sizing=MVO (weight=11.9%)
# 2025-10-17 15:53:07 | INFO | BUY ABFRL.NS     px=  222.13 sh=    74 fee=38.91 cash=375461.19 :: Entry: BullishPattern + TogglesOK; Conf=[RSI>50]; 52w%=93.3%; VOLAR rank 5/5 (VOLAR=1.51); Sizing=MVO (weight=13.3%)
# 2025-10-17 15:53:07 | INFO | Exit ABFRL.NS     px=  215.33 shares=    74 :: Exit: StopLoss hit — StopLoss hit: Low 213.90 ≤ SL 215.33 (from entry 226.66) | net=-600.97 cash=391336.70
# 2025-10-17 15:53:07 | INFO | Selected 1 BUY candidates on 2016-01-12:
# 2025-10-17 15:53:07 | INFO |   APLAPOLLO.NS volar=  2.23 rank=1 px=   74.89
# 2025-10-17 15:53:07 | INFO | BUY APLAPOLLO.NS px=   75.39 sh=  1297 fee=139.71 cash=293416.33 :: Entry: BullishPattern + TogglesOK; Conf=[RSI>50]; 52w%=97.3%; VOLAR rank 1/1 (VOLAR=2.23); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:07 | INFO | Exit APLAPOLLO.NS px=   71.14 shares=  1297 :: Exit: StopLoss hit — StopLoss hit: Low 68.42 ≤ SL 71.14 (from entry 74.89) | net=-5792.26 cash=385544.43
# 2025-10-17 15:53:07 | INFO | Exit CANFINHOME.NS px=  183.62 shares=   197 :: Exit: StopLoss hit — StopLoss hit: Low 172.62 ≤ SL 183.62 (from entry 193.29) | net=-2377.42 cash=421633.32
# 2025-10-17 15:53:07 | INFO | Exit KEI.NS       px=  110.59 shares=   144 :: Exit: StopLoss hit — StopLoss hit: Low 108.14 ≤ SL 110.59 (from entry 116.41) | net=-1554.93 cash=437499.50
# 2025-10-17 15:53:07 | INFO | Exit NATCOPHARM.NS px=  520.70 shares=    27 :: Exit: StopLoss hit — StopLoss hit: Low 489.74 ≤ SL 520.70 (from entry 548.10) | net=-642.74 cash=451503.58
# 2025-10-17 15:53:07 | INFO | Exit WELSPUNLIV.NS px=   76.01 shares=   464 :: Exit: StopLoss hit — StopLoss hit: Low 75.30 ≤ SL 76.01 (from entry 80.01) | net=-2344.56 cash=486687.13
# 2025-10-17 15:53:07 | INFO | Selected 5 BUY candidates on 2016-01-13:
# 2025-10-17 15:53:07 | INFO |   KPRMILL.NS   volar=  2.27 rank=1 px=   82.04
# 2025-10-17 15:53:07 | INFO |   BAJAJFINSV.NS volar=  1.73 rank=2 px=  195.04
# 2025-10-17 15:53:07 | INFO |   SJVN.NS      volar=  1.29 rank=3 px=   18.27
# 2025-10-17 15:53:07 | INFO |   CHOLAHLDNG.NS volar=  1.08 rank=4 px=  280.81
# 2025-10-17 15:53:07 | INFO |   DEEPAKFERT.NS volar=  0.58 rank=5 px=  128.56
# 2025-10-17 15:53:07 | INFO | BUY KPRMILL.NS   px=   78.71 sh=   783 fee=96.78 cash=424959.59 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=92.6%; VOLAR rank 1/5 (VOLAR=2.27); Sizing=MVO (weight=50.7%)
# 2025-10-17 15:53:07 | INFO | BUY BAJAJFINSV.NS px=  197.77 sh=   186 fee=67.28 cash=388106.46 :: Entry: HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=96.0%; VOLAR rank 2/5 (VOLAR=1.73); Sizing=MVO (weight=30.3%)
# 2025-10-17 15:53:07 | INFO | BUY SJVN.NS      px=   17.33 sh=  1303 fee=50.41 cash=365473.86 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=96.1%; VOLAR rank 3/5 (VOLAR=1.29); Sizing=MVO (weight=18.6%)
# 2025-10-17 15:53:07 | INFO | BUY CHOLAHLDNG.NS px=  276.49 sh=     1 fee=6.23 cash=365191.14 :: Entry: HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=98.8%; VOLAR rank 4/5 (VOLAR=1.08); Sizing=MVO (weight=0.4%)
# 2025-10-17 15:53:07 | INFO | Skip BUY DEEPAKFERT.NS (alloc 0.00 too small)
# 2025-10-17 15:53:07 | INFO | Exit KPRMILL.NS   px=   77.94 shares=   783 :: Exit: StopLoss hit — StopLoss hit: Low 75.08 ≤ SL 77.94 (from entry 82.04) | net=-809.02 cash=426109.66
# 2025-10-17 15:53:07 | INFO | Exit SJVN.NS      px=   17.36 shares=  1303 :: Exit: StopLoss hit — StopLoss hit: Low 16.62 ≤ SL 17.36 (from entry 18.27) | net=-87.70 cash=448654.56
# 2025-10-17 15:53:07 | INFO | Selected 3 BUY candidates on 2016-01-14:
# 2025-10-17 15:53:07 | INFO |   TRIVENI.NS   volar=  1.74 rank=1 px=   46.77
# 2025-10-17 15:53:07 | INFO |   HINDPETRO.NS volar=  1.59 rank=2 px=   80.37
# 2025-10-17 15:53:07 | INFO |   SAMMAANCAP.NS volar=  1.49 rank=3 px=  466.99
# 2025-10-17 15:53:07 | INFO | BUY TRIVENI.NS   px=   47.14 sh=   704 fee=63.00 cash=415408.24 :: Entry: HARAMI + HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=97.9%; VOLAR rank 1/3 (VOLAR=1.74); Sizing=MVO (weight=29.6%)
# 2025-10-17 15:53:07 | INFO | BUY HINDPETRO.NS px=   82.79 sh=   481 fee=70.88 cash=375517.39 :: Entry: HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=92.6%; VOLAR rank 2/3 (VOLAR=1.59); Sizing=MVO (weight=35.5%)
# 2025-10-17 15:53:07 | INFO | BUY SAMMAANCAP.NS px=  466.89 sh=    83 fee=69.61 cash=336695.77 :: Entry: HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=90.5%; VOLAR rank 3/3 (VOLAR=1.49); Sizing=MVO (weight=34.9%)
# 2025-10-17 15:53:07 | INFO | Exit SAMMAANCAP.NS px=  443.64 shares=    83 :: Exit: StopLoss hit — StopLoss hit: Low 442.87 ≤ SL 443.64 (from entry 466.99) | net=-2084.64 cash=373432.75
# 2025-10-17 15:53:07 | INFO | Exit TRIVENI.NS   px=   44.43 shares=   704 :: Exit: StopLoss hit — StopLoss hit: Low 43.02 ≤ SL 44.43 (from entry 46.77) | net=-2046.67 cash=404632.40
# 2025-10-17 15:53:07 | INFO | Selected 2 BUY candidates on 2016-01-15:
# 2025-10-17 15:53:07 | INFO |   BPCL.NS      volar=  1.55 rank=1 px=   84.57
# 2025-10-17 15:53:07 | INFO |   GODREJCP.NS  volar=  1.00 rank=2 px=  397.07
# 2025-10-17 15:53:07 | INFO | BUY BPCL.NS      px=   86.59 sh=   842 fee=110.17 cash=331615.75 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=96.0%; VOLAR rank 1/2 (VOLAR=1.55); Sizing=MVO (weight=72.1%)
# 2025-10-17 15:53:07 | INFO | BUY GODREJCP.NS  px=  383.61 sh=    73 fee=56.85 cash=303555.11 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=91.2%; VOLAR rank 2/2 (VOLAR=1.00); Sizing=MVO (weight=27.9%)
# 2025-10-17 15:53:07 | INFO | Exit BAJAJFINSV.NS px=  185.29 shares=   186 :: Exit: StopLoss hit — StopLoss hit: Low 179.52 ≤ SL 185.29 (from entry 195.04) | net=-2472.19 cash=337936.05
# 2025-10-17 15:53:07 | INFO | Exit CHOLAHLDNG.NS px=  266.77 shares=     1 :: Exit: StopLoss hit — StopLoss hit: Low 248.76 ≤ SL 266.77 (from entry 280.81) | net=-45.73 cash=338173.04
# 2025-10-17 15:53:07 | INFO | Exit GODREJCP.NS  px=  377.21 shares=    73 :: Exit: StopLoss hit — StopLoss hit: Low 371.09 ≤ SL 377.21 (from entry 397.07) | net=-599.91 cash=365633.77
# 2025-10-17 15:53:07 | INFO | Exit HINDPETRO.NS px=   76.35 shares=   481 :: Exit: StopLoss hit — StopLoss hit: Low 75.89 ≤ SL 76.35 (from entry 80.37) | net=-3251.57 cash=402273.06
# 2025-10-17 15:53:07 | INFO | Selected 1 BUY candidates on 2016-01-19:
# 2025-10-17 15:53:07 | INFO |   EMAMILTD.NS  volar=  1.12 rank=1 px=  425.78
# 2025-10-17 15:53:07 | INFO | BUY EMAMILTD.NS  px=  437.68 sh=   229 fee=142.61 cash=301902.57 :: Entry: PIERCING + TogglesOK; Conf=[RSI>50]; 52w%=75.2%; VOLAR rank 1/1 (VOLAR=1.12); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:07 | INFO | Selected 3 BUY candidates on 2016-01-20:
# 2025-10-17 15:53:07 | INFO |   RELIANCE.NS  volar=  1.11 rank=1 px=  224.25
# 2025-10-17 15:53:07 | INFO |   TORNTPOWER.NS volar=  0.94 rank=2 px=  160.66
# 2025-10-17 15:53:07 | INFO |   OLECTRA.NS   volar=  0.86 rank=3 px=   19.87
# 2025-10-17 15:53:07 | INFO | BUY RELIANCE.NS  px=  217.67 sh=   172 fee=68.06 cash=264395.30 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=96.9%; VOLAR rank 1/3 (VOLAR=1.11); Sizing=MVO (weight=49.7%)
# 2025-10-17 15:53:07 | INFO | BUY TORNTPOWER.NS px=  163.80 sh=   116 fee=44.98 cash=245349.05 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=87.3%; VOLAR rank 2/3 (VOLAR=0.94); Sizing=MVO (weight=25.3%)
# 2025-10-17 15:53:07 | INFO | BUY OLECTRA.NS   px=   17.72 sh=  1064 fee=44.65 cash=226445.96 :: Entry: ENGULFING + MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=98.3%; VOLAR rank 3/3 (VOLAR=0.86); Sizing=MVO (weight=25.0%)
# 2025-10-17 15:53:07 | INFO | Exit BPCL.NS      px=   82.82 shares=   842 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 82.22 | net=-3399.91 cash=296062.70
# 2025-10-17 15:53:07 | INFO | Exit OLECTRA.NS   px=   18.88 shares=  1064 :: Exit: StopLoss hit — StopLoss hit: Low 17.57 ≤ SL 18.88 (from entry 19.87) | net=1114.44 cash=316080.23
# 2025-10-17 15:53:07 | INFO | Exit RELIANCE.NS  px=  213.03 shares=   172 :: Exit: StopLoss hit — StopLoss hit: Low 211.64 ≤ SL 213.03 (from entry 224.25) | net=-950.65 cash=352636.85
# 2025-10-17 15:53:07 | INFO | Exit TORNTPOWER.NS px=  176.73 shares=   116 :: Exit: TakeProfit hit — TakeProfit hit: High 178.12 ≥ TP 176.73 (from entry 160.66) | net=1385.80 cash=373068.90
# 2025-10-17 15:53:07 | INFO | Selected 3 BUY candidates on 2016-01-25:
# 2025-10-17 15:53:07 | INFO |   PETRONET.NS  volar=  1.32 rank=1 px=   89.85
# 2025-10-17 15:53:07 | INFO |   MRPL.NS      volar=  1.10 rank=2 px=   56.88
# 2025-10-17 15:53:07 | INFO |   RELIANCE.NS  volar=  1.04 rank=3 px=  218.85
# 2025-10-17 15:53:07 | INFO | BUY PETRONET.NS  px=   88.77 sh=   630 fee=90.00 cash=317054.86 :: Entry: ENGULFING + MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=93.7%; VOLAR rank 1/3 (VOLAR=1.32); Sizing=MVO (weight=60.1%)
# 2025-10-17 15:53:07 | INFO | BUY MRPL.NS      px=   55.22 sh=   544 fee=59.27 cash=286956.89 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=80.9%; VOLAR rank 2/3 (VOLAR=1.10); Sizing=MVO (weight=32.2%)
# 2025-10-17 15:53:07 | INFO | BUY RELIANCE.NS  px=  217.54 sh=    33 fee=17.00 cash=279761.08 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=93.2%; VOLAR rank 3/3 (VOLAR=1.04); Sizing=MVO (weight=7.7%)
# 2025-10-17 15:53:07 | INFO | Exit MRPL.NS      px=   56.11 shares=   544 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 55.22 | net=347.48 cash=310206.53
# 2025-10-17 15:53:07 | INFO | Exit PETRONET.NS  px=   88.95 shares=   630 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 88.77 | net=-83.98 cash=366136.59
# 2025-10-17 15:53:07 | INFO | Selected 2 BUY candidates on 2016-01-27:
# 2025-10-17 15:53:07 | INFO |   MUTHOOTFIN.NS volar=  0.39 rank=1 px=  150.90
# 2025-10-17 15:53:07 | INFO |   SUNPHARMA.NS volar=  0.36 rank=2 px=  755.55
# 2025-10-17 15:53:07 | INFO | BUY MUTHOOTFIN.NS px=  156.77 sh=   308 fee=80.93 cash=317771.42 :: Entry: ENGULFING + MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=80.1%; VOLAR rank 1/2 (VOLAR=0.39); Sizing=MVO (weight=52.8%)
# 2025-10-17 15:53:07 | INFO | BUY SUNPHARMA.NS px=  759.39 sh=    56 fee=74.10 cash=275171.68 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=69.3%; VOLAR rank 2/2 (VOLAR=0.36); Sizing=MVO (weight=47.2%)
# 2025-10-17 15:53:07 | INFO | Exit MUTHOOTFIN.NS px=  158.36 shares=   308 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 156.77 | net=311.86 cash=323848.70
# 2025-10-17 15:53:07 | INFO | Exit RELIANCE.NS  px=  216.90 shares=    33 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 216.54 | net=-77.56 cash=330966.95
# 2025-10-17 15:53:07 | INFO | Selected 3 BUY candidates on 2016-01-28:
# 2025-10-17 15:53:07 | INFO |   DIVISLAB.NS  volar=  1.58 rank=1 px= 1053.55
# 2025-10-17 15:53:07 | INFO |   TRIVENI.NS   volar=  1.57 rank=2 px=   43.75
# 2025-10-17 15:53:07 | INFO |   BALRAMCHIN.NS volar=  1.12 rank=3 px=   77.51
# 2025-10-17 15:53:07 | INFO | BUY DIVISLAB.NS  px= 1044.44 sh=    46 fee=80.65 cash=282842.00 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=93.8%; VOLAR rank 1/3 (VOLAR=1.58); Sizing=MVO (weight=58.9%)
# 2025-10-17 15:53:07 | INFO | BUY TRIVENI.NS   px=   42.97 sh=   767 fee=62.74 cash=249820.51 :: Entry: HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=88.8%; VOLAR rank 2/3 (VOLAR=1.57); Sizing=MVO (weight=39.9%)
# 2025-10-17 15:53:07 | INFO | BUY BALRAMCHIN.NS px=   77.51 sh=    13 fee=7.10 cash=248805.84 :: Entry: HARAMI + HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=99.2%; VOLAR rank 3/3 (VOLAR=1.12); Sizing=MVO (weight=1.3%)
# 2025-10-17 15:53:07 | INFO | Exit DIVISLAB.NS  px= 1061.88 shares=    46 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 1044.44 | net=623.53 cash=297554.31
# 2025-10-17 15:53:07 | INFO | Selected 1 BUY candidates on 2016-01-29:
# 2025-10-17 15:53:07 | INFO |   TORNTPOWER.NS volar=  1.20 rank=1 px=  175.38
# 2025-10-17 15:53:07 | INFO | BUY TORNTPOWER.NS px=  186.11 sh=   399 fee=111.78 cash=223183.13 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=93.7%; VOLAR rank 1/1 (VOLAR=1.20); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:07 | INFO | Exit TORNTPOWER.NS px=  192.91 shares=   399 :: Exit: TakeProfit hit — TakeProfit hit: High 193.95 ≥ TP 192.91 (from entry 175.38) | net=2474.50 cash=300028.81
# 2025-10-17 15:53:07 | INFO | Selected 1 BUY candidates on 2016-02-01:
# 2025-10-17 15:53:07 | INFO |   KAJARIACER.NS volar=  1.42 rank=1 px=  457.38
# 2025-10-17 15:53:07 | INFO | BUY KAJARIACER.NS px=  450.99 sh=   166 fee=112.49 cash=225051.90 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=98.4%; VOLAR rank 1/1 (VOLAR=1.42); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:07 | INFO | Exit TRIVENI.NS   px=   41.56 shares=   767 :: Exit: StopLoss hit — StopLoss hit: Low 39.72 ≤ SL 41.56 (from entry 43.75) | net=-1224.08 cash=256849.32
# 2025-10-17 15:53:07 | INFO | Selected 1 BUY candidates on 2016-02-03:
# 2025-10-17 15:53:07 | INFO |   LUPIN.NS     volar=  1.06 rank=1 px= 1606.21
# 2025-10-17 15:53:07 | INFO | BUY LUPIN.NS     px= 1605.12 sh=    40 fee=99.84 cash=192544.49 :: Entry: HARAMI + HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=80.9%; VOLAR rank 1/1 (VOLAR=1.06); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:07 | INFO | Exit BALRAMCHIN.NS px=   73.63 shares=    13 :: Exit: StopLoss hit — StopLoss hit: Low 71.78 ≤ SL 73.63 (from entry 77.51) | net=-87.97 cash=193471.19
# 2025-10-17 15:53:07 | INFO | Exit KAJARIACER.NS px=  434.51 shares=   166 :: Exit: StopLoss hit — StopLoss hit: Low 430.00 ≤ SL 434.51 (from entry 457.38) | net=-2969.84 cash=265478.25
# 2025-10-17 15:53:07 | INFO | Exit LUPIN.NS     px= 1606.21 shares=    40 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 1605.12 | net=-170.23 cash=329612.84
# 2025-10-17 15:53:07 | INFO | Selected 3 BUY candidates on 2016-02-04:
# 2025-10-17 15:53:07 | INFO |   BAJFINANCE.NS volar=  1.92 rank=1 px=   62.05
# 2025-10-17 15:53:07 | INFO |   CHOLAFIN.NS  volar=  1.52 rank=2 px=  125.85
# 2025-10-17 15:53:07 | INFO |   JBCHEPHARM.NS volar=  1.37 rank=3 px=  122.14
# 2025-10-17 15:53:07 | INFO | BUY BAJFINANCE.NS px=   61.40 sh=   647 fee=70.77 cash=289813.17 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 1/3 (VOLAR=1.92); Sizing=MVO (weight=48.2%)
# 2025-10-17 15:53:07 | INFO | BUY CHOLAFIN.NS  px=  129.40 sh=   221 fee=57.56 cash=261158.66 :: Entry: PIERCING + TogglesOK; Conf=[RSI>50]; 52w%=90.8%; VOLAR rank 2/3 (VOLAR=1.52); Sizing=MVO (weight=34.7%)
# 2025-10-17 15:53:07 | INFO | BUY JBCHEPHARM.NS px=  120.77 sh=   116 fee=33.17 cash=247115.97 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=87.3%; VOLAR rank 3/3 (VOLAR=1.37); Sizing=MVO (weight=17.0%)
# 2025-10-17 15:53:07 | INFO | Exit JBCHEPHARM.NS px=  116.03 shares=   116 :: Exit: StopLoss hit — StopLoss hit: Low 114.28 ≤ SL 116.03 (from entry 122.14) | net=-636.16 cash=260522.50
# 2025-10-17 15:53:07 | INFO | Selected 1 BUY candidates on 2016-02-05:
# 2025-10-17 15:53:07 | INFO |   HINDZINC.NS  volar=  0.62 rank=1 px=   64.68
# 2025-10-17 15:53:07 | INFO | BUY HINDZINC.NS  px=   66.76 sh=   975 fee=100.89 cash=195327.18 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=90.4%; VOLAR rank 1/1 (VOLAR=0.62); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:07 | INFO | Exit CHOLAFIN.NS  px=  138.43 shares=   221 :: Exit: TakeProfit hit — TakeProfit hit: High 139.41 ≥ TP 138.43 (from entry 125.85) | net=1860.13 cash=225841.82
# 2025-10-17 15:53:07 | INFO | Selected 1 BUY candidates on 2016-02-08:
# 2025-10-17 15:53:07 | INFO |   TATAELXSI.NS volar=  2.18 rank=1 px=  971.54
# 2025-10-17 15:53:07 | INFO | BUY TATAELXSI.NS px=  948.86 sh=    59 fee=90.07 cash=169768.97 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=92.2%; VOLAR rank 1/1 (VOLAR=2.18); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:07 | INFO | Exit TATAELXSI.NS px=  922.96 shares=    59 :: Exit: StopLoss hit — StopLoss hit: Low 912.14 ≤ SL 922.96 (from entry 971.54) | net=-1721.71 cash=224120.11
# 2025-10-17 15:53:07 | INFO | Selected 1 BUY candidates on 2016-02-09:
# 2025-10-17 15:53:07 | INFO |   FORTIS.NS    volar=  1.27 rank=1 px=  165.01
# 2025-10-17 15:53:07 | INFO | BUY FORTIS.NS    px=  163.42 sh=   342 fee=89.96 cash=168140.36 :: Entry: HARAMI + HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=86.6%; VOLAR rank 1/1 (VOLAR=1.27); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:07 | INFO | Exit FORTIS.NS    px=  164.81 shares=   342 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 163.42 | net=280.17 cash=224400.28
# 2025-10-17 15:53:07 | INFO | Selected 1 BUY candidates on 2016-02-10:
# 2025-10-17 15:53:07 | INFO |   WELSPUNLIV.NS volar=  2.28 rank=1 px=   82.87
# 2025-10-17 15:53:07 | INFO | BUY WELSPUNLIV.NS px=   83.16 sh=   674 fee=90.16 cash=168258.52 :: Entry: HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=96.6%; VOLAR rank 1/1 (VOLAR=2.28); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:07 | INFO | Exit BAJFINANCE.NS px=   58.95 shares=   647 :: Exit: StopLoss hit — StopLoss hit: Low 58.67 ≤ SL 58.95 (from entry 62.05) | net=-1744.78 cash=206313.42
# 2025-10-17 15:53:07 | INFO | Exit EMAMILTD.NS  px=  468.36 shares=   229 :: Exit: TakeProfit hit — TakeProfit hit: High 471.12 ≥ TP 468.36 (from entry 425.78) | net=6724.91 cash=313408.81
# 2025-10-17 15:53:07 | INFO | Exit HINDZINC.NS  px=   61.45 shares=   975 :: Exit: StopLoss hit — StopLoss hit: Low 61.35 ≤ SL 61.45 (from entry 64.68) | net=-5394.59 cash=373209.55
# 2025-10-17 15:53:07 | INFO | Exit WELSPUNLIV.NS px=   78.73 shares=   674 :: Exit: StopLoss hit — StopLoss hit: Low 77.15 ≤ SL 78.73 (from entry 82.87) | net=-3181.33 cash=426169.98
# 2025-10-17 15:53:07 | INFO | Selected 4 BUY candidates on 2016-02-11:
# 2025-10-17 15:53:07 | INFO |   CHOLAFIN.NS  volar=  1.44 rank=1 px=  133.24
# 2025-10-17 15:53:07 | INFO |   WELCORP.NS   volar=  1.02 rank=2 px=   80.27
# 2025-10-17 15:53:07 | INFO |   RAMCOCEM.NS  volar=  0.89 rank=3 px=  359.24
# 2025-10-17 15:53:07 | INFO |   CUMMINSIND.NS volar=  0.88 rank=4 px=  780.55
# 2025-10-17 15:53:07 | INFO | BUY CHOLAFIN.NS  px=  130.79 sh=   570 fee=112.12 cash=351508.88 :: Entry: HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=96.1%; VOLAR rank 1/4 (VOLAR=1.44); Sizing=MVO (weight=70.0%)
# 2025-10-17 15:53:07 | INFO | BUY WELCORP.NS   px=   75.21 sh=   424 fee=61.47 cash=319556.71 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=62.6%; VOLAR rank 2/4 (VOLAR=1.02); Sizing=MVO (weight=30.0%)
# 2025-10-17 15:53:07 | INFO | Skip BUY RAMCOCEM.NS  (alloc 0.00 too small)
# 2025-10-17 15:53:07 | INFO | Skip BUY CUMMINSIND.NS (alloc 0.00 too small)
# 2025-10-17 15:53:07 | INFO | Exit CHOLAFIN.NS  px=  126.58 shares=   570 :: Exit: StopLoss hit — StopLoss hit: Low 120.91 ≤ SL 126.58 (from entry 133.24) | net=-2633.55 cash=391584.26
# 2025-10-17 15:53:07 | INFO | Exit WELCORP.NS   px=   76.26 shares=   424 :: Exit: StopLoss hit — StopLoss hit: Low 69.64 ≤ SL 76.26 (from entry 80.27) | net=301.27 cash=423837.70
# 2025-10-17 15:53:07 | INFO | Selected 1 BUY candidates on 2016-02-12:
# 2025-10-17 15:53:07 | INFO |   ABB.NS       volar=  0.14 rank=1 px=  943.29
# 2025-10-17 15:53:07 | INFO | BUY ABB.NS       px=  906.15 sh=   116 fee=148.41 cash=318575.59 :: Entry: HARAMI + HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=74.8%; VOLAR rank 1/1 (VOLAR=0.14); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:07 | INFO | Selected 3 BUY candidates on 2016-02-15:
# 2025-10-17 15:53:07 | INFO |   COFORGE.NS   volar=  1.34 rank=1 px=   88.64
# 2025-10-17 15:53:07 | INFO |   GODREJCP.NS  volar=  0.99 rank=2 px=  380.49
# 2025-10-17 15:53:07 | INFO |   EMAMILTD.NS  volar=  0.95 rank=3 px=  457.69
# 2025-10-17 15:53:07 | INFO | BUY COFORGE.NS   px=   87.15 sh=   521 fee=77.51 cash=273095.14 :: Entry: HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=79.0%; VOLAR rank 1/3 (VOLAR=1.34); Sizing=MVO (weight=57.1%)
# 2025-10-17 15:53:07 | INFO | BUY GODREJCP.NS  px=  385.67 sh=    49 fee=44.74 cash=254152.45 :: Entry: HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=86.0%; VOLAR rank 2/3 (VOLAR=0.99); Sizing=MVO (weight=24.1%)
# 2025-10-17 15:53:07 | INFO | BUY EMAMILTD.NS  px=  449.66 sh=    33 fee=35.13 cash=239278.56 :: Entry: HARAMI + HAMMER + INVERTED_HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=77.2%; VOLAR rank 3/3 (VOLAR=0.95); Sizing=MVO (weight=18.9%)
# 2025-10-17 15:53:07 | INFO | Exit COFORGE.NS   px=   87.41 shares=   521 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 87.15 | net=-35.60 cash=284723.41
# 2025-10-17 15:53:07 | INFO | Exit EMAMILTD.NS  px=  434.81 shares=    33 :: Exit: StopLoss hit — StopLoss hit: Low 434.37 ≤ SL 434.81 (from entry 457.69) | net=-580.68 cash=299016.62
# 2025-10-17 15:53:07 | INFO | Exit GODREJCP.NS  px=  381.91 shares=    49 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 385.67 | net=-294.09 cash=317665.22
# 2025-10-17 15:53:07 | INFO | Selected 3 BUY candidates on 2016-02-16:
# 2025-10-17 15:53:07 | INFO |   WELSPUNLIV.NS volar=  2.29 rank=1 px=   79.45
# 2025-10-17 15:53:07 | INFO |   ASHOKLEY.NS  volar=  1.55 rank=2 px=   38.01
# 2025-10-17 15:53:07 | INFO |   TORNTPOWER.NS volar=  1.15 rank=3 px=  175.10
# 2025-10-17 15:53:07 | INFO | BUY WELSPUNLIV.NS px=   80.23 sh=   679 fee=88.29 cash=263098.09 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=91.9%; VOLAR rank 1/3 (VOLAR=2.29); Sizing=MVO (weight=68.7%)
# 2025-10-17 15:53:07 | INFO | BUY ASHOKLEY.NS  px=   36.65 sh=   516 fee=44.77 cash=244142.73 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=91.9%; VOLAR rank 2/3 (VOLAR=1.55); Sizing=MVO (weight=23.8%)
# 2025-10-17 15:53:07 | INFO | BUY TORNTPOWER.NS px=  166.67 sh=    35 fee=13.81 cash=238295.56 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=91.8%; VOLAR rank 3/3 (VOLAR=1.15); Sizing=MVO (weight=7.5%)
# 2025-10-17 15:53:07 | INFO | Exit ASHOKLEY.NS  px=   36.11 shares=   516 :: Exit: StopLoss hit — StopLoss hit: Low 35.75 ≤ SL 36.11 (from entry 38.01) | net=-386.03 cash=256864.90
# 2025-10-17 15:53:07 | INFO | Exit TORNTPOWER.NS px=  166.34 shares=    35 :: Exit: StopLoss hit — StopLoss hit: Low 160.78 ≤ SL 166.34 (from entry 175.10) | net=-61.66 cash=262650.40
# 2025-10-17 15:53:08 | INFO | Selected 2 BUY candidates on 2016-02-18:
# 2025-10-17 15:53:08 | INFO |   BAJFINANCE.NS volar=  1.91 rank=1 px=   59.62
# 2025-10-17 15:53:08 | INFO |   EICHERMOT.NS volar=  1.14 rank=2 px= 1761.24
# 2025-10-17 15:53:08 | INFO | BUY BAJFINANCE.NS px=   59.66 sh=   903 fee=87.57 cash=208687.13 :: Entry: HARAMI + HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=91.2%; VOLAR rank 1/2 (VOLAR=1.91); Sizing=MVO (weight=82.1%)
# 2025-10-17 15:53:08 | INFO | BUY EICHERMOT.NS px= 1732.94 sh=     6 fee=24.62 cash=198264.89 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=88.1%; VOLAR rank 2/2 (VOLAR=1.14); Sizing=MVO (weight=17.9%)
# 2025-10-17 15:53:08 | INFO | Exit BAJFINANCE.NS px=   56.64 shares=   903 :: Exit: StopLoss hit — StopLoss hit: Low 56.64 ≤ SL 56.64 (from entry 59.62) | net=-2914.42 cash=249313.74
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-02-22:
# 2025-10-17 15:53:08 | INFO |   CEATLTD.NS   volar=  1.24 rank=1 px=  865.46
# 2025-10-17 15:53:08 | INFO | BUY CEATLTD.NS   px=  877.83 sh=    71 fee=97.61 cash=186890.34 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=73.2%; VOLAR rank 1/1 (VOLAR=1.24); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit ABB.NS       px=  896.13 shares=   116 :: Exit: StopLoss hit — StopLoss hit: Low 872.68 ≤ SL 896.13 (from entry 943.29) | net=-1466.44 cash=290686.01
# 2025-10-17 15:53:08 | INFO | Exit WELSPUNLIV.NS px=   75.48 shares=   679 :: Exit: StopLoss hit — StopLoss hit: Low 71.83 ≤ SL 75.48 (from entry 79.45) | net=-3416.17 cash=341836.96
# 2025-10-17 15:53:08 | INFO | Selected 2 BUY candidates on 2016-02-26:
# 2025-10-17 15:53:08 | INFO |   MARICO.NS    volar=  1.78 rank=1 px=  209.97
# 2025-10-17 15:53:08 | INFO |   FORTIS.NS    volar=  0.98 rank=2 px=  168.34
# 2025-10-17 15:53:08 | INFO | BUY MARICO.NS    px=  205.35 sh=   343 fee=107.23 cash=271295.10 :: Entry: ENGULFING + MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 1/2 (VOLAR=1.78); Sizing=MVO (weight=82.5%)
# 2025-10-17 15:53:08 | INFO | BUY FORTIS.NS    px=  165.95 sh=    89 fee=34.97 cash=256490.19 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=86.4%; VOLAR rank 2/2 (VOLAR=0.98); Sizing=MVO (weight=17.5%)
# 2025-10-17 15:53:08 | INFO | Exit FORTIS.NS    px=  166.60 shares=    89 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 165.95 | net=-33.96 cash=271261.14
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-02-29:
# 2025-10-17 15:53:08 | INFO |   NHPC.NS      volar=  1.02 rank=1 px=   12.38
# 2025-10-17 15:53:08 | INFO | BUY NHPC.NS      px=   12.51 sh=  5422 fee=104.11 cash=203352.58 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=93.9%; VOLAR rank 1/1 (VOLAR=1.02); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit CEATLTD.NS   px=  952.00 shares=    71 :: Exit: TakeProfit hit — TakeProfit hit: High 960.61 ≥ TP 952.00 (from entry 865.46) | net=5051.54 cash=270827.52
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-03-02:
# 2025-10-17 15:53:08 | INFO |   APLLTD.NS    volar=  1.83 rank=1 px=  557.89
# 2025-10-17 15:53:08 | INFO | BUY APLLTD.NS    px=  555.92 sh=   121 fee=103.47 cash=203457.57 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=80.5%; VOLAR rank 1/1 (VOLAR=1.83); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit APLLTD.NS    px=  557.89 shares=   121 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 555.92 | net=16.93 cash=270844.45
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-03-03:
# 2025-10-17 15:53:08 | INFO |   BRITANNIA.NS volar=  1.62 rank=1 px= 1257.18
# 2025-10-17 15:53:08 | INFO | BUY BRITANNIA.NS px= 1241.39 sh=    54 fee=103.20 cash=203706.17 :: Entry: INVERTED_HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=84.2%; VOLAR rank 1/1 (VOLAR=1.62); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit BRITANNIA.NS px= 1194.32 shares=    54 :: Exit: StopLoss hit — StopLoss hit: Low 1168.13 ≤ SL 1194.32 (from entry 1257.18) | net=-2758.97 cash=268085.48
# 2025-10-17 15:53:08 | INFO | Exit NHPC.NS      px=   13.62 shares=  5422 :: Exit: TakeProfit hit — TakeProfit hit: High 13.69 ≥ TP 13.62 (from entry 12.38) | net=5810.39 cash=341804.43
# 2025-10-17 15:53:08 | INFO | Selected 2 BUY candidates on 2016-03-16:
# 2025-10-17 15:53:08 | INFO |   APLAPOLLO.NS volar=  1.61 rank=1 px=   62.63
# 2025-10-17 15:53:08 | INFO |   INTELLECT.NS volar=  1.35 rank=2 px=  189.76
# 2025-10-17 15:53:08 | INFO | BUY APLAPOLLO.NS px=   61.23 sh=   885 fee=87.94 cash=287532.22 :: Entry: HARAMI + HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=82.9%; VOLAR rank 1/2 (VOLAR=1.61); Sizing=MVO (weight=63.5%)
# 2025-10-17 15:53:08 | INFO | BUY INTELLECT.NS px=  187.73 sh=   166 fee=60.60 cash=256307.88 :: Entry: INVERTED_HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=71.1%; VOLAR rank 2/2 (VOLAR=1.35); Sizing=MVO (weight=36.5%)
# 2025-10-17 15:53:08 | INFO | Exit EICHERMOT.NS px= 1673.18 shares=     6 :: Exit: StopLoss hit — StopLoss hit: Low 1668.09 ≤ SL 1673.18 (from entry 1761.24) | net=-429.02 cash=266301.10
# 2025-10-17 15:53:08 | INFO | Exit SUNPHARMA.NS px=  778.67 shares=    56 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 772.89 | net=913.25 cash=309814.10
# 2025-10-17 15:53:08 | INFO | Selected 2 BUY candidates on 2016-03-17:
# 2025-10-17 15:53:08 | INFO |   JUBLPHARMA.NS volar=  1.86 rank=1 px=  261.15
# 2025-10-17 15:53:08 | INFO |   SAREGAMA.NS  volar=  1.42 rank=2 px=   22.92
# 2025-10-17 15:53:08 | INFO | BUY JUBLPHARMA.NS px=  262.38 sh=   195 fee=84.35 cash=258564.93 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=83.7%; VOLAR rank 1/2 (VOLAR=1.86); Sizing=MVO (weight=66.3%)
# 2025-10-17 15:53:08 | INFO | BUY SAREGAMA.NS  px=   23.27 sh=  1123 fee=54.63 cash=232378.59 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=49.7%; VOLAR rank 2/2 (VOLAR=1.42); Sizing=MVO (weight=33.7%)
# 2025-10-17 15:53:08 | INFO | Exit SAREGAMA.NS  px=   23.53 shares=  1123 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 23.27 | net=165.86 cash=258730.79
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-03-18:
# 2025-10-17 15:53:08 | INFO |   CHENNPETRO.NS volar=  1.79 rank=1 px=  154.80
# 2025-10-17 15:53:08 | INFO | BUY CHENNPETRO.NS px=  151.62 sh=   426 fee=100.30 cash=194039.48 :: Entry: INVERTED_HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=77.9%; VOLAR rank 1/1 (VOLAR=1.79); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit JUBLPHARMA.NS px=  287.27 shares=   195 :: Exit: TakeProfit hit — TakeProfit hit: High 309.91 ≥ TP 287.27 (from entry 261.15) | net=4662.21 cash=249950.86
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-03-21:
# 2025-10-17 15:53:08 | INFO |   WELSPUNLIV.NS volar=  2.62 rank=1 px=   86.90
# 2025-10-17 15:53:08 | INFO | BUY WELSPUNLIV.NS px=   90.27 sh=   692 fee=97.78 cash=187383.45 :: Entry: HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=94.6%; VOLAR rank 1/1 (VOLAR=2.62); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit WELSPUNLIV.NS px=   95.59 shares=   692 :: Exit: TakeProfit hit — TakeProfit hit: High 102.99 ≥ TP 95.59 (from entry 86.90) | net=3464.85 cash=253415.71
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-03-23:
# 2025-10-17 15:53:08 | INFO |   NAVINFLUOR.NS volar=  1.71 rank=1 px=  268.99
# 2025-10-17 15:53:08 | INFO | BUY NAVINFLUOR.NS px=  317.14 sh=   199 fee=98.54 cash=190207.02 :: Entry: INVERTED_HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=71.6%; VOLAR rank 1/1 (VOLAR=1.71); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit NAVINFLUOR.NS px=  295.89 shares=   199 :: Exit: TakeProfit hit — TakeProfit hit: High 350.99 ≥ TP 295.89 (from entry 268.99) | net=-4435.23 cash=248980.48
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-03-28:
# 2025-10-17 15:53:08 | INFO |   TRIDENT.NS   volar=  1.61 rank=1 px=    3.96
# 2025-10-17 15:53:08 | INFO | BUY TRIDENT.NS   px=    3.70 sh= 16831 fee=97.51 cash=186639.97 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=83.6%; VOLAR rank 1/1 (VOLAR=1.61); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit TRIDENT.NS   px=    3.76 shares= 16831 :: Exit: StopLoss hit — StopLoss hit: Low 3.70 ≤ SL 3.76 (from entry 3.96) | net=846.96 cash=249827.44
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-03-29:
# 2025-10-17 15:53:08 | INFO |   SAREGAMA.NS  volar=  1.48 rank=1 px=   24.82
# 2025-10-17 15:53:08 | INFO | BUY SAREGAMA.NS  px=   24.23 sh=  2577 fee=97.76 cash=187277.16 :: Entry: ENGULFING + INVERTED_HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=54.7%; VOLAR rank 1/1 (VOLAR=1.48); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit INTELLECT.NS px=  208.74 shares=   166 :: Exit: TakeProfit hit — TakeProfit hit: High 210.72 ≥ TP 208.74 (from entry 189.76) | net=3342.67 cash=221844.18
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-03-30:
# 2025-10-17 15:53:08 | INFO |   TRIDENT.NS   volar=  1.74 rank=1 px=    3.89
# 2025-10-17 15:53:08 | INFO | BUY TRIDENT.NS   px=    3.98 sh= 13925 fee=89.45 cash=166297.18 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=82.1%; VOLAR rank 1/1 (VOLAR=1.74); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit SAREGAMA.NS  px=   27.30 shares=  2577 :: Exit: TakeProfit hit — TakeProfit hit: High 27.91 ≥ TP 27.30 (from entry 24.82) | net=7684.08 cash=236531.54
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-04-04:
# 2025-10-17 15:53:08 | INFO |   ASHOKLEY.NS  volar=  1.70 rank=1 px=   46.62
# 2025-10-17 15:53:08 | INFO | BUY ASHOKLEY.NS  px=   46.25 sh=  1278 fee=93.78 cash=177334.94 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 1/1 (VOLAR=1.70); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit APLAPOLLO.NS px=   68.89 shares=   885 :: Exit: TakeProfit hit — TakeProfit hit: High 69.75 ≥ TP 68.89 (from entry 62.63) | net=6584.63 cash=238191.78
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-04-07:
# 2025-10-17 15:53:08 | INFO |   TRIVENI.NS   volar=  2.09 rank=1 px=   48.23
# 2025-10-17 15:53:08 | INFO | BUY TRIVENI.NS   px=   46.63 sh=  1276 fee=94.25 cash=178595.10 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=96.9%; VOLAR rank 1/1 (VOLAR=2.09); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit TRIVENI.NS   px=   45.82 shares=  1276 :: Exit: StopLoss hit — StopLoss hit: Low 45.81 ≤ SL 45.82 (from entry 48.23) | net=-1235.66 cash=236956.12
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-04-08:
# 2025-10-17 15:53:08 | INFO |   AARTIIND.NS  volar=  1.48 rank=1 px=  123.48
# 2025-10-17 15:53:08 | INFO | BUY AARTIIND.NS  px=  123.25 sh=   480 fee=93.84 cash=177704.16 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=93.8%; VOLAR rank 1/1 (VOLAR=1.48); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit CHENNPETRO.NS px=  170.28 shares=   426 :: Exit: TakeProfit hit — TakeProfit hit: High 173.61 ≥ TP 170.28 (from entry 154.80) | net=7726.41 cash=250121.87
# 2025-10-17 15:53:08 | INFO | Exit TRIDENT.NS   px=    4.28 shares= 13925 :: Exit: TakeProfit hit — TakeProfit hit: High 4.33 ≥ TP 4.28 (from entry 3.89) | net=3894.87 cash=309563.73
# 2025-10-17 15:53:08 | INFO | Selected 2 BUY candidates on 2016-04-21:
# 2025-10-17 15:53:08 | INFO |   INFY.NS      volar=  0.82 rank=1 px=  484.77
# 2025-10-17 15:53:08 | INFO |   ASAHIINDIA.NS volar=  0.67 rank=2 px=  157.20
# 2025-10-17 15:53:08 | INFO | BUY INFY.NS      px=  475.20 sh=   102 fee=81.15 cash=261011.94 :: Entry: HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 1/2 (VOLAR=0.82); Sizing=MVO (weight=62.7%)
# 2025-10-17 15:53:08 | INFO | BUY ASAHIINDIA.NS px=  153.48 sh=   187 fee=57.68 cash=232252.59 :: Entry: INVERTED_HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=92.6%; VOLAR rank 2/2 (VOLAR=0.67); Sizing=MVO (weight=37.3%)
# 2025-10-17 15:53:08 | INFO | Exit ASHOKLEY.NS  px=   44.29 shares=  1278 :: Exit: StopLoss hit — StopLoss hit: Low 44.06 ≤ SL 44.29 (from entry 46.62) | net=-2695.87 cash=288753.33
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-04-22:
# 2025-10-17 15:53:08 | INFO |   APLAPOLLO.NS volar=  1.86 rank=1 px=   76.22
# 2025-10-17 15:53:08 | INFO | BUY APLAPOLLO.NS px=   76.62 sh=   942 fee=109.30 cash=216471.95 :: Entry: INVERTED_HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=98.2%; VOLAR rank 1/1 (VOLAR=1.86); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit MARICO.NS    px=  230.97 shares=   343 :: Exit: TakeProfit hit — TakeProfit hit: High 233.25 ≥ TP 230.97 (from entry 209.97) | net=8551.77 cash=295565.58
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-05-02:
# 2025-10-17 15:53:08 | INFO |   TRIVENI.NS   volar=  2.10 rank=1 px=   47.78
# 2025-10-17 15:53:08 | INFO | BUY TRIVENI.NS   px=   48.37 sh=  1527 fee=111.30 cash=221591.80 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=95.3%; VOLAR rank 1/1 (VOLAR=2.10); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit INFY.NS      px=  460.54 shares=   102 :: Exit: StopLoss hit — StopLoss hit: Low 454.08 ≤ SL 460.54 (from entry 484.77) | net=-1673.14 cash=268470.45
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-05-03:
# 2025-10-17 15:53:08 | INFO |   KPRMILL.NS   volar=  1.34 rank=1 px=   79.68
# 2025-10-17 15:53:08 | INFO | BUY KPRMILL.NS   px=   84.06 sh=   798 fee=103.25 cash=201285.34 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=91.3%; VOLAR rank 1/1 (VOLAR=1.34); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit KPRMILL.NS   px=   87.65 shares=   798 :: Exit: TakeProfit hit — TakeProfit hit: High 88.38 ≥ TP 87.65 (from entry 79.68) | net=2639.91 cash=271110.35
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-05-05:
# 2025-10-17 15:53:08 | INFO |   BIOCON.NS    volar=  1.53 rank=1 px=  101.93
# 2025-10-17 15:53:08 | INFO | BUY BIOCON.NS    px=  101.56 sh=   667 fee=104.03 cash=203269.04 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 1/1 (VOLAR=1.53); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit ASAHIINDIA.NS px=  149.34 shares=   187 :: Exit: StopLoss hit — StopLoss hit: Low 145.29 ≤ SL 149.34 (from entry 157.20) | net=-909.53 cash=231118.86
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-05-06:
# 2025-10-17 15:53:08 | INFO |   BALRAMCHIN.NS volar=  1.91 rank=1 px=   96.00
# 2025-10-17 15:53:08 | INFO | BUY BALRAMCHIN.NS px=   95.96 sh=   602 fee=92.19 cash=173260.56 :: Entry: MORNING_STAR + INVERTED_HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=98.6%; VOLAR rank 1/1 (VOLAR=1.91); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit AARTIIND.NS  px=  120.55 shares=   480 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 118.89 | net=-1493.27 cash=231019.24
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-05-12:
# 2025-10-17 15:53:08 | INFO |   BAJFINANCE.NS volar=  2.05 rank=1 px=   72.99
# 2025-10-17 15:53:08 | INFO | BUY BAJFINANCE.NS px=   74.45 sh=   775 fee=92.11 cash=173229.15 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 1/1 (VOLAR=2.05); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit APLAPOLLO.NS px=   83.84 shares=   942 :: Exit: TakeProfit hit — TakeProfit hit: High 84.39 ≥ TP 83.84 (from entry 76.22) | net=6565.19 cash=252075.71
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-05-13:
# 2025-10-17 15:53:08 | INFO |   MAHSCOOTER.NS volar=  1.42 rank=1 px= 1108.98
# 2025-10-17 15:53:08 | INFO | BUY MAHSCOOTER.NS px= 1160.06 sh=    54 fee=97.98 cash=189334.61 :: Entry: INVERTED_HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=90.1%; VOLAR rank 1/1 (VOLAR=1.42); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit TRIVENI.NS   px=   52.55 shares=  1527 :: Exit: TakeProfit hit — TakeProfit hit: High 53.45 ≥ TP 52.55 (from entry 47.78) | net=6145.22 cash=269453.62
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-05-16:
# 2025-10-17 15:53:08 | INFO |   DCMSHRIRAM.NS volar=  1.36 rank=1 px=  158.25
# 2025-10-17 15:53:08 | INFO | BUY DCMSHRIRAM.NS px=  154.58 sh=   435 fee=103.44 cash=202107.44 :: Entry: INVERTED_HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 1/1 (VOLAR=1.36); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit DCMSHRIRAM.NS px=  150.33 shares=   435 :: Exit: StopLoss hit — StopLoss hit: Low 150.31 ≤ SL 150.33 (from entry 158.25) | net=-2066.02 cash=267387.60
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-05-18:
# 2025-10-17 15:53:08 | INFO |   KEI.NS       volar=  1.48 rank=1 px=  110.96
# 2025-10-17 15:53:08 | INFO | BUY KEI.NS       px=  115.44 sh=   579 fee=102.96 cash=200445.93 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=93.5%; VOLAR rank 1/1 (VOLAR=1.48); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit BALRAMCHIN.NS px=   91.20 shares=   602 :: Exit: StopLoss hit — StopLoss hit: Low 89.48 ≤ SL 91.20 (from entry 96.00) | net=-3059.47 cash=255244.76
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-05-24:
# 2025-10-17 15:53:08 | INFO |   BAJAJHLDNG.NS volar=  1.00 rank=1 px= 1311.96
# 2025-10-17 15:53:08 | INFO | BUY BAJAJHLDNG.NS px= 1314.31 sh=    48 fee=98.51 cash=192059.39 :: Entry: HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=87.7%; VOLAR rank 1/1 (VOLAR=1.00); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit BIOCON.NS    px=  112.13 shares=   667 :: Exit: TakeProfit hit — TakeProfit hit: High 117.59 ≥ TP 112.13 (from entry 101.93) | net=6821.66 cash=266722.35
# 2025-10-17 15:53:08 | INFO | Selected 1 BUY candidates on 2016-05-27:
# 2025-10-17 15:53:08 | INFO |   BALRAMCHIN.NS volar=  1.97 rank=1 px=   96.09
# 2025-10-17 15:53:08 | INFO | BUY BALRAMCHIN.NS px=   94.94 sh=   702 fee=102.74 cash=199968.82 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=91.8%; VOLAR rank 1/1 (VOLAR=1.97); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:08 | INFO | Exit BALRAMCHIN.NS px=   94.02 shares=   702 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 94.94 | net=-867.62 cash=265854.73
# 2025-10-17 15:53:08 | INFO | Exit KEI.NS       px=  105.41 shares=   579 :: Exit: StopLoss hit — StopLoss hit: Low 103.66 ≤ SL 105.41 (from entry 110.96) | net=-6018.19 cash=326778.21
# 2025-10-17 15:53:08 | INFO | Selected 2 BUY candidates on 2016-05-30:
# 2025-10-17 15:53:08 | INFO |   APLAPOLLO.NS volar=  1.84 rank=1 px=   84.86
# 2025-10-17 15:53:08 | INFO |   UNOMINDA.NS  volar=  1.74 rank=2 px=   38.18
# 2025-10-17 15:53:08 | INFO | BUY APLAPOLLO.NS px=   84.63 sh=   546 fee=78.47 cash=280490.76 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 1/2 (VOLAR=1.84); Sizing=MVO (weight=56.7%)
# 2025-10-17 15:53:08 | INFO | BUY UNOMINDA.NS  px=   37.53 sh=   943 fee=65.62 cash=245036.96 :: Entry: HARAMI + HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 2/2 (VOLAR=1.74); Sizing=MVO (weight=43.3%)
# 2025-10-17 15:53:09 | INFO | Exit MAHSCOOTER.NS px= 1219.87 shares=    54 :: Exit: TakeProfit hit — TakeProfit hit: High 1243.42 ≥ TP 1219.87 (from entry 1108.98) | net=3016.55 cash=310794.61
# 2025-10-17 15:53:09 | INFO | Selected 1 BUY candidates on 2016-06-10:
# 2025-10-17 15:53:09 | INFO |   PETRONET.NS  volar=  1.42 rank=1 px=   96.37
# 2025-10-17 15:53:09 | INFO | BUY PETRONET.NS  px=   97.57 sh=   796 fee=115.82 cash=233012.34 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=96.8%; VOLAR rank 1/1 (VOLAR=1.42); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:09 | INFO | Exit UNOMINDA.NS  px=   36.27 shares=   943 :: Exit: StopLoss hit — StopLoss hit: Low 34.80 ≤ SL 36.27 (from entry 38.18) | net=-1330.29 cash=267135.85
# 2025-10-17 15:53:09 | INFO | Selected 1 BUY candidates on 2016-06-24:
# 2025-10-17 15:53:09 | INFO |   IGL.NS       volar=  1.51 rank=1 px=   51.59
# 2025-10-17 15:53:09 | INFO | BUY IGL.NS       px=   53.46 sh=  1249 fee=102.88 cash=200263.85 :: Entry: HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=98.1%; VOLAR rank 1/1 (VOLAR=1.51); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:09 | INFO | Exit BAJAJHLDNG.NS px= 1443.15 shares=    48 :: Exit: TakeProfit hit — TakeProfit hit: High 1477.85 ≥ TP 1443.15 (from entry 1311.96) | net=5966.83 cash=269416.06
# 2025-10-17 15:53:09 | INFO | Selected 1 BUY candidates on 2016-06-30:
# 2025-10-17 15:53:09 | INFO |   BALRAMCHIN.NS volar=  2.29 rank=1 px=  110.97
# 2025-10-17 15:53:09 | INFO | BUY BALRAMCHIN.NS px=  110.71 sh=   608 fee=103.53 cash=202001.18 :: Entry: HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=99.4%; VOLAR rank 1/1 (VOLAR=2.29); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:09 | INFO | Exit PETRONET.NS  px=  106.01 shares=   796 :: Exit: TakeProfit hit — TakeProfit hit: High 106.74 ≥ TP 106.01 (from entry 96.37) | net=6463.65 cash=286247.09
# ...
# 2025-10-17 15:53:57 | INFO |   ECLERX.NS    volar=  0.65 rank=2 px= 3340.16
# 2025-10-17 15:53:57 | INFO | BUY CDSL.NS      px= 1527.79 sh=   122 fee=244.92 cash=1238184.90 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=96.5%; VOLAR rank 1/2 (VOLAR=0.95); Sizing=MVO (weight=52.6%)
# 2025-10-17 15:53:57 | INFO | BUY ECLERX.NS    px= 3266.73 sh=    51 fee=221.43 cash=1071360.10 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=98.0%; VOLAR rank 2/2 (VOLAR=0.65); Sizing=MVO (weight=47.4%)
# 2025-10-17 15:53:57 | INFO | Exit MOTILALOFS.NS px=  902.95 shares=   451 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 900.47 | net=8812.83 cash=1478122.90
# 2025-10-17 15:53:57 | INFO | Selected 1 BUY candidates on 2024-11-26:
# 2025-10-17 15:53:57 | INFO |   GVT&D.NS     volar=  2.98 rank=1 px= 1820.17
# 2025-10-17 15:53:57 | INFO | BUY GVT&D.NS     px= 1820.17 sh=   203 fee=462.34 cash=1108167.06 :: Entry: HARAMI + HARAMI_CROSS + TogglesOK; Conf=[RSI>50]; 52w%=98.9%; VOLAR rank 1/1 (VOLAR=2.98); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:57 | INFO | Exit CAPLIPOINT.NS px= 2183.03 shares=    73 :: Exit: TakeProfit hit — TakeProfit hit: High 2189.02 ≥ TP 2183.03 (from entry 1984.58) | net=16838.04 cash=1267315.91
# 2025-10-17 15:53:58 | INFO | Selected 1 BUY candidates on 2024-11-28:
# 2025-10-17 15:53:58 | INFO |   NEULANDLAB.NS volar=  1.86 rank=1 px=16071.69
# 2025-10-17 15:53:58 | INFO | BUY NEULANDLAB.NS px=16579.47 sh=    19 fee=397.64 cash=951908.36 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=98.9%; VOLAR rank 1/1 (VOLAR=1.86); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:58 | INFO | Exit GVT&D.NS     px= 1729.16 shares=   203 :: Exit: StopLoss hit — StopLoss hit: Low 1705.87 ≤ SL 1729.16 (from entry 1820.17) | net=-19348.36 cash=1302515.84
# 2025-10-17 15:53:58 | INFO | Selected 1 BUY candidates on 2024-11-29:
# 2025-10-17 15:53:58 | INFO |   NAVA.NS      volar=  1.81 rank=1 px=  554.47
# 2025-10-17 15:53:58 | INFO | BUY NAVA.NS      px=  524.47 sh=   620 fee=409.71 cash=976936.00 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=83.7%; VOLAR rank 1/1 (VOLAR=1.81); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:58 | INFO | Exit NAVA.NS      px=  526.75 shares=   620 :: Exit: StopLoss hit — StopLoss hit: Low 503.35 ≤ SL 526.75 (from entry 554.47) | net=616.20 cash=1303132.04
# 2025-10-17 15:53:58 | INFO | Exit POLICYBZR.NS px= 1926.10 shares=   132 :: Exit: TakeProfit hit — TakeProfit hit: High 2005.00 ≥ TP 1926.10 (from entry 1751.00) | net=27572.40 cash=1557066.29
# 2025-10-17 15:53:58 | INFO | Selected 2 BUY candidates on 2024-12-02:
# 2025-10-17 15:53:58 | INFO |   TRENT.NS     volar=  2.07 rank=1 px= 6771.18
# 2025-10-17 15:53:58 | INFO |   M&M.NS       volar=  1.45 rank=2 px= 2960.22
# 2025-10-17 15:53:58 | INFO | BUY TRENT.NS     px= 6799.41 sh=    30 fee=265.81 cash=1352818.20 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=82.5%; VOLAR rank 1/2 (VOLAR=2.07); Sizing=MVO (weight=53.1%)
# 2025-10-17 15:53:58 | INFO | BUY M&M.NS       px= 2992.36 sh=    61 fee=240.34 cash=1170043.95 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=92.9%; VOLAR rank 2/2 (VOLAR=1.45); Sizing=MVO (weight=46.9%)
# 2025-10-17 15:53:58 | INFO | Exit TRENT.NS     px= 6799.41 shares=    30 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 6799.41 | net=-524.62 cash=1373767.41
# 2025-10-17 15:53:58 | INFO | Selected 1 BUY candidates on 2024-12-03:
# 2025-10-17 15:53:58 | INFO |   ZENTEC.NS    volar=  1.55 rank=1 px= 1899.32
# 2025-10-17 15:53:58 | INFO | BUY ZENTEC.NS    px= 1803.86 sh=   190 fee=430.56 cash=1030603.73 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=96.6%; VOLAR rank 1/1 (VOLAR=1.55); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:58 | INFO | Exit CDSL.NS      px= 1690.88 shares=   122 :: Exit: TakeProfit hit — TakeProfit hit: High 1717.20 ≥ TP 1690.88 (from entry 1537.17) | net=19390.88 cash=1236630.32
# 2025-10-17 15:53:58 | INFO | Exit NEULANDLAB.NS px=17678.86 shares=    19 :: Exit: TakeProfit hit — TakeProfit hit: High 18085.02 ≥ TP 17678.86 (from entry 16071.69) | net=20095.11 cash=1572132.98
# 2025-10-17 15:53:58 | INFO | Selected 2 BUY candidates on 2024-12-04:
# 2025-10-17 15:53:58 | INFO |   TRENT.NS     volar=  2.01 rank=1 px= 6884.04
# 2025-10-17 15:53:58 | INFO |   NATIONALUM.NS volar=  1.73 rank=2 px=  239.98
# 2025-10-17 15:53:58 | INFO | BUY TRENT.NS     px= 6817.89 sh=    37 fee=323.14 cash=1319547.80 :: Entry: HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=83.1%; VOLAR rank 1/2 (VOLAR=2.01); Sizing=MVO (weight=64.3%)
# 2025-10-17 15:53:58 | INFO | BUY NATIONALUM.NS px=  237.23 sh=   592 fee=190.36 cash=1178916.51 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=97.7%; VOLAR rank 2/2 (VOLAR=1.73); Sizing=MVO (weight=35.7%)
# 2025-10-17 15:53:58 | INFO | Exit ECLERX.NS    px= 3674.18 shares=    51 :: Exit: TakeProfit hit — TakeProfit hit: High 3710.07 ≥ TP 3674.18 (from entry 3340.16) | net=20316.83 cash=1366058.15
# 2025-10-17 15:53:58 | INFO | Exit TRENT.NS     px= 6864.00 shares=    37 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 6817.89 | net=1072.29 cash=1619715.62
# 2025-10-17 15:53:58 | INFO | Selected 2 BUY candidates on 2024-12-05:
# 2025-10-17 15:53:58 | INFO |   JUBLPHARMA.NS volar=  1.90 rank=1 px= 1220.78
# 2025-10-17 15:53:58 | INFO |   MCX.NS       volar=  1.40 rank=2 px= 6306.91
# 2025-10-17 15:53:58 | INFO | BUY JUBLPHARMA.NS px= 1200.07 sh=   192 fee=297.19 cash=1389004.71 :: Entry: INVERTED_HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=97.2%; VOLAR rank 1/2 (VOLAR=1.90); Sizing=MVO (weight=56.9%)
# 2025-10-17 15:53:58 | INFO | BUY MCX.NS       px= 6463.56 sh=    26 fee=223.15 cash=1220728.89 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=92.5%; VOLAR rank 2/2 (VOLAR=1.40); Sizing=MVO (weight=43.1%)
# 2025-10-17 15:53:58 | INFO | Exit MCX.NS       px= 6937.60 shares=    26 :: Exit: TakeProfit hit — TakeProfit hit: High 7021.78 ≥ TP 6937.60 (from entry 6306.91) | net=11867.56 cash=1400872.27
# 2025-10-17 15:53:58 | INFO | Selected 1 BUY candidates on 2024-12-06:
# 2025-10-17 15:53:58 | INFO |   MOTILALOFS.NS volar=  2.10 rank=1 px=  971.77
# 2025-10-17 15:53:58 | INFO | BUY MOTILALOFS.NS px=  964.03 sh=   363 fee=439.12 cash=1050491.02 :: Entry: INVERTED_HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=76.5%; VOLAR rank 1/1 (VOLAR=2.10); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:58 | INFO | Exit JUBLPHARMA.NS px= 1159.74 shares=   192 :: Exit: StopLoss hit — StopLoss hit: Low 1138.14 ≤ SL 1159.74 (from entry 1220.78) | net=-8318.30 cash=1272883.63
# 2025-10-17 15:53:58 | INFO | Selected 1 BUY candidates on 2024-12-09:
# 2025-10-17 15:53:58 | INFO |   INOXWIND.NS  volar=  1.53 rank=1 px=  208.15
# 2025-10-17 15:53:58 | INFO | BUY INOXWIND.NS  px=  208.67 sh=  1524 fee=401.21 cash=954469.34 :: Entry: ENGULFING + MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=81.7%; VOLAR rank 1/1 (VOLAR=1.53); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:58 | INFO | Exit ZENTEC.NS    px= 2089.26 shares=   190 :: Exit: TakeProfit hit — TakeProfit hit: High 2094.05 ≥ TP 2089.26 (from entry 1899.32) | net=53336.02 cash=1350969.05
# 2025-10-17 15:53:58 | INFO | Selected 1 BUY candidates on 2024-12-10:
# 2025-10-17 15:53:58 | INFO |   NETWEB.NS    volar=  2.06 rank=1 px= 2929.30
# 2025-10-17 15:53:58 | INFO | BUY NETWEB.NS    px= 2894.54 sh=   116 fee=422.29 cash=1014779.80 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 1/1 (VOLAR=2.06); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:58 | INFO | Exit NATIONALUM.NS px=  227.98 shares=   592 :: Exit: StopLoss hit — StopLoss hit: Low 221.07 ≤ SL 227.98 (from entry 239.98) | net=-5854.06 cash=1149557.02
# 2025-10-17 15:53:58 | INFO | Selected 1 BUY candidates on 2024-12-12:
# 2025-10-17 15:53:58 | INFO |   GVT&D.NS     volar=  2.97 rank=1 px= 1938.15
# 2025-10-17 15:53:58 | INFO | BUY GVT&D.NS     px= 1933.31 sh=   148 fee=363.35 cash=863064.13 :: Entry: HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 1/1 (VOLAR=2.97); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:58 | INFO | Exit INOXWIND.NS  px=  197.74 shares=  1524 :: Exit: StopLoss hit — StopLoss hit: Low 193.80 ≤ SL 197.74 (from entry 208.15) | net=-17414.56 cash=1164063.86
# 2025-10-17 15:53:58 | INFO | Exit NETWEB.NS    px= 2782.84 shares=   116 :: Exit: StopLoss hit — StopLoss hit: Low 2706.77 ≤ SL 2782.84 (from entry 2929.30) | net=-13762.40 cash=1486490.70
# 2025-10-17 15:53:58 | INFO | Selected 2 BUY candidates on 2024-12-13:
# 2025-10-17 15:53:58 | INFO |   ZENTEC.NS    volar=  2.04 rank=1 px= 2110.08
# 2025-10-17 15:53:58 | INFO |   PERSISTENT.NS volar=  1.69 rank=2 px= 6381.64
# 2025-10-17 15:53:58 | INFO | BUY ZENTEC.NS    px= 2164.90 sh=    74 fee=213.83 cash=1326074.30 :: Entry: HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 1/2 (VOLAR=2.04); Sizing=MVO (weight=43.3%)
# 2025-10-17 15:53:58 | INFO | BUY PERSISTENT.NS px= 6438.90 sh=    32 fee=268.26 cash=1119761.26 :: Entry: INVERTED_HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 2/2 (VOLAR=1.69); Sizing=MVO (weight=56.7%)
# 2025-10-17 15:53:58 | INFO | Exit ZENTEC.NS    px= 2321.08 shares=    74 :: Exit: TakeProfit hit — TakeProfit hit: High 2340.55 ≥ TP 2321.08 (from entry 2110.08) | net=11118.48 cash=1291296.15
# 2025-10-17 15:53:58 | INFO | Selected 1 BUY candidates on 2024-12-16:
# 2025-10-17 15:53:58 | INFO |   VOLTAS.NS    volar=  1.72 rank=1 px= 1809.90
# 2025-10-17 15:53:58 | INFO | BUY VOLTAS.NS    px= 1798.06 sh=   179 fee=405.77 cash=969037.12 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=93.7%; VOLAR rank 1/1 (VOLAR=1.72); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:58 | INFO | Exit GVT&D.NS     px= 2131.96 shares=   148 :: Exit: TakeProfit hit — TakeProfit hit: High 2146.07 ≥ TP 2131.96 (from entry 1938.15) | net=28663.20 cash=1284193.22
# 2025-10-17 15:53:58 | INFO | Exit MOTILALOFS.NS px=  923.18 shares=   363 :: Exit: StopLoss hit — StopLoss hit: Low 921.31 ≤ SL 923.18 (from entry 971.77) | net=-15662.08 cash=1618912.39
# 2025-10-17 15:53:58 | INFO | Selected 2 BUY candidates on 2024-12-19:
# 2025-10-17 15:53:58 | INFO |   TRENT.NS     volar=  2.10 rank=1 px= 6988.95
# 2025-10-17 15:53:58 | INFO |   LUPIN.NS     volar=  1.62 rank=2 px= 2077.08
# 2025-10-17 15:53:58 | INFO | BUY TRENT.NS     px= 7085.86 sh=    26 fee=242.36 cash=1434437.64 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=86.4%; VOLAR rank 1/2 (VOLAR=2.10); Sizing=MVO (weight=46.9%)
# 2025-10-17 15:53:58 | INFO | BUY LUPIN.NS     px= 2149.48 sh=    99 fee=276.28 cash=1221362.72 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=91.7%; VOLAR rank 2/2 (VOLAR=1.62); Sizing=MVO (weight=53.1%)
# 2025-10-17 15:53:58 | INFO | Exit VOLTAS.NS    px= 1719.40 shares=   179 :: Exit: StopLoss hit — StopLoss hit: Low 1669.88 ≤ SL 1719.40 (from entry 1809.90) | net=-14852.55 cash=1528769.19
# 2025-10-17 15:53:58 | INFO | Selected 1 BUY candidates on 2024-12-20:
# 2025-10-17 15:53:58 | INFO |   GVT&D.NS     volar=  3.25 rank=1 px= 2154.05
# 2025-10-17 15:53:58 | INFO | BUY GVT&D.NS     px= 2151.81 sh=   177 fee=475.85 cash=1147423.44 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 1/1 (VOLAR=3.25); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:58 | INFO | Exit GVT&D.NS     px= 2046.35 shares=   177 :: Exit: StopLoss hit — StopLoss hit: Low 2011.31 ≤ SL 2046.35 (from entry 2154.05) | net=-19564.65 cash=1509204.54
# 2025-10-17 15:53:58 | INFO | Exit M&M.NS       px= 2886.21 shares=    61 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 2886.11 | net=-6945.17 cash=1685033.62
# 2025-10-17 15:53:58 | INFO | Selected 2 BUY candidates on 2024-12-24:
# 2025-10-17 15:53:58 | INFO |   PGEL.NS      volar=  2.38 rank=1 px=  987.56
# 2025-10-17 15:53:58 | INFO |   VOLTAS.NS    volar=  1.62 rank=2 px= 1690.56
# 2025-10-17 15:53:58 | INFO | BUY PGEL.NS      px=  966.22 sh=   168 fee=216.35 cash=1522491.63 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=95.1%; VOLAR rank 1/2 (VOLAR=2.38); Sizing=MVO (weight=38.6%)
# 2025-10-17 15:53:58 | INFO | BUY VOLTAS.NS    px= 1665.70 sh=   155 fee=330.17 cash=1263977.68 :: Entry: HARAMI + TogglesOK; Conf=[RSI>50]; 52w%=87.9%; VOLAR rank 2/2 (VOLAR=1.62); Sizing=MVO (weight=61.4%)
# 2025-10-17 15:53:58 | INFO | Exit VOLTAS.NS    px= 1667.44 shares=   155 :: Exit: Trend invalidation — Trend invalidation: EMA10<EMA20 at close 1665.70 | net=-375.75 cash=1522115.88
# 2025-10-17 15:53:58 | INFO | Selected 1 BUY candidates on 2024-12-26:
# 2025-10-17 15:53:58 | INFO |   360ONE.NS    volar=  1.41 rank=1 px= 1228.86
# 2025-10-17 15:53:58 | INFO | BUY 360ONE.NS    px= 1248.59 sh=   304 fee=474.31 cash=1142070.44 :: Entry: HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=98.8%; VOLAR rank 1/1 (VOLAR=1.41); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:58 | INFO | Exit LUPIN.NS     px= 2284.79 shares=    99 :: Exit: TakeProfit hit — TakeProfit hit: High 2314.36 ≥ TP 2284.79 (from entry 2077.08) | net=12837.39 cash=1367982.75
# 2025-10-17 15:53:58 | INFO | Selected 1 BUY candidates on 2024-12-30:
# 2025-10-17 15:53:58 | INFO |   GLENMARK.NS  volar=  1.83 rank=1 px= 1585.46
# 2025-10-17 15:53:58 | INFO | BUY GLENMARK.NS  px= 1585.91 sh=   215 fee=428.47 cash=1026583.60 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=87.2%; VOLAR rank 1/1 (VOLAR=1.83); Sizing=MVO (weight=100.0%)
# 2025-10-17 15:53:58 | INFO | Exit 360ONE.NS    px= 1247.15 shares=   304 :: Exit: Final close — end of data | net=-1352.93 cash=1405276.10
# 2025-10-17 15:53:58 | INFO | Exit GLENMARK.NS  px= 1605.16 shares=   215 :: Exit: Final close — end of data | net=3305.64 cash=1749980.89
# 2025-10-17 15:53:58 | INFO | Exit PERSISTENT.NS px= 6419.07 shares=    32 :: Exit: Final close — end of data | net=-1163.12 cash=1955130.81
# 2025-10-17 15:53:58 | INFO | Exit PGEL.NS      px=  980.17 shares=   168 :: Exit: Final close — end of data | net=1908.18 cash=2119580.99
# 2025-10-17 15:53:58 | INFO | Exit TRENT.NS     px= 7117.18 shares=    26 :: Exit: Final close — end of data | net=332.86 cash=2304388.61
# 2025-10-17 15:53:58 | INFO | Selected 5 BUY candidates on 2024-12-31:
# 2025-10-17 15:53:58 | INFO |   KFINTECH.NS  volar=  2.29 rank=1 px= 1569.49
# 2025-10-17 15:53:58 | INFO |   KAYNES.NS    volar=  1.75 rank=2 px= 7173.00
# 2025-10-17 15:53:58 | INFO |   NEWGEN.NS    volar=  1.72 rank=3 px= 1701.66
# 2025-10-17 15:53:58 | INFO |   VOLTAS.NS    volar=  1.54 rank=4 px= 1727.16
# 2025-10-17 15:53:58 | INFO |   TECHNOE.NS   volar=  1.51 rank=5 px= 1580.17
# 2025-10-17 15:53:58 | INFO | BUY KFINTECH.NS  px= 1527.03 sh=    93 fee=192.23 cash=2162182.94 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=99.4%; VOLAR rank 1/5 (VOLAR=2.29); Sizing=MVO (weight=24.8%)
# 2025-10-17 15:53:58 | INFO | BUY KAYNES.NS    px= 7417.30 sh=    13 fee=138.10 cash=2065619.95 :: Entry: MORNING_STAR + HAMMER + TogglesOK; Conf=[RSI>50]; 52w%=98.1%; VOLAR rank 2/5 (VOLAR=1.75); Sizing=MVO (weight=17.9%)
# 2025-10-17 15:53:58 | INFO | BUY NEWGEN.NS    px= 1693.50 sh=    44 fee=112.08 cash=1990993.72 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=100.0%; VOLAR rank 3/5 (VOLAR=1.72); Sizing=MVO (weight=13.2%)
# 2025-10-17 15:53:58 | INFO | BUY VOLTAS.NS    px= 1780.01 sh=   108 fee=251.87 cash=1798500.38 :: Entry: ENGULFING + TogglesOK; Conf=[RSI>50]; 52w%=91.8%; VOLAR rank 4/5 (VOLAR=1.54); Sizing=MVO (weight=33.4%)
# 2025-10-17 15:53:58 | INFO | BUY TECHNOE.NS   px= 1561.04 sh=    39 fee=95.89 cash=1737523.80 :: Entry: MORNING_STAR + TogglesOK; Conf=[RSI>50]; 52w%=89.0%; VOLAR rank 5/5 (VOLAR=1.51); Sizing=MVO (weight=10.7%)
# 2025-10-17 15:53:59 | INFO | === METRICS ===
# {
#   "start_equity_inr": 500000.0,
#   "final_equity_inr": 2303598.4515987495,
#   "cagr_pct": 18.55591037128541,
#   "sharpe": 1.5056833723238041,
#   "max_drawdown_pct": -17.90295119459726,
#   "win_rate_pct": 42.17907227615966,
#   "n_trades": 1854
# }
# 2025-10-17 15:53:59 | INFO | Files written:
#   outputs/trades_legs_20251017_155359.csv
#   outputs/trades_roundtrips_20251017_155359.csv
#   outputs/equity_20251017_155359.csv
#   outputs/metrics_20251017_155359.json
# 2025-10-17 15:53:59 | INFO |   outputs/equity_20251017_155359.png
